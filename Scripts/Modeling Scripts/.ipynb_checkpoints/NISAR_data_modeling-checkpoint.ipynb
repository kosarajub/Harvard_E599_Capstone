# %%
# Import Packages
import os
import re
import sys
import time
import copy
from pathlib import Path
from IPython.display import display

import numpy as np
import pandas as pd
from scipy import stats
from scipy.stats import boxcox

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

from sklearn.metrics import r2_score, mean_squared_error

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score, GroupKFold
from sklearn.model_selection import RepeatedKFold

from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression, RidgeCV

from sklearn.feature_selection import VarianceThreshold

from itertools import product

#%load_ext autoreload
#%reload_ext autoreload
#%autoreload 2
#from model_functions import *

# %run Model_functions.ipynb

# %%
import warnings
warnings.filterwarnings('ignore', category=UserWarning, module='sklearn')

# !chmod 644 ~/.local/share/jupyter/history.sqlite
#!rm ~/.local/share/jupyter/history.sqlite
# Out:
# chmod: /Users/kosaraju_b/.local/share/jupyter/history.sqlite: No such file or directory

# %% [markdown]
# # DOWNLOAD NISAR-AGB-CANOPY DATA

# %%
NISAR_DATA_CSV = "../../DATA/AGB_DATA/Merged_Data/NISAR/Nisar_AGB_CANOPY.csv"

nisar_df = pd.read_csv(NISAR_DATA_CSV)
print(nisar_df.shape)
nisar_df.columns
# Out:
# (3176, 15)
# Index(['dataset', 'plot_id', 'start_date', 'end_date', 'latitude', 'longitude',
#        'diameter', 'height', 'species', 'plant_AGB_kg', 'date',
#        'nisar_value_hvhv', 'nisar_value_hhhh', 'simard_height_m',
#        'tandemx_height_m'],
#       dtype='object')

# %%
assert len(nisar_df["simard_height_m"].head())
assert len(nisar_df["tandemx_height_m"].head())

# %%
nisar_df['dataset'].unique()
# Out:
# array(['ElSalvador', 'Brazil-Mangue', 'Brazil-Furo_Do_Chato',
#        'Brazil-Maruipe', 'Brazil-BocaGrande', 'Brazil-Barreto',
#        'Brazil-Salinas', 'Brazil-FuroGrande', 'Brazil-Caetano'],
#       dtype=object)

# %% [markdown]
# ### Select features

# %%
non_feature_cols = [
    #'plant_AGB_kg',       # Target variable
    'dataset',             # metadata
    'start_date',          # metadata
    'end_date',            # metadata
    'capture_start',       # metadata
    'capture_end',         # metadata
    'latitude',           # coordinate
    'longitude',          # coordinate
    'diameter',            # Allometric
    'height',              # Allometric
    'cloud_threshold_used'
]

nisar_bands = ['nisar_value_hhhh', 'nisar_value_hvhv']
useful_categorical = ['plot_id', 'species']
struct_features = ['height']

target = 'plant_AGB_kg'
feature_cols = [c for c in nisar_df.columns if c not in non_feature_cols]

X = nisar_df[feature_cols]
y = nisar_df[target]

# Select TANDEMX
X = X.rename({'tandemx_height_m': 'height'}, axis=1)
X = X.drop(columns=['simard_height_m'])

# Select SIMARD
#X = X.rename({'simard_height_m': 'height'}, axis=1)
#X = X.drop(columns=['tandemx_height_m'])

print(f"Features: {feature_cols}")
# Out:
# Features: ['plot_id', 'species', 'plant_AGB_kg', 'date', 'nisar_value_hvhv', 'nisar_value_hhhh', 'simard_height_m', 'tandemx_height_m']

# %%
# Retain the groups/plot_id for splitting the data based on groups.
plot_groups = X['plot_id'].copy()
site_groups = plot_groups.map(lambda x: x.rsplit('_', maxsplit=1)[0])

# %% [markdown]
# ## DATA PREPROCESSING

# %%
null_rows   = X[X.isnull().any(axis=1)]
total_nulls = X.isnull().sum().sum()

print(f"Total NULL count           : {total_nulls}")
print(f"Rows with at least one NULL: {len(null_rows)}")
print(f"Total rows                 : {len(X)}")
print(f"Percentage                 : {len(null_rows)/len(X)*100:.1f}%")

# NULL count per column for only the affected rows
null_col_counts = null_rows.isnull().sum().sort_values(ascending=False)
print("\nNULL count per column in affected rows:")
print(null_col_counts[null_col_counts > 0])
# Out:
# Total NULL count           : 0
# Rows with at least one NULL: 0
# Total rows                 : 3176
# Percentage                 : 0.0%
#
# NULL count per column in affected rows:
# Series([], dtype: int64)

# %%
assert not total_nulls
#X = handle_null_data(X)
#X = X.dropna()
#print(X.shape)
#X.columns

# %% [markdown]
# ### Find correlations

# %%
numerical_cols = get_numerical_cols(X)
target_corr = plot_correlation_matrix(X[numerical_cols],
                                      X['plant_AGB_kg'],
                                      top_n=20)
print(target_corr)
# Out:
# height              0.214328
# nisar_value_hhhh    0.127950
# nisar_value_hvhv    0.081804
# Name: plant_AGB_kg, dtype: float64

# %% [markdown]
# **COMMENTS:**
# Columns with a Pearson correlation coefficient (r) between -0.1 and 0.1 with the target variable are generally considered to have a negligible or very weak relationship.

# %% [markdown]
# ### Remove Low Variance Features (cols)

# %% [raw]
# X = remove_low_variance_cols(X,
#                              exclude_cols=[],
#                              threshold=0.01,
#                              debug=True,
#                              exclude_categorical=True)
# assert X is not None
#
# X.columns

# %% [markdown]
# #### Is variance threshold valid for sentinel-2 data?

# %% [markdown]
# - Sentinel-2 surface reflectance values are typically in the range 0.0 to 0.3.
#  - Their absolute variance is naturally small — not because they carry no information but because their scale is small.
#  - A feature with values ranging from 0.05 to 0.25 has variance of ~0.003, which falls below the 0.01 threshold, but the variation within that range is meaningful for AGB prediction.
#  - VarianceThreshold is designed for features with near-identical values across all rows — like a binary column that is always 0.
#  - It is not appropriate for bounded continuous features like reflectance values.

# %% [markdown]
# ### Remove Features With Weak Correlation to Target

# %% [raw]
# corr_threshold = 0.1
# X = remove_uncorrelated_numerical_cols(X, y,
#                                        threshold=corr_threshold,
#                                        exclude_cols=[])
# assert belige_df is not None
#
# X.columns

# %% [markdown]
# #### Why Pearson correlation is unreliable here?
#
# Pearson correlation measures linear relationship between a feature and the target.
#
# The above correlation removal process is based on the correlations computed against the original y. But we are going log-transform the target for modeling.
#
# A feature can have a strong non-linear relationship with AGB that shows up clearly after log transformation but appears weak in linear correlation against raw AGB.
#
# The experiments (Belige-data-analysis.ipynb) already proved these features are useful.

# %%
X = remove_uncorrelated_categorical_cols(X, y)
assert X is not None

X.columns
# Out:
# --- plot_id ---
# Variable  : plot_id
# F-stat    : 4.8546
# p-value   : 0.0000
# Relevant? : True
#
# --- species ---
# Variable  : species
# F-stat    : 20.7686
# p-value   : 0.0000
# Relevant? : True
#
# --- date ---
# date : skipped — fewer than 2 valid groups after filtering
#
#    feature  relevant?
# 0  plot_id       True
# 1  species       True
# 2     date      False
#
#
# Strong correlations kept   : 6
# Weak correlations removed: 1
# Index(['plot_id', 'species', 'plant_AGB_kg', 'nisar_value_hvhv',
#        'nisar_value_hhhh', 'height'],
#       dtype='object')

# %% [markdown]
# ### Convert categorical variables to one-hot encoding

# %% [raw]
# # Retain the groups/plot_id for splitting the data based on groups.
# #groups = X['plot_id'].copy()
#
# categorical_cols = get_categorical_cols(X)
# X = pd.get_dummies(X, columns=categorical_cols, dtype=int)

# %% [markdown]
# # What would actually constitute a good result?
# For a model to be trustworthy you would want to see:
#  - Grouped CV mean above 0.40
#  - Grouped CV std below 0.15
#  - No individual grouped CV fold below -0.10
#  - Regular CV and grouped CV in the same ballpark — large divergence between them signals leakage
#  - Test R² close to grouped CV mean, not far above it

# %%
# %run Model_functions.ipynb

# %% [markdown]
# **Determine near_zero_threshold, and high_agb_threshold**
# **near_zero_threshold = 1.0 kg**
#  - Any site where the heaviest plant weighs less than 1 kg has near-zero AGB variance.
#  - From your data Frenchman Caye (max 0.26 kg) and Shipstern (max 0.94 kg) fall below this.
#  - R² is meaningless for these sites as a holdout set.
#  - In other words, R² is mathematically unstable when the holdout set has near-zero variance.
#
# **R² is defined as:** 1 - (sum of squared residuals / total sum of squares)
# **Total sum of squares is (denominator):** sum of (y - mean(y))²
# **Problem:**
#  - When every plant in the holdout site weighs between 0.001 and 0.26 kg, the mean is ~0.03 kg and every value is very close to that mean.
#  - This makes the total sum of squares as near-zero.
#  - Any prediction error, however small will produce a large negative R² because of the near-zero denominator.
#
# **high_agb_threshold = 100.0 kg**
#  - Any site with trees above 100 kg is potentially ecologically distinct from the rest.
#  - From your data Channel Caye (max 427 kg) and New River (max 261 kg) fall above this.
#  - These are the sites where generalization failure is a genuine concern.

# %%
near_zero_sites, high_agb_sites, near_zero_plots, high_agb_plots = \
    get_low_and_high_agb_plots(y, plot_groups)
# Out:
# High-AGB threshold  : 3110.16 kg
# Near-zero threshold : 0.002791
#
# Near-zero variance plots:
#
# High-AGB plots:
#   BOC_Boca Grande           : max AGB = 5572.3 kg
#   CAE_Caetano               : max AGB = 5248.5 kg
#   El_Plan_de_la_Ceiba_8_1   : max AGB = 5199.1 kg
#   El_Plan_de_la_Ceiba_8_3   : max AGB = 3403.8 kg
#   El_Plan_de_la_Ceiba_8_6   : max AGB = 5765.0 kg
#   MAN_Mangue Sul            : max AGB = 7172.7 kg
#   Montecristo_21_2          : max AGB = 4711.5 kg
#   Montecristo_21_3          : max AGB = 5765.0 kg
#   Montecristo_22_2          : max AGB = 9617.2 kg
#   Montecristo_22_3          : max AGB = 11337.3 kg
#   Montecristo_22_4          : max AGB = 3179.8 kg
#
# within-site high-AGB plots
# Bordo_del_Chile_23   : within-site high-AGB plots = ['Bordo_del_Chile_23_2']
# Santo_Domingo_5      : within-site high-AGB plots = ['Santo_Domingo_5_2']
# El_Espino_6          : within-site high-AGB plots = ['El_Espino_6_1']
# La_Herradura_7       : within-site high-AGB plots = ['La_Herradura_7_2']
# San_Antonio_Los_Blancos_12 : within-site high-AGB plots = ['San_Antonio_Los_Blancos_12_4']
# San_Sebastián_El_Chingo_16 : within-site high-AGB plots = ['San_Sebastián_El_Chingo_16_5']
# El_Aguacate_24       : within-site high-AGB plots = ['El_Aguacate_24_1']
#
# Near-zero sites: []
# High-AGB sites : ['BOC', 'Bordo_del_Chile_23', 'CAE', 'El_Aguacate_24', 'El_Espino_6', 'El_Plan_de_la_Ceiba_8', 'La_Herradura_7', 'MAN', 'Montecristo_21', 'Montecristo_22', 'San_Antonio_Los_Blancos_12', 'San_Sebastián_El_Chingo_16', 'Santo_Domingo_5']

# %%
features_list = [struct_features, 
                 struct_features + useful_categorical,
                 struct_features + nisar_bands,
                 nisar_bands,
                 nisar_bands + useful_categorical,
                 nisar_bands + struct_features + useful_categorical]

model_list = ["regular", "ridge", "lasso", "elasticnet"]

test_cv = 5
#test_cv = RepeatedKFold(n_splits=5, n_repeats=10, random_state=42)

# %%
# Group by dataset instead of plot/site
dataset_groups = nisar_df['dataset']

# %% [markdown]
# # LINEAR REGRESSION

# %%
# %run Model_functions.ipynb
lin_experiments = {}

# %%
def run_lin_experiment(model_type, X_df, y, features,
                       is_groups, groups, test_cv, idx,label_in):
    label = f"EXPERIMENT-{idx} {label_in}, Model: {model_type}, Features: {features}"
    
    X = X_df[features]
    categorical_cols = get_categorical_cols(X)
    if categorical_cols:
        X = pd.get_dummies(X, columns=categorical_cols, dtype=int)

    if is_groups:
        results = linear_reg_logo(model_type, X, y, test_cv, groups, label)
    else:
        results = linear_reg_regular(model_type, X, y, test_cv, label)
    lin_experiments[label] = results

    if is_groups:
        evaluate_experiment(label="",
                            results=results,
                            fold_sites=results["fold_sites"],
                            near_zero_sites=near_zero_sites,
                            high_agb_sites =high_agb_sites)
    else:
        evaluate_experiment(label="",
                            results=results,
                            fold_sites=None,
                            near_zero_sites=near_zero_plots,
                            high_agb_sites =high_agb_plots)

# %%
def lin_experiment(X, y, is_groups, groups, features_list, label):
    total     = len(features_list) * len(model_list)
    completed = 0

    for (feat_idx, features), (model_type) in product(enumerate(features_list), model_list):
        completed += 1
        print(f"\n[{completed}/{total}] {model_type}{features}")
    
        try:
            run_lin_experiment(model_type, X, y, features,
                               is_groups, groups, test_cv,
                               completed, label)        
        except Exception as e:
            print(f"  ERROR: {e}")
    print(f"\nCompleted: {completed}/{total} experiments")

# %% [markdown]
# ### Linear regression without groups.

# %%
lin_experiment(X, y,
               is_groups=False, groups=None,
               features_list=features_list,
               label="No groups")
# 1st-EXPERIMENT: No groups. Linear regression variants.
# Out:
# [1/24] regular['height']
#
#  EXPERIMENT-1 No groups, Model: regular, Features: ['height'], ALGO: LINEAR REGRESSION:
# Test R²     : -0.0499
# Test RMSE   : 453.88 kg
# Train R² (log scale): 0.0135
# Train R² (orig scale): -0.0450
# Train RMSE  : 569.50 kg
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: 0.0069
# CV R² std : 0.0103
# CV scores : [ 0.017  0.006 -0.008 -0.     0.02 ]
# ============================================================
# EXPERIMENT EVALUATION:
# ============================================================
#
# Test set:
#   R²   : -0.050
#   RMSE : 453.88 kg
#
# Regular CrossValidation:
#   Mean   : 0.007
#   Std    : 0.010
#   Scores : [ 0.017  0.006 -0.008 -0.     0.02 ]
#
#   ❌ Test R² is negative (-0.050)
#   ✅ CV mean is positive (0.007)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ NOT ACCEPTABLE
#
# [2/24] ridge['height']
#
#  EXPERIMENT-2 No groups, Model: ridge, Features: ['height'], ALGO: RIDGE REGRESSION:
# Test R²     : -0.0501
# Test RMSE   : 453.91 kg
# Train R² (log scale): 0.0135
# Train R² (orig scale): -0.0452
# Train RMSE  : 569.56 kg
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: 0.0070
# CV R² std : 0.0096
# CV scores : [ 0.016  0.006 -0.006  0.     0.019]
# ============================================================
# EXPERIMENT EVALUATION:
# ============================================================
#
# Test set:
#   R²   : -0.050
#   RMSE : 453.91 kg
#
# Regular CrossValidation:
#   Mean   : 0.007
#   Std    : 0.010
#   Scores : [ 0.016  0.006 -0.006  0.     0.019]
#
#   ❌ Test R² is negative (-0.050)
#   ✅ CV mean is positive (0.007)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ NOT ACCEPTABLE
#
# [3/24] lasso['height']
#
#  EXPERIMENT-3 No groups, Model: lasso, Features: ['height'], ALGO: LASSO REGRESSION:
# Test R²     : -0.0500
# Test RMSE   : 453.88 kg
# Train R² (log scale): 0.0135
# Train R² (orig scale): -0.0450
# Train RMSE  : 569.51 kg
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: 0.0069
# CV R² std : 0.0102
# CV scores : [ 0.017  0.006 -0.007 -0.     0.02 ]
# ============================================================
# EXPERIMENT EVALUATION:
# ============================================================
#
# Test set:
#   R²   : -0.050
#   RMSE : 453.88 kg
#
# Regular CrossValidation:
#   Mean   : 0.007
#   Std    : 0.010
#   Scores : [ 0.017  0.006 -0.007 -0.     0.02 ]
#
#   ❌ Test R² is negative (-0.050)
#   ✅ CV mean is positive (0.007)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ NOT ACCEPTABLE
#
# [4/24] elasticnet['height']
#
#  EXPERIMENT-4 No groups, Model: elasticnet, Features: ['height'], ALGO: ELASTICNET REGRESSION:
# Test R²     : -0.0500
# Test RMSE   : 453.90 kg
# Train R² (log scale): 0.0135
# Train R² (orig scale): -0.0451
# Train RMSE  : 569.53 kg
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: 0.0069
# CV R² std : 0.0100
# CV scores : [ 0.017  0.006 -0.007 -0.     0.02 ]
# ============================================================
# EXPERIMENT EVALUATION:
# ============================================================
#
# Test set:
#   R²   : -0.050
#   RMSE : 453.90 kg
#
# Regular CrossValidation:
#   Mean   : 0.007
#   Std    : 0.010
#   Scores : [ 0.017  0.006 -0.007 -0.     0.02 ]
#
#   ❌ Test R² is negative (-0.050)
#   ✅ CV mean is positive (0.007)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ NOT ACCEPTABLE
#
# [5/24] regular['height', 'plot_id', 'species']
#
#  EXPERIMENT-5 No groups, Model: regular, Features: ['height', 'plot_id', 'species'], ALGO: LINEAR REGRESSION:
# Test R²     : -0.3785
# Test RMSE   : 520.06 kg
# Train R² (log scale): 0.5110
# Train R² (orig scale): 0.0099
# Train RMSE  : 554.34 kg
# Num Features: 148
#
#  Cross-validation ---
# CV R² mean: 0.4216
# CV R² std : 0.0292
# CV scores : [0.39  0.403 0.47  0.439 0.405]
# ============================================================
# EXPERIMENT EVALUATION:
# ============================================================
#
# Test set:
#   R²   : -0.378
#   RMSE : 520.06 kg
#
# Regular CrossValidation:
#   Mean   : 0.422
#   Std    : 0.029
#   Scores : [0.39  0.403 0.47  0.439 0.405]
#
#   ❌ Test R² is negative (-0.378)
#   ✅ CV mean is positive (0.422)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ NOT ACCEPTABLE
#
# [6/24] ridge['height', 'plot_id', 'species']
#
#  EXPERIMENT-6 No groups, Model: ridge, Features: ['height', 'plot_id', 'species'], ALGO: RIDGE REGRESSION:
# Test R²     : 0.0005
# Test RMSE   : 442.85 kg
# Train R² (log scale): 0.5099
# Train R² (orig scale): 0.0067
# Train RMSE  : 555.24 kg
# Num Features: 148
#
#  Cross-validation ---
# CV R² mean: 0.4273
# CV R² std : 0.0271
# CV scores : [0.4   0.413 0.473 0.442 0.408]
# ============================================================
# EXPERIMENT EVALUATION:
# ============================================================
#
# Test set:
#   R²   : 0.000
#   RMSE : 442.85 kg
#
# Regular CrossValidation:
#   Mean   : 0.427
#   Std    : 0.027
#   Scores : [0.4   0.413 0.473 0.442 0.408]
#
#   ✅ Test R² is positive (0.000)
#   ✅ CV mean is positive (0.427)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ✅ ACCEPTABLE
#
# [7/24] lasso['height', 'plot_id', 'species']
#
#  EXPERIMENT-7 No groups, Model: lasso, Features: ['height', 'plot_id', 'species'], ALGO: LASSO REGRESSION:
# Test R²     : 0.0096
# Test RMSE   : 440.82 kg
# Train R² (log scale): 0.5059
# Train R² (orig scale): 0.0031
# Train RMSE  : 556.25 kg
# Num Features: 148
#
#  Cross-validation ---
# CV R² mean: 0.4315
# CV R² std : 0.0275
# CV scores : [0.403 0.419 0.481 0.44  0.414]
# ============================================================
# EXPERIMENT EVALUATION:
# ============================================================
#
# Test set:
#   R²   : 0.010
#   RMSE : 440.82 kg
#
# Regular CrossValidation:
#   Mean   : 0.431
#   Std    : 0.028
#   Scores : [0.403 0.419 0.481 0.44  0.414]
#
#   ✅ Test R² is positive (0.010)
#   ✅ CV mean is positive (0.431)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ✅ ACCEPTABLE
#
# [8/24] elasticnet['height', 'plot_id', 'species']
#
#  EXPERIMENT-8 No groups, Model: elasticnet, Features: ['height', 'plot_id', 'species'], ALGO: ELASTICNET REGRESSION:
# Test R²     : 0.0105
# Test RMSE   : 440.64 kg
# Train R² (log scale): 0.5074
# Train R² (orig scale): 0.0043
# Train RMSE  : 555.90 kg
# Num Features: 148
#
#  Cross-validation ---
# CV R² mean: 0.4306
# CV R² std : 0.0273
# CV scores : [0.407 0.419 0.479 0.441 0.407]
# ============================================================
# EXPERIMENT EVALUATION:
# ============================================================
#
# Test set:
#   R²   : 0.010
#   RMSE : 440.64 kg
#
# Regular CrossValidation:
#   Mean   : 0.431
#   Std    : 0.027
#   Scores : [0.407 0.419 0.479 0.441 0.407]
#
#   ✅ Test R² is positive (0.010)
#   ✅ CV mean is positive (0.431)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ✅ ACCEPTABLE
#
# [9/24] regular['height', 'nisar_value_hhhh', 'nisar_value_hvhv']
#
#  EXPERIMENT-9 No groups, Model: regular, Features: ['height', 'nisar_value_hhhh', 'nisar_value_hvhv'], ALGO: LINEAR REGRESSION:
# Test R²     : -0.0445
# Test RMSE   : 452.71 kg
# Train R² (log scale): 0.0594
# Train R² (orig scale): -0.0404
# Train RMSE  : 568.24 kg
# Num Features: 3
#
#  Cross-validation ---
# CV R² mean: 0.0495
# CV R² std : 0.0168
# CV scores : [0.073 0.021 0.056 0.052 0.046]
# ============================================================
# EXPERIMENT EVALUATION:
# ============================================================
#
# Test set:
#   R²   : -0.045
#   RMSE : 452.71 kg
#
# Regular CrossValidation:
#   Mean   : 0.050
#   Std    : 0.017
#   Scores : [0.073 0.021 0.056 0.052 0.046]
#
#   ❌ Test R² is negative (-0.045)
#   ✅ CV mean is positive (0.050)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ NOT ACCEPTABLE
#
# [10/24] ridge['height', 'nisar_value_hhhh', 'nisar_value_hvhv']
#
#  EXPERIMENT-10 No groups, Model: ridge, Features: ['height', 'nisar_value_hhhh', 'nisar_value_hvhv'], ALGO: RIDGE REGRESSION:
# Test R²     : -0.0446
# Test RMSE   : 452.72 kg
# Train R² (log scale): 0.0594
# Train R² (orig scale): -0.0404
# Train RMSE  : 568.26 kg
# Num Features: 3
#
#  Cross-validation ---
# CV R² mean: 0.0499
# CV R² std : 0.0166
# CV scores : [0.072 0.021 0.056 0.052 0.048]
# ============================================================
# EXPERIMENT EVALUATION:
# ============================================================
#
# Test set:
#   R²   : -0.045
#   RMSE : 452.72 kg
#
# Regular CrossValidation:
#   Mean   : 0.050
#   Std    : 0.017
#   Scores : [0.072 0.021 0.056 0.052 0.048]
#
#   ❌ Test R² is negative (-0.045)
#   ✅ CV mean is positive (0.050)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ NOT ACCEPTABLE
#
# [11/24] lasso['height', 'nisar_value_hhhh', 'nisar_value_hvhv']
#
#  EXPERIMENT-11 No groups, Model: lasso, Features: ['height', 'nisar_value_hhhh', 'nisar_value_hvhv'], ALGO: LASSO REGRESSION:
# Test R²     : -0.0446
# Test RMSE   : 452.72 kg
# Train R² (log scale): 0.0594
# Train R² (orig scale): -0.0404
# Train RMSE  : 568.25 kg
# Num Features: 3
#
#  Cross-validation ---
# CV R² mean: 0.0495
# CV R² std : 0.0167
# CV scores : [0.072 0.021 0.056 0.052 0.046]
# ============================================================
# EXPERIMENT EVALUATION:
# ============================================================
#
# Test set:
#   R²   : -0.045
#   RMSE : 452.72 kg
#
# Regular CrossValidation:
#   Mean   : 0.050
#   Std    : 0.017
#   Scores : [0.072 0.021 0.056 0.052 0.046]
#
#   ❌ Test R² is negative (-0.045)
#   ✅ CV mean is positive (0.050)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ NOT ACCEPTABLE
#
# [12/24] elasticnet['height', 'nisar_value_hhhh', 'nisar_value_hvhv']
#
#  EXPERIMENT-12 No groups, Model: elasticnet, Features: ['height', 'nisar_value_hhhh', 'nisar_value_hvhv'], ALGO: ELASTICNET REGRESSION:
# Test R²     : -0.0448
# Test RMSE   : 452.76 kg
# Train R² (log scale): 0.0594
# Train R² (orig scale): -0.0407
# Train RMSE  : 568.32 kg
# Num Features: 3
#
#  Cross-validation ---
# CV R² mean: 0.0496
# CV R² std : 0.0168
# CV scores : [0.073 0.021 0.056 0.052 0.047]
# ============================================================
# EXPERIMENT EVALUATION:
# ============================================================
#
# Test set:
#   R²   : -0.045
#   RMSE : 452.76 kg
#
# Regular CrossValidation:
#   Mean   : 0.050
#   Std    : 0.017
#   Scores : [0.073 0.021 0.056 0.052 0.047]
#
#   ❌ Test R² is negative (-0.045)
#   ✅ CV mean is positive (0.050)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ NOT ACCEPTABLE
#
# [13/24] regular['nisar_value_hhhh', 'nisar_value_hvhv']
#
#  EXPERIMENT-13 No groups, Model: regular, Features: ['nisar_value_hhhh', 'nisar_value_hvhv'], ALGO: LINEAR REGRESSION:
# Test R²     : -0.0461
# Test RMSE   : 453.04 kg
# Train R² (log scale): 0.0480
# Train R² (orig scale): -0.0443
# Train RMSE  : 569.32 kg
# Num Features: 2
#
#  Cross-validation ---
# CV R² mean: 0.0407
# CV R² std : 0.0204
# CV scores : [0.047 0.011 0.07  0.049 0.026]
# ============================================================
# EXPERIMENT EVALUATION:
# ============================================================
#
# Test set:
#   R²   : -0.046
#   RMSE : 453.04 kg
#
# Regular CrossValidation:
#   Mean   : 0.041
#   Std    : 0.020
#   Scores : [0.047 0.011 0.07  0.049 0.026]
#
#   ❌ Test R² is negative (-0.046)
#   ✅ CV mean is positive (0.041)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ NOT ACCEPTABLE
#
# [14/24] ridge['nisar_value_hhhh', 'nisar_value_hvhv']
#
#  EXPERIMENT-14 No groups, Model: ridge, Features: ['nisar_value_hhhh', 'nisar_value_hvhv'], ALGO: RIDGE REGRESSION:
# Test R²     : -0.0461
# Test RMSE   : 453.06 kg
# Train R² (log scale): 0.0480
# Train R² (orig scale): -0.0444
# Train RMSE  : 569.33 kg
# Num Features: 2
#
#  Cross-validation ---
# CV R² mean: 0.0407
# CV R² std : 0.0203
# CV scores : [0.047 0.011 0.07  0.049 0.026]
# ============================================================
# EXPERIMENT EVALUATION:
# ============================================================
#
# Test set:
#   R²   : -0.046
#   RMSE : 453.06 kg
#
# Regular CrossValidation:
#   Mean   : 0.041
#   Std    : 0.020
#   Scores : [0.047 0.011 0.07  0.049 0.026]
#
#   ❌ Test R² is negative (-0.046)
#   ✅ CV mean is positive (0.041)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ NOT ACCEPTABLE
#
# [15/24] lasso['nisar_value_hhhh', 'nisar_value_hvhv']
#
#  EXPERIMENT-15 No groups, Model: lasso, Features: ['nisar_value_hhhh', 'nisar_value_hvhv'], ALGO: LASSO REGRESSION:
# Test R²     : -0.0461
# Test RMSE   : 453.05 kg
# Train R² (log scale): 0.0480
# Train R² (orig scale): -0.0444
# Train RMSE  : 569.33 kg
# Num Features: 2
#
#  Cross-validation ---
# CV R² mean: 0.0407
# CV R² std : 0.0203
# CV scores : [0.047 0.011 0.07  0.049 0.026]
# ============================================================
# EXPERIMENT EVALUATION:
# ============================================================
#
# Test set:
#   R²   : -0.046
#   RMSE : 453.05 kg
#
# Regular CrossValidation:
#   Mean   : 0.041
#   Std    : 0.020
#   Scores : [0.047 0.011 0.07  0.049 0.026]
#
#   ❌ Test R² is negative (-0.046)
#   ✅ CV mean is positive (0.041)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ NOT ACCEPTABLE
#
# [16/24] elasticnet['nisar_value_hhhh', 'nisar_value_hvhv']
#
#  EXPERIMENT-16 No groups, Model: elasticnet, Features: ['nisar_value_hhhh', 'nisar_value_hvhv'], ALGO: ELASTICNET REGRESSION:
# Test R²     : -0.0461
# Test RMSE   : 453.05 kg
# Train R² (log scale): 0.0480
# Train R² (orig scale): -0.0443
# Train RMSE  : 569.32 kg
# Num Features: 2
#
#  Cross-validation ---
# CV R² mean: 0.0407
# CV R² std : 0.0201
# CV scores : [0.047 0.011 0.07  0.049 0.027]
# ============================================================
# EXPERIMENT EVALUATION:
# ============================================================
#
# Test set:
#   R²   : -0.046
#   RMSE : 453.05 kg
#
# Regular CrossValidation:
#   Mean   : 0.041
#   Std    : 0.020
#   Scores : [0.047 0.011 0.07  0.049 0.027]
#
#   ❌ Test R² is negative (-0.046)
#   ✅ CV mean is positive (0.041)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ NOT ACCEPTABLE
#
# [17/24] regular['nisar_value_hhhh', 'nisar_value_hvhv', 'plot_id', 'species']
#
#  EXPERIMENT-17 No groups, Model: regular, Features: ['nisar_value_hhhh', 'nisar_value_hvhv', 'plot_id', 'species'], ALGO: LINEAR REGRESSION:
# Test R²     : -0.3796
# Test RMSE   : 520.28 kg
# Train R² (log scale): 0.5113
# Train R² (orig scale): 0.0095
# Train RMSE  : 554.45 kg
# Num Features: 149
#
#  Cross-validation ---
# CV R² mean: 0.4222
# CV R² std : 0.0295
# CV scores : [0.392 0.404 0.473 0.438 0.404]
# ============================================================
# EXPERIMENT EVALUATION:
# ============================================================
#
# Test set:
#   R²   : -0.380
#   RMSE : 520.28 kg
#
# Regular CrossValidation:
#   Mean   : 0.422
#   Std    : 0.030
#   Scores : [0.392 0.404 0.473 0.438 0.404]
#
#   ❌ Test R² is negative (-0.380)
#   ✅ CV mean is positive (0.422)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ NOT ACCEPTABLE
#
# [18/24] ridge['nisar_value_hhhh', 'nisar_value_hvhv', 'plot_id', 'species']
#
#  EXPERIMENT-18 No groups, Model: ridge, Features: ['nisar_value_hhhh', 'nisar_value_hvhv', 'plot_id', 'species'], ALGO: RIDGE REGRESSION:
# Test R²     : 0.0003
# Test RMSE   : 442.88 kg
# Train R² (log scale): 0.5103
# Train R² (orig scale): 0.0063
# Train RMSE  : 555.35 kg
# Num Features: 149
#
#  Cross-validation ---
# CV R² mean: 0.4273
# CV R² std : 0.0274
# CV scores : [0.4   0.413 0.475 0.441 0.408]
# ============================================================
# EXPERIMENT EVALUATION:
# ============================================================
#
# Test set:
#   R²   : 0.000
#   RMSE : 442.88 kg
#
# Regular CrossValidation:
#   Mean   : 0.427
#   Std    : 0.027
#   Scores : [0.4   0.413 0.475 0.441 0.408]
#
#   ✅ Test R² is positive (0.000)
#   ✅ CV mean is positive (0.427)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ✅ ACCEPTABLE
#
# [19/24] lasso['nisar_value_hhhh', 'nisar_value_hvhv', 'plot_id', 'species']
#
#  EXPERIMENT-19 No groups, Model: lasso, Features: ['nisar_value_hhhh', 'nisar_value_hvhv', 'plot_id', 'species'], ALGO: LASSO REGRESSION:
# Test R²     : 0.0092
# Test RMSE   : 440.92 kg
# Train R² (log scale): 0.5053
# Train R² (orig scale): 0.0030
# Train RMSE  : 556.28 kg
# Num Features: 149
#
#  Cross-validation ---
# CV R² mean: 0.4291
# CV R² std : 0.0268
# CV scores : [0.402 0.418 0.477 0.439 0.41 ]
# ============================================================
# EXPERIMENT EVALUATION:
# ============================================================
#
# Test set:
#   R²   : 0.009
#   RMSE : 440.92 kg
#
# Regular CrossValidation:
#   Mean   : 0.429
#   Std    : 0.027
#   Scores : [0.402 0.418 0.477 0.439 0.41 ]
#
#   ✅ Test R² is positive (0.009)
#   ✅ CV mean is positive (0.429)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ✅ ACCEPTABLE
#
# [20/24] elasticnet['nisar_value_hhhh', 'nisar_value_hvhv', 'plot_id', 'species']
#
#  EXPERIMENT-20 No groups, Model: elasticnet, Features: ['nisar_value_hhhh', 'nisar_value_hvhv', 'plot_id', 'species'], ALGO: ELASTICNET REGRESSION:
# Test R²     : 0.0100
# Test RMSE   : 440.74 kg
# Train R² (log scale): 0.5069
# Train R² (orig scale): 0.0042
# Train RMSE  : 555.93 kg
# Num Features: 149
#
#  Cross-validation ---
# CV R² mean: 0.4283
# CV R² std : 0.0271
# CV scores : [0.406 0.417 0.476 0.44  0.403]
# ============================================================
# EXPERIMENT EVALUATION:
# ============================================================
#
# Test set:
#   R²   : 0.010
#   RMSE : 440.74 kg
#
# Regular CrossValidation:
#   Mean   : 0.428
#   Std    : 0.027
#   Scores : [0.406 0.417 0.476 0.44  0.403]
#
#   ✅ Test R² is positive (0.010)
#   ✅ CV mean is positive (0.428)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ✅ ACCEPTABLE
#
# [21/24] regular['nisar_value_hhhh', 'nisar_value_hvhv', 'height', 'plot_id', 'species']
#
#  EXPERIMENT-21 No groups, Model: regular, Features: ['nisar_value_hhhh', 'nisar_value_hvhv', 'height', 'plot_id', 'species'], ALGO: LINEAR REGRESSION:
# Test R²     : -0.3788
# Test RMSE   : 520.14 kg
# Train R² (log scale): 0.5117
# Train R² (orig scale): 0.0096
# Train RMSE  : 554.43 kg
# Num Features: 150
#
#  Cross-validation ---
# CV R² mean: 0.4216
# CV R² std : 0.0287
# CV scores : [0.391 0.404 0.471 0.437 0.406]
# ============================================================
# EXPERIMENT EVALUATION:
# ============================================================
#
# Test set:
#   R²   : -0.379
#   RMSE : 520.14 kg
#
# Regular CrossValidation:
#   Mean   : 0.422
#   Std    : 0.029
#   Scores : [0.391 0.404 0.471 0.437 0.406]
#
#   ❌ Test R² is negative (-0.379)
#   ✅ CV mean is positive (0.422)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ NOT ACCEPTABLE
#
# [22/24] ridge['nisar_value_hhhh', 'nisar_value_hvhv', 'height', 'plot_id', 'species']
#
#  EXPERIMENT-22 No groups, Model: ridge, Features: ['nisar_value_hhhh', 'nisar_value_hvhv', 'height', 'plot_id', 'species'], ALGO: RIDGE REGRESSION:
# Test R²     : 0.0006
# Test RMSE   : 442.83 kg
# Train R² (log scale): 0.5105
# Train R² (orig scale): 0.0065
# Train RMSE  : 555.29 kg
# Num Features: 150
#
#  Cross-validation ---
# CV R² mean: 0.4275
# CV R² std : 0.0272
# CV scores : [0.4   0.414 0.474 0.441 0.409]
# ============================================================
# EXPERIMENT EVALUATION:
# ============================================================
#
# Test set:
#   R²   : 0.001
#   RMSE : 442.83 kg
#
# Regular CrossValidation:
#   Mean   : 0.428
#   Std    : 0.027
#   Scores : [0.4   0.414 0.474 0.441 0.409]
#
#   ✅ Test R² is positive (0.001)
#   ✅ CV mean is positive (0.428)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ✅ ACCEPTABLE
#
# [23/24] lasso['nisar_value_hhhh', 'nisar_value_hvhv', 'height', 'plot_id', 'species']
#
#  EXPERIMENT-23 No groups, Model: lasso, Features: ['nisar_value_hhhh', 'nisar_value_hvhv', 'height', 'plot_id', 'species'], ALGO: LASSO REGRESSION:
# Test R²     : 0.0095
# Test RMSE   : 440.84 kg
# Train R² (log scale): 0.5059
# Train R² (orig scale): 0.0031
# Train RMSE  : 556.25 kg
# Num Features: 150
#
#  Cross-validation ---
# CV R² mean: 0.4313
# CV R² std : 0.0275
# CV scores : [0.404 0.419 0.481 0.44  0.414]
# ============================================================
# EXPERIMENT EVALUATION:
# ============================================================
#
# Test set:
#   R²   : 0.010
#   RMSE : 440.84 kg
#
# Regular CrossValidation:
#   Mean   : 0.431
#   Std    : 0.028
#   Scores : [0.404 0.419 0.481 0.44  0.414]
#
#   ✅ Test R² is positive (0.010)
#   ✅ CV mean is positive (0.431)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ✅ ACCEPTABLE
#
# [24/24] elasticnet['nisar_value_hhhh', 'nisar_value_hvhv', 'height', 'plot_id', 'species']
#
#  EXPERIMENT-24 No groups, Model: elasticnet, Features: ['nisar_value_hhhh', 'nisar_value_hvhv', 'height', 'plot_id', 'species'], ALGO: ELASTICNET REGRESSION:
# Test R²     : 0.0105
# Test RMSE   : 440.63 kg
# Train R² (log scale): 0.5075
# Train R² (orig scale): 0.0043
# Train RMSE  : 555.91 kg
# Num Features: 150
#
#  Cross-validation ---
# CV R² mean: 0.4294
# CV R² std : 0.0271
# CV scores : [0.407 0.418 0.479 0.435 0.407]
# ============================================================
# EXPERIMENT EVALUATION:
# ============================================================
#
# Test set:
#   R²   : 0.010
#   RMSE : 440.63 kg
#
# Regular CrossValidation:
#   Mean   : 0.429
#   Std    : 0.027
#   Scores : [0.407 0.418 0.479 0.435 0.407]
#
#   ✅ Test R² is positive (0.010)
#   ✅ CV mean is positive (0.429)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ✅ ACCEPTABLE
#
# Completed: 24/24 experiments

# %% [markdown]
# **Key Observations**
#
# **NISAR values add almost nothing**
# Experiments 9–16 (NISAR alone or NISAR+height) perform nearly identically to experiments 1–4 (height alone). Test R² hovers around -0.045 to -0.050 regardless. NISAR backscatter carries no additional predictive signal beyond height.
#
# **plot_id + species are doing all the work**
# Every acceptable result has these categorical features. The CV R² jumps from ~0.007 to ~0.43 the moment they are added — a 60x improvement. The model is essentially learning plot-level and species-level mean AGB.
#
# **Regular linear regression consistently fails with categoricals**
# Experiments 5, 17, 21 all use plain OLS with 148–150 features (after one-hot encoding) and get Test R² of ~-0.38. Ridge/Lasso/ElasticNet regularize the coefficients and recover to ~0.01. This is a classic overfitting signature.
#
# **Test R² is near-zero even for acceptable models**
# The "acceptable" models score 0.000–0.011 on the test set vs 0.42+ on CV. This is a large gap — the model generalizes poorly to unseen plots/species combinations.
#
# **NISAR data is the limiting factor**
# With only 9 datasets and 123 unique coordinates, the NISAR dataset is too small and geographically constrained for linear models to find a generalizable signal.

# %% [markdown]
# ### CONCLUSION
#
# The only "acceptable" experiments (6, 7, 8, 18, 19, 20, 22, 23, 24) pass purely because plot_id and species are included as features. These are categorical identifiers that the model memorizes during training — they carry no physical meaning at inference time.
#
# When you encounter a new location, you do not know its plot_id. The CV R² of ~0.43 is entirely driven by this memorization, not by any genuine signal from NISAR backscatter or height.
#
# **The pure physical features**
#  - nisar_value_hhhh, nisar_value_hvhv, and height — produce Test R² between -0.05 and +0.05 across all model variants.
#  - This is statistically indistinguishable from a null model that predicts the mean AGB for every tree.
#
# **Why it is not useful?**
#  - NISAR backscatter has a raw correlation of only 0.08–0.13 with individual tree AGB — too weak for any linear model to exploit
# Height, the strongest predictor at 0.21 correlation, is still too weak on its own
#  - The dataset spans 9 geographically diverse regions with very different forest structures, making a single linear model impossible to generalize
#  - Linear models assume a monotonic relationship between backscatter and AGB, which SAR physics does not support beyond low biomass ranges due to signal saturation.
#
# Finally, the Linear Regression model for predicting AGB using NISAR backscatter.

# %% [markdown]
# ### Linear regression with region groups.

# %%
# %run Model_functions.ipynb
lin_experiment(X, y,
               is_groups=True, groups=dataset_groups,
               features_list=features_list,
               label="Grouping: REGION")
# 2nd-EXPERIMENT: REGION level groups. Linear regression variants.
# Out:
# [1/24] regular['height']
#   fold: Brazil-Barreto, y_test size: 54
#
#  EXPERIMENT-1 Grouping: REGION, Model: regular, Features: ['height'], ALGO: LINEAR REGRESSION:
# Test R²     : -0.3995
# Test RMSE   : 655.69 kg
# Train R² (log scale): 0.0105
# Train R² (orig scale): -0.0433
# Train RMSE  : 546.52 kg
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: -1.2682
# CV R² std : 2.0962
# CV scores : [-0.218 -0.428 -0.203 -5.453 -0.039]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.4442
# Grouped CV R² std : 1.2705
# Grouped CV scores : [-2.404 -0.032 -0.012 -0.868 -1.034 -0.633 -3.358 -3.213]
#   fold: Brazil-BocaGrande, y_test size: 66
#
#  EXPERIMENT-1 Grouping: REGION, Model: regular, Features: ['height'], ALGO: LINEAR REGRESSION:
# Test R²     : -0.2050
# Test RMSE   : 1066.11 kg
# Train R² (log scale): 0.0128
# Train R² (orig scale): -0.0430
# Train RMSE  : 532.13 kg
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: -1.2135
# CV R² std : 1.9575
# CV scores : [-0.232 -0.473 -0.228 -5.118 -0.017]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.4144
# Grouped CV R² std : 1.4140
# Grouped CV scores : [-2.946 -0.034 -0.012 -0.879 -0.634 -0.163 -3.429 -3.219]
#   fold: Brazil-Caetano, y_test size: 124
#
#  EXPERIMENT-1 Grouping: REGION, Model: regular, Features: ['height'], ALGO: LINEAR REGRESSION:
# Test R²     : -0.1054
# Test RMSE   : 982.61 kg
# Train R² (log scale): 0.0128
# Train R² (orig scale): -0.0431
# Train RMSE  : 523.02 kg
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: -0.9430
# CV R² std : 1.5038
# CV scores : [-0.194 -0.384 -0.175 -3.942 -0.021]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.3315
# Grouped CV R² std : 1.1795
# Grouped CV scores : [-1.679 -0.004 -0.827 -1.011 -0.6   -0.147 -3.304 -3.08 ]
#   fold: Brazil-FuroGrande, y_test size: 46
#
#  EXPERIMENT-1 Grouping: REGION, Model: regular, Features: ['height'], ALGO: LINEAR REGRESSION:
# Test R²     : -0.9514
# Test RMSE   : 518.23 kg
# Train R² (log scale): 0.0076
# Train R² (orig scale): -0.0442
# Train RMSE  : 549.24 kg
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: -1.2862
# CV R² std : 2.1021
# CV scores : [-0.256 -0.436 -0.227 -5.483 -0.029]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.0280
# Grouped CV R² std : 1.0869
# Grouped CV scores : [-2.039 -0.022 -0.02  -0.9   -1.039 -0.663 -0.165 -3.375]
#   fold: Brazil-Furo_Do_Chato, y_test size: 52
#
#  EXPERIMENT-1 Grouping: REGION, Model: regular, Features: ['height'], ALGO: LINEAR REGRESSION:
# Test R²     : -0.7043
# Test RMSE   : 850.15 kg
# Train R² (log scale): 0.0130
# Train R² (orig scale): -0.0413
# Train RMSE  : 542.14 kg
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: -1.2751
# CV R² std : 2.0678
# CV scores : [-0.238 -0.49  -0.229 -5.4   -0.018]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.9799
# Grouped CV R² std : 1.0238
# Grouped CV scores : [-1.78  -0.032 -0.013 -0.887 -1.08  -0.64  -0.166 -3.242]
#   fold: Brazil-Mangue, y_test size: 71
#
#  EXPERIMENT-1 Grouping: REGION, Model: regular, Features: ['height'], ALGO: LINEAR REGRESSION:
# Test R²     : -0.1946
# Test RMSE   : 1092.50 kg
# Train R² (log scale): 0.0089
# Train R² (orig scale): -0.0441
# Train RMSE  : 529.84 kg
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: -1.1944
# CV R² std : 1.9116
# CV scores : [-0.257 -0.446 -0.248 -5.008 -0.014]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.3285
# Grouped CV R² std : 1.3213
# Grouped CV scores : [-1.996 -0.024 -0.019 -1.052 -0.659 -0.166 -3.398 -3.315]
#   fold: Brazil-Maruipe, y_test size: 59
#
#  EXPERIMENT-1 Grouping: REGION, Model: regular, Features: ['height'], ALGO: LINEAR REGRESSION:
# Test R²     : -0.7538
# Test RMSE   : 710.17 kg
# Train R² (log scale): 0.0075
# Train R² (orig scale): -0.0425
# Train RMSE  : 545.30 kg
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: -1.2352
# CV R² std : 1.9979
# CV scores : [-0.26  -0.437 -0.234 -5.222 -0.023]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.3696
# Grouped CV R² std : 1.3151
# Grouped CV scores : [-2.094 -0.021 -0.021 -0.902 -1.039 -0.166 -3.375 -3.339]
#   fold: Brazil-Salinas, y_test size: 71
#
#  EXPERIMENT-1 Grouping: REGION, Model: regular, Features: ['height'], ALGO: LINEAR REGRESSION:
# Test R²     : -0.1283
# Test RMSE   : 607.13 kg
# Train R² (log scale): 0.0097
# Train R² (orig scale): -0.0448
# Train RMSE  : 547.12 kg
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: -1.2186
# CV R² std : 2.0114
# CV scores : [-0.216 -0.397 -0.212 -5.235 -0.033]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.4221
# Grouped CV R² std : 1.2228
# Grouped CV scores : [-2.155 -0.033 -0.861 -1.018 -0.63  -0.155 -3.326 -3.199]
#   fold: ElSalvador, y_test size: 2633
#
#  EXPERIMENT-1 Grouping: REGION, Model: regular, Features: ['height'], ALGO: LINEAR REGRESSION:
# Test R²     : -0.0974
# Test RMSE   : 473.50 kg
# Train R² (log scale): 0.0797
# Train R² (orig scale): -0.1604
# Train RMSE  : 841.97 kg
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: -0.2903
# CV R² std : 0.2916
# CV scores : [-0.079 -0.178 -0.173 -0.152 -0.869]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.3442
# Grouped CV R² std : 0.4097
# Grouped CV scores : [-0.338 -0.094 -0.053 -0.346 -0.235 -0.095 -0.198 -1.393]
# ============================================================
# EXPERIMENT EVALUATION:
# ============================================================
#
# Test set:
#   R²   : -0.393
#   RMSE : 772.90 kg
#
# Regular CrossValidation:
#   Mean   : -0.290
#   Std    : 0.292
#   Scores : [-0.079 -0.178 -0.173 -0.152 -0.869]
#
#   ❌ Test R² is negative (-0.393)
#   ❌ CV mean is negative (-0.290)
#
# Grouped CrossValidation:
#   Brazil-Barreto       :  -0.338  ❌ negative — cause unknown
#   Brazil-BocaGrande    :  -0.094  ❌ negative — cause unknown
#   Brazil-Caetano       :  -0.053  ❌ negative — cause unknown
#   Brazil-FuroGrande    :  -0.346  ❌ negative — cause unknown
#   Brazil-Furo_Do_Chato :  -0.235  ❌ negative — cause unknown
#   Brazil-Mangue        :  -0.095  ❌ negative — cause unknown
#   Brazil-Maruipe       :  -0.198  ❌ negative — cause unknown
#   Brazil-Salinas       :  -1.393  ❌ negative — cause unknown
#
#   Mean : -0.344
#   Std  : 0.410
#
#   ❌ Grouped CV mean is negative (-0.344)
#   ❌ Unexplained negative folds: ['Brazil-Barreto', 'Brazil-BocaGrande', 'Brazil-Caetano', 'Brazil-FuroGrande', 'Brazil-Furo_Do_Chato', 'Brazil-Mangue', 'Brazil-Maruipe', 'Brazil-Salinas']
#   ✅ High-AGB sites generalize correctly
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ NOT ACCEPTABLE
#
# [2/24] ridge['height']
#   fold: Brazil-Barreto, y_test size: 54
#
#  EXPERIMENT-2 Grouping: REGION, Model: ridge, Features: ['height'], ALGO: RIDGE REGRESSION:
# Test R²     : -0.3995
# Test RMSE   : 655.70 kg
# Train R² (log scale): 0.0105
# Train R² (orig scale): -0.0434
# Train RMSE  : 546.56 kg
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: -1.2633
# CV R² std : 2.0847
# CV scores : [-0.22  -0.428 -0.204 -5.425 -0.039]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.3750
# Grouped CV R² std : 1.2313
# Grouped CV scores : [-1.844 -0.03  -0.013 -0.871 -1.03  -0.636 -3.352 -3.225]
#   fold: Brazil-BocaGrande, y_test size: 66
#
#  EXPERIMENT-2 Grouping: REGION, Model: ridge, Features: ['height'], ALGO: RIDGE REGRESSION:
# Test R²     : -0.2050
# Test RMSE   : 1066.09 kg
# Train R² (log scale): 0.0128
# Train R² (orig scale): -0.0432
# Train RMSE  : 532.17 kg
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: -1.2083
# CV R² std : 1.9454
# CV scores : [-0.234 -0.473 -0.229 -5.088 -0.017]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.4159
# Grouped CV R² std : 1.4146
# Grouped CV scores : [-2.945 -0.032 -0.013 -0.882 -0.638 -0.164 -3.422 -3.232]
#   fold: Brazil-Caetano, y_test size: 124
#
#  EXPERIMENT-2 Grouping: REGION, Model: ridge, Features: ['height'], ALGO: RIDGE REGRESSION:
# Test R²     : -0.1055
# Test RMSE   : 982.68 kg
# Train R² (log scale): 0.0127
# Train R² (orig scale): -0.0433
# Train RMSE  : 523.06 kg
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: -0.9342
# CV R² std : 1.4854
# CV scores : [-0.196 -0.381 -0.177 -3.896 -0.021]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.3134
# Grouped CV R² std : 1.1758
# Grouped CV scores : [-1.52  -0.005 -0.831 -1.007 -0.603 -0.147 -3.299 -3.095]
#   fold: Brazil-FuroGrande, y_test size: 46
#
#  EXPERIMENT-2 Grouping: REGION, Model: ridge, Features: ['height'], ALGO: RIDGE REGRESSION:
# Test R²     : -0.9518
# Test RMSE   : 518.29 kg
# Train R² (log scale): 0.0076
# Train R² (orig scale): -0.0443
# Train RMSE  : 549.26 kg
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: -1.2863
# CV R² std : 2.1008
# CV scores : [-0.258 -0.436 -0.228 -5.48  -0.03 ]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.0193
# Grouped CV R² std : 1.0778
# Grouped CV scores : [-1.972 -0.021 -0.021 -0.902 -1.037 -0.666 -0.166 -3.37 ]
#   fold: Brazil-Furo_Do_Chato, y_test size: 52
#
#  EXPERIMENT-2 Grouping: REGION, Model: ridge, Features: ['height'], ALGO: RIDGE REGRESSION:
# Test R²     : -0.7042
# Test RMSE   : 850.12 kg
# Train R² (log scale): 0.0130
# Train R² (orig scale): -0.0415
# Train RMSE  : 542.18 kg
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: -1.2701
# CV R² std : 2.0561
# CV scores : [-0.24  -0.49  -0.23  -5.371 -0.019]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.9263
# Grouped CV R² std : 0.9942
# Grouped CV scores : [-1.336 -0.03  -0.014 -0.89  -1.076 -0.643 -0.166 -3.255]
#   fold: Brazil-Mangue, y_test size: 71
#
#  EXPERIMENT-2 Grouping: REGION, Model: ridge, Features: ['height'], ALGO: RIDGE REGRESSION:
# Test R²     : -0.1946
# Test RMSE   : 1092.52 kg
# Train R² (log scale): 0.0089
# Train R² (orig scale): -0.0442
# Train RMSE  : 529.87 kg
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: -1.1893
# CV R² std : 1.8999
# CV scores : [-0.259 -0.446 -0.249 -4.979 -0.014]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.2748
# Grouped CV R² std : 1.3025
# Grouped CV scores : [-1.56  -0.023 -0.02  -1.048 -0.662 -0.166 -3.392 -3.326]
#   fold: Brazil-Maruipe, y_test size: 59
#
#  EXPERIMENT-2 Grouping: REGION, Model: ridge, Features: ['height'], ALGO: RIDGE REGRESSION:
# Test R²     : -0.7541
# Test RMSE   : 710.23 kg
# Train R² (log scale): 0.0075
# Train R² (orig scale): -0.0426
# Train RMSE  : 545.33 kg
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: -1.2304
# CV R² std : 1.9868
# CV scores : [-0.262 -0.437 -0.235 -5.195 -0.023]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.3099
# Grouped CV R² std : 1.2923
# Grouped CV scores : [-1.613 -0.02  -0.022 -0.904 -1.036 -0.166 -3.37  -3.348]
#   fold: Brazil-Salinas, y_test size: 71
#
#  EXPERIMENT-2 Grouping: REGION, Model: ridge, Features: ['height'], ALGO: RIDGE REGRESSION:
# Test R²     : -0.1285
# Test RMSE   : 607.18 kg
# Train R² (log scale): 0.0097
# Train R² (orig scale): -0.0450
# Train RMSE  : 547.16 kg
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: -1.2127
# CV R² std : 1.9978
# CV scores : [-0.218 -0.397 -0.213 -5.202 -0.034]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.3711
# Grouped CV R² std : 1.2003
# Grouped CV scores : [-1.74  -0.031 -0.863 -1.015 -0.633 -0.155 -3.32  -3.211]
#   fold: ElSalvador, y_test size: 2633
#
#  EXPERIMENT-2 Grouping: REGION, Model: ridge, Features: ['height'], ALGO: RIDGE REGRESSION:
# Test R²     : -0.0672
# Test RMSE   : 466.93 kg
# Train R² (log scale): 0.0777
# Train R² (orig scale): -0.1655
# Train RMSE  : 843.79 kg
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: -0.3093
# CV R² std : 0.3153
# CV scores : [-0.12  -0.174 -0.166 -0.149 -0.939]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.3533
# Grouped CV R² std : 0.3855
# Grouped CV scores : [-0.396 -0.107 -0.06  -0.346 -0.213 -0.074 -0.306 -1.323]
# ============================================================
# EXPERIMENT EVALUATION:
# ============================================================
#
# Test set:
#   R²   : -0.390
#   RMSE : 772.19 kg
#
# Regular CrossValidation:
#   Mean   : -0.309
#   Std    : 0.315
#   Scores : [-0.12  -0.174 -0.166 -0.149 -0.939]
#
#   ❌ Test R² is negative (-0.390)
#   ❌ CV mean is negative (-0.309)
#
# Grouped CrossValidation:
#   Brazil-Barreto       :  -0.396  ❌ negative — cause unknown
#   Brazil-BocaGrande    :  -0.107  ❌ negative — cause unknown
#   Brazil-Caetano       :  -0.060  ❌ negative — cause unknown
#   Brazil-FuroGrande    :  -0.346  ❌ negative — cause unknown
#   Brazil-Furo_Do_Chato :  -0.213  ❌ negative — cause unknown
#   Brazil-Mangue        :  -0.074  ❌ negative — cause unknown
#   Brazil-Maruipe       :  -0.306  ❌ negative — cause unknown
#   Brazil-Salinas       :  -1.323  ❌ negative — cause unknown
#
#   Mean : -0.353
#   Std  : 0.385
#
#   ❌ Grouped CV mean is negative (-0.353)
#   ❌ Unexplained negative folds: ['Brazil-Barreto', 'Brazil-BocaGrande', 'Brazil-Caetano', 'Brazil-FuroGrande', 'Brazil-Furo_Do_Chato', 'Brazil-Mangue', 'Brazil-Maruipe', 'Brazil-Salinas']
#   ✅ High-AGB sites generalize correctly
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ NOT ACCEPTABLE
#
# [3/24] lasso['height']
#   fold: Brazil-Barreto, y_test size: 54
#
#  EXPERIMENT-3 Grouping: REGION, Model: lasso, Features: ['height'], ALGO: LASSO REGRESSION:
# Test R²     : -0.4011
# Test RMSE   : 656.06 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.0468
# Train RMSE  : 547.44 kg
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: -1.2918
# CV R² std : 2.0834
# CV scores : [-0.283 -0.427 -0.247 -5.451 -0.05 ]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.4799
# Grouped CV R² std : 1.3026
# Grouped CV scores : [-2.4   -0.    -0.053 -0.953 -0.926 -0.735 -3.17  -3.603]
#   fold: Brazil-BocaGrande, y_test size: 66
#
#  EXPERIMENT-3 Grouping: REGION, Model: lasso, Features: ['height'], ALGO: LASSO REGRESSION:
# Test R²     : -0.2035
# Test RMSE   : 1065.43 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.0473
# Train RMSE  : 533.20 kg
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: -1.2391
# CV R² std : 1.9437
# CV scores : [-0.307 -0.472 -0.273 -5.116 -0.027]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.4698
# Grouped CV R² std : 1.4390
# Grouped CV scores : [-2.938 -0.    -0.058 -0.972 -0.748 -0.176 -3.212 -3.655]
#   fold: Brazil-Caetano, y_test size: 124
#
#  EXPERIMENT-3 Grouping: REGION, Model: lasso, Features: ['height'], ALGO: LASSO REGRESSION:
# Test R²     : -0.1102
# Test RMSE   : 984.75 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.0475
# Train RMSE  : 524.11 kg
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: -0.9589
# CV R² std : 1.4841
# CV scores : [-0.276 -0.339 -0.235 -3.919 -0.025]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.3433
# Grouped CV R² std : 1.2175
# Grouped CV scores : [-1.301 -0.049 -0.933 -0.905 -0.721 -0.163 -3.126 -3.549]
#   fold: Brazil-FuroGrande, y_test size: 46
#
#  EXPERIMENT-3 Grouping: REGION, Model: lasso, Features: ['height'], ALGO: LASSO REGRESSION:
# Test R²     : -0.9655
# Test RMSE   : 520.10 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.0469
# Train RMSE  : 549.96 kg
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: -1.3050
# CV R² std : 2.0918
# CV scores : [-0.305 -0.436 -0.265 -5.481 -0.039]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.0191
# Grouped CV R² std : 1.0373
# Grouped CV scores : [-2.035 -0.    -0.058 -0.973 -0.947 -0.748 -0.176 -3.215]
#   fold: Brazil-Furo_Do_Chato, y_test size: 52
#
#  EXPERIMENT-3 Grouping: REGION, Model: lasso, Features: ['height'], ALGO: LASSO REGRESSION:
# Test R²     : -0.7008
# Test RMSE   : 849.28 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.0453
# Train RMSE  : 543.18 kg
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: -1.3014
# CV R² std : 2.0535
# CV scores : [-0.313 -0.49  -0.276 -5.398 -0.031]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.9942
# Grouped CV R² std : 1.1138
# Grouped CV scores : [-1.343 -0.    -0.06  -0.981 -0.956 -0.754 -0.179 -3.681]
#   fold: Brazil-Mangue, y_test size: 71
#
#  EXPERIMENT-3 Grouping: REGION, Model: lasso, Features: ['height'], ALGO: LASSO REGRESSION:
# Test R²     : -0.1960
# Test RMSE   : 1093.15 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.0473
# Train RMSE  : 530.65 kg
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: -1.2148
# CV R² std : 1.9005
# CV scores : [-0.313 -0.445 -0.289 -5.006 -0.022]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.3539
# Grouped CV R² std : 1.3556
# Grouped CV scores : [-1.992 -0.    -0.059 -0.952 -0.752 -0.178 -3.226 -3.672]
#   fold: Brazil-Maruipe, y_test size: 59
#
#  EXPERIMENT-3 Grouping: REGION, Model: lasso, Features: ['height'], ALGO: LASSO REGRESSION:
# Test R²     : -0.7626
# Test RMSE   : 711.94 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.0451
# Train RMSE  : 546.00 kg
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: -1.2534
# CV R² std : 1.9878
# CV scores : [-0.307 -0.436 -0.272 -5.22  -0.031]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.3912
# Grouped CV R² std : 1.3482
# Grouped CV scores : [-2.091 -0.    -0.058 -0.974 -0.949 -0.177 -3.218 -3.662]
#   fold: Brazil-Salinas, y_test size: 71
#
#  EXPERIMENT-3 Grouping: REGION, Model: lasso, Features: ['height'], ALGO: LASSO REGRESSION:
# Test R²     : -0.1338
# Test RMSE   : 608.62 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.0482
# Train RMSE  : 548.01 kg
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: -1.2412
# CV R² std : 1.9991
# CV scores : [-0.279 -0.396 -0.256 -5.233 -0.042]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.3074
# Grouped CV R² std : 1.2414
# Grouped CV scores : [-0.962 -0.    -0.945 -0.918 -0.729 -0.167 -3.153 -3.583]
#   fold: ElSalvador, y_test size: 2633
#
#  EXPERIMENT-3 Grouping: REGION, Model: lasso, Features: ['height'], ALGO: LASSO REGRESSION:
# Test R²     : -0.0970
# Test RMSE   : 473.41 kg
# Train R² (log scale): 0.0797
# Train R² (orig scale): -0.1605
# Train RMSE  : 841.99 kg
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: -0.3562
# CV R² std : 0.4209
# CV scores : [-0.083 -0.178 -0.173 -0.152 -1.195]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.4950
# Grouped CV R² std : 0.4501
# Grouped CV scores : [-0.606 -0.213 -0.053 -0.344 -0.235 -0.095 -1.022 -1.393]
# ============================================================
# EXPERIMENT EVALUATION:
# ============================================================
#
# Test set:
#   R²   : -0.397
#   RMSE : 773.64 kg
#
# Regular CrossValidation:
#   Mean   : -0.356
#   Std    : 0.421
#   Scores : [-0.083 -0.178 -0.173 -0.152 -1.195]
#
#   ❌ Test R² is negative (-0.397)
#   ❌ CV mean is negative (-0.356)
#
# Grouped CrossValidation:
#   Brazil-Barreto       :  -0.606  ❌ negative — cause unknown
#   Brazil-BocaGrande    :  -0.213  ❌ negative — cause unknown
#   Brazil-Caetano       :  -0.053  ❌ negative — cause unknown
#   Brazil-FuroGrande    :  -0.344  ❌ negative — cause unknown
#   Brazil-Furo_Do_Chato :  -0.235  ❌ negative — cause unknown
#   Brazil-Mangue        :  -0.095  ❌ negative — cause unknown
#   Brazil-Maruipe       :  -1.022  ❌ negative — cause unknown
#   Brazil-Salinas       :  -1.393  ❌ negative — cause unknown
#
#   Mean : -0.495
#   Std  : 0.450
#
#   ❌ Grouped CV mean is negative (-0.495)
#   ❌ Unexplained negative folds: ['Brazil-Barreto', 'Brazil-BocaGrande', 'Brazil-Caetano', 'Brazil-FuroGrande', 'Brazil-Furo_Do_Chato', 'Brazil-Mangue', 'Brazil-Maruipe', 'Brazil-Salinas']
#   ✅ High-AGB sites generalize correctly
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ NOT ACCEPTABLE
#
# [4/24] elasticnet['height']
#   fold: Brazil-Barreto, y_test size: 54
#
#  EXPERIMENT-4 Grouping: REGION, Model: elasticnet, Features: ['height'], ALGO: ELASTICNET REGRESSION:
# Test R²     : -0.4011
# Test RMSE   : 656.06 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.0468
# Train RMSE  : 547.44 kg
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: -1.2920
# CV R² std : 2.0837
# CV scores : [-0.283 -0.428 -0.247 -5.452 -0.05 ]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.4371
# Grouped CV R² std : 1.2770
# Grouped CV scores : [-2.057 -0.    -0.053 -0.953 -0.926 -0.735 -3.17  -3.603]
#   fold: Brazil-BocaGrande, y_test size: 66
#
#  EXPERIMENT-4 Grouping: REGION, Model: elasticnet, Features: ['height'], ALGO: ELASTICNET REGRESSION:
# Test R²     : -0.2035
# Test RMSE   : 1065.43 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.0473
# Train RMSE  : 533.20 kg
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: -1.2393
# CV R² std : 1.9440
# CV scores : [-0.307 -0.473 -0.273 -5.117 -0.027]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.4697
# Grouped CV R² std : 1.4389
# Grouped CV scores : [-2.937 -0.    -0.058 -0.972 -0.748 -0.176 -3.212 -3.655]
#   fold: Brazil-Caetano, y_test size: 124
#
#  EXPERIMENT-4 Grouping: REGION, Model: elasticnet, Features: ['height'], ALGO: ELASTICNET REGRESSION:
# Test R²     : -0.1102
# Test RMSE   : 984.75 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.0475
# Train RMSE  : 524.11 kg
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: -0.9384
# CV R² std : 1.4433
# CV scores : [-0.276 -0.339 -0.235 -3.817 -0.025]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.3433
# Grouped CV R² std : 1.2175
# Grouped CV scores : [-1.301 -0.049 -0.933 -0.905 -0.721 -0.163 -3.126 -3.549]
#   fold: Brazil-FuroGrande, y_test size: 46
#
#  EXPERIMENT-4 Grouping: REGION, Model: elasticnet, Features: ['height'], ALGO: ELASTICNET REGRESSION:
# Test R²     : -0.9655
# Test RMSE   : 520.10 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.0469
# Train RMSE  : 549.96 kg
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: -1.3053
# CV R² std : 2.0921
# CV scores : [-0.305 -0.436 -0.265 -5.482 -0.039]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.9831
# Grouped CV R² std : 1.0059
# Grouped CV scores : [-1.747 -0.    -0.058 -0.973 -0.947 -0.748 -0.176 -3.215]
#   fold: Brazil-Furo_Do_Chato, y_test size: 52
#
#  EXPERIMENT-4 Grouping: REGION, Model: elasticnet, Features: ['height'], ALGO: ELASTICNET REGRESSION:
# Test R²     : -0.7008
# Test RMSE   : 849.28 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.0453
# Train RMSE  : 543.18 kg
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: -1.3017
# CV R² std : 2.0539
# CV scores : [-0.313 -0.49  -0.276 -5.399 -0.031]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.9223
# Grouped CV R² std : 1.1075
# Grouped CV scores : [-0.768 -0.    -0.06  -0.981 -0.956 -0.754 -0.179 -3.681]
#   fold: Brazil-Mangue, y_test size: 71
#
#  EXPERIMENT-4 Grouping: REGION, Model: elasticnet, Features: ['height'], ALGO: ELASTICNET REGRESSION:
# Test R²     : -0.1960
# Test RMSE   : 1093.15 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.0473
# Train RMSE  : 530.65 kg
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: -1.2151
# CV R² std : 1.9008
# CV scores : [-0.313 -0.445 -0.289 -5.007 -0.022]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.3212
# Grouped CV R² std : 1.3430
# Grouped CV scores : [-1.731 -0.    -0.059 -0.952 -0.752 -0.178 -3.226 -3.672]
#   fold: Brazil-Maruipe, y_test size: 59
#
#  EXPERIMENT-4 Grouping: REGION, Model: elasticnet, Features: ['height'], ALGO: ELASTICNET REGRESSION:
# Test R²     : -0.7626
# Test RMSE   : 711.94 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.0451
# Train RMSE  : 546.00 kg
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: -1.2536
# CV R² std : 1.9882
# CV scores : [-0.307 -0.437 -0.272 -5.221 -0.031]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.3549
# Grouped CV R² std : 1.3328
# Grouped CV scores : [-1.801 -0.    -0.058 -0.974 -0.949 -0.177 -3.218 -3.662]
#   fold: Brazil-Salinas, y_test size: 71
#
#  EXPERIMENT-4 Grouping: REGION, Model: elasticnet, Features: ['height'], ALGO: ELASTICNET REGRESSION:
# Test R²     : -0.1338
# Test RMSE   : 608.62 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.0482
# Train RMSE  : 548.01 kg
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: -1.2415
# CV R² std : 1.9994
# CV scores : [-0.279 -0.396 -0.256 -5.234 -0.042]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.3074
# Grouped CV R² std : 1.2414
# Grouped CV scores : [-0.962 -0.    -0.945 -0.918 -0.729 -0.167 -3.153 -3.583]
#   fold: ElSalvador, y_test size: 2633
#
#  EXPERIMENT-4 Grouping: REGION, Model: elasticnet, Features: ['height'], ALGO: ELASTICNET REGRESSION:
# Test R²     : -0.0948
# Test RMSE   : 472.94 kg
# Train R² (log scale): 0.0797
# Train R² (orig scale): -0.1608
# Train RMSE  : 842.11 kg
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: -0.3562
# CV R² std : 0.4202
# CV scores : [-0.103 -0.162 -0.17  -0.152 -1.195]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.4494
# Grouped CV R² std : 0.4057
# Grouped CV scores : [-0.606 -0.213 -0.057 -0.344 -0.222 -0.082 -0.721 -1.35 ]
# ============================================================
# EXPERIMENT EVALUATION:
# ============================================================
#
# Test set:
#   R²   : -0.396
#   RMSE : 773.58 kg
#
# Regular CrossValidation:
#   Mean   : -0.356
#   Std    : 0.420
#   Scores : [-0.103 -0.162 -0.17  -0.152 -1.195]
#
#   ❌ Test R² is negative (-0.396)
#   ❌ CV mean is negative (-0.356)
#
# Grouped CrossValidation:
#   Brazil-Barreto       :  -0.606  ❌ negative — cause unknown
#   Brazil-BocaGrande    :  -0.213  ❌ negative — cause unknown
#   Brazil-Caetano       :  -0.057  ❌ negative — cause unknown
#   Brazil-FuroGrande    :  -0.344  ❌ negative — cause unknown
#   Brazil-Furo_Do_Chato :  -0.222  ❌ negative — cause unknown
#   Brazil-Mangue        :  -0.082  ❌ negative — cause unknown
#   Brazil-Maruipe       :  -0.721  ❌ negative — cause unknown
#   Brazil-Salinas       :  -1.350  ❌ negative — cause unknown
#
#   Mean : -0.449
#   Std  : 0.406
#
#   ❌ Grouped CV mean is negative (-0.449)
#   ❌ Unexplained negative folds: ['Brazil-Barreto', 'Brazil-BocaGrande', 'Brazil-Caetano', 'Brazil-FuroGrande', 'Brazil-Furo_Do_Chato', 'Brazil-Mangue', 'Brazil-Maruipe', 'Brazil-Salinas']
#   ✅ High-AGB sites generalize correctly
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ NOT ACCEPTABLE
#
# [5/24] regular['height', 'plot_id', 'species']
#   fold: Brazil-Barreto, y_test size: 54
#
#  EXPERIMENT-5 Grouping: REGION, Model: regular, Features: ['height', 'plot_id', 'species'], ALGO: LINEAR REGRESSION:
# Test R²     : -0.3495
# Test RMSE   : 643.87 kg
# Train R² (log scale): 0.5252
# Train R² (orig scale): 0.0153
# Train RMSE  : 530.97 kg
# Num Features: 148
#
#  Cross-validation ---
# CV R² mean: -2.2778
# CV R² std : 1.6694
# CV scores : [-1.834 -2.102 -2.289 -5.182  0.019]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.8302
# Grouped CV R² std : 0.7972
# Grouped CV scores : [-0.479 -1.25  -0.01  -0.285 -0.692 -0.269 -2.691 -0.966]
#   fold: Brazil-BocaGrande, y_test size: 66
#
#  EXPERIMENT-5 Grouping: REGION, Model: regular, Features: ['height', 'plot_id', 'species'], ALGO: LINEAR REGRESSION:
# Test R²     : -0.1844
# Test RMSE   : 1056.95 kg
# Train R² (log scale): 0.5119
# Train R² (orig scale): 0.0137
# Train RMSE  : 517.46 kg
# Num Features: 148
#
#  Cross-validation ---
# CV R² mean: -2.2031
# CV R² std : 1.5589
# CV scores : [-1.977 -1.894 -2.345 -4.839  0.041]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.6966
# Grouped CV R² std : 0.6891
# Grouped CV scores : [-0.766 -0.277 -0.01  -0.369 -0.456 -0.042 -1.874 -1.777]
#   fold: Brazil-Caetano, y_test size: 124
#
#  EXPERIMENT-5 Grouping: REGION, Model: regular, Features: ['height', 'plot_id', 'species'], ALGO: LINEAR REGRESSION:
# Test R²     : -0.0731
# Test RMSE   : 968.17 kg
# Train R² (log scale): 0.5388
# Train R² (orig scale): 0.0209
# Train RMSE  : 506.72 kg
# Num Features: 148
#
#  Cross-validation ---
# CV R² mean: -1.9995
# CV R² std : 1.2816
# CV scores : [-1.869 -1.936 -2.272 -3.975  0.054]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.5811
# Grouped CV R² std : 0.5865
# Grouped CV scores : [-1.116 -0.047 -0.167 -0.304 -0.231 -0.05  -1.749 -0.987]
#   fold: Brazil-FuroGrande, y_test size: 46
#
#  EXPERIMENT-5 Grouping: REGION, Model: regular, Features: ['height', 'plot_id', 'species'], ALGO: LINEAR REGRESSION:
# Test R²     : -0.8270
# Test RMSE   : 501.45 kg
# Train R² (log scale): 0.5034
# Train R² (orig scale): 0.0142
# Train RMSE  : 533.66 kg
# Num Features: 148
#
#  Cross-validation ---
# CV R² mean: -2.2906
# CV R² std : 1.6704
# CV scores : [-2.007 -1.877 -2.425 -5.173  0.027]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.5184
# Grouped CV R² std : 0.5242
# Grouped CV scores : [-0.762 -0.276 -0.024 -0.406 -0.311 -0.543 -0.056 -1.769]
#   fold: Brazil-Furo_Do_Chato, y_test size: 52
#
#  EXPERIMENT-5 Grouping: REGION, Model: regular, Features: ['height', 'plot_id', 'species'], ALGO: LINEAR REGRESSION:
# Test R²     : -0.6477
# Test RMSE   : 835.91 kg
# Train R² (log scale): 0.4997
# Train R² (orig scale): 0.0062
# Train RMSE  : 529.63 kg
# Num Features: 148
#
#  Cross-validation ---
# CV R² mean: -2.2510
# CV R² std : 1.6181
# CV scores : [-1.984 -1.886 -2.408 -5.013  0.037]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.5218
# Grouped CV R² std : 0.5670
# Grouped CV scores : [-0.693 -0.227 -0.015 -0.405 -0.36  -0.508 -0.052 -1.914]
#   fold: Brazil-Mangue, y_test size: 71
#
#  EXPERIMENT-5 Grouping: REGION, Model: regular, Features: ['height', 'plot_id', 'species'], ALGO: LINEAR REGRESSION:
# Test R²     : -0.1668
# Test RMSE   : 1079.73 kg
# Train R² (log scale): 0.5111
# Train R² (orig scale): 0.0133
# Train RMSE  : 515.08 kg
# Num Features: 148
#
#  Cross-validation ---
# CV R² mean: -2.1453
# CV R² std : 1.4765
# CV scores : [-1.956 -1.915 -2.316 -4.588  0.049]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.7187
# Grouped CV R² std : 0.7239
# Grouped CV scores : [-0.713 -0.265 -0.01  -0.367 -0.484 -0.072 -1.962 -1.877]
#   fold: Brazil-Maruipe, y_test size: 59
#
#  EXPERIMENT-5 Grouping: REGION, Model: regular, Features: ['height', 'plot_id', 'species'], ALGO: LINEAR REGRESSION:
# Test R²     : -0.7272
# Test RMSE   : 704.76 kg
# Train R² (log scale): 0.5168
# Train R² (orig scale): 0.0127
# Train RMSE  : 530.69 kg
# Num Features: 148
#
#  Cross-validation ---
# CV R² mean: -2.2602
# CV R² std : 1.5681
# CV scores : [-2.133 -1.907 -2.432 -4.872  0.043]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.7052
# Grouped CV R² std : 0.7613
# Grouped CV scores : [-0.955 -0.156 -0.058 -0.409 -0.224 -0.027 -1.6   -2.213]
#   fold: Brazil-Salinas, y_test size: 71
#
#  EXPERIMENT-5 Grouping: REGION, Model: regular, Features: ['height', 'plot_id', 'species'], ALGO: LINEAR REGRESSION:
# Test R²     : -0.1212
# Test RMSE   : 605.22 kg
# Train R² (log scale): 0.5249
# Train R² (orig scale): 0.0149
# Train RMSE  : 531.25 kg
# Num Features: 148
#
#  Cross-validation ---
# CV R² mean: -2.2083
# CV R² std : 1.4370
# CV scores : [-2.204 -1.934 -2.444 -4.487  0.028]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.7318
# Grouped CV R² std : 0.6954
# Grouped CV scores : [-1.306e+00 -1.400e-01 -3.320e-01 -1.190e-01 -5.930e-01  2.000e-03
#  -1.307e+00 -2.060e+00]
#   fold: ElSalvador, y_test size: 2633
#
#  EXPERIMENT-5 Grouping: REGION, Model: regular, Features: ['height', 'plot_id', 'species'], ALGO: LINEAR REGRESSION:
# Test R²     : 0.0016
# Test RMSE   : 451.62 kg
# Train R² (log scale): 0.2030
# Train R² (orig scale): -0.1306
# Train RMSE  : 831.09 kg
# Num Features: 148
#
#  Cross-validation ---
# CV R² mean: -0.4868
# CV R² std : 0.7978
# CV scores : [-0.108 -0.125 -0.012 -0.109 -2.08 ]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.3601
# Grouped CV R² std : 0.3563
# Grouped CV scores : [-0.813 -0.157 -0.119 -0.001 -0.144 -0.018 -0.872 -0.756]
# ============================================================
# EXPERIMENT EVALUATION:
# ============================================================
#
# Test set:
#   R²   : -0.344
#   RMSE : 760.85 kg
#
# Regular CrossValidation:
#   Mean   : -0.487
#   Std    : 0.798
#   Scores : [-0.108 -0.125 -0.012 -0.109 -2.08 ]
#
#   ❌ Test R² is negative (-0.344)
#   ❌ CV mean is negative (-0.487)
#
# Grouped CrossValidation:
#   Brazil-Barreto       :  -0.813  ❌ negative — cause unknown
#   Brazil-BocaGrande    :  -0.157  ❌ negative — cause unknown
#   Brazil-Caetano       :  -0.119  ❌ negative — cause unknown
#   Brazil-FuroGrande    :  -0.001  ❌ negative — cause unknown
#   Brazil-Furo_Do_Chato :  -0.144  ❌ negative — cause unknown
#   Brazil-Mangue        :  -0.018  ❌ negative — cause unknown
#   Brazil-Maruipe       :  -0.872  ❌ negative — cause unknown
#   Brazil-Salinas       :  -0.756  ❌ negative — cause unknown
#
#   Mean : -0.360
#   Std  : 0.356
#
#   ❌ Grouped CV mean is negative (-0.360)
#   ❌ Unexplained negative folds: ['Brazil-Barreto', 'Brazil-BocaGrande', 'Brazil-Caetano', 'Brazil-FuroGrande', 'Brazil-Furo_Do_Chato', 'Brazil-Mangue', 'Brazil-Maruipe', 'Brazil-Salinas']
#   ✅ High-AGB sites generalize correctly
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ NOT ACCEPTABLE
#
# [6/24] ridge['height', 'plot_id', 'species']
#   fold: Brazil-Barreto, y_test size: 54
#
#  EXPERIMENT-6 Grouping: REGION, Model: ridge, Features: ['height', 'plot_id', 'species'], ALGO: RIDGE REGRESSION:
# Test R²     : -0.3492
# Test RMSE   : 643.80 kg
# Train R² (log scale): 0.5245
# Train R² (orig scale): 0.0134
# Train RMSE  : 531.48 kg
# Num Features: 148
#
#  Cross-validation ---
# CV R² mean: -2.2651
# CV R² std : 1.6545
# CV scores : [-1.818 -2.101 -2.275 -5.142  0.011]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.7055
# Grouped CV R² std : 0.6514
# Grouped CV scores : [-0.899 -0.206 -0.016 -0.327 -0.359 -0.349 -1.95  -1.538]
#   fold: Brazil-BocaGrande, y_test size: 66
#
#  EXPERIMENT-6 Grouping: REGION, Model: ridge, Features: ['height', 'plot_id', 'species'], ALGO: RIDGE REGRESSION:
# Test R²     : -0.1868
# Test RMSE   : 1058.01 kg
# Train R² (log scale): 0.5114
# Train R² (orig scale): 0.0119
# Train RMSE  : 517.93 kg
# Num Features: 148
#
#  Cross-validation ---
# CV R² mean: -2.0059
# CV R² std : 1.6111
# CV scores : [-1.535 -1.619 -1.993 -4.914  0.032]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.6977
# Grouped CV R² std : 0.7378
# Grouped CV scores : [-0.833 -0.18  -0.009 -0.376 -0.381 -0.015 -2.072 -1.715]
#   fold: Brazil-Caetano, y_test size: 124
#
#  EXPERIMENT-6 Grouping: REGION, Model: ridge, Features: ['height', 'plot_id', 'species'], ALGO: RIDGE REGRESSION:
# Test R²     : -0.0822
# Test RMSE   : 972.24 kg
# Train R² (log scale): 0.5382
# Train R² (orig scale): 0.0190
# Train RMSE  : 507.20 kg
# Num Features: 148
#
#  Cross-validation ---
# CV R² mean: -1.7926
# CV R² std : 1.2841
# CV scores : [-1.511 -1.622 -1.896 -3.975  0.041]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.6155
# Grouped CV R² std : 0.6142
# Grouped CV scores : [-1.291 -0.07  -0.204 -0.245 -0.239  0.004 -1.633 -1.246]
#   fold: Brazil-FuroGrande, y_test size: 46
#
#  EXPERIMENT-6 Grouping: REGION, Model: ridge, Features: ['height', 'plot_id', 'species'], ALGO: RIDGE REGRESSION:
# Test R²     : -0.8215
# Test RMSE   : 500.68 kg
# Train R² (log scale): 0.5029
# Train R² (orig scale): 0.0122
# Train RMSE  : 534.20 kg
# Num Features: 148
#
#  Cross-validation ---
# CV R² mean: -2.2063
# CV R² std : 1.6947
# CV scores : [-1.933 -1.841 -2.054 -5.23   0.027]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.5162
# Grouped CV R² std : 0.6124
# Grouped CV scores : [-0.778 -0.142 -0.005 -0.389 -0.381 -0.405 -0.018 -2.011]
#   fold: Brazil-Furo_Do_Chato, y_test size: 52
#
#  EXPERIMENT-6 Grouping: REGION, Model: ridge, Features: ['height', 'plot_id', 'species'], ALGO: RIDGE REGRESSION:
# Test R²     : -0.6554
# Test RMSE   : 837.88 kg
# Train R² (log scale): 0.4992
# Train R² (orig scale): 0.0048
# Train RMSE  : 529.99 kg
# Num Features: 148
#
#  Cross-validation ---
# CV R² mean: -2.2500
# CV R² std : 1.6273
# CV scores : [-1.977 -1.853 -2.408 -5.041  0.029]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.4930
# Grouped CV R² std : 0.5366
# Grouped CV scores : [-0.722 -0.147 -0.003 -0.409 -0.448 -0.413 -0.022 -1.779]
#   fold: Brazil-Mangue, y_test size: 71
#
#  EXPERIMENT-6 Grouping: REGION, Model: ridge, Features: ['height', 'plot_id', 'species'], ALGO: RIDGE REGRESSION:
# Test R²     : -0.1676
# Test RMSE   : 1080.07 kg
# Train R² (log scale): 0.5106
# Train R² (orig scale): 0.0117
# Train RMSE  : 515.50 kg
# Num Features: 148
#
#  Cross-validation ---
# CV R² mean: -1.9525
# CV R² std : 1.5180
# CV scores : [-1.542 -1.632 -1.979 -4.65   0.041]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.6951
# Grouped CV R² std : 0.7352
# Grouped CV scores : [-0.805 -0.144 -0.004 -0.403 -0.41  -0.019 -2.07  -1.704]
#   fold: Brazil-Maruipe, y_test size: 59
#
#  EXPERIMENT-6 Grouping: REGION, Model: ridge, Features: ['height', 'plot_id', 'species'], ALGO: RIDGE REGRESSION:
# Test R²     : -0.7143
# Test RMSE   : 702.12 kg
# Train R² (log scale): 0.5162
# Train R² (orig scale): 0.0110
# Train RMSE  : 531.14 kg
# Num Features: 148
#
#  Cross-validation ---
# CV R² mean: -2.1885
# CV R² std : 1.6125
# CV scores : [-1.981 -1.614 -2.432 -4.95   0.035]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.6990
# Grouped CV R² std : 0.7433
# Grouped CV scores : [-0.821 -0.145 -0.005 -0.391 -0.397 -0.016 -2.053 -1.763]
#   fold: Brazil-Salinas, y_test size: 71
#
#  EXPERIMENT-6 Grouping: REGION, Model: ridge, Features: ['height', 'plot_id', 'species'], ALGO: RIDGE REGRESSION:
# Test R²     : -0.1101
# Test RMSE   : 602.22 kg
# Train R² (log scale): 0.5242
# Train R² (orig scale): 0.0130
# Train RMSE  : 531.76 kg
# Num Features: 148
#
#  Cross-validation ---
# CV R² mean: -2.0494
# CV R² std : 1.5316
# CV scores : [-1.544 -1.613 -2.444 -4.666  0.019]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.6951
# Grouped CV R² std : 0.6346
# Grouped CV scores : [-1.066 -0.211 -0.303 -0.301 -0.34  -0.003 -1.81  -1.527]
#   fold: ElSalvador, y_test size: 2633
#
#  EXPERIMENT-6 Grouping: REGION, Model: ridge, Features: ['height', 'plot_id', 'species'], ALGO: RIDGE REGRESSION:
# Test R²     : -0.0299
# Test RMSE   : 458.69 kg
# Train R² (log scale): 0.1997
# Train R² (orig scale): -0.1375
# Train RMSE  : 833.62 kg
# Num Features: 148
#
#  Cross-validation ---
# CV R² mean: -0.3975
# CV R² std : 0.5906
# CV scores : [-0.148 -0.12  -0.023 -0.122 -1.576]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.3011
# Grouped CV R² std : 0.3077
# Grouped CV scores : [-0.531 -0.151 -0.1    0.051 -0.166 -0.027 -0.611 -0.874]
# ============================================================
# EXPERIMENT EVALUATION:
# ============================================================
#
# Test set:
#   R²   : -0.346
#   RMSE : 761.75 kg
#
# Regular CrossValidation:
#   Mean   : -0.398
#   Std    : 0.591
#   Scores : [-0.148 -0.12  -0.023 -0.122 -1.576]
#
#   ❌ Test R² is negative (-0.346)
#   ❌ CV mean is negative (-0.398)
#
# Grouped CrossValidation:
#   Brazil-Barreto       :  -0.531  ❌ negative — cause unknown
#   Brazil-BocaGrande    :  -0.151  ❌ negative — cause unknown
#   Brazil-Caetano       :  -0.100  ❌ negative — cause unknown
#   Brazil-FuroGrande    :   0.051  ✅
#   Brazil-Furo_Do_Chato :  -0.166  ❌ negative — cause unknown
#   Brazil-Mangue        :  -0.027  ❌ negative — cause unknown
#   Brazil-Maruipe       :  -0.611  ❌ negative — cause unknown
#   Brazil-Salinas       :  -0.874  ❌ negative — cause unknown
#
#   Mean : -0.301
#   Std  : 0.308
#
#   ❌ Grouped CV mean is negative (-0.301)
#   ❌ Unexplained negative folds: ['Brazil-Barreto', 'Brazil-BocaGrande', 'Brazil-Caetano', 'Brazil-Furo_Do_Chato', 'Brazil-Mangue', 'Brazil-Maruipe', 'Brazil-Salinas']
#   ✅ High-AGB sites generalize correctly
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ NOT ACCEPTABLE
#
# [7/24] lasso['height', 'plot_id', 'species']
#   fold: Brazil-Barreto, y_test size: 54
#
#  EXPERIMENT-7 Grouping: REGION, Model: lasso, Features: ['height', 'plot_id', 'species'], ALGO: LASSO REGRESSION:
# Test R²     : -0.4011
# Test RMSE   : 656.06 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.0468
# Train RMSE  : 547.44 kg
# Num Features: 148
#
#  Cross-validation ---
# CV R² mean: -1.2107
# CV R² std : 2.0131
# CV scores : [-0.194 -0.281 -0.296 -5.233 -0.05 ]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.3519
# Grouped CV R² std : 1.2553
# Grouped CV scores : [-1.376 -0.    -0.053 -0.953 -0.926 -0.735 -3.17  -3.603]
#   fold: Brazil-BocaGrande, y_test size: 66
#
#  EXPERIMENT-7 Grouping: REGION, Model: lasso, Features: ['height', 'plot_id', 'species'], ALGO: LASSO REGRESSION:
# Test R²     : -0.2035
# Test RMSE   : 1065.43 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.0473
# Train RMSE  : 533.20 kg
# Num Features: 148
#
#  Cross-validation ---
# CV R² mean: -1.4661
# CV R² std : 2.0368
# CV scores : [-0.197 -0.272 -1.415 -5.42  -0.027]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.2921
# Grouped CV R² std : 1.3303
# Grouped CV scores : [-1.517 -0.    -0.058 -0.972 -0.748 -0.176 -3.212 -3.655]
#   fold: Brazil-Caetano, y_test size: 124
#
#  EXPERIMENT-7 Grouping: REGION, Model: lasso, Features: ['height', 'plot_id', 'species'], ALGO: LASSO REGRESSION:
# Test R²     : -0.1102
# Test RMSE   : 984.75 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.0475
# Train RMSE  : 524.11 kg
# Num Features: 148
#
#  Cross-validation ---
# CV R² mean: -0.9740
# CV R² std : 1.5703
# CV scores : [-0.205 -0.266 -0.264 -4.11  -0.025]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.3707
# Grouped CV R² std : 1.2187
# Grouped CV scores : [-1.519 -0.049 -0.933 -0.905 -0.721 -0.163 -3.126 -3.549]
#   fold: Brazil-FuroGrande, y_test size: 46
#
#  EXPERIMENT-7 Grouping: REGION, Model: lasso, Features: ['height', 'plot_id', 'species'], ALGO: LASSO REGRESSION:
# Test R²     : -0.9655
# Test RMSE   : 520.10 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.0469
# Train RMSE  : 549.96 kg
# Num Features: 148
#
#  Cross-validation ---
# CV R² mean: -1.2339
# CV R² std : 2.0632
# CV scores : [-0.195 -0.279 -0.301 -5.356 -0.039]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.8676
# Grouped CV R² std : 0.9637
# Grouped CV scores : [-0.823 -0.    -0.058 -0.973 -0.947 -0.748 -0.176 -3.215]
#   fold: Brazil-Furo_Do_Chato, y_test size: 52
#
#  EXPERIMENT-7 Grouping: REGION, Model: lasso, Features: ['height', 'plot_id', 'species'], ALGO: LASSO REGRESSION:
# Test R²     : -0.7008
# Test RMSE   : 849.28 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.0453
# Train RMSE  : 543.18 kg
# Num Features: 148
#
#  Cross-validation ---
# CV R² mean: -1.2014
# CV R² std : 2.0048
# CV scores : [-0.194 -0.275 -0.301 -5.207 -0.031]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.9260
# Grouped CV R² std : 1.1071
# Grouped CV scores : [-0.798 -0.    -0.06  -0.981 -0.956 -0.754 -0.179 -3.681]
#   fold: Brazil-Mangue, y_test size: 71
#
#  EXPERIMENT-7 Grouping: REGION, Model: lasso, Features: ['height', 'plot_id', 'species'], ALGO: LASSO REGRESSION:
# Test R²     : -0.1960
# Test RMSE   : 1093.15 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.0473
# Train RMSE  : 530.65 kg
# Num Features: 148
#
#  Cross-validation ---
# CV R² mean: -1.1771
# CV R² std : 1.9581
# CV scores : [-0.196 -0.274 -0.306 -5.088 -0.022]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.2279
# Grouped CV R² std : 1.3372
# Grouped CV scores : [-0.984 -0.    -0.059 -0.952 -0.752 -0.178 -3.226 -3.672]
#   fold: Brazil-Maruipe, y_test size: 59
#
#  EXPERIMENT-7 Grouping: REGION, Model: lasso, Features: ['height', 'plot_id', 'species'], ALGO: LASSO REGRESSION:
# Test R²     : -0.7626
# Test RMSE   : 711.94 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.0451
# Train RMSE  : 546.00 kg
# Num Features: 148
#
#  Cross-validation ---
# CV R² mean: -1.2332
# CV R² std : 2.0685
# CV scores : [-0.194 -0.278 -0.296 -5.366 -0.031]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.2764
# Grouped CV R² std : 1.3227
# Grouped CV scores : [-1.172 -0.    -0.058 -0.974 -0.949 -0.177 -3.218 -3.662]
#   fold: Brazil-Salinas, y_test size: 71
#
#  EXPERIMENT-7 Grouping: REGION, Model: lasso, Features: ['height', 'plot_id', 'species'], ALGO: LASSO REGRESSION:
# Test R²     : -0.1338
# Test RMSE   : 608.62 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.0482
# Train RMSE  : 548.01 kg
# Num Features: 148
#
#  Cross-validation ---
# CV R² mean: -1.1847
# CV R² std : 1.9626
# CV scores : [-0.196 -0.274 -0.306 -5.106 -0.042]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.3446
# Grouped CV R² std : 1.2349
# Grouped CV scores : [-1.26  -0.    -0.945 -0.918 -0.729 -0.167 -3.153 -3.583]
#   fold: ElSalvador, y_test size: 2633
#
#  EXPERIMENT-7 Grouping: REGION, Model: lasso, Features: ['height', 'plot_id', 'species'], ALGO: LASSO REGRESSION:
# Test R²     : -0.0023
# Test RMSE   : 452.51 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.1818
# Train RMSE  : 849.67 kg
# Num Features: 148
#
#  Cross-validation ---
# CV R² mean: -0.4821
# CV R² std : 0.7911
# CV scores : [-0.045 -0.182 -0.078 -0.045 -2.061]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.4343
# Grouped CV R² std : 0.3992
# Grouped CV scores : [-0.705 -0.41  -0.023  0.04  -0.268 -0.092 -1.022 -0.996]
# ============================================================
# EXPERIMENT EVALUATION:
# ============================================================
#
# Test set:
#   R²   : -0.386
#   RMSE : 771.31 kg
#
# Regular CrossValidation:
#   Mean   : -0.482
#   Std    : 0.791
#   Scores : [-0.045 -0.182 -0.078 -0.045 -2.061]
#
#   ❌ Test R² is negative (-0.386)
#   ❌ CV mean is negative (-0.482)
#
# Grouped CrossValidation:
#   Brazil-Barreto       :  -0.705  ❌ negative — cause unknown
#   Brazil-BocaGrande    :  -0.410  ❌ negative — cause unknown
#   Brazil-Caetano       :  -0.023  ❌ negative — cause unknown
#   Brazil-FuroGrande    :   0.040  ✅
#   Brazil-Furo_Do_Chato :  -0.268  ❌ negative — cause unknown
#   Brazil-Mangue        :  -0.092  ❌ negative — cause unknown
#   Brazil-Maruipe       :  -1.022  ❌ negative — cause unknown
#   Brazil-Salinas       :  -0.996  ❌ negative — cause unknown
#
#   Mean : -0.434
#   Std  : 0.399
#
#   ❌ Grouped CV mean is negative (-0.434)
#   ❌ Unexplained negative folds: ['Brazil-Barreto', 'Brazil-BocaGrande', 'Brazil-Caetano', 'Brazil-Furo_Do_Chato', 'Brazil-Mangue', 'Brazil-Maruipe', 'Brazil-Salinas']
#   ✅ High-AGB sites generalize correctly
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ NOT ACCEPTABLE
#
# [8/24] elasticnet['height', 'plot_id', 'species']
#   fold: Brazil-Barreto, y_test size: 54
#
#  EXPERIMENT-8 Grouping: REGION, Model: elasticnet, Features: ['height', 'plot_id', 'species'], ALGO: ELASTICNET REGRESSION:
# Test R²     : -0.4011
# Test RMSE   : 656.06 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.0468
# Train RMSE  : 547.44 kg
# Num Features: 148
#
#  Cross-validation ---
# CV R² mean: -1.2478
# CV R² std : 1.9842
# CV scores : [-0.305 -0.316 -0.372 -5.209 -0.036]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.3296
# Grouped CV R² std : 1.2563
# Grouped CV scores : [-1.197 -0.    -0.053 -0.953 -0.926 -0.735 -3.17  -3.603]
#   fold: Brazil-BocaGrande, y_test size: 66
#
#  EXPERIMENT-8 Grouping: REGION, Model: elasticnet, Features: ['height', 'plot_id', 'species'], ALGO: ELASTICNET REGRESSION:
# Test R²     : -0.2035
# Test RMSE   : 1065.43 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.0473
# Train RMSE  : 533.20 kg
# Num Features: 148
#
#  Cross-validation ---
# CV R² mean: -1.3167
# CV R² std : 2.0231
# CV scores : [-0.201 -0.431 -0.589 -5.344 -0.018]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.2121
# Grouped CV R² std : 1.3337
# Grouped CV scores : [-0.877 -0.    -0.058 -0.972 -0.748 -0.176 -3.212 -3.655]
#   fold: Brazil-Caetano, y_test size: 124
#
#  EXPERIMENT-8 Grouping: REGION, Model: elasticnet, Features: ['height', 'plot_id', 'species'], ALGO: ELASTICNET REGRESSION:
# Test R²     : -0.1102
# Test RMSE   : 984.75 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.0475
# Train RMSE  : 524.11 kg
# Num Features: 148
#
#  Cross-validation ---
# CV R² mean: -0.9883
# CV R² std : 1.5602
# CV scores : [-0.208 -0.3   -0.316 -4.101 -0.016]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.3617
# Grouped CV R² std : 1.2178
# Grouped CV scores : [-1.448 -0.049 -0.933 -0.905 -0.721 -0.163 -3.126 -3.549]
#   fold: Brazil-FuroGrande, y_test size: 46
#
#  EXPERIMENT-8 Grouping: REGION, Model: elasticnet, Features: ['height', 'plot_id', 'species'], ALGO: ELASTICNET REGRESSION:
# Test R²     : -0.9655
# Test RMSE   : 520.10 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.0469
# Train RMSE  : 549.96 kg
# Num Features: 148
#
#  Cross-validation ---
# CV R² mean: -1.2986
# CV R² std : 2.0801
# CV scores : [-0.315 -0.321 -0.378 -5.451 -0.027]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.8663
# Grouped CV R² std : 0.9638
# Grouped CV scores : [-0.813 -0.    -0.058 -0.973 -0.947 -0.748 -0.176 -3.215]
#   fold: Brazil-Furo_Do_Chato, y_test size: 52
#
#  EXPERIMENT-8 Grouping: REGION, Model: elasticnet, Features: ['height', 'plot_id', 'species'], ALGO: ELASTICNET REGRESSION:
# Test R²     : -0.7008
# Test RMSE   : 849.28 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.0453
# Train RMSE  : 543.18 kg
# Num Features: 148
#
#  Cross-validation ---
# CV R² mean: -1.2477
# CV R² std : 1.9876
# CV scores : [-0.315 -0.31  -0.378 -5.215 -0.02 ]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.9293
# Grouped CV R² std : 1.1067
# Grouped CV scores : [-0.824 -0.    -0.06  -0.981 -0.956 -0.754 -0.179 -3.681]
#   fold: Brazil-Mangue, y_test size: 71
#
# ...
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.7380
# Grouped CV R² std : 0.6454
# Grouped CV scores : [-1.002 -0.207 -0.338 -0.3   -0.462 -0.125 -2.043 -1.427]
#   fold: ElSalvador, y_test size: 2633
#
#  EXPERIMENT-22 Grouping: REGION, Model: ridge, Features: ['nisar_value_hhhh', 'nisar_value_hvhv', 'height', 'plot_id', 'species'], ALGO: RIDGE REGRESSION:
# Test R²     : -0.0313
# Test RMSE   : 459.01 kg
# Train R² (log scale): 0.2012
# Train R² (orig scale): -0.1383
# Train RMSE  : 833.89 kg
# Num Features: 150
#
#  Cross-validation ---
# CV R² mean: -0.4616
# CV R² std : 0.5575
# CV scores : [-0.203 -0.199 -0.209 -0.123 -1.575]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.3524
# Grouped CV R² std : 0.3153
# Grouped CV scores : [-0.53  -0.198 -0.109  0.05  -0.259 -0.119 -0.787 -0.868]
# ============================================================
# EXPERIMENT EVALUATION:
# ============================================================
#
# Test set:
#   R²   : -0.347
#   RMSE : 762.22 kg
#
# Regular CrossValidation:
#   Mean   : -0.462
#   Std    : 0.557
#   Scores : [-0.203 -0.199 -0.209 -0.123 -1.575]
#
#   ❌ Test R² is negative (-0.347)
#   ❌ CV mean is negative (-0.462)
#
# Grouped CrossValidation:
#   Brazil-Barreto       :  -0.530  ❌ negative — cause unknown
#   Brazil-BocaGrande    :  -0.198  ❌ negative — cause unknown
#   Brazil-Caetano       :  -0.109  ❌ negative — cause unknown
#   Brazil-FuroGrande    :   0.050  ✅
#   Brazil-Furo_Do_Chato :  -0.259  ❌ negative — cause unknown
#   Brazil-Mangue        :  -0.119  ❌ negative — cause unknown
#   Brazil-Maruipe       :  -0.787  ❌ negative — cause unknown
#   Brazil-Salinas       :  -0.868  ❌ negative — cause unknown
#
#   Mean : -0.352
#   Std  : 0.315
#
#   ❌ Grouped CV mean is negative (-0.352)
#   ❌ Unexplained negative folds: ['Brazil-Barreto', 'Brazil-BocaGrande', 'Brazil-Caetano', 'Brazil-Furo_Do_Chato', 'Brazil-Mangue', 'Brazil-Maruipe', 'Brazil-Salinas']
#   ✅ High-AGB sites generalize correctly
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ NOT ACCEPTABLE
#
# [23/24] lasso['nisar_value_hhhh', 'nisar_value_hvhv', 'height', 'plot_id', 'species']
#   fold: Brazil-Barreto, y_test size: 54
#
#  EXPERIMENT-23 Grouping: REGION, Model: lasso, Features: ['nisar_value_hhhh', 'nisar_value_hvhv', 'height', 'plot_id', 'species'], ALGO: LASSO REGRESSION:
# Test R²     : -0.4011
# Test RMSE   : 656.06 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.0468
# Train RMSE  : 547.44 kg
# Num Features: 150
#
#  Cross-validation ---
# CV R² mean: -1.4239
# CV R² std : 1.8868
# CV scores : [-0.194 -0.288 -1.546 -5.042 -0.05 ]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.3428
# Grouped CV R² std : 1.2554
# Grouped CV scores : [-1.303 -0.    -0.053 -0.953 -0.926 -0.735 -3.17  -3.603]
#   fold: Brazil-BocaGrande, y_test size: 66
#
#  EXPERIMENT-23 Grouping: REGION, Model: lasso, Features: ['nisar_value_hhhh', 'nisar_value_hvhv', 'height', 'plot_id', 'species'], ALGO: LASSO REGRESSION:
# Test R²     : -0.2035
# Test RMSE   : 1065.43 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.0473
# Train RMSE  : 533.20 kg
# Num Features: 150
#
#  Cross-validation ---
# CV R² mean: -1.4734
# CV R² std : 2.0225
# CV scores : [-0.197 -0.285 -1.471 -5.387 -0.027]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.2201
# Grouped CV R² std : 1.3318
# Grouped CV scores : [-0.941 -0.    -0.058 -0.972 -0.748 -0.176 -3.212 -3.655]
#   fold: Brazil-Caetano, y_test size: 124
#
#  EXPERIMENT-23 Grouping: REGION, Model: lasso, Features: ['nisar_value_hhhh', 'nisar_value_hvhv', 'height', 'plot_id', 'species'], ALGO: LASSO REGRESSION:
# Test R²     : -0.1102
# Test RMSE   : 984.75 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.0475
# Train RMSE  : 524.11 kg
# Num Features: 150
#
#  Cross-validation ---
# CV R² mean: -0.9548
# CV R² std : 1.5320
# CV scores : [-0.205 -0.266 -0.264 -4.014 -0.025]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.3532
# Grouped CV R² std : 1.2174
# Grouped CV scores : [-1.38  -0.049 -0.933 -0.905 -0.721 -0.163 -3.126 -3.549]
#   fold: Brazil-FuroGrande, y_test size: 46
#
#  EXPERIMENT-23 Grouping: REGION, Model: lasso, Features: ['nisar_value_hhhh', 'nisar_value_hvhv', 'height', 'plot_id', 'species'], ALGO: LASSO REGRESSION:
# Test R²     : -0.9655
# Test RMSE   : 520.10 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.0469
# Train RMSE  : 549.96 kg
# Num Features: 150
#
#  Cross-validation ---
# CV R² mean: -1.2042
# CV R² std : 2.0026
# CV scores : [-0.195 -0.282 -0.301 -5.205 -0.039]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.8676
# Grouped CV R² std : 0.9637
# Grouped CV scores : [-0.823 -0.    -0.058 -0.973 -0.947 -0.748 -0.176 -3.215]
#   fold: Brazil-Furo_Do_Chato, y_test size: 52
#
#  EXPERIMENT-23 Grouping: REGION, Model: lasso, Features: ['nisar_value_hhhh', 'nisar_value_hvhv', 'height', 'plot_id', 'species'], ALGO: LASSO REGRESSION:
# Test R²     : -0.7008
# Test RMSE   : 849.28 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.0453
# Train RMSE  : 543.18 kg
# Num Features: 150
#
#  Cross-validation ---
# CV R² mean: -1.5308
# CV R² std : 1.9200
# CV scores : [-0.194 -0.279 -2.08  -5.07  -0.031]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.9260
# Grouped CV R² std : 1.1071
# Grouped CV scores : [-0.798 -0.    -0.06  -0.981 -0.956 -0.754 -0.179 -3.681]
#   fold: Brazil-Mangue, y_test size: 71
#
#  EXPERIMENT-23 Grouping: REGION, Model: lasso, Features: ['nisar_value_hhhh', 'nisar_value_hvhv', 'height', 'plot_id', 'species'], ALGO: LASSO REGRESSION:
# Test R²     : -0.1960
# Test RMSE   : 1093.15 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.0473
# Train RMSE  : 530.65 kg
# Num Features: 150
#
#  Cross-validation ---
# CV R² mean: -1.4062
# CV R² std : 1.8993
# CV scores : [-0.196 -0.275 -1.476 -5.063 -0.022]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.2173
# Grouped CV R² std : 1.3394
# Grouped CV scores : [-0.9   -0.    -0.059 -0.952 -0.752 -0.178 -3.226 -3.672]
#   fold: Brazil-Maruipe, y_test size: 59
#
#  EXPERIMENT-23 Grouping: REGION, Model: lasso, Features: ['nisar_value_hhhh', 'nisar_value_hvhv', 'height', 'plot_id', 'species'], ALGO: LASSO REGRESSION:
# Test R²     : -0.7626
# Test RMSE   : 711.94 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.0451
# Train RMSE  : 546.00 kg
# Num Features: 150
#
#  Cross-validation ---
# CV R² mean: -1.4895
# CV R² std : 2.0140
# CV scores : [-0.194 -0.278 -1.581 -5.363 -0.031]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.2706
# Grouped CV R² std : 1.3232
# Grouped CV scores : [-1.126 -0.    -0.058 -0.974 -0.949 -0.177 -3.218 -3.662]
#   fold: Brazil-Salinas, y_test size: 71
#
#  EXPERIMENT-23 Grouping: REGION, Model: lasso, Features: ['nisar_value_hhhh', 'nisar_value_hvhv', 'height', 'plot_id', 'species'], ALGO: LASSO REGRESSION:
# Test R²     : -0.1338
# Test RMSE   : 608.62 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.0482
# Train RMSE  : 548.01 kg
# Num Features: 150
#
#  Cross-validation ---
# CV R² mean: -1.1820
# CV R² std : 1.9553
# CV scores : [-0.196 -0.278 -0.306 -5.088 -0.042]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.3446
# Grouped CV R² std : 1.2349
# Grouped CV scores : [-1.26  -0.    -0.945 -0.918 -0.729 -0.167 -3.153 -3.583]
#   fold: ElSalvador, y_test size: 2633
#
#  EXPERIMENT-23 Grouping: REGION, Model: lasso, Features: ['nisar_value_hhhh', 'nisar_value_hvhv', 'height', 'plot_id', 'species'], ALGO: LASSO REGRESSION:
# Test R²     : -0.0023
# Test RMSE   : 452.51 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.1818
# Train RMSE  : 849.67 kg
# Num Features: 150
#
#  Cross-validation ---
# CV R² mean: -0.4827
# CV R² std : 0.4488
# CV scores : [-0.368 -0.193 -0.324 -0.162 -1.367]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.4489
# Grouped CV R² std : 0.3649
# Grouped CV scores : [-0.606 -0.41  -0.103 -0.064 -0.281 -0.11  -1.022 -0.996]
# ============================================================
# EXPERIMENT EVALUATION:
# ============================================================
#
# Test set:
#   R²   : -0.386
#   RMSE : 771.31 kg
#
# Regular CrossValidation:
#   Mean   : -0.483
#   Std    : 0.449
#   Scores : [-0.368 -0.193 -0.324 -0.162 -1.367]
#
#   ❌ Test R² is negative (-0.386)
#   ❌ CV mean is negative (-0.483)
#
# Grouped CrossValidation:
#   Brazil-Barreto       :  -0.606  ❌ negative — cause unknown
#   Brazil-BocaGrande    :  -0.410  ❌ negative — cause unknown
#   Brazil-Caetano       :  -0.103  ❌ negative — cause unknown
#   Brazil-FuroGrande    :  -0.064  ❌ negative — cause unknown
#   Brazil-Furo_Do_Chato :  -0.281  ❌ negative — cause unknown
#   Brazil-Mangue        :  -0.110  ❌ negative — cause unknown
#   Brazil-Maruipe       :  -1.022  ❌ negative — cause unknown
#   Brazil-Salinas       :  -0.996  ❌ negative — cause unknown
#
#   Mean : -0.449
#   Std  : 0.365
#
#   ❌ Grouped CV mean is negative (-0.449)
#   ❌ Unexplained negative folds: ['Brazil-Barreto', 'Brazil-BocaGrande', 'Brazil-Caetano', 'Brazil-FuroGrande', 'Brazil-Furo_Do_Chato', 'Brazil-Mangue', 'Brazil-Maruipe', 'Brazil-Salinas']
#   ✅ High-AGB sites generalize correctly
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ NOT ACCEPTABLE
#
# [24/24] elasticnet['nisar_value_hhhh', 'nisar_value_hvhv', 'height', 'plot_id', 'species']
#   fold: Brazil-Barreto, y_test size: 54
#
#  EXPERIMENT-24 Grouping: REGION, Model: elasticnet, Features: ['nisar_value_hhhh', 'nisar_value_hvhv', 'height', 'plot_id', 'species'], ALGO: ELASTICNET REGRESSION:
# Test R²     : -0.4011
# Test RMSE   : 656.06 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.0468
# Train RMSE  : 547.44 kg
# Num Features: 150
#
#  Cross-validation ---
# CV R² mean: -1.4605
# CV R² std : 1.8423
# CV scores : [-0.306 -0.334 -1.654 -4.969 -0.039]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.3296
# Grouped CV R² std : 1.2563
# Grouped CV scores : [-1.197 -0.    -0.053 -0.953 -0.926 -0.735 -3.17  -3.603]
#   fold: Brazil-BocaGrande, y_test size: 66
#
#  EXPERIMENT-24 Grouping: REGION, Model: elasticnet, Features: ['nisar_value_hhhh', 'nisar_value_hvhv', 'height', 'plot_id', 'species'], ALGO: ELASTICNET REGRESSION:
# Test R²     : -0.2035
# Test RMSE   : 1065.43 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.0473
# Train RMSE  : 533.20 kg
# Num Features: 150
#
#  Cross-validation ---
# CV R² mean: -1.2830
# CV R² std : 1.9475
# CV scores : [-0.201 -0.443 -0.589 -5.158 -0.022]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.2086
# Grouped CV R² std : 1.3346
# Grouped CV scores : [-0.849 -0.    -0.058 -0.972 -0.748 -0.176 -3.212 -3.655]
#   fold: Brazil-Caetano, y_test size: 124
#
#  EXPERIMENT-24 Grouping: REGION, Model: elasticnet, Features: ['nisar_value_hhhh', 'nisar_value_hvhv', 'height', 'plot_id', 'species'], ALGO: ELASTICNET REGRESSION:
# Test R²     : -0.1102
# Test RMSE   : 984.75 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.0475
# Train RMSE  : 524.11 kg
# Num Features: 150
#
#  Cross-validation ---
# CV R² mean: -0.9744
# CV R² std : 1.5277
# CV scores : [-0.208 -0.3   -0.314 -4.023 -0.027]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.3617
# Grouped CV R² std : 1.2178
# Grouped CV scores : [-1.448 -0.049 -0.933 -0.905 -0.721 -0.163 -3.126 -3.549]
#   fold: Brazil-FuroGrande, y_test size: 46
#
#  EXPERIMENT-24 Grouping: REGION, Model: elasticnet, Features: ['nisar_value_hhhh', 'nisar_value_hvhv', 'height', 'plot_id', 'species'], ALGO: ELASTICNET REGRESSION:
# Test R²     : -0.9655
# Test RMSE   : 520.10 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.0469
# Train RMSE  : 549.96 kg
# Num Features: 150
#
#  Cross-validation ---
# CV R² mean: -1.2899
# CV R² std : 2.0599
# CV scores : [-0.315 -0.326 -0.378 -5.402 -0.029]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.8663
# Grouped CV R² std : 0.9638
# Grouped CV scores : [-0.813 -0.    -0.058 -0.973 -0.947 -0.748 -0.176 -3.215]
#   fold: Brazil-Furo_Do_Chato, y_test size: 52
#
#  EXPERIMENT-24 Grouping: REGION, Model: elasticnet, Features: ['nisar_value_hhhh', 'nisar_value_hvhv', 'height', 'plot_id', 'species'], ALGO: ELASTICNET REGRESSION:
# Test R²     : -0.7008
# Test RMSE   : 849.28 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.0453
# Train RMSE  : 543.18 kg
# Num Features: 150
#
#  Cross-validation ---
# CV R² mean: -1.5606
# CV R² std : 1.8894
# CV scores : [-0.315 -0.316 -2.113 -5.036 -0.023]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.9293
# Grouped CV R² std : 1.1067
# Grouped CV scores : [-0.824 -0.    -0.06  -0.981 -0.956 -0.754 -0.179 -3.681]
#   fold: Brazil-Mangue, y_test size: 71
#
#  EXPERIMENT-24 Grouping: REGION, Model: elasticnet, Features: ['nisar_value_hhhh', 'nisar_value_hvhv', 'height', 'plot_id', 'species'], ALGO: ELASTICNET REGRESSION:
# Test R²     : -0.1960
# Test RMSE   : 1093.15 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.0473
# Train RMSE  : 530.65 kg
# Num Features: 150
#
#  Cross-validation ---
# CV R² mean: -1.2326
# CV R² std : 1.8326
# CV scores : [-0.2   -0.436 -0.638 -4.874 -0.016]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.2038
# Grouped CV R² std : 1.3431
# Grouped CV scores : [-0.791 -0.    -0.059 -0.952 -0.752 -0.178 -3.226 -3.672]
#   fold: Brazil-Maruipe, y_test size: 59
#
#  EXPERIMENT-24 Grouping: REGION, Model: elasticnet, Features: ['nisar_value_hhhh', 'nisar_value_hvhv', 'height', 'plot_id', 'species'], ALGO: ELASTICNET REGRESSION:
# Test R²     : -0.7626
# Test RMSE   : 711.94 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.0451
# Train RMSE  : 546.00 kg
# Num Features: 150
#
#  Cross-validation ---
# CV R² mean: -1.4091
# CV R² std : 1.9151
# CV scores : [-0.315 -0.441 -1.092 -5.175 -0.024]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.2331
# Grouped CV R² std : 1.3310
# Grouped CV scores : [-0.826 -0.    -0.058 -0.974 -0.949 -0.177 -3.218 -3.662]
#   fold: Brazil-Salinas, y_test size: 71
#
#  EXPERIMENT-24 Grouping: REGION, Model: elasticnet, Features: ['nisar_value_hhhh', 'nisar_value_hvhv', 'height', 'plot_id', 'species'], ALGO: ELASTICNET REGRESSION:
# Test R²     : -0.1338
# Test RMSE   : 608.62 kg
# Train R² (log scale): 0.0000
# Train R² (orig scale): -0.0482
# Train RMSE  : 548.01 kg
# Num Features: 150
#
#  Cross-validation ---
# CV R² mean: -1.2548
# CV R² std : 1.8858
# CV scores : [-0.199 -0.44  -0.596 -5.007 -0.033]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.3448
# Grouped CV R² std : 1.2349
# Grouped CV scores : [-1.261 -0.    -0.945 -0.918 -0.729 -0.167 -3.153 -3.583]
#   fold: ElSalvador, y_test size: 2633
#
#  EXPERIMENT-24 Grouping: REGION, Model: elasticnet, Features: ['nisar_value_hhhh', 'nisar_value_hvhv', 'height', 'plot_id', 'species'], ALGO: ELASTICNET REGRESSION:
# Test R²     : -0.0125
# Test RMSE   : 454.82 kg
# Train R² (log scale): 0.1117
# Train R² (orig scale): -0.1706
# Train RMSE  : 845.64 kg
# Num Features: 150
#
#  Cross-validation ---
# CV R² mean: -0.4656
# CV R² std : 0.4562
# CV scores : [-0.258 -0.249 -0.297 -0.151 -1.373]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.3883
# Grouped CV R² std : 0.3891
# Grouped CV scores : [-0.643 -0.285 -0.069  0.012 -0.141 -0.035 -1.022 -0.923]
# ============================================================
# EXPERIMENT EVALUATION:
# ============================================================
#
# Test set:
#   R²   : -0.387
#   RMSE : 771.57 kg
#
# Regular CrossValidation:
#   Mean   : -0.466
#   Std    : 0.456
#   Scores : [-0.258 -0.249 -0.297 -0.151 -1.373]
#
#   ❌ Test R² is negative (-0.387)
#   ❌ CV mean is negative (-0.466)
#
# Grouped CrossValidation:
#   Brazil-Barreto       :  -0.643  ❌ negative — cause unknown
#   Brazil-BocaGrande    :  -0.285  ❌ negative — cause unknown
#   Brazil-Caetano       :  -0.069  ❌ negative — cause unknown
#   Brazil-FuroGrande    :   0.012  ✅
#   Brazil-Furo_Do_Chato :  -0.141  ❌ negative — cause unknown
#   Brazil-Mangue        :  -0.035  ❌ negative — cause unknown
#   Brazil-Maruipe       :  -1.022  ❌ negative — cause unknown
#   Brazil-Salinas       :  -0.923  ❌ negative — cause unknown
#
#   Mean : -0.388
#   Std  : 0.389
#
#   ❌ Grouped CV mean is negative (-0.388)
#   ❌ Unexplained negative folds: ['Brazil-Barreto', 'Brazil-BocaGrande', 'Brazil-Caetano', 'Brazil-Furo_Do_Chato', 'Brazil-Mangue', 'Brazil-Maruipe', 'Brazil-Salinas']
#   ✅ High-AGB sites generalize correctly
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ NOT ACCEPTABLE
#
# Completed: 24/24 experiments

# %% [markdown]
# ### CONCLUSION
# Complete failure across all feature sets and all regions.
# Every LOGO fold for every experiment returns negative R².
# No combination of NISAR bands, height, plot_id, or species allows a model trained on 8 regions to predict AGB in a 9th unseen region.
#
# **Brazil-FuroGrande is the only consistently near-positive fold**
#  - In experiments 6, 7, 8, 17, 18, 21, 22, 24 it scores between +0.012 and +0.051 in grouped CV.
#  - This is not a signal — it suggests FuroGrande's AGB distribution happens to overlap with the training data mean, so even a poor model accidentally scores near zero.
#
# **Brazil-Maruipe and Brazil-Salinas are the worst folds**
#  - Consistently scoring -1.0 to -1.5 in grouped CV. These sites have AGB ranges most unlike the rest of the training data.
#
# **Compared to no-grouping results, region-grouping reveals the truth**
#  - No-grouping gave CV R² ~0.43 for experiments with plot_id + species.
#  - Region-grouping collapses that to -0.30 to -0.55.
#  - The 0.43 was entirely memorization of plot identities — not a real signal.

# %% [markdown]
# # RANDOM FOREST

# %%
# %run Model_functions.ipynb
rf_experiments = {}

# %%
def run_rf_experiment(X_df, y, features,
                      is_groups, groups, test_cv,
                      idx,label_in):
    label = f"EXPERIMENT-{idx} {label_in}, Features: {features}."
    
    X = X_df[features]
    categorical_cols = get_categorical_cols(X)
    if categorical_cols:
        X = pd.get_dummies(X, columns=categorical_cols, dtype=int)

    if is_groups:
        results = randomForest_groups(X, y, test_cv, groups, label, False, True)
    else:
        results = randomForest_regular(X, y, test_cv, label, False, True)

    rf_experiments[label] = results
    if is_groups:
        show_importances(results)

    fold_sites = None
    if is_groups:
        fold_sites = results["fold_sites"]
        
    if is_groups:
        evaluate_experiment(label=label,
                            results=results,
                            fold_sites=results["fold_sites"],
                            near_zero_sites=near_zero_sites,
                            high_agb_sites =high_agb_sites)
    else:
        evaluate_experiment(label=label,
                            results=results,
                            fold_sites=None,
                            near_zero_sites=near_zero_plots,
                            high_agb_sites =high_agb_plots)

# %%
def rf_experiment(X, y, is_groups, groups, features_list, label):
    total     = len(features_list)
    completed = 0

    for features in features_list:
        completed += 1
        print(f"\n[{completed}/{total}]")

        try:
            run_rf_experiment(X, y, features,
                              is_groups, groups, test_cv,
                              completed, label)
        except Exception as e:
            print(f"  ERROR: {e}")

    print(f"\nCompleted: {completed}/{total} experiments")

# %% [markdown]
# ### RANDOM FOREST WITHOUT GROUPS

# %%
rf_experiment(X, y,
              is_groups=False, groups=None,
              features_list=features_list, label="No groups")
#3rd-EXPERIMENT: No groups. RANDOM FOREST.
# Out:
# [1/6]
#
#  RANDOM FOREST: EXPERIMENT-1 No groups, Features: ['height'].
# Test R²     : -0.0153
# Test RMSE   : 446.34 kg
# Train R² (log scale): 0.4168
# Train R² (orig scale): 0.0246
# Train RMSE  : 550.20 kg
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: 0.3672
# CV R² std : 0.0678
# CV scores : [0.416 0.388 0.449 0.259 0.324]
# ============================================================
# EXPERIMENT EVALUATION: EXPERIMENT-1 No groups, Features: ['height'].
# ============================================================
#
# Test set:
#   R²   : -0.015
#   RMSE : 446.34 kg
#
# Regular CrossValidation:
#   Mean   : 0.367
#   Std    : 0.068
#   Scores : [0.416 0.388 0.449 0.259 0.324]
#
#   ❌ Test R² is negative (-0.015)
#   ✅ CV mean is positive (0.367)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ NOT ACCEPTABLE
#
# [2/6]
#
#  RANDOM FOREST: EXPERIMENT-2 No groups, Features: ['height', 'plot_id', 'species'].
# Test R²     : 0.0087
# Test RMSE   : 441.02 kg
# Train R² (log scale): 0.5571
# Train R² (orig scale): 0.0441
# Train RMSE  : 544.69 kg
# Num Features: 148
#
#  Cross-validation ---
# CV R² mean: 0.4624
# CV R² std : 0.0356
# CV scores : [0.459 0.462 0.528 0.425 0.438]
# ============================================================
# EXPERIMENT EVALUATION: EXPERIMENT-2 No groups, Features: ['height', 'plot_id', 'species'].
# ============================================================
#
# Test set:
#   R²   : 0.009
#   RMSE : 441.02 kg
#
# Regular CrossValidation:
#   Mean   : 0.462
#   Std    : 0.036
#   Scores : [0.459 0.462 0.528 0.425 0.438]
#
#   ✅ Test R² is positive (0.009)
#   ✅ CV mean is positive (0.462)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ✅ ACCEPTABLE
#
# [3/6]
#
#  RANDOM FOREST: EXPERIMENT-3 No groups, Features: ['height', 'nisar_value_hhhh', 'nisar_value_hvhv'].
# Test R²     : 0.0107
# Test RMSE   : 440.57 kg
# Train R² (log scale): 0.4491
# Train R² (orig scale): 0.0390
# Train RMSE  : 546.13 kg
# Num Features: 3
#
#  Cross-validation ---
# CV R² mean: 0.3894
# CV R² std : 0.0668
# CV scores : [0.446 0.396 0.476 0.3   0.329]
# ============================================================
# EXPERIMENT EVALUATION: EXPERIMENT-3 No groups, Features: ['height', 'nisar_value_hhhh', 'nisar_value_hvhv'].
# ============================================================
#
# Test set:
#   R²   : 0.011
#   RMSE : 440.57 kg
#
# Regular CrossValidation:
#   Mean   : 0.389
#   Std    : 0.067
#   Scores : [0.446 0.396 0.476 0.3   0.329]
#
#   ✅ Test R² is positive (0.011)
#   ✅ CV mean is positive (0.389)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ✅ ACCEPTABLE
#
# [4/6]
#
#  RANDOM FOREST: EXPERIMENT-4 No groups, Features: ['nisar_value_hhhh', 'nisar_value_hvhv'].
# Test R²     : 0.0120
# Test RMSE   : 440.29 kg
# Train R² (log scale): 0.4476
# Train R² (orig scale): 0.0377
# Train RMSE  : 546.50 kg
# Num Features: 2
#
#  Cross-validation ---
# CV R² mean: 0.3907
# CV R² std : 0.0679
# CV scores : [0.445 0.396 0.482 0.308 0.321]
# ============================================================
# EXPERIMENT EVALUATION: EXPERIMENT-4 No groups, Features: ['nisar_value_hhhh', 'nisar_value_hvhv'].
# ============================================================
#
# Test set:
#   R²   : 0.012
#   RMSE : 440.29 kg
#
# Regular CrossValidation:
#   Mean   : 0.391
#   Std    : 0.068
#   Scores : [0.445 0.396 0.482 0.308 0.321]
#
#   ✅ Test R² is positive (0.012)
#   ✅ CV mean is positive (0.391)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ✅ ACCEPTABLE
#
# [5/6]
#
#  RANDOM FOREST: EXPERIMENT-5 No groups, Features: ['nisar_value_hhhh', 'nisar_value_hvhv', 'plot_id', 'species'].
# Test R²     : 0.0241
# Test RMSE   : 437.58 kg
# Train R² (log scale): 0.5605
# Train R² (orig scale): 0.0421
# Train RMSE  : 545.25 kg
# Num Features: 149
#
#  Cross-validation ---
# CV R² mean: 0.4660
# CV R² std : 0.0407
# CV scores : [0.466 0.452 0.543 0.44  0.428]
# ============================================================
# EXPERIMENT EVALUATION: EXPERIMENT-5 No groups, Features: ['nisar_value_hhhh', 'nisar_value_hvhv', 'plot_id', 'species'].
# ============================================================
#
# Test set:
#   R²   : 0.024
#   RMSE : 437.58 kg
#
# Regular CrossValidation:
#   Mean   : 0.466
#   Std    : 0.041
#   Scores : [0.466 0.452 0.543 0.44  0.428]
#
#   ✅ Test R² is positive (0.024)
#   ✅ CV mean is positive (0.466)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ✅ ACCEPTABLE
#
# [6/6]
#
#  RANDOM FOREST: EXPERIMENT-6 No groups, Features: ['nisar_value_hhhh', 'nisar_value_hvhv', 'height', 'plot_id', 'species'].
# Test R²     : 0.0225
# Test RMSE   : 437.94 kg
# Train R² (log scale): 0.5653
# Train R² (orig scale): 0.0480
# Train RMSE  : 543.57 kg
# Num Features: 150
#
#  Cross-validation ---
# CV R² mean: 0.4651
# CV R² std : 0.0399
# CV scores : [0.469 0.455 0.539 0.432 0.43 ]
# ============================================================
# EXPERIMENT EVALUATION: EXPERIMENT-6 No groups, Features: ['nisar_value_hhhh', 'nisar_value_hvhv', 'height', 'plot_id', 'species'].
# ============================================================
#
# Test set:
#   R²   : 0.023
#   RMSE : 437.94 kg
#
# Regular CrossValidation:
#   Mean   : 0.465
#   Std    : 0.040
#   Scores : [0.469 0.455 0.539 0.432 0.43 ]
#
#   ✅ Test R² is positive (0.023)
#   ✅ CV mean is positive (0.465)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ✅ ACCEPTABLE
#
# Completed: 6/6 experiments

# %% [markdown]
# **COMMENTS**
#
# **NISAR alone (Experiment 4) outperforms height alone (Experiment 1)**
#  - Test R² 0.012 vs -0.015).
#  - Random Forest is picking up a non-linear relationship in NISAR backscatter that linear models completely missed.
#
# **Adding height to NISAR (Experiment 3 vs 4) gives marginal improvement**
#  - CV R² 0.389 vs 0.391 - essentially identical
#  - Height contributes almost nothing on top of NISAR in the RF framework, unlike what we expected from the correlation analysis.
#
# **Best result is NISAR + plot_id + species**
#  - Test R² 0.024.
#  - Adding height (Experiment 6) actually slightly reduces test R² from 0.024 to 0.023.
#  - Height is not adding value once NISAR and categorical features are present.
#
# **Experiments 2, 5, 6**
#  - These are passing only due to plot_id and species presence.
#
# **CV R² ~0.39–0.47 but Test R² near zero across all passing experiments**
#  - The same train/test gap from linear experiments persists.
#  - CV is inflated — the random 80/20 split is still allowing similar plots to appear in both train and test folds.

# %% [markdown]
# ### RANDOM FOREST WITH REGION GROUPS

# %%
rf_experiment(X, y,
              is_groups=True, groups=dataset_groups,
              features_list=features_list,
              label="Grouping: REGION")
# 4th-EXPERIMENT: REGION level groups. RANDOM FOREST.
# Out:
# [1/6]
#
#  RANDOM FOREST: EXPERIMENT-1 Grouping: REGION, Features: ['height'].
# Test R²     : -0.1766
# Test RMSE   : 865.58 kg
# Train R² (log scale): 0.4273
# Train R² (orig scale): 0.0310
# Train RMSE  : 511.47 kg
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: -1.7944
# CV R² std : 0.9176
# CV scores : [-2.238 -2.33  -1.609 -2.697 -0.098]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.8978
# Grouped CV R² std : 0.9354
# Grouped CV scores : [-1.762 -0.832 -0.127 -0.052 -0.298 -2.769 -0.444]
#
# Top 10 feature importances:
#   height                                        1.0000  ==================================================
# ============================================================
# EXPERIMENT EVALUATION: EXPERIMENT-1 Grouping: REGION, Features: ['height'].
# ============================================================
#
# Test set:
#   R²   : -0.177
#   RMSE : 865.58 kg
#
# Regular CrossValidation:
#   Mean   : -1.794
#   Std    : 0.918
#   Scores : [-2.238 -2.33  -1.609 -2.697 -0.098]
#
#   ❌ Test R² is negative (-0.177)
#   ❌ CV mean is negative (-1.794)
#
# Grouped CrossValidation:
#   ElSalvador           :  -1.762  ❌ negative — cause unknown
#   Brazil-Caetano       :  -0.832  ❌ negative — cause unknown
#   Brazil-Mangue        :  -0.127  ❌ negative — cause unknown
#   Brazil-Maruipe       :  -0.052  ❌ negative — cause unknown
#   Brazil-Barreto       :  -0.298  ❌ negative — cause unknown
#   Brazil-Furo_Do_Chato :  -2.769  ❌ negative — cause unknown
#   Brazil-FuroGrande    :  -0.444  ❌ negative — cause unknown
#
#   Mean : -0.898
#   Std  : 0.935
#
#   ❌ Grouped CV mean is negative (-0.898)
#   ❌ Unexplained negative folds: ['ElSalvador', 'Brazil-Caetano', 'Brazil-Mangue', 'Brazil-Maruipe', 'Brazil-Barreto', 'Brazil-Furo_Do_Chato', 'Brazil-FuroGrande']
#   ✅ High-AGB sites generalize correctly
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ NOT ACCEPTABLE
#
# [2/6]
#
#  RANDOM FOREST: EXPERIMENT-2 Grouping: REGION, Features: ['height', 'plot_id', 'species'].
# Test R²     : -0.0817
# Test RMSE   : 829.93 kg
# Train R² (log scale): 0.5682
# Train R² (orig scale): 0.0506
# Train RMSE  : 506.26 kg
# Num Features: 148
#
#  Cross-validation ---
# CV R² mean: -1.2374
# CV R² std : 1.0746
# CV scores : [-0.885 -0.937 -1.224 -3.204  0.063]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.4985
# Grouped CV R² std : 0.6750
# Grouped CV scores : [-2.024 -0.748  0.08  -0.008 -0.122 -0.45  -0.217]
#
# Top 10 feature importances:
#   height                                        0.2229  ===========
#   plot_id_El_Cañón_del_Bagre_17_6               0.0923  ====
#   plot_id_El_Cañón_del_Bagre_17_1               0.0531  ==
#   species_Rhizophora mangle                     0.0526  ==
#   plot_id_San_Sebastián_El_Chingo_16_4          0.0433  ==
#   plot_id_El_Plan_de_la_Ceiba_8_4               0.0356  =
#   species_racemosa                              0.0348  =
#   plot_id_El_Llorón_7_5                         0.0336  =
#   plot_id_FUR_Furo do Chato                     0.0311  =
#   plot_id_San_Sebastián_El_Chingo_16_2          0.0285  =
# ============================================================
# EXPERIMENT EVALUATION: EXPERIMENT-2 Grouping: REGION, Features: ['height', 'plot_id', 'species'].
# ============================================================
#
# Test set:
#   R²   : -0.082
#   RMSE : 829.93 kg
#
# Regular CrossValidation:
#   Mean   : -1.237
#   Std    : 1.075
#   Scores : [-0.885 -0.937 -1.224 -3.204  0.063]
#
#   ❌ Test R² is negative (-0.082)
#   ❌ CV mean is negative (-1.237)
#
# Grouped CrossValidation:
#   ElSalvador           :  -2.024  ❌ negative — cause unknown
#   Brazil-Caetano       :  -0.748  ❌ negative — cause unknown
#   Brazil-Mangue        :   0.080  ✅
#   Brazil-Maruipe       :  -0.008  ❌ negative — cause unknown
#   Brazil-Barreto       :  -0.122  ❌ negative — cause unknown
#   Brazil-Furo_Do_Chato :  -0.450  ❌ negative — cause unknown
#   Brazil-FuroGrande    :  -0.217  ❌ negative — cause unknown
#
#   Mean : -0.498
#   Std  : 0.675
#
#   ❌ Grouped CV mean is negative (-0.498)
#   ❌ Unexplained negative folds: ['ElSalvador', 'Brazil-Caetano', 'Brazil-Maruipe', 'Brazil-Barreto', 'Brazil-Furo_Do_Chato', 'Brazil-FuroGrande']
#   ✅ High-AGB sites generalize correctly
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ NOT ACCEPTABLE
#
# [3/6]
#
#  RANDOM FOREST: EXPERIMENT-3 Grouping: REGION, Features: ['height', 'nisar_value_hhhh', 'nisar_value_hvhv'].
# Test R²     : -0.1608
# Test RMSE   : 859.74 kg
# Train R² (log scale): 0.4473
# Train R² (orig scale): 0.0331
# Train RMSE  : 510.90 kg
# Num Features: 3
#
#  Cross-validation ---
# CV R² mean: -2.9476
# CV R² std : 1.5923
# CV scores : [-3.2   -3.491 -2.987 -4.977 -0.084]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.9313
# Grouped CV R² std : 0.8848
# Grouped CV scores : [-1.648 -0.208 -0.448 -0.206 -0.182 -2.686 -1.141]
#
# Top 10 feature importances:
#   nisar_value_hvhv                              0.3702  ==================
#   nisar_value_hhhh                              0.3308  ================
#   height                                        0.2990  ==============
# ============================================================
# EXPERIMENT EVALUATION: EXPERIMENT-3 Grouping: REGION, Features: ['height', 'nisar_value_hhhh', 'nisar_value_hvhv'].
# ============================================================
#
# Test set:
#   R²   : -0.161
#   RMSE : 859.74 kg
#
# Regular CrossValidation:
#   Mean   : -2.948
#   Std    : 1.592
#   Scores : [-3.2   -3.491 -2.987 -4.977 -0.084]
#
#   ❌ Test R² is negative (-0.161)
#   ❌ CV mean is negative (-2.948)
#
# Grouped CrossValidation:
#   ElSalvador           :  -1.648  ❌ negative — cause unknown
#   Brazil-Caetano       :  -0.208  ❌ negative — cause unknown
#   Brazil-Mangue        :  -0.448  ❌ negative — cause unknown
#   Brazil-Maruipe       :  -0.206  ❌ negative — cause unknown
#   Brazil-Barreto       :  -0.182  ❌ negative — cause unknown
#   Brazil-Furo_Do_Chato :  -2.686  ❌ negative — cause unknown
#   Brazil-FuroGrande    :  -1.141  ❌ negative — cause unknown
#
#   Mean : -0.931
#   Std  : 0.885
#
#   ❌ Grouped CV mean is negative (-0.931)
#   ❌ Unexplained negative folds: ['ElSalvador', 'Brazil-Caetano', 'Brazil-Mangue', 'Brazil-Maruipe', 'Brazil-Barreto', 'Brazil-Furo_Do_Chato', 'Brazil-FuroGrande']
#   ✅ High-AGB sites generalize correctly
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ NOT ACCEPTABLE
#
# [4/6]
#
#  RANDOM FOREST: EXPERIMENT-4 Grouping: REGION, Features: ['nisar_value_hhhh', 'nisar_value_hvhv'].
# Test R²     : -0.1808
# Test RMSE   : 867.10 kg
# Train R² (log scale): 0.4441
# Train R² (orig scale): 0.0301
# Train RMSE  : 511.70 kg
# Num Features: 2
#
#  Cross-validation ---
# CV R² mean: -3.1362
# CV R² std : 1.7060
# CV scores : [-3.201 -3.579 -3.508 -5.326 -0.067]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.0573
# Grouped CV R² std : 0.5600
# Grouped CV scores : [-1.604 -0.46  -1.702 -0.217 -0.627 -1.348 -1.442]
#
# Top 10 feature importances:
#   nisar_value_hvhv                              0.5155  =========================
#   nisar_value_hhhh                              0.4845  ========================
# ============================================================
# EXPERIMENT EVALUATION: EXPERIMENT-4 Grouping: REGION, Features: ['nisar_value_hhhh', 'nisar_value_hvhv'].
# ============================================================
#
# Test set:
#   R²   : -0.181
#   RMSE : 867.10 kg
#
# Regular CrossValidation:
#   Mean   : -3.136
#   Std    : 1.706
#   Scores : [-3.201 -3.579 -3.508 -5.326 -0.067]
#
#   ❌ Test R² is negative (-0.181)
#   ❌ CV mean is negative (-3.136)
#
# Grouped CrossValidation:
#   ElSalvador           :  -1.604  ❌ negative — cause unknown
#   Brazil-Caetano       :  -0.460  ❌ negative — cause unknown
#   Brazil-Mangue        :  -1.702  ❌ negative — cause unknown
#   Brazil-Maruipe       :  -0.217  ❌ negative — cause unknown
#   Brazil-Barreto       :  -0.627  ❌ negative — cause unknown
#   Brazil-Furo_Do_Chato :  -1.348  ❌ negative — cause unknown
#   Brazil-FuroGrande    :  -1.442  ❌ negative — cause unknown
#
#   Mean : -1.057
#   Std  : 0.560
#
#   ❌ Grouped CV mean is negative (-1.057)
#   ❌ Unexplained negative folds: ['ElSalvador', 'Brazil-Caetano', 'Brazil-Mangue', 'Brazil-Maruipe', 'Brazil-Barreto', 'Brazil-Furo_Do_Chato', 'Brazil-FuroGrande']
#   ✅ High-AGB sites generalize correctly
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ NOT ACCEPTABLE
#
# [5/6]
#
#  RANDOM FOREST: EXPERIMENT-5 Grouping: REGION, Features: ['nisar_value_hhhh', 'nisar_value_hvhv', 'plot_id', 'species'].
# Test R²     : -0.1258
# Test RMSE   : 846.67 kg
# Train R² (log scale): 0.5678
# Train R² (orig scale): 0.0440
# Train RMSE  : 508.02 kg
# Num Features: 149
#
#  Cross-validation ---
# CV R² mean: -1.6709
# CV R² std : 1.1536
# CV scores : [-1.340e+00 -1.349e+00 -2.140e+00 -3.524e+00 -1.000e-03]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.7123
# Grouped CV R² std : 0.4954
# Grouped CV scores : [-1.624 -0.589 -0.168 -0.372 -0.202 -1.106 -0.924]
#
# Top 10 feature importances:
#   nisar_value_hvhv                              0.1831  =========
#   nisar_value_hhhh                              0.1629  ========
#   plot_id_El_Cañón_del_Bagre_17_6               0.0631  ===
#   species_Rhizophora mangle                     0.0399  =
#   plot_id_San_Sebastián_El_Chingo_16_4          0.0357  =
#   species_racemosa                              0.0335  =
#   plot_id_El_Cañón_del_Bagre_17_1               0.0329  =
#   plot_id_El_Plan_de_la_Ceiba_8_4               0.0283  =
#   plot_id_FUR_Furo do Chato                     0.0268  =
#   plot_id_El_Llorón_7_5                         0.0241  =
# ============================================================
# EXPERIMENT EVALUATION: EXPERIMENT-5 Grouping: REGION, Features: ['nisar_value_hhhh', 'nisar_value_hvhv', 'plot_id', 'species'].
# ============================================================
#
# Test set:
#   R²   : -0.126
#   RMSE : 846.67 kg
#
# Regular CrossValidation:
#   Mean   : -1.671
#   Std    : 1.154
#   Scores : [-1.340e+00 -1.349e+00 -2.140e+00 -3.524e+00 -1.000e-03]
#
#   ❌ Test R² is negative (-0.126)
#   ❌ CV mean is negative (-1.671)
#
# Grouped CrossValidation:
#   ElSalvador           :  -1.624  ❌ negative — cause unknown
#   Brazil-Caetano       :  -0.589  ❌ negative — cause unknown
#   Brazil-Mangue        :  -0.168  ❌ negative — cause unknown
#   Brazil-Maruipe       :  -0.372  ❌ negative — cause unknown
#   Brazil-Barreto       :  -0.202  ❌ negative — cause unknown
#   Brazil-Furo_Do_Chato :  -1.106  ❌ negative — cause unknown
#   Brazil-FuroGrande    :  -0.924  ❌ negative — cause unknown
#
#   Mean : -0.712
#   Std  : 0.495
#
#   ❌ Grouped CV mean is negative (-0.712)
#   ❌ Unexplained negative folds: ['ElSalvador', 'Brazil-Caetano', 'Brazil-Mangue', 'Brazil-Maruipe', 'Brazil-Barreto', 'Brazil-Furo_Do_Chato', 'Brazil-FuroGrande']
#   ✅ High-AGB sites generalize correctly
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ NOT ACCEPTABLE
#
# [6/6]
#
#  RANDOM FOREST: EXPERIMENT-6 Grouping: REGION, Features: ['nisar_value_hhhh', 'nisar_value_hvhv', 'height', 'plot_id', 'species'].
# Test R²     : -0.1200
# Test RMSE   : 844.49 kg
# Train R² (log scale): 0.5724
# Train R² (orig scale): 0.0467
# Train RMSE  : 507.29 kg
# Num Features: 150
#
#  Cross-validation ---
# CV R² mean: -1.7808
# CV R² std : 1.2035
# CV scores : [-1.561 -1.534 -2.048 -3.757 -0.004]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.7161
# Grouped CV R² std : 0.5949
# Grouped CV scores : [-1.792 -0.737 -0.037 -0.23  -0.168 -1.28  -0.768]
#
# Top 10 feature importances:
#   nisar_value_hvhv                              0.1605  ========
#   nisar_value_hhhh                              0.1262  ======
#   height                                        0.1181  =====
#   plot_id_El_Cañón_del_Bagre_17_6               0.0562  ==
#   species_Rhizophora mangle                     0.0352  =
#   plot_id_El_Cañón_del_Bagre_17_1               0.0326  =
#   species_racemosa                              0.0307  =
#   plot_id_El_Plan_de_la_Ceiba_8_4               0.0301  =
#   plot_id_San_Sebastián_El_Chingo_16_4          0.0297  =
#   plot_id_FUR_Furo do Chato                     0.0256  =
# ============================================================
# EXPERIMENT EVALUATION: EXPERIMENT-6 Grouping: REGION, Features: ['nisar_value_hhhh', 'nisar_value_hvhv', 'height', 'plot_id', 'species'].
# ============================================================
#
# Test set:
#   R²   : -0.120
#   RMSE : 844.49 kg
#
# Regular CrossValidation:
#   Mean   : -1.781
#   Std    : 1.204
#   Scores : [-1.561 -1.534 -2.048 -3.757 -0.004]
#
#   ❌ Test R² is negative (-0.120)
#   ❌ CV mean is negative (-1.781)
#
# Grouped CrossValidation:
#   ElSalvador           :  -1.792  ❌ negative — cause unknown
#   Brazil-Caetano       :  -0.737  ❌ negative — cause unknown
#   Brazil-Mangue        :  -0.037  ❌ negative — cause unknown
#   Brazil-Maruipe       :  -0.230  ❌ negative — cause unknown
#   Brazil-Barreto       :  -0.168  ❌ negative — cause unknown
#   Brazil-Furo_Do_Chato :  -1.280  ❌ negative — cause unknown
#   Brazil-FuroGrande    :  -0.768  ❌ negative — cause unknown
#
#   Mean : -0.716
#   Std  : 0.595
#
#   ❌ Grouped CV mean is negative (-0.716)
#   ❌ Unexplained negative folds: ['ElSalvador', 'Brazil-Caetano', 'Brazil-Mangue', 'Brazil-Maruipe', 'Brazil-Barreto', 'Brazil-Furo_Do_Chato', 'Brazil-FuroGrande']
#   ✅ High-AGB sites generalize correctly
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ NOT ACCEPTABLE
#
# Completed: 6/6 experiments
