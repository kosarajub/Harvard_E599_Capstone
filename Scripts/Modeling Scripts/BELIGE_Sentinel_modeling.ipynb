# %%
# Import Packages
import os
import re
import sys
import time
import copy
from pathlib import Path
from IPython.display import display

import numpy as np
import pandas as pd

from itertools import product

#%load_ext autoreload
#%reload_ext autoreload
#%autoreload 2
#from model_functions import *

# %run Model_functions.ipynb
# Out:
# chmod: /Users/kosaraju_b/.local/share/jupyter/history.sqlite: No such file or directory

# %%
is_stratified_g = False

# %% [markdown]
# # GENERAL TEST FEATURES

# %%
global_experiment_list = {}

# %%
struct_features = ['height']

sentinel_bands  = ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2']
sentinel_indices = ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']

top_spectral_1  = ['height', 'EVI', 'NIR', 'NBR', 'SWIR1']
top_spectral_2  = ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1']

redband_1       = ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2']
redband_2       = ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2']

ineraction_terms = ['height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']

useful_categorical = []# ['plot_id']

target = 'plant_AGB_kg'

gen_features_list = [struct_features,
                     struct_features + ineraction_terms,
                 
                     sentinel_bands,
                     sentinel_bands + ineraction_terms,
                 
                     sentinel_indices,
                     sentinel_indices + ineraction_terms,
                 
                     sentinel_bands + sentinel_indices,
                     sentinel_bands + sentinel_indices + ineraction_terms,
                 
                     struct_features + sentinel_bands + sentinel_indices,
                     struct_features + sentinel_bands + sentinel_indices + ineraction_terms,

                     top_spectral_1,
                     top_spectral_1 + ineraction_terms,
                 
                     top_spectral_2,
                     top_spectral_2 + ineraction_terms,
                 
                     redband_1,
                     redband_1 + ineraction_terms,
                 
                     redband_2,
                     redband_2 + ineraction_terms
                    ]

model_list = ["regular", "ridge", "lasso", "elasticnet"]

test_cv = 5
#test_cv = RepeatedKFold(n_splits=5, n_repeats=10, random_state=42)

# %% [markdown]
# # DOWNLOAD SENTINEL-AGB DATA

# %%
SENTINEL_DATA_CSV        = "../../DATA/AGB_DATA/Merged_Data/Sentinel_AGB/AGB_SENTINEL_CANOPY.csv"
#SENINEL_MISSING_DATA_CSV = "../../DATA/AGB_DATA/Merged_Data/Sentinel_AGB/AGB_VAL_EO_SENTINEL.csv"

sentinel_df = pd.read_csv(SENTINEL_DATA_CSV)
print(sentinel_df.shape)
sentinel_df.columns
# Out:
# (8774, 34)
# Index(['dataset', 'plot_id', 'start_date', 'end_date', 'latitude', 'longitude',
#        'diameter', 'height', 'species', 'plant_AGB_kg', 'capture_start',
#        'capture_end', 'sentinel_time', 'Blue', 'Green', 'Red', 'RE1', 'RE2',
#        'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1',
#        'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'cloud_threshold_used',
#        'simard_height_m', 'tandemx_height_m'],
#       dtype='object')

# %%
assert len(sentinel_df["simard_height_m"].head())
assert len(sentinel_df["tandemx_height_m"].head())

# %%
sentinel_df['dataset'].unique()
# Out:
# array(['ElSalvador', 'Panama-Chirqui_2', 'CostaRica-Nicoya',
#        'CostaRica-Sierpe', 'Belige', 'Panama-Chirqui_1',
#        'Honduras-Blanca', 'Brazil-Mangue', 'Brazil-Furo_Do_Chato',
#        'Brazil-Manguezal', 'Brazil-Maruipe', 'Brazil-AcarauBoca',
#        'Brazil-BocaGrande', 'Brazil-Barreto', 'Brazil-Salinas',
#        'Brazil-FuroGrande', 'Brazil-Caetano'], dtype=object)

# %% [markdown]
# ### Select features

# %%
non_feature_cols = [
    'plant_AGB_kg',        # Target variable
    'dataset',             # metadata
    'sentinel_time',       # metadata
    'start_date',          # metadata
    'end_date',            # metadata
    'capture_start',       # metadata
    'capture_end',         # metadata
    'latitude',            # coordinate
    'longitude',           # coordinate
    'diameter',            # Allometric
    'height',               # Allometric
    'cloud_threshold_used',
    'start_date'
]

useful_categorical = ['plot_id', 'species']

target = 'plant_AGB_kg'
feature_cols = [c for c in sentinel_df.columns if c not in non_feature_cols]

X_all = sentinel_df[feature_cols]
# Select TANDEMX
X_all = X_all.rename({'tandemx_height_m': 'height'}, axis=1)
X_all = X_all.drop(columns=['simard_height_m'])
y_all = sentinel_df[target]

# %%
X_all.columns
# Out:
# Index(['plot_id', 'species', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3',
#        'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1',
#        'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height'],
#       dtype='object')

# %% [markdown]
# ## DATA PREPROCESSING

# %% [markdown]
# ### Interaction terms

# %%
# height × EVI — the most promising. Height captures structural biomass, EVI captures canopy greenness.
# Their product approximates a "green volume" index and may capture the AGB signal better than either alone.
X_all['height_x_EVI'] = X_all['height'] * X_all['EVI']

#height × NIR — NIR reflectance is strongly tied to canopy density.
# Combined with height it approximates canopy biomass density.
X_all['height_x_NIR'] = X_all['height'] * X_all['NIR']

#height × NDRE1 — red-edge is sensitive to chlorophyll content.
# For mangroves, chlorophyll × height is a reasonable proxy for woody biomass.
X_all['height_x_NDRE1'] = X_all['height'] * X_all['NDRE1']

# %%
null_rows   = X_all[X_all.isnull().any(axis=1)]
total_nulls = X_all.isnull().sum().sum()

print(f"Total NULL count           : {total_nulls}")
print(f"Rows with at least one NULL: {len(null_rows)}")
print(f"Total rows                 : {len(sentinel_df)}")
print(f"Percentage                 : {len(null_rows)/len(sentinel_df)*100:.1f}%")

# NULL count per column for only the affected rows
null_col_counts = null_rows.isnull().sum().sort_values(ascending=False)
print("\nNULL count per column in affected rows:")
print(null_col_counts[null_col_counts > 0])
# Out:
# Total NULL count           : 0
# Rows with at least one NULL: 0
# Total rows                 : 8774
# Percentage                 : 0.0%
#
# NULL count per column in affected rows:
# Series([], dtype: int64)

# %%
assert not total_nulls
#sentinel_df = handle_null_data(sentinel_df)
#X = X.dropna()
#print(X.shape)
#X.columns

# %% [markdown]
# ### Find correlations

# %%
numerical_cols = get_numerical_cols(X_all)
target_corr = plot_correlation_matrix(X_all[numerical_cols],
                                      y_all,
                                      top_n=20)
print(target_corr)
# Out:
# height            0.270332
# height_x_NIR      0.247795
# height_x_EVI      0.245307
# height_x_NDRE1    0.244525
# CLOUD_COVERAGE    0.148244
# CIrededge         0.075032
# RE1               0.051166
# RE3               0.034549
# NIR               0.029325
# NDVI              0.026838
# Blue              0.026532
# Red               0.025423
# RE2               0.023474
# Green             0.021944
# NDRE3             0.020353
# EVI               0.018145
# MNDWI             0.016781
# NBR               0.012546
# SWIR1             0.007646
# SWIR2             0.005075
# Name: plant_AGB_kg, dtype: float64

# %% [markdown]
# **COMMENTS:**
# Columns with a Pearson correlation coefficient (r) between -0.1 and 0.1 with the target variable are generally considered to have a negligible or very weak relationship.

# %% [markdown]
# ### Remove Low Variance Features (cols)

# %% [raw]
# X = remove_low_variance_cols(X,
#                              exclude_cols=[],
#                              threshold=0.01,
#                              debug=True,
#                              exclude_categorical=True)
# assert X is not None
#
# X.columns

# %% [markdown]
# #### Is variance threshold valid for sentinel-2 data?

# %% [markdown]
# - Sentinel-2 surface reflectance values are typically in the range 0.0 to 0.3.
#  - Their absolute variance is naturally small — not because they carry no information but because their scale is small.
#  - A feature with values ranging from 0.05 to 0.25 has variance of ~0.003, which falls below the 0.01 threshold, but the variation within that range is meaningful for AGB prediction.
#  - VarianceThreshold is designed for features with near-identical values across all rows — like a binary column that is always 0.
#  - It is not appropriate for bounded continuous features like reflectance values.

# %% [markdown]
# ### Remove Features With Weak Correlation to Target

# %% [raw]
# corr_threshold = 0.1
# X = remove_uncorrelated_numerical_cols(X, y,
#                                        threshold=corr_threshold,
#                                        exclude_cols=[])
# assert X is not None
#
# X.columns

# %% [markdown]
# #### Why Pearson correlation is unreliable here?
#
# Pearson correlation measures linear relationship between a feature and the target.
#
# The above correlation removal process is based on the correlations computed against the original y. But we are going log-transform the target for modeling.
#
# A feature can have a strong non-linear relationship with AGB that shows up clearly after log transformation but appears weak in linear correlation against raw AGB.
#
# The experiments (Belige-data-analysis.ipynb) already proved these features are useful.

# %% [raw]
# X = remove_uncorrelated_categorical_cols(X, y)
# assert X is not None
#
# X.columns

# %% [markdown]
# ### Convert categorical variables to one-hot encoding

# %% [raw]
# # Retain the groups/plot_id for splitting the data based on groups.
# #groups = X['plot_id'].copy()
#
# categorical_cols = get_categorical_cols(X)
# X = pd.get_dummies(X, columns=categorical_cols, dtype=int)

# %% [markdown]
# # BELIGE DATASET ONLY

# %%
belige_df = sentinel_df[sentinel_df['dataset'] == 'Belige'].copy()
assert len(belige_df['simard_height_m'].head())
assert len(belige_df['tandemx_height_m'].head())

X_belige = belige_df[feature_cols].copy()

# Select TANDEMX
X_belige = X_belige.rename({'tandemx_height_m': 'height'}, axis=1)
X_belige = X_belige.drop(columns=['simard_height_m'])

# Select SIMARD
#X_belige = X_belige.rename({'simard_height_m': 'height'}, axis=1)
#X_belige = X.drop(columns=['tandemx_height_m'])

y_belige  = belige_df[target]

test_cv = 5

# %%
X_belige.columns
# Out:
# Index(['plot_id', 'species', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3',
#        'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1',
#        'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height'],
#       dtype='object')

# %% [markdown]
# ## Interaction terms

# %%
# height × EVI — the most promising. Height captures structural biomass, EVI captures canopy greenness.
# Their product approximates a "green volume" index and may capture the AGB signal better than either alone.
X_belige['height_x_EVI'] = X_belige['height'] * X_belige['EVI']

#height × NIR — NIR reflectance is strongly tied to canopy density.
# Combined with height it approximates canopy biomass density.
X_belige['height_x_NIR'] = X_belige['height'] * X_belige['NIR']

#height × NDRE1 — red-edge is sensitive to chlorophyll content.
# For mangroves, chlorophyll × height is a reasonable proxy for woody biomass.
X_belige['height_x_NDRE1'] = X_belige['height'] * X_belige['NDRE1']

# %%
X_belige.columns
# Out:
# Index(['plot_id', 'species', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3',
#        'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1',
#        'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height',
#        'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'],
#       dtype='object')

# %% [markdown]
# ## Show correlations

# %%
numerical_cols = get_numerical_cols(X_belige)
target_corr = plot_correlation_matrix(X_belige[numerical_cols],
                                      y_belige,
                                      top_n=20)
print(target_corr)
# Out:
# height_x_NDRE1    0.315565
# height            0.305997
# height_x_EVI      0.285951
# height_x_NIR      0.275702
# CIrededge         0.119717
# EVI               0.119078
# NIR               0.103383
# RE3               0.099264
# NDRE1             0.098902
# RE2               0.076811
# NBR               0.068840
# NDVI              0.066806
# RE1               0.054646
# Red               0.049271
# Blue              0.048902
# MNDWI             0.044189
# SWIR2             0.043206
# NDRE2             0.042639
# NDRE3             0.037197
# Green             0.033607
# Name: plant_AGB_kg, dtype: float64

# %% [markdown]
# ## Create groups

# %%
n_plots = X_belige['plot_id'].nunique()
print(f"Belige : {len(X_belige)} rows, {n_plots} plots")
# Out:
# Belige : 3880 rows, 59 plots

# %%
# Retain the groups/plot_id for splitting the data based on groups.
plot_groups_belige = X_belige['plot_id'].copy()
X_belige = X_belige.drop(columns=['plot_id'])

site_groups_belige = plot_groups_belige.map(lambda x: x.rsplit('_', maxsplit=1)[0])

near_zero_sites_belige, high_agb_sites_belige,\
    near_zero_plots_belige, high_agb_plots_belige = get_low_and_high_agb_plots(y_belige,
                                                                               plot_groups_belige)

grp_belige = GROUP_INFO(near_zero_sites_belige, high_agb_sites_belige,
                        near_zero_plots_belige, high_agb_plots_belige,
                        groups=plot_groups_belige,
                        cv=test_cv)
# Out:
# High-AGB threshold  : 104.49 kg
# Near-zero threshold : 0.004134
#
# Near-zero variance plots:
#   Big Creek_1               : log var = 0.000036
#   Big Creek_4               : log var = 0.000032
#   Frenchman Caye_1          : log var = 0.000753
#   Frenchman Caye_2          : log var = 0.000381
#   Frenchman Caye_3          : log var = 0.000693
#   Frenchman Caye_4          : log var = 0.001306
#   Frenchman Caye_5          : log var = 0.001283
#   Frenchman Caye_6          : log var = 0.000158
#   Shipstern Lagoon_1        : log var = 0.001064
#   Shipstern Lagoon_3        : log var = 0.000232
#   Shipstern Lagoon_4        : log var = 0.000113
#   Shipstern Lagoon_5        : log var = 0.000052
#   Shipstern Lagoon_6        : log var = 0.000135
#
# High-AGB plots:
#   Channel Caye_1            : max AGB = 310.9 kg
#   Channel Caye_2            : max AGB = 206.4 kg
#   Channel Caye_3            : max AGB = 427.2 kg
#   Channel Caye_4            : max AGB = 237.6 kg
#   Channel Caye_5            : max AGB = 170.4 kg
#   Channel Caye_6            : max AGB = 128.6 kg
#   New River_2               : max AGB = 144.2 kg
#   New River_3               : max AGB = 260.8 kg
#
# within-site high-AGB plots
# Big Creek            : within-site high-AGB plots = ['Big Creek_3']
#
# Near-zero sites: ['Big Creek', 'Frenchman Caye', 'Shipstern Lagoon']
# High-AGB sites : ['Channel Caye', 'New River']

# %% [markdown]
# ### BELIGE DATA. LINEAR REGRESSION. NO GROUPS

# %%
# %run Model_functions.ipynb
lin_belige_no_groups = {}

run_experiment(X_belige, y_belige,
               is_groups=False, group_info=grp_belige,
               features_list=gen_features_list,
               experiments=lin_belige_no_groups,
               model_type="linear", is_grid=False,
               is_stratified=is_stratified_g,
               global_experiment_list=global_experiment_list)
# Out:
# chmod: /Users/kosaraju_b/.local/share/jupyter/history.sqlite: No such file or directory
#
# [1/72]
#
#  EXPERIMENT-1 No groups, Features: ['height']., Model: regular, Grouping? No, Grid? No, ALGO: LINEAR REGRESSION:
# Test R²     : 0.0131
# Test RMSE   : 16.75 kg
# Train R² (log scale): 0.2200
# Train R² (orig scale): 0.0166
# Train RMSE  : 16.59 kg
# Num rows    : 3104
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: 0.2180
# CV R² std : 0.0168
# CV scores : [0.23  0.221 0.186 0.233 0.221]
# ============================================================
#  EVALUATION: EXPERIMENT-1 No groups, Features: ['height']., Model: regular, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.013
#   RMSE : 16.75 kg
#
#  ✅ Test R² is positive (0.013)
#
# Regular CrossValidation:
#   Mean   : 0.218
#   Std    : 0.017
#   Scores : [0.23  0.221 0.186 0.233 0.221]
#  ✅ CV mean is positive (0.218)
#   ✅ Train/test R² gap acceptable (gap: 0.003)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [2/72]
#
#  EXPERIMENT-2 No groups, Features: ['height']., Model: ridge, Grouping? No, Grid? No, ALGO: RIDGE REGRESSION:
# Test R²     : 0.0166
# Test RMSE   : 16.72 kg
# Train R² (log scale): 0.2200
# Train R² (orig scale): 0.0181
# Train RMSE  : 16.58 kg
# Num rows    : 3104
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: 0.2180
# CV R² std : 0.0167
# CV scores : [0.229 0.221 0.186 0.233 0.221]
# ============================================================
#  EVALUATION: EXPERIMENT-2 No groups, Features: ['height']., Model: ridge, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.017
#   RMSE : 16.72 kg
#
#  ✅ Test R² is positive (0.017)
#
# Regular CrossValidation:
#   Mean   : 0.218
#   Std    : 0.017
#   Scores : [0.229 0.221 0.186 0.233 0.221]
#  ✅ CV mean is positive (0.218)
#   ✅ Train/test R² gap acceptable (gap: 0.002)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [3/72]
#
#  EXPERIMENT-3 No groups, Features: ['height']., Model: lasso, Grouping? No, Grid? No, ALGO: LASSO REGRESSION:
# Test R²     : 0.0153
# Test RMSE   : 16.73 kg
# Train R² (log scale): 0.2200
# Train R² (orig scale): 0.0175
# Train RMSE  : 16.59 kg
# Num rows    : 3104
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: 0.2180
# CV R² std : 0.0167
# CV scores : [0.23  0.221 0.186 0.233 0.221]
# ============================================================
#  EVALUATION: EXPERIMENT-3 No groups, Features: ['height']., Model: lasso, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.015
#   RMSE : 16.73 kg
#
#  ✅ Test R² is positive (0.015)
#
# Regular CrossValidation:
#   Mean   : 0.218
#   Std    : 0.017
#   Scores : [0.23  0.221 0.186 0.233 0.221]
#  ✅ CV mean is positive (0.218)
#   ✅ Train/test R² gap acceptable (gap: 0.002)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [4/72]
#
#  EXPERIMENT-4 No groups, Features: ['height']., Model: elasticnet, Grouping? No, Grid? No, ALGO: ELASTICNET REGRESSION:
# Test R²     : 0.0151
# Test RMSE   : 16.73 kg
# Train R² (log scale): 0.2200
# Train R² (orig scale): 0.0174
# Train RMSE  : 16.59 kg
# Num rows    : 3104
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: 0.2180
# CV R² std : 0.0166
# CV scores : [0.23  0.221 0.186 0.233 0.221]
# ============================================================
#  EVALUATION: EXPERIMENT-4 No groups, Features: ['height']., Model: elasticnet, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.015
#   RMSE : 16.73 kg
#
#  ✅ Test R² is positive (0.015)
#
# Regular CrossValidation:
#   Mean   : 0.218
#   Std    : 0.017
#   Scores : [0.23  0.221 0.186 0.233 0.221]
#  ✅ CV mean is positive (0.218)
#   ✅ Train/test R² gap acceptable (gap: 0.002)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [5/72]
#
#  EXPERIMENT-5 No groups, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: regular, Grouping? No, Grid? No, ALGO: LINEAR REGRESSION:
# Test R²     : 0.0873
# Test RMSE   : 16.11 kg
# Train R² (log scale): 0.2628
# Train R² (orig scale): 0.0510
# Train RMSE  : 16.30 kg
# Num rows    : 3104
# Num Features: 4
#
#  Cross-validation ---
# CV R² mean: 0.2583
# CV R² std : 0.0209
# CV scores : [0.261 0.26  0.22  0.284 0.266]
# ============================================================
#  EVALUATION: EXPERIMENT-5 No groups, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: regular, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.087
#   RMSE : 16.11 kg
#
#  ✅ Test R² is positive (0.087)
#
# Regular CrossValidation:
#   Mean   : 0.258
#   Std    : 0.021
#   Scores : [0.261 0.26  0.22  0.284 0.266]
#  ✅ CV mean is positive (0.258)
#   ✅ Train/test R² gap acceptable (gap: -0.036)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [6/72]
#
#  EXPERIMENT-6 No groups, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: ridge, Grouping? No, Grid? No, ALGO: RIDGE REGRESSION:
# Test R²     : 0.0860
# Test RMSE   : 16.12 kg
# Train R² (log scale): 0.2628
# Train R² (orig scale): 0.0506
# Train RMSE  : 16.31 kg
# Num rows    : 3104
# Num Features: 4
#
#  Cross-validation ---
# CV R² mean: 0.2583
# CV R² std : 0.0209
# CV scores : [0.261 0.26  0.22  0.284 0.265]
# ============================================================
#  EVALUATION: EXPERIMENT-6 No groups, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: ridge, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.086
#   RMSE : 16.12 kg
#
#  ✅ Test R² is positive (0.086)
#
# Regular CrossValidation:
#   Mean   : 0.258
#   Std    : 0.021
#   Scores : [0.261 0.26  0.22  0.284 0.265]
#  ✅ CV mean is positive (0.258)
#   ✅ Train/test R² gap acceptable (gap: -0.035)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [7/72]
#
#  EXPERIMENT-7 No groups, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: lasso, Grouping? No, Grid? No, ALGO: LASSO REGRESSION:
# Test R²     : 0.0632
# Test RMSE   : 16.32 kg
# Train R² (log scale): 0.2592
# Train R² (orig scale): 0.0415
# Train RMSE  : 16.38 kg
# Num rows    : 3104
# Num Features: 4
#
#  Cross-validation ---
# CV R² mean: 0.2553
# CV R² std : 0.0240
# CV scores : [0.261 0.264 0.21  0.281 0.261]
# ============================================================
#  EVALUATION: EXPERIMENT-7 No groups, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: lasso, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.063
#   RMSE : 16.32 kg
#
#  ✅ Test R² is positive (0.063)
#
# Regular CrossValidation:
#   Mean   : 0.255
#   Std    : 0.024
#   Scores : [0.261 0.264 0.21  0.281 0.261]
#  ✅ CV mean is positive (0.255)
#   ✅ Train/test R² gap acceptable (gap: -0.022)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [8/72]
#
#  EXPERIMENT-8 No groups, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: elasticnet, Grouping? No, Grid? No, ALGO: ELASTICNET REGRESSION:
# Test R²     : 0.0649
# Test RMSE   : 16.30 kg
# Train R² (log scale): 0.2589
# Train R² (orig scale): 0.0422
# Train RMSE  : 16.38 kg
# Num rows    : 3104
# Num Features: 4
#
#  Cross-validation ---
# CV R² mean: 0.2549
# CV R² std : 0.0241
# CV scores : [0.261 0.264 0.209 0.281 0.261]
# ============================================================
#  EVALUATION: EXPERIMENT-8 No groups, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: elasticnet, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.065
#   RMSE : 16.30 kg
#
#  ✅ Test R² is positive (0.065)
#
# Regular CrossValidation:
#   Mean   : 0.255
#   Std    : 0.024
#   Scores : [0.261 0.264 0.209 0.281 0.261]
#  ✅ CV mean is positive (0.255)
#   ✅ Train/test R² gap acceptable (gap: -0.023)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [9/72]
#
#  EXPERIMENT-9 No groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2']., Model: regular, Grouping? No, Grid? No, ALGO: LINEAR REGRESSION:
# Test R²     : 0.0299
# Test RMSE   : 16.61 kg
# Train R² (log scale): 0.2713
# Train R² (orig scale): 0.0210
# Train RMSE  : 16.56 kg
# Num rows    : 3104
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: 0.2647
# CV R² std : 0.0334
# CV scores : [0.283 0.276 0.198 0.278 0.287]
# ============================================================
#  EVALUATION: EXPERIMENT-9 No groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2']., Model: regular, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.030
#   RMSE : 16.61 kg
#
#  ✅ Test R² is positive (0.030)
#
# Regular CrossValidation:
#   Mean   : 0.265
#   Std    : 0.033
#   Scores : [0.283 0.276 0.198 0.278 0.287]
#  ✅ CV mean is positive (0.265)
#   ✅ Train/test R² gap acceptable (gap: -0.009)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [10/72]
#
#  EXPERIMENT-10 No groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2']., Model: ridge, Grouping? No, Grid? No, ALGO: RIDGE REGRESSION:
# Test R²     : 0.0295
# Test RMSE   : 16.61 kg
# Train R² (log scale): 0.2713
# Train R² (orig scale): 0.0207
# Train RMSE  : 16.56 kg
# Num rows    : 3104
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: 0.2645
# CV R² std : 0.0332
# CV scores : [0.283 0.276 0.198 0.278 0.287]
# ============================================================
#  EVALUATION: EXPERIMENT-10 No groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2']., Model: ridge, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.029
#   RMSE : 16.61 kg
#
#  ✅ Test R² is positive (0.029)
#
# Regular CrossValidation:
#   Mean   : 0.265
#   Std    : 0.033
#   Scores : [0.283 0.276 0.198 0.278 0.287]
#  ✅ CV mean is positive (0.265)
#   ✅ Train/test R² gap acceptable (gap: -0.009)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [11/72]
#
#  EXPERIMENT-11 No groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2']., Model: lasso, Grouping? No, Grid? No, ALGO: LASSO REGRESSION:
# Test R²     : 0.0214
# Test RMSE   : 16.68 kg
# Train R² (log scale): 0.2688
# Train R² (orig scale): 0.0146
# Train RMSE  : 16.61 kg
# Num rows    : 3104
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: 0.2626
# CV R² std : 0.0312
# CV scores : [0.277 0.278 0.2   0.277 0.281]
# ============================================================
#  EVALUATION: EXPERIMENT-11 No groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2']., Model: lasso, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.021
#   RMSE : 16.68 kg
#
#  ✅ Test R² is positive (0.021)
#
# Regular CrossValidation:
#   Mean   : 0.263
#   Std    : 0.031
#   Scores : [0.277 0.278 0.2   0.277 0.281]
#  ✅ CV mean is positive (0.263)
#   ✅ Train/test R² gap acceptable (gap: -0.007)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [12/72]
#
#  EXPERIMENT-12 No groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2']., Model: elasticnet, Grouping? No, Grid? No, ALGO: ELASTICNET REGRESSION:
# Test R²     : 0.0215
# Test RMSE   : 16.68 kg
# Train R² (log scale): 0.2683
# Train R² (orig scale): 0.0147
# Train RMSE  : 16.61 kg
# Num rows    : 3104
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: 0.2621
# CV R² std : 0.0305
# CV scores : [0.276 0.277 0.201 0.277 0.28 ]
# ============================================================
#  EVALUATION: EXPERIMENT-12 No groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2']., Model: elasticnet, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.022
#   RMSE : 16.68 kg
#
#  ✅ Test R² is positive (0.022)
#
# Regular CrossValidation:
#   Mean   : 0.262
#   Std    : 0.030
#   Scores : [0.276 0.277 0.201 0.277 0.28 ]
#  ✅ CV mean is positive (0.262)
#   ✅ Train/test R² gap acceptable (gap: -0.007)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [13/72]
#
#  EXPERIMENT-13 No groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: regular, Grouping? No, Grid? No, ALGO: LINEAR REGRESSION:
# Test R²     : 0.0688
# Test RMSE   : 16.27 kg
# Train R² (log scale): 0.3009
# Train R² (orig scale): 0.0525
# Train RMSE  : 16.29 kg
# Num rows    : 3104
# Num Features: 12
#
#  Cross-validation ---
# CV R² mean: 0.2932
# CV R² std : 0.0338
# CV scores : [0.308 0.299 0.227 0.32  0.313]
# ============================================================
#  EVALUATION: EXPERIMENT-13 No groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: regular, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.069
#   RMSE : 16.27 kg
#
#  ✅ Test R² is positive (0.069)
#
# Regular CrossValidation:
#   Mean   : 0.293
#   Std    : 0.034
#   Scores : [0.308 0.299 0.227 0.32  0.313]
#  ✅ CV mean is positive (0.293)
#   ✅ Train/test R² gap acceptable (gap: -0.016)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [14/72]
#
#  EXPERIMENT-14 No groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: ridge, Grouping? No, Grid? No, ALGO: RIDGE REGRESSION:
# Test R²     : 0.0697
# Test RMSE   : 16.26 kg
# Train R² (log scale): 0.3008
# Train R² (orig scale): 0.0526
# Train RMSE  : 16.29 kg
# Num rows    : 3104
# Num Features: 12
#
#  Cross-validation ---
# CV R² mean: 0.2933
# CV R² std : 0.0333
# CV scores : [0.307 0.299 0.228 0.32  0.313]
# ============================================================
#  EVALUATION: EXPERIMENT-14 No groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: ridge, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.070
#   RMSE : 16.26 kg
#
#  ✅ Test R² is positive (0.070)
#
# Regular CrossValidation:
#   Mean   : 0.293
#   Std    : 0.033
#   Scores : [0.307 0.299 0.228 0.32  0.313]
#  ✅ CV mean is positive (0.293)
#   ✅ Train/test R² gap acceptable (gap: -0.017)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [15/72]
#
#  EXPERIMENT-15 No groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: lasso, Grouping? No, Grid? No, ALGO: LASSO REGRESSION:
# Test R²     : 0.0797
# Test RMSE   : 16.18 kg
# Train R² (log scale): 0.2968
# Train R² (orig scale): 0.0527
# Train RMSE  : 16.29 kg
# Num rows    : 3104
# Num Features: 12
#
#  Cross-validation ---
# CV R² mean: 0.2906
# CV R² std : 0.0301
# CV scores : [0.297 0.297 0.232 0.317 0.309]
# ============================================================
#  EVALUATION: EXPERIMENT-15 No groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: lasso, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.080
#   RMSE : 16.18 kg
#
#  ✅ Test R² is positive (0.080)
#
# Regular CrossValidation:
#   Mean   : 0.291
#   Std    : 0.030
#   Scores : [0.297 0.297 0.232 0.317 0.309]
#  ✅ CV mean is positive (0.291)
#   ✅ Train/test R² gap acceptable (gap: -0.027)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [16/72]
#
#  EXPERIMENT-16 No groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: elasticnet, Grouping? No, Grid? No, ALGO: ELASTICNET REGRESSION:
# Test R²     : 0.0798
# Test RMSE   : 16.17 kg
# Train R² (log scale): 0.2967
# Train R² (orig scale): 0.0528
# Train RMSE  : 16.29 kg
# Num rows    : 3104
# Num Features: 12
#
#  Cross-validation ---
# CV R² mean: 0.2903
# CV R² std : 0.0301
# CV scores : [0.297 0.297 0.232 0.318 0.308]
# ============================================================
#  EVALUATION: EXPERIMENT-16 No groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: elasticnet, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.080
#   RMSE : 16.17 kg
#
#  ✅ Test R² is positive (0.080)
#
# Regular CrossValidation:
#   Mean   : 0.290
#   Std    : 0.030
#   Scores : [0.297 0.297 0.232 0.318 0.308]
#  ✅ CV mean is positive (0.290)
#   ✅ Train/test R² gap acceptable (gap: -0.027)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [17/72]
#
#  EXPERIMENT-17 No groups, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: regular, Grouping? No, Grid? No, ALGO: LINEAR REGRESSION:
# Test R²     : -0.0080
# Test RMSE   : 16.93 kg
# Train R² (log scale): 0.2298
# Train R² (orig scale): -0.0077
# Train RMSE  : 16.80 kg
# Num rows    : 3104
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: 0.2257
# CV R² std : 0.0411
# CV scores : [0.237 0.257 0.146 0.232 0.256]
# ============================================================
#  EVALUATION: EXPERIMENT-17 No groups, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: regular, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : -0.008
#   RMSE : 16.93 kg
#
#  ❌ Test R² is negative (-0.008)
#
# Regular CrossValidation:
#   Mean   : 0.226
#   Std    : 0.041
#   Scores : [0.237 0.257 0.146 0.232 0.256]
#  ✅ CV mean is positive (0.226)
#   ✅ Train/test R² gap acceptable (gap: 0.000)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {RED_CROSS} REJECTED
#
# [18/72]
#
#  EXPERIMENT-18 No groups, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: ridge, Grouping? No, Grid? No, ALGO: RIDGE REGRESSION:
# Test R²     : -0.0081
# Test RMSE   : 16.93 kg
# Train R² (log scale): 0.2298
# Train R² (orig scale): -0.0078
# Train RMSE  : 16.80 kg
# Num rows    : 3104
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: 0.2258
# CV R² std : 0.0411
# CV scores : [0.237 0.258 0.146 0.232 0.256]
# ============================================================
#  EVALUATION: EXPERIMENT-18 No groups, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: ridge, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : -0.008
#   RMSE : 16.93 kg
#
#  ❌ Test R² is negative (-0.008)
#
# Regular CrossValidation:
#   Mean   : 0.226
#   Std    : 0.041
#   Scores : [0.237 0.258 0.146 0.232 0.256]
#  ✅ CV mean is positive (0.226)
#   ✅ Train/test R² gap acceptable (gap: 0.000)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {RED_CROSS} REJECTED
#
# [19/72]
#
#  EXPERIMENT-19 No groups, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: lasso, Grouping? No, Grid? No, ALGO: LASSO REGRESSION:
# Test R²     : -0.0089
# Test RMSE   : 16.94 kg
# Train R² (log scale): 0.2294
# Train R² (orig scale): -0.0084
# Train RMSE  : 16.80 kg
# Num rows    : 3104
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: 0.2260
# CV R² std : 0.0411
# CV scores : [0.238 0.259 0.146 0.232 0.255]
# ============================================================
#  EVALUATION: EXPERIMENT-19 No groups, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: lasso, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : -0.009
#   RMSE : 16.94 kg
#
#  ❌ Test R² is negative (-0.009)
#
# Regular CrossValidation:
#   Mean   : 0.226
#   Std    : 0.041
#   Scores : [0.238 0.259 0.146 0.232 0.255]
#  ✅ CV mean is positive (0.226)
#   ✅ Train/test R² gap acceptable (gap: 0.001)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {RED_CROSS} REJECTED
#
# [20/72]
#
#  EXPERIMENT-20 No groups, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: elasticnet, Grouping? No, Grid? No, ALGO: ELASTICNET REGRESSION:
# Test R²     : -0.0089
# Test RMSE   : 16.94 kg
# Train R² (log scale): 0.2294
# Train R² (orig scale): -0.0084
# Train RMSE  : 16.80 kg
# Num rows    : 3104
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: 0.2259
# CV R² std : 0.0411
# CV scores : [0.237 0.259 0.146 0.232 0.255]
# ============================================================
#  EVALUATION: EXPERIMENT-20 No groups, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: elasticnet, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : -0.009
#   RMSE : 16.94 kg
#
#  ❌ Test R² is negative (-0.009)
#
# Regular CrossValidation:
#   Mean   : 0.226
#   Std    : 0.041
#   Scores : [0.237 0.259 0.146 0.232 0.255]
#  ✅ CV mean is positive (0.226)
#   ✅ Train/test R² gap acceptable (gap: 0.001)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {RED_CROSS} REJECTED
#
# [21/72]
#
#  EXPERIMENT-21 No groups, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: regular, Grouping? No, Grid? No, ALGO: LINEAR REGRESSION:
# Test R²     : 0.0202
# Test RMSE   : 16.69 kg
# Train R² (log scale): 0.2948
# Train R² (orig scale): 0.0208
# Train RMSE  : 16.56 kg
# Num rows    : 3104
# Num Features: 12
#
#  Cross-validation ---
# CV R² mean: 0.2875
# CV R² std : 0.0334
# CV scores : [0.292 0.285 0.226 0.321 0.314]
# ============================================================
#  EVALUATION: EXPERIMENT-21 No groups, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: regular, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.020
#   RMSE : 16.69 kg
#
#  ✅ Test R² is positive (0.020)
#
# Regular CrossValidation:
#   Mean   : 0.287
#   Std    : 0.033
#   Scores : [0.292 0.285 0.226 0.321 0.314]
#  ✅ CV mean is positive (0.287)
#   ✅ Train/test R² gap acceptable (gap: 0.001)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [22/72]
#
#  EXPERIMENT-22 No groups, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: ridge, Grouping? No, Grid? No, ALGO: RIDGE REGRESSION:
# Test R²     : 0.0239
# Test RMSE   : 16.66 kg
# Train R² (log scale): 0.2948
# Train R² (orig scale): 0.0225
# Train RMSE  : 16.54 kg
# Num rows    : 3104
# Num Features: 12
#
#  Cross-validation ---
# CV R² mean: 0.2869
# CV R² std : 0.0325
# CV scores : [0.292 0.285 0.227 0.32  0.311]
# ============================================================
#  EVALUATION: EXPERIMENT-22 No groups, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: ridge, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.024
#   RMSE : 16.66 kg
#
#  ✅ Test R² is positive (0.024)
#
# Regular CrossValidation:
#   Mean   : 0.287
#   Std    : 0.032
#   Scores : [0.292 0.285 0.227 0.32  0.311]
#  ✅ CV mean is positive (0.287)
#   ✅ Train/test R² gap acceptable (gap: -0.001)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [23/72]
#
#  EXPERIMENT-23 No groups, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: lasso, Grouping? No, Grid? No, ALGO: LASSO REGRESSION:
# Test R²     : 0.0646
# Test RMSE   : 16.31 kg
# Train R² (log scale): 0.2922
# Train R² (orig scale): 0.0403
# Train RMSE  : 16.39 kg
# Num rows    : 3104
# Num Features: 12
#
#  Cross-validation ---
# CV R² mean: 0.2856
# CV R² std : 0.0304
# CV scores : [0.285 0.287 0.23  0.317 0.308]
# ============================================================
#  EVALUATION: EXPERIMENT-23 No groups, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: lasso, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.065
#   RMSE : 16.31 kg
#
#  ✅ Test R² is positive (0.065)
#
# Regular CrossValidation:
#   Mean   : 0.286
#   Std    : 0.030
#   Scores : [0.285 0.287 0.23  0.317 0.308]
#  ✅ CV mean is positive (0.286)
#   ✅ Train/test R² gap acceptable (gap: -0.024)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [24/72]
#
#  EXPERIMENT-24 No groups, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: elasticnet, Grouping? No, Grid? No, ALGO: ELASTICNET REGRESSION:
# Test R²     : 0.0570
# Test RMSE   : 16.37 kg
# Train R² (log scale): 0.2930
# Train R² (orig scale): 0.0373
# Train RMSE  : 16.42 kg
# Num rows    : 3104
# Num Features: 12
#
#  Cross-validation ---
# CV R² mean: 0.2865
# CV R² std : 0.0310
# CV scores : [0.288 0.286 0.23  0.319 0.31 ]
# ============================================================
#  EVALUATION: EXPERIMENT-24 No groups, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: elasticnet, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.057
#   RMSE : 16.37 kg
#
#  ✅ Test R² is positive (0.057)
#
# Regular CrossValidation:
#   Mean   : 0.286
#   Std    : 0.031
#   Scores : [0.288 0.286 0.23  0.319 0.31 ]
#  ✅ CV mean is positive (0.286)
#   ✅ Train/test R² gap acceptable (gap: -0.020)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [25/72]
#
#  EXPERIMENT-25 No groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: regular, Grouping? No, Grid? No, ALGO: LINEAR REGRESSION:
# Test R²     : 0.0441
# Test RMSE   : 16.49 kg
# Train R² (log scale): 0.3123
# Train R² (orig scale): 0.0353
# Train RMSE  : 16.44 kg
# Num rows    : 3104
# Num Features: 18
#
#  Cross-validation ---
# CV R² mean: 0.3016
# CV R² std : 0.0370
# CV scores : [0.339 0.301 0.232 0.317 0.319]
# ============================================================
#  EVALUATION: EXPERIMENT-25 No groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: regular, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.044
#   RMSE : 16.49 kg
#
#  ✅ Test R² is positive (0.044)
#
# Regular CrossValidation:
#   Mean   : 0.302
#   Std    : 0.037
#   Scores : [0.339 0.301 0.232 0.317 0.319]
#  ✅ CV mean is positive (0.302)
#   ✅ Train/test R² gap acceptable (gap: -0.009)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [26/72]
#
#  EXPERIMENT-26 No groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: ridge, Grouping? No, Grid? No, ALGO: RIDGE REGRESSION:
# Test R²     : 0.0441
# Test RMSE   : 16.49 kg
# Train R² (log scale): 0.3123
# Train R² (orig scale): 0.0350
# Train RMSE  : 16.44 kg
# Num rows    : 3104
# Num Features: 18
#
#  Cross-validation ---
# CV R² mean: 0.3017
# CV R² std : 0.0369
# CV scores : [0.338 0.301 0.232 0.318 0.319]
# ============================================================
#  EVALUATION: EXPERIMENT-26 No groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: ridge, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.044
#   RMSE : 16.49 kg
#
#  ✅ Test R² is positive (0.044)
#
# Regular CrossValidation:
#   Mean   : 0.302
#   Std    : 0.037
#   Scores : [0.338 0.301 0.232 0.318 0.319]
#  ✅ CV mean is positive (0.302)
#   ✅ Train/test R² gap acceptable (gap: -0.009)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [27/72]
#
#  EXPERIMENT-27 No groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: lasso, Grouping? No, Grid? No, ALGO: LASSO REGRESSION:
# Test R²     : 0.0389
# Test RMSE   : 16.53 kg
# Train R² (log scale): 0.3076
# Train R² (orig scale): 0.0282
# Train RMSE  : 16.50 kg
# Num rows    : 3104
# Num Features: 18
#
#  Cross-validation ---
# CV R² mean: 0.2980
# CV R² std : 0.0350
# CV scores : [0.326 0.301 0.23  0.317 0.316]
# ============================================================
#  EVALUATION: EXPERIMENT-27 No groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: lasso, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.039
#   RMSE : 16.53 kg
#
#  ✅ Test R² is positive (0.039)
#
# Regular CrossValidation:
#   Mean   : 0.298
#   Std    : 0.035
#   Scores : [0.326 0.301 0.23  0.317 0.316]
#  ✅ CV mean is positive (0.298)
#   ✅ Train/test R² gap acceptable (gap: -0.011)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [28/72]
#
#  EXPERIMENT-28 No groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: elasticnet, Grouping? No, Grid? No, ALGO: ELASTICNET REGRESSION:
# Test R²     : 0.0390
# Test RMSE   : 16.53 kg
# Train R² (log scale): 0.3075
# Train R² (orig scale): 0.0283
# Train RMSE  : 16.50 kg
# Num rows    : 3104
# Num Features: 18
#
#  Cross-validation ---
# CV R² mean: 0.2980
# CV R² std : 0.0350
# CV scores : [0.326 0.3   0.23  0.317 0.316]
# ============================================================
#  EVALUATION: EXPERIMENT-28 No groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: elasticnet, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.039
#   RMSE : 16.53 kg
#
#  ✅ Test R² is positive (0.039)
#
# Regular CrossValidation:
#   Mean   : 0.298
#   Std    : 0.035
#   Scores : [0.326 0.3   0.23  0.317 0.316]
#  ✅ CV mean is positive (0.298)
#   ✅ Train/test R² gap acceptable (gap: -0.011)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [29/72]
#
#  EXPERIMENT-29 No groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: regular, Grouping? No, Grid? No, ALGO: LINEAR REGRESSION:
# Test R²     : 0.1027
# Test RMSE   : 15.97 kg
# Train R² (log scale): 0.3331
# Train R² (orig scale): 0.0771
# Train RMSE  : 16.08 kg
# Num rows    : 3104
# Num Features: 21
#
#  Cross-validation ---
# CV R² mean: 0.3214
# CV R² std : 0.0383
# CV scores : [0.357 0.306 0.253 0.347 0.344]
# ============================================================
#  EVALUATION: EXPERIMENT-29 No groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: regular, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.103
#   RMSE : 15.97 kg
#
#  ✅ Test R² is positive (0.103)
#
# Regular CrossValidation:
#   Mean   : 0.321
#   Std    : 0.038
#   Scores : [0.357 0.306 0.253 0.347 0.344]
#  ✅ CV mean is positive (0.321)
#   ✅ Train/test R² gap acceptable (gap: -0.026)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [30/72]
#
#  EXPERIMENT-30 No groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: ridge, Grouping? No, Grid? No, ALGO: RIDGE REGRESSION:
# Test R²     : 0.1016
# Test RMSE   : 15.98 kg
# Train R² (log scale): 0.3330
# Train R² (orig scale): 0.0755
# Train RMSE  : 16.09 kg
# Num rows    : 3104
# Num Features: 21
#
#  Cross-validation ---
# CV R² mean: 0.3216
# CV R² std : 0.0378
# CV scores : [0.356 0.307 0.254 0.347 0.344]
# ============================================================
#  EVALUATION: EXPERIMENT-30 No groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: ridge, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.102
#   RMSE : 15.98 kg
#
#  ✅ Test R² is positive (0.102)
#
# Regular CrossValidation:
#   Mean   : 0.322
#   Std    : 0.038
#   Scores : [0.356 0.307 0.254 0.347 0.344]
#  ✅ CV mean is positive (0.322)
#   ✅ Train/test R² gap acceptable (gap: -0.026)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [31/72]
#
#  EXPERIMENT-31 No groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: lasso, Grouping? No, Grid? No, ALGO: LASSO REGRESSION:
# Test R²     : 0.0965
# Test RMSE   : 16.03 kg
# Train R² (log scale): 0.3262
# Train R² (orig scale): 0.0615
# Train RMSE  : 16.21 kg
# Num rows    : 3104
# Num Features: 21
#
#  Cross-validation ---
# CV R² mean: 0.3163
# CV R² std : 0.0351
# CV scores : [0.336 0.309 0.251 0.345 0.341]
# ============================================================
#  EVALUATION: EXPERIMENT-31 No groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: lasso, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.096
#   RMSE : 16.03 kg
#
#  ✅ Test R² is positive (0.096)
#
# Regular CrossValidation:
#   Mean   : 0.316
#   Std    : 0.035
#   Scores : [0.336 0.309 0.251 0.345 0.341]
#  ✅ CV mean is positive (0.316)
#   ✅ Train/test R² gap acceptable (gap: -0.035)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [32/72]
#
#  EXPERIMENT-32 No groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: elasticnet, Grouping? No, Grid? No, ALGO: ELASTICNET REGRESSION:
# Test R²     : 0.0980
# Test RMSE   : 16.01 kg
# Train R² (log scale): 0.3271
# Train R² (orig scale): 0.0637
# Train RMSE  : 16.19 kg
# Num rows    : 3104
# Num Features: 21
#
#  Cross-validation ---
# CV R² mean: 0.3177
# CV R² std : 0.0353
# CV scores : [0.341 0.309 0.252 0.346 0.341]
# ============================================================
#  EVALUATION: EXPERIMENT-32 No groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: elasticnet, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.098
#   RMSE : 16.01 kg
#
#  ✅ Test R² is positive (0.098)
#
# Regular CrossValidation:
#   Mean   : 0.318
#   Std    : 0.035
#   Scores : [0.341 0.309 0.252 0.346 0.341]
#  ✅ CV mean is positive (0.318)
#   ✅ Train/test R² gap acceptable (gap: -0.034)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [33/72]
#
#  EXPERIMENT-33 No groups, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: regular, Grouping? No, Grid? No, ALGO: LINEAR REGRESSION:
# Test R²     : 0.0791
# Test RMSE   : 16.18 kg
# Train R² (log scale): 0.3251
# Train R² (orig scale): 0.0532
# Train RMSE  : 16.28 kg
# Num rows    : 3104
# Num Features: 19
#
#  Cross-validation ---
# CV R² mean: 0.3145
# CV R² std : 0.0361
# CV scores : [0.345 0.305 0.248 0.336 0.339]
# ============================================================
#  EVALUATION: EXPERIMENT-33 No groups, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: regular, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.079
#   RMSE : 16.18 kg
#
#  ✅ Test R² is positive (0.079)
#
# Regular CrossValidation:
#   Mean   : 0.315
#   Std    : 0.036
#   Scores : [0.345 0.305 0.248 0.336 0.339]
#  ✅ CV mean is positive (0.315)
#   ✅ Train/test R² gap acceptable (gap: -0.026)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [34/72]
#
#  EXPERIMENT-34 No groups, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: ridge, Grouping? No, Grid? No, ALGO: RIDGE REGRESSION:
# Test R²     : 0.0799
# Test RMSE   : 16.17 kg
# Train R² (log scale): 0.3251
# Train R² (orig scale): 0.0533
# Train RMSE  : 16.28 kg
# Num rows    : 3104
# Num Features: 19
#
#  Cross-validation ---
# CV R² mean: 0.3147
# CV R² std : 0.0359
# CV scores : [0.344 0.305 0.248 0.337 0.339]
# ============================================================
#  EVALUATION: EXPERIMENT-34 No groups, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: ridge, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.080
#   RMSE : 16.17 kg
#
#  ✅ Test R² is positive (0.080)
#
# Regular CrossValidation:
#   Mean   : 0.315
#   Std    : 0.036
#   Scores : [0.344 0.305 0.248 0.337 0.339]
#  ✅ CV mean is positive (0.315)
#   ✅ Train/test R² gap acceptable (gap: -0.027)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [35/72]
#
#  EXPERIMENT-35 No groups, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: lasso, Grouping? No, Grid? No, ALGO: LASSO REGRESSION:
# Test R²     : 0.0848
# Test RMSE   : 16.13 kg
# Train R² (log scale): 0.3205
# Train R² (orig scale): 0.0517
# Train RMSE  : 16.30 kg
# Num rows    : 3104
# Num Features: 19
#
#  Cross-validation ---
# CV R² mean: 0.3113
# CV R² std : 0.0345
# CV scores : [0.328 0.306 0.246 0.339 0.337]
# ============================================================
#  EVALUATION: EXPERIMENT-35 No groups, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: lasso, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.085
#   RMSE : 16.13 kg
#
#  ✅ Test R² is positive (0.085)
#
# Regular CrossValidation:
#   Mean   : 0.311
#   Std    : 0.034
#   Scores : [0.328 0.306 0.246 0.339 0.337]
#  ✅ CV mean is positive (0.311)
#   ✅ Train/test R² gap acceptable (gap: -0.033)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [36/72]
#
#  EXPERIMENT-36 No groups, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: elasticnet, Grouping? No, Grid? No, ALGO: ELASTICNET REGRESSION:
# Test R²     : 0.0857
# Test RMSE   : 16.12 kg
# Train R² (log scale): 0.3210
# Train R² (orig scale): 0.0526
# Train RMSE  : 16.29 kg
# Num rows    : 3104
# Num Features: 19
#
#  Cross-validation ---
# CV R² mean: 0.3119
# CV R² std : 0.0349
# CV scores : [0.332 0.305 0.247 0.339 0.337]
# ============================================================
#  EVALUATION: EXPERIMENT-36 No groups, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: elasticnet, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.086
#   RMSE : 16.12 kg
#
#  ✅ Test R² is positive (0.086)
#
# Regular CrossValidation:
#   Mean   : 0.312
#   Std    : 0.035
#   Scores : [0.332 0.305 0.247 0.339 0.337]
#  ✅ CV mean is positive (0.312)
#   ✅ Train/test R² gap acceptable (gap: -0.033)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [37/72]
#
#  EXPERIMENT-37 No groups, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: regular, Grouping? No, Grid? No, ALGO: LINEAR REGRESSION:
# Test R²     : 0.0965
# Test RMSE   : 16.03 kg
# Train R² (log scale): 0.3335
# Train R² (orig scale): 0.0725
# Train RMSE  : 16.12 kg
# Num rows    : 3104
# Num Features: 22
#
#  Cross-validation ---
# CV R² mean: 0.3214
# CV R² std : 0.0393
# CV scores : [0.357 0.307 0.251 0.347 0.345]
# ============================================================
#  EVALUATION: EXPERIMENT-37 No groups, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: regular, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.097
#   RMSE : 16.03 kg
#
#  ✅ Test R² is positive (0.097)
#
# Regular CrossValidation:
#   Mean   : 0.321
#   Std    : 0.039
#   Scores : [0.357 0.307 0.251 0.347 0.345]
#  ✅ CV mean is positive (0.321)
#   ✅ Train/test R² gap acceptable (gap: -0.024)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [38/72]
#
#  EXPERIMENT-38 No groups, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: ridge, Grouping? No, Grid? No, ALGO: RIDGE REGRESSION:
# Test R²     : 0.1001
# Test RMSE   : 16.00 kg
# Train R² (log scale): 0.3332
# Train R² (orig scale): 0.0742
# Train RMSE  : 16.10 kg
# Num rows    : 3104
# Num Features: 22
#
#  Cross-validation ---
# CV R² mean: 0.3216
# CV R² std : 0.0379
# CV scores : [0.356 0.307 0.254 0.347 0.344]
# ============================================================
#  EVALUATION: EXPERIMENT-38 No groups, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: ridge, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.100
#   RMSE : 16.00 kg
#
#  ✅ Test R² is positive (0.100)
#
# Regular CrossValidation:
#   Mean   : 0.322
#   Std    : 0.038
#   Scores : [0.356 0.307 0.254 0.347 0.344]
#  ✅ CV mean is positive (0.322)
#   ✅ Train/test R² gap acceptable (gap: -0.026)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [39/72]
#
#  EXPERIMENT-39 No groups, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: lasso, Grouping? No, Grid? No, ALGO: LASSO REGRESSION:
# Test R²     : 0.0964
# Test RMSE   : 16.03 kg
# Train R² (log scale): 0.3262
# Train R² (orig scale): 0.0614
# Train RMSE  : 16.21 kg
# Num rows    : 3104
# Num Features: 22
#
#  Cross-validation ---
# CV R² mean: 0.3162
# CV R² std : 0.0350
# CV scores : [0.335 0.309 0.251 0.345 0.341]
# ============================================================
#  EVALUATION: EXPERIMENT-39 No groups, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: lasso, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.096
#   RMSE : 16.03 kg
#
#  ✅ Test R² is positive (0.096)
#
# Regular CrossValidation:
#   Mean   : 0.316
#   Std    : 0.035
#   Scores : [0.335 0.309 0.251 0.345 0.341]
#  ✅ CV mean is positive (0.316)
#   ✅ Train/test R² gap acceptable (gap: -0.035)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [40/72]
#
#  EXPERIMENT-40 No groups, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: elasticnet, Grouping? No, Grid? No, ALGO: ELASTICNET REGRESSION:
# Test R²     : 0.0987
# Test RMSE   : 16.01 kg
# Train R² (log scale): 0.3272
# Train R² (orig scale): 0.0645
# Train RMSE  : 16.19 kg
# Num rows    : 3104
# Num Features: 22
#
#  Cross-validation ---
# CV R² mean: 0.3177
# CV R² std : 0.0354
# CV scores : [0.34  0.309 0.252 0.347 0.341]
# ============================================================
#  EVALUATION: EXPERIMENT-40 No groups, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: elasticnet, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.099
#   RMSE : 16.01 kg
#
#  ✅ Test R² is positive (0.099)
#
# Regular CrossValidation:
#   Mean   : 0.318
#   Std    : 0.035
#   Scores : [0.34  0.309 0.252 0.347 0.341]
#  ✅ CV mean is positive (0.318)
#   ✅ Train/test R² gap acceptable (gap: -0.034)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [41/72]
#
#  EXPERIMENT-41 No groups, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1']., Model: regular, Grouping? No, Grid? No, ALGO: LINEAR REGRESSION:
# ...
#   Std    : 0.024
#   Scores : [0.249 0.264 0.205 0.274 0.265]
#  ✅ CV mean is positive (0.251)
#   ✅ Train/test R² gap acceptable (gap: -0.035)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [59/72]
#
#  EXPERIMENT-59 No groups, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2']., Model: lasso, Grouping? No, Grid? No, ALGO: LASSO REGRESSION:
# Test R²     : 0.0812
# Test RMSE   : 16.16 kg
# Train R² (log scale): 0.2555
# Train R² (orig scale): 0.0460
# Train RMSE  : 16.34 kg
# Num rows    : 3104
# Num Features: 7
#
#  Cross-validation ---
# CV R² mean: 0.2507
# CV R² std : 0.0263
# CV scores : [0.248 0.264 0.201 0.276 0.265]
# ============================================================
#  EVALUATION: EXPERIMENT-59 No groups, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2']., Model: lasso, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.081
#   RMSE : 16.16 kg
#
#  ✅ Test R² is positive (0.081)
#
# Regular CrossValidation:
#   Mean   : 0.251
#   Std    : 0.026
#   Scores : [0.248 0.264 0.201 0.276 0.265]
#  ✅ CV mean is positive (0.251)
#   ✅ Train/test R² gap acceptable (gap: -0.035)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [60/72]
#
#  EXPERIMENT-60 No groups, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2']., Model: elasticnet, Grouping? No, Grid? No, ALGO: ELASTICNET REGRESSION:
# Test R²     : 0.0812
# Test RMSE   : 16.16 kg
# Train R² (log scale): 0.2560
# Train R² (orig scale): 0.0462
# Train RMSE  : 16.34 kg
# Num rows    : 3104
# Num Features: 7
#
#  Cross-validation ---
# CV R² mean: 0.2514
# CV R² std : 0.0252
# CV scores : [0.248 0.264 0.204 0.275 0.265]
# ============================================================
#  EVALUATION: EXPERIMENT-60 No groups, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2']., Model: elasticnet, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.081
#   RMSE : 16.16 kg
#
#  ✅ Test R² is positive (0.081)
#
# Regular CrossValidation:
#   Mean   : 0.251
#   Std    : 0.025
#   Scores : [0.248 0.264 0.204 0.275 0.265]
#  ✅ CV mean is positive (0.251)
#   ✅ Train/test R² gap acceptable (gap: -0.035)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [61/72]
#
#  EXPERIMENT-61 No groups, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: regular, Grouping? No, Grid? No, ALGO: LINEAR REGRESSION:
# Test R²     : 0.0841
# Test RMSE   : 16.14 kg
# Train R² (log scale): 0.2717
# Train R² (orig scale): 0.0536
# Train RMSE  : 16.28 kg
# Num rows    : 3104
# Num Features: 10
#
#  Cross-validation ---
# CV R² mean: 0.2653
# CV R² std : 0.0201
# CV scores : [0.262 0.27  0.23  0.291 0.273]
# ============================================================
#  EVALUATION: EXPERIMENT-61 No groups, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: regular, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.084
#   RMSE : 16.14 kg
#
#  ✅ Test R² is positive (0.084)
#
# Regular CrossValidation:
#   Mean   : 0.265
#   Std    : 0.020
#   Scores : [0.262 0.27  0.23  0.291 0.273]
#  ✅ CV mean is positive (0.265)
#   ✅ Train/test R² gap acceptable (gap: -0.030)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [62/72]
#
#  EXPERIMENT-62 No groups, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: ridge, Grouping? No, Grid? No, ALGO: RIDGE REGRESSION:
# Test R²     : 0.0836
# Test RMSE   : 16.14 kg
# Train R² (log scale): 0.2717
# Train R² (orig scale): 0.0534
# Train RMSE  : 16.28 kg
# Num rows    : 3104
# Num Features: 10
#
#  Cross-validation ---
# CV R² mean: 0.2654
# CV R² std : 0.0201
# CV scores : [0.263 0.27  0.23  0.291 0.272]
# ============================================================
#  EVALUATION: EXPERIMENT-62 No groups, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: ridge, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.084
#   RMSE : 16.14 kg
#
#  ✅ Test R² is positive (0.084)
#
# Regular CrossValidation:
#   Mean   : 0.265
#   Std    : 0.020
#   Scores : [0.263 0.27  0.23  0.291 0.272]
#  ✅ CV mean is positive (0.265)
#   ✅ Train/test R² gap acceptable (gap: -0.030)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [63/72]
#
#  EXPERIMENT-63 No groups, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: lasso, Grouping? No, Grid? No, ALGO: LASSO REGRESSION:
# Test R²     : 0.0455
# Test RMSE   : 16.47 kg
# Train R² (log scale): 0.2671
# Train R² (orig scale): 0.0356
# Train RMSE  : 16.43 kg
# Num rows    : 3104
# Num Features: 10
#
#  Cross-validation ---
# CV R² mean: 0.2612
# CV R² std : 0.0244
# CV scores : [0.261 0.272 0.216 0.289 0.268]
# ============================================================
#  EVALUATION: EXPERIMENT-63 No groups, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: lasso, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.045
#   RMSE : 16.47 kg
#
#  ✅ Test R² is positive (0.045)
#
# Regular CrossValidation:
#   Mean   : 0.261
#   Std    : 0.024
#   Scores : [0.261 0.272 0.216 0.289 0.268]
#  ✅ CV mean is positive (0.261)
#   ✅ Train/test R² gap acceptable (gap: -0.010)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [64/72]
#
#  EXPERIMENT-64 No groups, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: elasticnet, Grouping? No, Grid? No, ALGO: ELASTICNET REGRESSION:
# Test R²     : 0.0485
# Test RMSE   : 16.45 kg
# Train R² (log scale): 0.2687
# Train R² (orig scale): 0.0378
# Train RMSE  : 16.42 kg
# Num rows    : 3104
# Num Features: 10
#
#  Cross-validation ---
# CV R² mean: 0.2631
# CV R² std : 0.0229
# CV scores : [0.263 0.273 0.221 0.29  0.269]
# ============================================================
#  EVALUATION: EXPERIMENT-64 No groups, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: elasticnet, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.048
#   RMSE : 16.45 kg
#
#  ✅ Test R² is positive (0.048)
#
# Regular CrossValidation:
#   Mean   : 0.263
#   Std    : 0.023
#   Scores : [0.263 0.273 0.221 0.29  0.269]
#  ✅ CV mean is positive (0.263)
#   ✅ Train/test R² gap acceptable (gap: -0.011)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [65/72]
#
#  EXPERIMENT-65 No groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2']., Model: regular, Grouping? No, Grid? No, ALGO: LINEAR REGRESSION:
# Test R²     : 0.0722
# Test RMSE   : 16.24 kg
# Train R² (log scale): 0.2796
# Train R² (orig scale): 0.0419
# Train RMSE  : 16.38 kg
# Num rows    : 3104
# Num Features: 10
#
#  Cross-validation ---
# CV R² mean: 0.2738
# CV R² std : 0.0260
# CV scores : [0.265 0.276 0.229 0.3   0.298]
# ============================================================
#  EVALUATION: EXPERIMENT-65 No groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2']., Model: regular, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.072
#   RMSE : 16.24 kg
#
#  ✅ Test R² is positive (0.072)
#
# Regular CrossValidation:
#   Mean   : 0.274
#   Std    : 0.026
#   Scores : [0.265 0.276 0.229 0.3   0.298]
#  ✅ CV mean is positive (0.274)
#   ✅ Train/test R² gap acceptable (gap: -0.030)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [66/72]
#
#  EXPERIMENT-66 No groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2']., Model: ridge, Grouping? No, Grid? No, ALGO: RIDGE REGRESSION:
# Test R²     : 0.0736
# Test RMSE   : 16.23 kg
# Train R² (log scale): 0.2793
# Train R² (orig scale): 0.0425
# Train RMSE  : 16.37 kg
# Num rows    : 3104
# Num Features: 10
#
#  Cross-validation ---
# CV R² mean: 0.2735
# CV R² std : 0.0264
# CV scores : [0.264 0.277 0.228 0.3   0.298]
# ============================================================
#  EVALUATION: EXPERIMENT-66 No groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2']., Model: ridge, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.074
#   RMSE : 16.23 kg
#
#  ✅ Test R² is positive (0.074)
#
# Regular CrossValidation:
#   Mean   : 0.273
#   Std    : 0.026
#   Scores : [0.264 0.277 0.228 0.3   0.298]
#  ✅ CV mean is positive (0.273)
#   ✅ Train/test R² gap acceptable (gap: -0.031)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [67/72]
#
#  EXPERIMENT-67 No groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2']., Model: lasso, Grouping? No, Grid? No, ALGO: LASSO REGRESSION:
# Test R²     : 0.0737
# Test RMSE   : 16.23 kg
# Train R² (log scale): 0.2791
# Train R² (orig scale): 0.0425
# Train RMSE  : 16.37 kg
# Num rows    : 3104
# Num Features: 10
#
#  Cross-validation ---
# CV R² mean: 0.2738
# CV R² std : 0.0269
# CV scores : [0.263 0.277 0.228 0.302 0.298]
# ============================================================
#  EVALUATION: EXPERIMENT-67 No groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2']., Model: lasso, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.074
#   RMSE : 16.23 kg
#
#  ✅ Test R² is positive (0.074)
#
# Regular CrossValidation:
#   Mean   : 0.274
#   Std    : 0.027
#   Scores : [0.263 0.277 0.228 0.302 0.298]
#  ✅ CV mean is positive (0.274)
#   ✅ Train/test R² gap acceptable (gap: -0.031)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [68/72]
#
#  EXPERIMENT-68 No groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2']., Model: elasticnet, Grouping? No, Grid? No, ALGO: ELASTICNET REGRESSION:
# Test R²     : 0.0733
# Test RMSE   : 16.23 kg
# Train R² (log scale): 0.2794
# Train R² (orig scale): 0.0423
# Train RMSE  : 16.38 kg
# Num rows    : 3104
# Num Features: 10
#
#  Cross-validation ---
# CV R² mean: 0.2732
# CV R² std : 0.0269
# CV scores : [0.262 0.276 0.228 0.302 0.298]
# ============================================================
#  EVALUATION: EXPERIMENT-68 No groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2']., Model: elasticnet, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.073
#   RMSE : 16.23 kg
#
#  ✅ Test R² is positive (0.073)
#
# Regular CrossValidation:
#   Mean   : 0.273
#   Std    : 0.027
#   Scores : [0.262 0.276 0.228 0.302 0.298]
#  ✅ CV mean is positive (0.273)
#   ✅ Train/test R² gap acceptable (gap: -0.031)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [69/72]
#
#  EXPERIMENT-69 No groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: regular, Grouping? No, Grid? No, ALGO: LINEAR REGRESSION:
# Test R²     : 0.0905
# Test RMSE   : 16.08 kg
# Train R² (log scale): 0.2992
# Train R² (orig scale): 0.0593
# Train RMSE  : 16.23 kg
# Num rows    : 3104
# Num Features: 13
#
#  Cross-validation ---
# CV R² mean: 0.2923
# CV R² std : 0.0237
# CV scores : [0.287 0.289 0.253 0.324 0.308]
# ============================================================
#  EVALUATION: EXPERIMENT-69 No groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: regular, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.091
#   RMSE : 16.08 kg
#
#  ✅ Test R² is positive (0.091)
#
# Regular CrossValidation:
#   Mean   : 0.292
#   Std    : 0.024
#   Scores : [0.287 0.289 0.253 0.324 0.308]
#  ✅ CV mean is positive (0.292)
#   ✅ Train/test R² gap acceptable (gap: -0.031)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [70/72]
#
#  EXPERIMENT-70 No groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: ridge, Grouping? No, Grid? No, ALGO: RIDGE REGRESSION:
# Test R²     : 0.0908
# Test RMSE   : 16.08 kg
# Train R² (log scale): 0.2991
# Train R² (orig scale): 0.0591
# Train RMSE  : 16.23 kg
# Num rows    : 3104
# Num Features: 13
#
#  Cross-validation ---
# CV R² mean: 0.2926
# CV R² std : 0.0240
# CV scores : [0.287 0.29  0.253 0.325 0.309]
# ============================================================
#  EVALUATION: EXPERIMENT-70 No groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: ridge, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.091
#   RMSE : 16.08 kg
#
#  ✅ Test R² is positive (0.091)
#
# Regular CrossValidation:
#   Mean   : 0.293
#   Std    : 0.024
#   Scores : [0.287 0.29  0.253 0.325 0.309]
#  ✅ CV mean is positive (0.293)
#   ✅ Train/test R² gap acceptable (gap: -0.032)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [71/72]
#
#  EXPERIMENT-71 No groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: lasso, Grouping? No, Grid? No, ALGO: LASSO REGRESSION:
# Test R²     : 0.0858
# Test RMSE   : 16.12 kg
# Train R² (log scale): 0.2980
# Train R² (orig scale): 0.0561
# Train RMSE  : 16.26 kg
# Num rows    : 3104
# Num Features: 13
#
#  Cross-validation ---
# CV R² mean: 0.2918
# CV R² std : 0.0258
# CV scores : [0.285 0.291 0.249 0.325 0.309]
# ============================================================
#  EVALUATION: EXPERIMENT-71 No groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: lasso, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.086
#   RMSE : 16.12 kg
#
#  ✅ Test R² is positive (0.086)
#
# Regular CrossValidation:
#   Mean   : 0.292
#   Std    : 0.026
#   Scores : [0.285 0.291 0.249 0.325 0.309]
#  ✅ CV mean is positive (0.292)
#   ✅ Train/test R² gap acceptable (gap: -0.030)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [72/72]
#
#  EXPERIMENT-72 No groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: elasticnet, Grouping? No, Grid? No, ALGO: ELASTICNET REGRESSION:
# Test R²     : 0.0925
# Test RMSE   : 16.06 kg
# Train R² (log scale): 0.2987
# Train R² (orig scale): 0.0590
# Train RMSE  : 16.23 kg
# Num rows    : 3104
# Num Features: 13
#
#  Cross-validation ---
# CV R² mean: 0.2924
# CV R² std : 0.0247
# CV scores : [0.286 0.29  0.251 0.325 0.309]
# ============================================================
#  EVALUATION: EXPERIMENT-72 No groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: elasticnet, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.093
#   RMSE : 16.06 kg
#
#  ✅ Test R² is positive (0.093)
#
# Regular CrossValidation:
#   Mean   : 0.292
#   Std    : 0.025
#   Scores : [0.286 0.29  0.251 0.325 0.309]
#  ✅ CV mean is positive (0.292)
#   ✅ Train/test R² gap acceptable (gap: -0.034)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# Completed: 72/72 experiments

# %%
tabulate_results(lin_belige_no_groups, acceptable_only=True)
# Out:
# Showing 68 acceptable experiments
# <style type="text/css">
# #T_f063c_row0_col5, #T_f063c_row1_col5, #T_f063c_row3_col1, #T_f063c_row3_col2 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f063c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f063c_level0_col0" class="col_heading level0 col0" >Experiment</th>
#       <th id="T_f063c_level0_col1" class="col_heading level0 col1" >Test R²</th>
#       <th id="T_f063c_level0_col2" class="col_heading level0 col2" >Test RMSE</th>
#       <th id="T_f063c_level0_col3" class="col_heading level0 col3" >Train R²</th>
#       <th id="T_f063c_level0_col4" class="col_heading level0 col4" >Train RMSE</th>
#       <th id="T_f063c_level0_col5" class="col_heading level0 col5" >CV R² Mean</th>
#       <th id="T_f063c_level0_col6" class="col_heading level0 col6" >CV R² Std</th>
#       <th id="T_f063c_level0_col7" class="col_heading level0 col7" >verdict</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f063c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f063c_row0_col0" class="data row0 col0" >EXPERIMENT-38 No groups, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: ridge, Grouping? No, Grid? No</td>
#       <td id="T_f063c_row0_col1" class="data row0 col1" >0.1001</td>
#       <td id="T_f063c_row0_col2" class="data row0 col2" >16</td>
#       <td id="T_f063c_row0_col3" class="data row0 col3" >0.0742</td>
#       <td id="T_f063c_row0_col4" class="data row0 col4" >16.1</td>
#       <td id="T_f063c_row0_col5" class="data row0 col5" >0.3216</td>
#       <td id="T_f063c_row0_col6" class="data row0 col6" >0.0379</td>
#       <td id="T_f063c_row0_col7" class="data row0 col7" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_f063c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f063c_row1_col0" class="data row1 col0" >EXPERIMENT-30 No groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: ridge, Grouping? No, Grid? No</td>
#       <td id="T_f063c_row1_col1" class="data row1 col1" >0.1016</td>
#       <td id="T_f063c_row1_col2" class="data row1 col2" >15.98</td>
#       <td id="T_f063c_row1_col3" class="data row1 col3" >0.0755</td>
#       <td id="T_f063c_row1_col4" class="data row1 col4" >16.09</td>
#       <td id="T_f063c_row1_col5" class="data row1 col5" >0.3216</td>
#       <td id="T_f063c_row1_col6" class="data row1 col6" >0.0378</td>
#       <td id="T_f063c_row1_col7" class="data row1 col7" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_f063c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f063c_row2_col0" class="data row2 col0" >EXPERIMENT-37 No groups, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: regular, Grouping? No, Grid? No</td>
#       <td id="T_f063c_row2_col1" class="data row2 col1" >0.0965</td>
#       <td id="T_f063c_row2_col2" class="data row2 col2" >16.03</td>
#       <td id="T_f063c_row2_col3" class="data row2 col3" >0.0725</td>
#       <td id="T_f063c_row2_col4" class="data row2 col4" >16.12</td>
#       <td id="T_f063c_row2_col5" class="data row2 col5" >0.3214</td>
#       <td id="T_f063c_row2_col6" class="data row2 col6" >0.0393</td>
#       <td id="T_f063c_row2_col7" class="data row2 col7" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_f063c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f063c_row3_col0" class="data row3 col0" >EXPERIMENT-29 No groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: regular, Grouping? No, Grid? No</td>
#       <td id="T_f063c_row3_col1" class="data row3 col1" >0.1027</td>
#       <td id="T_f063c_row3_col2" class="data row3 col2" >15.97</td>
#       <td id="T_f063c_row3_col3" class="data row3 col3" >0.0771</td>
#       <td id="T_f063c_row3_col4" class="data row3 col4" >16.08</td>
#       <td id="T_f063c_row3_col5" class="data row3 col5" >0.3214</td>
#       <td id="T_f063c_row3_col6" class="data row3 col6" >0.0383</td>
#       <td id="T_f063c_row3_col7" class="data row3 col7" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_f063c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f063c_row4_col0" class="data row4 col0" >EXPERIMENT-32 No groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: elasticnet, Grouping? No, Grid? No</td>
#       <td id="T_f063c_row4_col1" class="data row4 col1" >0.098</td>
#       <td id="T_f063c_row4_col2" class="data row4 col2" >16.01</td>
#       <td id="T_f063c_row4_col3" class="data row4 col3" >0.0637</td>
#       <td id="T_f063c_row4_col4" class="data row4 col4" >16.19</td>
#       <td id="T_f063c_row4_col5" class="data row4 col5" >0.3177</td>
#       <td id="T_f063c_row4_col6" class="data row4 col6" >0.0353</td>
#       <td id="T_f063c_row4_col7" class="data row4 col7" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_f063c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f063c_row5_col0" class="data row5 col0" >EXPERIMENT-40 No groups, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: elasticnet, Grouping? No, Grid? No</td>
#       <td id="T_f063c_row5_col1" class="data row5 col1" >0.0987</td>
#       <td id="T_f063c_row5_col2" class="data row5 col2" >16.01</td>
#       <td id="T_f063c_row5_col3" class="data row5 col3" >0.0645</td>
#       <td id="T_f063c_row5_col4" class="data row5 col4" >16.19</td>
#       <td id="T_f063c_row5_col5" class="data row5 col5" >0.3177</td>
#       <td id="T_f063c_row5_col6" class="data row5 col6" >0.0354</td>
#       <td id="T_f063c_row5_col7" class="data row5 col7" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_f063c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f063c_row6_col0" class="data row6 col0" >EXPERIMENT-31 No groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: lasso, Grouping? No, Grid? No</td>
#       <td id="T_f063c_row6_col1" class="data row6 col1" >0.0965</td>
#       <td id="T_f063c_row6_col2" class="data row6 col2" >16.03</td>
#       <td id="T_f063c_row6_col3" class="data row6 col3" >0.0615</td>
#       <td id="T_f063c_row6_col4" class="data row6 col4" >16.21</td>
#       <td id="T_f063c_row6_col5" class="data row6 col5" >0.3163</td>
#       <td id="T_f063c_row6_col6" class="data row6 col6" >0.0351</td>
#       <td id="T_f063c_row6_col7" class="data row6 col7" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_f063c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f063c_row7_col0" class="data row7 col0" >EXPERIMENT-39 No groups, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: lasso, Grouping? No, Grid? No</td>
#       <td id="T_f063c_row7_col1" class="data row7 col1" >0.0964</td>
#       <td id="T_f063c_row7_col2" class

# %% [markdown]
# ### BELIGE DATA. PLOT GROUPS. ALL ROWS. LINEAR REGRESSION

# %%
lin_belige_groups = {}

run_experiment(X_belige, y_belige,
               is_groups=True, group_info=grp_belige,
               features_list=gen_features_list,
               experiments=lin_belige_groups,
               model_type="linear", is_grid=False,
               is_stratified=is_stratified_g,
               global_experiment_list=global_experiment_list)
# Out:
# [1/72]
#
#  EXPERIMENT-1 Plot groups, Features: ['height']., Model: regular, Grouping? Yes, Grid? No, ALGO: LINEAR REGRESSION:
# Test R²     : 0.1515
# Test RMSE   : 4.25 kg
# Train R² (log scale): 0.2551
# Train R² (orig scale): -0.1772
# Train RMSE  : 20.15 kg
# Num rows    : 3100
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: 0.1855
# CV R² std : 0.2018
# CV scores : [-0.029  0.568  0.095  0.134  0.16 ]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2296
# Grouped CV R² std : 0.2175
# Grouped CV scores : [-0.108  0.081  0.116 -0.026  0.407  0.535  0.582  0.187  0.21   0.313]
# ============================================================
#  EVALUATION: EXPERIMENT-1 Plot groups, Features: ['height']., Model: regular, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.152
#   RMSE : 4.25 kg
#
#  ✅ Test R² is positive (0.152)
#
# Regular CrossValidation:
#   Mean   : 0.185
#   Std    : 0.202
#   Scores : [-0.029  0.568  0.095  0.134  0.16 ]
#  ✅ CV mean is positive (0.185)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.108  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :   0.081  {GREEN_TICK}
#   Frenchman Caye_3     :   0.116  {GREEN_TICK}
#   Big Creek_3          :  -0.026  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.407  {GREEN_TICK}
#   Big Creek_2          :   0.535  {GREEN_TICK}
#   Drowned Caye_5       :   0.582  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.187  {GREEN_TICK}
#   Channel Caye_2       :   0.210  {GREEN_TICK}
#   Channel Caye_6       :   0.313  {GREEN_TICK}
#
#   Mean : 0.230
#   Std  : 0.218
#
#   ✅ Grouped CV mean above 0.15 (0.230)
#   ✅ Grouped CV std below 0.25 (0.218)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.078 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.329)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {WARNING}  MARGINAL — positive metrics but concerns
#
# [2/72]
#
#  EXPERIMENT-2 Plot groups, Features: ['height']., Model: ridge, Grouping? Yes, Grid? No, ALGO: RIDGE REGRESSION:
# Test R²     : 0.1536
# Test RMSE   : 4.25 kg
# Train R² (log scale): 0.2549
# Train R² (orig scale): -0.0952
# Train RMSE  : 19.43 kg
# Num rows    : 3100
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: 0.1820
# CV R² std : 0.1966
# CV scores : [-0.027  0.554  0.089  0.134  0.16 ]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2253
# Grouped CV R² std : 0.2148
# Grouped CV scores : [-0.108  0.081  0.109 -0.026  0.399  0.526  0.577  0.184  0.206  0.307]
# ============================================================
#  EVALUATION: EXPERIMENT-2 Plot groups, Features: ['height']., Model: ridge, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.154
#   RMSE : 4.25 kg
#
#  ✅ Test R² is positive (0.154)
#
# Regular CrossValidation:
#   Mean   : 0.182
#   Std    : 0.197
#   Scores : [-0.027  0.554  0.089  0.134  0.16 ]
#  ✅ CV mean is positive (0.182)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.108  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :   0.081  {GREEN_TICK}
#   Frenchman Caye_3     :   0.109  {GREEN_TICK}
#   Big Creek_3          :  -0.026  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.399  {GREEN_TICK}
#   Big Creek_2          :   0.526  {GREEN_TICK}
#   Drowned Caye_5       :   0.577  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.184  {GREEN_TICK}
#   Channel Caye_2       :   0.206  {GREEN_TICK}
#   Channel Caye_6       :   0.307  {GREEN_TICK}
#
#   Mean : 0.225
#   Std  : 0.215
#
#   ✅ Grouped CV mean above 0.15 (0.225)
#   ✅ Grouped CV std below 0.25 (0.215)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.072 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.249)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {WARNING}  MARGINAL — positive metrics but concerns
#
# [3/72]
#
#  EXPERIMENT-3 Plot groups, Features: ['height']., Model: lasso, Grouping? Yes, Grid? No, ALGO: LASSO REGRESSION:
# Test R²     : 0.1529
# Test RMSE   : 4.25 kg
# Train R² (log scale): 0.2550
# Train R² (orig scale): -0.1273
# Train RMSE  : 19.72 kg
# Num rows    : 3100
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: 0.1871
# CV R² std : 0.1968
# CV scores : [-0.02   0.56   0.092  0.145  0.157]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2238
# Grouped CV R² std : 0.2092
# Grouped CV scores : [-0.107  0.081  0.112 -0.023  0.403  0.53   0.539  0.185  0.208  0.31 ]
# ============================================================
#  EVALUATION: EXPERIMENT-3 Plot groups, Features: ['height']., Model: lasso, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.153
#   RMSE : 4.25 kg
#
#  ✅ Test R² is positive (0.153)
#
# Regular CrossValidation:
#   Mean   : 0.187
#   Std    : 0.197
#   Scores : [-0.02   0.56   0.092  0.145  0.157]
#  ✅ CV mean is positive (0.187)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.107  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :   0.081  {GREEN_TICK}
#   Frenchman Caye_3     :   0.112  {GREEN_TICK}
#   Big Creek_3          :  -0.023  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.403  {GREEN_TICK}
#   Big Creek_2          :   0.530  {GREEN_TICK}
#   Drowned Caye_5       :   0.539  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.185  {GREEN_TICK}
#   Channel Caye_2       :   0.208  {GREEN_TICK}
#   Channel Caye_6       :   0.310  {GREEN_TICK}
#
#   Mean : 0.224
#   Std  : 0.209
#
#   ✅ Grouped CV mean above 0.15 (0.224)
#   ✅ Grouped CV std below 0.25 (0.209)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.071 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.280)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {WARNING}  MARGINAL — positive metrics but concerns
#
# [4/72]
#
#  EXPERIMENT-4 Plot groups, Features: ['height']., Model: elasticnet, Grouping? Yes, Grid? No, ALGO: ELASTICNET REGRESSION:
# Test R²     : 0.1534
# Test RMSE   : 4.25 kg
# Train R² (log scale): 0.2522
# Train R² (orig scale): 0.0088
# Train RMSE  : 18.49 kg
# Num rows    : 3100
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: 0.1761
# CV R² std : 0.1844
# CV scores : [-0.023  0.524  0.093  0.144  0.142]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2153
# Grouped CV R² std : 0.2077
# Grouped CV scores : [-0.107  0.08   0.093 -0.023  0.38   0.503  0.561  0.175  0.198  0.294]
# ============================================================
#  EVALUATION: EXPERIMENT-4 Plot groups, Features: ['height']., Model: elasticnet, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.153
#   RMSE : 4.25 kg
#
#  ✅ Test R² is positive (0.153)
#
# Regular CrossValidation:
#   Mean   : 0.176
#   Std    : 0.184
#   Scores : [-0.023  0.524  0.093  0.144  0.142]
#  ✅ CV mean is positive (0.176)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.107  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :   0.080  {GREEN_TICK}
#   Frenchman Caye_3     :   0.093  {GREEN_TICK}
#   Big Creek_3          :  -0.023  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.380  {GREEN_TICK}
#   Big Creek_2          :   0.503  {GREEN_TICK}
#   Drowned Caye_5       :   0.561  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.175  {GREEN_TICK}
#   Channel Caye_2       :   0.198  {GREEN_TICK}
#   Channel Caye_6       :   0.294  {GREEN_TICK}
#
#   Mean : 0.215
#   Std  : 0.208
#
#   ✅ Grouped CV mean above 0.15 (0.215)
#   ✅ Grouped CV std below 0.25 (0.208)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.062 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.145)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {WARNING}  MARGINAL — positive metrics but concerns
#
# [5/72]
#
#  EXPERIMENT-5 Plot groups, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: regular, Grouping? Yes, Grid? No, ALGO: LINEAR REGRESSION:
# Test R²     : 0.2205
# Test RMSE   : 4.08 kg
# Train R² (log scale): 0.2707
# Train R² (orig scale): 0.0545
# Train RMSE  : 18.06 kg
# Num rows    : 3100
# Num Features: 4
#
#  Cross-validation ---
# CV R² mean: 0.1830
# CV R² std : 0.2180
# CV scores : [-0.064  0.591  0.098  0.159  0.13 ]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2378
# Grouped CV R² std : 0.1876
# Grouped CV scores : [-0.033  0.142  0.105  0.006  0.319  0.558  0.518  0.215  0.213  0.334]
# ============================================================
#  EVALUATION: EXPERIMENT-5 Plot groups, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: regular, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.220
#   RMSE : 4.08 kg
#
#  ✅ Test R² is positive (0.220)
#
# Regular CrossValidation:
#   Mean   : 0.183
#   Std    : 0.218
#   Scores : [-0.064  0.591  0.098  0.159  0.13 ]
#  ✅ CV mean is positive (0.183)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.033  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :   0.142  {GREEN_TICK}
#   Frenchman Caye_3     :   0.105  {GREEN_TICK}
#   Big Creek_3          :   0.006  {GREEN_TICK}
#   Frenchman Caye_1     :   0.319  {GREEN_TICK}
#   Big Creek_2          :   0.558  {GREEN_TICK}
#   Drowned Caye_5       :   0.518  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.215  {GREEN_TICK}
#   Channel Caye_2       :   0.213  {GREEN_TICK}
#   Channel Caye_6       :   0.334  {GREEN_TICK}
#
#   Mean : 0.238
#   Std  : 0.188
#
#   ✅ Grouped CV mean above 0.15 (0.238)
#   ✅ Grouped CV std below 0.25 (0.188)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ✅ Grouped CV and test R² agree (gap: 0.017)
#   ✅ Train/test R² gap acceptable (gap: -0.166)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [6/72]
#
#  EXPERIMENT-6 Plot groups, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: ridge, Grouping? Yes, Grid? No, ALGO: RIDGE REGRESSION:
# Test R²     : 0.1808
# Test RMSE   : 4.18 kg
# Train R² (log scale): 0.2676
# Train R² (orig scale): 0.0520
# Train RMSE  : 18.08 kg
# Num rows    : 3100
# Num Features: 4
#
#  Cross-validation ---
# CV R² mean: 0.1966
# CV R² std : 0.2185
# CV scores : [-0.055  0.6    0.089  0.183  0.167]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2369
# Grouped CV R² std : 0.1928
# Grouped CV scores : [-0.04   0.137  0.118 -0.011  0.33   0.558  0.53   0.197  0.216  0.334]
# ============================================================
#  EVALUATION: EXPERIMENT-6 Plot groups, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: ridge, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.181
#   RMSE : 4.18 kg
#
#  ✅ Test R² is positive (0.181)
#
# Regular CrossValidation:
#   Mean   : 0.197
#   Std    : 0.219
#   Scores : [-0.055  0.6    0.089  0.183  0.167]
#  ✅ CV mean is positive (0.197)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.040  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :   0.137  {GREEN_TICK}
#   Frenchman Caye_3     :   0.118  {GREEN_TICK}
#   Big Creek_3          :  -0.011  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.330  {GREEN_TICK}
#   Big Creek_2          :   0.558  {GREEN_TICK}
#   Drowned Caye_5       :   0.530  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.197  {GREEN_TICK}
#   Channel Caye_2       :   0.216  {GREEN_TICK}
#   Channel Caye_6       :   0.334  {GREEN_TICK}
#
#   Mean : 0.237
#   Std  : 0.193
#
#   ✅ Grouped CV mean above 0.15 (0.237)
#   ✅ Grouped CV std below 0.25 (0.193)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.056 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.129)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {WARNING}  MARGINAL — positive metrics but concerns
#
# [7/72]
#
#  EXPERIMENT-7 Plot groups, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: lasso, Grouping? Yes, Grid? No, ALGO: LASSO REGRESSION:
# Test R²     : 0.1518
# Test RMSE   : 4.25 kg
# Train R² (log scale): 0.2687
# Train R² (orig scale): 0.0541
# Train RMSE  : 18.06 kg
# Num rows    : 3100
# Num Features: 4
#
#  Cross-validation ---
# CV R² mean: 0.1940
# CV R² std : 0.2169
# CV scores : [-0.038  0.602  0.083  0.176  0.146]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2391
# Grouped CV R² std : 0.1952
# Grouped CV scores : [-0.045  0.134  0.121 -0.007  0.339  0.553  0.547  0.201  0.214  0.335]
# ============================================================
#  EVALUATION: EXPERIMENT-7 Plot groups, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: lasso, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.152
#   RMSE : 4.25 kg
#
#  ✅ Test R² is positive (0.152)
#
# Regular CrossValidation:
#   Mean   : 0.194
#   Std    : 0.217
#   Scores : [-0.038  0.602  0.083  0.176  0.146]
#  ✅ CV mean is positive (0.194)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.045  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :   0.134  {GREEN_TICK}
#   Frenchman Caye_3     :   0.121  {GREEN_TICK}
#   Big Creek_3          :  -0.007  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.339  {GREEN_TICK}
#   Big Creek_2          :   0.553  {GREEN_TICK}
#   Drowned Caye_5       :   0.547  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.201  {GREEN_TICK}
#   Channel Caye_2       :   0.214  {GREEN_TICK}
#   Channel Caye_6       :   0.335  {GREEN_TICK}
#
#   Mean : 0.239
#   Std  : 0.195
#
#   ✅ Grouped CV mean above 0.15 (0.239)
#   ✅ Grouped CV std below 0.25 (0.195)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.087 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.098)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {WARNING}  MARGINAL — positive metrics but concerns
#
# [8/72]
#
#  EXPERIMENT-8 Plot groups, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: elasticnet, Grouping? Yes, Grid? No, ALGO: ELASTICNET REGRESSION:
# Test R²     : 0.1383
# Test RMSE   : 4.28 kg
# Train R² (log scale): 0.2690
# Train R² (orig scale): 0.0544
# Train RMSE  : 18.06 kg
# Num rows    : 3100
# Num Features: 4
#
#  Cross-validation ---
# CV R² mean: 0.1945
# CV R² std : 0.2080
# CV scores : [-0.035  0.58   0.08   0.201  0.147]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2376
# Grouped CV R² std : 0.1936
# Grouped CV scores : [-0.04   0.134  0.121 -0.017  0.339  0.552  0.535  0.201  0.215  0.335]
# ============================================================
#  EVALUATION: EXPERIMENT-8 Plot groups, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: elasticnet, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.138
#   RMSE : 4.28 kg
#
#  ✅ Test R² is positive (0.138)
#
# Regular CrossValidation:
#   Mean   : 0.195
#   Std    : 0.208
#   Scores : [-0.035  0.58   0.08   0.201  0.147]
#  ✅ CV mean is positive (0.195)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.040  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :   0.134  {GREEN_TICK}
#   Frenchman Caye_3     :   0.121  {GREEN_TICK}
#   Big Creek_3          :  -0.017  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.339  {GREEN_TICK}
#   Big Creek_2          :   0.552  {GREEN_TICK}
#   Drowned Caye_5       :   0.535  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.201  {GREEN_TICK}
#   Channel Caye_2       :   0.215  {GREEN_TICK}
#   Channel Caye_6       :   0.335  {GREEN_TICK}
#
#   Mean : 0.238
#   Std  : 0.194
#
#   ✅ Grouped CV mean above 0.15 (0.238)
#   ✅ Grouped CV std below 0.25 (0.194)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.099 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.084)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {WARNING}  MARGINAL — positive metrics but concerns
#
# [9/72]
#
#  EXPERIMENT-9 Plot groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2']., Model: regular, Grouping? Yes, Grid? No, ALGO: LINEAR REGRESSION:
# Test R²     : 0.1988
# Test RMSE   : 4.13 kg
# Train R² (log scale): 0.2867
# Train R² (orig scale): 0.0337
# Train RMSE  : 18.25 kg
# Num rows    : 3100
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: -0.7363
# CV R² std : 1.4037
# CV scores : [-0.554  0.516  0.057 -0.248 -3.453]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1701
# Grouped CV R² std : 0.1435
# Grouped CV scores : [ 0.017  0.252  0.179 -0.056  0.362  0.101  0.403  0.018  0.182  0.242]
# ============================================================
#  EVALUATION: EXPERIMENT-9 Plot groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2']., Model: regular, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.199
#   RMSE : 4.13 kg
#
#  ✅ Test R² is positive (0.199)
#
# Regular CrossValidation:
#   Mean   : -0.736
#   Std    : 1.404
#   Scores : [-0.554  0.516  0.057 -0.248 -3.453]
#  ❌ CV mean is negative (-0.736)
#
# Grouped CrossValidation:
#   Big Creek_5          :   0.017  {GREEN_TICK}
#   Frenchman Caye_6     :   0.252  {GREEN_TICK}
#   Frenchman Caye_3     :   0.179  {GREEN_TICK}
#   Big Creek_3          :  -0.056  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.362  {GREEN_TICK}
#   Big Creek_2          :   0.101  {GREEN_TICK}
#   Drowned Caye_5       :   0.403  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.018  {GREEN_TICK}
#   Channel Caye_2       :   0.182  {GREEN_TICK}
#   Channel Caye_6       :   0.242  {GREEN_TICK}
#
#   Mean : 0.170
#   Std  : 0.143
#
#   ✅ Grouped CV mean above 0.15 (0.170)
#   ✅ Grouped CV std below 0.25 (0.143)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ✅ Grouped CV and test R² agree (gap: 0.029)
#   ✅ Train/test R² gap acceptable (gap: -0.165)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE (grouped CV clean — regular CV unreliable)
#
# [10/72]
#
#  EXPERIMENT-10 Plot groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2']., Model: ridge, Grouping? Yes, Grid? No, ALGO: RIDGE REGRESSION:
# Test R²     : 0.2707
# Test RMSE   : 3.94 kg
# Train R² (log scale): 0.2462
# Train R² (orig scale): -0.0020
# Train RMSE  : 18.59 kg
# Num rows    : 3100
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: -0.7553
# CV R² std : 1.3964
# CV scores : [-0.552  0.55  -0.033 -0.29  -3.451]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2051
# Grouped CV R² std : 0.1788
# Grouped CV scores : [-0.047  0.237  0.016 -0.006  0.195  0.492  0.502  0.248  0.175  0.239]
# ============================================================
#  EVALUATION: EXPERIMENT-10 Plot groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2']., Model: ridge, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.271
#   RMSE : 3.94 kg
#
#  ✅ Test R² is positive (0.271)
#
# Regular CrossValidation:
#   Mean   : -0.755
#   Std    : 1.396
#   Scores : [-0.552  0.55  -0.033 -0.29  -3.451]
#  ❌ CV mean is negative (-0.755)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.047  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :   0.237  {GREEN_TICK}
#   Frenchman Caye_3     :   0.016  {GREEN_TICK}
#   Big Creek_3          :  -0.006  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.195  {GREEN_TICK}
#   Big Creek_2          :   0.492  {GREEN_TICK}
#   Drowned Caye_5       :   0.502  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.248  {GREEN_TICK}
#   Channel Caye_2       :   0.175  {GREEN_TICK}
#   Channel Caye_6       :   0.239  {GREEN_TICK}
#
#   Mean : 0.205
#   Std  : 0.179
#
#   ✅ Grouped CV mean above 0.15 (0.205)
#   ✅ Grouped CV std below 0.25 (0.179)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.066 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.273)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {RED_CROSS} REJECTED
#
# [11/72]
#
#  EXPERIMENT-11 Plot groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2']., Model: lasso, Grouping? Yes, Grid? No, ALGO: LASSO REGRESSION:
# Test R²     : 0.2697
# Test RMSE   : 3.94 kg
# Train R² (log scale): 0.2477
# Train R² (orig scale): -0.0017
# Train RMSE  : 18.59 kg
# Num rows    : 3100
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: -0.2011
# CV R² std : 0.1547
# CV scores : [-0.429 -0.016 -0.085 -0.331 -0.145]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1116
# Grouped CV R² std : 0.1876
# Grouped CV scores : [-0.184  0.181 -0.078 -0.069  0.186  0.495 -0.003  0.248  0.171  0.169]
# ============================================================
#  EVALUATION: EXPERIMENT-11 Plot groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2']., Model: lasso, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.270
#   RMSE : 3.94 kg
#
#  ✅ Test R² is positive (0.270)
#
# Regular CrossValidation:
#   Mean   : -0.201
#   Std    : 0.155
#   Scores : [-0.429 -0.016 -0.085 -0.331 -0.145]
#  ❌ CV mean is negative (-0.201)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.184  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :   0.181  {GREEN_TICK}
#   Frenchman Caye_3     :  -0.078  {WARNING}  near-zero variance artifact
#   Big Creek_3          :  -0.069  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.186  {GREEN_TICK}
#   Big Creek_2          :   0.495  {GREEN_TICK}
#   Drowned Caye_5       :  -0.003  {RED_CROSS} negative — cause unknown
#   Gra Gra Lagoon_4     :   0.248  {GREEN_TICK}
#   Channel Caye_2       :   0.171  {GREEN_TICK}
#   Channel Caye_6       :   0.169  {GREEN_TICK}
#
#   Mean : 0.112
#   Std  : 0.188
#
#   ❌ Grouped CV mean below 0.15 (0.112)
#   ✅ Grouped CV std below 0.25 (0.188)
#   ❌ Unexplained negative folds: ['Drowned Caye_5']
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.158 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.271)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {RED_CROSS} REJECTED
#
# [12/72]
#
#  EXPERIMENT-12 Plot groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2']., Model: elasticnet, Grouping? Yes, Grid? No, ALGO: ELASTICNET REGRESSION:
# Test R²     : 0.2572
# Test RMSE   : 3.98 kg
# Train R² (log scale): 0.2180
# Train R² (orig scale): -0.0157
# Train RMSE  : 18.71 kg
# Num rows    : 3100
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: -0.1828
# CV R² std : 0.1493
# CV scores : [-0.347 -0.016 -0.068 -0.377 -0.106]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1495
# Grouped CV R² std : 0.1691
# Grouped CV scores : [-0.162  0.233 -0.016 -0.032  0.144  0.467  0.228  0.238  0.161  0.234]
# ============================================================
#  EVALUATION: EXPERIMENT-12 Plot groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2']., Model: elasticnet, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.257
#   RMSE : 3.98 kg
#
#  ✅ Test R² is positive (0.257)
#
# Regular CrossValidation:
#   Mean   : -0.183
#   Std    : 0.149
#   Scores : [-0.347 -0.016 -0.068 -0.377 -0.106]
#  ❌ CV mean is negative (-0.183)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.162  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :   0.233  {GREEN_TICK}
#   Frenchman Caye_3     :  -0.016  {WARNING}  near-zero variance artifact
#   Big Creek_3          :  -0.032  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.144  {GREEN_TICK}
#   Big Creek_2          :   0.467  {GREEN_TICK}
#   Drowned Caye_5       :   0.228  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.238  {GREEN_TICK}
#   Channel Caye_2       :   0.161  {GREEN_TICK}
#   Channel Caye_6       :   0.234  {GREEN_TICK}
#
#   Mean : 0.149
#   Std  : 0.169
#
#   ❌ Grouped CV mean below 0.15 (0.149)
#   ✅ Grouped CV std below 0.25 (0.169)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.108 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.273)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {RED_CROSS} REJECTED
#
# [13/72]
#
#  EXPERIMENT-13 Plot groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: regular, Grouping? Yes, Grid? No, ALGO: LINEAR REGRESSION:
# Test R²     : 0.1922
# Test RMSE   : 4.15 kg
# Train R² (log scale): 0.3063
# Train R² (orig scale): 0.0632
# Train RMSE  : 17.97 kg
# Num rows    : 3100
# Num Features: 12
#
#  Cross-validation ---
# CV R² mean: -1.4152
# CV R² std : 2.6263
# CV scores : [-0.362  0.555  0.096 -0.773 -6.592]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1237
# Grouped CV R² std : 0.1683
# Grouped CV scores : [-0.172  0.001  0.212 -0.041  0.328  0.079  0.428  0.056  0.172  0.176]
# ============================================================
#  EVALUATION: EXPERIMENT-13 Plot groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: regular, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.192
#   RMSE : 4.15 kg
#
#  ✅ Test R² is positive (0.192)
#
# Regular CrossValidation:
#   Mean   : -1.415
#   Std    : 2.626
#   Scores : [-0.362  0.555  0.096 -0.773 -6.592]
#  ❌ CV mean is negative (-1.415)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.172  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :   0.001  {GREEN_TICK}
#   Frenchman Caye_3     :   0.212  {GREEN_TICK}
#   Big Creek_3          :  -0.041  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.328  {GREEN_TICK}
#   Big Creek_2          :   0.079  {GREEN_TICK}
#   Drowned Caye_5       :   0.428  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.056  {GREEN_TICK}
#   Channel Caye_2       :   0.172  {GREEN_TICK}
#   Channel Caye_6       :   0.176  {GREEN_TICK}
#
#   Mean : 0.124
#   Std  : 0.168
#
#   ❌ Grouped CV mean below 0.15 (0.124)
#   ✅ Grouped CV std below 0.25 (0.168)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.068 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.129)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {RED_CROSS} REJECTED
#
# [14/72]
#
#  EXPERIMENT-14 Plot groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: ridge, Grouping? Yes, Grid? No, ALGO: RIDGE REGRESSION:
# Test R²     : 0.2547
# Test RMSE   : 3.98 kg
# Train R² (log scale): 0.2847
# Train R² (orig scale): 0.0542
# Train RMSE  : 18.06 kg
# Num rows    : 3100
# Num Features: 12
#
#  Cross-validation ---
# CV R² mean: -1.0017
# CV R² std : 1.9814
# CV scores : [-0.091  0.598  0.087 -0.73  -4.872]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2395
# Grouped CV R² std : 0.1875
# Grouped CV scores : [-0.044  0.166  0.112  0.001  0.32   0.555  0.526  0.252  0.208  0.299]
# ============================================================
#  EVALUATION: EXPERIMENT-14 Plot groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: ridge, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.255
#   RMSE : 3.98 kg
#
#  ✅ Test R² is positive (0.255)
#
# Regular CrossValidation:
#   Mean   : -1.002
#   Std    : 1.981
#   Scores : [-0.091  0.598  0.087 -0.73  -4.872]
#  ❌ CV mean is negative (-1.002)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.044  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :   0.166  {GREEN_TICK}
#   Frenchman Caye_3     :   0.112  {GREEN_TICK}
#   Big Creek_3          :   0.001  {GREEN_TICK}
#   Frenchman Caye_1     :   0.320  {GREEN_TICK}
#   Big Creek_2          :   0.555  {GREEN_TICK}
#   Drowned Caye_5       :   0.526  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.252  {GREEN_TICK}
#   Channel Caye_2       :   0.208  {GREEN_TICK}
#   Channel Caye_6       :   0.299  {GREEN_TICK}
#
#   Mean : 0.240
#   Std  : 0.188
#
#   ✅ Grouped CV mean above 0.15 (0.240)
#   ✅ Grouped CV std below 0.25 (0.188)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ✅ Grouped CV and test R² agree (gap: 0.015)
#   ✅ Train/test R² gap acceptable (gap: -0.200)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE (grouped CV clean — regular CV unreliable)
#
# [15/72]
#
#  EXPERIMENT-15 Plot groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: lasso, Grouping? Yes, Grid? No, ALGO: LASSO REGRESSION:
# Test R²     : 0.2546
# Test RMSE   : 3.98 kg
# Train R² (log scale): 0.2562
# Train R² (orig scale): 0.0429
# Train RMSE  : 18.17 kg
# Num rows    : 3100
# Num Features: 12
#
#  Cross-validation ---
# CV R² mean: 0.0781
# CV R² std : 0.2186
# CV scores : [-0.101  0.467  0.059 -0.153  0.118]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2303
# Grouped CV R² std : 0.1843
# Grouped CV scores : [ 0.052  0.121  0.058 -0.002  0.33   0.529  0.55   0.177  0.182  0.306]
# ============================================================
#  EVALUATION: EXPERIMENT-15 Plot groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: lasso, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.255
#   RMSE : 3.98 kg
#
#  ✅ Test R² is positive (0.255)
#
# Regular CrossValidation:
#   Mean   : 0.078
#   Std    : 0.219
#   Scores : [-0.101  0.467  0.059 -0.153  0.118]
#  ✅ CV mean is positive (0.078)
#
# Grouped CrossValidation:
#   Big Creek_5          :   0.052  {GREEN_TICK}
#   Frenchman Caye_6     :   0.121  {GREEN_TICK}
#   Frenchman Caye_3     :   0.058  {GREEN_TICK}
#   Big Creek_3          :  -0.002  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.330  {GREEN_TICK}
#   Big Creek_2          :   0.529  {GREEN_TICK}
#   Drowned Caye_5       :   0.550  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.177  {GREEN_TICK}
#   Channel Caye_2       :   0.182  {GREEN_TICK}
#   Channel Caye_6       :   0.306  {GREEN_TICK}
#
#   Mean : 0.230
#   Std  : 0.184
#
#   ✅ Grouped CV mean above 0.15 (0.230)
#   ✅ Grouped CV std below 0.25 (0.184)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ✅ Grouped CV and test R² agree (gap: 0.024)
#   ✅ Train/test R² gap acceptable (gap: -0.212)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [16/72]
#
#  EXPERIMENT-16 Plot groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: elasticnet, Grouping? Yes, Grid? No, ALGO: ELASTICNET REGRESSION:
# Test R²     : 0.2589
# Test RMSE   : 3.97 kg
# Train R² (log scale): 0.2655
# Train R² (orig scale): 0.0492
# Train RMSE  : 18.11 kg
# Num rows    : 3100
# Num Features: 12
#
#  Cross-validation ---
# CV R² mean: 0.0292
# CV R² std : 0.1749
# CV scores : [-0.091  0.284  0.066 -0.226  0.113]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2287
# Grouped CV R² std : 0.1914
# Grouped CV scores : [-0.002  0.118  0.067 -0.005  0.335  0.533  0.555  0.179  0.197  0.309]
# ============================================================
#  EVALUATION: EXPERIMENT-16 Plot groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: elasticnet, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.259
#   RMSE : 3.97 kg
#
#  ✅ Test R² is positive (0.259)
#
# Regular CrossValidation:
#   Mean   : 0.029
#   Std    : 0.175
#   Scores : [-0.091  0.284  0.066 -0.226  0.113]
#  ✅ CV mean is positive (0.029)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.002  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :   0.118  {GREEN_TICK}
#   Frenchman Caye_3     :   0.067  {GREEN_TICK}
#   Big Creek_3          :  -0.005  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.335  {GREEN_TICK}
#   Big Creek_2          :   0.533  {GREEN_TICK}
#   Drowned Caye_5       :   0.555  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.179  {GREEN_TICK}
#   Channel Caye_2       :   0.197  {GREEN_TICK}
#   Channel Caye_6       :   0.309  {GREEN_TICK}
#
#   Mean : 0.229
#   Std  : 0.191
#
#   ✅ Grouped CV mean above 0.15 (0.229)
#   ✅ Grouped CV std below 0.25 (0.191)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ✅ Grouped CV and test R² agree (gap: 0.030)
#   ✅ Train/test R² gap acceptable (gap: -0.210)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [17/72]
#
#  EXPERIMENT-17 Plot groups, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: regular, Grouping? Yes, Grid? No, ALGO: LINEAR REGRESSION:
# Test R²     : 0.1596
# Test RMSE   : 4.23 kg
# Train R² (log scale): 0.2404
# Train R² (orig scale): -0.0034
# Train RMSE  : 18.60 kg
# Num rows    : 3100
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: -5.2533
# CV R² std : 10.0491
# CV scores : [ -0.572   0.384  -0.038  -0.703 -25.337]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.2496
# Grouped CV R² std : 1.0840
# Grouped CV scores : [-0.096 -3.455 -0.229 -0.064  0.195  0.341  0.326  0.04   0.158  0.288]
# ============================================================
#  EVALUATION: EXPERIMENT-17 Plot groups, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: regular, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.160
#   RMSE : 4.23 kg
#
#  ✅ Test R² is positive (0.160)
#
# Regular CrossValidation:
#   Mean   : -5.253
#   Std    : 10.049
#   Scores : [ -0.572   0.384  -0.038  -0.703 -25.337]
#  ❌ CV mean is negative (-5.253)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.096  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :  -3.455  {WARNING}  near-zero variance artifact
#   Frenchman Caye_3     :  -0.229  {WARNING}  near-zero variance artifact
#   Big Creek_3          :  -0.064  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.195  {GREEN_TICK}
#   Big Creek_2          :   0.341  {GREEN_TICK}
#   Drowned Caye_5       :   0.326  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.040  {GREEN_TICK}
#   Channel Caye_2       :   0.158  {GREEN_TICK}
#   Channel Caye_6       :   0.288  {GREEN_TICK}
#
#   Mean : -0.250
#   Std  : 1.084
#
#   ❌ Grouped CV mean below 0.15 (-0.250)
#   ⚠️  Grouped CV std above 0.25 (1.084) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.409 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.163)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {RED_CROSS} REJECTED
#
# [18/72]
#
#  EXPERIMENT-18 Plot groups, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: ridge, Grouping? Yes, Grid? No, ALGO: RIDGE REGRESSION:
# Test R²     : 0.2670
# Test RMSE   : 3.95 kg
# Train R² (log scale): 0.2246
# Train R² (orig scale): -0.0093
# Train RMSE  : 18.66 kg
# Num rows    : 3100
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: -5.1515
# CV R² std : 10.0817
# CV scores : [ -0.25    0.544  -0.05   -0.703 -25.299]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.0419
# Grouped CV R² std : 0.4199
# Grouped CV scores : [-0.124 -1.027 -0.165 -0.089  0.222  0.457  0.534  0.182  0.153  0.276]
# ============================================================
#  EVALUATION: EXPERIMENT-18 Plot groups, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: ridge, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.267
#   RMSE : 3.95 kg
#
#  ✅ Test R² is positive (0.267)
#
# Regular CrossValidation:
#   Mean   : -5.152
#   Std    : 10.082
#   Scores : [ -0.25    0.544  -0.05   -0.703 -25.299]
#  ❌ CV mean is negative (-5.152)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.124  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :  -1.027  {WARNING}  near-zero variance artifact
#   Frenchman Caye_3     :  -0.165  {WARNING}  near-zero variance artifact
#   Big Creek_3          :  -0.089  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.222  {GREEN_TICK}
#   Big Creek_2          :   0.457  {GREEN_TICK}
#   Drowned Caye_5       :   0.534  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.182  {GREEN_TICK}
#   Channel Caye_2       :   0.153  {GREEN_TICK}
#   Channel Caye_6       :   0.276  {GREEN_TICK}
#
#   Mean : 0.042
#   Std  : 0.420
#
#   ❌ Grouped CV mean below 0.15 (0.042)
#   ⚠️  Grouped CV std above 0.25 (0.420) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.225 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.276)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {RED_CROSS} REJECTED
#
# [19/72]
#
#  EXPERIMENT-19 Plot groups, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: lasso, Grouping? Yes, Grid? No, ALGO: LASSO REGRESSION:
# Test R²     : 0.1525
# Test RMSE   : 4.25 kg
# Train R² (log scale): 0.1404
# Train R² (orig scale): -0.0292
# Train RMSE  : 18.84 kg
# Num rows    : 3100
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: -0.2384
# CV R² std : 0.2295
# CV scores : [-0.106 -0.016 -0.16  -0.236 -0.675]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1086
# Grouped CV R² std : 0.1832
# Grouped CV scores : [-0.134  0.17  -0.185 -0.042  0.076  0.393  0.366  0.22   0.067  0.156]
# ============================================================
#  EVALUATION: EXPERIMENT-19 Plot groups, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: lasso, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.153
#   RMSE : 4.25 kg
#
#  ✅ Test R² is positive (0.153)
#
# Regular CrossValidation:
#   Mean   : -0.238
#   Std    : 0.229
#   Scores : [-0.106 -0.016 -0.16  -0.236 -0.675]
#  ❌ CV mean is negative (-0.238)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.134  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :   0.170  {GREEN_TICK}
#   Frenchman Caye_3     :  -0.185  {WARNING}  near-zero variance artifact
#   Big Creek_3          :  -0.042  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.076  {GREEN_TICK}
#   Big Creek_2          :   0.393  {GREEN_TICK}
#   Drowned Caye_5       :   0.366  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.220  {GREEN_TICK}
#   Channel Caye_2       :   0.067  {GREEN_TICK}
#   Channel Caye_6       :   0.156  {GREEN_TICK}
#
#   Mean : 0.109
#   Std  : 0.183
#
#   ❌ Grouped CV mean below 0.15 (0.109)
#   ✅ Grouped CV std below 0.25 (0.183)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ✅ Grouped CV and test R² agree (gap: 0.044)
#   ✅ Train/test R² gap acceptable (gap: -0.182)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {RED_CROSS} REJECTED
#
# [20/72]
#
#  EXPERIMENT-20 Plot groups, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: elasticnet, Grouping? Yes, Grid? No, ALGO: ELASTICNET REGRESSION:
# Test R²     : 0.1675
# Test RMSE   : 4.21 kg
# Train R² (log scale): 0.1449
# Train R² (orig scale): -0.0285
# Train RMSE  : 18.83 kg
# Num rows    : 3100
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: -0.4169
# CV R² std : 0.4383
# CV scores : [-0.164 -0.016 -0.101 -0.614 -1.19 ]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.0302
# Grouped CV R² std : 0.1331
# Grouped CV scores : [-0.135 -0.042 -0.211 -0.08   0.078  0.165  0.155  0.206  0.113  0.053]
# ============================================================
#  EVALUATION: EXPERIMENT-20 Plot groups, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: elasticnet, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.167
#   RMSE : 4.21 kg
#
#  ✅ Test R² is positive (0.167)
#
# Regular CrossValidation:
#   Mean   : -0.417
#   Std    : 0.438
#   Scores : [-0.164 -0.016 -0.101 -0.614 -1.19 ]
#  ❌ CV mean is negative (-0.417)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.135  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :  -0.042  {WARNING}  near-zero variance artifact
#   Frenchman Caye_3     :  -0.211  {WARNING}  near-zero variance artifact
#   Big Creek_3          :  -0.080  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.078  {GREEN_TICK}
#   Big Creek_2          :   0.165  {GREEN_TICK}
#   Drowned Caye_5       :   0.155  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.206  {GREEN_TICK}
#   Channel Caye_2       :   0.113  {GREEN_TICK}
#   Channel Caye_6       :   0.053  {GREEN_TICK}
#
#   Mean : 0.030
#   Std  : 0.133
#
#   ❌ Grouped CV mean below 0.15 (0.030)
#   ✅ Grouped CV std below 0.25 (0.133)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.137 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.196)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {RED_CROSS} REJECTED
#
# [21/72]
#
#  EXPERIMENT-21 Plot groups, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: regular, Grouping? Yes, Grid? No, ALGO: LINEAR REGRESSION:
# Test R²     : 0.2599
# Test RMSE   : 3.97 kg
# Train R² (log scale): 0.2968
# Train R² (orig scale): 0.0399
# Train RMSE  : 18.19 kg
# Num rows    : 3100
# Num Features: 12
#
#  Cross-validation ---
# CV R² mean: -3.4430
# CV R² std : 6.7354
# CV scores : [ -0.223   0.56    0.076  -0.741 -16.887]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.0528
# Grouped CV R² std : 0.2453
# Grouped CV scores : [-0.057 -0.486 -0.003  0.017  0.118 -0.176  0.432  0.223  0.193  0.267]
# ============================================================
#  EVALUATION: EXPERIMENT-21 Plot groups, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: regular, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.260
#   RMSE : 3.97 kg
#
#  ✅ Test R² is positive (0.260)
#
# Regular CrossValidation:
#   Mean   : -3.443
#   Std    : 6.735
#   Scores : [ -0.223   0.56    0.076  -0.741 -16.887]
#  ❌ CV mean is negative (-3.443)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.057  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :  -0.486  {WARNING}  near-zero variance artifact
#   Frenchman Caye_3     :  -0.003  {WARNING}  near-zero variance artifact
#   Big Creek_3          :   0.017  {GREEN_TICK}
#   Frenchman Caye_1     :   0.118  {GREEN_TICK}
#   Big Creek_2          :  -0.176  {WARNING}  near-zero variance artifact
#   Drowned Caye_5       :   0.432  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.223  {GREEN_TICK}
#   Channel Caye_2       :   0.193  {GREEN_TICK}
#   Channel Caye_6       :   0.267  {GREEN_TICK}
#
#   Mean : 0.053
#   Std  : 0.245
#
#   ❌ Grouped CV mean below 0.15 (0.053)
#   ✅ Grouped CV std below 0.25 (0.245)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.207 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.220)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {RED_CROSS} REJECTED
#
# [22/72]
#
#  EXPERIMENT-22 Plot groups, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: ridge, Grouping? Yes, Grid? No, ALGO: RIDGE REGRESSION:
# Test R²     : 0.2604
# Test RMSE   : 3.97 kg
# Train R² (log scale): 0.2841
# Train R² (orig scale): 0.0520
# Train RMSE  : 18.08 kg
# Num rows    : 3100
# Num Features: 12
#
#  Cross-validation ---
# CV R² mean: -0.2299
# CV R² std : 0.8087
# CV scores : [-0.091  0.61   0.106 -0.002 -1.773]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2343
# Grouped CV R² std : 0.1921
# Grouped CV scores : [-0.035  0.175  0.072 -0.006  0.323  0.539  0.549  0.19   0.22   0.316]
# ============================================================
#  EVALUATION: EXPERIMENT-22 Plot groups, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: ridge, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.260
#   RMSE : 3.97 kg
#
#  ✅ Test R² is positive (0.260)
#
# Regular CrossValidation:
#   Mean   : -0.230
#   Std    : 0.809
#   Scores : [-0.091  0.61   0.106 -0.002 -1.773]
#  ❌ CV mean is negative (-0.230)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.035  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :   0.175  {GREEN_TICK}
#   Frenchman Caye_3     :   0.072  {GREEN_TICK}
#   Big Creek_3          :  -0.006  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.323  {GREEN_TICK}
#   Big Creek_2          :   0.539  {GREEN_TICK}
#   Drowned Caye_5       :   0.549  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.190  {GREEN_TICK}
#   Channel Caye_2       :   0.220  {GREEN_TICK}
#   Channel Caye_6       :   0.316  {GREEN_TICK}
#
#   Mean : 0.234
#   Std  : 0.192
#
#   ✅ Grouped CV mean above 0.15 (0.234)
#   ✅ Grouped CV std below 0.25 (0.192)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ✅ Grouped CV and test R² agree (gap: 0.026)
#   ✅ Train/test R² gap acceptable (gap: -0.208)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE (grouped CV clean — regular CV unreliable)
#
# [23/72]
#
#  EXPERIMENT-23 Plot groups, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: lasso, Grouping? Yes, Grid? No, ALGO: LASSO REGRESSION:
# Test R²     : 0.2561
# Test RMSE   : 3.98 kg
# Train R² (log scale): 0.2568
# Train R² (orig scale): 0.0422
# Train RMSE  : 18.17 kg
# Num rows    : 3100
# Num Features: 12
#
#  Cross-validation ---
# CV R² mean: 0.1370
# CV R² std : 0.1890
# CV scores : [-0.052  0.488  0.055  0.168  0.026]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2175
# Grouped CV R² std : 0.1957
# Grouped CV scores : [-0.052  0.121  0.053 -0.002  0.326  0.526  0.545  0.173  0.18   0.305]
# ...
#
# Regular CrossValidation:
#   Mean   : -1.199
#   Std    : 2.733
#   Scores : [-0.053  0.533  0.109  0.067 -6.651]
#  ❌ CV mean is negative (-1.199)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.012  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :  -0.244  {WARNING}  near-zero variance artifact
#   Frenchman Caye_3     :   0.128  {GREEN_TICK}
#   Big Creek_3          :  -0.011  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.375  {GREEN_TICK}
#   Big Creek_2          :   0.419  {GREEN_TICK}
#   Drowned Caye_5       :   0.578  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.190  {GREEN_TICK}
#   Channel Caye_2       :   0.275  {GREEN_TICK}
#   Channel Caye_6       :   0.345  {GREEN_TICK}
#
#   Mean : 0.204
#   Std  : 0.232
#
#   ✅ Grouped CV mean above 0.15 (0.204)
#   ✅ Grouped CV std below 0.25 (0.232)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ✅ Grouped CV and test R² agree (gap: 0.027)
#   ✅ Train/test R² gap acceptable (gap: -0.164)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE (grouped CV clean — regular CV unreliable)
#
# [66/72]
#
#  EXPERIMENT-66 Plot groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2']., Model: ridge, Grouping? Yes, Grid? No, ALGO: RIDGE REGRESSION:
# Test R²     : 0.2462
# Test RMSE   : 4.01 kg
# Train R² (log scale): 0.2994
# Train R² (orig scale): 0.0610
# Train RMSE  : 17.99 kg
# Num rows    : 3100
# Num Features: 10
#
#  Cross-validation ---
# CV R² mean: -1.1649
# CV R² std : 2.7377
# CV scores : [-0.047  0.588  0.095  0.163 -6.624]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2631
# Grouped CV R² std : 0.1957
# Grouped CV scores : [0.    0.17  0.094 0.016 0.351 0.559 0.601 0.237 0.263 0.34 ]
# ============================================================
#  EVALUATION: EXPERIMENT-66 Plot groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2']., Model: ridge, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.246
#   RMSE : 4.01 kg
#
#  ✅ Test R² is positive (0.246)
#
# Regular CrossValidation:
#   Mean   : -1.165
#   Std    : 2.738
#   Scores : [-0.047  0.588  0.095  0.163 -6.624]
#  ❌ CV mean is negative (-1.165)
#
# Grouped CrossValidation:
#   Big Creek_5          :   0.000  {GREEN_TICK}
#   Frenchman Caye_6     :   0.170  {GREEN_TICK}
#   Frenchman Caye_3     :   0.094  {GREEN_TICK}
#   Big Creek_3          :   0.016  {GREEN_TICK}
#   Frenchman Caye_1     :   0.351  {GREEN_TICK}
#   Big Creek_2          :   0.559  {GREEN_TICK}
#   Drowned Caye_5       :   0.601  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.237  {GREEN_TICK}
#   Channel Caye_2       :   0.263  {GREEN_TICK}
#   Channel Caye_6       :   0.340  {GREEN_TICK}
#
#   Mean : 0.263
#   Std  : 0.196
#
#   ✅ Grouped CV mean above 0.15 (0.263)
#   ✅ Grouped CV std below 0.25 (0.196)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ✅ Grouped CV and test R² agree (gap: 0.017)
#   ✅ Train/test R² gap acceptable (gap: -0.185)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE (grouped CV clean — regular CV unreliable)
#
# [67/72]
#
#  EXPERIMENT-67 Plot groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2']., Model: lasso, Grouping? Yes, Grid? No, ALGO: LASSO REGRESSION:
# Test R²     : 0.1860
# Test RMSE   : 4.16 kg
# Train R² (log scale): 0.2817
# Train R² (orig scale): 0.0477
# Train RMSE  : 18.12 kg
# Num rows    : 3100
# Num Features: 10
#
#  Cross-validation ---
# CV R² mean: 0.1858
# CV R² std : 0.1738
# CV scores : [-0.032  0.498  0.113  0.158  0.193]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2663
# Grouped CV R² std : 0.1814
# Grouped CV scores : [0.05  0.191 0.096 0.031 0.359 0.56  0.574 0.234 0.263 0.304]
# ============================================================
#  EVALUATION: EXPERIMENT-67 Plot groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2']., Model: lasso, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.186
#   RMSE : 4.16 kg
#
#  ✅ Test R² is positive (0.186)
#
# Regular CrossValidation:
#   Mean   : 0.186
#   Std    : 0.174
#   Scores : [-0.032  0.498  0.113  0.158  0.193]
#  ✅ CV mean is positive (0.186)
#
# Grouped CrossValidation:
#   Big Creek_5          :   0.050  {GREEN_TICK}
#   Frenchman Caye_6     :   0.191  {GREEN_TICK}
#   Frenchman Caye_3     :   0.096  {GREEN_TICK}
#   Big Creek_3          :   0.031  {GREEN_TICK}
#   Frenchman Caye_1     :   0.359  {GREEN_TICK}
#   Big Creek_2          :   0.560  {GREEN_TICK}
#   Drowned Caye_5       :   0.574  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.234  {GREEN_TICK}
#   Channel Caye_2       :   0.263  {GREEN_TICK}
#   Channel Caye_6       :   0.304  {GREEN_TICK}
#
#   Mean : 0.266
#   Std  : 0.181
#
#   ✅ Grouped CV mean above 0.15 (0.266)
#   ✅ Grouped CV std below 0.25 (0.181)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.080 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.138)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {WARNING}  MARGINAL — positive metrics but concerns
#
# [68/72]
#
#  EXPERIMENT-68 Plot groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2']., Model: elasticnet, Grouping? Yes, Grid? No, ALGO: ELASTICNET REGRESSION:
# Test R²     : 0.2110
# Test RMSE   : 4.10 kg
# Train R² (log scale): 0.2920
# Train R² (orig scale): 0.0515
# Train RMSE  : 18.09 kg
# Num rows    : 3100
# Num Features: 10
#
#  Cross-validation ---
# CV R² mean: 0.2093
# CV R² std : 0.2006
# CV scores : [-0.027  0.577  0.122  0.157  0.218]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2701
# Grouped CV R² std : 0.1777
# Grouped CV scores : [0.047 0.233 0.105 0.036 0.338 0.544 0.585 0.245 0.247 0.32 ]
# ============================================================
#  EVALUATION: EXPERIMENT-68 Plot groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2']., Model: elasticnet, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.211
#   RMSE : 4.10 kg
#
#  ✅ Test R² is positive (0.211)
#
# Regular CrossValidation:
#   Mean   : 0.209
#   Std    : 0.201
#   Scores : [-0.027  0.577  0.122  0.157  0.218]
#  ✅ CV mean is positive (0.209)
#
# Grouped CrossValidation:
#   Big Creek_5          :   0.047  {GREEN_TICK}
#   Frenchman Caye_6     :   0.233  {GREEN_TICK}
#   Frenchman Caye_3     :   0.105  {GREEN_TICK}
#   Big Creek_3          :   0.036  {GREEN_TICK}
#   Frenchman Caye_1     :   0.338  {GREEN_TICK}
#   Big Creek_2          :   0.544  {GREEN_TICK}
#   Drowned Caye_5       :   0.585  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.245  {GREEN_TICK}
#   Channel Caye_2       :   0.247  {GREEN_TICK}
#   Channel Caye_6       :   0.320  {GREEN_TICK}
#
#   Mean : 0.270
#   Std  : 0.178
#
#   ✅ Grouped CV mean above 0.15 (0.270)
#   ✅ Grouped CV std below 0.25 (0.178)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.059 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.160)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {WARNING}  MARGINAL — positive metrics but concerns
#
# [69/72]
#
#  EXPERIMENT-69 Plot groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: regular, Grouping? Yes, Grid? No, ALGO: LINEAR REGRESSION:
# Test R²     : -927383.6309
# Test RMSE   : 4444.78 kg
# Train R² (log scale): 0.3171
# Train R² (orig scale): 0.0633
# Train RMSE  : 17.97 kg
# Num rows    : 3100
# Num Features: 13
#
#  Cross-validation ---
# CV R² mean: -2.5468
# CV R² std : 3.7697
# CV scores : [-0.067  0.294  0.027 -3.409 -9.58 ]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.0829
# Grouped CV R² std : 0.4369
# Grouped CV scores : [-0.025 -1.141  0.122 -0.004  0.273  0.294  0.553  0.203  0.271  0.283]
# ============================================================
#  EVALUATION: EXPERIMENT-69 Plot groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: regular, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : -927383.631
#   RMSE : 4444.78 kg
#
#  ❌ Test R² is negative (-927383.631)
#
# Regular CrossValidation:
#   Mean   : -2.547
#   Std    : 3.770
#   Scores : [-0.067  0.294  0.027 -3.409 -9.58 ]
#  ❌ CV mean is negative (-2.547)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.025  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :  -1.141  {WARNING}  near-zero variance artifact
#   Frenchman Caye_3     :   0.122  {GREEN_TICK}
#   Big Creek_3          :  -0.004  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.273  {GREEN_TICK}
#   Big Creek_2          :   0.294  {GREEN_TICK}
#   Drowned Caye_5       :   0.553  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.203  {GREEN_TICK}
#   Channel Caye_2       :   0.271  {GREEN_TICK}
#   Channel Caye_6       :   0.283  {GREEN_TICK}
#
#   Mean : 0.083
#   Std  : 0.437
#
#   ❌ Grouped CV mean below 0.15 (0.083)
#   ⚠️  Grouped CV std above 0.25 (0.437) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 927383.714 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 927383.694 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: {RED_CROSS} REJECTED
#
# [70/72]
#
#  EXPERIMENT-70 Plot groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: ridge, Grouping? Yes, Grid? No, ALGO: RIDGE REGRESSION:
# Test R²     : 0.2877
# Test RMSE   : 3.90 kg
# Train R² (log scale): 0.3023
# Train R² (orig scale): 0.0624
# Train RMSE  : 17.98 kg
# Num rows    : 3100
# Num Features: 13
#
#  Cross-validation ---
# CV R² mean: -1.8002
# CV R² std : 4.0190
# CV scores : [-0.046  0.612  0.114  0.145 -9.826]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2656
# Grouped CV R² std : 0.1960
# Grouped CV scores : [-0.001  0.195  0.096  0.01   0.352  0.568  0.591  0.226  0.265  0.353]
# ============================================================
#  EVALUATION: EXPERIMENT-70 Plot groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: ridge, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.288
#   RMSE : 3.90 kg
#
#  ✅ Test R² is positive (0.288)
#
# Regular CrossValidation:
#   Mean   : -1.800
#   Std    : 4.019
#   Scores : [-0.046  0.612  0.114  0.145 -9.826]
#  ❌ CV mean is negative (-1.800)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.001  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :   0.195  {GREEN_TICK}
#   Frenchman Caye_3     :   0.096  {GREEN_TICK}
#   Big Creek_3          :   0.010  {GREEN_TICK}
#   Frenchman Caye_1     :   0.352  {GREEN_TICK}
#   Big Creek_2          :   0.568  {GREEN_TICK}
#   Drowned Caye_5       :   0.591  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.226  {GREEN_TICK}
#   Channel Caye_2       :   0.265  {GREEN_TICK}
#   Channel Caye_6       :   0.353  {GREEN_TICK}
#
#   Mean : 0.266
#   Std  : 0.196
#
#   ✅ Grouped CV mean above 0.15 (0.266)
#   ✅ Grouped CV std below 0.25 (0.196)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ✅ Grouped CV and test R² agree (gap: 0.022)
#   ✅ Train/test R² gap acceptable (gap: -0.225)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE (grouped CV clean — regular CV unreliable)
#
# [71/72]
#
#  EXPERIMENT-71 Plot groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: lasso, Grouping? Yes, Grid? No, ALGO: LASSO REGRESSION:
# Test R²     : 0.2556
# Test RMSE   : 3.98 kg
# Train R² (log scale): 0.2854
# Train R² (orig scale): 0.0440
# Train RMSE  : 18.16 kg
# Num rows    : 3100
# Num Features: 13
#
#  Cross-validation ---
# CV R² mean: 0.1802
# CV R² std : 0.1747
# CV scores : [-0.043  0.495  0.125  0.155  0.17 ]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2677
# Grouped CV R² std : 0.1862
# Grouped CV scores : [0.063 0.192 0.089 0.021 0.344 0.573 0.586 0.215 0.265 0.329]
# ============================================================
#  EVALUATION: EXPERIMENT-71 Plot groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: lasso, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.256
#   RMSE : 3.98 kg
#
#  ✅ Test R² is positive (0.256)
#
# Regular CrossValidation:
#   Mean   : 0.180
#   Std    : 0.175
#   Scores : [-0.043  0.495  0.125  0.155  0.17 ]
#  ✅ CV mean is positive (0.180)
#
# Grouped CrossValidation:
#   Big Creek_5          :   0.063  {GREEN_TICK}
#   Frenchman Caye_6     :   0.192  {GREEN_TICK}
#   Frenchman Caye_3     :   0.089  {GREEN_TICK}
#   Big Creek_3          :   0.021  {GREEN_TICK}
#   Frenchman Caye_1     :   0.344  {GREEN_TICK}
#   Big Creek_2          :   0.573  {GREEN_TICK}
#   Drowned Caye_5       :   0.586  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.215  {GREEN_TICK}
#   Channel Caye_2       :   0.265  {GREEN_TICK}
#   Channel Caye_6       :   0.329  {GREEN_TICK}
#
#   Mean : 0.268
#   Std  : 0.186
#
#   ✅ Grouped CV mean above 0.15 (0.268)
#   ✅ Grouped CV std below 0.25 (0.186)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ✅ Grouped CV and test R² agree (gap: 0.012)
#   ✅ Train/test R² gap acceptable (gap: -0.212)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [72/72]
#
#  EXPERIMENT-72 Plot groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: elasticnet, Grouping? Yes, Grid? No, ALGO: ELASTICNET REGRESSION:
# Test R²     : 0.2768
# Test RMSE   : 3.93 kg
# Train R² (log scale): 0.2996
# Train R² (orig scale): 0.0583
# Train RMSE  : 18.02 kg
# Num rows    : 3100
# Num Features: 13
#
#  Cross-validation ---
# CV R² mean: 0.1548
# CV R² std : 0.1083
# CV scores : [-0.033  0.3    0.137  0.179  0.191]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2741
# Grouped CV R² std : 0.1871
# Grouped CV scores : [0.053 0.212 0.104 0.022 0.349 0.563 0.604 0.235 0.26  0.34 ]
# ============================================================
#  EVALUATION: EXPERIMENT-72 Plot groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: elasticnet, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.277
#   RMSE : 3.93 kg
#
#  ✅ Test R² is positive (0.277)
#
# Regular CrossValidation:
#   Mean   : 0.155
#   Std    : 0.108
#   Scores : [-0.033  0.3    0.137  0.179  0.191]
#  ✅ CV mean is positive (0.155)
#
# Grouped CrossValidation:
#   Big Creek_5          :   0.053  {GREEN_TICK}
#   Frenchman Caye_6     :   0.212  {GREEN_TICK}
#   Frenchman Caye_3     :   0.104  {GREEN_TICK}
#   Big Creek_3          :   0.022  {GREEN_TICK}
#   Frenchman Caye_1     :   0.349  {GREEN_TICK}
#   Big Creek_2          :   0.563  {GREEN_TICK}
#   Drowned Caye_5       :   0.604  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.235  {GREEN_TICK}
#   Channel Caye_2       :   0.260  {GREEN_TICK}
#   Channel Caye_6       :   0.340  {GREEN_TICK}
#
#   Mean : 0.274
#   Std  : 0.187
#
#   ✅ Grouped CV mean above 0.15 (0.274)
#   ✅ Grouped CV std below 0.25 (0.187)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ✅ Grouped CV and test R² agree (gap: 0.003)
#   ✅ Train/test R² gap acceptable (gap: -0.219)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# Completed: 72/72 experiments

# %%
tabulate_results(lin_belige_groups, acceptable_only=True)
# Out:
# Showing 49 acceptable experiments
# <style type="text/css">
# #T_e5889_row0_col7, #T_e5889_row3_col1, #T_e5889_row3_col2, #T_e5889_row12_col9, #T_e5889_row48_col8 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e5889">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e5889_level0_col0" class="col_heading level0 col0" >Experiment</th>
#       <th id="T_e5889_level0_col1" class="col_heading level0 col1" >Test R²</th>
#       <th id="T_e5889_level0_col2" class="col_heading level0 col2" >Test RMSE</th>
#       <th id="T_e5889_level0_col3" class="col_heading level0 col3" >Train R²</th>
#       <th id="T_e5889_level0_col4" class="col_heading level0 col4" >Train RMSE</th>
#       <th id="T_e5889_level0_col5" class="col_heading level0 col5" >CV R² Mean</th>
#       <th id="T_e5889_level0_col6" class="col_heading level0 col6" >CV R² Std</th>
#       <th id="T_e5889_level0_col7" class="col_heading level0 col7" >Group CV R² Mean</th>
#       <th id="T_e5889_level0_col8" class="col_heading level0 col8" >Group CV R² Std</th>
#       <th id="T_e5889_level0_col9" class="col_heading level0 col9" >CV-Test Gap</th>
#       <th id="T_e5889_level0_col10" class="col_heading level0 col10" >-ve Folds</th>
#       <th id="T_e5889_level0_col11" class="col_heading level0 col11" >verdict</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e5889_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e5889_row0_col0" class="data row0 col0" >EXPERIMENT-51 Plot groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1']., Model: lasso, Grouping? Yes, Grid? No</td>
#       <td id="T_e5889_row0_col1" class="data row0 col1" >0.2264</td>
#       <td id="T_e5889_row0_col2" class="data row0 col2" >4.06</td>
#       <td id="T_e5889_row0_col3" class="data row0 col3" >0.0577</td>
#       <td id="T_e5889_row0_col4" class="data row0 col4" >18.03</td>
#       <td id="T_e5889_row0_col5" class="data row0 col5" >0.2099</td>
#       <td id="T_e5889_row0_col6" class="data row0 col6" >0.2179</td>
#       <td id="T_e5889_row0_col7" class="data row0 col7" >0.2785</td>
#       <td id="T_e5889_row0_col8" class="data row0 col8" >0.1877</td>
#       <td id="T_e5889_row0_col9" class="data row0 col9" >0.052</td>
#       <td id="T_e5889_row0_col10" class="data row0 col10" >none</td>
#       <td id="T_e5889_row0_col11" class="data row0 col11" >⚠️  MARGINAL — positive metrics but concerns</td>
#     </tr>
#     <tr>
#       <th id="T_e5889_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e5889_row1_col0" class="data row1 col0" >EXPERIMENT-56 Plot groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: elasticnet, Grouping? Yes, Grid? No</td>
#       <td id="T_e5889_row1_col1" class="data row1 col1" >0.2768</td>
#       <td id="T_e5889_row1_col2" class="data row1 col2" >3.93</td>
#       <td id="T_e5889_row1_col3" class="data row1 col3" >0.0583</td>
#       <td id="T_e5889_row1_col4" class="data row1 col4" >18.02</td>
#       <td id="T_e5889_row1_col5" class="data row1 col5" >0.2136</td>
#       <td id="T_e5889_row1_col6" class="data row1 col6" >0.2164</td>
#       <td id="T_e5889_row1_col7" class="data row1 col7" >0.2764</td>
#       <td id="T_e5889_row1_col8" class="data row1 col8" >0.1878</td>
#       <td id="T_e5889_row1_col9" class="data row1 col9" >0.0004</td>
#       <td id="T_e5889_row1_col10" class="data row1 col10" >none</td>
#       <td id="T_e5889_row1_col11" class="data row1 col11" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_e5889_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e5889_row2_col0" class="data row2 col0" >EXPERIMENT-72 Plot groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: elasticnet, Grouping? Yes, Grid? No</td>
#       <td id="T_e5889_row2_col1" class="data row2 col1" >0.2768</td>
#       <td id="T_e5889_row2_col2" class="data row2 col2" >3.93</td>
#       <td id="T_e5889_row2_col3" class="data row2 col3" >0.0583</td>
#       <td id="T_e5889_row2_col4" class="data row2 col4" >18.02</td>
#       <td id="T_e5889_row2_col5" class="data row2 col5" >0.1548</td>
#       <td id="T_e5889_row2_col6" class="data row2 col6" >0.1083</td>
#       <td id="T_e5889_row2_col7" class="data row2 col7" >0.2741</td>
#       <td id="T_e5889_row2_col8" class="data row2 col8" >0.1871</td>
#       <td id="T_e5889_row2_col9" class="data row2 col9" >0.0027</td>
#       <td id="T_e5889_row2_col10" class="data row2 col10" >none</td>
#       <td id="T_e5889_row2_col11" class="data row2 col11" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_e5889_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e5889_row3_col0" class="data row3 col0" >EXPERIMENT-55 Plot groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: lasso, Grouping? Yes, Grid? No</td>
#       <td id="T_e5889_row3_col1" class="data row3 col1" >0.2932</td>
#       <td id="T_e5889_row3_col2" class="data row3 col2" >3.88</td>
#       <td id="T_e5889_row3_col3" class="data row3 col3" >0.0605</td>
#       <td id="T_e5889_row3_col4" class="data row3 col4" >18</td>
#       <td id="T_e5889_row3_col5" class="data row3 col5" >0.2034</td>
#       <td id="T_e5889_row3_col6" class="data row3 col6" >0.2173</td>
#       <td id="T_e5889_row3_col7" class="data row3 col7" >0.2734</td>
#       <td id="T_e5889_row3_col8" class="data row3 col8" >0.1899</td>
#       <td id="T_e5889_row3_col9" class="data row3 col9" >0.0198</td>
#       <td id="T_e5889_row3_col10" class="data row3 col10" >none</td>
#       <td id="T_e5889_row3_col11" class="data row3 col11" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_e5889_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e5889_row4_col0" class="data row4 col0" >EXPERIMENT-52 Plot groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1']., Model: elasticnet, Grouping? Yes, Grid? No</td>
#       <td id="T_e5889_row4_col1" class="data row4 col1" >0.2284</td>
#       <td id="T_e5889_row4_col2" class="data row4 col2" >4.05</td>
#       <td id="T_e5889_row4_col3" class="data row4 col3" >0.0537</td>
#       <td id="T_e5889_row4_col4" class="data row4 col4" >18.06</td>
#       <td id="T_e5889_row4_col5" class="data row4 col5" >-0.2836</td>
#       <td id="T_e5889_row4_col6" class="data row4 col6" >1.008</td>
#       <td id="T_e5889_row4_col7" class="data row4 col7" >0.2729</td>
#       <td id="T_e5889_row4_col8" class="data row4 col8" >0.1831</td>
#       <td id="T_e5889_row4_col9" class="data row4 col9" >0.0444</td>
#       <td id="T_e5889_row4_col10" class="data row4 col10" >none</td>
#       <td id="T_e5889_row4_col11" class="data row4 col11" >VERDICT: ✅ ACCEPTABLE (Reg CV unstable)</td>
#     </tr>
#     <tr>
#       <th id="T_e5889_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e5889_row5_col0" class="data row5 col0" >EXPERIMENT-68 Plot groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2']., Model: elasticnet, Grouping? Yes, Grid? No</td>
#       <td id="T_e5889_row5_col1" class="data row5 col1" >0.211</td>
#       <td id="T_e5889_row5_col2" class="data row5 col2" >4.1</td>
#       <td id="T_e5889_row5_col3" class="data row5 col3" >0.0515</td>
#       <td id="T_e5889_row5_col4" class="data row5 col4" >18.09</td>
#       <td id="T_e5889_row5_col5" class="data row5 col5" >0.2093</td>
#       <td id="T_e5889_row5_col6" class="data row5 col6" >0.2006</td>
#       <td id="T_e5889_row5_col7" class="data row5 col7" >0.2701</td>
#       <td id="T_e5889_row5_col8" class="data row5 col8" >0.1777</td>
#       <td id="T_e5889_row5_col9" class="data row5 col9" >0.0591</td>
#       <td id="T_e5889_row5_col10" class="data row5 col10" >none</td>
#       <td id="T_e5889_row5_col11" class="data row5 col11" >⚠️  MARGINAL — positive metrics but concerns</td>
#     </tr>
#     <tr>
#       <th id="T_e5889_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e5889_row6_col0" class="d

# %% [markdown]
# ### BELIGE DATA. NO GROUPS. ALL ROWS. RANDOM FOREST

# %%
# %run Model_functions.ipynb

rf_belige_no_grps = {}

run_experiment(X_belige, y_belige,
               is_groups=False,
               group_info=grp_belige,
               features_list=gen_features_list,
               experiments=rf_belige_no_grps,
               model_type="rf", is_grid=False,
               is_stratified=is_stratified_g,
               global_experiment_list=global_experiment_list)
# Out:
# chmod: /Users/kosaraju_b/.local/share/jupyter/history.sqlite: No such file or directory
#
# [1/18]
#
#  RANDOM FOREST: EXPERIMENT-1 No groups, Features: ['height']., Model: rf, Grouping? No, Grid? No
# Test R²     : 0.1327
# Test RMSE   : 15.70 kg
# Train R² (log scale): 0.4042
# Train R² (orig scale): 0.1865
# Train RMSE  : 15.09 kg
# Num rows    : 3104
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: 0.3710
# CV R² std : 0.0310
# CV scores : [0.427 0.343 0.344 0.363 0.378]
# ============================================================
#  EVALUATION: EXPERIMENT-1 No groups, Features: ['height']., Model: rf, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.133
#   RMSE : 15.70 kg
#
#  ✅ Test R² is positive (0.133)
#
# Regular CrossValidation:
#   Mean   : 0.371
#   Std    : 0.031
#   Scores : [0.427 0.343 0.344 0.363 0.378]
#  ✅ CV mean is positive (0.371)
#   ✅ Train/test R² gap acceptable (gap: 0.054)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# Top 10 feature importances:
#   height                                        1.0000  ==================================================
#
# [2/18]
#
#  RANDOM FOREST: EXPERIMENT-2 No groups, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? No, Grid? No
# Test R²     : 0.1327
# Test RMSE   : 15.70 kg
# Train R² (log scale): 0.4042
# Train R² (orig scale): 0.1865
# Train RMSE  : 15.09 kg
# Num rows    : 3104
# Num Features: 4
#
#  Cross-validation ---
# CV R² mean: 0.3711
# CV R² std : 0.0310
# CV scores : [0.427 0.343 0.345 0.363 0.378]
# ============================================================
#  EVALUATION: EXPERIMENT-2 No groups, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.133
#   RMSE : 15.70 kg
#
#  ✅ Test R² is positive (0.133)
#
# Regular CrossValidation:
#   Mean   : 0.371
#   Std    : 0.031
#   Scores : [0.427 0.343 0.345 0.363 0.378]
#  ✅ CV mean is positive (0.371)
#   ✅ Train/test R² gap acceptable (gap: 0.054)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# Top 10 feature importances:
#   height_x_EVI                                  0.3066  ===============
#   height_x_NDRE1                                0.3045  ===============
#   height_x_NIR                                  0.2599  ============
#   height                                        0.1290  ======
#
# [3/18]
#
#  RANDOM FOREST: EXPERIMENT-3 No groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2']., Model: rf, Grouping? No, Grid? No
# Test R²     : 0.1329
# Test RMSE   : 15.70 kg
# Train R² (log scale): 0.4042
# Train R² (orig scale): 0.1864
# Train RMSE  : 15.09 kg
# Num rows    : 3104
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: 0.3712
# CV R² std : 0.0310
# CV scores : [0.427 0.343 0.345 0.363 0.379]
# ============================================================
#  EVALUATION: EXPERIMENT-3 No groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2']., Model: rf, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.133
#   RMSE : 15.70 kg
#
#  ✅ Test R² is positive (0.133)
#
# Regular CrossValidation:
#   Mean   : 0.371
#   Std    : 0.031
#   Scores : [0.427 0.343 0.345 0.363 0.379]
#  ✅ CV mean is positive (0.371)
#   ✅ Train/test R² gap acceptable (gap: 0.053)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# Top 10 feature importances:
#   NIR                                           0.1764  ========
#   RE2                                           0.1652  ========
#   RE3                                           0.1267  ======
#   RE1                                           0.1098  =====
#   Green                                         0.1069  =====
#   SWIR1                                         0.1056  =====
#   Red                                           0.0964  ====
#   SWIR2                                         0.0572  ==
#   Blue                                          0.0558  ==
#
# [4/18]
#
#  RANDOM FOREST: EXPERIMENT-4 No groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? No, Grid? No
# Test R²     : 0.1330
# Test RMSE   : 15.70 kg
# Train R² (log scale): 0.4042
# Train R² (orig scale): 0.1865
# Train RMSE  : 15.09 kg
# Num rows    : 3104
# Num Features: 12
#
#  Cross-validation ---
# CV R² mean: 0.3716
# CV R² std : 0.0307
# CV scores : [0.427 0.343 0.346 0.363 0.379]
# ============================================================
#  EVALUATION: EXPERIMENT-4 No groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.133
#   RMSE : 15.70 kg
#
#  ✅ Test R² is positive (0.133)
#
# Regular CrossValidation:
#   Mean   : 0.372
#   Std    : 0.031
#   Scores : [0.427 0.343 0.346 0.363 0.379]
#  ✅ CV mean is positive (0.372)
#   ✅ Train/test R² gap acceptable (gap: 0.053)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# Top 10 feature importances:
#   height_x_NDRE1                                0.1851  =========
#   height_x_EVI                                  0.1764  ========
#   height_x_NIR                                  0.1681  ========
#   RE3                                           0.0828  ====
#   NIR                                           0.0804  ====
#   RE2                                           0.0681  ===
#   Red                                           0.0516  ==
#   SWIR1                                         0.0482  ==
#   RE1                                           0.0388  =
#   SWIR2                                         0.0353  =
#
# [5/18]
#
#  RANDOM FOREST: EXPERIMENT-5 No groups, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: rf, Grouping? No, Grid? No
# Test R²     : 0.1325
# Test RMSE   : 15.70 kg
# Train R² (log scale): 0.4042
# Train R² (orig scale): 0.1867
# Train RMSE  : 15.09 kg
# Num rows    : 3104
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: 0.3717
# CV R² std : 0.0307
# CV scores : [0.427 0.343 0.347 0.363 0.379]
# ============================================================
#  EVALUATION: EXPERIMENT-5 No groups, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: rf, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.133
#   RMSE : 15.70 kg
#
#  ✅ Test R² is positive (0.133)
#
# Regular CrossValidation:
#   Mean   : 0.372
#   Std    : 0.031
#   Scores : [0.427 0.343 0.347 0.363 0.379]
#  ✅ CV mean is positive (0.372)
#   ✅ Train/test R² gap acceptable (gap: 0.054)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# Top 10 feature importances:
#   EVI                                           0.2304  ===========
#   NDRE1                                         0.2220  ===========
#   CIrededge                                     0.1542  =======
#   NDVI                                          0.1160  =====
#   NDRE2                                         0.0792  ===
#   NBR                                           0.0782  ===
#   NDRE3                                         0.0719  ===
#   MNDWI                                         0.0481  ==
#   CLOUD_COVERAGE                                0.0000
#
# [6/18]
#
#  RANDOM FOREST: EXPERIMENT-6 No groups, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? No, Grid? No
# Test R²     : 0.1329
# Test RMSE   : 15.70 kg
# Train R² (log scale): 0.4042
# Train R² (orig scale): 0.1865
# Train RMSE  : 15.09 kg
# Num rows    : 3104
# Num Features: 12
#
#  Cross-validation ---
# CV R² mean: 0.3717
# CV R² std : 0.0307
# CV scores : [0.427 0.343 0.346 0.363 0.379]
# ============================================================
#  EVALUATION: EXPERIMENT-6 No groups, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.133
#   RMSE : 15.70 kg
#
#  ✅ Test R² is positive (0.133)
#
# Regular CrossValidation:
#   Mean   : 0.372
#   Std    : 0.031
#   Scores : [0.427 0.343 0.346 0.363 0.379]
#  ✅ CV mean is positive (0.372)
#   ✅ Train/test R² gap acceptable (gap: 0.054)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# Top 10 feature importances:
#   height_x_NDRE1                                0.1816  =========
#   height_x_EVI                                  0.1774  ========
#   height_x_NIR                                  0.1700  ========
#   EVI                                           0.0993  ====
#   NDRE1                                         0.0905  ====
#   CIrededge                                     0.0660  ===
#   NDVI                                          0.0657  ===
#   NDRE2                                         0.0473  ==
#   NBR                                           0.0392  =
#   NDRE3                                         0.0345  =
#
# [7/18]
#
#  RANDOM FOREST: EXPERIMENT-7 No groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: rf, Grouping? No, Grid? No
# Test R²     : 0.1331
# Test RMSE   : 15.70 kg
# Train R² (log scale): 0.4042
# Train R² (orig scale): 0.1864
# Train RMSE  : 15.09 kg
# Num rows    : 3104
# Num Features: 18
#
#  Cross-validation ---
# CV R² mean: 0.3716
# CV R² std : 0.0307
# CV scores : [0.427 0.343 0.346 0.363 0.379]
# ============================================================
#  EVALUATION: EXPERIMENT-7 No groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: rf, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.133
#   RMSE : 15.70 kg
#
#  ✅ Test R² is positive (0.133)
#
# Regular CrossValidation:
#   Mean   : 0.372
#   Std    : 0.031
#   Scores : [0.427 0.343 0.346 0.363 0.379]
#  ✅ CV mean is positive (0.372)
#   ✅ Train/test R² gap acceptable (gap: 0.053)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# Top 10 feature importances:
#   EVI                                           0.1257  ======
#   NDRE1                                         0.1247  ======
#   CIrededge                                     0.0952  ====
#   NIR                                           0.0908  ====
#   RE2                                           0.0837  ====
#   RE3                                           0.0798  ===
#   SWIR1                                         0.0526  ==
#   NDVI                                          0.0510  ==
#   Red                                           0.0471  ==
#   NBR                                           0.0410  ==
#
# [8/18]
#
#  RANDOM FOREST: EXPERIMENT-8 No groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? No, Grid? No
# Test R²     : 0.1327
# Test RMSE   : 15.70 kg
# Train R² (log scale): 0.4042
# Train R² (orig scale): 0.1867
# Train RMSE  : 15.09 kg
# Num rows    : 3104
# Num Features: 21
#
#  Cross-validation ---
# CV R² mean: 0.3716
# CV R² std : 0.0307
# CV scores : [0.427 0.343 0.346 0.363 0.379]
# ============================================================
#  EVALUATION: EXPERIMENT-8 No groups, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.133
#   RMSE : 15.70 kg
#
#  ✅ Test R² is positive (0.133)
#
# Regular CrossValidation:
#   Mean   : 0.372
#   Std    : 0.031
#   Scores : [0.427 0.343 0.346 0.363 0.379]
#  ✅ CV mean is positive (0.372)
#   ✅ Train/test R² gap acceptable (gap: 0.054)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# Top 10 feature importances:
#   height_x_NDRE1                                0.1485  =======
#   height_x_EVI                                  0.1287  ======
#   height_x_NIR                                  0.1137  =====
#   EVI                                           0.0771  ===
#   NIR                                           0.0622  ===
#   NDRE1                                         0.0612  ===
#   RE2                                           0.0526  ==
#   RE3                                           0.0501  ==
#   CIrededge                                     0.0475  ==
#   Red                                           0.0329  =
#
# [9/18]
#
#  RANDOM FOREST: EXPERIMENT-9 No groups, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: rf, Grouping? No, Grid? No
# Test R²     : 0.1330
# Test RMSE   : 15.70 kg
# Train R² (log scale): 0.4042
# Train R² (orig scale): 0.1865
# Train RMSE  : 15.09 kg
# Num rows    : 3104
# Num Features: 19
#
#  Cross-validation ---
# CV R² mean: 0.3716
# CV R² std : 0.0307
# CV scores : [0.427 0.343 0.346 0.363 0.379]
# ============================================================
#  EVALUATION: EXPERIMENT-9 No groups, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: rf, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.133
#   RMSE : 15.70 kg
#
#  ✅ Test R² is positive (0.133)
#
# Regular CrossValidation:
#   Mean   : 0.372
#   Std    : 0.031
#   Scores : [0.427 0.343 0.346 0.363 0.379]
#  ✅ CV mean is positive (0.372)
#   ✅ Train/test R² gap acceptable (gap: 0.053)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# Top 10 feature importances:
#   height                                        0.1802  =========
#   EVI                                           0.1115  =====
#   NDRE1                                         0.0972  ====
#   NIR                                           0.0797  ===
#   CIrededge                                     0.0674  ===
#   RE3                                           0.0639  ===
#   RE2                                           0.0614  ===
#   NDVI                                          0.0430  ==
#   SWIR1                                         0.0376  =
#   Red                                           0.0376  =
#
# [10/18]
#
#  RANDOM FOREST: EXPERIMENT-10 No groups, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? No, Grid? No
# Test R²     : 0.1329
# Test RMSE   : 15.70 kg
# Train R² (log scale): 0.4042
# Train R² (orig scale): 0.1866
# Train RMSE  : 15.09 kg
# Num rows    : 3104
# Num Features: 22
#
#  Cross-validation ---
# CV R² mean: 0.3716
# CV R² std : 0.0307
# CV scores : [0.427 0.343 0.347 0.363 0.379]
# ============================================================
#  EVALUATION: EXPERIMENT-10 No groups, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.133
#   RMSE : 15.70 kg
#
#  ✅ Test R² is positive (0.133)
#
# Regular CrossValidation:
#   Mean   : 0.372
#   Std    : 0.031
#   Scores : [0.427 0.343 0.347 0.363 0.379]
#  ✅ CV mean is positive (0.372)
#   ✅ Train/test R² gap acceptable (gap: 0.054)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# Top 10 feature importances:
#   height_x_NDRE1                                0.1383  ======
#   height_x_EVI                                  0.1227  ======
#   height_x_NIR                                  0.1151  =====
#   height                                        0.0812  ====
#   EVI                                           0.0652  ===
#   NDRE1                                         0.0563  ==
#   NIR                                           0.0534  ==
#   RE2                                           0.0511  ==
#   CIrededge                                     0.0418  ==
#   RE3                                           0.0359  =
#
# [11/18]
#
#  RANDOM FOREST: EXPERIMENT-11 No groups, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1']., Model: rf, Grouping? No, Grid? No
# Test R²     : 0.1330
# Test RMSE   : 15.70 kg
# Train R² (log scale): 0.4042
# Train R² (orig scale): 0.1865
# Train RMSE  : 15.09 kg
# Num rows    : 3104
# Num Features: 5
#
#  Cross-validation ---
# CV R² mean: 0.3716
# CV R² std : 0.0308
# CV scores : [0.427 0.343 0.346 0.363 0.379]
# ============================================================
#  EVALUATION: EXPERIMENT-11 No groups, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1']., Model: rf, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.133
#   RMSE : 15.70 kg
#
#  ✅ Test R² is positive (0.133)
#
# Regular CrossValidation:
#   Mean   : 0.372
#   Std    : 0.031
#   Scores : [0.427 0.343 0.346 0.363 0.379]
#  ✅ CV mean is positive (0.372)
#   ✅ Train/test R² gap acceptable (gap: 0.053)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# Top 10 feature importances:
#   height                                        0.3520  =================
#   EVI                                           0.2340  ===========
#   NIR                                           0.1785  ========
#   NBR                                           0.1180  =====
#   SWIR1                                         0.1175  =====
#
# [12/18]
#
#  RANDOM FOREST: EXPERIMENT-12 No groups, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? No, Grid? No
# Test R²     : 0.1328
# Test RMSE   : 15.70 kg
# Train R² (log scale): 0.4042
# Train R² (orig scale): 0.1867
# Train RMSE  : 15.09 kg
# Num rows    : 3104
# Num Features: 8
#
#  Cross-validation ---
# CV R² mean: 0.3716
# CV R² std : 0.0307
# CV scores : [0.427 0.343 0.346 0.363 0.379]
# ============================================================
#  EVALUATION: EXPERIMENT-12 No groups, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.133
#   RMSE : 15.70 kg
#
#  ✅ Test R² is positive (0.133)
#
# Regular CrossValidation:
#   Mean   : 0.372
#   Std    : 0.031
#   Scores : [0.427 0.343 0.346 0.363 0.379]
#  ✅ CV mean is positive (0.372)
#   ✅ Train/test R² gap acceptable (gap: 0.054)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# Top 10 feature importances:
#   height_x_EVI                                  0.1940  =========
#   height_x_NDRE1                                0.1847  =========
#   height_x_NIR                                  0.1609  ========
#   height                                        0.1347  ======
#   EVI                                           0.1251  ======
#   NIR                                           0.0904  ====
#   SWIR1                                         0.0628  ===
#   NBR                                           0.0475  ==
#
# [13/18]
#
#  RANDOM FOREST: EXPERIMENT-13 No groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1']., Model: rf, Grouping? No, Grid? No
# Test R²     : 0.1478
# Test RMSE   : 15.57 kg
# Train R² (log scale): 0.4601
# Train R² (orig scale): 0.2020
# Train RMSE  : 14.95 kg
# Num rows    : 3104
# Num Features: 8
#
#  Cross-validation ---
# CV R² mean: 0.4083
# CV R² std : 0.0353
# CV scores : [0.457 0.358 0.38  0.42  0.427]
# ============================================================
#  EVALUATION: EXPERIMENT-13 No groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1']., Model: rf, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.148
#   RMSE : 15.57 kg
#
#  ✅ Test R² is positive (0.148)
#
# Regular CrossValidation:
#   Mean   : 0.408
#   Std    : 0.035
#   Scores : [0.457 0.358 0.38  0.42  0.427]
#  ✅ CV mean is positive (0.408)
#   ✅ Train/test R² gap acceptable (gap: 0.054)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# Top 10 feature importances:
#   height                                        0.2588  ============
#   EVI                                           0.2058  ==========
#   NIR                                           0.1766  ========
#   SWIR1                                         0.1321  ======
#   NBR                                           0.1278  ======
#   species_Rhizophora mangle                     0.0483  ==
#   species_Avicennia germinans                   0.0383  =
#   species_Laguncularia racemosa                 0.0122
#
# [14/18]
#
#  RANDOM FOREST: EXPERIMENT-14 No groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? No, Grid? No
# Test R²     : 0.1467
# Test RMSE   : 15.58 kg
# Train R² (log scale): 0.4599
# Train R² (orig scale): 0.2027
# Train RMSE  : 14.94 kg
# Num rows    : 3104
# Num Features: 11
#
#  Cross-validation ---
# CV R² mean: 0.4085
# CV R² std : 0.0351
# CV scores : [0.458 0.359 0.38  0.42  0.425]
# ============================================================
#  EVALUATION: EXPERIMENT-14 No groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.147
#   RMSE : 15.58 kg
#
#  ✅ Test R² is positive (0.147)
#
# Regular CrossValidation:
#   Mean   : 0.408
#   Std    : 0.035
#   Scores : [0.458 0.359 0.38  0.42  0.425]
#  ✅ CV mean is positive (0.408)
#   ✅ Train/test R² gap acceptable (gap: 0.056)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# Top 10 feature importances:
#   height_x_NDRE1                                0.1904  =========
#   height_x_EVI                                  0.1625  ========
#   height_x_NIR                                  0.1465  =======
#   height                                        0.1104  =====
#   EVI                                           0.1073  =====
#   NIR                                           0.0861  ====
#   SWIR1                                         0.0578  ==
#   NBR                                           0.0450  ==
#   species_Rhizophora mangle                     0.0404  ==
#   species_Avicennia germinans                   0.0398  =
#
# [15/18]
#
#  RANDOM FOREST: EXPERIMENT-15 No groups, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2']., Model: rf, Grouping? No, Grid? No
# Test R²     : 0.1328
# Test RMSE   : 15.70 kg
# Train R² (log scale): 0.4042
# Train R² (orig scale): 0.1864
# Train RMSE  : 15.09 kg
# Num rows    : 3104
# Num Features: 7
#
#  Cross-validation ---
# CV R² mean: 0.3717
# CV R² std : 0.0308
# CV scores : [0.427 0.343 0.346 0.363 0.379]
# ============================================================
#  EVALUATION: EXPERIMENT-15 No groups, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2']., Model: rf, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.133
#   RMSE : 15.70 kg
#
#  ✅ Test R² is positive (0.133)
#
# Regular CrossValidation:
#   Mean   : 0.372
#   Std    : 0.031
#   Scores : [0.427 0.343 0.346 0.363 0.379]
#  ✅ CV mean is positive (0.372)
#   ✅ Train/test R² gap acceptable (gap: 0.054)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# Top 10 feature importances:
#   height                                        0.2650  =============
#   EVI                                           0.1855  =========
#   NIR                                           0.1329  ======
#   RE2                                           0.1320  ======
#   SWIR1                                         0.0962  ====
#   NBR                                           0.0962  ====
#   RE1                                           0.0923  ====
#
# [16/18]
#
#  RANDOM FOREST: EXPERIMENT-16 No groups, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? No, Grid? No
# Test R²     : 0.1327
# Test RMSE   : 15.70 kg
# Train R² (log scale): 0.4042
# Train R² (orig scale): 0.1868
# Train RMSE  : 15.09 kg
# Num rows    : 3104
# Num Features: 10
#
#  Cross-validation ---
# CV R² mean: 0.3717
# CV R² std : 0.0307
# CV scores : [0.427 0.343 0.347 0.363 0.379]
# ============================================================
#  EVALUATION: EXPERIMENT-16 No groups, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.133
#   RMSE : 15.70 kg
#
#  ✅ Test R² is positive (0.133)
#
# Regular CrossValidation:
#   Mean   : 0.372
#   Std    : 0.031
#   Scores : [0.427 0.343 0.347 0.363 0.379]
#  ✅ CV mean is positive (0.372)
#   ✅ Train/test R² gap acceptable (gap: 0.054)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# Top 10 feature importances:
#   height_x_NDRE1                                0.2077  ==========
#   height_x_EVI                                  0.1713  ========
#   height_x_NIR                                  0.1619  ========
#   height                                        0.1243  ======
#   EVI                                           0.0918  ====
#   NIR                                           0.0654  ===
#   RE2                                           0.0584  ==
#   SWIR1                                         0.0459  ==
#   RE1                                           0.0372  =
#   NBR                                           0.0361  =
#
# [17/18]
#
#  RANDOM FOREST: EXPERIMENT-17 No groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2']., Model: rf, Grouping? No, Grid? No
# Test R²     : 0.1469
# Test RMSE   : 15.57 kg
# Train R² (log scale): 0.4597
# Train R² (orig scale): 0.2023
# Train RMSE  : 14.95 kg
# Num rows    : 3104
# Num Features: 10
#
#  Cross-validation ---
# CV R² mean: 0.4079
# CV R² std : 0.0353
# CV scores : [0.458 0.358 0.379 0.42  0.424]
# ============================================================
#  EVALUATION: EXPERIMENT-17 No groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2']., Model: rf, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.147
#   RMSE : 15.57 kg
#
#  ✅ Test R² is positive (0.147)
#
# Regular CrossValidation:
#   Mean   : 0.408
#   Std    : 0.035
#   Scores : [0.458 0.358 0.379 0.42  0.424]
#  ✅ CV mean is positive (0.408)
#   ✅ Train/test R² gap acceptable (gap: 0.055)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# Top 10 feature importances:
#   height                                        0.2415  ============
#   EVI                                           0.1754  ========
#   NIR                                           0.1251  ======
#   RE2                                           0.1105  =====
#   RE1                                           0.0895  ====
#   SWIR1                                         0.0839  ====
#   NBR                                           0.0763  ===
#   species_Rhizophora mangle                     0.0460  ==
#   species_Avicennia germinans                   0.0379  =
#   species_Laguncularia racemosa                 0.0139
#
# [18/18]
#
#  RANDOM FOREST: EXPERIMENT-18 No groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? No, Grid? No
# Test R²     : 0.1467
# Test RMSE   : 15.58 kg
# Train R² (log scale): 0.4597
# Train R² (orig scale): 0.2023
# Train RMSE  : 14.95 kg
# Num rows    : 3104
# Num Features: 13
#
#  Cross-validation ---
# CV R² mean: 0.4082
# CV R² std : 0.0351
# CV scores : [0.458 0.359 0.379 0.42  0.425]
# ============================================================
#  EVALUATION: EXPERIMENT-18 No groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? No, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.147
#   RMSE : 15.58 kg
#
#  ✅ Test R² is positive (0.147)
#
# Regular CrossValidation:
#   Mean   : 0.408
#   Std    : 0.035
#   Scores : [0.458 0.359 0.379 0.42  0.425]
#  ✅ CV mean is positive (0.408)
#   ✅ Train/test R² gap acceptable (gap: 0.056)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# Top 10 feature importances:
#   height_x_EVI                                  0.1546  =======
#   height_x_NDRE1                                0.1449  =======
#   height_x_NIR                                  0.1356  ======
#   height                                        0.1126  =====
#   EVI                                           0.0902  ====
#   NIR                                           0.0715  ===
#   RE2                                           0.0637  ===
#   SWIR1                                         0.0488  ==
#   species_Rhizophora mangle                     0.0457  ==
#   RE1                                           0.0443  ==
#
# Completed: 18/18 experiments

# %% [markdown]
# This run has a serious problem
# Experiments 1 through 6 and experiment 8 all produce identical results — test R² 0.133, CV mean 0.371-0.372, CV std 0.031, train R² 0.1864-0.1865, train RMSE 15.09 kg. Eight completely different feature sets producing the exact same numbers is not a coincidence. It means the model is ignoring the spectral features entirely and predicting the same values regardless of what features it is given.
# The most likely cause is that Random Forest without grouping is dominated by the target distribution — it is learning the marginal distribution of y_train_log and outputting something close to the mean for every prediction. The spectral features are contributing essentially nothing beyond what height provides in the first place.
#
#
# Why this happens without grouping
# Without plot-level grouping, the train/test split does not respect plot boundaries. Plants from the same plot appear in both train and test. Random Forest memorises the within-plot AGB distribution during training. When it sees test plants from the same plots, it predicts reasonably based on that memorised distribution — and that is exactly what it does regardless of which spectral features you give it, because the plot-level pattern drowns out any spectral signal.
# This is a more severe form of the same leakage problem that inflated linear regression CV scores without grouping.

# %%
tabulate_results(rf_belige_no_grps, acceptable_only=True)
# Out:
# Showing 18 acceptable experiments
# <style type="text/css">
# #T_255d6_row0_col5, #T_255d6_row1_col1, #T_255d6_row1_col2, #T_255d6_row3_col2 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_255d6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_255d6_level0_col0" class="col_heading level0 col0" >Experiment</th>
#       <th id="T_255d6_level0_col1" class="col_heading level0 col1" >Test R²</th>
#       <th id="T_255d6_level0_col2" class="col_heading level0 col2" >Test RMSE</th>
#       <th id="T_255d6_level0_col3" class="col_heading level0 col3" >Train R²</th>
#       <th id="T_255d6_level0_col4" class="col_heading level0 col4" >Train RMSE</th>
#       <th id="T_255d6_level0_col5" class="col_heading level0 col5" >CV R² Mean</th>
#       <th id="T_255d6_level0_col6" class="col_heading level0 col6" >CV R² Std</th>
#       <th id="T_255d6_level0_col7" class="col_heading level0 col7" >verdict</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_255d6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_255d6_row0_col0" class="data row0 col0" >EXPERIMENT-14 No groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? No, Grid? No</td>
#       <td id="T_255d6_row0_col1" class="data row0 col1" >0.1467</td>
#       <td id="T_255d6_row0_col2" class="data row0 col2" >15.58</td>
#       <td id="T_255d6_row0_col3" class="data row0 col3" >0.2027</td>
#       <td id="T_255d6_row0_col4" class="data row0 col4" >14.94</td>
#       <td id="T_255d6_row0_col5" class="data row0 col5" >0.4085</td>
#       <td id="T_255d6_row0_col6" class="data row0 col6" >0.0351</td>
#       <td id="T_255d6_row0_col7" class="data row0 col7" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_255d6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_255d6_row1_col0" class="data row1 col0" >EXPERIMENT-13 No groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1']., Model: rf, Grouping? No, Grid? No</td>
#       <td id="T_255d6_row1_col1" class="data row1 col1" >0.1478</td>
#       <td id="T_255d6_row1_col2" class="data row1 col2" >15.57</td>
#       <td id="T_255d6_row1_col3" class="data row1 col3" >0.202</td>
#       <td id="T_255d6_row1_col4" class="data row1 col4" >14.95</td>
#       <td id="T_255d6_row1_col5" class="data row1 col5" >0.4083</td>
#       <td id="T_255d6_row1_col6" class="data row1 col6" >0.0353</td>
#       <td id="T_255d6_row1_col7" class="data row1 col7" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_255d6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_255d6_row2_col0" class="data row2 col0" >EXPERIMENT-18 No groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? No, Grid? No</td>
#       <td id="T_255d6_row2_col1" class="data row2 col1" >0.1467</td>
#       <td id="T_255d6_row2_col2" class="data row2 col2" >15.58</td>
#       <td id="T_255d6_row2_col3" class="data row2 col3" >0.2023</td>
#       <td id="T_255d6_row2_col4" class="data row2 col4" >14.95</td>
#       <td id="T_255d6_row2_col5" class="data row2 col5" >0.4082</td>
#       <td id="T_255d6_row2_col6" class="data row2 col6" >0.0351</td>
#       <td id="T_255d6_row2_col7" class="data row2 col7" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_255d6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_255d6_row3_col0" class="data row3 col0" >EXPERIMENT-17 No groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2']., Model: rf, Grouping? No, Grid? No</td>
#       <td id="T_255d6_row3_col1" class="data row3 col1" >0.1469</td>
#       <td id="T_255d6_row3_col2" class="data row3 col2" >15.57</td>
#       <td id="T_255d6_row3_col3" class="data row3 col3" >0.2023</td>
#       <td id="T_255d6_row3_col4" class="data row3 col4" >14.95</td>
#       <td id="T_255d6_row3_col5" class="data row3 col5" >0.4079</td>
#       <td id="T_255d6_row3_col6" class="data row3 col6" >0.0353</td>
#       <td id="T_255d6_row3_col7" class="data row3 col7" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_255d6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_255d6_row4_col0" class="data row4 col0" >EXPERIMENT-16 No groups, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? No, Grid? No</td>
#       <td id="T_255d6_row4_col1" class="data row4 col1" >0.1327</td>
#       <td id="T_255d6_row4_col2" class="data row4 col2" >15.7</td>
#       <td id="T_255d6_row4_col3" class="data row4 col3" >0.1868</td>
#       <td id="T_255d6_row4_col4" class="data row4 col4" >15.09</td>
#       <td id="T_255d6_row4_col5" class="data row4 col5" >0.3717</td>
#       <td id="T_255d6_row4_col6" class="data row4 col6" >0.0307</td>
#       <td id="T_255d6_row4_col7" class="data row4 col7" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_255d6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_255d6_row5_col0" class="data row5 col0" >EXPERIMENT-5 No groups, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: rf, Grouping? No, Grid? No</td>
#       <td id="T_255d6_row5_col1" class="data row5 col1" >0.1325</td>
#       <td id="T_255d6_row5_col2" class="data row5 col2" >15.7</td>
#       <td id="T_255d6_row5_col3" class="data row5 col3" >0.1867</td>
#       <td id="T_255d6_row5_col4" class="data row5 col4" >15.09</td>
#       <td id="T_255d6_row5_col5" class="data row5 col5" >0.3717</td>
#       <td id="T_255d6_row5_col6" class="data row5 col6" >0.0307</td>
#       <td id="T_255d6_row5_col7" class="data row5 col7" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_255d6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_255d6_row6_col0" class="data row6 col0" >EXPERIMENT-6 No groups, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? No, Grid? No</td>
#       <td id="T_255d6_row6_col1" class="data row6 col1" >0.1329</td>
#       <td id="T_255d6_row6_col2" class="data row6 col2" >15.7</td>
#       <td id="T_255d6_row6_col3" class="data row6 col3" >0.1865</td>
#       <td id="T_255d6_row6_col4" class="data row6 col4" >15.09</td>
#       <td id="T_255d6_row6_col5" class="data row6 col5" >0.3717</td>
#       <td id="T_255d6_row6_col6" class="data row6 col6" >0.0307</td>
#       <td id="T_255d6_row6_col7" class="data row6 col7" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_255d6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_255d6_row7_col0" class="data row7 col0" >EXPERIMENT-15 No groups, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2']., Model: rf, Grouping? No, Grid? No</td>
#       <td id="T_255d6_row7_col1" class="data row7 col1" >0.1328</td>
#       <td id="T_255d6_row7_col2" class="data row7 col2" >15.7</td>
#       <td id="T_255d6_row7_col3" class="data row7 col3" >0.1864</td>
#       <td id="T_255d6_row7_col4" class="data row7 col4" >15.09</td>
#       <td id="T_255d6_row7_col5" class="data row7 col5" >0.3717</td>
#       <td id="T_255d6_row7_col6" class="data row7 col6" >0.0308</td>
#       <td id="T_255d6_row7_col7" class="data row7 col7" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_255d6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_255d6_row8_col0" class="data row8 col0" >EXPERIMENT-11 No groups, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1']., Model: rf, Grouping? No, Grid? No</td>
#       <td id="T_255d6_row8_col1" class="data row8 col1" >0.133</td>
#       <td id="T_255d6_row8_col2" class="data row8 col2" >15.7</td>
#       <td id="T_255d6_row8_col3" class="data row8 col3" >0.1865</td>
#       <td id="T_255d6_row8_col4" class="data row8 col4" >15.09</td>
#       <td id="T_255d6_row8_col5" class="data row8 col5" >0.3716</td>
#       <td id="T_255d6_row8_col6" class="data

# %% [markdown]
# ### BELIGE DATA. PLOT GROUPS. ALL ROWS. RANDOM FOREST (Hyper parameter tuning: NO)

# %%
# %run Model_functions.ipynb

rf_belige_no_grid_grps = {}

run_experiment(X_belige, y_belige,
               is_groups=True, group_info=grp_belige,
               features_list=gen_features_list,
               experiments=rf_belige_no_grid_grps,
               model_type="rf", is_grid=False,
               is_stratified=is_stratified_g,
               global_experiment_list=global_experiment_list)
# Out:
# chmod: /Users/kosaraju_b/.local/share/jupyter/history.sqlite: No such file or directory
#
# [1/18]
#
#  RANDOM FOREST: EXPERIMENT-1 Plot groups Grid search: No, Features: ['height']., Model: rf, Grouping? Yes, Grid? No
# Test R²     : 0.1277
# Test RMSE   : 4.31 kg
# Train R² (log scale): 0.4040
# Train R² (orig scale): 0.1658
# Train RMSE  : 16.96 kg
# Num rows    : 3100
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: 0.0628
# CV R² std : 0.2958
# CV scores : [-0.197  0.565  0.031  0.175 -0.26 ]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2012
# Grouped CV R² std : 0.2784
# Grouped CV scores : [ 0.066 -0.36   0.251 -0.164  0.448  0.569  0.485  0.286  0.112  0.319]
# ============================================================
#  EVALUATION: EXPERIMENT-1 Plot groups Grid search: No, Features: ['height']., Model: rf, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.128
#   RMSE : 4.31 kg
#
#  ✅ Test R² is positive (0.128)
#
# Regular CrossValidation:
#   Mean   : 0.063
#   Std    : 0.296
#   Scores : [-0.197  0.565  0.031  0.175 -0.26 ]
#  ✅ CV mean is positive (0.063)
#
# Grouped CrossValidation:
#   Big Creek_5          :   0.066  {GREEN_TICK}
#   Frenchman Caye_6     :  -0.360  {WARNING}  near-zero variance artifact
#   Frenchman Caye_3     :   0.251  {GREEN_TICK}
#   Big Creek_3          :  -0.164  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.448  {GREEN_TICK}
#   Big Creek_2          :   0.569  {GREEN_TICK}
#   Drowned Caye_5       :   0.485  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.286  {GREEN_TICK}
#   Channel Caye_2       :   0.112  {GREEN_TICK}
#   Channel Caye_6       :   0.319  {GREEN_TICK}
#
#   Mean : 0.201
#   Std  : 0.278
#
#   ✅ Grouped CV mean above 0.15 (0.201)
#   ⚠️  Grouped CV std above 0.25 (0.278) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.074 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: 0.038)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {WARNING}  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height                                        1.0000  ==================================================
#
# [2/18]
#
#  RANDOM FOREST: EXPERIMENT-2 Plot groups Grid search: No, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? Yes, Grid? No
# Test R²     : 0.2060
# Test RMSE   : 4.11 kg
# Train R² (log scale): 0.4040
# Train R² (orig scale): 0.1658
# Train RMSE  : 16.96 kg
# Num rows    : 3100
# Num Features: 4
#
#  Cross-validation ---
# CV R² mean: 0.1640
# CV R² std : 0.2314
# CV scores : [-0.066  0.6    0.033  0.175  0.078]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2578
# Grouped CV R² std : 0.2159
# Grouped CV scores : [-0.078  0.11   0.246 -0.09   0.469  0.591  0.485  0.283  0.248  0.314]
# ============================================================
#  EVALUATION: EXPERIMENT-2 Plot groups Grid search: No, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.206
#   RMSE : 4.11 kg
#
#  ✅ Test R² is positive (0.206)
#
# Regular CrossValidation:
#   Mean   : 0.164
#   Std    : 0.231
#   Scores : [-0.066  0.6    0.033  0.175  0.078]
#  ✅ CV mean is positive (0.164)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.078  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :   0.110  {GREEN_TICK}
#   Frenchman Caye_3     :   0.246  {GREEN_TICK}
#   Big Creek_3          :  -0.090  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.469  {GREEN_TICK}
#   Big Creek_2          :   0.591  {GREEN_TICK}
#   Drowned Caye_5       :   0.485  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.283  {GREEN_TICK}
#   Channel Caye_2       :   0.248  {GREEN_TICK}
#   Channel Caye_6       :   0.314  {GREEN_TICK}
#
#   Mean : 0.258
#   Std  : 0.216
#
#   ✅ Grouped CV mean above 0.15 (0.258)
#   ✅ Grouped CV std below 0.25 (0.216)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.052 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.040)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {WARNING}  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height                                        0.3389  ================
#   height_x_NDRE1                                0.2823  ==============
#   height_x_EVI                                  0.1962  =========
#   height_x_NIR                                  0.1826  =========
#
# [3/18]
#
#  RANDOM FOREST: EXPERIMENT-3 Plot groups Grid search: No, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2']., Model: rf, Grouping? Yes, Grid? No
# Test R²     : 0.2656
# Test RMSE   : 3.96 kg
# Train R² (log scale): 0.4040
# Train R² (orig scale): 0.1658
# Train RMSE  : 16.96 kg
# Num rows    : 3100
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: -0.2205
# CV R² std : 0.6188
# CV scores : [-0.077  0.582 -0.077 -0.201 -1.329]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.0542
# Grouped CV R² std : 0.5126
# Grouped CV scores : [-0.254 -1.33   0.226 -0.021  0.347  0.497  0.524  0.268  0.236  0.048]
# ============================================================
#  EVALUATION: EXPERIMENT-3 Plot groups Grid search: No, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2']., Model: rf, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.266
#   RMSE : 3.96 kg
#
#  ✅ Test R² is positive (0.266)
#
# Regular CrossValidation:
#   Mean   : -0.221
#   Std    : 0.619
#   Scores : [-0.077  0.582 -0.077 -0.201 -1.329]
#  ❌ CV mean is negative (-0.221)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.254  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :  -1.330  {WARNING}  near-zero variance artifact
#   Frenchman Caye_3     :   0.226  {GREEN_TICK}
#   Big Creek_3          :  -0.021  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.347  {GREEN_TICK}
#   Big Creek_2          :   0.497  {GREEN_TICK}
#   Drowned Caye_5       :   0.524  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.268  {GREEN_TICK}
#   Channel Caye_2       :   0.236  {GREEN_TICK}
#   Channel Caye_6       :   0.048  {GREEN_TICK}
#
#   Mean : 0.054
#   Std  : 0.513
#
#   ❌ Grouped CV mean below 0.15 (0.054)
#   ⚠️  Grouped CV std above 0.25 (0.513) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.211 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.100)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {RED_CROSS} REJECTED
#
# Top 10 feature importances:
#   NIR                                           0.1781  ========
#   RE2                                           0.1564  =======
#   RE3                                           0.1393  ======
#   Green                                         0.1224  ======
#   RE1                                           0.1066  =====
#   SWIR1                                         0.0912  ====
#   Red                                           0.0844  ====
#   Blue                                          0.0622  ===
#   SWIR2                                         0.0593  ==
#
# [4/18]
#
#  RANDOM FOREST: EXPERIMENT-4 Plot groups Grid search: No, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? Yes, Grid? No
# Test R²     : 0.2460
# Test RMSE   : 4.01 kg
# Train R² (log scale): 0.4040
# Train R² (orig scale): 0.1658
# Train RMSE  : 16.96 kg
# Num rows    : 3100
# Num Features: 12
#
#  Cross-validation ---
# CV R² mean: 0.0006
# CV R² std : 0.2825
# CV scores : [-0.093  0.508 -0.043 -0.007 -0.362]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1946
# Grouped CV R² std : 0.2484
# Grouped CV scores : [-0.162 -0.249  0.25  -0.047  0.425  0.488  0.481  0.27   0.246  0.244]
# ============================================================
#  EVALUATION: EXPERIMENT-4 Plot groups Grid search: No, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.246
#   RMSE : 4.01 kg
#
#  ✅ Test R² is positive (0.246)
#
# Regular CrossValidation:
#   Mean   : 0.001
#   Std    : 0.283
#   Scores : [-0.093  0.508 -0.043 -0.007 -0.362]
#  ✅ CV mean is positive (0.001)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.162  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :  -0.249  {WARNING}  near-zero variance artifact
#   Frenchman Caye_3     :   0.250  {GREEN_TICK}
#   Big Creek_3          :  -0.047  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.425  {GREEN_TICK}
#   Big Creek_2          :   0.488  {GREEN_TICK}
#   Drowned Caye_5       :   0.481  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.270  {GREEN_TICK}
#   Channel Caye_2       :   0.246  {GREEN_TICK}
#   Channel Caye_6       :   0.244  {GREEN_TICK}
#
#   Mean : 0.195
#   Std  : 0.248
#
#   ✅ Grouped CV mean above 0.15 (0.195)
#   ✅ Grouped CV std below 0.25 (0.248)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.051 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.080)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {WARNING}  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height_x_NDRE1                                0.1967  =========
#   height_x_NIR                                  0.1965  =========
#   height_x_EVI                                  0.1855  =========
#   RE3                                           0.0805  ====
#   NIR                                           0.0693  ===
#   RE2                                           0.0640  ===
#   SWIR1                                         0.0424  ==
#   Red                                           0.0386  =
#   SWIR2                                         0.0369  =
#   RE1                                           0.0317  =
#
# [5/18]
#
#  RANDOM FOREST: EXPERIMENT-5 Plot groups Grid search: No, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: rf, Grouping? Yes, Grid? No
# Test R²     : 0.2420
# Test RMSE   : 4.02 kg
# Train R² (log scale): 0.4040
# Train R² (orig scale): 0.1658
# Train RMSE  : 16.96 kg
# Num rows    : 3100
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: -0.4866
# CV R² std : 1.2446
# CV scores : [-0.067  0.619 -0.009 -0.053 -2.922]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.0474
# Grouped CV R² std : 0.8645
# Grouped CV scores : [-0.061 -2.542  0.028 -0.118  0.492  0.572  0.581  0.171  0.225  0.177]
# ============================================================
#  EVALUATION: EXPERIMENT-5 Plot groups Grid search: No, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: rf, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.242
#   RMSE : 4.02 kg
#
#  ✅ Test R² is positive (0.242)
#
# Regular CrossValidation:
#   Mean   : -0.487
#   Std    : 1.245
#   Scores : [-0.067  0.619 -0.009 -0.053 -2.922]
#  ❌ CV mean is negative (-0.487)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.061  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :  -2.542  {WARNING}  near-zero variance artifact
#   Frenchman Caye_3     :   0.028  {GREEN_TICK}
#   Big Creek_3          :  -0.118  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.492  {GREEN_TICK}
#   Big Creek_2          :   0.572  {GREEN_TICK}
#   Drowned Caye_5       :   0.581  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.171  {GREEN_TICK}
#   Channel Caye_2       :   0.225  {GREEN_TICK}
#   Channel Caye_6       :   0.177  {GREEN_TICK}
#
#   Mean : -0.047
#   Std  : 0.865
#
#   ❌ Grouped CV mean below 0.15 (-0.047)
#   ⚠️  Grouped CV std above 0.25 (0.865) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.289 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.076)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {RED_CROSS} REJECTED
#
# Top 10 feature importances:
#   NDRE1                                         0.2396  ===========
#   EVI                                           0.2155  ==========
#   CIrededge                                     0.1719  ========
#   NDRE2                                         0.0967  ====
#   NDVI                                          0.0890  ====
#   NDRE3                                         0.0745  ===
#   NBR                                           0.0698  ===
#   MNDWI                                         0.0430  ==
#   CLOUD_COVERAGE                                0.0000
#
# [6/18]
#
#  RANDOM FOREST: EXPERIMENT-6 Plot groups Grid search: No, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? Yes, Grid? No
# Test R²     : 0.2099
# Test RMSE   : 4.10 kg
# Train R² (log scale): 0.4040
# Train R² (orig scale): 0.1658
# Train RMSE  : 16.96 kg
# Num rows    : 3100
# Num Features: 12
#
#  Cross-validation ---
# CV R² mean: -0.0539
# CV R² std : 0.4807
# CV scores : [-0.082  0.648 -0.011  0.037 -0.861]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2085
# Grouped CV R² std : 0.2959
# Grouped CV scores : [-0.066 -0.359  0.226 -0.098  0.476  0.595  0.608  0.254  0.225  0.225]
# ============================================================
#  EVALUATION: EXPERIMENT-6 Plot groups Grid search: No, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.210
#   RMSE : 4.10 kg
#
#  ✅ Test R² is positive (0.210)
#
# Regular CrossValidation:
#   Mean   : -0.054
#   Std    : 0.481
#   Scores : [-0.082  0.648 -0.011  0.037 -0.861]
#  ❌ CV mean is negative (-0.054)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.066  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :  -0.359  {WARNING}  near-zero variance artifact
#   Frenchman Caye_3     :   0.226  {GREEN_TICK}
#   Big Creek_3          :  -0.098  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.476  {GREEN_TICK}
#   Big Creek_2          :   0.595  {GREEN_TICK}
#   Drowned Caye_5       :   0.608  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.254  {GREEN_TICK}
#   Channel Caye_2       :   0.225  {GREEN_TICK}
#   Channel Caye_6       :   0.225  {GREEN_TICK}
#
#   Mean : 0.209
#   Std  : 0.296
#
#   ✅ Grouped CV mean above 0.15 (0.209)
#   ⚠️  Grouped CV std above 0.25 (0.296) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ✅ Grouped CV and test R² agree (gap: 0.001)
#   ✅ Train/test R² gap acceptable (gap: -0.044)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {RED_CROSS} REJECTED
#
# Top 10 feature importances:
#   height_x_NDRE1                                0.1988  =========
#   height_x_EVI                                  0.1890  =========
#   height_x_NIR                                  0.1791  ========
#   NDRE1                                         0.0968  ====
#   EVI                                           0.0822  ====
#   CIrededge                                     0.0787  ===
#   NDRE2                                         0.0406  ==
#   NDVI                                          0.0398  =
#   NBR                                           0.0322  =
#   NDRE3                                         0.0315  =
#
# [7/18]
#
#  RANDOM FOREST: EXPERIMENT-7 Plot groups Grid search: No, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: rf, Grouping? Yes, Grid? No
# Test R²     : 0.2497
# Test RMSE   : 4.00 kg
# Train R² (log scale): 0.4040
# Train R² (orig scale): 0.1658
# Train RMSE  : 16.96 kg
# Num rows    : 3100
# Num Features: 18
#
#  Cross-validation ---
# CV R² mean: -0.2575
# CV R² std : 0.7890
# CV scores : [-0.073  0.641  0.01  -0.131 -1.735]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.0369
# Grouped CV R² std : 0.9205
# Grouped CV scores : [-0.152 -2.706  0.236 -0.056  0.452  0.571  0.639  0.233  0.249  0.165]
# ============================================================
#  EVALUATION: EXPERIMENT-7 Plot groups Grid search: No, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: rf, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.250
#   RMSE : 4.00 kg
#
#  ✅ Test R² is positive (0.250)
#
# Regular CrossValidation:
#   Mean   : -0.258
#   Std    : 0.789
#   Scores : [-0.073  0.641  0.01  -0.131 -1.735]
#  ❌ CV mean is negative (-0.258)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.152  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :  -2.706  {WARNING}  near-zero variance artifact
#   Frenchman Caye_3     :   0.236  {GREEN_TICK}
#   Big Creek_3          :  -0.056  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.452  {GREEN_TICK}
#   Big Creek_2          :   0.571  {GREEN_TICK}
#   Drowned Caye_5       :   0.639  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.233  {GREEN_TICK}
#   Channel Caye_2       :   0.249  {GREEN_TICK}
#   Channel Caye_6       :   0.165  {GREEN_TICK}
#
#   Mean : -0.037
#   Std  : 0.921
#
#   ❌ Grouped CV mean below 0.15 (-0.037)
#   ⚠️  Grouped CV std above 0.25 (0.921) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.287 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.084)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {RED_CROSS} REJECTED
#
# Top 10 feature importances:
#   NDRE1                                         0.1408  =======
#   CIrededge                                     0.1286  ======
#   EVI                                           0.1068  =====
#   NIR                                           0.0880  ====
#   RE3                                           0.0852  ====
#   RE2                                           0.0698  ===
#   Red                                           0.0493  ==
#   NBR                                           0.0480  ==
#   SWIR1                                         0.0453  ==
#   NDRE2                                         0.0450  ==
#
# [8/18]
#
#  RANDOM FOREST: EXPERIMENT-8 Plot groups Grid search: No, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? Yes, Grid? No
# Test R²     : 0.2327
# Test RMSE   : 4.04 kg
# Train R² (log scale): 0.4040
# Train R² (orig scale): 0.1658
# Train RMSE  : 16.96 kg
# Num rows    : 3100
# Num Features: 21
#
#  Cross-validation ---
# CV R² mean: -0.0781
# CV R² std : 0.4715
# CV scores : [-0.088  0.634 -0.04  -0.044 -0.853]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1493
# Grouped CV R² std : 0.4121
# Grouped CV scores : [-0.119 -0.903  0.254 -0.055  0.443  0.549  0.588  0.256  0.238  0.242]
# ============================================================
#  EVALUATION: EXPERIMENT-8 Plot groups Grid search: No, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.233
#   RMSE : 4.04 kg
#
#  ✅ Test R² is positive (0.233)
#
# Regular CrossValidation:
#   Mean   : -0.078
#   Std    : 0.472
#   Scores : [-0.088  0.634 -0.04  -0.044 -0.853]
#  ❌ CV mean is negative (-0.078)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.119  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :  -0.903  {WARNING}  near-zero variance artifact
#   Frenchman Caye_3     :   0.254  {GREEN_TICK}
#   Big Creek_3          :  -0.055  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.443  {GREEN_TICK}
#   Big Creek_2          :   0.549  {GREEN_TICK}
#   Drowned Caye_5       :   0.588  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.256  {GREEN_TICK}
#   Channel Caye_2       :   0.238  {GREEN_TICK}
#   Channel Caye_6       :   0.242  {GREEN_TICK}
#
#   Mean : 0.149
#   Std  : 0.412
#
#   ❌ Grouped CV mean below 0.15 (0.149)
#   ⚠️  Grouped CV std above 0.25 (0.412) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.083 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.067)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {RED_CROSS} REJECTED
#
# Top 10 feature importances:
#   height_x_NDRE1                                0.1586  =======
#   height_x_EVI                                  0.1442  =======
#   height_x_NIR                                  0.1289  ======
#   EVI                                           0.0706  ===
#   NDRE1                                         0.0686  ===
#   CIrededge                                     0.0599  ==
#   RE2                                           0.0479  ==
#   NIR                                           0.0462  ==
#   RE3                                           0.0400  =
#   SWIR1                                         0.0320  =
#
# [9/18]
#
#  RANDOM FOREST: EXPERIMENT-9 Plot groups Grid search: No, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: rf, Grouping? Yes, Grid? No
# Test R²     : 0.2190
# Test RMSE   : 4.08 kg
# Train R² (log scale): 0.4040
# Train R² (orig scale): 0.1658
# Train RMSE  : 16.96 kg
# Num rows    : 3100
# Num Features: 19
#
#  Cross-validation ---
# CV R² mean: -0.1657
# CV R² std : 0.6034
# CV scores : [-0.138  0.646 -0.017 -0.09  -1.23 ]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.0975
# Grouped CV R² std : 0.5588
# Grouped CV scores : [-0.084 -1.45   0.251 -0.051  0.445  0.532  0.631  0.248  0.243  0.21 ]
# ============================================================
#  EVALUATION: EXPERIMENT-9 Plot groups Grid search: No, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: rf, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.219
#   RMSE : 4.08 kg
#
#  ✅ Test R² is positive (0.219)
#
# Regular CrossValidation:
#   Mean   : -0.166
#   Std    : 0.603
#   Scores : [-0.138  0.646 -0.017 -0.09  -1.23 ]
#  ❌ CV mean is negative (-0.166)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.084  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :  -1.450  {WARNING}  near-zero variance artifact
#   Frenchman Caye_3     :   0.251  {GREEN_TICK}
#   Big Creek_3          :  -0.051  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.445  {GREEN_TICK}
#   Big Creek_2          :   0.532  {GREEN_TICK}
#   Drowned Caye_5       :   0.631  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.248  {GREEN_TICK}
#   Channel Caye_2       :   0.243  {GREEN_TICK}
#   Channel Caye_6       :   0.210  {GREEN_TICK}
#
#   Mean : 0.098
#   Std  : 0.559
#
#   ❌ Grouped CV mean below 0.15 (0.098)
#   ⚠️  Grouped CV std above 0.25 (0.559) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.121 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.053)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {RED_CROSS} REJECTED
#
# Top 10 feature importances:
#   height                                        0.2241  ===========
#   NDRE1                                         0.1084  =====
#   EVI                                           0.0966  ====
#   CIrededge                                     0.0904  ====
#   RE3                                           0.0639  ===
#   NIR                                           0.0629  ===
#   RE2                                           0.0557  ==
#   Red                                           0.0435  ==
#   NDRE2                                         0.0345  =
#   NBR                                           0.0322  =
#
# [10/18]
#
#  RANDOM FOREST: EXPERIMENT-10 Plot groups Grid search: No, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? Yes, Grid? No
# Test R²     : 0.2120
# Test RMSE   : 4.10 kg
# Train R² (log scale): 0.4040
# Train R² (orig scale): 0.1658
# Train RMSE  : 16.96 kg
# Num rows    : 3100
# Num Features: 22
#
#  Cross-validation ---
# CV R² mean: -0.0453
# CV R² std : 0.4151
# CV scores : [-0.083  0.615 -0.052 -0.011 -0.696]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1573
# Grouped CV R² std : 0.3890
# Grouped CV scores : [-0.1   -0.821  0.255 -0.06   0.45   0.518  0.598  0.261  0.236  0.237]
# ============================================================
#  EVALUATION: EXPERIMENT-10 Plot groups Grid search: No, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.212
#   RMSE : 4.10 kg
#
#  ✅ Test R² is positive (0.212)
#
# Regular CrossValidation:
#   Mean   : -0.045
#   Std    : 0.415
#   Scores : [-0.083  0.615 -0.052 -0.011 -0.696]
#  ❌ CV mean is negative (-0.045)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.100  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :  -0.821  {WARNING}  near-zero variance artifact
#   Frenchman Caye_3     :   0.255  {GREEN_TICK}
#   Big Creek_3          :  -0.060  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.450  {GREEN_TICK}
#   Big Creek_2          :   0.518  {GREEN_TICK}
#   Drowned Caye_5       :   0.598  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.261  {GREEN_TICK}
#   Channel Caye_2       :   0.236  {GREEN_TICK}
#   Channel Caye_6       :   0.237  {GREEN_TICK}
#
#   Mean : 0.157
#   Std  : 0.389
#
#   ✅ Grouped CV mean above 0.15 (0.157)
#   ⚠️  Grouped CV std above 0.25 (0.389) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.055 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.046)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {RED_CROSS} REJECTED
#
# Top 10 feature importances:
#   height_x_NDRE1                                0.1511  =======
#   height                                        0.1290  ======
#   height_x_EVI                                  0.1147  =====
#   height_x_NIR                                  0.1073  =====
#   NDRE1                                         0.0685  ===
#   EVI                                           0.0626  ===
#   CIrededge                                     0.0546  ==
#   NIR                                           0.0398  =
#   RE2                                           0.0391  =
#   RE3                                           0.0320  =
#
# [11/18]
#
#  RANDOM FOREST: EXPERIMENT-11 Plot groups Grid search: No, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1']., Model: rf, Grouping? Yes, Grid? No
# Test R²     : -0.0222
# Test RMSE   : 4.67 kg
# Train R² (log scale): 0.4040
# Train R² (orig scale): 0.1658
# Train RMSE  : 16.96 kg
# Num rows    : 3100
# Num Features: 5
#
#  Cross-validation ---
# CV R² mean: 0.0301
# CV R² std : 0.3048
# CV scores : [-0.338  0.587 -0.093 -0.032  0.028]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2240
# Grouped CV R² std : 0.2070
# Grouped CV scores : [-0.137  0.064  0.255 -0.066  0.34   0.545  0.485  0.265  0.25   0.239]
# ============================================================
#  EVALUATION: EXPERIMENT-11 Plot groups Grid search: No, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1']., Model: rf, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : -0.022
#   RMSE : 4.67 kg
#
#  ❌ Test R² is negative (-0.022)
#
# Regular CrossValidation:
#   Mean   : 0.030
#   Std    : 0.305
#   Scores : [-0.338  0.587 -0.093 -0.032  0.028]
#  ✅ CV mean is positive (0.030)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.137  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :   0.064  {GREEN_TICK}
#   Frenchman Caye_3     :   0.255  {GREEN_TICK}
#   Big Creek_3          :  -0.066  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.340  {GREEN_TICK}
#   Big Creek_2          :   0.545  {GREEN_TICK}
#   Drowned Caye_5       :   0.485  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.265  {GREEN_TICK}
#   Channel Caye_2       :   0.250  {GREEN_TICK}
#   Channel Caye_6       :   0.239  {GREEN_TICK}
#
#   Mean : 0.224
#   Std  : 0.207
#
#   ✅ Grouped CV mean above 0.15 (0.224)
#   ✅ Grouped CV std below 0.25 (0.207)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.246 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.188 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: {RED_CROSS} REJECTED
#
# Top 10 feature importances:
#   height                                        0.4096  ====================
#   EVI                                           0.2194  ==========
#   NIR                                           0.1438  =======
#   NBR                                           0.1246  ======
#   SWIR1                                         0.1026  =====
#
# [12/18]
#
#  RANDOM FOREST: EXPERIMENT-12 Plot groups Grid search: No, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? Yes, Grid? No
# Test R²     : 0.1853
# Test RMSE   : 4.17 kg
# Train R² (log scale): 0.4040
# Train R² (orig scale): 0.1658
# Train RMSE  : 16.96 kg
# Num rows    : 3100
# Num Features: 8
#
#  Cross-validation ---
# CV R² mean: 0.1315
# CV R² std : 0.2420
# CV scores : [-0.095  0.59  -0.032  0.061  0.133]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2521
# Grouped CV R² std : 0.2039
# Grouped CV scores : [-0.087  0.154  0.251 -0.068  0.426  0.574  0.485  0.269  0.253  0.264]
# ============================================================
#  EVALUATION: EXPERIMENT-12 Plot groups Grid search: No, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.185
#   RMSE : 4.17 kg
#
#  ✅ Test R² is positive (0.185)
#
# Regular CrossValidation:
#   Mean   : 0.131
#   Std    : 0.242
#   Scores : [-0.095  0.59  -0.032  0.061  0.133]
#  ✅ CV mean is positive (0.131)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.087  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :   0.154  {GREEN_TICK}
#   Frenchman Caye_3     :   0.251  {GREEN_TICK}
#   Big Creek_3          :  -0.068  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.426  {GREEN_TICK}
#   Big Creek_2          :   0.574  {GREEN_TICK}
#   Drowned Caye_5       :   0.485  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.269  {GREEN_TICK}
#   Channel Caye_2       :   0.253  {GREEN_TICK}
#   Channel Caye_6       :   0.264  {GREEN_TICK}
#
#   Mean : 0.252
#   Std  : 0.204
#
#   ✅ Grouped CV mean above 0.15 (0.252)
#   ✅ Grouped CV std below 0.25 (0.204)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.067 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.020)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {WARNING}  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height_x_NDRE1                                0.1954  =========
#   height_x_EVI                                  0.1916  =========
#   height                                        0.1900  =========
#   height_x_NIR                                  0.1574  =======
#   EVI                                           0.1035  =====
#   NIR                                           0.0723  ===
#   SWIR1                                         0.0483  ==
#   NBR                                           0.0415  ==
#
# [13/18]
#
#  RANDOM FOREST: EXPERIMENT-13 Plot groups Grid search: No, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1']., Model: rf, Grouping? Yes, Grid? No
# Test R²     : 0.2648
# Test RMSE   : 3.96 kg
# Train R² (log scale): 0.4657
# Train R² (orig scale): 0.1862
# Train RMSE  : 16.75 kg
# Num rows    : 3100
# Num Features: 8
#
#  Cross-validation ---
# CV R² mean: -0.0305
# CV R² std : 0.3556
# CV scores : [-0.404  0.521  0.255 -0.251 -0.274]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2660
# Grouped CV R² std : 0.2125
# Grouped CV scores : [-0.157  0.156  0.357 -0.013  0.308  0.587  0.508  0.35   0.324  0.239]
# ============================================================
#  EVALUATION: EXPERIMENT-13 Plot groups Grid search: No, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1']., Model: rf, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.265
#   RMSE : 3.96 kg
#
#  ✅ Test R² is positive (0.265)
#
# Regular CrossValidation:
#   Mean   : -0.031
#   Std    : 0.356
#   Scores : [-0.404  0.521  0.255 -0.251 -0.274]
#  ❌ CV mean is negative (-0.031)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.157  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :   0.156  {GREEN_TICK}
#   Frenchman Caye_3     :   0.357  {GREEN_TICK}
#   Big Creek_3          :  -0.013  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.308  {GREEN_TICK}
#   Big Creek_2          :   0.587  {GREEN_TICK}
#   Drowned Caye_5       :   0.508  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.350  {GREEN_TICK}
#   Channel Caye_2       :   0.324  {GREEN_TICK}
#   Channel Caye_6       :   0.239  {GREEN_TICK}
#
#   Mean : 0.266
#   Std  : 0.212
#
#   ✅ Grouped CV mean above 0.15 (0.266)
#   ✅ Grouped CV std below 0.25 (0.212)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ✅ Grouped CV and test R² agree (gap: 0.001)
#   ✅ Train/test R² gap acceptable (gap: -0.079)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE (grouped CV clean — regular CV unreliable)
#
# Top 10 feature importances:
#   height                                        0.2803  ==============
#   EVI                                           0.1930  =========
#   NIR                                           0.1630  ========
#   NBR                                           0.1243  ======
#   SWIR1                                         0.1225  ======
#   species_Rhizophora mangle                     0.0586  ==
#   species_Avicennia germinans                   0.0443  ==
#   species_Laguncularia racemosa                 0.0139
#
# [14/18]
#
#  RANDOM FOREST: EXPERIMENT-14 Plot groups Grid search: No, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? Yes, Grid? No
# Test R²     : 0.2396
# Test RMSE   : 4.02 kg
# Train R² (log scale): 0.4655
# Train R² (orig scale): 0.1865
# Train RMSE  : 16.75 kg
# Num rows    : 3100
# Num Features: 11
#
#  Cross-validation ---
# CV R² mean: 0.1022
# CV R² std : 0.2779
# CV scores : [-0.254  0.54   0.255 -0.106  0.075]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.3072
# Grouped CV R² std : 0.2064
# Grouped CV scores : [-0.067  0.288  0.346 -0.057  0.462  0.595  0.507  0.363  0.349  0.288]
# ============================================================
#  EVALUATION: EXPERIMENT-14 Plot groups Grid search: No, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.240
#   RMSE : 4.02 kg
#
#  ✅ Test R² is positive (0.240)
#
# Regular CrossValidation:
#   Mean   : 0.102
#   Std    : 0.278
#   Scores : [-0.254  0.54   0.255 -0.106  0.075]
#  ✅ CV mean is positive (0.102)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.067  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :   0.288  {GREEN_TICK}
#   Frenchman Caye_3     :   0.346  {GREEN_TICK}
#   Big Creek_3          :  -0.057  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.462  {GREEN_TICK}
#   Big Creek_2          :   0.595  {GREEN_TICK}
#   Drowned Caye_5       :   0.507  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.363  {GREEN_TICK}
#   Channel Caye_2       :   0.349  {GREEN_TICK}
#   Channel Caye_6       :   0.288  {GREEN_TICK}
#
#   Mean : 0.307
#   Std  : 0.206
#
#   ✅ Grouped CV mean above 0.15 (0.307)
#   ✅ Grouped CV std below 0.25 (0.206)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.068 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.053)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {WARNING}  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height_x_NDRE1                                0.1849  =========
#   height                                        0.1611  ========
#   height_x_EVI                                  0.1531  =======
#   height_x_NIR                                  0.1514  =======
#   EVI                                           0.0863  ====
#   NIR                                           0.0687  ===
#   SWIR1                                         0.0497  ==
#   species_Rhizophora mangle                     0.0457  ==
#   species_Avicennia germinans                   0.0436  ==
#   NBR                                           0.0401  ==
#
# [15/18]
#
#  RANDOM FOREST: EXPERIMENT-15 Plot groups Grid search: No, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2']., Model: rf, Grouping? Yes, Grid? No
# Test R²     : 0.1924
# Test RMSE   : 4.15 kg
# Train R² (log scale): 0.4040
# Train R² (orig scale): 0.1658
# Train RMSE  : 16.96 kg
# Num rows    : 3100
# Num Features: 7
#
#  Cross-validation ---
# CV R² mean: -0.0282
# CV R² std : 0.3538
# CV scores : [-0.229  0.618 -0.028 -0.065 -0.436]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2029
# Grouped CV R² std : 0.2323
# Grouped CV scores : [-0.128 -0.193  0.25  -0.036  0.4    0.488  0.497  0.261  0.251  0.241]
# ============================================================
#  EVALUATION: EXPERIMENT-15 Plot groups Grid search: No, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2']., Model: rf, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.192
#   RMSE : 4.15 kg
#
#  ✅ Test R² is positive (0.192)
#
# Regular CrossValidation:
#   Mean   : -0.028
#   Std    : 0.354
#   Scores : [-0.229  0.618 -0.028 -0.065 -0.436]
#  ❌ CV mean is negative (-0.028)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.128  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :  -0.193  {WARNING}  near-zero variance artifact
#   Frenchman Caye_3     :   0.250  {GREEN_TICK}
#   Big Creek_3          :  -0.036  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.400  {GREEN_TICK}
#   Big Creek_2          :   0.488  {GREEN_TICK}
#   Drowned Caye_5       :   0.497  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.261  {GREEN_TICK}
#   Channel Caye_2       :   0.251  {GREEN_TICK}
#   Channel Caye_6       :   0.241  {GREEN_TICK}
#
#   Mean : 0.203
#   Std  : 0.232
#
#   ✅ Grouped CV mean above 0.15 (0.203)
#   ✅ Grouped CV std below 0.25 (0.232)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ✅ Grouped CV and test R² agree (gap: 0.010)
#   ✅ Train/test R² gap acceptable (gap: -0.027)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE (grouped CV clean — regular CV unreliable)
#
# Top 10 feature importances:
#   height                                        0.3170  ===============
#   EVI                                           0.1728  ========
#   RE2                                           0.1209  ======
#   NIR                                           0.1195  =====
#   NBR                                           0.0958  ====
#   RE1                                           0.0919  ====
#   SWIR1                                         0.0822  ====
#
# [16/18]
#
#  RANDOM FOREST: EXPERIMENT-16 Plot groups Grid search: No, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? Yes, Grid? No
# Test R²     : 0.1765
# Test RMSE   : 4.19 kg
# Train R² (log scale): 0.4040
# Train R² (orig scale): 0.1658
# Train RMSE  : 16.96 kg
# Num rows    : 3100
# Num Features: 10
#
#  Cross-validation ---
# CV R² mean: 0.1232
# CV R² std : 0.2470
# CV scores : [-0.111  0.602  0.02   0.04   0.064]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2465
# Grouped CV R² std : 0.1941
# Grouped CV scores : [-0.076  0.118  0.253 -0.061  0.446  0.495  0.487  0.266  0.252  0.286]
# ============================================================
#  EVALUATION: EXPERIMENT-16 Plot groups Grid search: No, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.176
#   RMSE : 4.19 kg
#
#  ✅ Test R² is positive (0.176)
#
# Regular CrossValidation:
#   Mean   : 0.123
#   Std    : 0.247
#   Scores : [-0.111  0.602  0.02   0.04   0.064]
#  ✅ CV mean is positive (0.123)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.076  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :   0.118  {GREEN_TICK}
#   Frenchman Caye_3     :   0.253  {GREEN_TICK}
#   Big Creek_3          :  -0.061  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.446  {GREEN_TICK}
#   Big Creek_2          :   0.495  {GREEN_TICK}
#   Drowned Caye_5       :   0.487  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.266  {GREEN_TICK}
#   Channel Caye_2       :   0.252  {GREEN_TICK}
#   Channel Caye_6       :   0.286  {GREEN_TICK}
#
#   Mean : 0.247
#   Std  : 0.194
#
#   ✅ Grouped CV mean above 0.15 (0.247)
#   ✅ Grouped CV std below 0.25 (0.194)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.070 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.011)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {WARNING}  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height                                        0.2237  ===========
#   height_x_NDRE1                                0.2034  ==========
#   height_x_NIR                                  0.1589  =======
#   height_x_EVI                                  0.1545  =======
#   EVI                                           0.0794  ===
#   NIR                                           0.0531  ==
#   RE2                                           0.0419  ==
#   SWIR1                                         0.0330  =
#   NBR                                           0.0307  =
#   RE1                                           0.0212  =
#
# [17/18]
#
#  RANDOM FOREST: EXPERIMENT-17 Plot groups Grid search: No, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2']., Model: rf, Grouping? Yes, Grid? No
# Test R²     : 0.2797
# Test RMSE   : 3.92 kg
# Train R² (log scale): 0.4654
# Train R² (orig scale): 0.1866
# Train RMSE  : 16.75 kg
# Num rows    : 3100
# Num Features: 10
#
#  Cross-validation ---
# CV R² mean: -0.0818
# CV R² std : 0.4107
# CV scores : [-0.486  0.583  0.192 -0.246 -0.451]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2775
# Grouped CV R² std : 0.2033
# Grouped CV scores : [-0.099  0.108  0.36   0.004  0.413  0.563  0.519  0.301  0.329  0.275]
# ============================================================
#  EVALUATION: EXPERIMENT-17 Plot groups Grid search: No, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2']., Model: rf, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.280
#   RMSE : 3.92 kg
#
#  ✅ Test R² is positive (0.280)
#
# Regular CrossValidation:
#   Mean   : -0.082
#   Std    : 0.411
#   Scores : [-0.486  0.583  0.192 -0.246 -0.451]
#  ❌ CV mean is negative (-0.082)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.099  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :   0.108  {GREEN_TICK}
#   Frenchman Caye_3     :   0.360  {GREEN_TICK}
#   Big Creek_3          :   0.004  {GREEN_TICK}
#   Frenchman Caye_1     :   0.413  {GREEN_TICK}
#   Big Creek_2          :   0.563  {GREEN_TICK}
#   Drowned Caye_5       :   0.519  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.301  {GREEN_TICK}
#   Channel Caye_2       :   0.329  {GREEN_TICK}
#   Channel Caye_6       :   0.275  {GREEN_TICK}
#
#   Mean : 0.277
#   Std  : 0.203
#
#   ✅ Grouped CV mean above 0.15 (0.277)
#   ✅ Grouped CV std below 0.25 (0.203)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ✅ Grouped CV and test R² agree (gap: 0.002)
#   ✅ Train/test R² gap acceptable (gap: -0.093)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE (grouped CV clean — regular CV unreliable)
#
# Top 10 feature importances:
#   height                                        0.2847  ==============
#   EVI                                           0.1573  =======
#   NIR                                           0.1150  =====
#   RE2                                           0.1016  =====
#   NBR                                           0.0834  ====
#   RE1                                           0.0764  ===
#   SWIR1                                         0.0718  ===
#   species_Rhizophora mangle                     0.0501  ==
#   species_Avicennia germinans                   0.0457  ==
#   species_Laguncularia racemosa                 0.0140
#
# [18/18]
#
#  RANDOM FOREST: EXPERIMENT-18 Plot groups Grid search: No, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? Yes, Grid? No
# Test R²     : 0.2771
# Test RMSE   : 3.92 kg
# Train R² (log scale): 0.4654
# Train R² (orig scale): 0.1865
# Train RMSE  : 16.75 kg
# Num rows    : 3100
# Num Features: 13
#
#  Cross-validation ---
# CV R² mean: 0.0583
# CV R² std : 0.3049
# CV scores : [-0.305  0.559  0.235 -0.124 -0.073]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.3001
# Grouped CV R² std : 0.2019
# Grouped CV scores : [-0.077  0.259  0.351 -0.039  0.456  0.57   0.513  0.335  0.348  0.286]
# ============================================================
#  EVALUATION: EXPERIMENT-18 Plot groups Grid search: No, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? Yes, Grid? No
# ============================================================
#
# Test set:
#   R²   : 0.277
#   RMSE : 3.92 kg
#
#  ✅ Test R² is positive (0.277)
#
# Regular CrossValidation:
#   Mean   : 0.058
#   Std    : 0.305
#   Scores : [-0.305  0.559  0.235 -0.124 -0.073]
#  ✅ CV mean is positive (0.058)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.077  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :   0.259  {GREEN_TICK}
#   Frenchman Caye_3     :   0.351  {GREEN_TICK}
#   Big Creek_3          :  -0.039  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.456  {GREEN_TICK}
#   Big Creek_2          :   0.570  {GREEN_TICK}
#   Drowned Caye_5       :   0.513  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.335  {GREEN_TICK}
#   Channel Caye_2       :   0.348  {GREEN_TICK}
#   Channel Caye_6       :   0.286  {GREEN_TICK}
#
#   Mean : 0.300
#   Std  : 0.202
#
#   ✅ Grouped CV mean above 0.15 (0.300)
#   ✅ Grouped CV std below 0.25 (0.202)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ✅ Grouped CV and test R² agree (gap: 0.023)
#   ✅ Train/test R² gap acceptable (gap: -0.091)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# Top 10 feature importances:
#   height                                        0.1727  ========
#   height_x_NIR                                  0.1448  =======
#   height_x_EVI                                  0.1434  =======
#   height_x_NDRE1                                0.1358  ======
#   EVI                                           0.0784  ===
#   NIR                                           0.0587  ==
#   RE2                                           0.0488  ==
#   species_Rhizophora mangle                     0.0479  ==
#   species_Avicennia germinans                   0.0417  ==
#   SWIR1                                         0.0400  =
#
# Completed: 18/18 experiments

# %%
tabulate_results(rf_belige_no_grid_grps, acceptable_only=True)
# Out:
# Showing 10 acceptable experiments
# <style type="text/css">
# #T_8336d_row0_col7, #T_8336d_row1_col2, #T_8336d_row2_col1, #T_8336d_row2_col2, #T_8336d_row3_col9, #T_8336d_row6_col8 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_8336d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8336d_level0_col0" class="col_heading level0 col0" >Experiment</th>
#       <th id="T_8336d_level0_col1" class="col_heading level0 col1" >Test R²</th>
#       <th id="T_8336d_level0_col2" class="col_heading level0 col2" >Test RMSE</th>
#       <th id="T_8336d_level0_col3" class="col_heading level0 col3" >Train R²</th>
#       <th id="T_8336d_level0_col4" class="col_heading level0 col4" >Train RMSE</th>
#       <th id="T_8336d_level0_col5" class="col_heading level0 col5" >CV R² Mean</th>
#       <th id="T_8336d_level0_col6" class="col_heading level0 col6" >CV R² Std</th>
#       <th id="T_8336d_level0_col7" class="col_heading level0 col7" >Group CV R² Mean</th>
#       <th id="T_8336d_level0_col8" class="col_heading level0 col8" >Group CV R² Std</th>
#       <th id="T_8336d_level0_col9" class="col_heading level0 col9" >CV-Test Gap</th>
#       <th id="T_8336d_level0_col10" class="col_heading level0 col10" >-ve Folds</th>
#       <th id="T_8336d_level0_col11" class="col_heading level0 col11" >verdict</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8336d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8336d_row0_col0" class="data row0 col0" >EXPERIMENT-14 Plot groups Grid search: No, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? Yes, Grid? No</td>
#       <td id="T_8336d_row0_col1" class="data row0 col1" >0.2396</td>
#       <td id="T_8336d_row0_col2" class="data row0 col2" >4.02</td>
#       <td id="T_8336d_row0_col3" class="data row0 col3" >0.1865</td>
#       <td id="T_8336d_row0_col4" class="data row0 col4" >16.75</td>
#       <td id="T_8336d_row0_col5" class="data row0 col5" >0.1022</td>
#       <td id="T_8336d_row0_col6" class="data row0 col6" >0.2779</td>
#       <td id="T_8336d_row0_col7" class="data row0 col7" >0.3072</td>
#       <td id="T_8336d_row0_col8" class="data row0 col8" >0.2064</td>
#       <td id="T_8336d_row0_col9" class="data row0 col9" >0.0676</td>
#       <td id="T_8336d_row0_col10" class="data row0 col10" >2 (Big Creek_5, Big Creek_3)</td>
#       <td id="T_8336d_row0_col11" class="data row0 col11" >⚠️  MARGINAL — positive metrics but concerns</td>
#     </tr>
#     <tr>
#       <th id="T_8336d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8336d_row1_col0" class="data row1 col0" >EXPERIMENT-18 Plot groups Grid search: No, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? Yes, Grid? No</td>
#       <td id="T_8336d_row1_col1" class="data row1 col1" >0.2771</td>
#       <td id="T_8336d_row1_col2" class="data row1 col2" >3.92</td>
#       <td id="T_8336d_row1_col3" class="data row1 col3" >0.1865</td>
#       <td id="T_8336d_row1_col4" class="data row1 col4" >16.75</td>
#       <td id="T_8336d_row1_col5" class="data row1 col5" >0.0583</td>
#       <td id="T_8336d_row1_col6" class="data row1 col6" >0.3049</td>
#       <td id="T_8336d_row1_col7" class="data row1 col7" >0.3001</td>
#       <td id="T_8336d_row1_col8" class="data row1 col8" >0.2019</td>
#       <td id="T_8336d_row1_col9" class="data row1 col9" >0.023</td>
#       <td id="T_8336d_row1_col10" class="data row1 col10" >2 (Big Creek_5, Big Creek_3)</td>
#       <td id="T_8336d_row1_col11" class="data row1 col11" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_8336d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8336d_row2_col0" class="data row2 col0" >EXPERIMENT-17 Plot groups Grid search: No, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2']., Model: rf, Grouping? Yes, Grid? No</td>
#       <td id="T_8336d_row2_col1" class="data row2 col1" >0.2797</td>
#       <td id="T_8336d_row2_col2" class="data row2 col2" >3.92</td>
#       <td id="T_8336d_row2_col3" class="data row2 col3" >0.1866</td>
#       <td id="T_8336d_row2_col4" class="data row2 col4" >16.75</td>
#       <td id="T_8336d_row2_col5" class="data row2 col5" >-0.0818</td>
#       <td id="T_8336d_row2_col6" class="data row2 col6" >0.4107</td>
#       <td id="T_8336d_row2_col7" class="data row2 col7" >0.2775</td>
#       <td id="T_8336d_row2_col8" class="data row2 col8" >0.2033</td>
#       <td id="T_8336d_row2_col9" class="data row2 col9" >0.0023</td>
#       <td id="T_8336d_row2_col10" class="data row2 col10" >1 (Big Creek_5)</td>
#       <td id="T_8336d_row2_col11" class="data row2 col11" >VERDICT: ✅ ACCEPTABLE (Reg CV unstable)</td>
#     </tr>
#     <tr>
#       <th id="T_8336d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8336d_row3_col0" class="data row3 col0" >EXPERIMENT-13 Plot groups Grid search: No, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1']., Model: rf, Grouping? Yes, Grid? No</td>
#       <td id="T_8336d_row3_col1" class="data row3 col1" >0.2648</td>
#       <td id="T_8336d_row3_col2" class="data row3 col2" >3.96</td>
#       <td id="T_8336d_row3_col3" class="data row3 col3" >0.1862</td>
#       <td id="T_8336d_row3_col4" class="data row3 col4" >16.75</td>
#       <td id="T_8336d_row3_col5" class="data row3 col5" >-0.0305</td>
#       <td id="T_8336d_row3_col6" class="data row3 col6" >0.3556</td>
#       <td id="T_8336d_row3_col7" class="data row3 col7" >0.266</td>
#       <td id="T_8336d_row3_col8" class="data row3 col8" >0.2125</td>
#       <td id="T_8336d_row3_col9" class="data row3 col9" >0.0012</td>
#       <td id="T_8336d_row3_col10" class="data row3 col10" >2 (Big Creek_5, Big Creek_3)</td>
#       <td id="T_8336d_row3_col11" class="data row3 col11" >VERDICT: ✅ ACCEPTABLE (Reg CV unstable)</td>
#     </tr>
#     <tr>
#       <th id="T_8336d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8336d_row4_col0" class="data row4 col0" >EXPERIMENT-2 Plot groups Grid search: No, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? Yes, Grid? No</td>
#       <td id="T_8336d_row4_col1" class="data row4 col1" >0.206</td>
#       <td id="T_8336d_row4_col2" class="data row4 col2" >4.11</td>
#       <td id="T_8336d_row4_col3" class="data row4 col3" >0.1658</td>
#       <td id="T_8336d_row4_col4" class="data row4 col4" >16.96</td>
#       <td id="T_8336d_row4_col5" class="data row4 col5" >0.164</td>
#       <td id="T_8336d_row4_col6" class="data row4 col6" >0.2314</td>
#       <td id="T_8336d_row4_col7" class="data row4 col7" >0.2578</td>
#       <td id="T_8336d_row4_col8" class="data row4 col8" >0.2159</td>
#       <td id="T_8336d_row4_col9" class="data row4 col9" >0.0518</td>
#       <td id="T_8336d_row4_col10" class="data row4 col10" >2 (Big Creek_5, Big Creek_3)</td>
#       <td id="T_8336d_row4_col11" class="data row4 col11" >⚠️  MARGINAL — positive metrics but concerns</td>
#     </tr>
#     <tr>
#       <th id="T_8336d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8336d_row5_col0" class="data row5 col0" >EXPERIMENT-12 Plot groups Grid search: No, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? Yes, Grid? No</td>
#       <td id="T_8336d_row5_col1" class="data row5 col1" >0.1853</td>
#       <td id="T_8336d_row5_col2" class="data row5 col2" >4.17</td>
#       <td id="T_8336d_row5_col3" class="data row5 col3" >0.1658</td>
#       <td id="T_8336d_row5_col4" class="data row5 col4" >16.96</td>
#       <td id="T_8336d_row5_col5" class="data row5 col5" >0.1315</td>
#       <td id="T_8336d_row5_col6" class="data row5 col6" >0.242</td>
#       <td id="T_8336d_row5_col7" class="data row5 col7" >0.2521</td>
#       <td id="T_8336d_row5_col8" class="data row5 col8" >0.2039</td>
#       <td id="T_8336d_row5_col9" class="data row5 col9" >0.0667</td>
#       <td id="T_8336d_row5_col10" class="data row5 col10" >2 (Big Creek

# %% [raw]
# **BEST EXPERIMENT**
#
# RANDOM FOREST: EXPERIMENT-9 Plot groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2'].
# Test R²     : 0.2797
# Test RMSE   : 3.92 kg
# Train R² (log scale): 0.4654
# Train R² (orig scale): 0.1866
# Train RMSE  : 16.75 kg
# Num rows    : 3100
# Num Features: 10
#
#  Cross-validation ---
# CV R² mean: -0.0818
# CV R² std : 0.4107
# CV scores : [-0.486  0.583  0.192 -0.246 -0.451]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2775
# Grouped CV R² std : 0.2033
# Grouped CV scores : [-0.099  0.108  0.36   0.004  0.413  0.563  0.519  0.301  0.329  0.275]
# ============================================================
#  EVALUATION: EXPERIMENT-9 Plot groups, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2'].
# ============================================================
#
# Test set:
#   R²   : 0.280
#   RMSE : 3.92 kg
#
# Regular CrossValidation:
#   Mean   : -0.082
#   Std    : 0.411
#   Scores : [-0.486  0.583  0.192 -0.246 -0.451]
#
#   ✅ Test R² is positive (0.280)
#   ❌ CV mean is negative (-0.082)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.099  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :   0.108  ✅
#   Frenchman Caye_3     :   0.360  ✅
#   Big Creek_3          :   0.004  ✅
#   Frenchman Caye_1     :   0.413  ✅
#   Big Creek_2          :   0.563  ✅
#   Drowned Caye_5       :   0.519  ✅
#   Gra Gra Lagoon_4     :   0.301  ✅
#   Channel Caye_2       :   0.329  ✅
#   Channel Caye_6       :   0.275  ✅
#
#   Mean : 0.277
#   Std  : 0.203
#
#   ✅ Grouped CV mean above 0.15 (0.277)
#   ✅ Grouped CV std below 0.25 (0.203)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ✅ Grouped CV and test R² agree (gap: 0.002)
#   ✅ Train/test R² gap acceptable (gap: -0.093)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ✅ ACCEPTABLE (grouped CV clean — regular CV unreliable)
#
# Top 10 feature importances:
#   height                                        0.2847  ==============
#   EVI                                           0.1573  =======
#   NIR                                           0.1150  =====
#   RE2                                           0.1016  =====
#   NBR                                           0.0834  ====
#   RE1                                           0.0764  ===
#   SWIR1                                         0.0718  ===
#   species_Rhizophora mangle                     0.0501  ==
#   species_Avicennia germinans                   0.0457  ==
#   species_Laguncularia racemosa                 0.0140

# %% [markdown]
# **"Big Creek_5          :  -0.099  ⚠️  near-zero variance artifact" - What does this mean?**
# This line is the output for one specific fold in the grouped cross-validation.
#
# **What is meant by fold?**
#  - In grouped cross-validation with 10 folds across 59 plots, each fold holds out a group of plots as the test set.
#  - For this fold, Big Creek_5 is the primary plot that was held out — meaning the model was trained on all other plots and then asked to predict AGB for plants in Big Creek_5.
#
# **What does -0.099 mean?**
#  - R² of -0.099 means the model performed worse than simply predicting the mean AGB for every plant in Big Creek_5.
#  - A model that just outputs the average AGB of the training set for every plant would score R² = 0.
#  - Scoring -0.099 means the model's predictions were actively worse than that baseline.
#
# **What does baseline mean?**
#  - The baseline is a dummy model that ignores all features entirely and simply predicts the mean AGB of the training set for every single plant.
#  - Say the mean AGB of all training plants is 8 kg. The baseline model would predict 8 kg for every plant in Big Creek_5, regardless of its height, spectral values, or species. No learning, no features — just the same number repeated for every plant.
#
# R² = 0 means your model performs exactly as well as this dummy baseline.
# R² > 0 means your model beats the dummy.
# R² < 0 means your model is worse than the dummy — it would have been better to just predict the mean for everyone.
#
#
# **Why this happens — the near-zero variance problem?**
#  - Big Creek_5 is one of the near-zero variance plots.
#  - Its plants all weigh almost nothing — the AGB values are clustered extremely tightly around a very small number like 0.003 kg.
#
# R² is computed as:
# R² = 1 - (sum of squared residuals / variance of test set)
#
# When the test set has near-zero variance — meaning all true values are almost identical — the denominator approaches zero. Even a very small prediction error in the numerator produces a catastrophically bad R² score.
# So -0.128 does not mean the model made large errors. It means the denominator was so small that even tiny errors look catastrophic mathematically.
#
#
# **Why it is labelled ⚠️ and not ❌?**
#  - The ⚠️ near-zero variance artifact label means the evaluation function identified this as a mathematical breakdown of the R² metric rather than a genuine model failure.
#  - The model is not failing to predict AGB for Big Creek_5 plants — it simply cannot be evaluated with R² on a holdout set where all true values are essentially the same number.
#  -  This is why these folds are excluded from the high-AGB failure check and from the unexplained negatives check. They are not counted against the model.
#
# **Why this happens for Big Creek_5?**
#  - Big Creek_5 plants all weigh around 0.003 kg.
#  - The training set mean is much higher — say 8 kg.
#  - So the dummy baseline predicts 8 kg for every Big Creek_5 plant, which is already a terrible prediction.
#  - Your model predicts something different — perhaps 2 kg or 5 kg based on the spectral features — which is also wrong, but the R² formula punishes it even more harshly than the dummy because the variance of the test set is essentially zero.
#  - So the -0.128 is not saying the model predicted worse than 8 kg for every plant. It is saying the R² formula, given near-zero variance in the test set, makes the model look worse than the dummy even when both are making similarly bad predictions. This is the mathematical artifact we have been labelling as ⚠️.

# %% [raw]
# Why every RF grouped CV run has negative folds
# All the negative folds come from the same plots — Big Creek_5, Big Creek_3, Frenchman Caye plots, and occasionally others in the near-zero variance group. These are the same plots that caused problems in linear regression too, but they are worse for Random Forest for a specific reason.
#
# Linear regression produces a smooth prediction surface — it interpolates. When it sees a near-zero variance holdout set, its predictions are usually close to the mean, which keeps R² near zero rather than deeply negative.
#
# Random Forest does not interpolate. It predicts by averaging leaf nodes from trees that were built on the training data. When a near-zero variance plot is held out, the trees were never trained on plants with that particular combination of near-zero AGB and specific spectral values. The forest makes predictions based on similar-looking plants it has seen — which may be plants from normal AGB plots — and those predictions can be far from the near-zero true values. This produces larger residuals and more negative R² values than linear regression produces on the same folds.
#
# Is this a problem for the passing experiments?
#  - For experiments 7, 8, and 9 — no.
#  - Every negative fold is correctly labelled as a near-zero variance artifact.
#  - The non-near-zero folds all score positively and consistently.
#  - The model is not genuinely failing — it is hitting the same mathematical limitation of R² on near-zero variance holdout sets that was established earlier.
#
# What would be a problem
# If negative folds appeared in normal-AGB plots like Drowned Caye, Gra Gra Lagoon, or Channel Caye without explanation — that would indicate genuine generalisation failure.
# Looking at experiments 7 and 9:
#  - Exp 7  — only Big Creek_5 (-0.157) and Big Creek_3 (-0.013) are negative — both near-zero
#  - Exp 9  — only Big Creek_5 (-0.099) is negative — near-zero
#  - The high-AGB sites (Channel Caye, Drowned Caye, Big Creek_2) all score positively. That is the important signal.
#
#
# One thing worth tracking
# The magnitude of the near-zero fold scores is larger for Random Forest than for linear regression. For example Frenchman Caye_6 scores -1.330 in RF experiment 2 versus -0.312 in the equivalent linear regression experiment. This is consistent with what was described above — RF makes more extreme errors on near-zero variance holdouts. This does not affect the verdict logic but is worth mentioning to sponsors as a characteristic of the algorithm rather than a failure of the model.

# %% [markdown]
# ### BELIGE DATA. PLOT GROUPS. ALL ROWS. RANDOM FOREST (Hyper parameter tuning: Yes)

# %%
# %run Model_functions.ipynb

rf_belige_grid_grps = {}

run_experiment(X_belige, y_belige,
               is_groups=True, group_info=grp_belige,
               features_list=gen_features_list,
               experiments=rf_belige_grid_grps,
               model_type="rf", is_grid=True,
               is_stratified=is_stratified_g,
               global_experiment_list=global_experiment_list)
# Out:
# chmod: /Users/kosaraju_b/.local/share/jupyter/history.sqlite: No such file or directory
#
# [1/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# Best params: {'n_estimators': 100, 'min_samples_leaf': 4, 'max_samples': 0.6, 'max_features': 'sqrt', 'max_depth': 5}
#
#  RANDOM FOREST: EXPERIMENT-1 Plot groups Grid search: Yes, Features: ['height']., Model: rf, Grouping? Yes, Grid? Yes
# Test R²     : 0.1378
# Test RMSE   : 4.29 kg
# Train R² (log scale): 0.3906
# Train R² (orig scale): 0.1398
# Train RMSE  : 17.22 kg
# Num rows    : 3100
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: 0.1506
# CV R² std : 0.2367
# CV scores : [-0.184  0.537  0.168  0.207  0.026]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2464
# Grouped CV R² std : 0.2156
# Grouped CV scores : [ 0.072 -0.018  0.237 -0.162  0.427  0.555  0.491  0.265  0.25   0.346]
# ============================================================
#  EVALUATION: EXPERIMENT-1 Plot groups Grid search: Yes, Features: ['height']., Model: rf, Grouping? Yes, Grid? Yes
# ============================================================
#
# Test set:
#   R²   : 0.138
#   RMSE : 4.29 kg
#
#  ✅ Test R² is positive (0.138)
#
# Regular CrossValidation:
#   Mean   : 0.151
#   Std    : 0.237
#   Scores : [-0.184  0.537  0.168  0.207  0.026]
#  ✅ CV mean is positive (0.151)
#
# Grouped CrossValidation:
#   Big Creek_5          :   0.072  {GREEN_TICK}
#   Frenchman Caye_6     :  -0.018  {WARNING}  near-zero variance artifact
#   Frenchman Caye_3     :   0.237  {GREEN_TICK}
#   Big Creek_3          :  -0.162  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.427  {GREEN_TICK}
#   Big Creek_2          :   0.555  {GREEN_TICK}
#   Drowned Caye_5       :   0.491  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.265  {GREEN_TICK}
#   Channel Caye_2       :   0.250  {GREEN_TICK}
#   Channel Caye_6       :   0.346  {GREEN_TICK}
#
#   Mean : 0.246
#   Std  : 0.216
#
#   ✅ Grouped CV mean above 0.15 (0.246)
#   ✅ Grouped CV std below 0.25 (0.216)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.109 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: 0.002)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {WARNING}  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height                                        1.0000  ==================================================
#
# [2/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'n_estimators': 200, 'min_samples_leaf': 2, 'max_samples': 1.0, 'max_features': 0.3, 'max_depth': 5}
#
#  RANDOM FOREST: EXPERIMENT-2 Plot groups Grid search: Yes, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? Yes, Grid? Yes
# Test R²     : 0.2064
# Test RMSE   : 4.11 kg
# Train R² (log scale): 0.3846
# Train R² (orig scale): 0.1547
# Train RMSE  : 17.07 kg
# Num rows    : 3100
# Num Features: 4
#
#  Cross-validation ---
# CV R² mean: 0.2310
# CV R² std : 0.2173
# CV scores : [-0.077  0.598  0.151  0.249  0.233]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2625
# Grouped CV R² std : 0.2096
# Grouped CV scores : [-0.057  0.167  0.231 -0.097  0.446  0.588  0.489  0.271  0.243  0.344]
# ============================================================
#  EVALUATION: EXPERIMENT-2 Plot groups Grid search: Yes, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? Yes, Grid? Yes
# ============================================================
#
# Test set:
#   R²   : 0.206
#   RMSE : 4.11 kg
#
#  ✅ Test R² is positive (0.206)
#
# Regular CrossValidation:
#   Mean   : 0.231
#   Std    : 0.217
#   Scores : [-0.077  0.598  0.151  0.249  0.233]
#  ✅ CV mean is positive (0.231)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.057  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :   0.167  {GREEN_TICK}
#   Frenchman Caye_3     :   0.231  {GREEN_TICK}
#   Big Creek_3          :  -0.097  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.446  {GREEN_TICK}
#   Big Creek_2          :   0.588  {GREEN_TICK}
#   Drowned Caye_5       :   0.489  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.271  {GREEN_TICK}
#   Channel Caye_2       :   0.243  {GREEN_TICK}
#   Channel Caye_6       :   0.344  {GREEN_TICK}
#
#   Mean : 0.262
#   Std  : 0.210
#
#   ✅ Grouped CV mean above 0.15 (0.262)
#   ✅ Grouped CV std below 0.25 (0.210)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.056 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.052)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {WARNING}  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height_x_NIR                                  0.2773  =============
#   height_x_EVI                                  0.2527  ============
#   height                                        0.2374  ===========
#   height_x_NDRE1                                0.2327  ===========
#
# [3/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'n_estimators': 100, 'min_samples_leaf': 8, 'max_samples': 0.6, 'max_features': 0.3, 'max_depth': 5}
#
#  RANDOM FOREST: EXPERIMENT-3 Plot groups Grid search: Yes, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2']., Model: rf, Grouping? Yes, Grid? Yes
# Test R²     : 0.2603
# Test RMSE   : 3.97 kg
# Train R² (log scale): 0.3693
# Train R² (orig scale): 0.0690
# Train RMSE  : 17.92 kg
# Num rows    : 3100
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: -0.1667
# CV R² std : 0.5528
# CV scores : [-0.078  0.529  0.117 -0.262 -1.139]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1198
# Grouped CV R² std : 0.3539
# Grouped CV scores : [-0.12  -0.786  0.207 -0.001  0.357  0.417  0.544  0.254  0.219  0.107]
# ============================================================
#  EVALUATION: EXPERIMENT-3 Plot groups Grid search: Yes, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2']., Model: rf, Grouping? Yes, Grid? Yes
# ============================================================
#
# Test set:
#   R²   : 0.260
#   RMSE : 3.97 kg
#
#  ✅ Test R² is positive (0.260)
#
# Regular CrossValidation:
#   Mean   : -0.167
#   Std    : 0.553
#   Scores : [-0.078  0.529  0.117 -0.262 -1.139]
#  ❌ CV mean is negative (-0.167)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.120  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :  -0.786  {WARNING}  near-zero variance artifact
#   Frenchman Caye_3     :   0.207  {GREEN_TICK}
#   Big Creek_3          :  -0.001  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.357  {GREEN_TICK}
#   Big Creek_2          :   0.417  {GREEN_TICK}
#   Drowned Caye_5       :   0.544  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.254  {GREEN_TICK}
#   Channel Caye_2       :   0.219  {GREEN_TICK}
#   Channel Caye_6       :   0.107  {GREEN_TICK}
#
#   Mean : 0.120
#   Std  : 0.354
#
#   ❌ Grouped CV mean below 0.15 (0.120)
#   ⚠️  Grouped CV std above 0.25 (0.354) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.140 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.191)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {RED_CROSS} REJECTED
#
# Top 10 feature importances:
#   NIR                                           0.1587  =======
#   Green                                         0.1483  =======
#   RE3                                           0.1260  ======
#   Red                                           0.1218  ======
#   RE1                                           0.1214  ======
#   RE2                                           0.1191  =====
#   SWIR1                                         0.0982  ====
#   Blue                                          0.0614  ===
#   SWIR2                                         0.0451  ==
#
# [4/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'n_estimators': 100, 'min_samples_leaf': 4, 'max_samples': 1.0, 'max_features': 0.5, 'max_depth': 5}
#
#  RANDOM FOREST: EXPERIMENT-4 Plot groups Grid search: Yes, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? Yes, Grid? Yes
# Test R²     : 0.2433
# Test RMSE   : 4.01 kg
# Train R² (log scale): 0.3864
# Train R² (orig scale): 0.1596
# Train RMSE  : 17.02 kg
# Num rows    : 3100
# Num Features: 12
#
#  Cross-validation ---
# CV R² mean: 0.0771
# CV R² std : 0.1962
# CV scores : [-0.099  0.456  0.057  0.001 -0.03 ]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2526
# Grouped CV R² std : 0.2050
# Grouped CV scores : [-0.14   0.175  0.246 -0.049  0.456  0.505  0.492  0.274  0.239  0.328]
# ============================================================
#  EVALUATION: EXPERIMENT-4 Plot groups Grid search: Yes, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? Yes, Grid? Yes
# ============================================================
#
# Test set:
#   R²   : 0.243
#   RMSE : 4.01 kg
#
#  ✅ Test R² is positive (0.243)
#
# Regular CrossValidation:
#   Mean   : 0.077
#   Std    : 0.196
#   Scores : [-0.099  0.456  0.057  0.001 -0.03 ]
#  ✅ CV mean is positive (0.077)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.140  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :   0.175  {GREEN_TICK}
#   Frenchman Caye_3     :   0.246  {GREEN_TICK}
#   Big Creek_3          :  -0.049  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.456  {GREEN_TICK}
#   Big Creek_2          :   0.505  {GREEN_TICK}
#   Drowned Caye_5       :   0.492  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.274  {GREEN_TICK}
#   Channel Caye_2       :   0.239  {GREEN_TICK}
#   Channel Caye_6       :   0.328  {GREEN_TICK}
#
#   Mean : 0.253
#   Std  : 0.205
#
#   ✅ Grouped CV mean above 0.15 (0.253)
#   ✅ Grouped CV std below 0.25 (0.205)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ✅ Grouped CV and test R² agree (gap: 0.009)
#   ✅ Train/test R² gap acceptable (gap: -0.084)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# Top 10 feature importances:
#   height_x_NDRE1                                0.3614  ==================
#   height_x_NIR                                  0.2355  ===========
#   height_x_EVI                                  0.2083  ==========
#   NIR                                           0.0454  ==
#   RE3                                           0.0365  =
#   RE2                                           0.0283  =
#   SWIR2                                         0.0256  =
#   SWIR1                                         0.0169
#   Green                                         0.0160
#   Red                                           0.0146
#
# [5/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'n_estimators': 100, 'min_samples_leaf': 8, 'max_samples': 0.8, 'max_features': 0.3, 'max_depth': 5}
#
#  RANDOM FOREST: EXPERIMENT-5 Plot groups Grid search: Yes, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: rf, Grouping? Yes, Grid? Yes
# Test R²     : 0.2400
# Test RMSE   : 4.02 kg
# Train R² (log scale): 0.3765
# Train R² (orig scale): 0.1324
# Train RMSE  : 17.30 kg
# Num rows    : 3100
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: -0.3177
# CV R² std : 0.9823
# CV scores : [-0.075  0.598  0.143 -0.031 -2.224]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.0296
# Grouped CV R² std : 0.8320
# Grouped CV scores : [-0.041 -2.427  0.012 -0.114  0.415  0.589  0.595  0.19   0.243  0.241]
# ============================================================
#  EVALUATION: EXPERIMENT-5 Plot groups Grid search: Yes, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: rf, Grouping? Yes, Grid? Yes
# ============================================================
#
# Test set:
#   R²   : 0.240
#   RMSE : 4.02 kg
#
#  ✅ Test R² is positive (0.240)
#
# Regular CrossValidation:
#   Mean   : -0.318
#   Std    : 0.982
#   Scores : [-0.075  0.598  0.143 -0.031 -2.224]
#  ❌ CV mean is negative (-0.318)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.041  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :  -2.427  {WARNING}  near-zero variance artifact
#   Frenchman Caye_3     :   0.012  {GREEN_TICK}
#   Big Creek_3          :  -0.114  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.415  {GREEN_TICK}
#   Big Creek_2          :   0.589  {GREEN_TICK}
#   Drowned Caye_5       :   0.595  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.190  {GREEN_TICK}
#   Channel Caye_2       :   0.243  {GREEN_TICK}
#   Channel Caye_6       :   0.241  {GREEN_TICK}
#
#   Mean : -0.030
#   Std  : 0.832
#
#   ❌ Grouped CV mean below 0.15 (-0.030)
#   ⚠️  Grouped CV std above 0.25 (0.832) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.270 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.108)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {RED_CROSS} REJECTED
#
# Top 10 feature importances:
#   NDRE1                                         0.2117  ==========
#   CIrededge                                     0.2085  ==========
#   EVI                                           0.1619  ========
#   NDVI                                          0.1137  =====
#   NBR                                           0.0865  ====
#   NDRE3                                         0.0794  ===
#   NDRE2                                         0.0725  ===
#   MNDWI                                         0.0657  ===
#   CLOUD_COVERAGE                                0.0000
#
# [6/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'n_estimators': 200, 'min_samples_leaf': 2, 'max_samples': 1.0, 'max_features': 0.5, 'max_depth': 5}
#
#  RANDOM FOREST: EXPERIMENT-6 Plot groups Grid search: Yes, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? Yes, Grid? Yes
# Test R²     : 0.1282
# Test RMSE   : 4.31 kg
# Train R² (log scale): 0.3868
# Train R² (orig scale): 0.1597
# Train RMSE  : 17.02 kg
# Num rows    : 3100
# Num Features: 12
#
#  Cross-validation ---
# CV R² mean: 0.0973
# CV R² std : 0.2974
# CV scores : [-0.094  0.627  0.171  0.024 -0.241]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2248
# Grouped CV R² std : 0.2892
# Grouped CV scores : [-0.079 -0.312  0.239 -0.081  0.476  0.585  0.623  0.256  0.215  0.326]
# ============================================================
#  EVALUATION: EXPERIMENT-6 Plot groups Grid search: Yes, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? Yes, Grid? Yes
# ============================================================
#
# Test set:
#   R²   : 0.128
#   RMSE : 4.31 kg
#
#  ✅ Test R² is positive (0.128)
#
# Regular CrossValidation:
#   Mean   : 0.097
#   Std    : 0.297
#   Scores : [-0.094  0.627  0.171  0.024 -0.241]
#  ✅ CV mean is positive (0.097)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.079  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :  -0.312  {WARNING}  near-zero variance artifact
#   Frenchman Caye_3     :   0.239  {GREEN_TICK}
#   Big Creek_3          :  -0.081  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.476  {GREEN_TICK}
#   Big Creek_2          :   0.585  {GREEN_TICK}
#   Drowned Caye_5       :   0.623  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.256  {GREEN_TICK}
#   Channel Caye_2       :   0.215  {GREEN_TICK}
#   Channel Caye_6       :   0.326  {GREEN_TICK}
#
#   Mean : 0.225
#   Std  : 0.289
#
#   ✅ Grouped CV mean above 0.15 (0.225)
#   ⚠️  Grouped CV std above 0.25 (0.289) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.097 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: 0.032)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {WARNING}  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height_x_NDRE1                                0.3147  ===============
#   height_x_NIR                                  0.2409  ============
#   height_x_EVI                                  0.2007  ==========
#   NDRE1                                         0.0640  ===
#   EVI                                           0.0466  ==
#   CIrededge                                     0.0405  ==
#   MNDWI                                         0.0314  =
#   NBR                                           0.0211  =
#   NDRE2                                         0.0164
#   NDVI                                          0.0160
#
# [7/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'n_estimators': 100, 'min_samples_leaf': 8, 'max_samples': 1.0, 'max_features': 'sqrt', 'max_depth': 15}
#
#  RANDOM FOREST: EXPERIMENT-7 Plot groups Grid search: Yes, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: rf, Grouping? Yes, Grid? Yes
# Test R²     : 0.2516
# Test RMSE   : 3.99 kg
# Train R² (log scale): 0.4035
# Train R² (orig scale): 0.1553
# Train RMSE  : 17.07 kg
# Num rows    : 3100
# Num Features: 18
#
#  Cross-validation ---
# CV R² mean: -0.1934
# CV R² std : 0.6384
# CV scores : [-0.073  0.653 -0.004 -0.222 -1.321]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.0952
# Grouped CV R² std : 1.0957
# Grouped CV scores : [-0.157 -3.305  0.245 -0.057  0.449  0.57   0.637  0.246  0.249  0.171]
# ============================================================
#  EVALUATION: EXPERIMENT-7 Plot groups Grid search: Yes, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']., Model: rf, Grouping? Yes, Grid? Yes
# ============================================================
#
# Test set:
#   R²   : 0.252
#   RMSE : 3.99 kg
#
#  ✅ Test R² is positive (0.252)
#
# Regular CrossValidation:
#   Mean   : -0.193
#   Std    : 0.638
#   Scores : [-0.073  0.653 -0.004 -0.222 -1.321]
#  ❌ CV mean is negative (-0.193)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.157  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :  -3.305  {WARNING}  near-zero variance artifact
#   Frenchman Caye_3     :   0.245  {GREEN_TICK}
#   Big Creek_3          :  -0.057  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.449  {GREEN_TICK}
#   Big Creek_2          :   0.570  {GREEN_TICK}
#   Drowned Caye_5       :   0.637  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.246  {GREEN_TICK}
#   Channel Caye_2       :   0.249  {GREEN_TICK}
#   Channel Caye_6       :   0.171  {GREEN_TICK}
#
#   Mean : -0.095
#   Std  : 1.096
#
#   ❌ Grouped CV mean below 0.15 (-0.095)
#   ⚠️  Grouped CV std above 0.25 (1.096) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.347 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.096)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {RED_CROSS} REJECTED
#
# Top 10 feature importances:
#   NDRE1                                         0.1298  ======
#   CIrededge                                     0.1159  =====
#   RE3                                           0.1062  =====
#   EVI                                           0.0959  ====
#   NIR                                           0.0900  ====
#   RE2                                           0.0635  ===
#   NBR                                           0.0532  ==
#   NDRE2                                         0.0531  ==
#   SWIR1                                         0.0492  ==
#   Red                                           0.0460  ==
#
# [8/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'n_estimators': 500, 'min_samples_leaf': 4, 'max_samples': 1.0, 'max_features': 0.5, 'max_depth': 5}
#
#  RANDOM FOREST: EXPERIMENT-8 Plot groups Grid search: Yes, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? Yes, Grid? Yes
# Test R²     : 0.2114
# Test RMSE   : 4.10 kg
# Train R² (log scale): 0.3898
# Train R² (orig scale): 0.1599
# Train RMSE  : 17.02 kg
# Num rows    : 3100
# Num Features: 21
#
#  Cross-validation ---
# CV R² mean: 0.0280
# CV R² std : 0.3321
# CV scores : [-0.099  0.591  0.12  -0.049 -0.423]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1823
# Grouped CV R² std : 0.3514
# Grouped CV scores : [-0.133 -0.634  0.249 -0.06   0.459  0.517  0.62   0.265  0.223  0.316]
# ============================================================
# ...
#   Channel Caye_6       :   0.278  {GREEN_TICK}
#
#   Mean : 0.271
#   Std  : 0.203
#
#   ✅ Grouped CV mean above 0.15 (0.271)
#   ✅ Grouped CV std below 0.25 (0.203)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ✅ Grouped CV and test R² agree (gap: 0.033)
#   ✅ Train/test R² gap acceptable (gap: -0.094)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# Top 10 feature importances:
#   height                                        0.3217  ================
#   EVI                                           0.1971  =========
#   NIR                                           0.1708  ========
#   SWIR1                                         0.1136  =====
#   NBR                                           0.1060  =====
#   species_Rhizophora mangle                     0.0448  ==
#   species_Avicennia germinans                   0.0423  ==
#   species_Laguncularia racemosa                 0.0038
#
# [14/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'n_estimators': 100, 'min_samples_leaf': 8, 'max_samples': 0.8, 'max_features': 0.3, 'max_depth': 5}
#
#  RANDOM FOREST: EXPERIMENT-14 Plot groups Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? Yes, Grid? Yes
# Test R²     : 0.2252
# Test RMSE   : 4.06 kg
# Train R² (log scale): 0.4153
# Train R² (orig scale): 0.1594
# Train RMSE  : 17.03 kg
# Num rows    : 3100
# Num Features: 11
#
#  Cross-validation ---
# CV R² mean: 0.2001
# CV R² std : 0.2096
# CV scores : [-0.08   0.548  0.241  0.067  0.226]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.3019
# Grouped CV R² std : 0.2025
# Grouped CV scores : [-0.057  0.279  0.295 -0.043  0.457  0.591  0.525  0.346  0.28   0.346]
# ============================================================
#  EVALUATION: EXPERIMENT-14 Plot groups Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? Yes, Grid? Yes
# ============================================================
#
# Test set:
#   R²   : 0.225
#   RMSE : 4.06 kg
#
#  ✅ Test R² is positive (0.225)
#
# Regular CrossValidation:
#   Mean   : 0.200
#   Std    : 0.210
#   Scores : [-0.08   0.548  0.241  0.067  0.226]
#  ✅ CV mean is positive (0.200)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.057  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :   0.279  {GREEN_TICK}
#   Frenchman Caye_3     :   0.295  {GREEN_TICK}
#   Big Creek_3          :  -0.043  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.457  {GREEN_TICK}
#   Big Creek_2          :   0.591  {GREEN_TICK}
#   Drowned Caye_5       :   0.525  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.346  {GREEN_TICK}
#   Channel Caye_2       :   0.280  {GREEN_TICK}
#   Channel Caye_6       :   0.346  {GREEN_TICK}
#
#   Mean : 0.302
#   Std  : 0.203
#
#   ✅ Grouped CV mean above 0.15 (0.302)
#   ✅ Grouped CV std below 0.25 (0.203)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.077 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.066)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {WARNING}  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height_x_NDRE1                                0.2772  =============
#   height                                        0.1701  ========
#   height_x_NIR                                  0.1630  ========
#   height_x_EVI                                  0.1327  ======
#   NIR                                           0.0606  ===
#   EVI                                           0.0597  ==
#   species_Avicennia germinans                   0.0359  =
#   SWIR1                                         0.0353  =
#   species_Rhizophora mangle                     0.0328  =
#   NBR                                           0.0322  =
#
# [15/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'n_estimators': 100, 'min_samples_leaf': 8, 'max_samples': 0.6, 'max_features': 0.5, 'max_depth': 5}
#
#  RANDOM FOREST: EXPERIMENT-15 Plot groups Grid search: Yes, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2']., Model: rf, Grouping? Yes, Grid? Yes
# Test R²     : 0.0879
# Test RMSE   : 4.41 kg
# Train R² (log scale): 0.3911
# Train R² (orig scale): 0.1320
# Train RMSE  : 17.30 kg
# Num rows    : 3100
# Num Features: 7
#
#  Cross-validation ---
# CV R² mean: 0.0574
# CV R² std : 0.3032
# CV scores : [-0.258  0.598  0.157 -0.058 -0.152]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1796
# Grouped CV R² std : 0.3005
# Grouped CV scores : [-0.094 -0.529  0.234 -0.019  0.402  0.489  0.521  0.263  0.252  0.277]
# ============================================================
#  EVALUATION: EXPERIMENT-15 Plot groups Grid search: Yes, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2']., Model: rf, Grouping? Yes, Grid? Yes
# ============================================================
#
# Test set:
#   R²   : 0.088
#   RMSE : 4.41 kg
#
#  ✅ Test R² is positive (0.088)
#
# Regular CrossValidation:
#   Mean   : 0.057
#   Std    : 0.303
#   Scores : [-0.258  0.598  0.157 -0.058 -0.152]
#  ✅ CV mean is positive (0.057)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.094  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :  -0.529  {WARNING}  near-zero variance artifact
#   Frenchman Caye_3     :   0.234  {GREEN_TICK}
#   Big Creek_3          :  -0.019  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.402  {GREEN_TICK}
#   Big Creek_2          :   0.489  {GREEN_TICK}
#   Drowned Caye_5       :   0.521  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.263  {GREEN_TICK}
#   Channel Caye_2       :   0.252  {GREEN_TICK}
#   Channel Caye_6       :   0.277  {GREEN_TICK}
#
#   Mean : 0.180
#   Std  : 0.300
#
#   ✅ Grouped CV mean above 0.15 (0.180)
#   ⚠️  Grouped CV std above 0.25 (0.300) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.092 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: 0.044)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {WARNING}  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height                                        0.4305  =====================
#   EVI                                           0.1667  ========
#   NIR                                           0.1262  ======
#   NBR                                           0.0858  ====
#   RE2                                           0.0826  ====
#   SWIR1                                         0.0597  ==
#   RE1                                           0.0486  ==
#
# [16/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'n_estimators': 200, 'min_samples_leaf': 2, 'max_samples': 1.0, 'max_features': 0.5, 'max_depth': 5}
#
#  RANDOM FOREST: EXPERIMENT-16 Plot groups Grid search: Yes, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? Yes, Grid? Yes
# Test R²     : 0.0873
# Test RMSE   : 4.41 kg
# Train R² (log scale): 0.3867
# Train R² (orig scale): 0.1598
# Train RMSE  : 17.02 kg
# Num rows    : 3100
# Num Features: 10
#
#  Cross-validation ---
# CV R² mean: 0.1790
# CV R² std : 0.2407
# CV scores : [-0.112  0.599  0.16   0.018  0.23 ]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2490
# Grouped CV R² std : 0.1845
# Grouped CV scores : [-0.078  0.194  0.238 -0.06   0.447  0.423  0.489  0.262  0.237  0.338]
# ============================================================
#  EVALUATION: EXPERIMENT-16 Plot groups Grid search: Yes, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? Yes, Grid? Yes
# ============================================================
#
# Test set:
#   R²   : 0.087
#   RMSE : 4.41 kg
#
#  ✅ Test R² is positive (0.087)
#
# Regular CrossValidation:
#   Mean   : 0.179
#   Std    : 0.241
#   Scores : [-0.112  0.599  0.16   0.018  0.23 ]
#  ✅ CV mean is positive (0.179)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.078  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :   0.194  {GREEN_TICK}
#   Frenchman Caye_3     :   0.238  {GREEN_TICK}
#   Big Creek_3          :  -0.060  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.447  {GREEN_TICK}
#   Big Creek_2          :   0.423  {GREEN_TICK}
#   Drowned Caye_5       :   0.489  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.262  {GREEN_TICK}
#   Channel Caye_2       :   0.237  {GREEN_TICK}
#   Channel Caye_6       :   0.338  {GREEN_TICK}
#
#   Mean : 0.249
#   Std  : 0.185
#
#   ✅ Grouped CV mean above 0.15 (0.249)
#   ✅ Grouped CV std below 0.25 (0.185)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.162 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: 0.072)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {WARNING}  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height                                        0.2837  ==============
#   height_x_NDRE1                                0.2553  ============
#   height_x_EVI                                  0.1470  =======
#   height_x_NIR                                  0.1457  =======
#   EVI                                           0.0510  ==
#   NIR                                           0.0325  =
#   SWIR1                                         0.0288  =
#   RE2                                           0.0236  =
#   NBR                                           0.0221  =
#   RE1                                           0.0103
#
# [17/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'n_estimators': 200, 'min_samples_leaf': 2, 'max_samples': 1.0, 'max_features': 0.3, 'max_depth': 5}
#
#  RANDOM FOREST: EXPERIMENT-17 Plot groups Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2']., Model: rf, Grouping? Yes, Grid? Yes
# Test R²     : 0.2161
# Test RMSE   : 4.09 kg
# Train R² (log scale): 0.4181
# Train R² (orig scale): 0.1628
# Train RMSE  : 16.99 kg
# Num rows    : 3100
# Num Features: 10
#
#  Cross-validation ---
# CV R² mean: 0.0675
# CV R² std : 0.3067
# CV scores : [-0.193  0.606  0.213 -0.113 -0.176]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2669
# Grouped CV R² std : 0.1953
# Grouped CV scores : [-0.067  0.109  0.291 -0.015  0.411  0.544  0.521  0.311  0.273  0.291]
# ============================================================
#  EVALUATION: EXPERIMENT-17 Plot groups Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2']., Model: rf, Grouping? Yes, Grid? Yes
# ============================================================
#
# Test set:
#   R²   : 0.216
#   RMSE : 4.09 kg
#
#  ✅ Test R² is positive (0.216)
#
# Regular CrossValidation:
#   Mean   : 0.068
#   Std    : 0.307
#   Scores : [-0.193  0.606  0.213 -0.113 -0.176]
#  ✅ CV mean is positive (0.068)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.067  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :   0.109  {GREEN_TICK}
#   Frenchman Caye_3     :   0.291  {GREEN_TICK}
#   Big Creek_3          :  -0.015  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.411  {GREEN_TICK}
#   Big Creek_2          :   0.544  {GREEN_TICK}
#   Drowned Caye_5       :   0.521  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.311  {GREEN_TICK}
#   Channel Caye_2       :   0.273  {GREEN_TICK}
#   Channel Caye_6       :   0.291  {GREEN_TICK}
#
#   Mean : 0.267
#   Std  : 0.195
#
#   ✅ Grouped CV mean above 0.15 (0.267)
#   ✅ Grouped CV std below 0.25 (0.195)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.051 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.053)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {WARNING}  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height                                        0.3062  ===============
#   EVI                                           0.1448  =======
#   NIR                                           0.1311  ======
#   RE2                                           0.1061  =====
#   RE1                                           0.0787  ===
#   NBR                                           0.0780  ===
#   SWIR1                                         0.0715  ===
#   species_Rhizophora mangle                     0.0418  ==
#   species_Avicennia germinans                   0.0392  =
#   species_Laguncularia racemosa                 0.0026
#
# [18/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'n_estimators': 200, 'min_samples_leaf': 2, 'max_samples': 1.0, 'max_features': 0.3, 'max_depth': 5}
#
#  RANDOM FOREST: EXPERIMENT-18 Plot groups Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? Yes, Grid? Yes
# Test R²     : 0.2271
# Test RMSE   : 4.06 kg
# Train R² (log scale): 0.4171
# Train R² (orig scale): 0.1699
# Train RMSE  : 16.92 kg
# Num rows    : 3100
# Num Features: 13
#
#  Cross-validation ---
# CV R² mean: 0.1739
# CV R² std : 0.2411
# CV scores : [-0.1    0.603  0.239  0.023  0.104]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2937
# Grouped CV R² std : 0.1991
# Grouped CV scores : [-0.054  0.245  0.296 -0.045  0.454  0.573  0.518  0.327  0.276  0.346]
# ============================================================
#  EVALUATION: EXPERIMENT-18 Plot groups Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? Yes, Grid? Yes
# ============================================================
#
# Test set:
#   R²   : 0.227
#   RMSE : 4.06 kg
#
#  ✅ Test R² is positive (0.227)
#
# Regular CrossValidation:
#   Mean   : 0.174
#   Std    : 0.241
#   Scores : [-0.1    0.603  0.239  0.023  0.104]
#  ✅ CV mean is positive (0.174)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.054  ⚠️  fold contamination — Channel Caye_1 in same fold
#   Frenchman Caye_6     :   0.245  {GREEN_TICK}
#   Frenchman Caye_3     :   0.296  {GREEN_TICK}
#   Big Creek_3          :  -0.045  ⚠️  fold contamination — Channel Caye_3 in same fold
#   Frenchman Caye_1     :   0.454  {GREEN_TICK}
#   Big Creek_2          :   0.573  {GREEN_TICK}
#   Drowned Caye_5       :   0.518  {GREEN_TICK}
#   Gra Gra Lagoon_4     :   0.327  {GREEN_TICK}
#   Channel Caye_2       :   0.276  {GREEN_TICK}
#   Channel Caye_6       :   0.346  {GREEN_TICK}
#
#   Mean : 0.294
#   Std  : 0.199
#
#   ✅ Grouped CV mean above 0.15 (0.294)
#   ✅ Grouped CV std below 0.25 (0.199)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.067 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.057)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {WARNING}  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height                                        0.1826  =========
#   height_x_EVI                                  0.1703  ========
#   height_x_NIR                                  0.1696  ========
#   height_x_NDRE1                                0.1453  =======
#   EVI                                           0.0798  ===
#   NIR                                           0.0546  ==
#   RE2                                           0.0439  ==
#   species_Rhizophora mangle                     0.0399  =
#   SWIR1                                         0.0358  =
#   RE1                                           0.0282  =
#
# Completed: 18/18 experiments

# %%
tabulate_results(rf_belige_grid_grps, acceptable_only=True)
# Out:
# Showing 14 acceptable experiments
# <style type="text/css">
# #T_fc028_row0_col7, #T_fc028_row6_col1, #T_fc028_row6_col2, #T_fc028_row6_col9, #T_fc028_row7_col8 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_fc028">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc028_level0_col0" class="col_heading level0 col0" >Experiment</th>
#       <th id="T_fc028_level0_col1" class="col_heading level0 col1" >Test R²</th>
#       <th id="T_fc028_level0_col2" class="col_heading level0 col2" >Test RMSE</th>
#       <th id="T_fc028_level0_col3" class="col_heading level0 col3" >Train R²</th>
#       <th id="T_fc028_level0_col4" class="col_heading level0 col4" >Train RMSE</th>
#       <th id="T_fc028_level0_col5" class="col_heading level0 col5" >CV R² Mean</th>
#       <th id="T_fc028_level0_col6" class="col_heading level0 col6" >CV R² Std</th>
#       <th id="T_fc028_level0_col7" class="col_heading level0 col7" >Group CV R² Mean</th>
#       <th id="T_fc028_level0_col8" class="col_heading level0 col8" >Group CV R² Std</th>
#       <th id="T_fc028_level0_col9" class="col_heading level0 col9" >CV-Test Gap</th>
#       <th id="T_fc028_level0_col10" class="col_heading level0 col10" >-ve Folds</th>
#       <th id="T_fc028_level0_col11" class="col_heading level0 col11" >verdict</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc028_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fc028_row0_col0" class="data row0 col0" >EXPERIMENT-14 Plot groups Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? Yes, Grid? Yes</td>
#       <td id="T_fc028_row0_col1" class="data row0 col1" >0.2252</td>
#       <td id="T_fc028_row0_col2" class="data row0 col2" >4.06</td>
#       <td id="T_fc028_row0_col3" class="data row0 col3" >0.1594</td>
#       <td id="T_fc028_row0_col4" class="data row0 col4" >17.03</td>
#       <td id="T_fc028_row0_col5" class="data row0 col5" >0.2001</td>
#       <td id="T_fc028_row0_col6" class="data row0 col6" >0.2096</td>
#       <td id="T_fc028_row0_col7" class="data row0 col7" >0.3019</td>
#       <td id="T_fc028_row0_col8" class="data row0 col8" >0.2025</td>
#       <td id="T_fc028_row0_col9" class="data row0 col9" >0.0766</td>
#       <td id="T_fc028_row0_col10" class="data row0 col10" >2 (Big Creek_5, Big Creek_3)</td>
#       <td id="T_fc028_row0_col11" class="data row0 col11" >⚠️  MARGINAL — positive metrics but concerns</td>
#     </tr>
#     <tr>
#       <th id="T_fc028_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fc028_row1_col0" class="data row1 col0" >EXPERIMENT-18 Plot groups Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? Yes, Grid? Yes</td>
#       <td id="T_fc028_row1_col1" class="data row1 col1" >0.2271</td>
#       <td id="T_fc028_row1_col2" class="data row1 col2" >4.06</td>
#       <td id="T_fc028_row1_col3" class="data row1 col3" >0.1699</td>
#       <td id="T_fc028_row1_col4" class="data row1 col4" >16.92</td>
#       <td id="T_fc028_row1_col5" class="data row1 col5" >0.1739</td>
#       <td id="T_fc028_row1_col6" class="data row1 col6" >0.2411</td>
#       <td id="T_fc028_row1_col7" class="data row1 col7" >0.2937</td>
#       <td id="T_fc028_row1_col8" class="data row1 col8" >0.1991</td>
#       <td id="T_fc028_row1_col9" class="data row1 col9" >0.0665</td>
#       <td id="T_fc028_row1_col10" class="data row1 col10" >2 (Big Creek_5, Big Creek_3)</td>
#       <td id="T_fc028_row1_col11" class="data row1 col11" >⚠️  MARGINAL — positive metrics but concerns</td>
#     </tr>
#     <tr>
#       <th id="T_fc028_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fc028_row2_col0" class="data row2 col0" >EXPERIMENT-13 Plot groups Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1']., Model: rf, Grouping? Yes, Grid? Yes</td>
#       <td id="T_fc028_row2_col1" class="data row2 col1" >0.2375</td>
#       <td id="T_fc028_row2_col2" class="data row2 col2" >4.03</td>
#       <td id="T_fc028_row2_col3" class="data row2 col3" >0.144</td>
#       <td id="T_fc028_row2_col4" class="data row2 col4" >17.18</td>
#       <td id="T_fc028_row2_col5" class="data row2 col5" >0.1064</td>
#       <td id="T_fc028_row2_col6" class="data row2 col6" >0.2709</td>
#       <td id="T_fc028_row2_col7" class="data row2 col7" >0.2709</td>
#       <td id="T_fc028_row2_col8" class="data row2 col8" >0.2026</td>
#       <td id="T_fc028_row2_col9" class="data row2 col9" >0.0334</td>
#       <td id="T_fc028_row2_col10" class="data row2 col10" >2 (Big Creek_5, Big Creek_3)</td>
#       <td id="T_fc028_row2_col11" class="data row2 col11" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_fc028_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fc028_row3_col0" class="data row3 col0" >EXPERIMENT-17 Plot groups Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2']., Model: rf, Grouping? Yes, Grid? Yes</td>
#       <td id="T_fc028_row3_col1" class="data row3 col1" >0.2161</td>
#       <td id="T_fc028_row3_col2" class="data row3 col2" >4.09</td>
#       <td id="T_fc028_row3_col3" class="data row3 col3" >0.1628</td>
#       <td id="T_fc028_row3_col4" class="data row3 col4" >16.99</td>
#       <td id="T_fc028_row3_col5" class="data row3 col5" >0.0675</td>
#       <td id="T_fc028_row3_col6" class="data row3 col6" >0.3067</td>
#       <td id="T_fc028_row3_col7" class="data row3 col7" >0.2669</td>
#       <td id="T_fc028_row3_col8" class="data row3 col8" >0.1953</td>
#       <td id="T_fc028_row3_col9" class="data row3 col9" >0.0508</td>
#       <td id="T_fc028_row3_col10" class="data row3 col10" >2 (Big Creek_5, Big Creek_3)</td>
#       <td id="T_fc028_row3_col11" class="data row3 col11" >⚠️  MARGINAL — positive metrics but concerns</td>
#     </tr>
#     <tr>
#       <th id="T_fc028_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fc028_row4_col0" class="data row4 col0" >EXPERIMENT-2 Plot groups Grid search: Yes, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? Yes, Grid? Yes</td>
#       <td id="T_fc028_row4_col1" class="data row4 col1" >0.2064</td>
#       <td id="T_fc028_row4_col2" class="data row4 col2" >4.11</td>
#       <td id="T_fc028_row4_col3" class="data row4 col3" >0.1547</td>
#       <td id="T_fc028_row4_col4" class="data row4 col4" >17.07</td>
#       <td id="T_fc028_row4_col5" class="data row4 col5" >0.231</td>
#       <td id="T_fc028_row4_col6" class="data row4 col6" >0.2173</td>
#       <td id="T_fc028_row4_col7" class="data row4 col7" >0.2625</td>
#       <td id="T_fc028_row4_col8" class="data row4 col8" >0.2096</td>
#       <td id="T_fc028_row4_col9" class="data row4 col9" >0.0561</td>
#       <td id="T_fc028_row4_col10" class="data row4 col10" >2 (Big Creek_5, Big Creek_3)</td>
#       <td id="T_fc028_row4_col11" class="data row4 col11" >⚠️  MARGINAL — positive metrics but concerns</td>
#     </tr>
#     <tr>
#       <th id="T_fc028_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fc028_row5_col0" class="data row5 col0" >EXPERIMENT-12 Plot groups Grid search: Yes, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']., Model: rf, Grouping? Yes, Grid? Yes</td>
#       <td id="T_fc028_row5_col1" class="data row5 col1" >0.1913</td>
#       <td id="T_fc028_row5_col2" class="data row5 col2" >4.15</td>
#       <td id="T_fc028_row5_col3" class="data row5 col3" >0.1574</td>
#       <td id="T_fc028_row5_col4" class="data row5 col4" >17.05</td>
#       <td id="T_fc028_row5_col5" class="data row5 col5" >0.2</td>
#       <td id="T_fc028_row5_col6" class="data row5 col6" >0.2186</td>
#       <td id="T_fc028_row5_col7" class="data row5 col7" >0.2559</td>
#       <td id="T_fc028_row5_col8" class="data row5 col8" >0.2045</td>
#       <td id="T_fc028_row5_col9" class="data row5 col9" >0.0646</td>
#       <td id="T_fc028_row5_col10" class="data row5 col10"

# %%
# %run Model_functions.ipynb
best_results = filter_best_experiments(global_experiment_list)
tabulate_results(best_results)
# Out:
# chmod: /Users/kosaraju_b/.local/share/jupyter/history.sqlite: No such file or directory
#   File /var/folders/b8/8qlj5yzd0jng0b9470zpnl9h0000gn/T/ipykernel_5169/2527560106.py:6
#     label=""
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
# Traceback (most recent call last):
#
#   File /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/IPython/core/interactiveshell.py:3747 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[150], line 1
#     get_ipython().run_line_magic('run', 'Model_functions.ipynb')
#
#   File /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/IPython/core/interactiveshell.py:2532 in run_line_magic
#     result = fn(*args, **kwargs)
#
#   File /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/IPython/core/magics/execution.py:750 in run
#     self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#
#   File /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/IPython/core/interactiveshell.py:3048 in safe_execfile_ipy
#     result.raise_error()
#
#   File /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/IPython/core/interactiveshell.py:327 in raise_error
#     raise self.error_before_exec
#
#   File /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/IPython/core/interactiveshell.py:3418 in run_cell_async
#     code_ast = compiler.ast_parse(cell, filename=cell_name)
#
#   File /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/IPython/core/compilerop.py:86 in ast_parse
#     return compile(source, filename, symbol, self.flags | PyCF_ONLY_AST, 1)
#
#   File /var/folders/b8/8qlj5yzd0jng0b9470zpnl9h0000gn/T/ipykernel_5169/2527560106.py:6
#     label=""
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# ### BELIGE DATA. PLOT GROUPS. ALL ROWS. XGBOOST (Hyper parameter tuning: No)

# %%
# %run Model_functions.ipynb

xg_belige_no_grid_grps = {}

run_experiment(X_belige, y_belige,
               is_groups=True, group_info=grp_belige,
               features_list=gen_features_list,
               experiments=xg_belige_no_grid_grps,
               model_type="xgboost", is_grid=False,
               is_stratified=is_stratified_g,
               global_experiment_list=global_experiment_list)
# Out:
# [1/18]
#
#  XGBOOST: EXPERIMENT-1 Plot groups. Grid search: No, Features: ['height'].
# Test R²     : 0.1187
# Test RMSE   : 4.33 kg
# Train R² (log scale): 0.2290
# Train R² (orig scale): -0.0122
# Train RMSE  : 18.68 kg
# Num rows    : 3100
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: 0.1260
# CV R² std : 0.1651
# CV scores : [0.    0.446 0.031 0.122 0.03 ]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2468
# Grouped CV R² std : 0.1956
# Grouped CV scores : [ 0.073  0.065  0.239 -0.092  0.457  0.505  0.512  0.282  0.114  0.314]
# ============================================================
#  EVALUATION: EXPERIMENT-1 Plot groups. Grid search: No, Features: ['height'].
# ============================================================
#
# Test set:
#   R²   : 0.119
#   RMSE : 4.33 kg
#
# Regular CrossValidation:
#   Mean   : 0.126
#   Std    : 0.165
#   Scores : [0.    0.446 0.031 0.122 0.03 ]
#
#   ✅ Test R² is positive (0.119)
#   ✅ CV mean is positive (0.126)
#
# Grouped CrossValidation:
#   Big Creek_5          :   0.073  ✅
#   Frenchman Caye_6     :   0.065  ✅
#   Frenchman Caye_3     :   0.239  ✅
#   Big Creek_3          :  -0.092  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.457  ✅
#   Big Creek_2          :   0.505  ✅
#   Drowned Caye_5       :   0.512  ✅
#   Gra Gra Lagoon_4     :   0.282  ✅
#   Channel Caye_2       :   0.114  ✅
#   Channel Caye_6       :   0.314  ✅
#
#   Mean : 0.247
#   Std  : 0.196
#
#   ✅ Grouped CV mean above 0.15 (0.247)
#   ✅ Grouped CV std below 0.25 (0.196)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.128 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.131)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ⚠️  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height                                        1.0000  ==================================================
#
# [2/18]
#
#  XGBOOST: EXPERIMENT-2 Plot groups. Grid search: No, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : 0.1298
# Test RMSE   : 4.31 kg
# Train R² (log scale): 0.2380
# Train R² (orig scale): -0.0097
# Train RMSE  : 18.66 kg
# Num rows    : 3100
# Num Features: 4
#
#  Cross-validation ---
# CV R² mean: 0.1438
# CV R² std : 0.1642
# CV scores : [-0.031  0.446  0.033  0.156  0.115]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2543
# Grouped CV R² std : 0.2041
# Grouped CV scores : [-0.051  0.14   0.239 -0.108  0.434  0.522  0.512  0.281  0.232  0.342]
# ============================================================
#  EVALUATION: EXPERIMENT-2 Plot groups. Grid search: No, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : 0.130
#   RMSE : 4.31 kg
#
# Regular CrossValidation:
#   Mean   : 0.144
#   Std    : 0.164
#   Scores : [-0.031  0.446  0.033  0.156  0.115]
#
#   ✅ Test R² is positive (0.130)
#   ✅ CV mean is positive (0.144)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.051  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :   0.140  ✅
#   Frenchman Caye_3     :   0.239  ✅
#   Big Creek_3          :  -0.108  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.434  ✅
#   Big Creek_2          :   0.522  ✅
#   Drowned Caye_5       :   0.512  ✅
#   Gra Gra Lagoon_4     :   0.281  ✅
#   Channel Caye_2       :   0.232  ✅
#   Channel Caye_6       :   0.342  ✅
#
#   Mean : 0.254
#   Std  : 0.204
#
#   ✅ Grouped CV mean above 0.15 (0.254)
#   ✅ Grouped CV std below 0.25 (0.204)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.124 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.140)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ⚠️  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height                                        0.3772  ==================
#   height_x_NDRE1                                0.3142  ===============
#   height_x_EVI                                  0.1939  =========
#   height_x_NIR                                  0.1147  =====
#
# [3/18]
#
#  XGBOOST: EXPERIMENT-3 Plot groups. Grid search: No, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2'].
# Test R²     : 0.2630
# Test RMSE   : 3.96 kg
# Train R² (log scale): 0.3554
# Train R² (orig scale): 0.0448
# Train RMSE  : 18.15 kg
# Num rows    : 3100
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: -0.1797
# CV R² std : 0.4554
# CV scores : [-0.03   0.472 -0.128 -0.272 -0.94 ]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.0743
# Grouped CV R² std : 0.4687
# Grouped CV scores : [-0.189 -1.149  0.205 -0.058  0.422  0.535  0.537  0.272  0.149  0.018]
# ============================================================
#  EVALUATION: EXPERIMENT-3 Plot groups. Grid search: No, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2'].
# ============================================================
#
# Test set:
#   R²   : 0.263
#   RMSE : 3.96 kg
#
# Regular CrossValidation:
#   Mean   : -0.180
#   Std    : 0.455
#   Scores : [-0.03   0.472 -0.128 -0.272 -0.94 ]
#
#   ✅ Test R² is positive (0.263)
#   ❌ CV mean is negative (-0.180)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.189  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :  -1.149  ⚠️  near-zero variance artifact
#   Frenchman Caye_3     :   0.205  ✅
#   Big Creek_3          :  -0.058  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.422  ✅
#   Big Creek_2          :   0.535  ✅
#   Drowned Caye_5       :   0.537  ✅
#   Gra Gra Lagoon_4     :   0.272  ✅
#   Channel Caye_2       :   0.149  ✅
#   Channel Caye_6       :   0.018  ✅
#
#   Mean : 0.074
#   Std  : 0.469
#
#   ❌ Grouped CV mean below 0.15 (0.074)
#   ⚠️  Grouped CV std above 0.25 (0.469) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.189 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.218)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   RE2                                           0.2967  ==============
#   RE3                                           0.2498  ============
#   Red                                           0.0980  ====
#   Green                                         0.0800  ====
#   NIR                                           0.0750  ===
#   SWIR2                                         0.0718  ===
#   RE1                                           0.0474  ==
#   Blue                                          0.0426  ==
#   SWIR1                                         0.0387  =
#
# [4/18]
#
#  XGBOOST: EXPERIMENT-4 Plot groups. Grid search: No, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : 0.2117
# Test RMSE   : 4.10 kg
# Train R² (log scale): 0.3102
# Train R² (orig scale): 0.0170
# Train RMSE  : 18.41 kg
# Num rows    : 3100
# Num Features: 12
#
#  Cross-validation ---
# CV R² mean: 0.0877
# CV R² std : 0.2025
# CV scores : [-0.073  0.484 -0.004 -0.023  0.054]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2269
# Grouped CV R² std : 0.2111
# Grouped CV scores : [-0.152  0.034  0.272 -0.054  0.425  0.428  0.544  0.265  0.239  0.268]
# ============================================================
#  EVALUATION: EXPERIMENT-4 Plot groups. Grid search: No, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : 0.212
#   RMSE : 4.10 kg
#
# Regular CrossValidation:
#   Mean   : 0.088
#   Std    : 0.202
#   Scores : [-0.073  0.484 -0.004 -0.023  0.054]
#
#   ✅ Test R² is positive (0.212)
#   ✅ CV mean is positive (0.088)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.152  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :   0.034  ✅
#   Frenchman Caye_3     :   0.272  ✅
#   Big Creek_3          :  -0.054  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.425  ✅
#   Big Creek_2          :   0.428  ✅
#   Drowned Caye_5       :   0.544  ✅
#   Gra Gra Lagoon_4     :   0.265  ✅
#   Channel Caye_2       :   0.239  ✅
#   Channel Caye_6       :   0.268  ✅
#
#   Mean : 0.227
#   Std  : 0.211
#
#   ✅ Grouped CV mean above 0.15 (0.227)
#   ✅ Grouped CV std below 0.25 (0.211)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ✅ Grouped CV and test R² agree (gap: 0.015)
#   ✅ Train/test R² gap acceptable (gap: -0.195)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ✅ ACCEPTABLE
#
# Top 10 feature importances:
#   height_x_NIR                                  0.2842  ==============
#   height_x_EVI                                  0.2717  =============
#   height_x_NDRE1                                0.1971  =========
#   RE2                                           0.0473  ==
#   RE3                                           0.0396  =
#   Green                                         0.0352  =
#   Red                                           0.0317  =
#   RE1                                           0.0243  =
#   SWIR2                                         0.0207  =
#   NIR                                           0.0182
#
# [5/18]
#
#  XGBOOST: EXPERIMENT-5 Plot groups. Grid search: No, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# Test R²     : 0.2190
# Test RMSE   : 4.08 kg
# Train R² (log scale): 0.3077
# Train R² (orig scale): 0.0194
# Train RMSE  : 18.39 kg
# Num rows    : 3100
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: -0.4752
# CV R² std : 1.0012
# CV scores : [-0.056  0.335 -0.042 -0.164 -2.449]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.1563
# Grouped CV R² std : 1.0000
# Grouped CV scores : [-0.054 -3.123  0.172 -0.082  0.469  0.276  0.187  0.216  0.221  0.156]
# ============================================================
#  EVALUATION: EXPERIMENT-5 Plot groups. Grid search: No, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# ============================================================
#
# Test set:
#   R²   : 0.219
#   RMSE : 4.08 kg
#
# Regular CrossValidation:
#   Mean   : -0.475
#   Std    : 1.001
#   Scores : [-0.056  0.335 -0.042 -0.164 -2.449]
#
#   ✅ Test R² is positive (0.219)
#   ❌ CV mean is negative (-0.475)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.054  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :  -3.123  ⚠️  near-zero variance artifact
#   Frenchman Caye_3     :   0.172  ✅
#   Big Creek_3          :  -0.082  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.469  ✅
#   Big Creek_2          :   0.276  ✅
#   Drowned Caye_5       :   0.187  ✅
#   Gra Gra Lagoon_4     :   0.216  ✅
#   Channel Caye_2       :   0.221  ✅
#   Channel Caye_6       :   0.156  ✅
#
#   Mean : -0.156
#   Std  : 1.000
#
#   ❌ Grouped CV mean below 0.15 (-0.156)
#   ⚠️  Grouped CV std above 0.25 (1.000) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.375 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.200)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   CIrededge                                     0.2948  ==============
#   NDRE1                                         0.2558  ============
#   NDRE2                                         0.1303  ======
#   EVI                                           0.1249  ======
#   NBR                                           0.0631  ===
#   MNDWI                                         0.0544  ==
#   NDVI                                          0.0392  =
#   NDRE3                                         0.0374  =
#   CLOUD_COVERAGE                                0.0000
#
# [6/18]
#
#  XGBOOST: EXPERIMENT-6 Plot groups. Grid search: No, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : 0.1042
# Test RMSE   : 4.37 kg
# Train R² (log scale): 0.2277
# Train R² (orig scale): -0.0107
# Train RMSE  : 18.67 kg
# Num rows    : 3100
# Num Features: 12
#
#  Cross-validation ---
# CV R² mean: -0.0661
# CV R² std : 0.4414
# CV scores : [-0.09   0.547  0.016  0.026 -0.829]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.0939
# Grouped CV R² std : 0.5034
# Grouped CV scores : [-0.088 -1.31   0.262 -0.057  0.408  0.439  0.52   0.246  0.243  0.275]
# ============================================================
#  EVALUATION: EXPERIMENT-6 Plot groups. Grid search: No, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : 0.104
#   RMSE : 4.37 kg
#
# Regular CrossValidation:
#   Mean   : -0.066
#   Std    : 0.441
#   Scores : [-0.09   0.547  0.016  0.026 -0.829]
#
#   ✅ Test R² is positive (0.104)
#   ❌ CV mean is negative (-0.066)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.088  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :  -1.310  ⚠️  near-zero variance artifact
#   Frenchman Caye_3     :   0.262  ✅
#   Big Creek_3          :  -0.057  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.408  ✅
#   Big Creek_2          :   0.439  ✅
#   Drowned Caye_5       :   0.520  ✅
#   Gra Gra Lagoon_4     :   0.246  ✅
#   Channel Caye_2       :   0.243  ✅
#   Channel Caye_6       :   0.275  ✅
#
#   Mean : 0.094
#   Std  : 0.503
#
#   ❌ Grouped CV mean below 0.15 (0.094)
#   ⚠️  Grouped CV std above 0.25 (0.503) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ✅ Grouped CV and test R² agree (gap: 0.010)
#   ✅ Train/test R² gap acceptable (gap: -0.115)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height_x_NIR                                  0.2490  ============
#   height_x_EVI                                  0.2424  ============
#   height_x_NDRE1                                0.2387  ===========
#   EVI                                           0.0430  ==
#   NDRE2                                         0.0418  ==
#   CIrededge                                     0.0407  ==
#   MNDWI                                         0.0405  ==
#   NBR                                           0.0343  =
#   NDRE1                                         0.0310  =
#   NDVI                                          0.0229  =
#
# [7/18]
#
#  XGBOOST: EXPERIMENT-7 Plot groups. Grid search: No, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# Test R²     : 0.1861
# Test RMSE   : 4.16 kg
# Train R² (log scale): 0.2933
# Train R² (orig scale): 0.0102
# Train RMSE  : 18.47 kg
# Num rows    : 3100
# Num Features: 18
#
#  Cross-validation ---
# CV R² mean: -0.2641
# CV R² std : 0.6672
# CV scores : [-0.07   0.461 -0.009 -0.178 -1.525]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.3228
# Grouped CV R² std : 1.5912
# Grouped CV scores : [-0.168 -5.06   0.244 -0.096  0.454  0.503  0.211  0.232  0.242  0.211]
# ============================================================
#  EVALUATION: EXPERIMENT-7 Plot groups. Grid search: No, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# ============================================================
#
# Test set:
#   R²   : 0.186
#   RMSE : 4.16 kg
#
# Regular CrossValidation:
#   Mean   : -0.264
#   Std    : 0.667
#   Scores : [-0.07   0.461 -0.009 -0.178 -1.525]
#
#   ✅ Test R² is positive (0.186)
#   ❌ CV mean is negative (-0.264)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.168  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :  -5.060  ⚠️  near-zero variance artifact
#   Frenchman Caye_3     :   0.244  ✅
#   Big Creek_3          :  -0.096  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.454  ✅
#   Big Creek_2          :   0.503  ✅
#   Drowned Caye_5       :   0.211  ✅
#   Gra Gra Lagoon_4     :   0.232  ✅
#   Channel Caye_2       :   0.242  ✅
#   Channel Caye_6       :   0.211  ✅
#
#   Mean : -0.323
#   Std  : 1.591
#
#   ❌ Grouped CV mean below 0.15 (-0.323)
#   ⚠️  Grouped CV std above 0.25 (1.591) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.509 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.176)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   NDRE1                                         0.2271  ===========
#   CIrededge                                     0.1893  =========
#   EVI                                           0.1341  ======
#   RE2                                           0.0724  ===
#   RE3                                           0.0650  ===
#   NDRE2                                         0.0502  ==
#   NBR                                           0.0460  ==
#   NIR                                           0.0363  =
#   Red                                           0.0283  =
#   SWIR1                                         0.0215  =
#
# [8/18]
#
#  XGBOOST: EXPERIMENT-8 Plot groups. Grid search: No, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : 0.2013
# Test RMSE   : 4.12 kg
# Train R² (log scale): 0.2970
# Train R² (orig scale): 0.0109
# Train RMSE  : 18.47 kg
# Num rows    : 3100
# Num Features: 21
#
#  Cross-validation ---
# CV R² mean: 0.0384
# CV R² std : 0.3392
# CV scores : [-0.086  0.666  0.02  -0.048 -0.36 ]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.0298
# Grouped CV R² std : 0.7877
# Grouped CV scores : [-0.144 -2.322  0.263 -0.076  0.44   0.227  0.521  0.249  0.24   0.303]
# ============================================================
#  EVALUATION: EXPERIMENT-8 Plot groups. Grid search: No, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : 0.201
#   RMSE : 4.12 kg
#
# Regular CrossValidation:
#   Mean   : 0.038
#   Std    : 0.339
#   Scores : [-0.086  0.666  0.02  -0.048 -0.36 ]
#
#   ✅ Test R² is positive (0.201)
#   ✅ CV mean is positive (0.038)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.144  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :  -2.322  ⚠️  near-zero variance artifact
#   Frenchman Caye_3     :   0.263  ✅
#   Big Creek_3          :  -0.076  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.440  ✅
#   Big Creek_2          :   0.227  ✅
#   Drowned Caye_5       :   0.521  ✅
#   Gra Gra Lagoon_4     :   0.249  ✅
#   Channel Caye_2       :   0.240  ✅
#   Channel Caye_6       :   0.303  ✅
#
#   Mean : -0.030
#   Std  : 0.788
#
#   ❌ Grouped CV mean below 0.15 (-0.030)
#   ⚠️  Grouped CV std above 0.25 (0.788) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.231 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.190)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ⚠️  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height_x_NDRE1                                0.2337  ===========
#   height_x_EVI                                  0.2280  ===========
#   height_x_NIR                                  0.1396  ======
#   NBR                                           0.0764  ===
#   Red                                           0.0365  =
#   NDRE2                                         0.0338  =
#   RE3                                           0.0327  =
#   Green                                         0.0308  =
#   RE2                                           0.0299  =
#   SWIR2                                         0.0271  =
#
# [9/18]
#
#  XGBOOST: EXPERIMENT-9 Plot groups. Grid search: No, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# Test R²     : 0.0996
# Test RMSE   : 4.38 kg
# Train R² (log scale): 0.2297
# Train R² (orig scale): -0.0101
# Train RMSE  : 18.66 kg
# Num rows    : 3100
# Num Features: 19
#
#  Cross-validation ---
# CV R² mean: 0.0337
# CV R² std : 0.2677
# CV scores : [-0.008  0.538 -0.079 -0.023 -0.259]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1789
# Grouped CV R² std : 0.2791
# Grouped CV scores : [ 0.007 -0.491  0.252 -0.073  0.441  0.451  0.45   0.249  0.252  0.249]
# ============================================================
#  EVALUATION: EXPERIMENT-9 Plot groups. Grid search: No, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# ============================================================
#
# Test set:
#   R²   : 0.100
#   RMSE : 4.38 kg
#
# Regular CrossValidation:
#   Mean   : 0.034
#   Std    : 0.268
#   Scores : [-0.008  0.538 -0.079 -0.023 -0.259]
#
#   ✅ Test R² is positive (0.100)
#   ✅ CV mean is positive (0.034)
#
# Grouped CrossValidation:
#   Big Creek_5          :   0.007  ✅
#   Frenchman Caye_6     :  -0.491  ⚠️  near-zero variance artifact
#   Frenchman Caye_3     :   0.252  ✅
#   Big Creek_3          :  -0.073  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.441  ✅
#   Big Creek_2          :   0.451  ✅
#   Drowned Caye_5       :   0.450  ✅
#   Gra Gra Lagoon_4     :   0.249  ✅
#   Channel Caye_2       :   0.252  ✅
#   Channel Caye_6       :   0.249  ✅
#
#   Mean : 0.179
#   Std  : 0.279
#
#   ✅ Grouped CV mean above 0.15 (0.179)
#   ⚠️  Grouped CV std above 0.25 (0.279) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.079 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.110)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ⚠️  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   NDRE1                                         0.2752  =============
#   height                                        0.1542  =======
#   EVI                                           0.1223  ======
#   CIrededge                                     0.0646  ===
#   Green                                         0.0498  ==
#   RE3                                           0.0421  ==
#   NBR                                           0.0400  ==
#   NDRE3                                         0.0360  =
#   RE2                                           0.0336  =
#   NDRE2                                         0.0308  =
#
# [10/18]
#
#  XGBOOST: EXPERIMENT-10 Plot groups. Grid search: No, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : 0.1060
# Test RMSE   : 4.36 kg
# Train R² (log scale): 0.2305
# Train R² (orig scale): -0.0103
# Train RMSE  : 18.66 kg
# Num rows    : 3100
# Num Features: 22
#
#  Cross-validation ---
# CV R² mean: 0.0319
# CV R² std : 0.2460
# CV scores : [-0.006  0.479 -0.04   0.003 -0.276]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1869
# Grouped CV R² std : 0.2441
# Grouped CV scores : [-0.114 -0.286  0.259 -0.045  0.433  0.308  0.55   0.237  0.248  0.28 ]
# ============================================================
#  EVALUATION: EXPERIMENT-10 Plot groups. Grid search: No, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : 0.106
#   RMSE : 4.36 kg
#
# Regular CrossValidation:
#   Mean   : 0.032
#   Std    : 0.246
#   Scores : [-0.006  0.479 -0.04   0.003 -0.276]
#
#   ✅ Test R² is positive (0.106)
#   ✅ CV mean is positive (0.032)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.114  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :  -0.286  ⚠️  near-zero variance artifact
#   Frenchman Caye_3     :   0.259  ✅
#   Big Creek_3          :  -0.045  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.433  ✅
#   Big Creek_2          :   0.308  ✅
#   Drowned Caye_5       :   0.550  ✅
#   Gra Gra Lagoon_4     :   0.237  ✅
#   Channel Caye_2       :   0.248  ✅
#   Channel Caye_6       :   0.280  ✅
#
#   Mean : 0.187
#   Std  : 0.244
#
#   ✅ Grouped CV mean above 0.15 (0.187)
#   ✅ Grouped CV std below 0.25 (0.244)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.081 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.116)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ⚠️  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height_x_NDRE1                                0.2854  ==============
#   height                                        0.1484  =======
#   height_x_NIR                                  0.0987  ====
#   height_x_EVI                                  0.0982  ====
#   Green                                         0.0586  ==
#   RE2                                           0.0326  =
#   NDVI                                          0.0300  =
#   RE3                                           0.0298  =
#   Red                                           0.0279  =
#   NIR                                           0.0275  =
#
# [11/18]
#
#  XGBOOST: EXPERIMENT-11 Plot groups. Grid search: No, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1'].
# Test R²     : 0.0833
# Test RMSE   : 4.42 kg
# Train R² (log scale): 0.2287
# Train R² (orig scale): -0.0108
# Train RMSE  : 18.67 kg
# Num rows    : 3100
# Num Features: 5
#
#  Cross-validation ---
# CV R² mean: 0.0761
# CV R² std : 0.2579
# CV scores : [-0.039  0.576 -0.055  0.051 -0.152]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2096
# Grouped CV R² std : 0.2042
# Grouped CV scores : [ 0.016 -0.069  0.246 -0.077  0.362  0.193  0.641  0.257  0.241  0.285]
# ============================================================
#  EVALUATION: EXPERIMENT-11 Plot groups. Grid search: No, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1'].
# ============================================================
#
# Test set:
#   R²   : 0.083
#   RMSE : 4.42 kg
#
# Regular CrossValidation:
#   Mean   : 0.076
#   Std    : 0.258
#   Scores : [-0.039  0.576 -0.055  0.051 -0.152]
#
#   ✅ Test R² is positive (0.083)
#   ✅ CV mean is positive (0.076)
#
# Grouped CrossValidation:
#   Big Creek_5          :   0.016  ✅
#   Frenchman Caye_6     :  -0.069  ⚠️  near-zero variance artifact
#   Frenchman Caye_3     :   0.246  ✅
#   Big Creek_3          :  -0.077  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.362  ✅
#   Big Creek_2          :   0.193  ✅
#   Drowned Caye_5       :   0.641  ✅
#   Gra Gra Lagoon_4     :   0.257  ✅
#   Channel Caye_2       :   0.241  ✅
#   Channel Caye_6       :   0.285  ✅
#
#   Mean : 0.210
#   Std  : 0.204
#
#   ✅ Grouped CV mean above 0.15 (0.210)
#   ✅ Grouped CV std below 0.25 (0.204)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.126 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.094)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ⚠️  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height                                        0.4549  ======================
#   EVI                                           0.2101  ==========
#   NBR                                           0.1813  =========
#   NIR                                           0.1031  =====
#   SWIR1                                         0.0506  ==
#
# [12/18]
#
#  XGBOOST: EXPERIMENT-12 Plot groups. Grid search: No, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : 0.0415
# Test RMSE   : 4.52 kg
# Train R² (log scale): 0.1597
# Train R² (orig scale): -0.0232
# Train RMSE  : 18.78 kg
# Num rows    : 3100
# Num Features: 8
#
#  Cross-validation ---
# CV R² mean: 0.1394
# CV R² std : 0.2166
# CV scores : [-0.045  0.563  0.025  0.063  0.091]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2119
# Grouped CV R² std : 0.1886
# Grouped CV scores : [-0.051  0.051  0.255 -0.063  0.412  0.145  0.565  0.231  0.25   0.323]
# ============================================================
#  EVALUATION: EXPERIMENT-12 Plot groups. Grid search: No, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : 0.042
#   RMSE : 4.52 kg
#
# Regular CrossValidation:
#   Mean   : 0.139
#   Std    : 0.217
#   Scores : [-0.045  0.563  0.025  0.063  0.091]
#
#   ✅ Test R² is positive (0.042)
#   ✅ CV mean is positive (0.139)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.051  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :   0.051  ✅
#   Frenchman Caye_3     :   0.255  ✅
#   Big Creek_3          :  -0.063  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.412  ✅
#   Big Creek_2          :   0.145  ✅
#   Drowned Caye_5       :   0.565  ✅
#   Gra Gra Lagoon_4     :   0.231  ✅
#   Channel Caye_2       :   0.250  ✅
#   Channel Caye_6       :   0.323  ✅
#
#   Mean : 0.212
#   Std  : 0.189
#
#   ✅ Grouped CV mean above 0.15 (0.212)
#   ✅ Grouped CV std below 0.25 (0.189)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.170 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.065)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ⚠️  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height_x_EVI                                  0.2738  =============
#   height_x_NDRE1                                0.2702  =============
#   height                                        0.1642  ========
#   height_x_NIR                                  0.1076  =====
#   NIR                                           0.0612  ===
#   EVI                                           0.0513  ==
#   NBR                                           0.0397  =
#   SWIR1                                         0.0319  =
#
# [13/18]
#
#  XGBOOST: EXPERIMENT-13 Plot groups. Grid search: No, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1'].
# Test R²     : 0.0120
# Test RMSE   : 4.59 kg
# Train R² (log scale): 0.1193
# Train R² (orig scale): -0.0293
# Train RMSE  : 18.84 kg
# Num rows    : 3100
# Num Features: 8
#
#  Cross-validation ---
# CV R² mean: -0.1366
# CV R² std : 0.4224
# CV scores : [-0.299  0.451  0.117 -0.139 -0.812]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2713
# Grouped CV R² std : 0.1812
# Grouped CV scores : [ 0.023  0.147  0.377 -0.044  0.381  0.322  0.621  0.32   0.312  0.254]
# ============================================================
#  EVALUATION: EXPERIMENT-13 Plot groups. Grid search: No, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1'].
# ============================================================
#
# Test set:
#   R²   : 0.012
#   RMSE : 4.59 kg
#
# Regular CrossValidation:
#   Mean   : -0.137
#   Std    : 0.422
#   Scores : [-0.299  0.451  0.117 -0.139 -0.812]
#
#   ✅ Test R² is positive (0.012)
#   ❌ CV mean is negative (-0.137)
#
# Grouped CrossValidation:
#   Big Creek_5          :   0.023  ✅
#   Frenchman Caye_6     :   0.147  ✅
#   Frenchman Caye_3     :   0.377  ✅
#   Big Creek_3          :  -0.044  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.381  ✅
#   Big Creek_2          :   0.322  ✅
#   Drowned Caye_5       :   0.621  ✅
#   Gra Gra Lagoon_4     :   0.320  ✅
#   Channel Caye_2       :   0.312  ✅
#   Channel Caye_6       :   0.254  ✅
#
#   Mean : 0.271
#   Std  : 0.181
#
#   ✅ Grouped CV mean above 0.15 (0.271)
#   ✅ Grouped CV std below 0.25 (0.181)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.259 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.041)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height                                        0.2557  ============
#   NIR                                           0.2001  ==========
#   EVI                                           0.1920  =========
#   NBR                                           0.1359  ======
#   species_Avicennia germinans                   0.0757  ===
#   species_Rhizophora mangle                     0.0589  ==
#   SWIR1                                         0.0538  ==
#   species_Laguncularia racemosa                 0.0278  =
#
# [14/18]
#
#  XGBOOST: EXPERIMENT-14 Plot groups. Grid search: No, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : 0.0883
# Test RMSE   : 4.41 kg
# Train R² (log scale): 0.2539
# Train R² (orig scale): -0.0056
# Train RMSE  : 18.62 kg
# Num rows    : 3100
# Num Features: 11
#
#  Cross-validation ---
# CV R² mean: 0.0123
# CV R² std : 0.1807
# CV scores : [-0.159  0.321  0.102 -0.051 -0.151]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2485
# Grouped CV R² std : 0.1650
# Grouped CV scores : [-0.046  0.169  0.349 -0.047  0.462  0.404  0.295  0.279  0.335  0.285]
# ============================================================
#  EVALUATION: EXPERIMENT-14 Plot groups. Grid search: No, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : 0.088
#   RMSE : 4.41 kg
#
# Regular CrossValidation:
#   Mean   : 0.012
#   Std    : 0.181
#   Scores : [-0.159  0.321  0.102 -0.051 -0.151]
#
#   ✅ Test R² is positive (0.088)
#   ✅ CV mean is positive (0.012)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.046  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :   0.169  ✅
#   Frenchman Caye_3     :   0.349  ✅
#   Big Creek_3          :  -0.047  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.462  ✅
#   Big Creek_2          :   0.404  ✅
#   Drowned Caye_5       :   0.295  ✅
#   Gra Gra Lagoon_4     :   0.279  ✅
#   Channel Caye_2       :   0.335  ✅
#   Channel Caye_6       :   0.285  ✅
#
#   Mean : 0.248
#   Std  : 0.165
#
#   ✅ Grouped CV mean above 0.15 (0.248)
#   ✅ Grouped CV std below 0.25 (0.165)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.160 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.094)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ⚠️  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height_x_NDRE1                                0.2289  ===========
#   height_x_EVI                                  0.2117  ==========
#   height_x_NIR                                  0.1520  =======
#   height                                        0.1482  =======
#   NBR                                           0.0561  ==
#   EVI                                           0.0467  ==
#   species_Rhizophora mangle                     0.0395  =
#   species_Avicennia germinans                   0.0353  =
#   NIR                                           0.0344  =
#   SWIR1                                         0.0308  =
#
# [15/18]
#
#  XGBOOST: EXPERIMENT-15 Plot groups. Grid search: No, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2'].
# Test R²     : 0.0483
# Test RMSE   : 4.50 kg
# Train R² (log scale): 0.1590
# Train R² (orig scale): -0.0230
# Train RMSE  : 18.78 kg
# Num rows    : 3100
# Num Features: 7
#
#  Cross-validation ---
# CV R² mean: 0.0334
# CV R² std : 0.2353
# CV scores : [-0.038  0.453  0.002  0.025 -0.275]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1571
# Grouped CV R² std : 0.3004
# Grouped CV scores : [-0.021 -0.555  0.258 -0.067  0.388  0.144  0.615  0.254  0.248  0.305]
# ============================================================
#  EVALUATION: EXPERIMENT-15 Plot groups. Grid search: No, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2'].
# ============================================================
#
# Test set:
#   R²   : 0.048
#   RMSE : 4.50 kg
#
# Regular CrossValidation:
#   Mean   : 0.033
#   Std    : 0.235
#   Scores : [-0.038  0.453  0.002  0.025 -0.275]
#
#   ✅ Test R² is positive (0.048)
#   ✅ CV mean is positive (0.033)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.021  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :  -0.555  ⚠️  near-zero variance artifact
#   Frenchman Caye_3     :   0.258  ✅
#   Big Creek_3          :  -0.067  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.388  ✅
#   Big Creek_2          :   0.144  ✅
#   Drowned Caye_5       :   0.615  ✅
#   Gra Gra Lagoon_4     :   0.254  ✅
#   Channel Caye_2       :   0.248  ✅
#   Channel Caye_6       :   0.305  ✅
#
#   Mean : 0.157
#   Std  : 0.300
#
#   ✅ Grouped CV mean above 0.15 (0.157)
#   ⚠️  Grouped CV std above 0.25 (0.300) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.109 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.071)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ⚠️  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height                                        0.2895  ==============
#   EVI                                           0.1765  ========
#   RE2                                           0.1623  ========
#   RE1                                           0.1329  ======
#   NBR                                           0.1167  =====
#   NIR                                           0.0839  ====
#   SWIR1                                         0.0383  =
#
# [16/18]
#
#  XGBOOST: EXPERIMENT-16 Plot groups. Grid search: No, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : 0.0965
# Test RMSE   : 4.39 kg
# Train R² (log scale): 0.2290
# Train R² (orig scale): -0.0109
# Train RMSE  : 18.67 kg
# Num rows    : 3100
# Num Features: 10
#
#  Cross-validation ---
# CV R² mean: 0.1125
# CV R² std : 0.2025
# CV scores : [-0.034  0.512  0.048  0.046 -0.01 ]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1971
# Grouped CV R² std : 0.1975
# Grouped CV scores : [-0.031 -0.047  0.247 -0.043  0.433  0.077  0.559  0.207  0.247  0.322]
# ============================================================
#  EVALUATION: EXPERIMENT-16 Plot groups. Grid search: No, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : 0.097
#   RMSE : 4.39 kg
#
# Regular CrossValidation:
#   Mean   : 0.112
#   Std    : 0.202
#   Scores : [-0.034  0.512  0.048  0.046 -0.01 ]
#
#   ✅ Test R² is positive (0.097)
#   ✅ CV mean is positive (0.112)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.031  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :  -0.047  ⚠️  near-zero variance artifact
#   Frenchman Caye_3     :   0.247  ✅
#   Big Creek_3          :  -0.043  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.433  ✅
#   Big Creek_2          :   0.077  ✅
#   Drowned Caye_5       :   0.559  ✅
#   Gra Gra Lagoon_4     :   0.207  ✅
#   Channel Caye_2       :   0.247  ✅
#   Channel Caye_6       :   0.322  ✅
#
#   Mean : 0.197
#   Std  : 0.198
#
#   ✅ Grouped CV mean above 0.15 (0.197)
#   ✅ Grouped CV std below 0.25 (0.198)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.101 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.107)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ⚠️  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height_x_NIR                                  0.3022  ===============
#   height_x_EVI                                  0.2360  ===========
#   height_x_NDRE1                                0.2069  ==========
#   height                                        0.1075  =====
#   EVI                                           0.0383  =
#   RE1                                           0.0322  =
#   NBR                                           0.0279  =
#   NIR                                           0.0235  =
#   SWIR1                                         0.0210  =
#   RE2                                           0.0046
#
# [17/18]
#
#  XGBOOST: EXPERIMENT-17 Plot groups. Grid search: No, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2'].
# Test R²     : 0.0683
# Test RMSE   : 4.46 kg
# Train R² (log scale): 0.2071
# Train R² (orig scale): -0.0155
# Train RMSE  : 18.71 kg
# Num rows    : 3100
# Num Features: 10
#
#  Cross-validation ---
# CV R² mean: -0.1494
# CV R² std : 0.2663
# CV scores : [-0.223  0.096  0.118 -0.123 -0.615]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2393
# Grouped CV R² std : 0.1913
# Grouped CV scores : [ 0.048 -0.073  0.351 -0.012  0.423  0.34   0.562  0.19   0.32   0.244]
# ============================================================
#  EVALUATION: EXPERIMENT-17 Plot groups. Grid search: No, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2'].
# ============================================================
#
# Test set:
#   R²   : 0.068
#   RMSE : 4.46 kg
#
# Regular CrossValidation:
#   Mean   : -0.149
#   Std    : 0.266
#   Scores : [-0.223  0.096  0.118 -0.123 -0.615]
#
#   ✅ Test R² is positive (0.068)
#   ❌ CV mean is negative (-0.149)
#
# Grouped CrossValidation:
#   Big Creek_5          :   0.048  ✅
#   Frenchman Caye_6     :  -0.073  ⚠️  near-zero variance artifact
#   Frenchman Caye_3     :   0.351  ✅
#   Big Creek_3          :  -0.012  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.423  ✅
#   Big Creek_2          :   0.340  ✅
#   Drowned Caye_5       :   0.562  ✅
#   Gra Gra Lagoon_4     :   0.190  ✅
#   Channel Caye_2       :   0.320  ✅
#   Channel Caye_6       :   0.244  ✅
#
#   Mean : 0.239
#   Std  : 0.191
#
#   ✅ Grouped CV mean above 0.15 (0.239)
#   ✅ Grouped CV std below 0.25 (0.191)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.171 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.084)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height                                        0.2312  ===========
#   NIR                                           0.1672  ========
#   EVI                                           0.1311  ======
#   NBR                                           0.1238  ======
#   RE1                                           0.0985  ====
#   species_Rhizophora mangle                     0.0715  ===
#   species_Avicennia germinans                   0.0548  ==
#   SWIR1                                         0.0417  ==
#   RE2                                           0.0404  ==
#   species_Laguncularia racemosa                 0.0397  =
#
# [18/18]
#
#  XGBOOST: EXPERIMENT-18 Plot groups. Grid search: No, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : 0.0722
# Test RMSE   : 4.45 kg
# Train R² (log scale): 0.2072
# Train R² (orig scale): -0.0155
# Train RMSE  : 18.71 kg
# Num rows    : 3100
# Num Features: 13
#
#  Cross-validation ---
# CV R² mean: -0.0559
# CV R² std : 0.2135
# CV scores : [-0.228  0.235  0.138 -0.095 -0.329]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2354
# Grouped CV R² std : 0.1566
# Grouped CV scores : [ 0.013  0.084  0.355 -0.023  0.472  0.225  0.39   0.235  0.344  0.258]
# ============================================================
#  EVALUATION: EXPERIMENT-18 Plot groups. Grid search: No, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : 0.072
#   RMSE : 4.45 kg
#
# Regular CrossValidation:
#   Mean   : -0.056
#   Std    : 0.214
#   Scores : [-0.228  0.235  0.138 -0.095 -0.329]
#
#   ✅ Test R² is positive (0.072)
#   ❌ CV mean is negative (-0.056)
#
# Grouped CrossValidation:
#   Big Creek_5          :   0.013  ✅
#   Frenchman Caye_6     :   0.084  ✅
#   Frenchman Caye_3     :   0.355  ✅
#   Big Creek_3          :  -0.023  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.472  ✅
#   Big Creek_2          :   0.225  ✅
#   Drowned Caye_5       :   0.390  ✅
#   Gra Gra Lagoon_4     :   0.235  ✅
#   Channel Caye_2       :   0.344  ✅
#   Channel Caye_6       :   0.258  ✅
#
#   Mean : 0.235
#   Std  : 0.157
#
#   ✅ Grouped CV mean above 0.15 (0.235)
#   ✅ Grouped CV std below 0.25 (0.157)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.163 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.088)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height_x_NDRE1                                0.2634  =============
#   height_x_NIR                                  0.1686  ========
#   height_x_EVI                                  0.1554  =======
#   height                                        0.1453  =======
#   NBR                                           0.0543  ==
#   EVI                                           0.0397  =
#   species_Avicennia germinans                   0.0316  =
#   RE2                                           0.0305  =
#   RE1                                           0.0296  =
#   species_Rhizophora mangle                     0.0251  =
#
# Completed: 18/18 experiments

# %%
tabulate_results(xg_belige_no_grid_grps, acceptable_only=True)
# Out:
# Showing 11 acceptable experiments
# <style type="text/css">
# #T_b77d8_row0_col8, #T_b77d8_row1_col9, #T_b77d8_row3_col2, #T_b77d8_row3_col3, #T_b77d8_row3_col10 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b77d8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b77d8_level0_col0" class="col_heading level0 col0" >Experiment</th>
#       <th id="T_b77d8_level0_col1" class="col_heading level0 col1" >Num_features</th>
#       <th id="T_b77d8_level0_col2" class="col_heading level0 col2" >Test R²</th>
#       <th id="T_b77d8_level0_col3" class="col_heading level0 col3" >Test RMSE</th>
#       <th id="T_b77d8_level0_col4" class="col_heading level0 col4" >Train R²</th>
#       <th id="T_b77d8_level0_col5" class="col_heading level0 col5" >Train RMSE</th>
#       <th id="T_b77d8_level0_col6" class="col_heading level0 col6" >CV R² Mean</th>
#       <th id="T_b77d8_level0_col7" class="col_heading level0 col7" >CV R² Std</th>
#       <th id="T_b77d8_level0_col8" class="col_heading level0 col8" >Group CV R² Mean</th>
#       <th id="T_b77d8_level0_col9" class="col_heading level0 col9" >Group CV R² Std</th>
#       <th id="T_b77d8_level0_col10" class="col_heading level0 col10" >CV-Test Gap</th>
#       <th id="T_b77d8_level0_col11" class="col_heading level0 col11" >-ve Folds</th>
#       <th id="T_b77d8_level0_col12" class="col_heading level0 col12" >verdict</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b77d8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b77d8_row0_col0" class="data row0 col0" >EXPERIMENT-2 Plot groups. Grid search: No, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].</td>
#       <td id="T_b77d8_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_b77d8_row0_col2" class="data row0 col2" >0.1298</td>
#       <td id="T_b77d8_row0_col3" class="data row0 col3" >4.31</td>
#       <td id="T_b77d8_row0_col4" class="data row0 col4" >-0.0097</td>
#       <td id="T_b77d8_row0_col5" class="data row0 col5" >18.66</td>
#       <td id="T_b77d8_row0_col6" class="data row0 col6" >0.1438</td>
#       <td id="T_b77d8_row0_col7" class="data row0 col7" >0.1642</td>
#       <td id="T_b77d8_row0_col8" class="data row0 col8" >0.2543</td>
#       <td id="T_b77d8_row0_col9" class="data row0 col9" >0.2041</td>
#       <td id="T_b77d8_row0_col10" class="data row0 col10" >0.1245</td>
#       <td id="T_b77d8_row0_col11" class="data row0 col11" >2 (Big Creek_5, Big Creek_3)</td>
#       <td id="T_b77d8_row0_col12" class="data row0 col12" >⚠️  MARGINAL — positive metrics but concerns</td>
#     </tr>
#     <tr>
#       <th id="T_b77d8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b77d8_row1_col0" class="data row1 col0" >EXPERIMENT-14 Plot groups. Grid search: No, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].</td>
#       <td id="T_b77d8_row1_col1" class="data row1 col1" >11</td>
#       <td id="T_b77d8_row1_col2" class="data row1 col2" >0.0883</td>
#       <td id="T_b77d8_row1_col3" class="data row1 col3" >4.41</td>
#       <td id="T_b77d8_row1_col4" class="data row1 col4" >-0.0056</td>
#       <td id="T_b77d8_row1_col5" class="data row1 col5" >18.62</td>
#       <td id="T_b77d8_row1_col6" class="data row1 col6" >0.0123</td>
#       <td id="T_b77d8_row1_col7" class="data row1 col7" >0.1807</td>
#       <td id="T_b77d8_row1_col8" class="data row1 col8" >0.2485</td>
#       <td id="T_b77d8_row1_col9" class="data row1 col9" >0.165</td>
#       <td id="T_b77d8_row1_col10" class="data row1 col10" >0.1602</td>
#       <td id="T_b77d8_row1_col11" class="data row1 col11" >2 (Big Creek_5, Big Creek_3)</td>
#       <td id="T_b77d8_row1_col12" class="data row1 col12" >⚠️  MARGINAL — positive metrics but concerns</td>
#     </tr>
#     <tr>
#       <th id="T_b77d8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b77d8_row2_col0" class="data row2 col0" >EXPERIMENT-1 Plot groups. Grid search: No, Features: ['height'].</td>
#       <td id="T_b77d8_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_b77d8_row2_col2" class="data row2 col2" >0.1187</td>
#       <td id="T_b77d8_row2_col3" class="data row2 col3" >4.33</td>
#       <td id="T_b77d8_row2_col4" class="data row2 col4" >-0.0122</td>
#       <td id="T_b77d8_row2_col5" class="data row2 col5" >18.68</td>
#       <td id="T_b77d8_row2_col6" class="data row2 col6" >0.126</td>
#       <td id="T_b77d8_row2_col7" class="data row2 col7" >0.1651</td>
#       <td id="T_b77d8_row2_col8" class="data row2 col8" >0.2468</td>
#       <td id="T_b77d8_row2_col9" class="data row2 col9" >0.1956</td>
#       <td id="T_b77d8_row2_col10" class="data row2 col10" >0.1281</td>
#       <td id="T_b77d8_row2_col11" class="data row2 col11" >1 (Big Creek_3)</td>
#       <td id="T_b77d8_row2_col12" class="data row2 col12" >⚠️  MARGINAL — positive metrics but concerns</td>
#     </tr>
#     <tr>
#       <th id="T_b77d8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b77d8_row3_col0" class="data row3 col0" >EXPERIMENT-4 Plot groups. Grid search: No, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].</td>
#       <td id="T_b77d8_row3_col1" class="data row3 col1" >12</td>
#       <td id="T_b77d8_row3_col2" class="data row3 col2" >0.2117</td>
#       <td id="T_b77d8_row3_col3" class="data row3 col3" >4.1</td>
#       <td id="T_b77d8_row3_col4" class="data row3 col4" >0.017</td>
#       <td id="T_b77d8_row3_col5" class="data row3 col5" >18.41</td>
#       <td id="T_b77d8_row3_col6" class="data row3 col6" >0.0877</td>
#       <td id="T_b77d8_row3_col7" class="data row3 col7" >0.2025</td>
#       <td id="T_b77d8_row3_col8" class="data row3 col8" >0.2269</td>
#       <td id="T_b77d8_row3_col9" class="data row3 col9" >0.2111</td>
#       <td id="T_b77d8_row3_col10" class="data row3 col10" >0.0152</td>
#       <td id="T_b77d8_row3_col11" class="data row3 col11" >2 (Big Creek_5, Big Creek_3)</td>
#       <td id="T_b77d8_row3_col12" class="data row3 col12" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_b77d8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b77d8_row4_col0" class="data row4 col0" >EXPERIMENT-12 Plot groups. Grid search: No, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].</td>
#       <td id="T_b77d8_row4_col1" class="data row4 col1" >8</td>
#       <td id="T_b77d8_row4_col2" class="data row4 col2" >0.0415</td>
#       <td id="T_b77d8_row4_col3" class="data row4 col3" >4.52</td>
#       <td id="T_b77d8_row4_col4" class="data row4 col4" >-0.0232</td>
#       <td id="T_b77d8_row4_col5" class="data row4 col5" >18.78</td>
#       <td id="T_b77d8_row4_col6" class="data row4 col6" >0.1394</td>
#       <td id="T_b77d8_row4_col7" class="data row4 col7" >0.2166</td>
#       <td id="T_b77d8_row4_col8" class="data row4 col8" >0.2119</td>
#       <td id="T_b77d8_row4_col9" class="data row4 col9" >0.1886</td>
#       <td id="T_b77d8_row4_col10" class="data row4 col10" >0.1704</td>
#       <td id="T_b77d8_row4_col11" class="data row4 col11" >2 (Big Creek_5, Big Creek_3)</td>
#       <td id="T_b77d8_row4_col12" class="data row4 col12" >⚠️  MARGINAL — positive metrics but concerns</td>
#     </tr>
#     <tr>
#       <th id="T_b77d8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b77d8_row5_col0" class="data row5 col0" >EXPERIMENT-11 Plot groups. Grid search: No, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1'].</td>
#       <td id="T_b77d8_row5_col1" class="data row5 col1" >5</td>
#       <td id="T_b77d8_row5_col2" class="data row5 col2" >0.0833</td>
#       <td id="T_b77d8_row5_col3" class="data row5 col3" >4.42</td>
#       <td id="T_b77d8_row5_col4" class="data row5 col4" >-0.0108</td>
#       <td id="T_b77d8_row5_col5" class="data row5 col5" >18.67</td>
#       <td id="T_b77d8_row5_col6" class="data row5 col6" >0.0761</td>
#       <td id="T_b77d8_row5_col7" class="data row5 col7" >0.2579</td>
#       <td id="T_b77d8_row5_col8" class="data row5 col8" >0.2096</td>

# %% [markdown]
# ### BELIGE DATA. PLOT GROUPS. ALL ROWS. XGBOOST (Hyper parameter tuning: Yes)

# %%
# %run Model_functions.ipynb

xg_belige_grid_grps = {}

run_experiment(X_belige, y_belige,
               is_groups=True, group_info=grp_belige,
               features_list=gen_features_list,
               experiments=xg_belige_grid_grps,
               model_type="xgboost", is_grid=True,
               is_stratified=is_stratified_g,
               global_experiment_list=global_experiment_list)
# Out:
# [1/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'subsample': 0.8, 'reg_lambda': 5, 'reg_alpha': 1.0, 'n_estimators': 500, 'min_child_weight': 5, 'max_depth': 3, 'learning_rate': 0.01, 'colsample_bytree': 0.7}
#
#  XGBOOST: EXPERIMENT-1 Plot groups. Grid search: Yes, Features: ['height'].
# Test R²     : 0.1217
# Test RMSE   : 4.33 kg
# Train R² (log scale): 0.3939
# Train R² (orig scale): 0.1213
# Train RMSE  : 17.41 kg
# Num rows    : 3100
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: 0.1910
# CV R² std : 0.1397
# CV scores : [0.004 0.439 0.162 0.171 0.179]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2669
# Grouped CV R² std : 0.1799
# Grouped CV scores : [ 0.08   0.127  0.246 -0.058  0.42   0.54   0.504  0.277  0.202  0.331]
# ============================================================
#  EVALUATION: EXPERIMENT-1 Plot groups. Grid search: Yes, Features: ['height'].
# ============================================================
#
# Test set:
#   R²   : 0.122
#   RMSE : 4.33 kg
#
# Regular CrossValidation:
#   Mean   : 0.191
#   Std    : 0.140
#   Scores : [0.004 0.439 0.162 0.171 0.179]
#
#   ✅ Test R² is positive (0.122)
#   ✅ CV mean is positive (0.191)
#
# Grouped CrossValidation:
#   Big Creek_5          :   0.080  ✅
#   Frenchman Caye_6     :   0.127  ✅
#   Frenchman Caye_3     :   0.246  ✅
#   Big Creek_3          :  -0.058  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.420  ✅
#   Big Creek_2          :   0.540  ✅
#   Drowned Caye_5       :   0.504  ✅
#   Gra Gra Lagoon_4     :   0.277  ✅
#   Channel Caye_2       :   0.202  ✅
#   Channel Caye_6       :   0.331  ✅
#
#   Mean : 0.267
#   Std  : 0.180
#
#   ✅ Grouped CV mean above 0.15 (0.267)
#   ✅ Grouped CV std below 0.25 (0.180)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.145 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.000)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ⚠️  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height                                        1.0000  ==================================================
#
# [2/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'subsample': 1.0, 'reg_lambda': 10, 'reg_alpha': 1.0, 'n_estimators': 500, 'min_child_weight': 5, 'max_depth': 3, 'learning_rate': 0.01, 'colsample_bytree': 0.5}
#
#  XGBOOST: EXPERIMENT-2 Plot groups. Grid search: Yes, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : 0.2186
# Test RMSE   : 4.08 kg
# Train R² (log scale): 0.3965
# Train R² (orig scale): 0.1225
# Train RMSE  : 17.40 kg
# Num rows    : 3100
# Num Features: 4
#
#  Cross-validation ---
# CV R² mean: 0.1925
# CV R² std : 0.1530
# CV scores : [-0.044  0.434  0.152  0.197  0.225]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2588
# Grouped CV R² std : 0.1969
# Grouped CV scores : [-0.071  0.17   0.242 -0.067  0.423  0.523  0.503  0.282  0.24   0.344]
# ============================================================
#  EVALUATION: EXPERIMENT-2 Plot groups. Grid search: Yes, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : 0.219
#   RMSE : 4.08 kg
#
# Regular CrossValidation:
#   Mean   : 0.193
#   Std    : 0.153
#   Scores : [-0.044  0.434  0.152  0.197  0.225]
#
#   ✅ Test R² is positive (0.219)
#   ✅ CV mean is positive (0.193)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.071  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :   0.170  ✅
#   Frenchman Caye_3     :   0.242  ✅
#   Big Creek_3          :  -0.067  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.423  ✅
#   Big Creek_2          :   0.523  ✅
#   Drowned Caye_5       :   0.503  ✅
#   Gra Gra Lagoon_4     :   0.282  ✅
#   Channel Caye_2       :   0.240  ✅
#   Channel Caye_6       :   0.344  ✅
#
#   Mean : 0.259
#   Std  : 0.197
#
#   ✅ Grouped CV mean above 0.15 (0.259)
#   ✅ Grouped CV std below 0.25 (0.197)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ✅ Grouped CV and test R² agree (gap: 0.040)
#   ✅ Train/test R² gap acceptable (gap: -0.096)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ✅ ACCEPTABLE
#
# Top 10 feature importances:
#   height_x_NDRE1                                0.3522  =================
#   height                                        0.3044  ===============
#   height_x_EVI                                  0.2094  ==========
#   height_x_NIR                                  0.1341  ======
#
# [3/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'subsample': 1.0, 'reg_lambda': 1, 'reg_alpha': 1.0, 'n_estimators': 200, 'min_child_weight': 5, 'max_depth': 5, 'learning_rate': 0.2, 'colsample_bytree': 0.5}
#
#  XGBOOST: EXPERIMENT-3 Plot groups. Grid search: Yes, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2'].
# Test R²     : 0.2359
# Test RMSE   : 4.03 kg
# Train R² (log scale): 0.4040
# Train R² (orig scale): 0.1636
# Train RMSE  : 16.98 kg
# Num rows    : 3100
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: -0.0238
# CV R² std : 0.3401
# CV scores : [-0.101  0.642 -0.127 -0.264 -0.269]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.0348
# Grouped CV R² std : 0.4669
# Grouped CV scores : [-0.145 -1.28   0.196 -0.015  0.148  0.317  0.481  0.223  0.22   0.203]
# ============================================================
#  EVALUATION: EXPERIMENT-3 Plot groups. Grid search: Yes, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2'].
# ============================================================
#
# Test set:
#   R²   : 0.236
#   RMSE : 4.03 kg
#
# Regular CrossValidation:
#   Mean   : -0.024
#   Std    : 0.340
#   Scores : [-0.101  0.642 -0.127 -0.264 -0.269]
#
#   ✅ Test R² is positive (0.236)
#   ❌ CV mean is negative (-0.024)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.145  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :  -1.280  ⚠️  near-zero variance artifact
#   Frenchman Caye_3     :   0.196  ✅
#   Big Creek_3          :  -0.015  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.148  ✅
#   Big Creek_2          :   0.317  ✅
#   Drowned Caye_5       :   0.481  ✅
#   Gra Gra Lagoon_4     :   0.223  ✅
#   Channel Caye_2       :   0.220  ✅
#   Channel Caye_6       :   0.203  ✅
#
#   Mean : 0.035
#   Std  : 0.467
#
#   ❌ Grouped CV mean below 0.15 (0.035)
#   ⚠️  Grouped CV std above 0.25 (0.467) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.201 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.072)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   RE2                                           0.3464  =================
#   Green                                         0.2099  ==========
#   SWIR1                                         0.1757  ========
#   Red                                           0.0820  ====
#   SWIR2                                         0.0519  ==
#   RE1                                           0.0431  ==
#   Blue                                          0.0413  ==
#   RE3                                           0.0321  =
#   NIR                                           0.0176
#
# [4/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'subsample': 0.6, 'reg_lambda': 1, 'reg_alpha': 1.0, 'n_estimators': 200, 'min_child_weight': 10, 'max_depth': 3, 'learning_rate': 0.2, 'colsample_bytree': 1.0}
#
#  XGBOOST: EXPERIMENT-4 Plot groups. Grid search: Yes, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : 0.1645
# Test RMSE   : 4.22 kg
# Train R² (log scale): 0.4035
# Train R² (orig scale): 0.1695
# Train RMSE  : 16.92 kg
# Num rows    : 3100
# Num Features: 12
#
#  Cross-validation ---
# CV R² mean: 0.1400
# CV R² std : 0.2118
# CV scores : [-0.027  0.554  0.017  0.046  0.11 ]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.0817
# Grouped CV R² std : 0.4235
# Grouped CV scores : [-0.018 -0.973  0.251 -0.05   0.477 -0.236  0.612  0.263  0.247  0.245]
# ============================================================
#  EVALUATION: EXPERIMENT-4 Plot groups. Grid search: Yes, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : 0.164
#   RMSE : 4.22 kg
#
# Regular CrossValidation:
#   Mean   : 0.140
#   Std    : 0.212
#   Scores : [-0.027  0.554  0.017  0.046  0.11 ]
#
#   ✅ Test R² is positive (0.164)
#   ✅ CV mean is positive (0.140)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.018  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :  -0.973  ⚠️  near-zero variance artifact
#   Frenchman Caye_3     :   0.251  ✅
#   Big Creek_3          :  -0.050  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.477  ✅
#   Big Creek_2          :  -0.236  ⚠️  near-zero variance artifact
#   Drowned Caye_5       :   0.612  ✅
#   Gra Gra Lagoon_4     :   0.263  ✅
#   Channel Caye_2       :   0.247  ✅
#   Channel Caye_6       :   0.245  ✅
#
#   Mean : 0.082
#   Std  : 0.423
#
#   ❌ Grouped CV mean below 0.15 (0.082)
#   ⚠️  Grouped CV std above 0.25 (0.423) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.083 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: 0.005)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ⚠️  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height_x_NDRE1                                0.2423  ============
#   height_x_EVI                                  0.2319  ===========
#   RE3                                           0.0803  ====
#   Red                                           0.0696  ===
#   RE2                                           0.0667  ===
#   RE1                                           0.0561  ==
#   height_x_NIR                                  0.0499  ==
#   SWIR2                                         0.0475  ==
#   Green                                         0.0414  ==
#   SWIR1                                         0.0386  =
#
# [5/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'subsample': 1.0, 'reg_lambda': 5, 'reg_alpha': 0, 'n_estimators': 500, 'min_child_weight': 5, 'max_depth': 5, 'learning_rate': 0.2, 'colsample_bytree': 0.7}
#
#  XGBOOST: EXPERIMENT-5 Plot groups. Grid search: Yes, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# Test R²     : 0.2082
# Test RMSE   : 4.11 kg
# Train R² (log scale): 0.4040
# Train R² (orig scale): 0.1660
# Train RMSE  : 16.96 kg
# Num rows    : 3100
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: -0.1609
# CV R² std : 0.4714
# CV scores : [-0.064  0.435 -0.131 -0.03  -1.014]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.2829
# Grouped CV R² std : 1.2395
# Grouped CV scores : [-0.029 -3.973  0.193 -0.099  0.402 -0.108  0.16   0.205  0.226  0.195]
# ============================================================
#  EVALUATION: EXPERIMENT-5 Plot groups. Grid search: Yes, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# ============================================================
#
# Test set:
#   R²   : 0.208
#   RMSE : 4.11 kg
#
# Regular CrossValidation:
#   Mean   : -0.161
#   Std    : 0.471
#   Scores : [-0.064  0.435 -0.131 -0.03  -1.014]
#
#   ✅ Test R² is positive (0.208)
#   ❌ CV mean is negative (-0.161)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.029  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :  -3.973  ⚠️  near-zero variance artifact
#   Frenchman Caye_3     :   0.193  ✅
#   Big Creek_3          :  -0.099  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.402  ✅
#   Big Creek_2          :  -0.108  ⚠️  near-zero variance artifact
#   Drowned Caye_5       :   0.160  ✅
#   Gra Gra Lagoon_4     :   0.205  ✅
#   Channel Caye_2       :   0.226  ✅
#   Channel Caye_6       :   0.195  ✅
#
#   Mean : -0.283
#   Std  : 1.240
#
#   ❌ Grouped CV mean below 0.15 (-0.283)
#   ⚠️  Grouped CV std above 0.25 (1.240) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.491 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.042)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   CIrededge                                     0.4028  ====================
#   NDRE1                                         0.2374  ===========
#   EVI                                           0.1780  ========
#   NDRE2                                         0.0660  ===
#   NBR                                           0.0474  ==
#   MNDWI                                         0.0405  ==
#   NDVI                                          0.0181
#   NDRE3                                         0.0099
#   CLOUD_COVERAGE                                0.0000
#
# [6/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'subsample': 1.0, 'reg_lambda': 10, 'reg_alpha': 0, 'n_estimators': 100, 'min_child_weight': 5, 'max_depth': 3, 'learning_rate': 0.01, 'colsample_bytree': 0.7}
#
#  XGBOOST: EXPERIMENT-6 Plot groups. Grid search: Yes, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : 0.1855
# Test RMSE   : 4.17 kg
# Train R² (log scale): 0.3074
# Train R² (orig scale): 0.0132
# Train RMSE  : 18.45 kg
# Num rows    : 3100
# Num Features: 12
#
#  Cross-validation ---
# CV R² mean: 0.0996
# CV R² std : 0.2275
# CV scores : [-0.066  0.536  0.107 -0.005 -0.074]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1390
# Grouped CV R² std : 0.2212
# Grouped CV scores : [-0.038 -0.401  0.162 -0.003  0.33   0.388  0.291  0.189  0.196  0.275]
# ============================================================
#  EVALUATION: EXPERIMENT-6 Plot groups. Grid search: Yes, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : 0.186
#   RMSE : 4.17 kg
#
# Regular CrossValidation:
#   Mean   : 0.100
#   Std    : 0.227
#   Scores : [-0.066  0.536  0.107 -0.005 -0.074]
#
#   ✅ Test R² is positive (0.186)
#   ✅ CV mean is positive (0.100)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.038  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :  -0.401  ⚠️  near-zero variance artifact
#   Frenchman Caye_3     :   0.162  ✅
#   Big Creek_3          :  -0.003  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.330  ✅
#   Big Creek_2          :   0.388  ✅
#   Drowned Caye_5       :   0.291  ✅
#   Gra Gra Lagoon_4     :   0.189  ✅
#   Channel Caye_2       :   0.196  ✅
#   Channel Caye_6       :   0.275  ✅
#
#   Mean : 0.139
#   Std  : 0.221
#
#   ❌ Grouped CV mean below 0.15 (0.139)
#   ✅ Grouped CV std below 0.25 (0.221)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ✅ Grouped CV and test R² agree (gap: 0.047)
#   ✅ Train/test R² gap acceptable (gap: -0.172)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ⚠️  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height_x_NIR                                  0.2550  ============
#   height_x_NDRE1                                0.2397  ===========
#   height_x_EVI                                  0.2277  ===========
#   CIrededge                                     0.0564  ==
#   NDRE1                                         0.0472  ==
#   MNDWI                                         0.0466  ==
#   EVI                                           0.0352  =
#   NDVI                                          0.0312  =
#   NDRE2                                         0.0285  =
#   NBR                                           0.0206  =
#
# [7/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'subsample': 0.8, 'reg_lambda': 1, 'reg_alpha': 0.1, 'n_estimators': 200, 'min_child_weight': 5, 'max_depth': 7, 'learning_rate': 0.1, 'colsample_bytree': 0.5}
#
#  XGBOOST: EXPERIMENT-7 Plot groups. Grid search: Yes, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# Test R²     : 0.2262
# Test RMSE   : 4.06 kg
# Train R² (log scale): 0.4039
# Train R² (orig scale): 0.1672
# Train RMSE  : 16.95 kg
# Num rows    : 3100
# Num Features: 18
#
#  Cross-validation ---
# CV R² mean: -0.1263
# CV R² std : 0.3897
# CV scores : [-0.068  0.412  0.007 -0.189 -0.793]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.3136
# Grouped CV R² std : 1.5272
# Grouped CV scores : [-0.141 -4.866  0.227 -0.1    0.323  0.451  0.243  0.237  0.249  0.243]
# ============================================================
#  EVALUATION: EXPERIMENT-7 Plot groups. Grid search: Yes, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# ============================================================
#
# Test set:
#   R²   : 0.226
#   RMSE : 4.06 kg
#
# Regular CrossValidation:
#   Mean   : -0.126
#   Std    : 0.390
#   Scores : [-0.068  0.412  0.007 -0.189 -0.793]
#
#   ✅ Test R² is positive (0.226)
#   ❌ CV mean is negative (-0.126)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.141  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :  -4.866  ⚠️  near-zero variance artifact
#   Frenchman Caye_3     :   0.227  ✅
#   Big Creek_3          :  -0.100  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.323  ✅
#   Big Creek_2          :   0.451  ✅
#   Drowned Caye_5       :   0.243  ✅
#   Gra Gra Lagoon_4     :   0.237  ✅
#   Channel Caye_2       :   0.249  ✅
#   Channel Caye_6       :   0.243  ✅
#
#   Mean : -0.314
#   Std  : 1.527
#
#   ❌ Grouped CV mean below 0.15 (-0.314)
#   ⚠️  Grouped CV std above 0.25 (1.527) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.540 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.059)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   CIrededge                                     0.1915  =========
#   NIR                                           0.1608  ========
#   NDRE1                                         0.1451  =======
#   EVI                                           0.1003  =====
#   RE3                                           0.0774  ===
#   RE2                                           0.0638  ===
#   NDRE2                                         0.0589  ==
#   NBR                                           0.0453  ==
#   SWIR1                                         0.0345  =
#   SWIR2                                         0.0226  =
#
# [8/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'subsample': 1.0, 'reg_lambda': 10, 'reg_alpha': 0, 'n_estimators': 100, 'min_child_weight': 5, 'max_depth': 3, 'learning_rate': 0.01, 'colsample_bytree': 0.7}
#
#  XGBOOST: EXPERIMENT-8 Plot groups. Grid search: Yes, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : 0.2154
# Test RMSE   : 4.09 kg
# Train R² (log scale): 0.3060
# Train R² (orig scale): 0.0140
# Train RMSE  : 18.44 kg
# Num rows    : 3100
# Num Features: 21
#
#  Cross-validation ---
# CV R² mean: 0.1101
# CV R² std : 0.2543
# CV scores : [-0.062  0.601  0.109 -0.016 -0.082]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.0629
# Grouped CV R² std : 0.4193
# Grouped CV scores : [-4.100e-02 -1.139e+00  1.660e-01  1.000e-03  3.270e-01  3.390e-01
#   3.120e-01  2.000e-01  1.890e-01  2.750e-01]
# ============================================================
#  EVALUATION: EXPERIMENT-8 Plot groups. Grid search: Yes, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : 0.215
#   RMSE : 4.09 kg
#
# Regular CrossValidation:
#   Mean   : 0.110
#   Std    : 0.254
#   Scores : [-0.062  0.601  0.109 -0.016 -0.082]
#
#   ✅ Test R² is positive (0.215)
#   ✅ CV mean is positive (0.110)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.041  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :  -1.139  ⚠️  near-zero variance artifact
#   Frenchman Caye_3     :   0.166  ✅
#   Big Creek_3          :   0.001  ✅
#   Frenchman Caye_1     :   0.327  ✅
#   Big Creek_2          :   0.339  ✅
#   Drowned Caye_5       :   0.312  ✅
#   Gra Gra Lagoon_4     :   0.200  ✅
#   Channel Caye_2       :   0.189  ✅
#   Channel Caye_6       :   0.275  ✅
#
#   Mean : 0.063
#   Std  : 0.419
#
#   ❌ Grouped CV mean below 0.15 (0.063)
#   ⚠️  Grouped CV std above 0.25 (0.419) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.153 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.201)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ⚠️  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height_x_NIR                                  0.2188  ==========
#   height_x_EVI                                  0.2004  ==========
#   height_x_NDRE1                                0.1801  =========
#   NDRE1                                         0.0713  ===
#   NDRE2                                         0.0659  ===
#   EVI                                           0.0437  ==
#   RE2                                           0.0383  =
#   Green                                         0.0263  =
#   MNDWI                                         0.0227  =
#   RE3                                           0.0205  =
#
# [9/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'subsample': 0.8, 'reg_lambda': 1, 'reg_alpha': 0, 'n_estimators': 200, 'min_child_weight': 10, 'max_depth': 5, 'learning_rate': 0.01, 'colsample_bytree': 1.0}
#
#  XGBOOST: EXPERIMENT-9 Plot groups. Grid search: Yes, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# Test R²     : -0.6765
# Test RMSE   : 5.98 kg
# Train R² (log scale): 0.3935
# Train R² (orig scale): 0.1122
# Train RMSE  : 17.50 kg
# Num rows    : 3100
# Num Features: 19
#
#  Cross-validation ---
# CV R² mean: 0.0766
# CV R² std : 0.1681
# CV scores : [-0.001  0.407  0.031 -0.064  0.01 ]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2050
# Grouped CV R² std : 0.1720
# Grouped CV scores : [ 0.056  0.15   0.243 -0.035  0.423 -0.056  0.494  0.262  0.211  0.301]
# ============================================================
#  EVALUATION: EXPERIMENT-9 Plot groups. Grid search: Yes, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# ============================================================
#
# Test set:
#   R²   : -0.676
#   RMSE : 5.98 kg
#
# Regular CrossValidation:
#   Mean   : 0.077
#   Std    : 0.168
#   Scores : [-0.001  0.407  0.031 -0.064  0.01 ]
#
#   ❌ Test R² is negative (-0.676)
#   ✅ CV mean is positive (0.077)
#
# Grouped CrossValidation:
#   Big Creek_5          :   0.056  ✅
#   Frenchman Caye_6     :   0.150  ✅
#   Frenchman Caye_3     :   0.243  ✅
#   Big Creek_3          :  -0.035  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.423  ✅
#   Big Creek_2          :  -0.056  ⚠️  near-zero variance artifact
#   Drowned Caye_5       :   0.494  ✅
#   Gra Gra Lagoon_4     :   0.262  ✅
#   Channel Caye_2       :   0.211  ✅
#   Channel Caye_6       :   0.301  ✅
#
#   Mean : 0.205
#   Std  : 0.172
#
#   ✅ Grouped CV mean above 0.15 (0.205)
#   ✅ Grouped CV std below 0.25 (0.172)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.881 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.789 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height                                        0.2624  =============
#   RE3                                           0.1476  =======
#   Green                                         0.1004  =====
#   RE2                                           0.0818  ====
#   EVI                                           0.0632  ===
#   NBR                                           0.0482  ==
#   SWIR2                                         0.0419  ==
#   NDRE2                                         0.0401  ==
#   SWIR1                                         0.0365  =
#   Red                                           0.0347  =
#
# [10/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'subsample': 0.8, 'reg_lambda': 1, 'reg_alpha': 0, 'n_estimators': 500, 'min_child_weight': 1, 'max_depth': 5, 'learning_rate': 0.05, 'colsample_bytree': 0.7}
#
#  XGBOOST: EXPERIMENT-10 Plot groups. Grid search: Yes, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : -0.3547
# Test RMSE   : 5.37 kg
# Train R² (log scale): 0.4040
# Train R² (orig scale): 0.1665
# Train RMSE  : 16.95 kg
# Num rows    : 3100
# Num Features: 22
#
#  Cross-validation ---
# CV R² mean: 0.0947
# CV R² std : 0.2199
# CV scores : [ 0.011  0.528 -0.084  0.001  0.018]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2068
# Grouped CV R² std : 0.1980
# Grouped CV scores : [-0.1   -0.041  0.238 -0.047  0.437  0.261  0.528  0.248  0.245  0.299]
# ============================================================
#  EVALUATION: EXPERIMENT-10 Plot groups. Grid search: Yes, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : -0.355
#   RMSE : 5.37 kg
#
# Regular CrossValidation:
#   Mean   : 0.095
#   Std    : 0.220
#   Scores : [ 0.011  0.528 -0.084  0.001  0.018]
#
#   ❌ Test R² is negative (-0.355)
#   ✅ CV mean is positive (0.095)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.100  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :  -0.041  ⚠️  near-zero variance artifact
#   Frenchman Caye_3     :   0.238  ✅
#   Big Creek_3          :  -0.047  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.437  ✅
#   Big Creek_2          :   0.261  ✅
#   Drowned Caye_5       :   0.528  ✅
#   Gra Gra Lagoon_4     :   0.248  ✅
#   Channel Caye_2       :   0.245  ✅
#   Channel Caye_6       :   0.299  ✅
#
#   Mean : 0.207
#   Std  : 0.198
#
#   ✅ Grouped CV mean above 0.15 (0.207)
#   ✅ Grouped CV std below 0.25 (0.198)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.562 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.521 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height_x_NDRE1                                0.3608  ==================
#   height_x_NIR                                  0.0889  ====
#   height                                        0.0752  ===
#   height_x_EVI                                  0.0674  ===
#   RE3                                           0.0598  ==
#   NIR                                           0.0465  ==
#   RE2                                           0.0408  ==
#   CIrededge                                     0.0293  =
#   Red                                           0.0237  =
#   NDRE1                                         0.0236  =
#
# [11/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'subsample': 0.8, 'reg_lambda': 1, 'reg_alpha': 0, 'n_estimators': 200, 'min_child_weight': 10, 'max_depth': 5, 'learning_rate': 0.01, 'colsample_bytree': 1.0}
#
#  XGBOOST: EXPERIMENT-11 Plot groups. Grid search: Yes, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1'].
# Test R²     : -0.5873
# Test RMSE   : 5.82 kg
# Train R² (log scale): 0.3922
# Train R² (orig scale): 0.1106
# Train RMSE  : 17.51 kg
# Num rows    : 3100
# Num Features: 5
#
#  Cross-validation ---
# CV R² mean: 0.1385
# CV R² std : 0.1401
# CV scores : [0.    0.384 0.083 0.029 0.197]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1747
# Grouped CV R² std : 0.2277
# Grouped CV scores : [ 0.112  0.132  0.24  -0.02   0.409 -0.375  0.466  0.238  0.222  0.324]
# ============================================================
#  EVALUATION: EXPERIMENT-11 Plot groups. Grid search: Yes, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1'].
# ============================================================
#
# Test set:
#   R²   : -0.587
#   RMSE : 5.82 kg
#
# Regular CrossValidation:
#   Mean   : 0.138
#   Std    : 0.140
#   Scores : [0.    0.384 0.083 0.029 0.197]
#
#   ❌ Test R² is negative (-0.587)
#   ✅ CV mean is positive (0.138)
#
# Grouped CrossValidation:
#   Big Creek_5          :   0.112  ✅
#   Frenchman Caye_6     :   0.132  ✅
#   Frenchman Caye_3     :   0.240  ✅
#   Big Creek_3          :  -0.020  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.409  ✅
#   Big Creek_2          :  -0.375  ⚠️  near-zero variance artifact
#   Drowned Caye_5       :   0.466  ✅
#   Gra Gra Lagoon_4     :   0.238  ✅
#   Channel Caye_2       :   0.222  ✅
#   Channel Caye_6       :   0.324  ✅
#
#   Mean : 0.175
#   Std  : 0.228
#
#   ✅ Grouped CV mean above 0.15 (0.175)
#   ✅ Grouped CV std below 0.25 (0.228)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.762 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.698 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height                                        0.5719  ============================
#   EVI                                           0.1921  =========
#   NBR                                           0.1119  =====
#   SWIR1                                         0.1007  =====
#   NIR                                           0.0233  =
#
# [12/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'subsample': 0.6, 'reg_lambda': 1, 'reg_alpha': 0, 'n_estimators': 200, 'min_child_weight': 10, 'max_depth': 3, 'learning_rate': 0.01, 'colsample_bytree': 0.5}
#
#  XGBOOST: EXPERIMENT-12 Plot groups. Grid search: Yes, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : 0.1283
# Test RMSE   : 4.31 kg
# Train R² (log scale): 0.3781
# Train R² (orig scale): 0.0895
# Train RMSE  : 17.72 kg
# Num rows    : 3100
# Num Features: 8
#
#  Cross-validation ---
# CV R² mean: 0.1846
# CV R² std : 0.1738
# CV scores : [-0.035  0.494  0.165  0.103  0.196]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2260
# Grouped CV R² std : 0.1853
# Grouped CV scores : [-0.024 -0.05   0.229 -0.008  0.413  0.355  0.522  0.26   0.242  0.322]
# ============================================================
#  EVALUATION: EXPERIMENT-12 Plot groups. Grid search: Yes, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : 0.128
#   RMSE : 4.31 kg
#
# Regular CrossValidation:
#   Mean   : 0.185
#   Std    : 0.174
#   Scores : [-0.035  0.494  0.165  0.103  0.196]
#
#   ✅ Test R² is positive (0.128)
#   ✅ CV mean is positive (0.185)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.024  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :  -0.050  ⚠️  near-zero variance artifact
#   Frenchman Caye_3     :   0.229  ✅
#   Big Creek_3          :  -0.008  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.413  ✅
#   Big Creek_2          :   0.355  ✅
#   Drowned Caye_5       :   0.522  ✅
#   Gra Gra Lagoon_4     :   0.260  ✅
#   Channel Caye_2       :   0.242  ✅
#   Channel Caye_6       :   0.322  ✅
#
#   Mean : 0.226
#   Std  : 0.185
#
#   ✅ Grouped CV mean above 0.15 (0.226)
#   ✅ Grouped CV std below 0.25 (0.185)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.098 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.039)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ⚠️  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height_x_NDRE1                                0.2755  =============
#   height_x_EVI                                  0.1978  =========
#   height                                        0.1708  ========
#   height_x_NIR                                  0.1526  =======
#   EVI                                           0.0625  ===
#   NBR                                           0.0566  ==
#   NIR                                           0.0491  ==
#   SWIR1                                         0.0351  =
#
# [13/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'subsample': 0.6, 'reg_lambda': 1, 'reg_alpha': 0, 'n_estimators': 200, 'min_child_weight': 10, 'max_depth': 3, 'learning_rate': 0.01, 'colsample_bytree': 0.5}
#
#  XGBOOST: EXPERIMENT-13 Plot groups. Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1'].
# Test R²     : 0.0933
# Test RMSE   : 4.39 kg
# Train R² (log scale): 0.3919
# Train R² (orig scale): 0.0743
# Train RMSE  : 17.87 kg
# Num rows    : 3100
# Num Features: 8
#
#  Cross-validation ---
# CV R² mean: 0.0906
# CV R² std : 0.2431
# CV scores : [ 0.013  0.488  0.211 -0.029 -0.23 ]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2554
# Grouped CV R² std : 0.1883
# Grouped CV scores : [0.031 0.    0.264 0.016 0.338 0.452 0.619 0.254 0.262 0.319]
# ============================================================
#  EVALUATION: EXPERIMENT-13 Plot groups. Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1'].
# ============================================================
#
# Test set:
#   R²   : 0.093
#   RMSE : 4.39 kg
#
# Regular CrossValidation:
#   Mean   : 0.091
#   Std    : 0.243
#   Scores : [ 0.013  0.488  0.211 -0.029 -0.23 ]
#
#   ✅ Test R² is positive (0.093)
#   ✅ CV mean is positive (0.091)
#
# Grouped CrossValidation:
#   Big Creek_5          :   0.031  ✅
#   Frenchman Caye_6     :   0.000  ✅
#   Frenchman Caye_3     :   0.264  ✅
#   Big Creek_3          :   0.016  ✅
#   Frenchman Caye_1     :   0.338  ✅
#   Big Creek_2          :   0.452  ✅
#   Drowned Caye_5       :   0.619  ✅
#   Gra Gra Lagoon_4     :   0.254  ✅
#   Channel Caye_2       :   0.262  ✅
#   Channel Caye_6       :   0.319  ✅
#
#   Mean : 0.255
#   Std  : 0.188
#
#   ✅ Grouped CV mean above 0.15 (0.255)
#   ✅ Grouped CV std below 0.25 (0.188)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.162 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.019)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ⚠️  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height                                        0.2817  ==============
#   EVI                                           0.1563  =======
#   NBR                                           0.1431  =======
#   NIR                                           0.1356  ======
#   species_Rhizophora mangle                     0.1020  =====
#   species_Avicennia germinans                   0.0947  ====
#   SWIR1                                         0.0697  ===
#   species_Laguncularia racemosa                 0.0168
#
# [14/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'subsample': 0.6, 'reg_lambda': 1, 'reg_alpha': 0, 'n_estimators': 200, 'min_child_weight': 10, 'max_depth': 3, 'learning_rate': 0.01, 'colsample_bytree': 0.5}
#
#  XGBOOST: EXPERIMENT-14 Plot groups. Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : 0.1871
# Test RMSE   : 4.16 kg
# Train R² (log scale): 0.3967
# Train R² (orig scale): 0.0899
# Train RMSE  : 17.71 kg
# Num rows    : 3100
# Num Features: 11
#
#  Cross-validation ---
# CV R² mean: 0.1205
# CV R² std : 0.1606
# CV scores : [-0.008  0.393  0.21   0.04  -0.033]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2603
# Grouped CV R² std : 0.1627
# Grouped CV scores : [-0.005  0.13   0.27   0.     0.428  0.455  0.454  0.259  0.273  0.34 ]
# ============================================================
#  EVALUATION: EXPERIMENT-14 Plot groups. Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : 0.187
#   RMSE : 4.16 kg
#
# Regular CrossValidation:
#   Mean   : 0.121
#   Std    : 0.161
#   Scores : [-0.008  0.393  0.21   0.04  -0.033]
#
#   ✅ Test R² is positive (0.187)
#   ✅ CV mean is positive (0.121)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.005  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :   0.130  ✅
#   Frenchman Caye_3     :   0.270  ✅
#   Big Creek_3          :   0.000  ✅
#   Frenchman Caye_1     :   0.428  ✅
#   Big Creek_2          :   0.455  ✅
#   Drowned Caye_5       :   0.454  ✅
#   Gra Gra Lagoon_4     :   0.259  ✅
#   Channel Caye_2       :   0.273  ✅
#   Channel Caye_6       :   0.340  ✅
#
#   Mean : 0.260
#   Std  : 0.163
#
#   ✅ Grouped CV mean above 0.15 (0.260)
#   ✅ Grouped CV std below 0.25 (0.163)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.073 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.097)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ⚠️  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height_x_NIR                                  0.1911  =========
#   height_x_NDRE1                                0.1776  ========
#   height                                        0.1549  =======
#   height_x_EVI                                  0.1548  =======
#   EVI                                           0.0576  ==
#   NBR                                           0.0574  ==
#   species_Rhizophora mangle                     0.0523  ==
#   species_Avicennia germinans                   0.0508  ==
#   NIR                                           0.0454  ==
#   SWIR1                                         0.0349  =
#
# [15/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'subsample': 0.8, 'reg_lambda': 1, 'reg_alpha': 0, 'n_estimators': 200, 'min_child_weight': 10, 'max_depth': 5, 'learning_rate': 0.01, 'colsample_bytree': 1.0}
#
#  XGBOOST: EXPERIMENT-15 Plot groups. Grid search: Yes, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2'].
# Test R²     : -0.6474
# Test RMSE   : 5.92 kg
# Train R² (log scale): 0.3924
# Train R² (orig scale): 0.1111
# Train RMSE  : 17.51 kg
# Num rows    : 3100
# Num Features: 7
#
#  Cross-validation ---
# CV R² mean: 0.1219
# CV R² std : 0.1331
# CV scores : [ 0.002  0.359  0.1   -0.006  0.155]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1603
# Grouped CV R² std : 0.2565
# Grouped CV scores : [ 0.111  0.127  0.233 -0.019  0.415 -0.497  0.456  0.225  0.242  0.311]
# ============================================================
#  EVALUATION: EXPERIMENT-15 Plot groups. Grid search: Yes, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2'].
# ============================================================
#
# Test set:
#   R²   : -0.647
#   RMSE : 5.92 kg
#
# Regular CrossValidation:
#   Mean   : 0.122
#   Std    : 0.133
#   Scores : [ 0.002  0.359  0.1   -0.006  0.155]
#
#   ❌ Test R² is negative (-0.647)
#   ✅ CV mean is positive (0.122)
#
# Grouped CrossValidation:
#   Big Creek_5          :   0.111  ✅
#   Frenchman Caye_6     :   0.127  ✅
#   Frenchman Caye_3     :   0.233  ✅
#   Big Creek_3          :  -0.019  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.415  ✅
#   Big Creek_2          :  -0.497  ⚠️  near-zero variance artifact
#   Drowned Caye_5       :   0.456  ✅
#   Gra Gra Lagoon_4     :   0.225  ✅
#   Channel Caye_2       :   0.242  ✅
#   Channel Caye_6       :   0.311  ✅
#
#   Mean : 0.160
#   Std  : 0.257
#
#   ✅ Grouped CV mean above 0.15 (0.160)
#   ⚠️  Grouped CV std above 0.25 (0.257) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.808 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.759 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height                                        0.5243  ==========================
#   EVI                                           0.1725  ========
#   NBR                                           0.1036  =====
#   SWIR1                                         0.0989  ====
#   RE1                                           0.0647  ===
#   NIR                                           0.0232  =
#   RE2                                           0.0128
#
# [16/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'subsample': 0.6, 'reg_lambda': 1, 'reg_alpha': 0, 'n_estimators': 200, 'min_child_weight': 10, 'max_depth': 3, 'learning_rate': 0.01, 'colsample_bytree': 0.5}
#
#  XGBOOST: EXPERIMENT-16 Plot groups. Grid search: Yes, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : 0.1558
# Test RMSE   : 4.24 kg
# Train R² (log scale): 0.3784
# Train R² (orig scale): 0.0872
# Train RMSE  : 17.74 kg
# Num rows    : 3100
# Num Features: 10
#
#  Cross-validation ---
# CV R² mean: 0.1511
# CV R² std : 0.1643
# CV scores : [-0.039  0.453  0.153  0.067  0.121]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1899
# Grouped CV R² std : 0.2233
# Grouped CV scores : [-0.027 -0.278  0.226 -0.007  0.418  0.223  0.528  0.251  0.239  0.327]
# ============================================================
#  EVALUATION: EXPERIMENT-16 Plot groups. Grid search: Yes, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : 0.156
#   RMSE : 4.24 kg
#
# Regular CrossValidation:
#   Mean   : 0.151
#   Std    : 0.164
#   Scores : [-0.039  0.453  0.153  0.067  0.121]
#
#   ✅ Test R² is positive (0.156)
#   ✅ CV mean is positive (0.151)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.027  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :  -0.278  ⚠️  near-zero variance artifact
#   Frenchman Caye_3     :   0.226  ✅
#   Big Creek_3          :  -0.007  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.418  ✅
#   Big Creek_2          :   0.223  ✅
#   Drowned Caye_5       :   0.528  ✅
#   Gra Gra Lagoon_4     :   0.251  ✅
#   Channel Caye_2       :   0.239  ✅
#   Channel Caye_6       :   0.327  ✅
#
#   Mean : 0.190
#   Std  : 0.223
#
#   ✅ Grouped CV mean above 0.15 (0.190)
#   ✅ Grouped CV std below 0.25 (0.223)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ✅ Grouped CV and test R² agree (gap: 0.034)
#   ✅ Train/test R² gap acceptable (gap: -0.069)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ✅ ACCEPTABLE
#
# Top 10 feature importances:
#   height_x_EVI                                  0.2228  ===========
#   height_x_NDRE1                                0.1931  =========
#   height_x_NIR                                  0.1823  =========
#   height                                        0.1515  =======
#   EVI                                           0.0624  ===
#   NIR                                           0.0437  ==
#   NBR                                           0.0413  ==
#   RE1                                           0.0360  =
#   RE2                                           0.0355  =
#   SWIR1                                         0.0315  =
#
# [17/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'subsample': 0.6, 'reg_lambda': 1, 'reg_alpha': 0, 'n_estimators': 200, 'min_child_weight': 10, 'max_depth': 3, 'learning_rate': 0.01, 'colsample_bytree': 0.5}
#
#  XGBOOST: EXPERIMENT-17 Plot groups. Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2'].
# Test R²     : 0.1583
# Test RMSE   : 4.23 kg
# Train R² (log scale): 0.3942
# Train R² (orig scale): 0.0750
# Train RMSE  : 17.86 kg
# Num rows    : 3100
# Num Features: 10
#
#  Cross-validation ---
# CV R² mean: 0.0545
# CV R² std : 0.2402
# CV scores : [ 0.008  0.417  0.196 -0.052 -0.297]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2378
# Grouped CV R² std : 0.2110
# Grouped CV scores : [ 0.043 -0.162  0.254  0.025  0.353  0.439  0.613  0.243  0.253  0.318]
# ============================================================
#  EVALUATION: EXPERIMENT-17 Plot groups. Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2'].
# ============================================================
#
# Test set:
#   R²   : 0.158
#   RMSE : 4.23 kg
#
# Regular CrossValidation:
#   Mean   : 0.054
#   Std    : 0.240
#   Scores : [ 0.008  0.417  0.196 -0.052 -0.297]
#
#   ✅ Test R² is positive (0.158)
#   ✅ CV mean is positive (0.054)
#
# Grouped CrossValidation:
#   Big Creek_5          :   0.043  ✅
#   Frenchman Caye_6     :  -0.162  ⚠️  near-zero variance artifact
#   Frenchman Caye_3     :   0.254  ✅
#   Big Creek_3          :   0.025  ✅
#   Frenchman Caye_1     :   0.353  ✅
#   Big Creek_2          :   0.439  ✅
#   Drowned Caye_5       :   0.613  ✅
#   Gra Gra Lagoon_4     :   0.243  ✅
#   Channel Caye_2       :   0.253  ✅
#   Channel Caye_6       :   0.318  ✅
#
#   Mean : 0.238
#   Std  : 0.211
#
#   ✅ Grouped CV mean above 0.15 (0.238)
#   ✅ Grouped CV std below 0.25 (0.211)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.079 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.083)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ⚠️  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height                                        0.2055  ==========
#   EVI                                           0.1743  ========
#   NIR                                           0.1226  ======
#   NBR                                           0.1055  =====
#   RE2                                           0.0919  ====
#   RE1                                           0.0742  ===
#   species_Rhizophora mangle                     0.0735  ===
#   species_Avicennia germinans                   0.0651  ===
#   SWIR1                                         0.0546  ==
#   species_Laguncularia racemosa                 0.0329  =
#
# [18/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'subsample': 0.8, 'reg_lambda': 1, 'reg_alpha': 1.0, 'n_estimators': 200, 'min_child_weight': 5, 'max_depth': 3, 'learning_rate': 0.1, 'colsample_bytree': 0.5}
#
#  XGBOOST: EXPERIMENT-18 Plot groups. Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : 0.1318
# Test RMSE   : 4.30 kg
# Train R² (log scale): 0.4591
# Train R² (orig scale): 0.1851
# Train RMSE  : 16.76 kg
# Num rows    : 3100
# Num Features: 13
#
#  Cross-validation ---
# CV R² mean: 0.1199
# CV R² std : 0.2307
# CV scores : [-0.027  0.551  0.17  -0.033 -0.061]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2646
# Grouped CV R² std : 0.1673
# Grouped CV scores : [ 0.016  0.152  0.362 -0.02   0.444  0.239  0.541  0.313  0.32   0.278]
# ============================================================
#  EVALUATION: EXPERIMENT-18 Plot groups. Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : 0.132
#   RMSE : 4.30 kg
#
# Regular CrossValidation:
#   Mean   : 0.120
#   Std    : 0.231
#   Scores : [-0.027  0.551  0.17  -0.033 -0.061]
#
#   ✅ Test R² is positive (0.132)
#   ✅ CV mean is positive (0.120)
#
# Grouped CrossValidation:
#   Big Creek_5          :   0.016  ✅
#   Frenchman Caye_6     :   0.152  ✅
#   Frenchman Caye_3     :   0.362  ✅
#   Big Creek_3          :  -0.020  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.444  ✅
#   Big Creek_2          :   0.239  ✅
#   Drowned Caye_5       :   0.541  ✅
#   Gra Gra Lagoon_4     :   0.313  ✅
#   Channel Caye_2       :   0.320  ✅
#   Channel Caye_6       :   0.278  ✅
#
#   Mean : 0.265
#   Std  : 0.167
#
#   ✅ Grouped CV mean above 0.15 (0.265)
#   ✅ Grouped CV std below 0.25 (0.167)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.133 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: 0.053)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ⚠️  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height_x_NDRE1                                0.2528  ============
#   height_x_EVI                                  0.1914  =========
#   height_x_NIR                                  0.1025  =====
#   height                                        0.0917  ====
#   EVI                                           0.0855  ====
#   species_Avicennia germinans                   0.0625  ===
#   species_Rhizophora mangle                     0.0525  ==
#   RE1                                           0.0397  =
#   NIR                                           0.0380  =
#   NBR                                           0.0260  =
#
# Completed: 18/18 experiments

# %%
tabulate_results(xg_belige_grid_grps, acceptable_only=True)
# Out:
# Showing 11 acceptable experiments
# <style type="text/css">
# #T_71bce_row0_col8, #T_71bce_row2_col9, #T_71bce_row3_col2, #T_71bce_row3_col3, #T_71bce_row7_col10 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_71bce">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_71bce_level0_col0" class="col_heading level0 col0" >Experiment</th>
#       <th id="T_71bce_level0_col1" class="col_heading level0 col1" >Num_features</th>
#       <th id="T_71bce_level0_col2" class="col_heading level0 col2" >Test R²</th>
#       <th id="T_71bce_level0_col3" class="col_heading level0 col3" >Test RMSE</th>
#       <th id="T_71bce_level0_col4" class="col_heading level0 col4" >Train R²</th>
#       <th id="T_71bce_level0_col5" class="col_heading level0 col5" >Train RMSE</th>
#       <th id="T_71bce_level0_col6" class="col_heading level0 col6" >CV R² Mean</th>
#       <th id="T_71bce_level0_col7" class="col_heading level0 col7" >CV R² Std</th>
#       <th id="T_71bce_level0_col8" class="col_heading level0 col8" >Group CV R² Mean</th>
#       <th id="T_71bce_level0_col9" class="col_heading level0 col9" >Group CV R² Std</th>
#       <th id="T_71bce_level0_col10" class="col_heading level0 col10" >CV-Test Gap</th>
#       <th id="T_71bce_level0_col11" class="col_heading level0 col11" >-ve Folds</th>
#       <th id="T_71bce_level0_col12" class="col_heading level0 col12" >verdict</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_71bce_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_71bce_row0_col0" class="data row0 col0" >EXPERIMENT-1 Plot groups. Grid search: Yes, Features: ['height'].</td>
#       <td id="T_71bce_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_71bce_row0_col2" class="data row0 col2" >0.1217</td>
#       <td id="T_71bce_row0_col3" class="data row0 col3" >4.33</td>
#       <td id="T_71bce_row0_col4" class="data row0 col4" >0.1213</td>
#       <td id="T_71bce_row0_col5" class="data row0 col5" >17.41</td>
#       <td id="T_71bce_row0_col6" class="data row0 col6" >0.191</td>
#       <td id="T_71bce_row0_col7" class="data row0 col7" >0.1397</td>
#       <td id="T_71bce_row0_col8" class="data row0 col8" >0.2669</td>
#       <td id="T_71bce_row0_col9" class="data row0 col9" >0.1799</td>
#       <td id="T_71bce_row0_col10" class="data row0 col10" >0.1452</td>
#       <td id="T_71bce_row0_col11" class="data row0 col11" >1 (Big Creek_3)</td>
#       <td id="T_71bce_row0_col12" class="data row0 col12" >⚠️  MARGINAL — positive metrics but concerns</td>
#     </tr>
#     <tr>
#       <th id="T_71bce_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_71bce_row1_col0" class="data row1 col0" >EXPERIMENT-18 Plot groups. Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].</td>
#       <td id="T_71bce_row1_col1" class="data row1 col1" >13</td>
#       <td id="T_71bce_row1_col2" class="data row1 col2" >0.1318</td>
#       <td id="T_71bce_row1_col3" class="data row1 col3" >4.3</td>
#       <td id="T_71bce_row1_col4" class="data row1 col4" >0.1851</td>
#       <td id="T_71bce_row1_col5" class="data row1 col5" >16.76</td>
#       <td id="T_71bce_row1_col6" class="data row1 col6" >0.1199</td>
#       <td id="T_71bce_row1_col7" class="data row1 col7" >0.2307</td>
#       <td id="T_71bce_row1_col8" class="data row1 col8" >0.2646</td>
#       <td id="T_71bce_row1_col9" class="data row1 col9" >0.1673</td>
#       <td id="T_71bce_row1_col10" class="data row1 col10" >0.1327</td>
#       <td id="T_71bce_row1_col11" class="data row1 col11" >1 (Big Creek_3)</td>
#       <td id="T_71bce_row1_col12" class="data row1 col12" >⚠️  MARGINAL — positive metrics but concerns</td>
#     </tr>
#     <tr>
#       <th id="T_71bce_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_71bce_row2_col0" class="data row2 col0" >EXPERIMENT-14 Plot groups. Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].</td>
#       <td id="T_71bce_row2_col1" class="data row2 col1" >11</td>
#       <td id="T_71bce_row2_col2" class="data row2 col2" >0.1871</td>
#       <td id="T_71bce_row2_col3" class="data row2 col3" >4.16</td>
#       <td id="T_71bce_row2_col4" class="data row2 col4" >0.0899</td>
#       <td id="T_71bce_row2_col5" class="data row2 col5" >17.71</td>
#       <td id="T_71bce_row2_col6" class="data row2 col6" >0.1205</td>
#       <td id="T_71bce_row2_col7" class="data row2 col7" >0.1606</td>
#       <td id="T_71bce_row2_col8" class="data row2 col8" >0.2603</td>
#       <td id="T_71bce_row2_col9" class="data row2 col9" >0.1627</td>
#       <td id="T_71bce_row2_col10" class="data row2 col10" >0.0732</td>
#       <td id="T_71bce_row2_col11" class="data row2 col11" >1 (Big Creek_5)</td>
#       <td id="T_71bce_row2_col12" class="data row2 col12" >⚠️  MARGINAL — positive metrics but concerns</td>
#     </tr>
#     <tr>
#       <th id="T_71bce_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_71bce_row3_col0" class="data row3 col0" >EXPERIMENT-2 Plot groups. Grid search: Yes, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].</td>
#       <td id="T_71bce_row3_col1" class="data row3 col1" >4</td>
#       <td id="T_71bce_row3_col2" class="data row3 col2" >0.2186</td>
#       <td id="T_71bce_row3_col3" class="data row3 col3" >4.08</td>
#       <td id="T_71bce_row3_col4" class="data row3 col4" >0.1225</td>
#       <td id="T_71bce_row3_col5" class="data row3 col5" >17.4</td>
#       <td id="T_71bce_row3_col6" class="data row3 col6" >0.1925</td>
#       <td id="T_71bce_row3_col7" class="data row3 col7" >0.153</td>
#       <td id="T_71bce_row3_col8" class="data row3 col8" >0.2588</td>
#       <td id="T_71bce_row3_col9" class="data row3 col9" >0.1969</td>
#       <td id="T_71bce_row3_col10" class="data row3 col10" >0.0403</td>
#       <td id="T_71bce_row3_col11" class="data row3 col11" >2 (Big Creek_5, Big Creek_3)</td>
#       <td id="T_71bce_row3_col12" class="data row3 col12" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_71bce_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_71bce_row4_col0" class="data row4 col0" >EXPERIMENT-13 Plot groups. Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1'].</td>
#       <td id="T_71bce_row4_col1" class="data row4 col1" >8</td>
#       <td id="T_71bce_row4_col2" class="data row4 col2" >0.0933</td>
#       <td id="T_71bce_row4_col3" class="data row4 col3" >4.39</td>
#       <td id="T_71bce_row4_col4" class="data row4 col4" >0.0743</td>
#       <td id="T_71bce_row4_col5" class="data row4 col5" >17.87</td>
#       <td id="T_71bce_row4_col6" class="data row4 col6" >0.0906</td>
#       <td id="T_71bce_row4_col7" class="data row4 col7" >0.2431</td>
#       <td id="T_71bce_row4_col8" class="data row4 col8" >0.2554</td>
#       <td id="T_71bce_row4_col9" class="data row4 col9" >0.1883</td>
#       <td id="T_71bce_row4_col10" class="data row4 col10" >0.1621</td>
#       <td id="T_71bce_row4_col11" class="data row4 col11" >none</td>
#       <td id="T_71bce_row4_col12" class="data row4 col12" >⚠️  MARGINAL — positive metrics but concerns</td>
#     </tr>
#     <tr>
#       <th id="T_71bce_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_71bce_row5_col0" class="data row5 col0" >EXPERIMENT-17 Plot groups. Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2'].</td>
#       <td id="T_71bce_row5_col1" class="data row5 col1" >10</td>
#       <td id="T_71bce_row5_col2" class="data row5 col2" >0.1583</td>
#       <td id="T_71bce_row5_col3" class="data row5 col3" >4.23</td>
#       <td id="T_71bce_row5_col4" class="data row5 col4" >0.075</td>
#       <td id="T_71bce_row5_col5" class="data row5 col5" >17.86</td>
#       <td id="T_71bce_row5_col6" class="data row5 col6" >0.0545</td>
#       <td id="T_71bce_row5_col7" class="data row5 col7" >0.2402</td>
#       <td id="T_71bce_row5_col8" class="data row5 col8" >0.2378</td>
#       <td id="T_71bce_row5_col9" class="data row5 col9" >0.211</td>

# %% [markdown]
# ### BELIGE DATA. PLOT GROUPS. ALL ROWS. LGBM (Hyper parameter tuning: No)

# %%
# %run Model_functions.ipynb

lgbm_belige_no_grid_grps = {}

run_experiment(X_belige, y_belige,
               is_groups=True, group_info=grp_belige,
               features_list=gen_features_list,
               experiments=lgbm_belige_no_grid_grps,
               model_type="lgbm", is_grid=False,
               is_stratified=is_stratified_g,
               global_experiment_list=global_experiment_list)
# Out:
# [1/18]
#
#  LIGHTGBM: EXPERIMENT-1 Plot groups. Grid search: Yes, Features: ['height'].
# Test R²     : 0.1322
# Test RMSE   : 4.30 kg
# Train R² (log scale): 0.4003
# Train R² (orig scale): 0.1462
# Train RMSE  : 17.16 kg
# Num rows    : 3100
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: 0.0796
# CV R² std : 0.2890
# CV scores : [-0.196  0.567  0.08   0.176 -0.229]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2093
# Grouped CV R² std : 0.2722
# Grouped CV scores : [ 0.106 -0.363  0.25  -0.129  0.451  0.563  0.486  0.286  0.123  0.32 ]
# ============================================================
#  EVALUATION: EXPERIMENT-1 Plot groups. Grid search: Yes, Features: ['height'].
# ============================================================
#
# Test set:
#   R²   : 0.132
#   RMSE : 4.30 kg
#
# Regular CrossValidation:
#   Mean   : 0.080
#   Std    : 0.289
#   Scores : [-0.196  0.567  0.08   0.176 -0.229]
#
#   ✅ Test R² is positive (0.132)
#   ✅ CV mean is positive (0.080)
#
# Grouped CrossValidation:
#   Big Creek_5          :   0.106  ✅
#   Frenchman Caye_6     :  -0.363  ⚠️  near-zero variance artifact
#   Frenchman Caye_3     :   0.250  ✅
#   Big Creek_3          :  -0.129  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.451  ✅
#   Big Creek_2          :   0.563  ✅
#   Drowned Caye_5       :   0.486  ✅
#   Gra Gra Lagoon_4     :   0.286  ✅
#   Channel Caye_2       :   0.123  ✅
#   Channel Caye_6       :   0.320  ✅
#
#   Mean : 0.209
#   Std  : 0.272
#
#   ✅ Grouped CV mean above 0.15 (0.209)
#   ⚠️  Grouped CV std above 0.25 (0.272) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.077 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: 0.014)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ⚠️  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height                                        1.0000  ==================================================
#
# [2/18]
#
#  LIGHTGBM: EXPERIMENT-2 Plot groups. Grid search: Yes, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : 0.1671
# Test RMSE   : 4.21 kg
# Train R² (log scale): 0.4005
# Train R² (orig scale): 0.1494
# Train RMSE  : 17.13 kg
# Num rows    : 3100
# Num Features: 4
#
#  Cross-validation ---
# CV R² mean: 0.1646
# CV R² std : 0.2192
# CV scores : [-0.109  0.557  0.069  0.183  0.122]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2619
# Grouped CV R² std : 0.2058
# Grouped CV scores : [-0.042  0.147  0.252 -0.051  0.476  0.583  0.485  0.282  0.143  0.344]
# ============================================================
#  EVALUATION: EXPERIMENT-2 Plot groups. Grid search: Yes, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : 0.167
#   RMSE : 4.21 kg
#
# Regular CrossValidation:
#   Mean   : 0.165
#   Std    : 0.219
#   Scores : [-0.109  0.557  0.069  0.183  0.122]
#
#   ✅ Test R² is positive (0.167)
#   ✅ CV mean is positive (0.165)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.042  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :   0.147  ✅
#   Frenchman Caye_3     :   0.252  ✅
#   Big Creek_3          :  -0.051  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.476  ✅
#   Big Creek_2          :   0.583  ✅
#   Drowned Caye_5       :   0.485  ✅
#   Gra Gra Lagoon_4     :   0.282  ✅
#   Channel Caye_2       :   0.143  ✅
#   Channel Caye_6       :   0.344  ✅
#
#   Mean : 0.262
#   Std  : 0.206
#
#   ✅ Grouped CV mean above 0.15 (0.262)
#   ✅ Grouped CV std below 0.25 (0.206)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.095 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.018)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ⚠️  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height                                        0.5015  =========================
#   height_x_EVI                                  0.2749  =============
#   height_x_NIR                                  0.1178  =====
#   height_x_NDRE1                                0.1058  =====
#
# [3/18]
#
#  LIGHTGBM: EXPERIMENT-3 Plot groups. Grid search: Yes, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2'].
# Test R²     : 0.2357
# Test RMSE   : 4.03 kg
# Train R² (log scale): 0.4040
# Train R² (orig scale): 0.1659
# Train RMSE  : 16.96 kg
# Num rows    : 3100
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: -0.2286
# CV R² std : 0.4582
# CV scores : [-0.057  0.343 -0.106 -0.272 -1.051]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.0352
# Grouped CV R² std : 0.5884
# Grouped CV scores : [-0.338 -1.542  0.23  -0.109  0.444  0.578  0.527  0.166  0.179  0.217]
# ============================================================
#  EVALUATION: EXPERIMENT-3 Plot groups. Grid search: Yes, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2'].
# ============================================================
#
# Test set:
#   R²   : 0.236
#   RMSE : 4.03 kg
#
# Regular CrossValidation:
#   Mean   : -0.229
#   Std    : 0.458
#   Scores : [-0.057  0.343 -0.106 -0.272 -1.051]
#
#   ✅ Test R² is positive (0.236)
#   ❌ CV mean is negative (-0.229)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.338  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :  -1.542  ⚠️  near-zero variance artifact
#   Frenchman Caye_3     :   0.230  ✅
#   Big Creek_3          :  -0.109  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.444  ✅
#   Big Creek_2          :   0.578  ✅
#   Drowned Caye_5       :   0.527  ✅
#   Gra Gra Lagoon_4     :   0.166  ✅
#   Channel Caye_2       :   0.179  ✅
#   Channel Caye_6       :   0.217  ✅
#
#   Mean : 0.035
#   Std  : 0.588
#
#   ❌ Grouped CV mean below 0.15 (0.035)
#   ⚠️  Grouped CV std above 0.25 (0.588) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.201 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.070)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   Green                                         0.1916  =========
#   RE1                                           0.1546  =======
#   Blue                                          0.1413  =======
#   SWIR1                                         0.1411  =======
#   RE2                                           0.0984  ====
#   Red                                           0.0884  ====
#   RE3                                           0.0637  ===
#   SWIR2                                         0.0619  ===
#   NIR                                           0.0591  ==
#
# [4/18]
#
#  LIGHTGBM: EXPERIMENT-4 Plot groups. Grid search: Yes, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : 0.0655
# Test RMSE   : 4.46 kg
# Train R² (log scale): 0.4040
# Train R² (orig scale): 0.1659
# Train RMSE  : 16.96 kg
# Num rows    : 3100
# Num Features: 12
#
#  Cross-validation ---
# CV R² mean: 0.0355
# CV R² std : 0.1487
# CV scores : [-0.089  0.328 -0.012 -0.022 -0.028]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1977
# Grouped CV R² std : 0.2183
# Grouped CV scores : [-0.231  0.017  0.249 -0.065  0.485  0.217  0.494  0.254  0.249  0.307]
# ============================================================
#  EVALUATION: EXPERIMENT-4 Plot groups. Grid search: Yes, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : 0.066
#   RMSE : 4.46 kg
#
# Regular CrossValidation:
#   Mean   : 0.036
#   Std    : 0.149
#   Scores : [-0.089  0.328 -0.012 -0.022 -0.028]
#
#   ✅ Test R² is positive (0.066)
#   ✅ CV mean is positive (0.036)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.231  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :   0.017  ✅
#   Frenchman Caye_3     :   0.249  ✅
#   Big Creek_3          :  -0.065  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.485  ✅
#   Big Creek_2          :   0.217  ✅
#   Drowned Caye_5       :   0.494  ✅
#   Gra Gra Lagoon_4     :   0.254  ✅
#   Channel Caye_2       :   0.249  ✅
#   Channel Caye_6       :   0.307  ✅
#
#   Mean : 0.198
#   Std  : 0.218
#
#   ✅ Grouped CV mean above 0.15 (0.198)
#   ✅ Grouped CV std below 0.25 (0.218)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.132 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.100 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ⚠️  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height_x_EVI                                  0.1406  =======
#   Blue                                          0.1200  =====
#   Green                                         0.1135  =====
#   RE2                                           0.1046  =====
#   SWIR1                                         0.0969  ====
#   Red                                           0.0777  ===
#   height_x_NIR                                  0.0750  ===
#   RE1                                           0.0748  ===
#   height_x_NDRE1                                0.0561  ==
#   RE3                                           0.0541  ==
#
# [5/18]
#
#  LIGHTGBM: EXPERIMENT-5 Plot groups. Grid search: Yes, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# Test R²     : 0.2230
# Test RMSE   : 4.07 kg
# Train R² (log scale): 0.4040
# Train R² (orig scale): 0.1658
# Train RMSE  : 16.96 kg
# Num rows    : 3100
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: -0.5259
# CV R² std : 1.1789
# CV scores : [-0.062  0.326  0.054 -0.082 -2.866]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.5003
# Grouped CV R² std : 1.9310
# Grouped CV scores : [-0.166 -6.262 -0.096 -0.069  0.48   0.387  0.193  0.231  0.237  0.063]
# ============================================================
#  EVALUATION: EXPERIMENT-5 Plot groups. Grid search: Yes, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# ============================================================
#
# Test set:
#   R²   : 0.223
#   RMSE : 4.07 kg
#
# Regular CrossValidation:
#   Mean   : -0.526
#   Std    : 1.179
#   Scores : [-0.062  0.326  0.054 -0.082 -2.866]
#
#   ✅ Test R² is positive (0.223)
#   ❌ CV mean is negative (-0.526)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.166  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :  -6.262  ⚠️  near-zero variance artifact
#   Frenchman Caye_3     :  -0.096  ⚠️  near-zero variance artifact
#   Big Creek_3          :  -0.069  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.480  ✅
#   Big Creek_2          :   0.387  ✅
#   Drowned Caye_5       :   0.193  ✅
#   Gra Gra Lagoon_4     :   0.231  ✅
#   Channel Caye_2       :   0.237  ✅
#   Channel Caye_6       :   0.063  ✅
#
#   Mean : -0.500
#   Std  : 1.931
#
#   ❌ Grouped CV mean below 0.15 (-0.500)
#   ⚠️  Grouped CV std above 0.25 (1.931) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.723 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.057)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   NDVI                                          0.2091  ==========
#   EVI                                           0.1623  ========
#   NBR                                           0.1439  =======
#   NDRE2                                         0.1419  =======
#   MNDWI                                         0.1350  ======
#   NDRE1                                         0.0942  ====
#   NDRE3                                         0.0885  ====
#   CIrededge                                     0.0252  =
#   CLOUD_COVERAGE                                0.0000
#
# [6/18]
#
#  LIGHTGBM: EXPERIMENT-6 Plot groups. Grid search: Yes, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : 0.1462
# Test RMSE   : 4.26 kg
# Train R² (log scale): 0.4040
# Train R² (orig scale): 0.1659
# Train RMSE  : 16.96 kg
# Num rows    : 3100
# Num Features: 12
#
#  Cross-validation ---
# CV R² mean: -0.0457
# CV R² std : 0.4477
# CV scores : [-0.082  0.645  0.009 -0.033 -0.768]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.0512
# Grouped CV R² std : 0.7489
# Grouped CV scores : [-0.11  -2.094  0.263 -0.039  0.507  0.578  0.59   0.267  0.223  0.328]
# ============================================================
#  EVALUATION: EXPERIMENT-6 Plot groups. Grid search: Yes, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : 0.146
#   RMSE : 4.26 kg
#
# Regular CrossValidation:
#   Mean   : -0.046
#   Std    : 0.448
#   Scores : [-0.082  0.645  0.009 -0.033 -0.768]
#
#   ✅ Test R² is positive (0.146)
#   ❌ CV mean is negative (-0.046)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.110  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :  -2.094  ⚠️  near-zero variance artifact
#   Frenchman Caye_3     :   0.263  ✅
#   Big Creek_3          :  -0.039  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.507  ✅
#   Big Creek_2          :   0.578  ✅
#   Drowned Caye_5       :   0.590  ✅
#   Gra Gra Lagoon_4     :   0.267  ✅
#   Channel Caye_2       :   0.223  ✅
#   Channel Caye_6       :   0.328  ✅
#
#   Mean : 0.051
#   Std  : 0.749
#
#   ❌ Grouped CV mean below 0.15 (0.051)
#   ⚠️  Grouped CV std above 0.25 (0.749) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.095 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: 0.020)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   MNDWI                                         0.1634  ========
#   NDVI                                          0.1611  ========
#   EVI                                           0.1206  ======
#   NBR                                           0.1078  =====
#   NDRE2                                         0.0975  ====
#   NDRE3                                         0.0838  ====
#   height_x_NDRE1                                0.0808  ====
#   height_x_EVI                                  0.0727  ===
#   NDRE1                                         0.0641  ===
#   height_x_NIR                                  0.0337  =
#
# [7/18]
#
#  LIGHTGBM: EXPERIMENT-7 Plot groups. Grid search: Yes, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# Test R²     : 0.1548
# Test RMSE   : 4.24 kg
# Train R² (log scale): 0.4040
# Train R² (orig scale): 0.1658
# Train RMSE  : 16.96 kg
# Num rows    : 3100
# Num Features: 18
#
#  Cross-validation ---
# CV R² mean: -0.2542
# CV R² std : 0.5966
# CV scores : [-0.047  0.311  0.027 -0.155 -1.407]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.3708
# Grouped CV R² std : 1.8509
# Grouped CV scores : [-0.1   -5.893  0.246 -0.052  0.507  0.547  0.318  0.27   0.253  0.196]
# ============================================================
#  EVALUATION: EXPERIMENT-7 Plot groups. Grid search: Yes, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# ============================================================
#
# Test set:
#   R²   : 0.155
#   RMSE : 4.24 kg
#
# Regular CrossValidation:
#   Mean   : -0.254
#   Std    : 0.597
#   Scores : [-0.047  0.311  0.027 -0.155 -1.407]
#
#   ✅ Test R² is positive (0.155)
#   ❌ CV mean is negative (-0.254)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.100  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :  -5.893  ⚠️  near-zero variance artifact
#   Frenchman Caye_3     :   0.246  ✅
#   Big Creek_3          :  -0.052  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.507  ✅
#   Big Creek_2          :   0.547  ✅
#   Drowned Caye_5       :   0.318  ✅
#   Gra Gra Lagoon_4     :   0.270  ✅
#   Channel Caye_2       :   0.253  ✅
#   Channel Caye_6       :   0.196  ✅
#
#   Mean : -0.371
#   Std  : 1.851
#
#   ❌ Grouped CV mean below 0.15 (-0.371)
#   ⚠️  Grouped CV std above 0.25 (1.851) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.526 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: 0.011)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   NBR                                           0.1067  =====
#   Blue                                          0.1010  =====
#   RE1                                           0.0909  ====
#   NDRE2                                         0.0837  ====
#   EVI                                           0.0788  ===
#   Green                                         0.0695  ===
#   SWIR1                                         0.0690  ===
#   MNDWI                                         0.0666  ===
#   RE2                                           0.0560  ==
#   NDRE1                                         0.0465  ==
#
# [8/18]
#
#  LIGHTGBM: EXPERIMENT-8 Plot groups. Grid search: Yes, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : 0.1213
# Test RMSE   : 4.33 kg
# Train R² (log scale): 0.4040
# Train R² (orig scale): 0.1658
# Train RMSE  : 16.96 kg
# Num rows    : 3100
# Num Features: 21
#
#  Cross-validation ---
# CV R² mean: -0.0378
# CV R² std : 0.3371
# CV scores : [-0.086  0.485  0.    -0.011 -0.577]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.1425
# Grouped CV R² std : 1.0531
# Grouped CV scores : [-0.28  -3.219  0.259 -0.053  0.44   0.012  0.605  0.249  0.241  0.321]
# ============================================================
#  EVALUATION: EXPERIMENT-8 Plot groups. Grid search: Yes, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : 0.121
#   RMSE : 4.33 kg
#
# Regular CrossValidation:
#   Mean   : -0.038
#   Std    : 0.337
#   Scores : [-0.086  0.485  0.    -0.011 -0.577]
#
#   ✅ Test R² is positive (0.121)
#   ❌ CV mean is negative (-0.038)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.280  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :  -3.219  ⚠️  near-zero variance artifact
#   Frenchman Caye_3     :   0.259  ✅
#   Big Creek_3          :  -0.053  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.440  ✅
#   Big Creek_2          :   0.012  ✅
#   Drowned Caye_5       :   0.605  ✅
#   Gra Gra Lagoon_4     :   0.249  ✅
#   Channel Caye_2       :   0.241  ✅
#   Channel Caye_6       :   0.321  ✅
#
#   Mean : -0.142
#   Std  : 1.053
#
#   ❌ Grouped CV mean below 0.15 (-0.142)
#   ⚠️  Grouped CV std above 0.25 (1.053) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.264 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: 0.045)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   Blue                                          0.1078  =====
#   Green                                         0.0879  ====
#   MNDWI                                         0.0717  ===
#   NBR                                           0.0681  ===
#   RE2                                           0.0673  ===
#   RE1                                           0.0614  ===
#   RE3                                           0.0578  ==
#   NDRE3                                         0.0564  ==
#   SWIR1                                         0.0544  ==
#   height_x_EVI                                  0.0539  ==
#
# [9/18]
#
#  LIGHTGBM: EXPERIMENT-9 Plot groups. Grid search: Yes, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# Test R²     : -0.4733
# Test RMSE   : 5.60 kg
# Train R² (log scale): 0.4040
# Train R² (orig scale): 0.1658
# Train RMSE  : 16.96 kg
# Num rows    : 3100
# Num Features: 19
#
#  Cross-validation ---
# CV R² mean: -0.1434
# CV R² std : 0.3274
# CV scores : [-0.603  0.343 -0.01  -0.055 -0.392]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2012
# Grouped CV R² std : 0.2706
# Grouped CV scores : [ 0.053 -0.397  0.262 -0.063  0.491  0.288  0.625  0.225  0.254  0.273]
# ============================================================
#  EVALUATION: EXPERIMENT-9 Plot groups. Grid search: Yes, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# ============================================================
#
# Test set:
#   R²   : -0.473
#   RMSE : 5.60 kg
#
# Regular CrossValidation:
#   Mean   : -0.143
#   Std    : 0.327
#   Scores : [-0.603  0.343 -0.01  -0.055 -0.392]
#
#   ❌ Test R² is negative (-0.473)
#   ❌ CV mean is negative (-0.143)
#
# Grouped CrossValidation:
#   Big Creek_5          :   0.053  ✅
#   Frenchman Caye_6     :  -0.397  ⚠️  near-zero variance artifact
#   Frenchman Caye_3     :   0.262  ✅
#   Big Creek_3          :  -0.063  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.491  ✅
#   Big Creek_2          :   0.288  ✅
#   Drowned Caye_5       :   0.625  ✅
#   Gra Gra Lagoon_4     :   0.225  ✅
#   Channel Caye_2       :   0.254  ✅
#   Channel Caye_6       :   0.273  ✅
#
#   Mean : 0.201
#   Std  : 0.271
#
#   ✅ Grouped CV mean above 0.15 (0.201)
#   ⚠️  Grouped CV std above 0.25 (0.271) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.675 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.639 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height                                        0.1851  =========
#   Blue                                          0.1029  =====
#   NBR                                           0.0799  ===
#   Red                                           0.0685  ===
#   Green                                         0.0635  ===
#   RE1                                           0.0550  ==
#   SWIR1                                         0.0514  ==
#   EVI                                           0.0502  ==
#   MNDWI                                         0.0485  ==
#   NDRE3                                         0.0467  ==
#
# [10/18]
#
#  LIGHTGBM: EXPERIMENT-10 Plot groups. Grid search: Yes, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : -0.4050
# Test RMSE   : 5.47 kg
# Train R² (log scale): 0.4040
# Train R² (orig scale): 0.1658
# Train RMSE  : 16.96 kg
# Num rows    : 3100
# Num Features: 22
#
#  Cross-validation ---
# CV R² mean: -0.0736
# CV R² std : 0.2995
# CV scores : [-0.449  0.441 -0.023 -0.063 -0.273]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1409
# Grouped CV R² std : 0.3345
# Grouped CV scores : [-0.257 -0.562  0.262 -0.051  0.496  0.093  0.62   0.23   0.242  0.335]
# ============================================================
#  EVALUATION: EXPERIMENT-10 Plot groups. Grid search: Yes, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : -0.405
#   RMSE : 5.47 kg
#
# Regular CrossValidation:
#   Mean   : -0.074
#   Std    : 0.299
#   Scores : [-0.449  0.441 -0.023 -0.063 -0.273]
#
#   ❌ Test R² is negative (-0.405)
#   ❌ CV mean is negative (-0.074)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.257  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :  -0.562  ⚠️  near-zero variance artifact
#   Frenchman Caye_3     :   0.262  ✅
#   Big Creek_3          :  -0.051  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.496  ✅
#   Big Creek_2          :   0.093  ✅
#   Drowned Caye_5       :   0.620  ✅
#   Gra Gra Lagoon_4     :   0.230  ✅
#   Channel Caye_2       :   0.242  ✅
#   Channel Caye_6       :   0.335  ✅
#
#   Mean : 0.141
#   Std  : 0.335
#
#   ❌ Grouped CV mean below 0.15 (0.141)
#   ⚠️  Grouped CV std above 0.25 (0.335) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.546 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.571 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height                                        0.1490  =======
#   Blue                                          0.0801  ====
#   RE2                                           0.0716  ===
#   NBR                                           0.0697  ===
#   MNDWI                                         0.0684  ===
#   EVI                                           0.0609  ===
#   Green                                         0.0515  ==
#   SWIR1                                         0.0513  ==
#   NDRE1                                         0.0454  ==
#   Red                                           0.0446  ==
#
# [11/18]
#
#  LIGHTGBM: EXPERIMENT-11 Plot groups. Grid search: Yes, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1'].
# Test R²     : -0.2134
# Test RMSE   : 5.08 kg
# Train R² (log scale): 0.4040
# Train R² (orig scale): 0.1658
# Train RMSE  : 16.96 kg
# Num rows    : 3100
# Num Features: 5
#
#  Cross-validation ---
# CV R² mean: -0.0727
# CV R² std : 0.4828
# CV scores : [-0.903  0.608 -0.084 -0.     0.016]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2229
# Grouped CV R² std : 0.1768
# Grouped CV scores : [ 0.031  0.016  0.257 -0.068  0.485  0.219  0.484  0.233  0.249  0.323]
# ============================================================
#  EVALUATION: EXPERIMENT-11 Plot groups. Grid search: Yes, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1'].
# ============================================================
#
# Test set:
#   R²   : -0.213
#   RMSE : 5.08 kg
#
# Regular CrossValidation:
#   Mean   : -0.073
#   Std    : 0.483
#   Scores : [-0.903  0.608 -0.084 -0.     0.016]
#
#   ❌ Test R² is negative (-0.213)
#   ❌ CV mean is negative (-0.073)
#
# Grouped CrossValidation:
#   Big Creek_5          :   0.031  ✅
#   Frenchman Caye_6     :   0.016  ✅
#   Frenchman Caye_3     :   0.257  ✅
#   Big Creek_3          :  -0.068  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.485  ✅
#   Big Creek_2          :   0.219  ✅
#   Drowned Caye_5       :   0.484  ✅
#   Gra Gra Lagoon_4     :   0.233  ✅
#   Channel Caye_2       :   0.249  ✅
#   Channel Caye_6       :   0.323  ✅
#
#   Mean : 0.223
#   Std  : 0.177
#
#   ✅ Grouped CV mean above 0.15 (0.223)
#   ✅ Grouped CV std below 0.25 (0.177)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.436 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.379 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height                                        0.3753  ==================
#   EVI                                           0.1912  =========
#   NBR                                           0.1910  =========
#   SWIR1                                         0.1400  =======
#   NIR                                           0.1024  =====
#
# [12/18]
#
#  LIGHTGBM: EXPERIMENT-12 Plot groups. Grid search: Yes, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : 0.0282
# Test RMSE   : 4.55 kg
# Train R² (log scale): 0.4040
# Train R² (orig scale): 0.1660
# Train RMSE  : 16.96 kg
# Num rows    : 3100
# Num Features: 8
#
#  Cross-validation ---
# CV R² mean: 0.0248
# CV R² std : 0.3791
# CV scores : [-0.57   0.612 -0.054 -0.001  0.137]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1838
# Grouped CV R² std : 0.2171
# Grouped CV scores : [-0.115  0.04   0.267 -0.047  0.493 -0.107  0.485  0.238  0.244  0.338]
# ============================================================
#  EVALUATION: EXPERIMENT-12 Plot groups. Grid search: Yes, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : 0.028
#   RMSE : 4.55 kg
#
# Regular CrossValidation:
#   Mean   : 0.025
#   Std    : 0.379
#   Scores : [-0.57   0.612 -0.054 -0.001  0.137]
#
#   ✅ Test R² is positive (0.028)
#   ✅ CV mean is positive (0.025)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.115  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :   0.040  ✅
#   Frenchman Caye_3     :   0.267  ✅
#   Big Creek_3          :  -0.047  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.493  ✅
#   Big Creek_2          :  -0.107  ⚠️  near-zero variance artifact
#   Drowned Caye_5       :   0.485  ✅
#   Gra Gra Lagoon_4     :   0.238  ✅
#   Channel Caye_2       :   0.244  ✅
#   Channel Caye_6       :   0.338  ✅
#
#   Mean : 0.184
#   Std  : 0.217
#
#   ✅ Grouped CV mean above 0.15 (0.184)
#   ✅ Grouped CV std below 0.25 (0.217)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.156 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.138 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ⚠️  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height                                        0.2935  ==============
#   EVI                                           0.2111  ==========
#   NBR                                           0.1424  =======
#   SWIR1                                         0.1293  ======
#   NIR                                           0.0796  ===
#   height_x_EVI                                  0.0723  ===
#   height_x_NDRE1                                0.0364  =
#   height_x_NIR                                  0.0354  =
#
# [13/18]
#
#  LIGHTGBM: EXPERIMENT-13 Plot groups. Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1'].
# Test R²     : -0.1549
# Test RMSE   : 4.96 kg
# Train R² (log scale): 0.4643
# Train R² (orig scale): 0.1864
# Train RMSE  : 16.75 kg
# Num rows    : 3100
# Num Features: 8
#
#  Cross-validation ---
# CV R² mean: -0.2072
# CV R² std : 0.5021
# CV scores : [-1.041  0.471  0.055 -0.136 -0.386]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2754
# Grouped CV R² std : 0.1692
# Grouped CV scores : [ 0.066  0.151  0.374 -0.032  0.488  0.418  0.504  0.242  0.319  0.225]
# ============================================================
#  EVALUATION: EXPERIMENT-13 Plot groups. Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1'].
# ============================================================
#
# Test set:
#   R²   : -0.155
#   RMSE : 4.96 kg
#
# Regular CrossValidation:
#   Mean   : -0.207
#   Std    : 0.502
#   Scores : [-1.041  0.471  0.055 -0.136 -0.386]
#
#   ❌ Test R² is negative (-0.155)
#   ❌ CV mean is negative (-0.207)
#
# Grouped CrossValidation:
#   Big Creek_5          :   0.066  ✅
#   Frenchman Caye_6     :   0.151  ✅
#   Frenchman Caye_3     :   0.374  ✅
#   Big Creek_3          :  -0.032  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.488  ✅
#   Big Creek_2          :   0.418  ✅
#   Drowned Caye_5       :   0.504  ✅
#   Gra Gra Lagoon_4     :   0.242  ✅
#   Channel Caye_2       :   0.319  ✅
#   Channel Caye_6       :   0.225  ✅
#
#   Mean : 0.275
#   Std  : 0.169
#
#   ✅ Grouped CV mean above 0.15 (0.275)
#   ✅ Grouped CV std below 0.25 (0.169)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.430 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.341 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height                                        0.2504  ============
#   EVI                                           0.1941  =========
#   SWIR1                                         0.1366  ======
#   NBR                                           0.1283  ======
#   NIR                                           0.0959  ====
#   species_Avicennia germinans                   0.0713  ===
#   species_Rhizophora mangle                     0.0701  ===
#   species_Laguncularia racemosa                 0.0533  ==
#
# [14/18]
#
#  LIGHTGBM: EXPERIMENT-14 Plot groups. Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : -0.1786
# Test RMSE   : 5.01 kg
# Train R² (log scale): 0.4643
# Train R² (orig scale): 0.1862
# Train RMSE  : 16.75 kg
# Num rows    : 3100
# Num Features: 11
#
#  Cross-validation ---
# CV R² mean: -0.1571
# CV R² std : 0.5106
# CV scores : [-1.076  0.445  0.155 -0.165 -0.145]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2758
# Grouped CV R² std : 0.1918
# Grouped CV scores : [-0.076  0.229  0.344 -0.061  0.51   0.393  0.505  0.3    0.32   0.295]
# ============================================================
#  EVALUATION: EXPERIMENT-14 Plot groups. Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : -0.179
#   RMSE : 5.01 kg
#
# Regular CrossValidation:
#   Mean   : -0.157
#   Std    : 0.511
#   Scores : [-1.076  0.445  0.155 -0.165 -0.145]
#
#   ❌ Test R² is negative (-0.179)
#   ❌ CV mean is negative (-0.157)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.076  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :   0.229  ✅
#   Frenchman Caye_3     :   0.344  ✅
#   Big Creek_3          :  -0.061  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.510  ✅
#   Big Creek_2          :   0.393  ✅
#   Drowned Caye_5       :   0.505  ✅
#   Gra Gra Lagoon_4     :   0.300  ✅
#   Channel Caye_2       :   0.320  ✅
#   Channel Caye_6       :   0.295  ✅
#
#   Mean : 0.276
#   Std  : 0.192
#
#   ✅ Grouped CV mean above 0.15 (0.276)
#   ✅ Grouped CV std below 0.25 (0.192)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.454 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.365 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height                                        0.2024  ==========
#   EVI                                           0.1448  =======
#   NBR                                           0.1124  =====
#   SWIR1                                         0.1094  =====
#   NIR                                           0.0961  ====
#   species_Avicennia germinans                   0.0686  ===
#   species_Rhizophora mangle                     0.0684  ===
#   height_x_EVI                                  0.0676  ===
#   species_Laguncularia racemosa                 0.0643  ===
#   height_x_NDRE1                                0.0352  =
#
# [15/18]
#
#  LIGHTGBM: EXPERIMENT-15 Plot groups. Grid search: Yes, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2'].
# Test R²     : -0.3743
# Test RMSE   : 5.41 kg
# Train R² (log scale): 0.4040
# Train R² (orig scale): 0.1658
# Train RMSE  : 16.96 kg
# Num rows    : 3100
# Num Features: 7
#
#  Cross-validation ---
# CV R² mean: -0.0482
# CV R² std : 0.4126
# CV scores : [-0.692  0.601  0.018 -0.021 -0.147]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2108
# Grouped CV R² std : 0.2014
# Grouped CV scores : [ 0.028 -0.131  0.257 -0.052  0.483  0.224  0.526  0.222  0.246  0.306]
# ============================================================
#  EVALUATION: EXPERIMENT-15 Plot groups. Grid search: Yes, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2'].
# ============================================================
#
# Test set:
#   R²   : -0.374
#   RMSE : 5.41 kg
#
# Regular CrossValidation:
#   Mean   : -0.048
#   Std    : 0.413
#   Scores : [-0.692  0.601  0.018 -0.021 -0.147]
#
#   ❌ Test R² is negative (-0.374)
#   ❌ CV mean is negative (-0.048)
#
# Grouped CrossValidation:
#   Big Creek_5          :   0.028  ✅
#   Frenchman Caye_6     :  -0.131  ⚠️  near-zero variance artifact
#   Frenchman Caye_3     :   0.257  ✅
#   Big Creek_3          :  -0.052  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.483  ✅
#   Big Creek_2          :   0.224  ✅
#   Drowned Caye_5       :   0.526  ✅
#   Gra Gra Lagoon_4     :   0.222  ✅
#   Channel Caye_2       :   0.246  ✅
#   Channel Caye_6       :   0.306  ✅
#
#   Mean : 0.211
#   Std  : 0.201
#
#   ✅ Grouped CV mean above 0.15 (0.211)
#   ✅ Grouped CV std below 0.25 (0.201)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.585 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.540 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height                                        0.2985  ==============
#   NBR                                           0.1801  =========
#   EVI                                           0.1473  =======
#   RE1                                           0.1213  ======
#   SWIR1                                         0.1171  =====
#   NIR                                           0.1076  =====
#   RE2                                           0.0281  =
#
# [16/18]
#
#  LIGHTGBM: EXPERIMENT-16 Plot groups. Grid search: Yes, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : -0.0171
# Test RMSE   : 4.65 kg
# Train R² (log scale): 0.4040
# Train R² (orig scale): 0.1660
# Train RMSE  : 16.96 kg
# Num rows    : 3100
# Num Features: 10
#
#  Cross-validation ---
# CV R² mean: 0.0231
# CV R² std : 0.3783
# CV scores : [-0.579  0.611  0.028 -0.032  0.086]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1895
# Grouped CV R² std : 0.2061
# Grouped CV scores : [-0.106  0.051  0.256 -0.035  0.483 -0.059  0.486  0.235  0.247  0.337]
# ============================================================
#  EVALUATION: EXPERIMENT-16 Plot groups. Grid search: Yes, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : -0.017
#   RMSE : 4.65 kg
#
# Regular CrossValidation:
#   Mean   : 0.023
#   Std    : 0.378
#   Scores : [-0.579  0.611  0.028 -0.032  0.086]
#
#   ❌ Test R² is negative (-0.017)
#   ✅ CV mean is positive (0.023)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.106  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :   0.051  ✅
#   Frenchman Caye_3     :   0.256  ✅
#   Big Creek_3          :  -0.035  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.483  ✅
#   Big Creek_2          :  -0.059  ⚠️  near-zero variance artifact
#   Drowned Caye_5       :   0.486  ✅
#   Gra Gra Lagoon_4     :   0.235  ✅
#   Channel Caye_2       :   0.247  ✅
#   Channel Caye_6       :   0.337  ✅
#
#   Mean : 0.189
#   Std  : 0.206
#
#   ✅ Grouped CV mean above 0.15 (0.189)
#   ✅ Grouped CV std below 0.25 (0.206)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.207 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.183 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height                                        0.2514  ============
#   EVI                                           0.1658  ========
#   NBR                                           0.1453  =======
#   SWIR1                                         0.1104  =====
#   RE1                                           0.0981  ====
#   NIR                                           0.0891  ====
#   height_x_EVI                                  0.0504  ==
#   height_x_NIR                                  0.0334  =
#   RE2                                           0.0329  =
#   height_x_NDRE1                                0.0233  =
#
# [17/18]
#
#  LIGHTGBM: EXPERIMENT-17 Plot groups. Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2'].
# Test R²     : 0.0921
# Test RMSE   : 4.40 kg
# Train R² (log scale): 0.4644
# Train R² (orig scale): 0.1865
# Train RMSE  : 16.75 kg
# Num rows    : 3100
# Num Features: 10
#
#  Cross-validation ---
# CV R² mean: -0.2264
# CV R² std : 0.4968
# CV scores : [-1.053  0.442  0.017 -0.126 -0.412]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2587
# Grouped CV R² std : 0.1798
# Grouped CV scores : [ 0.052  0.07   0.369 -0.032  0.486  0.258  0.565  0.25   0.311  0.258]
# ============================================================
#  EVALUATION: EXPERIMENT-17 Plot groups. Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2'].
# ============================================================
#
# Test set:
#   R²   : 0.092
#   RMSE : 4.40 kg
#
# Regular CrossValidation:
#   Mean   : -0.226
#   Std    : 0.497
#   Scores : [-1.053  0.442  0.017 -0.126 -0.412]
#
#   ✅ Test R² is positive (0.092)
#   ❌ CV mean is negative (-0.226)
#
# Grouped CrossValidation:
#   Big Creek_5          :   0.052  ✅
#   Frenchman Caye_6     :   0.070  ✅
#   Frenchman Caye_3     :   0.369  ✅
#   Big Creek_3          :  -0.032  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.486  ✅
#   Big Creek_2          :   0.258  ✅
#   Drowned Caye_5       :   0.565  ✅
#   Gra Gra Lagoon_4     :   0.250  ✅
#   Channel Caye_2       :   0.311  ✅
#   Channel Caye_6       :   0.258  ✅
#
#   Mean : 0.259
#   Std  : 0.180
#
#   ✅ Grouped CV mean above 0.15 (0.259)
#   ✅ Grouped CV std below 0.25 (0.180)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.167 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: 0.094)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height                                        0.2104  ==========
#   EVI                                           0.1354  ======
#   NBR                                           0.1184  =====
#   RE1                                           0.1005  =====
#   SWIR1                                         0.0958  ====
#   species_Laguncularia racemosa                 0.0813  ====
#   species_Avicennia germinans                   0.0747  ===
#   species_Rhizophora mangle                     0.0711  ===
#   NIR                                           0.0698  ===
#   RE2                                           0.0424  ==
#
# [18/18]
#
#  LIGHTGBM: EXPERIMENT-18 Plot groups. Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : -0.1025
# Test RMSE   : 4.85 kg
# Train R² (log scale): 0.4650
# Train R² (orig scale): 0.1869
# Train RMSE  : 16.74 kg
# Num rows    : 3100
# Num Features: 13
#
#  Cross-validation ---
# CV R² mean: -0.1887
# CV R² std : 0.5375
# CV scores : [-1.128  0.47   0.154 -0.154 -0.285]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2634
# Grouped CV R² std : 0.1942
# Grouped CV scores : [-0.1    0.223  0.353 -0.037  0.536  0.266  0.524  0.27   0.316  0.283]
# ============================================================
#  EVALUATION: EXPERIMENT-18 Plot groups. Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : -0.103
#   RMSE : 4.85 kg
#
# Regular CrossValidation:
#   Mean   : -0.189
#   Std    : 0.537
#   Scores : [-1.128  0.47   0.154 -0.154 -0.285]
#
#   ❌ Test R² is negative (-0.103)
#   ❌ CV mean is negative (-0.189)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.100  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :   0.223  ✅
#   Frenchman Caye_3     :   0.353  ✅
#   Big Creek_3          :  -0.037  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.536  ✅
#   Big Creek_2          :   0.266  ✅
#   Drowned Caye_5       :   0.524  ✅
#   Gra Gra Lagoon_4     :   0.270  ✅
#   Channel Caye_2       :   0.316  ✅
#   Channel Caye_6       :   0.283  ✅
#
#   Mean : 0.263
#   Std  : 0.194
#
#   ✅ Grouped CV mean above 0.15 (0.263)
#   ✅ Grouped CV std below 0.25 (0.194)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.366 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.289 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height                                        0.1896  =========
#   EVI                                           0.1188  =====
#   SWIR1                                         0.1046  =====
#   NBR                                           0.0822  ====
#   species_Avicennia germinans                   0.0812  ====
#   RE1                                           0.0790  ===
#   species_Rhizophora mangle                     0.0708  ===
#   NIR                                           0.0676  ===
#   species_Laguncularia racemosa                 0.0656  ===
#   height_x_EVI                                  0.0506  ==
#
# Completed: 18/18 experiments

# %%
tabulate_results(lgbm_belige_no_grid_grps, acceptable_only=True)
# Out:
# Showing 4 acceptable experiments
# <style type="text/css">
# #T_b46a6_row0_col2, #T_b46a6_row0_col3, #T_b46a6_row0_col8, #T_b46a6_row0_col9, #T_b46a6_row1_col10 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b46a6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b46a6_level0_col0" class="col_heading level0 col0" >Experiment</th>
#       <th id="T_b46a6_level0_col1" class="col_heading level0 col1" >Num_features</th>
#       <th id="T_b46a6_level0_col2" class="col_heading level0 col2" >Test R²</th>
#       <th id="T_b46a6_level0_col3" class="col_heading level0 col3" >Test RMSE</th>
#       <th id="T_b46a6_level0_col4" class="col_heading level0 col4" >Train R²</th>
#       <th id="T_b46a6_level0_col5" class="col_heading level0 col5" >Train RMSE</th>
#       <th id="T_b46a6_level0_col6" class="col_heading level0 col6" >CV R² Mean</th>
#       <th id="T_b46a6_level0_col7" class="col_heading level0 col7" >CV R² Std</th>
#       <th id="T_b46a6_level0_col8" class="col_heading level0 col8" >Group CV R² Mean</th>
#       <th id="T_b46a6_level0_col9" class="col_heading level0 col9" >Group CV R² Std</th>
#       <th id="T_b46a6_level0_col10" class="col_heading level0 col10" >CV-Test Gap</th>
#       <th id="T_b46a6_level0_col11" class="col_heading level0 col11" >-ve Folds</th>
#       <th id="T_b46a6_level0_col12" class="col_heading level0 col12" >verdict</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b46a6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b46a6_row0_col0" class="data row0 col0" >EXPERIMENT-2 Plot groups. Grid search: Yes, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].</td>
#       <td id="T_b46a6_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_b46a6_row0_col2" class="data row0 col2" >0.1671</td>
#       <td id="T_b46a6_row0_col3" class="data row0 col3" >4.21</td>
#       <td id="T_b46a6_row0_col4" class="data row0 col4" >0.1494</td>
#       <td id="T_b46a6_row0_col5" class="data row0 col5" >17.13</td>
#       <td id="T_b46a6_row0_col6" class="data row0 col6" >0.1646</td>
#       <td id="T_b46a6_row0_col7" class="data row0 col7" >0.2192</td>
#       <td id="T_b46a6_row0_col8" class="data row0 col8" >0.2619</td>
#       <td id="T_b46a6_row0_col9" class="data row0 col9" >0.2058</td>
#       <td id="T_b46a6_row0_col10" class="data row0 col10" >0.0948</td>
#       <td id="T_b46a6_row0_col11" class="data row0 col11" >2 (Big Creek_5, Big Creek_3)</td>
#       <td id="T_b46a6_row0_col12" class="data row0 col12" >⚠️  MARGINAL — positive metrics but concerns</td>
#     </tr>
#     <tr>
#       <th id="T_b46a6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b46a6_row1_col0" class="data row1 col0" >EXPERIMENT-1 Plot groups. Grid search: Yes, Features: ['height'].</td>
#       <td id="T_b46a6_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_b46a6_row1_col2" class="data row1 col2" >0.1322</td>
#       <td id="T_b46a6_row1_col3" class="data row1 col3" >4.3</td>
#       <td id="T_b46a6_row1_col4" class="data row1 col4" >0.1462</td>
#       <td id="T_b46a6_row1_col5" class="data row1 col5" >17.16</td>
#       <td id="T_b46a6_row1_col6" class="data row1 col6" >0.0796</td>
#       <td id="T_b46a6_row1_col7" class="data row1 col7" >0.289</td>
#       <td id="T_b46a6_row1_col8" class="data row1 col8" >0.2093</td>
#       <td id="T_b46a6_row1_col9" class="data row1 col9" >0.2722</td>
#       <td id="T_b46a6_row1_col10" class="data row1 col10" >0.0771</td>
#       <td id="T_b46a6_row1_col11" class="data row1 col11" >2 (Frenchman Caye_6, Big Creek_3)</td>
#       <td id="T_b46a6_row1_col12" class="data row1 col12" >⚠️  MARGINAL — positive metrics but concerns</td>
#     </tr>
#     <tr>
#       <th id="T_b46a6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b46a6_row2_col0" class="data row2 col0" >EXPERIMENT-4 Plot groups. Grid search: Yes, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].</td>
#       <td id="T_b46a6_row2_col1" class="data row2 col1" >12</td>
#       <td id="T_b46a6_row2_col2" class="data row2 col2" >0.0655</td>
#       <td id="T_b46a6_row2_col3" class="data row2 col3" >4.46</td>
#       <td id="T_b46a6_row2_col4" class="data row2 col4" >0.1659</td>
#       <td id="T_b46a6_row2_col5" class="data row2 col5" >16.96</td>
#       <td id="T_b46a6_row2_col6" class="data row2 col6" >0.0355</td>
#       <td id="T_b46a6_row2_col7" class="data row2 col7" >0.1487</td>
#       <td id="T_b46a6_row2_col8" class="data row2 col8" >0.1977</td>
#       <td id="T_b46a6_row2_col9" class="data row2 col9" >0.2183</td>
#       <td id="T_b46a6_row2_col10" class="data row2 col10" >0.1321</td>
#       <td id="T_b46a6_row2_col11" class="data row2 col11" >2 (Big Creek_5, Big Creek_3)</td>
#       <td id="T_b46a6_row2_col12" class="data row2 col12" >⚠️  MARGINAL — positive metrics but concerns</td>
#     </tr>
#     <tr>
#       <th id="T_b46a6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b46a6_row3_col0" class="data row3 col0" >EXPERIMENT-12 Plot groups. Grid search: Yes, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].</td>
#       <td id="T_b46a6_row3_col1" class="data row3 col1" >8</td>
#       <td id="T_b46a6_row3_col2" class="data row3 col2" >0.0282</td>
#       <td id="T_b46a6_row3_col3" class="data row3 col3" >4.55</td>
#       <td id="T_b46a6_row3_col4" class="data row3 col4" >0.166</td>
#       <td id="T_b46a6_row3_col5" class="data row3 col5" >16.96</td>
#       <td id="T_b46a6_row3_col6" class="data row3 col6" >0.0248</td>
#       <td id="T_b46a6_row3_col7" class="data row3 col7" >0.3791</td>
#       <td id="T_b46a6_row3_col8" class="data row3 col8" >0.1838</td>
#       <td id="T_b46a6_row3_col9" class="data row3 col9" >0.2171</td>
#       <td id="T_b46a6_row3_col10" class="data row3 col10" >0.1556</td>
#       <td id="T_b46a6_row3_col11" class="data row3 col11" >3 (Big Creek_5, Big Creek_3, Big Creek_2)</td>
#       <td id="T_b46a6_row3_col12" class="data row3 col12" >⚠️  MARGINAL — positive metrics but concerns</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### BELIGE DATA. PLOT GROUPS. ALL ROWS. LGBM (Hyper parameter tuning: Yes)

# %%
# %run Model_functions.ipynb

lgbm_belige_grid_grps = {}

run_experiment(X_belige, y_belige,
               is_groups=True, group_info=grp_belige,
               features_list=gen_features_list,
               experiments=lgbm_belige_grid_grps,
               model_type="lgbm", is_grid=True,
               is_stratified=is_stratified_g,
               global_experiment_list=global_experiment_list)
# Out:
# [1/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'subsample': 1.0, 'reg_lambda': 10, 'reg_alpha': 0.1, 'num_leaves': 31, 'n_estimators': 200, 'min_child_samples': 50, 'max_depth': 3, 'learning_rate': 0.01, 'colsample_bytree': 1.0}
#
#  LIGHTGBM: EXPERIMENT-1 Plot groups. Grid search: Yes, Features: ['height'].
# Test R²     : 0.2145
# Test RMSE   : 4.09 kg
# Train R² (log scale): 0.3405
# Train R² (orig scale): 0.0386
# Train RMSE  : 18.21 kg
# Num rows    : 3100
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: 0.2050
# CV R² std : 0.1963
# CV scores : [-0.111  0.491  0.157  0.192  0.296]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2831
# Grouped CV R² std : 0.1899
# Grouped CV scores : [ 0.072  0.224  0.229 -0.068  0.394  0.565  0.581  0.251  0.244  0.337]
# ============================================================
#  EVALUATION: EXPERIMENT-1 Plot groups. Grid search: Yes, Features: ['height'].
# ============================================================
#
# Test set:
#   R²   : 0.214
#   RMSE : 4.09 kg
#
# Regular CrossValidation:
#   Mean   : 0.205
#   Std    : 0.196
#   Scores : [-0.111  0.491  0.157  0.192  0.296]
#
#   ✅ Test R² is positive (0.214)
#   ✅ CV mean is positive (0.205)
#
# Grouped CrossValidation:
#   Big Creek_5          :   0.072  ✅
#   Frenchman Caye_6     :   0.224  ✅
#   Frenchman Caye_3     :   0.229  ✅
#   Big Creek_3          :  -0.068  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.394  ✅
#   Big Creek_2          :   0.565  ✅
#   Drowned Caye_5       :   0.581  ✅
#   Gra Gra Lagoon_4     :   0.251  ✅
#   Channel Caye_2       :   0.244  ✅
#   Channel Caye_6       :   0.337  ✅
#
#   Mean : 0.283
#   Std  : 0.190
#
#   ✅ Grouped CV mean above 0.15 (0.283)
#   ✅ Grouped CV std below 0.25 (0.190)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.069 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.176)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ⚠️  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height                                        1.0000  ==================================================
#
# [2/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'subsample': 1.0, 'reg_lambda': 10, 'reg_alpha': 1.0, 'num_leaves': 63, 'n_estimators': 200, 'min_child_samples': 10, 'max_depth': 3, 'learning_rate': 0.01, 'colsample_bytree': 0.5}
#
#  LIGHTGBM: EXPERIMENT-2 Plot groups. Grid search: Yes, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : 0.2468
# Test RMSE   : 4.01 kg
# Train R² (log scale): 0.3637
# Train R² (orig scale): 0.0505
# Train RMSE  : 18.09 kg
# Num rows    : 3100
# Num Features: 4
#
#  Cross-validation ---
# CV R² mean: 0.2355
# CV R² std : 0.2177
# CV scores : [-0.057  0.614  0.153  0.216  0.252]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2755
# Grouped CV R² std : 0.2024
# Grouped CV scores : [-0.038  0.212  0.242 -0.05   0.394  0.57   0.583  0.257  0.247  0.337]
# ============================================================
#  EVALUATION: EXPERIMENT-2 Plot groups. Grid search: Yes, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : 0.247
#   RMSE : 4.01 kg
#
# Regular CrossValidation:
#   Mean   : 0.236
#   Std    : 0.218
#   Scores : [-0.057  0.614  0.153  0.216  0.252]
#
#   ✅ Test R² is positive (0.247)
#   ✅ CV mean is positive (0.236)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.038  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :   0.212  ✅
#   Frenchman Caye_3     :   0.242  ✅
#   Big Creek_3          :  -0.050  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.394  ✅
#   Big Creek_2          :   0.570  ✅
#   Drowned Caye_5       :   0.583  ✅
#   Gra Gra Lagoon_4     :   0.257  ✅
#   Channel Caye_2       :   0.247  ✅
#   Channel Caye_6       :   0.337  ✅
#
#   Mean : 0.276
#   Std  : 0.202
#
#   ✅ Grouped CV mean above 0.15 (0.276)
#   ✅ Grouped CV std below 0.25 (0.202)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ✅ Grouped CV and test R² agree (gap: 0.029)
#   ✅ Train/test R² gap acceptable (gap: -0.196)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ✅ ACCEPTABLE
#
# Top 10 feature importances:
#   height                                        0.4630  =======================
#   height_x_NIR                                  0.2539  ============
#   height_x_EVI                                  0.1896  =========
#   height_x_NDRE1                                0.0936  ====
#
# [3/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'subsample': 0.6, 'reg_lambda': 1, 'reg_alpha': 0, 'num_leaves': 31, 'n_estimators': 500, 'min_child_samples': 10, 'max_depth': 3, 'learning_rate': 0.01, 'colsample_bytree': 0.5}
#
#  LIGHTGBM: EXPERIMENT-3 Plot groups. Grid search: Yes, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2'].
# Test R²     : 0.2485
# Test RMSE   : 4.00 kg
# Train R² (log scale): 0.4003
# Train R² (orig scale): 0.1278
# Train RMSE  : 17.34 kg
# Num rows    : 3100
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: -0.1214
# CV R² std : 0.4639
# CV scores : [-0.035  0.579  0.003 -0.305 -0.849]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.0527
# Grouped CV R² std : 0.8487
# Grouped CV scores : [-0.21  -2.494  0.234 -0.168  0.353  0.56   0.548  0.276  0.181  0.193]
# ============================================================
#  EVALUATION: EXPERIMENT-3 Plot groups. Grid search: Yes, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2'].
# ============================================================
#
# Test set:
#   R²   : 0.248
#   RMSE : 4.00 kg
#
# Regular CrossValidation:
#   Mean   : -0.121
#   Std    : 0.464
#   Scores : [-0.035  0.579  0.003 -0.305 -0.849]
#
#   ✅ Test R² is positive (0.248)
#   ❌ CV mean is negative (-0.121)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.210  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :  -2.494  ⚠️  near-zero variance artifact
#   Frenchman Caye_3     :   0.234  ✅
#   Big Creek_3          :  -0.168  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.353  ✅
#   Big Creek_2          :   0.560  ✅
#   Drowned Caye_5       :   0.548  ✅
#   Gra Gra Lagoon_4     :   0.276  ✅
#   Channel Caye_2       :   0.181  ✅
#   Channel Caye_6       :   0.193  ✅
#
#   Mean : -0.053
#   Std  : 0.849
#
#   ❌ Grouped CV mean below 0.15 (-0.053)
#   ⚠️  Grouped CV std above 0.25 (0.849) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.301 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.121)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   Blue                                          0.1845  =========
#   RE1                                           0.1764  ========
#   Green                                         0.1374  ======
#   SWIR1                                         0.1035  =====
#   RE2                                           0.1003  =====
#   Red                                           0.0929  ====
#   NIR                                           0.0776  ===
#   SWIR2                                         0.0735  ===
#   RE3                                           0.0539  ==
#
# [4/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'subsample': 1.0, 'reg_lambda': 10, 'reg_alpha': 1.0, 'num_leaves': 63, 'n_estimators': 200, 'min_child_samples': 10, 'max_depth': 3, 'learning_rate': 0.01, 'colsample_bytree': 0.5}
#
#  LIGHTGBM: EXPERIMENT-4 Plot groups. Grid search: Yes, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : 0.2250
# Test RMSE   : 4.06 kg
# Train R² (log scale): 0.3712
# Train R² (orig scale): 0.0623
# Train RMSE  : 17.98 kg
# Num rows    : 3100
# Num Features: 12
#
#  Cross-validation ---
# CV R² mean: 0.1527
# CV R² std : 0.2427
# CV scores : [-0.077  0.616  0.146  0.013  0.065]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1950
# Grouped CV R² std : 0.2507
# Grouped CV scores : [-0.105 -0.31   0.239 -0.005  0.415  0.312  0.593  0.259  0.234  0.317]
# ============================================================
#  EVALUATION: EXPERIMENT-4 Plot groups. Grid search: Yes, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : 0.225
#   RMSE : 4.06 kg
#
# Regular CrossValidation:
#   Mean   : 0.153
#   Std    : 0.243
#   Scores : [-0.077  0.616  0.146  0.013  0.065]
#
#   ✅ Test R² is positive (0.225)
#   ✅ CV mean is positive (0.153)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.105  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :  -0.310  ⚠️  near-zero variance artifact
#   Frenchman Caye_3     :   0.239  ✅
#   Big Creek_3          :  -0.005  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.415  ✅
#   Big Creek_2          :   0.312  ✅
#   Drowned Caye_5       :   0.593  ✅
#   Gra Gra Lagoon_4     :   0.259  ✅
#   Channel Caye_2       :   0.234  ✅
#   Channel Caye_6       :   0.317  ✅
#
#   Mean : 0.195
#   Std  : 0.251
#
#   ✅ Grouped CV mean above 0.15 (0.195)
#   ⚠️  Grouped CV std above 0.25 (0.251) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ✅ Grouped CV and test R² agree (gap: 0.030)
#   ✅ Train/test R² gap acceptable (gap: -0.163)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ⚠️  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height_x_EVI                                  0.1872  =========
#   height_x_NDRE1                                0.1194  =====
#   Green                                         0.0998  ====
#   RE3                                           0.0981  ====
#   RE2                                           0.0924  ====
#   SWIR1                                         0.0834  ====
#   height_x_NIR                                  0.0769  ===
#   Red                                           0.0605  ===
#   NIR                                           0.0548  ==
#   Blue                                          0.0466  ==
#
# [5/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'subsample': 0.8, 'reg_lambda': 10, 'reg_alpha': 1.0, 'num_leaves': 31, 'n_estimators': 100, 'min_child_samples': 50, 'max_depth': 5, 'learning_rate': 0.01, 'colsample_bytree': 0.5}
#
#  LIGHTGBM: EXPERIMENT-5 Plot groups. Grid search: Yes, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# Test R²     : 0.2405
# Test RMSE   : 4.02 kg
# Train R² (log scale): 0.2966
# Train R² (orig scale): 0.0047
# Train RMSE  : 18.53 kg
# Num rows    : 3100
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: 0.0034
# CV R² std : 0.3011
# CV scores : [-0.05   0.478  0.097 -0.049 -0.459]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.0003
# Grouped CV R² std : 0.3681
# Grouped CV scores : [-0.026 -1.012 -0.12  -0.016  0.17   0.42   0.014  0.153  0.198  0.217]
# ============================================================
#  EVALUATION: EXPERIMENT-5 Plot groups. Grid search: Yes, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# ============================================================
#
# Test set:
#   R²   : 0.241
#   RMSE : 4.02 kg
#
# Regular CrossValidation:
#   Mean   : 0.003
#   Std    : 0.301
#   Scores : [-0.05   0.478  0.097 -0.049 -0.459]
#
#   ✅ Test R² is positive (0.241)
#   ✅ CV mean is positive (0.003)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.026  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :  -1.012  ⚠️  near-zero variance artifact
#   Frenchman Caye_3     :  -0.120  ⚠️  near-zero variance artifact
#   Big Creek_3          :  -0.016  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.170  ✅
#   Big Creek_2          :   0.420  ✅
#   Drowned Caye_5       :   0.014  ✅
#   Gra Gra Lagoon_4     :   0.153  ✅
#   Channel Caye_2       :   0.198  ✅
#   Channel Caye_6       :   0.217  ✅
#
#   Mean : -0.000
#   Std  : 0.368
#
#   ❌ Grouped CV mean below 0.15 (-0.000)
#   ⚠️  Grouped CV std above 0.25 (0.368) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.241 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.236)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ⚠️  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   NDVI                                          0.2525  ============
#   NDRE1                                         0.1965  =========
#   NBR                                           0.1567  =======
#   EVI                                           0.1318  ======
#   NDRE2                                         0.1045  =====
#   MNDWI                                         0.0709  ===
#   NDRE3                                         0.0535  ==
#   CIrededge                                     0.0336  =
#   CLOUD_COVERAGE                                0.0000
#
# [6/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'subsample': 1.0, 'reg_lambda': 10, 'reg_alpha': 0, 'num_leaves': 31, 'n_estimators': 100, 'min_child_samples': 50, 'max_depth': 3, 'learning_rate': 0.01, 'colsample_bytree': 0.7}
#
#  LIGHTGBM: EXPERIMENT-6 Plot groups. Grid search: Yes, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : 0.2253
# Test RMSE   : 4.06 kg
# Train R² (log scale): 0.2952
# Train R² (orig scale): 0.0053
# Train RMSE  : 18.52 kg
# Num rows    : 3100
# Num Features: 12
#
#  Cross-validation ---
# CV R² mean: 0.1209
# CV R² std : 0.2579
# CV scores : [-0.062  0.615  0.11  -0.099  0.042]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1346
# Grouped CV R² std : 0.2989
# Grouped CV scores : [-0.038 -0.625  0.173 -0.004  0.233  0.517  0.416  0.195  0.184  0.295]
# ============================================================
#  EVALUATION: EXPERIMENT-6 Plot groups. Grid search: Yes, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : 0.225
#   RMSE : 4.06 kg
#
# Regular CrossValidation:
#   Mean   : 0.121
#   Std    : 0.258
#   Scores : [-0.062  0.615  0.11  -0.099  0.042]
#
#   ✅ Test R² is positive (0.225)
#   ✅ CV mean is positive (0.121)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.038  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :  -0.625  ⚠️  near-zero variance artifact
#   Frenchman Caye_3     :   0.173  ✅
#   Big Creek_3          :  -0.004  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.233  ✅
#   Big Creek_2          :   0.517  ✅
#   Drowned Caye_5       :   0.416  ✅
#   Gra Gra Lagoon_4     :   0.195  ✅
#   Channel Caye_2       :   0.184  ✅
#   Channel Caye_6       :   0.295  ✅
#
#   Mean : 0.135
#   Std  : 0.299
#
#   ❌ Grouped CV mean below 0.15 (0.135)
#   ⚠️  Grouped CV std above 0.25 (0.299) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.091 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.220)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ⚠️  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height_x_EVI                                  0.3102  ===============
#   height_x_NDRE1                                0.1693  ========
#   NDVI                                          0.1533  =======
#   MNDWI                                         0.0963  ====
#   height_x_NIR                                  0.0838  ====
#   NDRE2                                         0.0642  ===
#   NDRE1                                         0.0339  =
#   NBR                                           0.0321  =
#   EVI                                           0.0267  =
#   NDRE3                                         0.0196
#
# [7/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'subsample': 1.0, 'reg_lambda': 5, 'reg_alpha': 1.0, 'num_leaves': 31, 'n_estimators': 200, 'min_child_samples': 10, 'max_depth': 5, 'learning_rate': 0.01, 'colsample_bytree': 0.5}
#
#  LIGHTGBM: EXPERIMENT-7 Plot groups. Grid search: Yes, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# Test R²     : 0.2124
# Test RMSE   : 4.10 kg
# Train R² (log scale): 0.3876
# Train R² (orig scale): 0.0903
# Train RMSE  : 17.71 kg
# Num rows    : 3100
# Num Features: 18
#
#  Cross-validation ---
# CV R² mean: -0.0856
# CV R² std : 0.4255
# CV scores : [-0.061  0.49   0.123 -0.171 -0.808]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.1084
# Grouped CV R² std : 1.0762
# Grouped CV scores : [-9.90e-02 -3.29e+00  2.06e-01  2.00e-03  4.40e-01  5.24e-01  4.37e-01
#   2.34e-01  2.43e-01  2.19e-01]
# ============================================================
#  EVALUATION: EXPERIMENT-7 Plot groups. Grid search: Yes, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# ============================================================
#
# Test set:
#   R²   : 0.212
#   RMSE : 4.10 kg
#
# Regular CrossValidation:
#   Mean   : -0.086
#   Std    : 0.425
#   Scores : [-0.061  0.49   0.123 -0.171 -0.808]
#
#   ✅ Test R² is positive (0.212)
#   ❌ CV mean is negative (-0.086)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.099  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :  -3.290  ⚠️  near-zero variance artifact
#   Frenchman Caye_3     :   0.206  ✅
#   Big Creek_3          :   0.002  ✅
#   Frenchman Caye_1     :   0.440  ✅
#   Big Creek_2          :   0.524  ✅
#   Drowned Caye_5       :   0.437  ✅
#   Gra Gra Lagoon_4     :   0.234  ✅
#   Channel Caye_2       :   0.243  ✅
#   Channel Caye_6       :   0.219  ✅
#
#   Mean : -0.108
#   Std  : 1.076
#
#   ❌ Grouped CV mean below 0.15 (-0.108)
#   ⚠️  Grouped CV std above 0.25 (1.076) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.321 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.122)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   Red                                           0.1156  =====
#   RE2                                           0.1126  =====
#   Blue                                          0.1045  =====
#   NBR                                           0.0787  ===
#   RE3                                           0.0714  ===
#   EVI                                           0.0684  ===
#   Green                                         0.0658  ===
#   NIR                                           0.0641  ===
#   RE1                                           0.0606  ===
#   SWIR2                                         0.0503  ==
#
# [8/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'subsample': 0.6, 'reg_lambda': 5, 'reg_alpha': 0, 'num_leaves': 31, 'n_estimators': 100, 'min_child_samples': 20, 'max_depth': 5, 'learning_rate': 0.01, 'colsample_bytree': 0.7}
#
#  LIGHTGBM: EXPERIMENT-8 Plot groups. Grid search: Yes, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : 0.1239
# Test RMSE   : 4.32 kg
# Train R² (log scale): 0.3292
# Train R² (orig scale): 0.0279
# Train RMSE  : 18.31 kg
# Num rows    : 3100
# Num Features: 21
#
#  Cross-validation ---
# CV R² mean: 0.1212
# CV R² std : 0.2618
# CV scores : [-0.061  0.632  0.095 -0.061  0.001]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.0944
# Grouped CV R² std : 0.8166
# Grouped CV scores : [-0.118 -2.509  0.174  0.006  0.302  0.147  0.403  0.216  0.184  0.251]
# ============================================================
#  EVALUATION: EXPERIMENT-8 Plot groups. Grid search: Yes, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : 0.124
#   RMSE : 4.32 kg
#
# Regular CrossValidation:
#   Mean   : 0.121
#   Std    : 0.262
#   Scores : [-0.061  0.632  0.095 -0.061  0.001]
#
#   ✅ Test R² is positive (0.124)
#   ✅ CV mean is positive (0.121)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.118  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :  -2.509  ⚠️  near-zero variance artifact
#   Frenchman Caye_3     :   0.174  ✅
#   Big Creek_3          :   0.006  ✅
#   Frenchman Caye_1     :   0.302  ✅
#   Big Creek_2          :   0.147  ✅
#   Drowned Caye_5       :   0.403  ✅
#   Gra Gra Lagoon_4     :   0.216  ✅
#   Channel Caye_2       :   0.184  ✅
#   Channel Caye_6       :   0.251  ✅
#
#   Mean : -0.094
#   Std  : 0.817
#
#   ❌ Grouped CV mean below 0.15 (-0.094)
#   ⚠️  Grouped CV std above 0.25 (0.817) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.218 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.096)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ⚠️  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height_x_EVI                                  0.1392  ======
#   RE3                                           0.1193  =====
#   Green                                         0.1183  =====
#   RE2                                           0.1064  =====
#   height_x_NDRE1                                0.0855  ====
#   SWIR1                                         0.0656  ===
#   Red                                           0.0616  ===
#   height_x_NIR                                  0.0596  ==
#   RE1                                           0.0507  ==
#   EVI                                           0.0328  =
#
# [9/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'subsample': 1.0, 'reg_lambda': 10, 'reg_alpha': 0.1, 'num_leaves': 31, 'n_estimators': 200, 'min_child_samples': 50, 'max_depth': 3, 'learning_rate': 0.01, 'colsample_bytree': 1.0}
#
#  LIGHTGBM: EXPERIMENT-9 Plot groups. Grid search: Yes, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# Test R²     : 0.2124
# Test RMSE   : 4.10 kg
# Train R² (log scale): 0.3600
# Train R² (orig scale): 0.0460
# Train RMSE  : 18.14 kg
# Num rows    : 3100
# Num Features: 19
#
#  Cross-validation ---
# CV R² mean: 0.1198
# CV R² std : 0.2111
# CV scores : [-0.11   0.501  0.142 -0.034  0.1  ]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2606
# Grouped CV R² std : 0.1761
# Grouped CV scores : [-0.006  0.183  0.245 -0.012  0.408  0.431  0.579  0.232  0.224  0.324]
# ============================================================
#  EVALUATION: EXPERIMENT-9 Plot groups. Grid search: Yes, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# ============================================================
#
# Test set:
#   R²   : 0.212
#   RMSE : 4.10 kg
#
# Regular CrossValidation:
#   Mean   : 0.120
#   Std    : 0.211
#   Scores : [-0.11   0.501  0.142 -0.034  0.1  ]
#
#   ✅ Test R² is positive (0.212)
#   ✅ CV mean is positive (0.120)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.006  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :   0.183  ✅
#   Frenchman Caye_3     :   0.245  ✅
#   Big Creek_3          :  -0.012  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.408  ✅
#   Big Creek_2          :   0.431  ✅
#   Drowned Caye_5       :   0.579  ✅
#   Gra Gra Lagoon_4     :   0.232  ✅
#   Channel Caye_2       :   0.224  ✅
#   Channel Caye_6       :   0.324  ✅
#
#   Mean : 0.261
#   Std  : 0.176
#
#   ✅ Grouped CV mean above 0.15 (0.261)
#   ✅ Grouped CV std below 0.25 (0.176)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ✅ Grouped CV and test R² agree (gap: 0.048)
#   ✅ Train/test R² gap acceptable (gap: -0.166)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ✅ ACCEPTABLE
#
# Top 10 feature importances:
#   height                                        0.5424  ===========================
#   RE2                                           0.1104  =====
#   Green                                         0.0679  ===
#   SWIR1                                         0.0645  ===
#   NDRE1                                         0.0289  =
#   RE3                                           0.0272  =
#   NDVI                                          0.0246  =
#   SWIR2                                         0.0238  =
#   NDRE2                                         0.0229  =
#   EVI                                           0.0212  =
#
# [10/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'subsample': 1.0, 'reg_lambda': 10, 'reg_alpha': 0, 'num_leaves': 31, 'n_estimators': 100, 'min_child_samples': 50, 'max_depth': 3, 'learning_rate': 0.01, 'colsample_bytree': 0.7}
#
#  LIGHTGBM: EXPERIMENT-10 Plot groups. Grid search: Yes, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : 0.2170
# Test RMSE   : 4.08 kg
# Train R² (log scale): 0.2976
# Train R² (orig scale): 0.0055
# Train RMSE  : 18.52 kg
# Num rows    : 3100
# Num Features: 22
#
#  Cross-validation ---
# CV R² mean: 0.1446
# CV R² std : 0.2311
# CV scores : [-0.05   0.591  0.12  -0.008  0.07 ]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1864
# Grouped CV R² std : 0.2035
# Grouped CV scores : [-0.069 -0.122  0.18  -0.032  0.314  0.349  0.581  0.192  0.195  0.275]
# ============================================================
#  EVALUATION: EXPERIMENT-10 Plot groups. Grid search: Yes, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : 0.217
#   RMSE : 4.08 kg
#
# Regular CrossValidation:
#   Mean   : 0.145
#   Std    : 0.231
#   Scores : [-0.05   0.591  0.12  -0.008  0.07 ]
#
#   ✅ Test R² is positive (0.217)
#   ✅ CV mean is positive (0.145)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.069  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :  -0.122  ⚠️  near-zero variance artifact
#   Frenchman Caye_3     :   0.180  ✅
#   Big Creek_3          :  -0.032  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.314  ✅
#   Big Creek_2          :   0.349  ✅
#   Drowned Caye_5       :   0.581  ✅
#   Gra Gra Lagoon_4     :   0.192  ✅
#   Channel Caye_2       :   0.195  ✅
#   Channel Caye_6       :   0.275  ✅
#
#   Mean : 0.186
#   Std  : 0.204
#
#   ✅ Grouped CV mean above 0.15 (0.186)
#   ✅ Grouped CV std below 0.25 (0.204)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ✅ Grouped CV and test R² agree (gap: 0.031)
#   ✅ Train/test R² gap acceptable (gap: -0.212)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ✅ ACCEPTABLE
#
# Top 10 feature importances:
#   height                                        0.4357  =====================
#   height_x_NDRE1                                0.0946  ====
#   height_x_EVI                                  0.0768  ===
#   Green                                         0.0714  ===
#   Blue                                          0.0554  ==
#   RE2                                           0.0464  ==
#   height_x_NIR                                  0.0446  ==
#   RE3                                           0.0304  =
#   SWIR2                                         0.0250  =
#   NBR                                           0.0214  =
#
# [11/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'subsample': 1.0, 'reg_lambda': 10, 'reg_alpha': 0.1, 'num_leaves': 31, 'n_estimators': 200, 'min_child_samples': 50, 'max_depth': 3, 'learning_rate': 0.01, 'colsample_bytree': 1.0}
#
#  LIGHTGBM: EXPERIMENT-11 Plot groups. Grid search: Yes, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1'].
# Test R²     : 0.2376
# Test RMSE   : 4.03 kg
# Train R² (log scale): 0.3614
# Train R² (orig scale): 0.0485
# Train RMSE  : 18.11 kg
# Num rows    : 3100
# Num Features: 5
#
#  Cross-validation ---
# CV R² mean: 0.1446
# CV R² std : 0.2246
# CV scores : [-0.122  0.522  0.124 -0.031  0.231]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2805
# Grouped CV R² std : 0.1811
# Grouped CV scores : [ 0.075  0.213  0.229 -0.014  0.403  0.563  0.575  0.227  0.205  0.329]
# ============================================================
#  EVALUATION: EXPERIMENT-11 Plot groups. Grid search: Yes, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1'].
# ============================================================
#
# Test set:
#   R²   : 0.238
#   RMSE : 4.03 kg
#
# Regular CrossValidation:
#   Mean   : 0.145
#   Std    : 0.225
#   Scores : [-0.122  0.522  0.124 -0.031  0.231]
#
#   ✅ Test R² is positive (0.238)
#   ✅ CV mean is positive (0.145)
#
# Grouped CrossValidation:
#   Big Creek_5          :   0.075  ✅
#   Frenchman Caye_6     :   0.213  ✅
#   Frenchman Caye_3     :   0.229  ✅
#   Big Creek_3          :  -0.014  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.403  ✅
#   Big Creek_2          :   0.563  ✅
#   Drowned Caye_5       :   0.575  ✅
#   Gra Gra Lagoon_4     :   0.227  ✅
#   Channel Caye_2       :   0.205  ✅
#   Channel Caye_6       :   0.329  ✅
#
#   Mean : 0.280
#   Std  : 0.181
#
#   ✅ Grouped CV mean above 0.15 (0.280)
#   ✅ Grouped CV std below 0.25 (0.181)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ✅ Grouped CV and test R² agree (gap: 0.043)
#   ✅ Train/test R² gap acceptable (gap: -0.189)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ✅ ACCEPTABLE
#
# Top 10 feature importances:
#   height                                        0.6156  ==============================
#   EVI                                           0.1737  ========
#   NBR                                           0.1140  =====
#   SWIR1                                         0.0739  ===
#   NIR                                           0.0228  =
#
# [12/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'subsample': 1.0, 'reg_lambda': 10, 'reg_alpha': 0, 'num_leaves': 31, 'n_estimators': 100, 'min_child_samples': 50, 'max_depth': 3, 'learning_rate': 0.01, 'colsample_bytree': 0.7}
#
#  LIGHTGBM: EXPERIMENT-12 Plot groups. Grid search: Yes, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : 0.2071
# Test RMSE   : 4.11 kg
# Train R² (log scale): 0.3006
# Train R² (orig scale): 0.0062
# Train RMSE  : 18.51 kg
# Num rows    : 3100
# Num Features: 8
#
#  Cross-validation ---
# CV R² mean: 0.1677
# CV R² std : 0.2291
# CV scores : [-0.054  0.593  0.108 -0.002  0.193]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2402
# Grouped CV R² std : 0.1971
# Grouped CV scores : [-0.039  0.196  0.164 -0.048  0.302  0.513  0.609  0.208  0.203  0.294]
# ============================================================
#  EVALUATION: EXPERIMENT-12 Plot groups. Grid search: Yes, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : 0.207
#   RMSE : 4.11 kg
#
# Regular CrossValidation:
#   Mean   : 0.168
#   Std    : 0.229
#   Scores : [-0.054  0.593  0.108 -0.002  0.193]
#
#   ✅ Test R² is positive (0.207)
#   ✅ CV mean is positive (0.168)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.039  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :   0.196  ✅
#   Frenchman Caye_3     :   0.164  ✅
#   Big Creek_3          :  -0.048  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.302  ✅
#   Big Creek_2          :   0.513  ✅
#   Drowned Caye_5       :   0.609  ✅
#   Gra Gra Lagoon_4     :   0.208  ✅
#   Channel Caye_2       :   0.203  ✅
#   Channel Caye_6       :   0.294  ✅
#
#   Mean : 0.240
#   Std  : 0.197
#
#   ✅ Grouped CV mean above 0.15 (0.240)
#   ✅ Grouped CV std below 0.25 (0.197)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ✅ Grouped CV and test R² agree (gap: 0.033)
#   ✅ Train/test R² gap acceptable (gap: -0.201)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ✅ ACCEPTABLE
#
# Top 10 feature importances:
#   height                                        0.4881  ========================
#   height_x_EVI                                  0.1054  =====
#   height_x_NDRE1                                0.0901  ====
#   EVI                                           0.0867  ====
#   SWIR1                                         0.0765  ===
#   NIR                                           0.0714  ===
#   NBR                                           0.0578  ==
#   height_x_NIR                                  0.0238  =
#
# [13/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'subsample': 1.0, 'reg_lambda': 1, 'reg_alpha': 1.0, 'num_leaves': 63, 'n_estimators': 100, 'min_child_samples': 50, 'max_depth': -1, 'learning_rate': 0.01, 'colsample_bytree': 0.5}
#
#  LIGHTGBM: EXPERIMENT-13 Plot groups. Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1'].
# Test R²     : 0.2093
# Test RMSE   : 4.10 kg
# Train R² (log scale): 0.3476
# Train R² (orig scale): 0.0139
# Train RMSE  : 18.44 kg
# Num rows    : 3100
# Num Features: 8
#
#  Cross-validation ---
# CV R² mean: 0.1189
# CV R² std : 0.2232
# CV scores : [-0.025  0.539  0.159 -0.04  -0.038]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2670
# Grouped CV R² std : 0.1787
# Grouped CV scores : [ 0.041  0.234  0.242 -0.018  0.3    0.52   0.61   0.227  0.237  0.278]
# ============================================================
#  EVALUATION: EXPERIMENT-13 Plot groups. Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1'].
# ============================================================
#
# Test set:
#   R²   : 0.209
#   RMSE : 4.10 kg
#
# Regular CrossValidation:
#   Mean   : 0.119
#   Std    : 0.223
#   Scores : [-0.025  0.539  0.159 -0.04  -0.038]
#
#   ✅ Test R² is positive (0.209)
#   ✅ CV mean is positive (0.119)
#
# Grouped CrossValidation:
#   Big Creek_5          :   0.041  ✅
#   Frenchman Caye_6     :   0.234  ✅
#   Frenchman Caye_3     :   0.242  ✅
#   Big Creek_3          :  -0.018  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.300  ✅
#   Big Creek_2          :   0.520  ✅
#   Drowned Caye_5       :   0.610  ✅
#   Gra Gra Lagoon_4     :   0.227  ✅
#   Channel Caye_2       :   0.237  ✅
#   Channel Caye_6       :   0.278  ✅
#
#   Mean : 0.267
#   Std  : 0.179
#
#   ✅ Grouped CV mean above 0.15 (0.267)
#   ✅ Grouped CV std below 0.25 (0.179)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.058 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.195)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ⚠️  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height                                        0.3951  ===================
#   SWIR1                                         0.2125  ==========
#   NIR                                           0.1420  =======
#   EVI                                           0.1171  =====
#   NBR                                           0.0728  ===
#   species_Rhizophora mangle                     0.0420  ==
#   species_Avicennia germinans                   0.0166
#   species_Laguncularia racemosa                 0.0018
#
# [14/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'subsample': 1.0, 'reg_lambda': 10, 'reg_alpha': 0, 'num_leaves': 31, 'n_estimators': 100, 'min_child_samples': 50, 'max_depth': 3, 'learning_rate': 0.01, 'colsample_bytree': 0.7}
#
#  LIGHTGBM: EXPERIMENT-14 Plot groups. Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : 0.2085
# Test RMSE   : 4.11 kg
# Train R² (log scale): 0.3044
# Train R² (orig scale): 0.0069
# Train RMSE  : 18.51 kg
# Num rows    : 3100
# Num Features: 11
#
#  Cross-validation ---
# CV R² mean: 0.1488
# CV R² std : 0.2299
# CV scores : [-0.022  0.585  0.143 -0.055  0.093]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2530
# Grouped CV R² std : 0.1888
# Grouped CV scores : [-0.026  0.229  0.166 -0.002  0.292  0.519  0.609  0.206  0.227  0.312]
# ============================================================
#  EVALUATION: EXPERIMENT-14 Plot groups. Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : 0.208
#   RMSE : 4.11 kg
#
# Regular CrossValidation:
#   Mean   : 0.149
#   Std    : 0.230
#   Scores : [-0.022  0.585  0.143 -0.055  0.093]
#
#   ✅ Test R² is positive (0.208)
#   ✅ CV mean is positive (0.149)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.026  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :   0.229  ✅
#   Frenchman Caye_3     :   0.166  ✅
#   Big Creek_3          :  -0.002  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.292  ✅
#   Big Creek_2          :   0.519  ✅
#   Drowned Caye_5       :   0.609  ✅
#   Gra Gra Lagoon_4     :   0.206  ✅
#   Channel Caye_2       :   0.227  ✅
#   Channel Caye_6       :   0.312  ✅
#
#   Mean : 0.253
#   Std  : 0.189
#
#   ✅ Grouped CV mean above 0.15 (0.253)
#   ✅ Grouped CV std below 0.25 (0.189)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ✅ Grouped CV and test R² agree (gap: 0.045)
#   ✅ Train/test R² gap acceptable (gap: -0.202)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ✅ ACCEPTABLE
#
# Top 10 feature importances:
#   height                                        0.4306  =====================
#   height_x_NDRE1                                0.1372  ======
#   height_x_EVI                                  0.0851  ====
#   SWIR1                                         0.0712  ===
#   species_Rhizophora mangle                     0.0660  ===
#   species_Avicennia germinans                   0.0521  ==
#   NIR                                           0.0503  ==
#   height_x_NIR                                  0.0451  ==
#   EVI                                           0.0434  ==
#   NBR                                           0.0191
#
# [15/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'subsample': 1.0, 'reg_lambda': 10, 'reg_alpha': 0.1, 'num_leaves': 31, 'n_estimators': 200, 'min_child_samples': 50, 'max_depth': 3, 'learning_rate': 0.01, 'colsample_bytree': 1.0}
#
#  LIGHTGBM: EXPERIMENT-15 Plot groups. Grid search: Yes, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2'].
# Test R²     : 0.2275
# Test RMSE   : 4.06 kg
# Train R² (log scale): 0.3607
# Train R² (orig scale): 0.0482
# Train RMSE  : 18.12 kg
# Num rows    : 3100
# Num Features: 7
#
#  Cross-validation ---
# CV R² mean: 0.1486
# CV R² std : 0.2263
# CV scores : [-0.122  0.54   0.126 -0.01   0.21 ]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2575
# Grouped CV R² std : 0.1628
# Grouped CV scores : [ 0.076  0.179  0.224 -0.014  0.415  0.38   0.576  0.227  0.189  0.322]
# ============================================================
#  EVALUATION: EXPERIMENT-15 Plot groups. Grid search: Yes, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2'].
# ============================================================
#
# Test set:
#   R²   : 0.228
#   RMSE : 4.06 kg
#
# Regular CrossValidation:
#   Mean   : 0.149
#   Std    : 0.226
#   Scores : [-0.122  0.54   0.126 -0.01   0.21 ]
#
#   ✅ Test R² is positive (0.228)
#   ✅ CV mean is positive (0.149)
#
# Grouped CrossValidation:
#   Big Creek_5          :   0.076  ✅
#   Frenchman Caye_6     :   0.179  ✅
#   Frenchman Caye_3     :   0.224  ✅
#   Big Creek_3          :  -0.014  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.415  ✅
#   Big Creek_2          :   0.380  ✅
#   Drowned Caye_5       :   0.576  ✅
#   Gra Gra Lagoon_4     :   0.227  ✅
#   Channel Caye_2       :   0.189  ✅
#   Channel Caye_6       :   0.322  ✅
#
#   Mean : 0.258
#   Std  : 0.163
#
#   ✅ Grouped CV mean above 0.15 (0.258)
#   ✅ Grouped CV std below 0.25 (0.163)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ✅ Grouped CV and test R² agree (gap: 0.030)
#   ✅ Train/test R² gap acceptable (gap: -0.179)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ✅ ACCEPTABLE
#
# Top 10 feature importances:
#   height                                        0.5746  ============================
#   EVI                                           0.1642  ========
#   NBR                                           0.0963  ====
#   SWIR1                                         0.0773  ===
#   RE1                                           0.0600  ==
#   NIR                                           0.0276  =
#   RE2                                           0.0000
#
# [16/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'subsample': 1.0, 'reg_lambda': 10, 'reg_alpha': 0, 'num_leaves': 31, 'n_estimators': 100, 'min_child_samples': 50, 'max_depth': 3, 'learning_rate': 0.01, 'colsample_bytree': 0.7}
#
#  LIGHTGBM: EXPERIMENT-16 Plot groups. Grid search: Yes, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : 0.2058
# Test RMSE   : 4.11 kg
# Train R² (log scale): 0.3013
# Train R² (orig scale): 0.0065
# Train RMSE  : 18.51 kg
# Num rows    : 3100
# Num Features: 10
#
#  Cross-validation ---
# CV R² mean: 0.1604
# CV R² std : 0.2284
# CV scores : [-0.049  0.595  0.106  0.004  0.146]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2237
# Grouped CV R² std : 0.1776
# Grouped CV scores : [-0.032  0.199  0.164 -0.048  0.306  0.329  0.609  0.207  0.208  0.294]
# ============================================================
#  EVALUATION: EXPERIMENT-16 Plot groups. Grid search: Yes, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : 0.206
#   RMSE : 4.11 kg
#
# Regular CrossValidation:
#   Mean   : 0.160
#   Std    : 0.228
#   Scores : [-0.049  0.595  0.106  0.004  0.146]
#
#   ✅ Test R² is positive (0.206)
#   ✅ CV mean is positive (0.160)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.032  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :   0.199  ✅
#   Frenchman Caye_3     :   0.164  ✅
#   Big Creek_3          :  -0.048  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.306  ✅
#   Big Creek_2          :   0.329  ✅
#   Drowned Caye_5       :   0.609  ✅
#   Gra Gra Lagoon_4     :   0.207  ✅
#   Channel Caye_2       :   0.208  ✅
#   Channel Caye_6       :   0.294  ✅
#
#   Mean : 0.224
#   Std  : 0.178
#
#   ✅ Grouped CV mean above 0.15 (0.224)
#   ✅ Grouped CV std below 0.25 (0.178)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ✅ Grouped CV and test R² agree (gap: 0.018)
#   ✅ Train/test R² gap acceptable (gap: -0.199)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ✅ ACCEPTABLE
#
# Top 10 feature importances:
#   height                                        0.4416  ======================
#   EVI                                           0.0914  ====
#   height_x_EVI                                  0.0914  ====
#   height_x_NDRE1                                0.0880  ====
#   SWIR1                                         0.0829  ====
#   NIR                                           0.0660  ===
#   NBR                                           0.0575  ==
#   height_x_NIR                                  0.0355  =
#   RE1                                           0.0288  =
#   RE2                                           0.0169
#
# [17/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'subsample': 1.0, 'reg_lambda': 10, 'reg_alpha': 0, 'num_leaves': 31, 'n_estimators': 100, 'min_child_samples': 50, 'max_depth': 3, 'learning_rate': 0.01, 'colsample_bytree': 0.7}
#
#  LIGHTGBM: EXPERIMENT-17 Plot groups. Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2'].
# Test R²     : 0.2178
# Test RMSE   : 4.08 kg
# Train R² (log scale): 0.3035
# Train R² (orig scale): 0.0058
# Train RMSE  : 18.52 kg
# Num rows    : 3100
# Num Features: 10
#
#  Cross-validation ---
# CV R² mean: 0.1114
# CV R² std : 0.2227
# CV scores : [-0.007  0.534  0.129 -0.008 -0.091]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2409
# Grouped CV R² std : 0.1562
# Grouped CV scores : [0.069 0.213 0.162 0.021 0.269 0.372 0.607 0.169 0.243 0.284]
# ============================================================
#  EVALUATION: EXPERIMENT-17 Plot groups. Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2'].
# ============================================================
#
# Test set:
#   R²   : 0.218
#   RMSE : 4.08 kg
#
# Regular CrossValidation:
#   Mean   : 0.111
#   Std    : 0.223
#   Scores : [-0.007  0.534  0.129 -0.008 -0.091]
#
#   ✅ Test R² is positive (0.218)
#   ✅ CV mean is positive (0.111)
#
# Grouped CrossValidation:
#   Big Creek_5          :   0.069  ✅
#   Frenchman Caye_6     :   0.213  ✅
#   Frenchman Caye_3     :   0.162  ✅
#   Big Creek_3          :   0.021  ✅
#   Frenchman Caye_1     :   0.269  ✅
#   Big Creek_2          :   0.372  ✅
#   Drowned Caye_5       :   0.607  ✅
#   Gra Gra Lagoon_4     :   0.169  ✅
#   Channel Caye_2       :   0.243  ✅
#   Channel Caye_6       :   0.284  ✅
#
#   Mean : 0.241
#   Std  : 0.156
#
#   ✅ Grouped CV mean above 0.15 (0.241)
#   ✅ Grouped CV std below 0.25 (0.156)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ✅ Grouped CV and test R² agree (gap: 0.023)
#   ✅ Train/test R² gap acceptable (gap: -0.212)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ✅ ACCEPTABLE
#
# Top 10 feature importances:
#   height                                        0.5026  =========================
#   NBR                                           0.1158  =====
#   RE1                                           0.0954  ====
#   EVI                                           0.0818  ====
#   species_Avicennia germinans                   0.0664  ===
#   species_Rhizophora mangle                     0.0528  ==
#   NIR                                           0.0477  ==
#   SWIR1                                         0.0239  =
#   RE2                                           0.0136
#   species_Laguncularia racemosa                 0.0000
#
# [18/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'subsample': 1.0, 'reg_lambda': 10, 'reg_alpha': 0, 'num_leaves': 31, 'n_estimators': 100, 'min_child_samples': 50, 'max_depth': 3, 'learning_rate': 0.01, 'colsample_bytree': 0.7}
#
#  LIGHTGBM: EXPERIMENT-18 Plot groups. Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : 0.2067
# Test RMSE   : 4.11 kg
# Train R² (log scale): 0.3035
# Train R² (orig scale): 0.0070
# Train RMSE  : 18.50 kg
# Num rows    : 3100
# Num Features: 13
#
#  Cross-validation ---
# CV R² mean: 0.1480
# CV R² std : 0.2279
# CV scores : [-0.028  0.583  0.144 -0.037  0.078]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.2466
# Grouped CV R² std : 0.1780
# Grouped CV scores : [-0.023  0.224  0.167 -0.006  0.307  0.43   0.609  0.216  0.234  0.308]
# ============================================================
#  EVALUATION: EXPERIMENT-18 Plot groups. Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : 0.207
#   RMSE : 4.11 kg
#
# Regular CrossValidation:
#   Mean   : 0.148
#   Std    : 0.228
#   Scores : [-0.028  0.583  0.144 -0.037  0.078]
#
#   ✅ Test R² is positive (0.207)
#   ✅ CV mean is positive (0.148)
#
# Grouped CrossValidation:
#   Big Creek_5          :  -0.023  ⚠️  near-zero variance artifact
#   Frenchman Caye_6     :   0.224  ✅
#   Frenchman Caye_3     :   0.167  ✅
#   Big Creek_3          :  -0.006  ⚠️  near-zero variance artifact
#   Frenchman Caye_1     :   0.307  ✅
#   Big Creek_2          :   0.430  ✅
#   Drowned Caye_5       :   0.609  ✅
#   Gra Gra Lagoon_4     :   0.216  ✅
#   Channel Caye_2       :   0.234  ✅
#   Channel Caye_6       :   0.308  ✅
#
#   Mean : 0.247
#   Std  : 0.178
#
#   ✅ Grouped CV mean above 0.15 (0.247)
#   ✅ Grouped CV std below 0.25 (0.178)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ✅ Grouped CV and test R² agree (gap: 0.040)
#   ✅ Train/test R² gap acceptable (gap: -0.200)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ✅ ACCEPTABLE
#
# Top 10 feature importances:
#   height                                        0.4496  ======================
#   height_x_NDRE1                                0.1133  =====
#   height_x_EVI                                  0.0863  ====
#   species_Rhizophora mangle                     0.0719  ===
#   RE1                                           0.0665  ===
#   SWIR1                                         0.0576  ==
#   species_Avicennia germinans                   0.0540  ==
#   NIR                                           0.0468  ==
#   height_x_NIR                                  0.0234  =
#   EVI                                           0.0144
#
# Completed: 18/18 experiments

# %%
tabulate_results(lgbm_belige_grid_grps, acceptable_only=True)
# Out:
# Showing 16 acceptable experiments
# <style type="text/css">
# #T_12670_row0_col8, #T_12670_row2_col2, #T_12670_row2_col3, #T_12670_row8_col9, #T_12670_row10_col10 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_12670">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_12670_level0_col0" class="col_heading level0 col0" >Experiment</th>
#       <th id="T_12670_level0_col1" class="col_heading level0 col1" >Num_features</th>
#       <th id="T_12670_level0_col2" class="col_heading level0 col2" >Test R²</th>
#       <th id="T_12670_level0_col3" class="col_heading level0 col3" >Test RMSE</th>
#       <th id="T_12670_level0_col4" class="col_heading level0 col4" >Train R²</th>
#       <th id="T_12670_level0_col5" class="col_heading level0 col5" >Train RMSE</th>
#       <th id="T_12670_level0_col6" class="col_heading level0 col6" >CV R² Mean</th>
#       <th id="T_12670_level0_col7" class="col_heading level0 col7" >CV R² Std</th>
#       <th id="T_12670_level0_col8" class="col_heading level0 col8" >Group CV R² Mean</th>
#       <th id="T_12670_level0_col9" class="col_heading level0 col9" >Group CV R² Std</th>
#       <th id="T_12670_level0_col10" class="col_heading level0 col10" >CV-Test Gap</th>
#       <th id="T_12670_level0_col11" class="col_heading level0 col11" >-ve Folds</th>
#       <th id="T_12670_level0_col12" class="col_heading level0 col12" >verdict</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12670_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_12670_row0_col0" class="data row0 col0" >EXPERIMENT-1 Plot groups. Grid search: Yes, Features: ['height'].</td>
#       <td id="T_12670_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_12670_row0_col2" class="data row0 col2" >0.2145</td>
#       <td id="T_12670_row0_col3" class="data row0 col3" >4.09</td>
#       <td id="T_12670_row0_col4" class="data row0 col4" >0.0386</td>
#       <td id="T_12670_row0_col5" class="data row0 col5" >18.21</td>
#       <td id="T_12670_row0_col6" class="data row0 col6" >0.205</td>
#       <td id="T_12670_row0_col7" class="data row0 col7" >0.1963</td>
#       <td id="T_12670_row0_col8" class="data row0 col8" >0.2831</td>
#       <td id="T_12670_row0_col9" class="data row0 col9" >0.1899</td>
#       <td id="T_12670_row0_col10" class="data row0 col10" >0.0686</td>
#       <td id="T_12670_row0_col11" class="data row0 col11" >1 (Big Creek_3)</td>
#       <td id="T_12670_row0_col12" class="data row0 col12" >⚠️  MARGINAL — positive metrics but concerns</td>
#     </tr>
#     <tr>
#       <th id="T_12670_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_12670_row1_col0" class="data row1 col0" >EXPERIMENT-11 Plot groups. Grid search: Yes, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1'].</td>
#       <td id="T_12670_row1_col1" class="data row1 col1" >5</td>
#       <td id="T_12670_row1_col2" class="data row1 col2" >0.2376</td>
#       <td id="T_12670_row1_col3" class="data row1 col3" >4.03</td>
#       <td id="T_12670_row1_col4" class="data row1 col4" >0.0485</td>
#       <td id="T_12670_row1_col5" class="data row1 col5" >18.11</td>
#       <td id="T_12670_row1_col6" class="data row1 col6" >0.1446</td>
#       <td id="T_12670_row1_col7" class="data row1 col7" >0.2246</td>
#       <td id="T_12670_row1_col8" class="data row1 col8" >0.2805</td>
#       <td id="T_12670_row1_col9" class="data row1 col9" >0.1811</td>
#       <td id="T_12670_row1_col10" class="data row1 col10" >0.0429</td>
#       <td id="T_12670_row1_col11" class="data row1 col11" >1 (Big Creek_3)</td>
#       <td id="T_12670_row1_col12" class="data row1 col12" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_12670_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_12670_row2_col0" class="data row2 col0" >EXPERIMENT-2 Plot groups. Grid search: Yes, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].</td>
#       <td id="T_12670_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_12670_row2_col2" class="data row2 col2" >0.2468</td>
#       <td id="T_12670_row2_col3" class="data row2 col3" >4.01</td>
#       <td id="T_12670_row2_col4" class="data row2 col4" >0.0505</td>
#       <td id="T_12670_row2_col5" class="data row2 col5" >18.09</td>
#       <td id="T_12670_row2_col6" class="data row2 col6" >0.2355</td>
#       <td id="T_12670_row2_col7" class="data row2 col7" >0.2177</td>
#       <td id="T_12670_row2_col8" class="data row2 col8" >0.2755</td>
#       <td id="T_12670_row2_col9" class="data row2 col9" >0.2024</td>
#       <td id="T_12670_row2_col10" class="data row2 col10" >0.0287</td>
#       <td id="T_12670_row2_col11" class="data row2 col11" >2 (Big Creek_5, Big Creek_3)</td>
#       <td id="T_12670_row2_col12" class="data row2 col12" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_12670_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_12670_row3_col0" class="data row3 col0" >EXPERIMENT-13 Plot groups. Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1'].</td>
#       <td id="T_12670_row3_col1" class="data row3 col1" >8</td>
#       <td id="T_12670_row3_col2" class="data row3 col2" >0.2093</td>
#       <td id="T_12670_row3_col3" class="data row3 col3" >4.1</td>
#       <td id="T_12670_row3_col4" class="data row3 col4" >0.0139</td>
#       <td id="T_12670_row3_col5" class="data row3 col5" >18.44</td>
#       <td id="T_12670_row3_col6" class="data row3 col6" >0.1189</td>
#       <td id="T_12670_row3_col7" class="data row3 col7" >0.2232</td>
#       <td id="T_12670_row3_col8" class="data row3 col8" >0.267</td>
#       <td id="T_12670_row3_col9" class="data row3 col9" >0.1787</td>
#       <td id="T_12670_row3_col10" class="data row3 col10" >0.0576</td>
#       <td id="T_12670_row3_col11" class="data row3 col11" >1 (Big Creek_3)</td>
#       <td id="T_12670_row3_col12" class="data row3 col12" >⚠️  MARGINAL — positive metrics but concerns</td>
#     </tr>
#     <tr>
#       <th id="T_12670_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_12670_row4_col0" class="data row4 col0" >EXPERIMENT-9 Plot groups. Grid search: Yes, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].</td>
#       <td id="T_12670_row4_col1" class="data row4 col1" >19</td>
#       <td id="T_12670_row4_col2" class="data row4 col2" >0.2124</td>
#       <td id="T_12670_row4_col3" class="data row4 col3" >4.1</td>
#       <td id="T_12670_row4_col4" class="data row4 col4" >0.046</td>
#       <td id="T_12670_row4_col5" class="data row4 col5" >18.14</td>
#       <td id="T_12670_row4_col6" class="data row4 col6" >0.1198</td>
#       <td id="T_12670_row4_col7" class="data row4 col7" >0.2111</td>
#       <td id="T_12670_row4_col8" class="data row4 col8" >0.2606</td>
#       <td id="T_12670_row4_col9" class="data row4 col9" >0.1761</td>
#       <td id="T_12670_row4_col10" class="data row4 col10" >0.0482</td>
#       <td id="T_12670_row4_col11" class="data row4 col11" >2 (Big Creek_5, Big Creek_3)</td>
#       <td id="T_12670_row4_col12" class="data row4 col12" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_12670_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_12670_row5_col0" class="data row5 col0" >EXPERIMENT-15 Plot groups. Grid search: Yes, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2'].</td>
#       <td id="T_12670_row5_col1" class="data row5 col1" >7</td>
#       <td id="T_12670_row5_col2" class="data row5 col2" >0.2275</td>
#       <td id="T_12670_row5_col3" class="data row5 col3" >4.06</td>
#       <td id="T_12670_row5_col4" class="data row5 col4" >0.0482</td>
#       <td id="T_12670_row5_col5" class="data row5 col5" >18.12</td>
#       <td id="T_12670_row5_col6" class="data row5 col6" >0.1486</td>
#       <td id="T_12670_row5_col7" class="data row5 col7" >0.2263</td>
#       <td id="T_12670_row5_col8" class="data row5 col8" >0.2575</td>
#       <td id="T_12670_row5_col9" class="data row5 col9" >0.1628</td>
#       <td id="T_12670_row5_col10" class="data row5 col10" >0.

# %% [markdown]
# **COMMENTS:**
# Many of the gradient boosting variants — XGBoost no grid, XGBoost with grid, LGBM no grid, with and without interaction terms produced zero acceptable results.
#
# Tuned LGBM finally worked but remains consistently weaker than RF across all metrics.
# Grouped CV is ~0.02–0.04 lower, test R² is ~0.04–0.05 lower across matched experiments.
#
# Gradient boosting can work on this dataset with extreme regularisation, but it requires tuning that essentially limits it to shallow trees and very slow learning — at which point it is doing less than what RF does naturally via bagging.
#
# The conclusion is definitve that the Gradient boosting methods are categorically not suited to this dataset structure.
# With only 59 plots and high within-plot variance, bagging (RF) will always outperform boosting.

# %% [markdown]
# ### BELIGE DATA. PLOT GROUPS. ALL ROWS. MERF (Hyper parameter tuning: NO)

# %%
# %run Model_functions.ipynb

start = time.perf_counter()
merf_belige_no_grid_grps = {}

run_experiment(X_belige, y_belige,
               is_groups=True, group_info=grp_belige,
               features_list=gen_features_list,
               experiments=merf_belige_no_grid_grps,
               model_type="merf", is_grid=False,
               is_stratified=is_stratified_g,
               global_experiment_list=global_experiment_list)

elapsed = time.perf_counter() - start
print(f"Time taken for the experiment: {elapsed:.4f}s")
# Out:
# [1/18]
#
#  MERF. EXPERIMENT-1 Plot groups. Grid search: NO, Features: ['height'].
# MERF model fitting starts
# MERF model fitting completed
# MERF cross validation starts
#
#  Cross-validation ---
# CV R² mean: -0.0123
# CV R² std : 0.3550
# CV scores : [ 0.137  0.381  0.291 -0.477 -0.394]
# Time taken for MERF cross validation: 66.3569s
# MERF Grouped cross validation starts
#   [Grouped CV 1/10] Fitting fold: ['Big Creek_5', 'Channel Caye_1', 'Channel Caye_4', 'New River_2', 'Turneffe Atoll_3'] ... R² = 0.0659
#   [Grouped CV 2/10] Fitting fold: ['Frenchman Caye_6', 'Gra Gra Lagoon_6', 'Hicks Caye_2', 'Hicks Caye_6', 'Turneffe Atoll_4'] ... R² = -0.3600
#   [Grouped CV 3/10] Fitting fold: ['Frenchman Caye_3', 'Gra Gra Lagoon_3', 'Hicks Caye_4', "Payne's Creek_3", 'Shipstern Lagoon_6'] ... R² = 0.2510
#   [Grouped CV 4/10] Fitting fold: ['Big Creek_3', 'Channel Caye_3', 'Channel Caye_5', 'New River_1', "Payne's Creek_2"] ... R² = -0.1641
#   [Grouped CV 5/10] Fitting fold: ['Frenchman Caye_1', 'Gra Gra Lagoon_5', 'Hicks Caye_3', 'New River_3', "Payne's Creek_6"] ... R² = 0.4482
#   [Grouped CV 6/10] Fitting fold: ['Big Creek_2', 'Drowned Caye_4', 'New River_6', "Payne's Creek_1", 'Shipstern Lagoon_2'] ... R² = 0.5690
#   [Grouped CV 7/10] Fitting fold: ['Drowned Caye_5', 'Drowned Caye_6', 'Frenchman Caye_2', 'Frenchman Caye_4'] ... R² = 0.4851
#   [Grouped CV 8/10] Fitting fold: ['Gra Gra Lagoon_4', 'Shipstern Lagoon_4', 'Shipstern Lagoon_5', 'Turneffe Atoll_6'] ... R² = 0.2857
#   [Grouped CV 9/10] Fitting fold: ['Channel Caye_2', 'Frenchman Caye_5', 'Hicks Caye_1', 'New River_5', "Payne's Creek_4"] ... R² = 0.1123
#   [Grouped CV 10/10] Fitting fold: ['Channel Caye_6', 'Drowned Caye_3', 'Gra Gra Lagoon_1', 'Turneffe Atoll_2'] ... R² = 0.3191
#
#  Grouped Cross-validation ---
# Grouped CV R² mean: 0.2012
# Grouped CV R² std : 0.2784
# Grouped CV scores : [ 0.066 -0.36   0.251 -0.164  0.448  0.569  0.485  0.286  0.112  0.319]
# Time taken for MERF Grouped cross validation: 66.3569s
#
#  MERF: EXPERIMENT-1 Plot groups. Grid search: NO, Features: ['height'].
# Test R²              : 0.1277
# Test RMSE            : 4.31 kg
# Train R² (log scale) : 0.4040
# Train R² (orig scale): 0.1658
# Train RMSE           : 16.96 kg
#
#  Cross-validation ---
# CV R² mean           : -0.0123
# CV R² std            : 0.3550
# CV scores            : [ 0.137  0.381  0.291 -0.477 -0.394]
# Num rows             : 3100
# Num groups           : 47
# ============================================================
#  EVALUATION: EXPERIMENT-1 Plot groups. Grid search: NO, Features: ['height'].
# ============================================================
#
# Test set:
#   R²   : 0.128
#   RMSE : 4.31 kg
#
#   ✅ Test R² is positive (0.128)
#
# Regular CrossValidation:
#   Mean   : -0.012
#   Std    : 0.355
#   Scores : [ 0.137  0.381  0.291 -0.477 -0.394]
#   ❌ CV mean is negative (-0.012)
#
# Grouped CrossValidation:
#   Big Creek            :   0.066  ✅
#   Frenchman Caye       :  -0.360  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.251  ✅
#   Big Creek            :  -0.164  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.448  ✅
#   Big Creek            :   0.569  ✅
#   Drowned Caye         :   0.485  ✅
#   Gra Gra Lagoon       :   0.286  ✅
#   Channel Caye         :   0.112  ✅
#   Channel Caye         :   0.319  ✅
#
#   Mean : 0.201
#   Std  : 0.278
#
#   ✅ Grouped CV mean above 0.15 (0.201)
#   ⚠️  Grouped CV std above 0.25 (0.278) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.074 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: 0.038)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height                                        1.0000  ==================================================
#
# [2/18]
#
#  MERF. EXPERIMENT-2 Plot groups. Grid search: NO, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# MERF model fitting starts
# MERF model fitting completed
# MERF cross validation starts
#
#  Cross-validation ---
# CV R² mean: 0.2424
# CV R² std : 0.1670
# CV scores : [0.134 0.371 0.16  0.047 0.5  ]
# Time taken for MERF cross validation: 64.7668s
# MERF Grouped cross validation starts
#   [Grouped CV 1/10] Fitting fold: ['Big Creek_5', 'Channel Caye_1', 'Channel Caye_4', 'New River_2', 'Turneffe Atoll_3'] ... R² = -0.0879
#   [Grouped CV 2/10] Fitting fold: ['Frenchman Caye_6', 'Gra Gra Lagoon_6', 'Hicks Caye_2', 'Hicks Caye_6', 'Turneffe Atoll_4'] ... R² = 0.0961
#   [Grouped CV 3/10] Fitting fold: ['Frenchman Caye_3', 'Gra Gra Lagoon_3', 'Hicks Caye_4', "Payne's Creek_3", 'Shipstern Lagoon_6'] ... R² = 0.2460
#   [Grouped CV 4/10] Fitting fold: ['Big Creek_3', 'Channel Caye_3', 'Channel Caye_5', 'New River_1', "Payne's Creek_2"] ... R² = -0.0666
#   [Grouped CV 5/10] Fitting fold: ['Frenchman Caye_1', 'Gra Gra Lagoon_5', 'Hicks Caye_3', 'New River_3', "Payne's Creek_6"] ... R² = 0.4694
#   [Grouped CV 6/10] Fitting fold: ['Big Creek_2', 'Drowned Caye_4', 'New River_6', "Payne's Creek_1", 'Shipstern Lagoon_2'] ... R² = 0.5535
#   [Grouped CV 7/10] Fitting fold: ['Drowned Caye_5', 'Drowned Caye_6', 'Frenchman Caye_2', 'Frenchman Caye_4'] ... R² = 0.4851
#   [Grouped CV 8/10] Fitting fold: ['Gra Gra Lagoon_4', 'Shipstern Lagoon_4', 'Shipstern Lagoon_5', 'Turneffe Atoll_6'] ... R² = 0.2841
#   [Grouped CV 9/10] Fitting fold: ['Channel Caye_2', 'Frenchman Caye_5', 'Hicks Caye_1', 'New River_5', "Payne's Creek_4"] ... R² = 0.2464
#   [Grouped CV 10/10] Fitting fold: ['Channel Caye_6', 'Drowned Caye_3', 'Gra Gra Lagoon_1', 'Turneffe Atoll_2'] ... R² = 0.3009
#
#  Grouped Cross-validation ---
# Grouped CV R² mean: 0.2527
# Grouped CV R² std : 0.2091
# Grouped CV scores : [-0.088  0.096  0.246 -0.067  0.469  0.554  0.485  0.284  0.246  0.301]
# Time taken for MERF Grouped cross validation: 64.7668s
#
#  MERF: EXPERIMENT-2 Plot groups. Grid search: NO, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²              : 0.2153
# Test RMSE            : 4.09 kg
# Train R² (log scale) : 0.4040
# Train R² (orig scale): 0.1658
# Train RMSE           : 16.96 kg
#
#  Cross-validation ---
# CV R² mean           : 0.2424
# CV R² std            : 0.1670
# CV scores            : [0.134 0.371 0.16  0.047 0.5  ]
# Num rows             : 3100
# Num groups           : 47
# ============================================================
#  EVALUATION: EXPERIMENT-2 Plot groups. Grid search: NO, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : 0.215
#   RMSE : 4.09 kg
#
#   ✅ Test R² is positive (0.215)
#
# Regular CrossValidation:
#   Mean   : 0.242
#   Std    : 0.167
#   Scores : [0.134 0.371 0.16  0.047 0.5  ]
#   ✅ CV mean is positive (0.242)
#
# Grouped CrossValidation:
#   Big Creek            :  -0.088  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.096  ✅
#   Frenchman Caye       :   0.246  ✅
#   Big Creek            :  -0.067  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.469  ✅
#   Big Creek            :   0.554  ✅
#   Drowned Caye         :   0.485  ✅
#   Gra Gra Lagoon       :   0.284  ✅
#   Channel Caye         :   0.246  ✅
#   Channel Caye         :   0.301  ✅
#
#   Mean : 0.253
#   Std  : 0.209
#
#   ✅ Grouped CV mean above 0.15 (0.253)
#   ✅ Grouped CV std below 0.25 (0.209)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ✅ Grouped CV and test R² agree (gap: 0.037)
#   ✅ Train/test R² gap acceptable (gap: -0.049)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ✅ ACCEPTABLE
#
# Top 10 feature importances:
#   height_x_NDRE1                                0.3908  ===================
#   height                                        0.2297  ===========
#   height_x_EVI                                  0.1978  =========
#   height_x_NIR                                  0.1817  =========
#
# [3/18]
#
#  MERF. EXPERIMENT-3 Plot groups. Grid search: NO, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2'].
# MERF model fitting starts
# MERF model fitting completed
# MERF cross validation starts
#
#  Cross-validation ---
# CV R² mean: 0.0000
# CV R² std : 0.4692
# CV scores : [ 0.04  -0.865  0.177  0.091  0.558]
# Time taken for MERF cross validation: 66.6716s
# MERF Grouped cross validation starts
#   [Grouped CV 1/10] Fitting fold: ['Big Creek_5', 'Channel Caye_1', 'Channel Caye_4', 'New River_2', 'Turneffe Atoll_3'] ... R² = -0.2471
#   [Grouped CV 2/10] Fitting fold: ['Frenchman Caye_6', 'Gra Gra Lagoon_6', 'Hicks Caye_2', 'Hicks Caye_6', 'Turneffe Atoll_4'] ... R² = -2.6817
#   [Grouped CV 3/10] Fitting fold: ['Frenchman Caye_3', 'Gra Gra Lagoon_3', 'Hicks Caye_4', "Payne's Creek_3", 'Shipstern Lagoon_6'] ... R² = 0.2266
#   [Grouped CV 4/10] Fitting fold: ['Big Creek_3', 'Channel Caye_3', 'Channel Caye_5', 'New River_1', "Payne's Creek_2"] ... R² = -0.0406
#   [Grouped CV 5/10] Fitting fold: ['Frenchman Caye_1', 'Gra Gra Lagoon_5', 'Hicks Caye_3', 'New River_3', "Payne's Creek_6"] ... R² = 0.3116
#   [Grouped CV 6/10] Fitting fold: ['Big Creek_2', 'Drowned Caye_4', 'New River_6', "Payne's Creek_1", 'Shipstern Lagoon_2'] ... R² = 0.3166
#   [Grouped CV 7/10] Fitting fold: ['Drowned Caye_5', 'Drowned Caye_6', 'Frenchman Caye_2', 'Frenchman Caye_4'] ... R² = 0.5111
#   [Grouped CV 8/10] Fitting fold: ['Gra Gra Lagoon_4', 'Shipstern Lagoon_4', 'Shipstern Lagoon_5', 'Turneffe Atoll_6'] ... R² = 0.2651
#   [Grouped CV 9/10] Fitting fold: ['Channel Caye_2', 'Frenchman Caye_5', 'Hicks Caye_1', 'New River_5', "Payne's Creek_4"] ... R² = 0.2132
#   [Grouped CV 10/10] Fitting fold: ['Channel Caye_6', 'Drowned Caye_3', 'Gra Gra Lagoon_1', 'Turneffe Atoll_2'] ... R² = -0.2214
#
#  Grouped Cross-validation ---
# Grouped CV R² mean: -0.1347
# Grouped CV R² std : 0.8802
# Grouped CV scores : [-0.247 -2.682  0.227 -0.041  0.312  0.317  0.511  0.265  0.213 -0.221]
# Time taken for MERF Grouped cross validation: 66.6716s
#
#  MERF: EXPERIMENT-3 Plot groups. Grid search: NO, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2'].
# Test R²              : 0.2709
# Test RMSE            : 3.94 kg
# Train R² (log scale) : 0.4040
# Train R² (orig scale): 0.1658
# Train RMSE           : 16.96 kg
#
#  Cross-validation ---
# CV R² mean           : 0.0000
# CV R² std            : 0.4692
# CV scores            : [ 0.04  -0.865  0.177  0.091  0.558]
# Num rows             : 3100
# Num groups           : 47
# ============================================================
#  EVALUATION: EXPERIMENT-3 Plot groups. Grid search: NO, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2'].
# ============================================================
#
# Test set:
#   R²   : 0.271
#   RMSE : 3.94 kg
#
#   ✅ Test R² is positive (0.271)
#
# Regular CrossValidation:
#   Mean   : 0.000
#   Std    : 0.469
#   Scores : [ 0.04  -0.865  0.177  0.091  0.558]
#   ✅ CV mean is positive (0.000)
#
# Grouped CrossValidation:
#   Big Creek            :  -0.247  ⚠️  near-zero variance artifact
#   Frenchman Caye       :  -2.682  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.227  ✅
#   Big Creek            :  -0.041  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.312  ✅
#   Big Creek            :   0.317  ✅
#   Drowned Caye         :   0.511  ✅
#   Gra Gra Lagoon       :   0.265  ✅
#   Channel Caye         :   0.213  ✅
#   Channel Caye         :  -0.221  ❌ negative — cause unknown
#
#   Mean : -0.135
#   Std  : 0.880
#
#   ❌ Grouped CV mean below 0.15 (-0.135)
#   ⚠️  Grouped CV std above 0.25 (0.880) — high variance across folds
#   ❌ Unexplained negative folds: ['Channel Caye']
#   ❌ High-AGB sites failed: ['Channel Caye']
#   ⚠️  Grouped CV and test R² diverge (gap: 0.406 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.105)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ⚠️  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   NIR                                           0.1831  =========
#   RE2                                           0.1600  =======
#   RE3                                           0.1416  =======
#   RE1                                           0.1379  ======
#   Red                                           0.0969  ====
#   Blue                                          0.0836  ====
#   Green                                         0.0695  ===
#   SWIR1                                         0.0667  ===
#   SWIR2                                         0.0607  ===
#
# [4/18]
#
#  MERF. EXPERIMENT-4 Plot groups. Grid search: NO, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# MERF model fitting starts
# MERF model fitting completed
# MERF cross validation starts
#
#  Cross-validation ---
# CV R² mean: 0.2467
# CV R² std : 0.1776
# CV scores : [0.107 0.34  0.159 0.076 0.551]
# Time taken for MERF cross validation: 65.3664s
# MERF Grouped cross validation starts
#   [Grouped CV 1/10] Fitting fold: ['Big Creek_5', 'Channel Caye_1', 'Channel Caye_4', 'New River_2', 'Turneffe Atoll_3'] ... R² = -0.1386
#   [Grouped CV 2/10] Fitting fold: ['Frenchman Caye_6', 'Gra Gra Lagoon_6', 'Hicks Caye_2', 'Hicks Caye_6', 'Turneffe Atoll_4'] ... R² = 0.1531
#   [Grouped CV 3/10] Fitting fold: ['Frenchman Caye_3', 'Gra Gra Lagoon_3', 'Hicks Caye_4', "Payne's Creek_3", 'Shipstern Lagoon_6'] ... R² = 0.2471
#   [Grouped CV 4/10] Fitting fold: ['Big Creek_3', 'Channel Caye_3', 'Channel Caye_5', 'New River_1', "Payne's Creek_2"] ... R² = -0.0363
#   [Grouped CV 5/10] Fitting fold: ['Frenchman Caye_1', 'Gra Gra Lagoon_5', 'Hicks Caye_3', 'New River_3', "Payne's Creek_6"] ... R² = 0.4592
#   [Grouped CV 6/10] Fitting fold: ['Big Creek_2', 'Drowned Caye_4', 'New River_6', "Payne's Creek_1", 'Shipstern Lagoon_2'] ... R² = 0.2725
#   [Grouped CV 7/10] Fitting fold: ['Drowned Caye_5', 'Drowned Caye_6', 'Frenchman Caye_2', 'Frenchman Caye_4'] ... R² = 0.4852
#   [Grouped CV 8/10] Fitting fold: ['Gra Gra Lagoon_4', 'Shipstern Lagoon_4', 'Shipstern Lagoon_5', 'Turneffe Atoll_6'] ... R² = 0.2621
#   [Grouped CV 9/10] Fitting fold: ['Channel Caye_2', 'Frenchman Caye_5', 'Hicks Caye_1', 'New River_5', "Payne's Creek_4"] ... R² = 0.2332
#   [Grouped CV 10/10] Fitting fold: ['Channel Caye_6', 'Drowned Caye_3', 'Gra Gra Lagoon_1', 'Turneffe Atoll_2'] ... R² = 0.3109
#
#  Grouped Cross-validation ---
# Grouped CV R² mean: 0.2249
# Grouped CV R² std : 0.1843
# Grouped CV scores : [-0.139  0.153  0.247 -0.036  0.459  0.273  0.485  0.262  0.233  0.311]
# Time taken for MERF Grouped cross validation: 65.3664s
#
#  MERF: EXPERIMENT-4 Plot groups. Grid search: NO, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²              : 0.2610
# Test RMSE            : 3.97 kg
# Train R² (log scale) : 0.4040
# Train R² (orig scale): 0.1658
# Train RMSE           : 16.96 kg
#
#  Cross-validation ---
# CV R² mean           : 0.2467
# CV R² std            : 0.1776
# CV scores            : [0.107 0.34  0.159 0.076 0.551]
# Num rows             : 3100
# Num groups           : 47
# ============================================================
#  EVALUATION: EXPERIMENT-4 Plot groups. Grid search: NO, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : 0.261
#   RMSE : 3.97 kg
#
#   ✅ Test R² is positive (0.261)
#
# Regular CrossValidation:
#   Mean   : 0.247
#   Std    : 0.178
#   Scores : [0.107 0.34  0.159 0.076 0.551]
#   ✅ CV mean is positive (0.247)
#
# Grouped CrossValidation:
#   Big Creek            :  -0.139  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.153  ✅
#   Frenchman Caye       :   0.247  ✅
#   Big Creek            :  -0.036  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.459  ✅
#   Big Creek            :   0.273  ✅
#   Drowned Caye         :   0.485  ✅
#   Gra Gra Lagoon       :   0.262  ✅
#   Channel Caye         :   0.233  ✅
#   Channel Caye         :   0.311  ✅
#
#   Mean : 0.225
#   Std  : 0.184
#
#   ✅ Grouped CV mean above 0.15 (0.225)
#   ✅ Grouped CV std below 0.25 (0.184)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ✅ Grouped CV and test R² agree (gap: 0.036)
#   ✅ Train/test R² gap acceptable (gap: -0.095)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ✅ ACCEPTABLE
#
# Top 10 feature importances:
#   height_x_NDRE1                                0.5830  =============================
#   height_x_EVI                                  0.1185  =====
#   height_x_NIR                                  0.0794  ===
#   SWIR1                                         0.0353  =
#   RE3                                           0.0350  =
#   NIR                                           0.0338  =
#   Green                                         0.0302  =
#   SWIR2                                         0.0279  =
#   Red                                           0.0175
#   RE2                                           0.0148
#
# [5/18]
#
#  MERF. EXPERIMENT-5 Plot groups. Grid search: NO, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# MERF model fitting starts
# MERF model fitting completed
# MERF cross validation starts
#
#  Cross-validation ---
# CV R² mean: -0.0281
# CV R² std : 0.3882
# CV scores : [ 0.142 -0.791  0.157  0.065  0.288]
# Time taken for MERF cross validation: 63.4380s
# MERF Grouped cross validation starts
#   [Grouped CV 1/10] Fitting fold: ['Big Creek_5', 'Channel Caye_1', 'Channel Caye_4', 'New River_2', 'Turneffe Atoll_3'] ... R² = -0.1169
#   [Grouped CV 2/10] Fitting fold: ['Frenchman Caye_6', 'Gra Gra Lagoon_6', 'Hicks Caye_2', 'Hicks Caye_6', 'Turneffe Atoll_4'] ... R² = -6.5664
#   [Grouped CV 3/10] Fitting fold: ['Frenchman Caye_3', 'Gra Gra Lagoon_3', 'Hicks Caye_4', "Payne's Creek_3", 'Shipstern Lagoon_6'] ... R² = 0.2398
#   [Grouped CV 4/10] Fitting fold: ['Big Creek_3', 'Channel Caye_3', 'Channel Caye_5', 'New River_1', "Payne's Creek_2"] ... R² = -0.1118
#   [Grouped CV 5/10] Fitting fold: ['Frenchman Caye_1', 'Gra Gra Lagoon_5', 'Hicks Caye_3', 'New River_3', "Payne's Creek_6"] ... R² = 0.5023
#   [Grouped CV 6/10] Fitting fold: ['Big Creek_2', 'Drowned Caye_4', 'New River_6', "Payne's Creek_1", 'Shipstern Lagoon_2'] ... R² = 0.5817
#   [Grouped CV 7/10] Fitting fold: ['Drowned Caye_5', 'Drowned Caye_6', 'Frenchman Caye_2', 'Frenchman Caye_4'] ... R² = 0.2195
#   [Grouped CV 8/10] Fitting fold: ['Gra Gra Lagoon_4', 'Shipstern Lagoon_4', 'Shipstern Lagoon_5', 'Turneffe Atoll_6'] ... R² = 0.2004
#   [Grouped CV 9/10] Fitting fold: ['Channel Caye_2', 'Frenchman Caye_5', 'Hicks Caye_1', 'New River_5', "Payne's Creek_4"] ... R² = 0.1803
#   [Grouped CV 10/10] Fitting fold: ['Channel Caye_6', 'Drowned Caye_3', 'Gra Gra Lagoon_1', 'Turneffe Atoll_2'] ... R² = 0.2153
#
#  Grouped Cross-validation ---
# Grouped CV R² mean: -0.4656
# Grouped CV R² std : 2.0443
# Grouped CV scores : [-0.117 -6.566  0.24  -0.112  0.502  0.582  0.22   0.2    0.18   0.215]
# Time taken for MERF Grouped cross validation: 63.4380s
#
#  MERF: EXPERIMENT-5 Plot groups. Grid search: NO, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# Test R²              : 0.0500
# Test RMSE            : 4.50 kg
# Train R² (log scale) : 0.4040
# Train R² (orig scale): 0.1658
# Train RMSE           : 16.96 kg
#
#  Cross-validation ---
# CV R² mean           : -0.0281
# CV R² std            : 0.3882
# CV scores            : [ 0.142 -0.791  0.157  0.065  0.288]
# Num rows             : 3100
# Num groups           : 47
# ============================================================
#  EVALUATION: EXPERIMENT-5 Plot groups. Grid search: NO, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# ============================================================
#
# Test set:
#   R²   : 0.050
#   RMSE : 4.50 kg
#
#   ✅ Test R² is positive (0.050)
#
# Regular CrossValidation:
#   Mean   : -0.028
#   Std    : 0.388
#   Scores : [ 0.142 -0.791  0.157  0.065  0.288]
#   ❌ CV mean is negative (-0.028)
#
# Grouped CrossValidation:
#   Big Creek            :  -0.117  ⚠️  near-zero variance artifact
#   Frenchman Caye       :  -6.566  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.240  ✅
#   Big Creek            :  -0.112  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.502  ✅
#   Big Creek            :   0.582  ✅
#   Drowned Caye         :   0.220  ✅
#   Gra Gra Lagoon       :   0.200  ✅
#   Channel Caye         :   0.180  ✅
#   Channel Caye         :   0.215  ✅
#
#   Mean : -0.466
#   Std  : 2.044
#
#   ❌ Grouped CV mean below 0.15 (-0.466)
#   ⚠️  Grouped CV std above 0.25 (2.044) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.516 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.116 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   NDRE1                                         0.3771  ==================
#   EVI                                           0.3289  ================
#   NBR                                           0.0994  ====
#   NDRE2                                         0.0654  ===
#   CIrededge                                     0.0438  ==
#   MNDWI                                         0.0350  =
#   NDRE3                                         0.0273  =
#   NDVI                                          0.0231  =
#   CLOUD_COVERAGE                                0.0000
#
# [6/18]
#
#  MERF. EXPERIMENT-6 Plot groups. Grid search: NO, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# MERF model fitting starts
# MERF model fitting completed
# MERF cross validation starts
#
#  Cross-validation ---
# CV R² mean: 0.2244
# CV R² std : 0.1648
# CV scores : [0.125 0.198 0.184 0.073 0.542]
# Time taken for MERF cross validation: 63.9629s
# MERF Grouped cross validation starts
#   [Grouped CV 1/10] Fitting fold: ['Big Creek_5', 'Channel Caye_1', 'Channel Caye_4', 'New River_2', 'Turneffe Atoll_3'] ... R² = -0.0772
#   [Grouped CV 2/10] Fitting fold: ['Frenchman Caye_6', 'Gra Gra Lagoon_6', 'Hicks Caye_2', 'Hicks Caye_6', 'Turneffe Atoll_4'] ... R² = -3.5401
#   [Grouped CV 3/10] Fitting fold: ['Frenchman Caye_3', 'Gra Gra Lagoon_3', 'Hicks Caye_4', "Payne's Creek_3", 'Shipstern Lagoon_6'] ... R² = 0.2633
#   [Grouped CV 4/10] Fitting fold: ['Big Creek_3', 'Channel Caye_3', 'Channel Caye_5', 'New River_1', "Payne's Creek_2"] ... R² = -0.0796
#   [Grouped CV 5/10] Fitting fold: ['Frenchman Caye_1', 'Gra Gra Lagoon_5', 'Hicks Caye_3', 'New River_3', "Payne's Creek_6"] ... R² = 0.4926
#   [Grouped CV 6/10] Fitting fold: ['Big Creek_2', 'Drowned Caye_4', 'New River_6', "Payne's Creek_1", 'Shipstern Lagoon_2'] ... R² = 0.5742
#   [Grouped CV 7/10] Fitting fold: ['Drowned Caye_5', 'Drowned Caye_6', 'Frenchman Caye_2', 'Frenchman Caye_4'] ... R² = 0.6150
#   [Grouped CV 8/10] Fitting fold: ['Gra Gra Lagoon_4', 'Shipstern Lagoon_4', 'Shipstern Lagoon_5', 'Turneffe Atoll_6'] ... R² = 0.2587
#   [Grouped CV 9/10] Fitting fold: ['Channel Caye_2', 'Frenchman Caye_5', 'Hicks Caye_1', 'New River_5', "Payne's Creek_4"] ... R² = 0.2077
#   [Grouped CV 10/10] Fitting fold: ['Channel Caye_6', 'Drowned Caye_3', 'Gra Gra Lagoon_1', 'Turneffe Atoll_2'] ... R² = 0.2925
#
#  Grouped Cross-validation ---
# Grouped CV R² mean: -0.0993
# Grouped CV R² std : 1.1688
# Grouped CV scores : [-0.077 -3.54   0.263 -0.08   0.493  0.574  0.615  0.259  0.208  0.292]
# Time taken for MERF Grouped cross validation: 63.9629s
#
#  MERF: EXPERIMENT-6 Plot groups. Grid search: NO, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²              : 0.0558
# Test RMSE            : 4.48 kg
# Train R² (log scale) : 0.4040
# Train R² (orig scale): 0.1658
# Train RMSE           : 16.96 kg
#
#  Cross-validation ---
# CV R² mean           : 0.2244
# CV R² std            : 0.1648
# CV scores            : [0.125 0.198 0.184 0.073 0.542]
# Num rows             : 3100
# Num groups           : 47
# ============================================================
#  EVALUATION: EXPERIMENT-6 Plot groups. Grid search: NO, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : 0.056
#   RMSE : 4.48 kg
#
#   ✅ Test R² is positive (0.056)
#
# Regular CrossValidation:
#   Mean   : 0.224
#   Std    : 0.165
#   Scores : [0.125 0.198 0.184 0.073 0.542]
#   ✅ CV mean is positive (0.224)
#
# Grouped CrossValidation:
#   Big Creek            :  -0.077  ⚠️  near-zero variance artifact
#   Frenchman Caye       :  -3.540  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.263  ✅
#   Big Creek            :  -0.080  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.493  ✅
#   Big Creek            :   0.574  ✅
#   Drowned Caye         :   0.615  ✅
#   Gra Gra Lagoon       :   0.259  ✅
#   Channel Caye         :   0.208  ✅
#   Channel Caye         :   0.292  ✅
#
#   Mean : -0.099
#   Std  : 1.169
#
#   ❌ Grouped CV mean below 0.15 (-0.099)
#   ⚠️  Grouped CV std above 0.25 (1.169) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.155 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.110 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ⚠️  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height_x_NDRE1                                0.3802  ===================
#   height_x_EVI                                  0.2012  ==========
#   height_x_NIR                                  0.1607  ========
#   EVI                                           0.0653  ===
#   MNDWI                                         0.0642  ===
#   NBR                                           0.0330  =
#   NDRE1                                         0.0240  =
#   CIrededge                                     0.0234  =
#   NDRE3                                         0.0186
#   NDRE2                                         0.0170
#
# [7/18]
#
#  MERF. EXPERIMENT-7 Plot groups. Grid search: NO, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# MERF model fitting starts
# MERF model fitting completed
# MERF cross validation starts
#
#  Cross-validation ---
# CV R² mean: -0.0943
# CV R² std : 0.5701
# CV scores : [ 0.131 -1.211  0.156  0.056  0.397]
# Time taken for MERF cross validation: 64.1444s
# MERF Grouped cross validation starts
#   [Grouped CV 1/10] Fitting fold: ['Big Creek_5', 'Channel Caye_1', 'Channel Caye_4', 'New River_2', 'Turneffe Atoll_3'] ... R² = -0.1227
#   [Grouped CV 2/10] Fitting fold: ['Frenchman Caye_6', 'Gra Gra Lagoon_6', 'Hicks Caye_2', 'Hicks Caye_6', 'Turneffe Atoll_4'] ... R² = -6.4285
#   [Grouped CV 3/10] Fitting fold: ['Frenchman Caye_3', 'Gra Gra Lagoon_3', 'Hicks Caye_4', "Payne's Creek_3", 'Shipstern Lagoon_6'] ... R² = 0.2378
#   [Grouped CV 4/10] Fitting fold: ['Big Creek_3', 'Channel Caye_3', 'Channel Caye_5', 'New River_1', "Payne's Creek_2"] ... R² = -0.0616
#   [Grouped CV 5/10] Fitting fold: ['Frenchman Caye_1', 'Gra Gra Lagoon_5', 'Hicks Caye_3', 'New River_3', "Payne's Creek_6"] ... R² = 0.4774
#   [Grouped CV 6/10] Fitting fold: ['Big Creek_2', 'Drowned Caye_4', 'New River_6', "Payne's Creek_1", 'Shipstern Lagoon_2'] ... R² = 0.5525
#   [Grouped CV 7/10] Fitting fold: ['Drowned Caye_5', 'Drowned Caye_6', 'Frenchman Caye_2', 'Frenchman Caye_4'] ... R² = 0.1733
#   [Grouped CV 8/10] Fitting fold: ['Gra Gra Lagoon_4', 'Shipstern Lagoon_4', 'Shipstern Lagoon_5', 'Turneffe Atoll_6'] ... R² = 0.1984
#   [Grouped CV 9/10] Fitting fold: ['Channel Caye_2', 'Frenchman Caye_5', 'Hicks Caye_1', 'New River_5', "Payne's Creek_4"] ... R² = 0.2080
#   [Grouped CV 10/10] Fitting fold: ['Channel Caye_6', 'Drowned Caye_3', 'Gra Gra Lagoon_1', 'Turneffe Atoll_2'] ... R² = 0.2342
#
#  Grouped Cross-validation ---
# Grouped CV R² mean: -0.4531
# Grouped CV R² std : 2.0012
# Grouped CV scores : [-0.123 -6.429  0.238 -0.062  0.477  0.553  0.173  0.198  0.208  0.234]
# Time taken for MERF Grouped cross validation: 64.1444s
#
#  MERF: EXPERIMENT-7 Plot groups. Grid search: NO, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# Test R²              : 0.1777
# Test RMSE            : 4.19 kg
# Train R² (log scale) : 0.4040
# Train R² (orig scale): 0.1658
# Train RMSE           : 16.96 kg
#
#  Cross-validation ---
# CV R² mean           : -0.0943
# CV R² std            : 0.5701
# CV scores            : [ 0.131 -1.211  0.156  0.056  0.397]
# Num rows             : 3100
# Num groups           : 47
# ============================================================
#  EVALUATION: EXPERIMENT-7 Plot groups. Grid search: NO, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# ============================================================
#
# Test set:
#   R²   : 0.178
#   RMSE : 4.19 kg
#
#   ✅ Test R² is positive (0.178)
#
# Regular CrossValidation:
#   Mean   : -0.094
#   Std    : 0.570
#   Scores : [ 0.131 -1.211  0.156  0.056  0.397]
#   ❌ CV mean is negative (-0.094)
#
# Grouped CrossValidation:
#   Big Creek            :  -0.123  ⚠️  near-zero variance artifact
#   Frenchman Caye       :  -6.429  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.238  ✅
#   Big Creek            :  -0.062  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.477  ✅
#   Big Creek            :   0.553  ✅
#   Drowned Caye         :   0.173  ✅
#   Gra Gra Lagoon       :   0.198  ✅
#   Channel Caye         :   0.208  ✅
#   Channel Caye         :   0.234  ✅
#
#   Mean : -0.453
#   Std  : 2.001
#
#   ❌ Grouped CV mean below 0.15 (-0.453)
#   ⚠️  Grouped CV std above 0.25 (2.001) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.631 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.012)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   NDRE1                                         0.3748  ==================
#   EVI                                           0.2773  =============
#   NBR                                           0.0731  ===
#   NDRE2                                         0.0474  ==
#   CIrededge                                     0.0323  =
#   SWIR2                                         0.0229  =
#   Blue                                          0.0227  =
#   NIR                                           0.0225  =
#   MNDWI                                         0.0223  =
#   RE3                                           0.0202  =
#
# [8/18]
#
#  MERF. EXPERIMENT-8 Plot groups. Grid search: NO, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# MERF model fitting starts
# MERF model fitting completed
# MERF cross validation starts
#
#  Cross-validation ---
# CV R² mean: 0.1967
# CV R² std : 0.1807
# CV scores : [0.103 0.085 0.166 0.077 0.553]
# Time taken for MERF cross validation: 64.4526s
# MERF Grouped cross validation starts
#   [Grouped CV 1/10] Fitting fold: ['Big Creek_5', 'Channel Caye_1', 'Channel Caye_4', 'New River_2', 'Turneffe Atoll_3'] ... R² = -0.1229
#   [Grouped CV 2/10] Fitting fold: ['Frenchman Caye_6', 'Gra Gra Lagoon_6', 'Hicks Caye_2', 'Hicks Caye_6', 'Turneffe Atoll_4'] ... R² = -3.4963
#   [Grouped CV 3/10] Fitting fold: ['Frenchman Caye_3', 'Gra Gra Lagoon_3', 'Hicks Caye_4', "Payne's Creek_3", 'Shipstern Lagoon_6'] ... R² = 0.2646
#   [Grouped CV 4/10] Fitting fold: ['Big Creek_3', 'Channel Caye_3', 'Channel Caye_5', 'New River_1', "Payne's Creek_2"] ... R² = -0.0693
#   [Grouped CV 5/10] Fitting fold: ['Frenchman Caye_1', 'Gra Gra Lagoon_5', 'Hicks Caye_3', 'New River_3', "Payne's Creek_6"] ... R² = 0.4695
#   [Grouped CV 6/10] Fitting fold: ['Big Creek_2', 'Drowned Caye_4', 'New River_6', "Payne's Creek_1", 'Shipstern Lagoon_2'] ... R² = 0.1595
#   [Grouped CV 7/10] Fitting fold: ['Drowned Caye_5', 'Drowned Caye_6', 'Frenchman Caye_2', 'Frenchman Caye_4'] ... R² = 0.6146
#   [Grouped CV 8/10] Fitting fold: ['Gra Gra Lagoon_4', 'Shipstern Lagoon_4', 'Shipstern Lagoon_5', 'Turneffe Atoll_6'] ... R² = 0.2544
#   [Grouped CV 9/10] Fitting fold: ['Channel Caye_2', 'Frenchman Caye_5', 'Hicks Caye_1', 'New River_5', "Payne's Creek_4"] ... R² = 0.2063
#   [Grouped CV 10/10] Fitting fold: ['Channel Caye_6', 'Drowned Caye_3', 'Gra Gra Lagoon_1', 'Turneffe Atoll_2'] ... R² = 0.2919
#
#  Grouped Cross-validation ---
# Grouped CV R² mean: -0.1428
# Grouped CV R² std : 1.1369
# Grouped CV scores : [-0.123 -3.496  0.265 -0.069  0.469  0.16   0.615  0.254  0.206  0.292]
# Time taken for MERF Grouped cross validation: 64.4526s
#
#  MERF: EXPERIMENT-8 Plot groups. Grid search: NO, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²              : 0.2249
# Test RMSE            : 4.06 kg
# Train R² (log scale) : 0.4040
# Train R² (orig scale): 0.1658
# Train RMSE           : 16.96 kg
#
#  Cross-validation ---
# CV R² mean           : 0.1967
# CV R² std            : 0.1807
# CV scores            : [0.103 0.085 0.166 0.077 0.553]
# Num rows             : 3100
# Num groups           : 47
# ============================================================
#  EVALUATION: EXPERIMENT-8 Plot groups. Grid search: NO, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : 0.225
#   RMSE : 4.06 kg
#
#   ✅ Test R² is positive (0.225)
#
# Regular CrossValidation:
#   Mean   : 0.197
#   Std    : 0.181
#   Scores : [0.103 0.085 0.166 0.077 0.553]
#   ✅ CV mean is positive (0.197)
#
# Grouped CrossValidation:
#   Big Creek            :  -0.123  ⚠️  near-zero variance artifact
#   Frenchman Caye       :  -3.496  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.265  ✅
#   Big Creek            :  -0.069  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.469  ✅
#   Big Creek            :   0.160  ✅
#   Drowned Caye         :   0.615  ✅
#   Gra Gra Lagoon       :   0.254  ✅
#   Channel Caye         :   0.206  ✅
#   Channel Caye         :   0.292  ✅
#
#   Mean : -0.143
#   Std  : 1.137
#
#   ❌ Grouped CV mean below 0.15 (-0.143)
#   ⚠️  Grouped CV std above 0.25 (1.137) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.368 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.059)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ⚠️  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height_x_NDRE1                                0.3749  ==================
#   height_x_NIR                                  0.2132  ==========
#   height_x_EVI                                  0.1522  =======
#   MNDWI                                         0.0289  =
#   EVI                                           0.0274  =
#   SWIR1                                         0.0232  =
#   Green                                         0.0215  =
#   RE3                                           0.0213  =
#   NBR                                           0.0201  =
#   NIR                                           0.0175
#
# [9/18]
#
#  MERF. EXPERIMENT-9 Plot groups. Grid search: NO, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# MERF model fitting starts
# MERF model fitting completed
# MERF cross validation starts
#
#  Cross-validation ---
# CV R² mean: 0.2255
# CV R² std : 0.1825
# CV scores : [0.122 0.087 0.269 0.085 0.564]
# Time taken for MERF cross validation: 63.9361s
# MERF Grouped cross validation starts
#   [Grouped CV 1/10] Fitting fold: ['Big Creek_5', 'Channel Caye_1', 'Channel Caye_4', 'New River_2', 'Turneffe Atoll_3'] ... R² = 0.0665
#   [Grouped CV 2/10] Fitting fold: ['Frenchman Caye_6', 'Gra Gra Lagoon_6', 'Hicks Caye_2', 'Hicks Caye_6', 'Turneffe Atoll_4'] ... R² = -3.7960
#   [Grouped CV 3/10] Fitting fold: ['Frenchman Caye_3', 'Gra Gra Lagoon_3', 'Hicks Caye_4', "Payne's Creek_3", 'Shipstern Lagoon_6'] ... R² = 0.2666
#   [Grouped CV 4/10] Fitting fold: ['Big Creek_3', 'Channel Caye_3', 'Channel Caye_5', 'New River_1', "Payne's Creek_2"] ... R² = -0.0676
#   [Grouped CV 5/10] Fitting fold: ['Frenchman Caye_1', 'Gra Gra Lagoon_5', 'Hicks Caye_3', 'New River_3', "Payne's Creek_6"] ... R² = 0.4604
#   [Grouped CV 6/10] Fitting fold: ['Big Creek_2', 'Drowned Caye_4', 'New River_6', "Payne's Creek_1", 'Shipstern Lagoon_2'] ... R² = 0.1427
#   [Grouped CV 7/10] Fitting fold: ['Drowned Caye_5', 'Drowned Caye_6', 'Frenchman Caye_2', 'Frenchman Caye_4'] ... R² = 0.5881
#   [Grouped CV 8/10] Fitting fold: ['Gra Gra Lagoon_4', 'Shipstern Lagoon_4', 'Shipstern Lagoon_5', 'Turneffe Atoll_6'] ... R² = 0.2568
#   [Grouped CV 9/10] Fitting fold: ['Channel Caye_2', 'Frenchman Caye_5', 'Hicks Caye_1', 'New River_5', "Payne's Creek_4"] ... R² = 0.2159
#   [Grouped CV 10/10] Fitting fold: ['Channel Caye_6', 'Drowned Caye_3', 'Gra Gra Lagoon_1', 'Turneffe Atoll_2'] ... R² = 0.2947
#
#  Grouped Cross-validation ---
# Grouped CV R² mean: -0.1572
# Grouped CV R² std : 1.2256
# Grouped CV scores : [ 0.067 -3.796  0.267 -0.068  0.46   0.143  0.588  0.257  0.216  0.295]
# Time taken for MERF Grouped cross validation: 63.9361s
#
#  MERF: EXPERIMENT-9 Plot groups. Grid search: NO, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# Test R²              : -2.2833
# Test RMSE            : 8.36 kg
# Train R² (log scale) : 0.4040
# Train R² (orig scale): 0.1658
# Train RMSE           : 16.96 kg
#
#  Cross-validation ---
# CV R² mean           : 0.2255
# CV R² std            : 0.1825
# CV scores            : [0.122 0.087 0.269 0.085 0.564]
# Num rows             : 3100
# Num groups           : 47
# ============================================================
#  EVALUATION: EXPERIMENT-9 Plot groups. Grid search: NO, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# ============================================================
#
# Test set:
#   R²   : -2.283
#   RMSE : 8.36 kg
#
#   ❌ Test R² is negative (-2.283)
#
# Regular CrossValidation:
#   Mean   : 0.226
#   Std    : 0.182
#   Scores : [0.122 0.087 0.269 0.085 0.564]
#   ✅ CV mean is positive (0.226)
#
# Grouped CrossValidation:
#   Big Creek            :   0.067  ✅
#   Frenchman Caye       :  -3.796  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.267  ✅
#   Big Creek            :  -0.068  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.460  ✅
#   Big Creek            :   0.143  ✅
#   Drowned Caye         :   0.588  ✅
#   Gra Gra Lagoon       :   0.257  ✅
#   Channel Caye         :   0.216  ✅
#   Channel Caye         :   0.295  ✅
#
#   Mean : -0.157
#   Std  : 1.226
#
#   ❌ Grouped CV mean below 0.15 (-0.157)
#   ⚠️  Grouped CV std above 0.25 (1.226) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 2.126 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 2.449 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height                                        0.7003  ===================================
#   MNDWI                                         0.0455  ==
#   NBR                                           0.0311  =
#   EVI                                           0.0284  =
#   Green                                         0.0244  =
#   SWIR1                                         0.0234  =
#   RE3                                           0.0195
#   NIR                                           0.0185
#   SWIR2                                         0.0176
#   Red                                           0.0164
#
# [10/18]
#
#  MERF. EXPERIMENT-10 Plot groups. Grid search: NO, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# MERF model fitting starts
# MERF model fitting completed
# MERF cross validation starts
#
#  Cross-validation ---
# CV R² mean: 0.2124
# CV R² std : 0.1760
# CV scores : [0.112 0.143 0.169 0.079 0.559]
# Time taken for MERF cross validation: 63.8641s
# MERF Grouped cross validation starts
#   [Grouped CV 1/10] Fitting fold: ['Big Creek_5', 'Channel Caye_1', 'Channel Caye_4', 'New River_2', 'Turneffe Atoll_3'] ... R² = -0.1015
#   [Grouped CV 2/10] Fitting fold: ['Frenchman Caye_6', 'Gra Gra Lagoon_6', 'Hicks Caye_2', 'Hicks Caye_6', 'Turneffe Atoll_4'] ... R² = -3.3684
#   [Grouped CV 3/10] Fitting fold: ['Frenchman Caye_3', 'Gra Gra Lagoon_3', 'Hicks Caye_4', "Payne's Creek_3", 'Shipstern Lagoon_6'] ... R² = 0.2644
#   [Grouped CV 4/10] Fitting fold: ['Big Creek_3', 'Channel Caye_3', 'Channel Caye_5', 'New River_1', "Payne's Creek_2"] ... R² = -0.0620
#   [Grouped CV 5/10] Fitting fold: ['Frenchman Caye_1', 'Gra Gra Lagoon_5', 'Hicks Caye_3', 'New River_3', "Payne's Creek_6"] ... R² = 0.4656
#   [Grouped CV 6/10] Fitting fold: ['Big Creek_2', 'Drowned Caye_4', 'New River_6', "Payne's Creek_1", 'Shipstern Lagoon_2'] ... R² = 0.1687
#   [Grouped CV 7/10] Fitting fold: ['Drowned Caye_5', 'Drowned Caye_6', 'Frenchman Caye_2', 'Frenchman Caye_4'] ... R² = 0.5915
#   [Grouped CV 8/10] Fitting fold: ['Gra Gra Lagoon_4', 'Shipstern Lagoon_4', 'Shipstern Lagoon_5', 'Turneffe Atoll_6'] ... R² = 0.2567
#   [Grouped CV 9/10] Fitting fold: ['Channel Caye_2', 'Frenchman Caye_5', 'Hicks Caye_1', 'New River_5', "Payne's Creek_4"] ... R² = 0.2084
#   [Grouped CV 10/10] Fitting fold: ['Channel Caye_6', 'Drowned Caye_3', 'Gra Gra Lagoon_1', 'Turneffe Atoll_2'] ... R² = 0.2937
#
#  Grouped Cross-validation ---
# Grouped CV R² mean: -0.1283
# Grouped CV R² std : 1.0980
# Grouped CV scores : [-0.101 -3.368  0.264 -0.062  0.466  0.169  0.591  0.257  0.208  0.294]
# Time taken for MERF Grouped cross validation: 63.8641s
#
#  MERF: EXPERIMENT-10 Plot groups. Grid search: NO, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²              : -0.1632
# Test RMSE            : 4.98 kg
# Train R² (log scale) : 0.4040
# Train R² (orig scale): 0.1658
# Train RMSE           : 16.96 kg
#
#  Cross-validation ---
# CV R² mean           : 0.2124
# CV R² std            : 0.1760
# CV scores            : [0.112 0.143 0.169 0.079 0.559]
# Num rows             : 3100
# Num groups           : 47
# ============================================================
#  EVALUATION: EXPERIMENT-10 Plot groups. Grid search: NO, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : -0.163
#   RMSE : 4.98 kg
#
#   ❌ Test R² is negative (-0.163)
#
# Regular CrossValidation:
#   Mean   : 0.212
#   Std    : 0.176
#   Scores : [0.112 0.143 0.169 0.079 0.559]
#   ✅ CV mean is positive (0.212)
#
# Grouped CrossValidation:
#   Big Creek            :  -0.101  ⚠️  near-zero variance artifact
#   Frenchman Caye       :  -3.368  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.264  ✅
#   Big Creek            :  -0.062  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.466  ✅
#   Big Creek            :   0.169  ✅
#   Drowned Caye         :   0.591  ✅
#   Gra Gra Lagoon       :   0.257  ✅
#   Channel Caye         :   0.208  ✅
#   Channel Caye         :   0.294  ✅
#
#   Mean : -0.128
#   Std  : 1.098
#
#   ❌ Grouped CV mean below 0.15 (-0.128)
#   ⚠️  Grouped CV std above 0.25 (1.098) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ✅ Grouped CV and test R² agree (gap: 0.035)
#   ⚠️  Train R² well above test R² (gap: 0.329 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height_x_NDRE1                                0.3725  ==================
#   height                                        0.2005  ==========
#   height_x_EVI                                  0.0885  ====
#   height_x_NIR                                  0.0689  ===
#   MNDWI                                         0.0625  ===
#   NBR                                           0.0261  =
#   EVI                                           0.0232  =
#   Green                                         0.0215  =
#   SWIR1                                         0.0198
#   NIR                                           0.0182
#
# [11/18]
#
#  MERF. EXPERIMENT-11 Plot groups. Grid search: NO, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1'].
# MERF model fitting starts
# MERF model fitting completed
# MERF cross validation starts
#
#  Cross-validation ---
# CV R² mean: 0.2889
# CV R² std : 0.1739
# CV scores : [0.108 0.394 0.279 0.104 0.559]
# Time taken for MERF cross validation: 61.3358s
# MERF Grouped cross validation starts
#   [Grouped CV 1/10] Fitting fold: ['Big Creek_5', 'Channel Caye_1', 'Channel Caye_4', 'New River_2', 'Turneffe Atoll_3'] ... R² = 0.0815
#   [Grouped CV 2/10] Fitting fold: ['Frenchman Caye_6', 'Gra Gra Lagoon_6', 'Hicks Caye_2', 'Hicks Caye_6', 'Turneffe Atoll_4'] ... R² = 0.2669
#   [Grouped CV 3/10] Fitting fold: ['Frenchman Caye_3', 'Gra Gra Lagoon_3', 'Hicks Caye_4', "Payne's Creek_3", 'Shipstern Lagoon_6'] ... R² = 0.2584
#   [Grouped CV 4/10] Fitting fold: ['Big Creek_3', 'Channel Caye_3', 'Channel Caye_5', 'New River_1', "Payne's Creek_2"] ... R² = -0.0664
#   [Grouped CV 5/10] Fitting fold: ['Frenchman Caye_1', 'Gra Gra Lagoon_5', 'Hicks Caye_3', 'New River_3', "Payne's Creek_6"] ... R² = 0.4718
#   [Grouped CV 6/10] Fitting fold: ['Big Creek_2', 'Drowned Caye_4', 'New River_6', "Payne's Creek_1", 'Shipstern Lagoon_2'] ... R² = 0.4948
#   [Grouped CV 7/10] Fitting fold: ['Drowned Caye_5', 'Drowned Caye_6', 'Frenchman Caye_2', 'Frenchman Caye_4'] ... R² = 0.4851
#   [Grouped CV 8/10] Fitting fold: ['Gra Gra Lagoon_4', 'Shipstern Lagoon_4', 'Shipstern Lagoon_5', 'Turneffe Atoll_6'] ... R² = 0.2492
#   [Grouped CV 9/10] Fitting fold: ['Channel Caye_2', 'Frenchman Caye_5', 'Hicks Caye_1', 'New River_5', "Payne's Creek_4"] ... R² = 0.2372
#   [Grouped CV 10/10] Fitting fold: ['Channel Caye_6', 'Drowned Caye_3', 'Gra Gra Lagoon_1', 'Turneffe Atoll_2'] ... R² = 0.3156
#
#  Grouped Cross-validation ---
# Grouped CV R² mean: 0.2794
# Grouped CV R² std : 0.1700
# Grouped CV scores : [ 0.081  0.267  0.258 -0.066  0.472  0.495  0.485  0.249  0.237  0.316]
# Time taken for MERF Grouped cross validation: 61.3358s
#
# ...
# Test R²              : -2.9449
# Test RMSE            : 9.17 kg
# Train R² (log scale) : 0.4040
# Train R² (orig scale): 0.1658
# Train RMSE           : 16.96 kg
#
#  Cross-validation ---
# CV R² mean           : 0.2877
# CV R² std            : 0.1728
# CV scores            : [0.138 0.394 0.267 0.082 0.557]
# Num rows             : 3100
# Num groups           : 47
# ============================================================
#  EVALUATION: EXPERIMENT-15 Plot groups. Grid search: NO, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2'].
# ============================================================
#
# Test set:
#   R²   : -2.945
#   RMSE : 9.17 kg
#
#   ❌ Test R² is negative (-2.945)
#
# Regular CrossValidation:
#   Mean   : 0.288
#   Std    : 0.173
#   Scores : [0.138 0.394 0.267 0.082 0.557]
#   ✅ CV mean is positive (0.288)
#
# Grouped CrossValidation:
#   Big Creek            :   0.089  ✅
#   Frenchman Caye       :   0.260  ✅
#   Frenchman Caye       :   0.257  ✅
#   Big Creek            :  -0.060  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.458  ✅
#   Big Creek            :   0.166  ✅
#   Drowned Caye         :   0.485  ✅
#   Gra Gra Lagoon       :   0.248  ✅
#   Channel Caye         :   0.239  ✅
#   Channel Caye         :   0.283  ✅
#
#   Mean : 0.243
#   Std  : 0.151
#
#   ✅ Grouped CV mean above 0.15 (0.243)
#   ✅ Grouped CV std below 0.25 (0.151)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 3.187 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 3.111 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height                                        0.7391  ====================================
#   EVI                                           0.0639  ===
#   SWIR1                                         0.0593  ==
#   NBR                                           0.0467  ==
#   NIR                                           0.0430  ==
#   RE2                                           0.0263  =
#   RE1                                           0.0217  =
#
# [16/18]
#
#  MERF. EXPERIMENT-16 Plot groups. Grid search: NO, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# MERF model fitting starts
# MERF model fitting completed
# MERF cross validation starts
#
#  Cross-validation ---
# CV R² mean: 0.2647
# CV R² std : 0.1747
# CV scores : [0.149 0.374 0.161 0.084 0.554]
# Time taken for MERF cross validation: 61.1199s
# MERF Grouped cross validation starts
#   [Grouped CV 1/10] Fitting fold: ['Big Creek_5', 'Channel Caye_1', 'Channel Caye_4', 'New River_2', 'Turneffe Atoll_3'] ... R² = -0.0776
#   [Grouped CV 2/10] Fitting fold: ['Frenchman Caye_6', 'Gra Gra Lagoon_6', 'Hicks Caye_2', 'Hicks Caye_6', 'Turneffe Atoll_4'] ... R² = 0.2064
#   [Grouped CV 3/10] Fitting fold: ['Frenchman Caye_3', 'Gra Gra Lagoon_3', 'Hicks Caye_4', "Payne's Creek_3", 'Shipstern Lagoon_6'] ... R² = 0.2544
#   [Grouped CV 4/10] Fitting fold: ['Big Creek_3', 'Channel Caye_3', 'Channel Caye_5', 'New River_1', "Payne's Creek_2"] ... R² = -0.0489
#   [Grouped CV 5/10] Fitting fold: ['Frenchman Caye_1', 'Gra Gra Lagoon_5', 'Hicks Caye_3', 'New River_3', "Payne's Creek_6"] ... R² = 0.4632
#   [Grouped CV 6/10] Fitting fold: ['Big Creek_2', 'Drowned Caye_4', 'New River_6', "Payne's Creek_1", 'Shipstern Lagoon_2'] ... R² = 0.1931
#   [Grouped CV 7/10] Fitting fold: ['Drowned Caye_5', 'Drowned Caye_6', 'Frenchman Caye_2', 'Frenchman Caye_4'] ... R² = 0.4851
#   [Grouped CV 8/10] Fitting fold: ['Gra Gra Lagoon_4', 'Shipstern Lagoon_4', 'Shipstern Lagoon_5', 'Turneffe Atoll_6'] ... R² = 0.2563
#   [Grouped CV 9/10] Fitting fold: ['Channel Caye_2', 'Frenchman Caye_5', 'Hicks Caye_1', 'New River_5', "Payne's Creek_4"] ... R² = 0.2361
#   [Grouped CV 10/10] Fitting fold: ['Channel Caye_6', 'Drowned Caye_3', 'Gra Gra Lagoon_1', 'Turneffe Atoll_2'] ... R² = 0.2945
#
#  Grouped Cross-validation ---
# Grouped CV R² mean: 0.2263
# Grouped CV R² std : 0.1730
# Grouped CV scores : [-0.078  0.206  0.254 -0.049  0.463  0.193  0.485  0.256  0.236  0.295]
# Time taken for MERF Grouped cross validation: 61.1199s
#
#  MERF: EXPERIMENT-16 Plot groups. Grid search: NO, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²              : 0.0076
# Test RMSE            : 4.60 kg
# Train R² (log scale) : 0.4040
# Train R² (orig scale): 0.1658
# Train RMSE           : 16.96 kg
#
#  Cross-validation ---
# CV R² mean           : 0.2647
# CV R² std            : 0.1747
# CV scores            : [0.149 0.374 0.161 0.084 0.554]
# Num rows             : 3100
# Num groups           : 47
# ============================================================
#  EVALUATION: EXPERIMENT-16 Plot groups. Grid search: NO, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : 0.008
#   RMSE : 4.60 kg
#
#   ✅ Test R² is positive (0.008)
#
# Regular CrossValidation:
#   Mean   : 0.265
#   Std    : 0.175
#   Scores : [0.149 0.374 0.161 0.084 0.554]
#   ✅ CV mean is positive (0.265)
#
# Grouped CrossValidation:
#   Big Creek            :  -0.078  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.206  ✅
#   Frenchman Caye       :   0.254  ✅
#   Big Creek            :  -0.049  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.463  ✅
#   Big Creek            :   0.193  ✅
#   Drowned Caye         :   0.485  ✅
#   Gra Gra Lagoon       :   0.256  ✅
#   Channel Caye         :   0.236  ✅
#   Channel Caye         :   0.295  ✅
#
#   Mean : 0.226
#   Std  : 0.173
#
#   ✅ Grouped CV mean above 0.15 (0.226)
#   ✅ Grouped CV std below 0.25 (0.173)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.219 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.158 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ⚠️  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height_x_NDRE1                                0.3770  ==================
#   height                                        0.2718  =============
#   height_x_EVI                                  0.0837  ====
#   height_x_NIR                                  0.0617  ===
#   EVI                                           0.0517  ==
#   SWIR1                                         0.0422  ==
#   NBR                                           0.0396  =
#   NIR                                           0.0359  =
#   RE2                                           0.0200
#   RE1                                           0.0164
#
# [17/18]
#
#  MERF. EXPERIMENT-17 Plot groups. Grid search: NO, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2'].
# MERF model fitting starts
# MERF model fitting completed
# MERF cross validation starts
#
#  Cross-validation ---
# CV R² mean: 0.3196
# CV R² std : 0.1620
# CV scores : [0.151 0.463 0.306 0.137 0.54 ]
# Time taken for MERF cross validation: 62.7531s
# MERF Grouped cross validation starts
#   [Grouped CV 1/10] Fitting fold: ['Big Creek_5', 'Channel Caye_1', 'Channel Caye_4', 'New River_2', 'Turneffe Atoll_3'] ... R² = 0.1393
#   [Grouped CV 2/10] Fitting fold: ['Frenchman Caye_6', 'Gra Gra Lagoon_6', 'Hicks Caye_2', 'Hicks Caye_6', 'Turneffe Atoll_4'] ... R² = 0.3347
#   [Grouped CV 3/10] Fitting fold: ['Frenchman Caye_3', 'Gra Gra Lagoon_3', 'Hicks Caye_4', "Payne's Creek_3", 'Shipstern Lagoon_6'] ... R² = 0.3707
#   [Grouped CV 4/10] Fitting fold: ['Big Creek_3', 'Channel Caye_3', 'Channel Caye_5', 'New River_1', "Payne's Creek_2"] ... R² = -0.0407
#   [Grouped CV 5/10] Fitting fold: ['Frenchman Caye_1', 'Gra Gra Lagoon_5', 'Hicks Caye_3', 'New River_3', "Payne's Creek_6"] ... R² = 0.4972
#   [Grouped CV 6/10] Fitting fold: ['Big Creek_2', 'Drowned Caye_4', 'New River_6', "Payne's Creek_1", 'Shipstern Lagoon_2'] ... R² = 0.3238
#   [Grouped CV 7/10] Fitting fold: ['Drowned Caye_5', 'Drowned Caye_6', 'Frenchman Caye_2', 'Frenchman Caye_4'] ... R² = 0.5032
#   [Grouped CV 8/10] Fitting fold: ['Gra Gra Lagoon_4', 'Shipstern Lagoon_4', 'Shipstern Lagoon_5', 'Turneffe Atoll_6'] ... R² = 0.2048
#   [Grouped CV 9/10] Fitting fold: ['Channel Caye_2', 'Frenchman Caye_5', 'Hicks Caye_1', 'New River_5', "Payne's Creek_4"] ... R² = 0.3425
#   [Grouped CV 10/10] Fitting fold: ['Channel Caye_6', 'Drowned Caye_3', 'Gra Gra Lagoon_1', 'Turneffe Atoll_2'] ... R² = 0.3067
#
#  Grouped Cross-validation ---
# Grouped CV R² mean: 0.2982
# Grouped CV R² std : 0.1548
# Grouped CV scores : [ 0.139  0.335  0.371 -0.041  0.497  0.324  0.503  0.205  0.343  0.307]
# Time taken for MERF Grouped cross validation: 62.7531s
#
#  MERF: EXPERIMENT-17 Plot groups. Grid search: NO, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2'].
# Test R²              : -4.2410
# Test RMSE            : 10.57 kg
# Train R² (log scale) : 0.4666
# Train R² (orig scale): 0.1874
# Train RMSE           : 16.74 kg
#
#  Cross-validation ---
# CV R² mean           : 0.3196
# CV R² std            : 0.1620
# CV scores            : [0.151 0.463 0.306 0.137 0.54 ]
# Num rows             : 3100
# Num groups           : 47
# ============================================================
#  EVALUATION: EXPERIMENT-17 Plot groups. Grid search: NO, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2'].
# ============================================================
#
# Test set:
#   R²   : -4.241
#   RMSE : 10.57 kg
#
#   ❌ Test R² is negative (-4.241)
#
# Regular CrossValidation:
#   Mean   : 0.320
#   Std    : 0.162
#   Scores : [0.151 0.463 0.306 0.137 0.54 ]
#   ✅ CV mean is positive (0.320)
#
# Grouped CrossValidation:
#   Big Creek            :   0.139  ✅
#   Frenchman Caye       :   0.335  ✅
#   Frenchman Caye       :   0.371  ✅
#   Big Creek            :  -0.041  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.497  ✅
#   Big Creek            :   0.324  ✅
#   Drowned Caye         :   0.503  ✅
#   Gra Gra Lagoon       :   0.205  ✅
#   Channel Caye         :   0.343  ✅
#   Channel Caye         :   0.307  ✅
#
#   Mean : 0.298
#   Std  : 0.155
#
#   ✅ Grouped CV mean above 0.15 (0.298)
#   ✅ Grouped CV std below 0.25 (0.155)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 4.539 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 4.428 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height                                        0.6486  ================================
#   SWIR1                                         0.0558  ==
#   EVI                                           0.0557  ==
#   species_Avicennia germinans                   0.0513  ==
#   NIR                                           0.0404  ==
#   RE2                                           0.0377  =
#   NBR                                           0.0360  =
#   species_Rhizophora mangle                     0.0338  =
#   RE1                                           0.0301  =
#   species_Laguncularia racemosa                 0.0106
#
# [18/18]
#
#  MERF. EXPERIMENT-18 Plot groups. Grid search: NO, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# MERF model fitting starts
# MERF model fitting completed
# MERF cross validation starts
#
#  Cross-validation ---
# CV R² mean: 0.2928
# CV R² std : 0.1690
# CV scores : [0.144 0.45  0.196 0.134 0.54 ]
# Time taken for MERF cross validation: 62.9362s
# MERF Grouped cross validation starts
#   [Grouped CV 1/10] Fitting fold: ['Big Creek_5', 'Channel Caye_1', 'Channel Caye_4', 'New River_2', 'Turneffe Atoll_3'] ... R² = -0.0855
#   [Grouped CV 2/10] Fitting fold: ['Frenchman Caye_6', 'Gra Gra Lagoon_6', 'Hicks Caye_2', 'Hicks Caye_6', 'Turneffe Atoll_4'] ... R² = 0.3204
#   [Grouped CV 3/10] Fitting fold: ['Frenchman Caye_3', 'Gra Gra Lagoon_3', 'Hicks Caye_4', "Payne's Creek_3", 'Shipstern Lagoon_6'] ... R² = 0.3660
#   [Grouped CV 4/10] Fitting fold: ['Big Creek_3', 'Channel Caye_3', 'Channel Caye_5', 'New River_1', "Payne's Creek_2"] ... R² = -0.0353
#   [Grouped CV 5/10] Fitting fold: ['Frenchman Caye_1', 'Gra Gra Lagoon_5', 'Hicks Caye_3', 'New River_3', "Payne's Creek_6"] ... R² = 0.5060
#   [Grouped CV 6/10] Fitting fold: ['Big Creek_2', 'Drowned Caye_4', 'New River_6', "Payne's Creek_1", 'Shipstern Lagoon_2'] ... R² = 0.3318
#   [Grouped CV 7/10] Fitting fold: ['Drowned Caye_5', 'Drowned Caye_6', 'Frenchman Caye_2', 'Frenchman Caye_4'] ... R² = 0.5031
#   [Grouped CV 8/10] Fitting fold: ['Gra Gra Lagoon_4', 'Shipstern Lagoon_4', 'Shipstern Lagoon_5', 'Turneffe Atoll_6'] ... R² = 0.2116
#   [Grouped CV 9/10] Fitting fold: ['Channel Caye_2', 'Frenchman Caye_5', 'Hicks Caye_1', 'New River_5', "Payne's Creek_4"] ... R² = 0.3507
#   [Grouped CV 10/10] Fitting fold: ['Channel Caye_6', 'Drowned Caye_3', 'Gra Gra Lagoon_1', 'Turneffe Atoll_2'] ... R² = 0.3041
#
#  Grouped Cross-validation ---
# Grouped CV R² mean: 0.2773
# Grouped CV R² std : 0.1886
# Grouped CV scores : [-0.086  0.32   0.366 -0.035  0.506  0.332  0.503  0.212  0.351  0.304]
# Time taken for MERF Grouped cross validation: 62.9362s
#
#  MERF: EXPERIMENT-18 Plot groups. Grid search: NO, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²              : 0.0620
# Test RMSE            : 4.47 kg
# Train R² (log scale) : 0.4666
# Train R² (orig scale): 0.1874
# Train RMSE           : 16.74 kg
#
#  Cross-validation ---
# CV R² mean           : 0.2928
# CV R² std            : 0.1690
# CV scores            : [0.144 0.45  0.196 0.134 0.54 ]
# Num rows             : 3100
# Num groups           : 47
# ============================================================
#  EVALUATION: EXPERIMENT-18 Plot groups. Grid search: NO, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : 0.062
#   RMSE : 4.47 kg
#
#   ✅ Test R² is positive (0.062)
#
# Regular CrossValidation:
#   Mean   : 0.293
#   Std    : 0.169
#   Scores : [0.144 0.45  0.196 0.134 0.54 ]
#   ✅ CV mean is positive (0.293)
#
# Grouped CrossValidation:
#   Big Creek            :  -0.086  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.320  ✅
#   Frenchman Caye       :   0.366  ✅
#   Big Creek            :  -0.035  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.506  ✅
#   Big Creek            :   0.332  ✅
#   Drowned Caye         :   0.503  ✅
#   Gra Gra Lagoon       :   0.212  ✅
#   Channel Caye         :   0.351  ✅
#   Channel Caye         :   0.304  ✅
#
#   Mean : 0.277
#   Std  : 0.189
#
#   ✅ Grouped CV mean above 0.15 (0.277)
#   ✅ Grouped CV std below 0.25 (0.189)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.215 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.125 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ⚠️  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height_x_NDRE1                                0.2238  ===========
#   height                                        0.1922  =========
#   height_x_NIR                                  0.1693  ========
#   height_x_EVI                                  0.0976  ====
#   species_Avicennia germinans                   0.0485  ==
#   SWIR1                                         0.0482  ==
#   EVI                                           0.0450  ==
#   NBR                                           0.0394  =
#   NIR                                           0.0351  =
#   species_Rhizophora mangle                     0.0329  =
#
# Completed: 18/18 experiments
# Time taken for the experiment: 9856.4629s

# %%
# %run Model_functions.ipynb
tabulate_results(merf_belige_no_grid_grps, acceptable_only=True)
# Out:
# Showing 8 acceptable experiments
# <style type="text/css">
# #T_0e878_row0_col7, #T_0e878_row3_col8, #T_0e878_row4_col9, #T_0e878_row6_col1, #T_0e878_row6_col2 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_0e878">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0e878_level0_col0" class="col_heading level0 col0" >Experiment</th>
#       <th id="T_0e878_level0_col1" class="col_heading level0 col1" >Test R²</th>
#       <th id="T_0e878_level0_col2" class="col_heading level0 col2" >Test RMSE</th>
#       <th id="T_0e878_level0_col3" class="col_heading level0 col3" >Train R²</th>
#       <th id="T_0e878_level0_col4" class="col_heading level0 col4" >Train RMSE</th>
#       <th id="T_0e878_level0_col5" class="col_heading level0 col5" >CV R² Mean</th>
#       <th id="T_0e878_level0_col6" class="col_heading level0 col6" >CV R² Std</th>
#       <th id="T_0e878_level0_col7" class="col_heading level0 col7" >Group CV R² Mean</th>
#       <th id="T_0e878_level0_col8" class="col_heading level0 col8" >Group CV R² Std</th>
#       <th id="T_0e878_level0_col9" class="col_heading level0 col9" >CV-Test Gap</th>
#       <th id="T_0e878_level0_col10" class="col_heading level0 col10" >-ve Folds</th>
#       <th id="T_0e878_level0_col11" class="col_heading level0 col11" >verdict</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0e878_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0e878_row0_col0" class="data row0 col0" >EXPERIMENT-14 Plot groups. Grid search: NO, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].</td>
#       <td id="T_0e878_row0_col1" class="data row0 col1" >0.157</td>
#       <td id="T_0e878_row0_col2" class="data row0 col2" >4.24</td>
#       <td id="T_0e878_row0_col3" class="data row0 col3" >0.1874</td>
#       <td id="T_0e878_row0_col4" class="data row0 col4" >16.74</td>
#       <td id="T_0e878_row0_col5" class="data row0 col5" >0.296</td>
#       <td id="T_0e878_row0_col6" class="data row0 col6" >0.1704</td>
#       <td id="T_0e878_row0_col7" class="data row0 col7" >0.314</td>
#       <td id="T_0e878_row0_col8" class="data row0 col8" >0.2018</td>
#       <td id="T_0e878_row0_col9" class="data row0 col9" >0.157</td>
#       <td id="T_0e878_row0_col10" class="data row0 col10" >2 (Big Creek, Big Creek)</td>
#       <td id="T_0e878_row0_col11" class="data row0 col11" >⚠️  MARGINAL — positive metrics but concerns</td>
#     </tr>
#     <tr>
#       <th id="T_0e878_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0e878_row1_col0" class="data row1 col0" >EXPERIMENT-18 Plot groups. Grid search: NO, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].</td>
#       <td id="T_0e878_row1_col1" class="data row1 col1" >0.062</td>
#       <td id="T_0e878_row1_col2" class="data row1 col2" >4.47</td>
#       <td id="T_0e878_row1_col3" class="data row1 col3" >0.1874</td>
#       <td id="T_0e878_row1_col4" class="data row1 col4" >16.74</td>
#       <td id="T_0e878_row1_col5" class="data row1 col5" >0.2928</td>
#       <td id="T_0e878_row1_col6" class="data row1 col6" >0.169</td>
#       <td id="T_0e878_row1_col7" class="data row1 col7" >0.2773</td>
#       <td id="T_0e878_row1_col8" class="data row1 col8" >0.1886</td>
#       <td id="T_0e878_row1_col9" class="data row1 col9" >0.2153</td>
#       <td id="T_0e878_row1_col10" class="data row1 col10" >2 (Big Creek, Big Creek)</td>
#       <td id="T_0e878_row1_col11" class="data row1 col11" >⚠️  MARGINAL — positive metrics but concerns</td>
#     </tr>
#     <tr>
#       <th id="T_0e878_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0e878_row2_col0" class="data row2 col0" >EXPERIMENT-2 Plot groups. Grid search: NO, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].</td>
#       <td id="T_0e878_row2_col1" class="data row2 col1" >0.2153</td>
#       <td id="T_0e878_row2_col2" class="data row2 col2" >4.09</td>
#       <td id="T_0e878_row2_col3" class="data row2 col3" >0.1658</td>
#       <td id="T_0e878_row2_col4" class="data row2 col4" >16.96</td>
#       <td id="T_0e878_row2_col5" class="data row2 col5" >0.2424</td>
#       <td id="T_0e878_row2_col6" class="data row2 col6" >0.167</td>
#       <td id="T_0e878_row2_col7" class="data row2 col7" >0.2527</td>
#       <td id="T_0e878_row2_col8" class="data row2 col8" >0.2091</td>
#       <td id="T_0e878_row2_col9" class="data row2 col9" >0.0374</td>
#       <td id="T_0e878_row2_col10" class="data row2 col10" >2 (Big Creek, Big Creek)</td>
#       <td id="T_0e878_row2_col11" class="data row2 col11" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_0e878_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0e878_row3_col0" class="data row3 col0" >EXPERIMENT-16 Plot groups. Grid search: NO, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].</td>
#       <td id="T_0e878_row3_col1" class="data row3 col1" >0.0076</td>
#       <td id="T_0e878_row3_col2" class="data row3 col2" >4.6</td>
#       <td id="T_0e878_row3_col3" class="data row3 col3" >0.1658</td>
#       <td id="T_0e878_row3_col4" class="data row3 col4" >16.96</td>
#       <td id="T_0e878_row3_col5" class="data row3 col5" >0.2647</td>
#       <td id="T_0e878_row3_col6" class="data row3 col6" >0.1747</td>
#       <td id="T_0e878_row3_col7" class="data row3 col7" >0.2263</td>
#       <td id="T_0e878_row3_col8" class="data row3 col8" >0.173</td>
#       <td id="T_0e878_row3_col9" class="data row3 col9" >0.2187</td>
#       <td id="T_0e878_row3_col10" class="data row3 col10" >2 (Big Creek, Big Creek)</td>
#       <td id="T_0e878_row3_col11" class="data row3 col11" >⚠️  MARGINAL — positive metrics but concerns</td>
#     </tr>
#     <tr>
#       <th id="T_0e878_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0e878_row4_col0" class="data row4 col0" >EXPERIMENT-4 Plot groups. Grid search: NO, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].</td>
#       <td id="T_0e878_row4_col1" class="data row4 col1" >0.261</td>
#       <td id="T_0e878_row4_col2" class="data row4 col2" >3.97</td>
#       <td id="T_0e878_row4_col3" class="data row4 col3" >0.1658</td>
#       <td id="T_0e878_row4_col4" class="data row4 col4" >16.96</td>
#       <td id="T_0e878_row4_col5" class="data row4 col5" >0.2467</td>
#       <td id="T_0e878_row4_col6" class="data row4 col6" >0.1776</td>
#       <td id="T_0e878_row4_col7" class="data row4 col7" >0.2249</td>
#       <td id="T_0e878_row4_col8" class="data row4 col8" >0.1843</td>
#       <td id="T_0e878_row4_col9" class="data row4 col9" >0.0362</td>
#       <td id="T_0e878_row4_col10" class="data row4 col10" >2 (Big Creek, Big Creek)</td>
#       <td id="T_0e878_row4_col11" class="data row4 col11" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_0e878_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0e878_row5_col0" class="data row5 col0" >EXPERIMENT-6 Plot groups. Grid search: NO, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].</td>
#       <td id="T_0e878_row5_col1" class="data row5 col1" >0.0558</td>
#       <td id="T_0e878_row5_col2" class="data row5 col2" >4.48</td>
#       <td id="T_0e878_row5_col3" class="data row5 col3" >0.1658</td>
#       <td id="T_0e878_row5_col4" class="data row5 col4" >16.96</td>
#       <td id="T_0e878_row5_col5" class="data row5 col5" >0.2244</td>
#       <td id="T_0e878_row5_col6" class="data row5 col6" >0.1648</td>
#       <td id="T_0e878_row5_col7" class="data row5 col7" >-0.0993</td>
#       <td id="T_0e878_row5_col8" class="data row5 col8" >1.169</td>
#       <td id="T_0e878_row5_col9" class="data row5 col9" >0.1551</td>
#       <td id="T_0e878_row5_col10" class="data row5 col10" >3 (Big Creek, Frenchman Caye, Big Creek)</td>
#       <td id="T_0e878_row5_col11" class="data row5 col11" >⚠️  MARGINAL — pos

# %% [markdown]
# MERF Exp 2 passes all checks but is weaker than plain RF Exp 18 on both metrics. The features are different though — Exp 2 uses only height + interactions while RF Exp 18 uses species + height + spectral + interactions.
#
# MERF Exp 2 is a valid model but does not beat plain RF. The height+interactions feature set works for MERF specifically because it avoids the height-dominance trap.

# %% [markdown]
# ### BELIGE DATA. PLOT GROUPS. ALL ROWS. MERF (Hyper parameter tuning: Yes)

# %%
# %run Model_functions.ipynb

merf_belige_grid_grps = {}

run_experiment(X_belige, y_belige,
               is_groups=True, group_info=grp_belige,
               features_list=gen_features_list,
               experiments=merf_belige_no_grid_grps,
               model_type="merf", is_grid=True,
               is_stratified=is_stratified_g,
               global_experiment_list=global_experiment_list)
# Out:
# [1/18]
# Grid search over MERF base RF params:
#   n_estimators=500, max_depth=None, min_samples_leaf=2 → Train R² (log)=0.4040
#   n_estimators=500, max_depth=10, min_samples_leaf=2 → Train R² (log)=0.4040
#   n_estimators=200, max_depth=5, min_samples_leaf=4 → Train R² (log)=0.3996
#   n_estimators=100, max_depth=5, min_samples_leaf=8 → Train R² (log)=0.3983
#   Best train R² (log): 0.4040
#
#  MERF. EXPERIMENT-1 Plot groups. Grid search: Yes, Features: ['height'].
# MERF model fitting starts
# MERF model fitting completed
# MERF cross validation starts
#
#  Cross-validation ---
# CV R² mean: -0.0123
# CV R² std : 0.3550
# CV scores : [ 0.137  0.381  0.291 -0.477 -0.394]
# Time taken for MERF cross validation: 60.1773s
# MERF Grouped cross validation starts
#   [Grouped CV 1/10] Fitting fold: ['Big Creek_5', 'Channel Caye_1', 'Channel Caye_4', 'New River_2', 'Turneffe Atoll_3'] ... R² = 0.0659
#   [Grouped CV 2/10] Fitting fold: ['Frenchman Caye_6', 'Gra Gra Lagoon_6', 'Hicks Caye_2', 'Hicks Caye_6', 'Turneffe Atoll_4'] ... R² = -0.3600
#   [Grouped CV 3/10] Fitting fold: ['Frenchman Caye_3', 'Gra Gra Lagoon_3', 'Hicks Caye_4', "Payne's Creek_3", 'Shipstern Lagoon_6'] ... R² = 0.2510
#   [Grouped CV 4/10] Fitting fold: ['Big Creek_3', 'Channel Caye_3', 'Channel Caye_5', 'New River_1', "Payne's Creek_2"] ... R² = -0.1641
#   [Grouped CV 5/10] Fitting fold: ['Frenchman Caye_1', 'Gra Gra Lagoon_5', 'Hicks Caye_3', 'New River_3', "Payne's Creek_6"] ... R² = 0.4481
#   [Grouped CV 6/10] Fitting fold: ['Big Creek_2', 'Drowned Caye_4', 'New River_6', "Payne's Creek_1", 'Shipstern Lagoon_2'] ... R² = 0.5689
#   [Grouped CV 7/10] Fitting fold: ['Drowned Caye_5', 'Drowned Caye_6', 'Frenchman Caye_2', 'Frenchman Caye_4'] ... R² = 0.4851
#   [Grouped CV 8/10] Fitting fold: ['Gra Gra Lagoon_4', 'Shipstern Lagoon_4', 'Shipstern Lagoon_5', 'Turneffe Atoll_6'] ... R² = 0.2857
#   [Grouped CV 9/10] Fitting fold: ['Channel Caye_2', 'Frenchman Caye_5', 'Hicks Caye_1', 'New River_5', "Payne's Creek_4"] ... R² = 0.1123
#   [Grouped CV 10/10] Fitting fold: ['Channel Caye_6', 'Drowned Caye_3', 'Gra Gra Lagoon_1', 'Turneffe Atoll_2'] ... R² = 0.3191
#
#  Grouped Cross-validation ---
# Grouped CV R² mean: 0.2012
# Grouped CV R² std : 0.2784
# Grouped CV scores : [ 0.066 -0.36   0.251 -0.164  0.448  0.569  0.485  0.286  0.112  0.319]
# Time taken for MERF Grouped cross validation: 60.1773s
#
#  MERF: EXPERIMENT-1 Plot groups. Grid search: Yes, Features: ['height'].
# Test R²              : 0.1277
# Test RMSE            : 4.31 kg
# Train R² (log scale) : 0.4040
# Train R² (orig scale): 0.1658
# Train RMSE           : 16.96 kg
#
#  Cross-validation ---
# CV R² mean           : -0.0123
# CV R² std            : 0.3550
# CV scores            : [ 0.137  0.381  0.291 -0.477 -0.394]
# Num rows             : 3100
# Num groups           : 47
# ============================================================
#  EVALUATION: EXPERIMENT-1 Plot groups. Grid search: Yes, Features: ['height'].
# ============================================================
#
# Test set:
#   R²   : 0.128
#   RMSE : 4.31 kg
#
#   ✅ Test R² is positive (0.128)
#
# Regular CrossValidation:
#   Mean   : -0.012
#   Std    : 0.355
#   Scores : [ 0.137  0.381  0.291 -0.477 -0.394]
#   ❌ CV mean is negative (-0.012)
#
# Grouped CrossValidation:
#   Big Creek            :   0.066  ✅
#   Frenchman Caye       :  -0.360  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.251  ✅
#   Big Creek            :  -0.164  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.448  ✅
#   Big Creek            :   0.569  ✅
#   Drowned Caye         :   0.485  ✅
#   Gra Gra Lagoon       :   0.286  ✅
#   Channel Caye         :   0.112  ✅
#   Channel Caye         :   0.319  ✅
#
#   Mean : 0.201
#   Std  : 0.278
#
#   ✅ Grouped CV mean above 0.15 (0.201)
#   ⚠️  Grouped CV std above 0.25 (0.278) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.074 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: 0.038)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height                                        1.0000  ==================================================
#
# [2/18]
# Grid search over MERF base RF params:
#   n_estimators=500, max_depth=None, min_samples_leaf=2 → Train R² (log)=0.4040
#   n_estimators=500, max_depth=10, min_samples_leaf=2 → Train R² (log)=0.4040
#   n_estimators=200, max_depth=5, min_samples_leaf=4 → Train R² (log)=0.4005
#   n_estimators=100, max_depth=5, min_samples_leaf=8 → Train R² (log)=0.3996
#   Best train R² (log): 0.4040
#
#  MERF. EXPERIMENT-2 Plot groups. Grid search: Yes, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# MERF model fitting starts
# MERF model fitting completed
# MERF cross validation starts
#
#  Cross-validation ---
# CV R² mean: 0.2428
# CV R² std : 0.1679
# CV scores : [0.134 0.371 0.158 0.048 0.503]
# Time taken for MERF cross validation: 60.6219s
# MERF Grouped cross validation starts
#   [Grouped CV 1/10] Fitting fold: ['Big Creek_5', 'Channel Caye_1', 'Channel Caye_4', 'New River_2', 'Turneffe Atoll_3'] ... R² = -0.0821
#   [Grouped CV 2/10] Fitting fold: ['Frenchman Caye_6', 'Gra Gra Lagoon_6', 'Hicks Caye_2', 'Hicks Caye_6', 'Turneffe Atoll_4'] ... R² = 0.1023
#   [Grouped CV 3/10] Fitting fold: ['Frenchman Caye_3', 'Gra Gra Lagoon_3', 'Hicks Caye_4', "Payne's Creek_3", 'Shipstern Lagoon_6'] ... R² = 0.2498
#   [Grouped CV 4/10] Fitting fold: ['Big Creek_3', 'Channel Caye_3', 'Channel Caye_5', 'New River_1', "Payne's Creek_2"] ... R² = -0.0683
#   [Grouped CV 5/10] Fitting fold: ['Frenchman Caye_1', 'Gra Gra Lagoon_5', 'Hicks Caye_3', 'New River_3', "Payne's Creek_6"] ... R² = 0.4695
#   [Grouped CV 6/10] Fitting fold: ['Big Creek_2', 'Drowned Caye_4', 'New River_6', "Payne's Creek_1", 'Shipstern Lagoon_2'] ... R² = 0.5576
#   [Grouped CV 7/10] Fitting fold: ['Drowned Caye_5', 'Drowned Caye_6', 'Frenchman Caye_2', 'Frenchman Caye_4'] ... R² = 0.4851
#   [Grouped CV 8/10] Fitting fold: ['Gra Gra Lagoon_4', 'Shipstern Lagoon_4', 'Shipstern Lagoon_5', 'Turneffe Atoll_6'] ... R² = 0.2841
#   [Grouped CV 9/10] Fitting fold: ['Channel Caye_2', 'Frenchman Caye_5', 'Hicks Caye_1', 'New River_5', "Payne's Creek_4"] ... R² = 0.2480
#   [Grouped CV 10/10] Fitting fold: ['Channel Caye_6', 'Drowned Caye_3', 'Gra Gra Lagoon_1', 'Turneffe Atoll_2'] ... R² = 0.2859
#
#  Grouped Cross-validation ---
# Grouped CV R² mean: 0.2532
# Grouped CV R² std : 0.2083
# Grouped CV scores : [-0.082  0.102  0.25  -0.068  0.47   0.558  0.485  0.284  0.248  0.286]
# Time taken for MERF Grouped cross validation: 60.6219s
#
#  MERF: EXPERIMENT-2 Plot groups. Grid search: Yes, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²              : 0.2110
# Test RMSE            : 4.10 kg
# Train R² (log scale) : 0.4040
# Train R² (orig scale): 0.1658
# Train RMSE           : 16.96 kg
#
#  Cross-validation ---
# CV R² mean           : 0.2428
# CV R² std            : 0.1679
# CV scores            : [0.134 0.371 0.158 0.048 0.503]
# Num rows             : 3100
# Num groups           : 47
# ============================================================
#  EVALUATION: EXPERIMENT-2 Plot groups. Grid search: Yes, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : 0.211
#   RMSE : 4.10 kg
#
#   ✅ Test R² is positive (0.211)
#
# Regular CrossValidation:
#   Mean   : 0.243
#   Std    : 0.168
#   Scores : [0.134 0.371 0.158 0.048 0.503]
#   ✅ CV mean is positive (0.243)
#
# Grouped CrossValidation:
#   Big Creek            :  -0.082  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.102  ✅
#   Frenchman Caye       :   0.250  ✅
#   Big Creek            :  -0.068  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.470  ✅
#   Big Creek            :   0.558  ✅
#   Drowned Caye         :   0.485  ✅
#   Gra Gra Lagoon       :   0.284  ✅
#   Channel Caye         :   0.248  ✅
#   Channel Caye         :   0.286  ✅
#
#   Mean : 0.253
#   Std  : 0.208
#
#   ✅ Grouped CV mean above 0.15 (0.253)
#   ✅ Grouped CV std below 0.25 (0.208)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ✅ Grouped CV and test R² agree (gap: 0.042)
#   ✅ Train/test R² gap acceptable (gap: -0.045)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ✅ ACCEPTABLE
#
# Top 10 feature importances:
#   height_x_NDRE1                                0.3824  ===================
#   height                                        0.2520  ============
#   height_x_NIR                                  0.2146  ==========
#   height_x_EVI                                  0.1511  =======
#
# [3/18]
# Grid search over MERF base RF params:
#   n_estimators=500, max_depth=None, min_samples_leaf=2 → Train R² (log)=0.4040
#   n_estimators=500, max_depth=10, min_samples_leaf=2 → Train R² (log)=0.4040
#   n_estimators=200, max_depth=5, min_samples_leaf=4 → Train R² (log)=0.4016
#   n_estimators=100, max_depth=5, min_samples_leaf=8 → Train R² (log)=0.4014
#   Best train R² (log): 0.4040
#
#  MERF. EXPERIMENT-3 Plot groups. Grid search: Yes, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2'].
# MERF model fitting starts
# MERF model fitting completed
# MERF cross validation starts
#
#  Cross-validation ---
# CV R² mean: 0.0115
# CV R² std : 0.4479
# CV scores : [ 0.042 -0.808  0.18   0.086  0.556]
# Time taken for MERF cross validation: 61.5768s
# MERF Grouped cross validation starts
#   [Grouped CV 1/10] Fitting fold: ['Big Creek_5', 'Channel Caye_1', 'Channel Caye_4', 'New River_2', 'Turneffe Atoll_3'] ... R² = -0.2762
#   [Grouped CV 2/10] Fitting fold: ['Frenchman Caye_6', 'Gra Gra Lagoon_6', 'Hicks Caye_2', 'Hicks Caye_6', 'Turneffe Atoll_4'] ... R² = -2.5932
#   [Grouped CV 3/10] Fitting fold: ['Frenchman Caye_3', 'Gra Gra Lagoon_3', 'Hicks Caye_4', "Payne's Creek_3", 'Shipstern Lagoon_6'] ... R² = 0.2300
#   [Grouped CV 4/10] Fitting fold: ['Big Creek_3', 'Channel Caye_3', 'Channel Caye_5', 'New River_1', "Payne's Creek_2"] ... R² = -0.0392
#   [Grouped CV 5/10] Fitting fold: ['Frenchman Caye_1', 'Gra Gra Lagoon_5', 'Hicks Caye_3', 'New River_3', "Payne's Creek_6"] ... R² = 0.3317
#   [Grouped CV 6/10] Fitting fold: ['Big Creek_2', 'Drowned Caye_4', 'New River_6', "Payne's Creek_1", 'Shipstern Lagoon_2'] ... R² = 0.3302
#   [Grouped CV 7/10] Fitting fold: ['Drowned Caye_5', 'Drowned Caye_6', 'Frenchman Caye_2', 'Frenchman Caye_4'] ... R² = 0.5135
#   [Grouped CV 8/10] Fitting fold: ['Gra Gra Lagoon_4', 'Shipstern Lagoon_4', 'Shipstern Lagoon_5', 'Turneffe Atoll_6'] ... R² = 0.2675
#   [Grouped CV 9/10] Fitting fold: ['Channel Caye_2', 'Frenchman Caye_5', 'Hicks Caye_1', 'New River_5', "Payne's Creek_4"] ... R² = 0.2104
#   [Grouped CV 10/10] Fitting fold: ['Channel Caye_6', 'Drowned Caye_3', 'Gra Gra Lagoon_1', 'Turneffe Atoll_2'] ... R² = -0.2788
#
#  Grouped Cross-validation ---
# Grouped CV R² mean: -0.1304
# Grouped CV R² std : 0.8580
# Grouped CV scores : [-0.276 -2.593  0.23  -0.039  0.332  0.33   0.513  0.268  0.21  -0.279]
# Time taken for MERF Grouped cross validation: 61.5768s
#
#  MERF: EXPERIMENT-3 Plot groups. Grid search: Yes, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2'].
# Test R²              : 0.2691
# Test RMSE            : 3.95 kg
# Train R² (log scale) : 0.4040
# Train R² (orig scale): 0.1657
# Train RMSE           : 16.96 kg
#
#  Cross-validation ---
# CV R² mean           : 0.0115
# CV R² std            : 0.4479
# CV scores            : [ 0.042 -0.808  0.18   0.086  0.556]
# Num rows             : 3100
# Num groups           : 47
# ============================================================
#  EVALUATION: EXPERIMENT-3 Plot groups. Grid search: Yes, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2'].
# ============================================================
#
# Test set:
#   R²   : 0.269
#   RMSE : 3.95 kg
#
#   ✅ Test R² is positive (0.269)
#
# Regular CrossValidation:
#   Mean   : 0.012
#   Std    : 0.448
#   Scores : [ 0.042 -0.808  0.18   0.086  0.556]
#   ✅ CV mean is positive (0.012)
#
# Grouped CrossValidation:
#   Big Creek            :  -0.276  ⚠️  near-zero variance artifact
#   Frenchman Caye       :  -2.593  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.230  ✅
#   Big Creek            :  -0.039  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.332  ✅
#   Big Creek            :   0.330  ✅
#   Drowned Caye         :   0.513  ✅
#   Gra Gra Lagoon       :   0.268  ✅
#   Channel Caye         :   0.210  ✅
#   Channel Caye         :  -0.279  ❌ negative — cause unknown
#
#   Mean : -0.130
#   Std  : 0.858
#
#   ❌ Grouped CV mean below 0.15 (-0.130)
#   ⚠️  Grouped CV std above 0.25 (0.858) — high variance across folds
#   ❌ Unexplained negative folds: ['Channel Caye']
#   ❌ High-AGB sites failed: ['Channel Caye']
#   ⚠️  Grouped CV and test R² diverge (gap: 0.400 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.103)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ⚠️  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   NIR                                           0.1851  =========
#   RE3                                           0.1611  ========
#   RE2                                           0.1424  =======
#   RE1                                           0.1321  ======
#   Red                                           0.0949  ====
#   Blue                                          0.0791  ===
#   Green                                         0.0761  ===
#   SWIR1                                         0.0686  ===
#   SWIR2                                         0.0606  ===
#
# [4/18]
# Grid search over MERF base RF params:
#   n_estimators=500, max_depth=None, min_samples_leaf=2 → Train R² (log)=0.4040
#   n_estimators=500, max_depth=10, min_samples_leaf=2 → Train R² (log)=0.4040
#   n_estimators=200, max_depth=5, min_samples_leaf=4 → Train R² (log)=0.4001
#   n_estimators=100, max_depth=5, min_samples_leaf=8 → Train R² (log)=0.3998
#   Best train R² (log): 0.4040
#
#  MERF. EXPERIMENT-4 Plot groups. Grid search: Yes, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# MERF model fitting starts
# MERF model fitting completed
# MERF cross validation starts
#
#  Cross-validation ---
# CV R² mean: 0.2460
# CV R² std : 0.1769
# CV scores : [0.108 0.337 0.155 0.079 0.551]
# Time taken for MERF cross validation: 61.9079s
# MERF Grouped cross validation starts
#   [Grouped CV 1/10] Fitting fold: ['Big Creek_5', 'Channel Caye_1', 'Channel Caye_4', 'New River_2', 'Turneffe Atoll_3'] ... R² = -0.1292
#   [Grouped CV 2/10] Fitting fold: ['Frenchman Caye_6', 'Gra Gra Lagoon_6', 'Hicks Caye_2', 'Hicks Caye_6', 'Turneffe Atoll_4'] ... R² = 0.1566
#   [Grouped CV 3/10] Fitting fold: ['Frenchman Caye_3', 'Gra Gra Lagoon_3', 'Hicks Caye_4', "Payne's Creek_3", 'Shipstern Lagoon_6'] ... R² = 0.2469
#   [Grouped CV 4/10] Fitting fold: ['Big Creek_3', 'Channel Caye_3', 'Channel Caye_5', 'New River_1', "Payne's Creek_2"] ... R² = -0.0354
#   [Grouped CV 5/10] Fitting fold: ['Frenchman Caye_1', 'Gra Gra Lagoon_5', 'Hicks Caye_3', 'New River_3', "Payne's Creek_6"] ... R² = 0.4564
#   [Grouped CV 6/10] Fitting fold: ['Big Creek_2', 'Drowned Caye_4', 'New River_6', "Payne's Creek_1", 'Shipstern Lagoon_2'] ... R² = 0.2790
#   [Grouped CV 7/10] Fitting fold: ['Drowned Caye_5', 'Drowned Caye_6', 'Frenchman Caye_2', 'Frenchman Caye_4'] ... R² = 0.4856
#   [Grouped CV 8/10] Fitting fold: ['Gra Gra Lagoon_4', 'Shipstern Lagoon_4', 'Shipstern Lagoon_5', 'Turneffe Atoll_6'] ... R² = 0.2630
#   [Grouped CV 9/10] Fitting fold: ['Channel Caye_2', 'Frenchman Caye_5', 'Hicks Caye_1', 'New River_5', "Payne's Creek_4"] ... R² = 0.2347
#   [Grouped CV 10/10] Fitting fold: ['Channel Caye_6', 'Drowned Caye_3', 'Gra Gra Lagoon_1', 'Turneffe Atoll_2'] ... R² = 0.3029
#
#  Grouped Cross-validation ---
# Grouped CV R² mean: 0.2261
# Grouped CV R² std : 0.1818
# Grouped CV scores : [-0.129  0.157  0.247 -0.035  0.456  0.279  0.486  0.263  0.235  0.303]
# Time taken for MERF Grouped cross validation: 61.9079s
#
#  MERF: EXPERIMENT-4 Plot groups. Grid search: Yes, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²              : 0.2610
# Test RMSE            : 3.97 kg
# Train R² (log scale) : 0.4040
# Train R² (orig scale): 0.1658
# Train RMSE           : 16.96 kg
#
#  Cross-validation ---
# CV R² mean           : 0.2460
# CV R² std            : 0.1769
# CV scores            : [0.108 0.337 0.155 0.079 0.551]
# Num rows             : 3100
# Num groups           : 47
# ============================================================
#  EVALUATION: EXPERIMENT-4 Plot groups. Grid search: Yes, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : 0.261
#   RMSE : 3.97 kg
#
#   ✅ Test R² is positive (0.261)
#
# Regular CrossValidation:
#   Mean   : 0.246
#   Std    : 0.177
#   Scores : [0.108 0.337 0.155 0.079 0.551]
#   ✅ CV mean is positive (0.246)
#
# Grouped CrossValidation:
#   Big Creek            :  -0.129  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.157  ✅
#   Frenchman Caye       :   0.247  ✅
#   Big Creek            :  -0.035  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.456  ✅
#   Big Creek            :   0.279  ✅
#   Drowned Caye         :   0.486  ✅
#   Gra Gra Lagoon       :   0.263  ✅
#   Channel Caye         :   0.235  ✅
#   Channel Caye         :   0.303  ✅
#
#   Mean : 0.226
#   Std  : 0.182
#
#   ✅ Grouped CV mean above 0.15 (0.226)
#   ✅ Grouped CV std below 0.25 (0.182)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ✅ Grouped CV and test R² agree (gap: 0.035)
#   ✅ Train/test R² gap acceptable (gap: -0.095)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ✅ ACCEPTABLE
#
# Top 10 feature importances:
#   height_x_NDRE1                                0.4099  ====================
#   height_x_NIR                                  0.1952  =========
#   height_x_EVI                                  0.1735  ========
#   NIR                                           0.0369  =
#   RE3                                           0.0329  =
#   SWIR1                                         0.0329  =
#   SWIR2                                         0.0297  =
#   Green                                         0.0268  =
#   Red                                           0.0175
#   RE2                                           0.0169
#
# [5/18]
# Grid search over MERF base RF params:
#   n_estimators=500, max_depth=None, min_samples_leaf=2 → Train R² (log)=0.4040
#   n_estimators=500, max_depth=10, min_samples_leaf=2 → Train R² (log)=0.4040
#   n_estimators=200, max_depth=5, min_samples_leaf=4 → Train R² (log)=0.3997
#   n_estimators=100, max_depth=5, min_samples_leaf=8 → Train R² (log)=0.3996
#   Best train R² (log): 0.4040
#
#  MERF. EXPERIMENT-5 Plot groups. Grid search: Yes, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# MERF model fitting starts
# MERF model fitting completed
# MERF cross validation starts
#
#  Cross-validation ---
# CV R² mean: -0.0218
# CV R² std : 0.3787
# CV scores : [ 0.152 -0.764  0.156  0.054  0.293]
# Time taken for MERF cross validation: 61.0295s
# MERF Grouped cross validation starts
#   [Grouped CV 1/10] Fitting fold: ['Big Creek_5', 'Channel Caye_1', 'Channel Caye_4', 'New River_2', 'Turneffe Atoll_3'] ... R² = -0.0978
#   [Grouped CV 2/10] Fitting fold: ['Frenchman Caye_6', 'Gra Gra Lagoon_6', 'Hicks Caye_2', 'Hicks Caye_6', 'Turneffe Atoll_4'] ... R² = -6.6295
#   [Grouped CV 3/10] Fitting fold: ['Frenchman Caye_3', 'Gra Gra Lagoon_3', 'Hicks Caye_4', "Payne's Creek_3", 'Shipstern Lagoon_6'] ... R² = 0.2359
#   [Grouped CV 4/10] Fitting fold: ['Big Creek_3', 'Channel Caye_3', 'Channel Caye_5', 'New River_1', "Payne's Creek_2"] ... R² = -0.1003
#   [Grouped CV 5/10] Fitting fold: ['Frenchman Caye_1', 'Gra Gra Lagoon_5', 'Hicks Caye_3', 'New River_3', "Payne's Creek_6"] ... R² = 0.4932
#   [Grouped CV 6/10] Fitting fold: ['Big Creek_2', 'Drowned Caye_4', 'New River_6', "Payne's Creek_1", 'Shipstern Lagoon_2'] ... R² = 0.5691
#   [Grouped CV 7/10] Fitting fold: ['Drowned Caye_5', 'Drowned Caye_6', 'Frenchman Caye_2', 'Frenchman Caye_4'] ... R² = 0.2345
#   [Grouped CV 8/10] Fitting fold: ['Gra Gra Lagoon_4', 'Shipstern Lagoon_4', 'Shipstern Lagoon_5', 'Turneffe Atoll_6'] ... R² = 0.2006
#   [Grouped CV 9/10] Fitting fold: ['Channel Caye_2', 'Frenchman Caye_5', 'Hicks Caye_1', 'New River_5', "Payne's Creek_4"] ... R² = 0.1770
#   [Grouped CV 10/10] Fitting fold: ['Channel Caye_6', 'Drowned Caye_3', 'Gra Gra Lagoon_1', 'Turneffe Atoll_2'] ... R² = 0.2267
#
#  Grouped Cross-validation ---
# Grouped CV R² mean: -0.4691
# Grouped CV R² std : 2.0633
# Grouped CV scores : [-0.098 -6.63   0.236 -0.1    0.493  0.569  0.235  0.201  0.177  0.227]
# Time taken for MERF Grouped cross validation: 61.0295s
#
#  MERF: EXPERIMENT-5 Plot groups. Grid search: Yes, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# Test R²              : -0.0249
# Test RMSE            : 4.67 kg
# Train R² (log scale) : 0.4040
# Train R² (orig scale): 0.1658
# Train RMSE           : 16.96 kg
#
#  Cross-validation ---
# CV R² mean           : -0.0218
# CV R² std            : 0.3787
# CV scores            : [ 0.152 -0.764  0.156  0.054  0.293]
# Num rows             : 3100
# Num groups           : 47
# ============================================================
#  EVALUATION: EXPERIMENT-5 Plot groups. Grid search: Yes, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# ============================================================
#
# Test set:
#   R²   : -0.025
#   RMSE : 4.67 kg
#
#   ❌ Test R² is negative (-0.025)
#
# Regular CrossValidation:
#   Mean   : -0.022
#   Std    : 0.379
#   Scores : [ 0.152 -0.764  0.156  0.054  0.293]
#   ❌ CV mean is negative (-0.022)
#
# Grouped CrossValidation:
#   Big Creek            :  -0.098  ⚠️  near-zero variance artifact
#   Frenchman Caye       :  -6.630  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.236  ✅
#   Big Creek            :  -0.100  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.493  ✅
#   Big Creek            :   0.569  ✅
#   Drowned Caye         :   0.235  ✅
#   Gra Gra Lagoon       :   0.201  ✅
#   Channel Caye         :   0.177  ✅
#   Channel Caye         :   0.227  ✅
#
#   Mean : -0.469
#   Std  : 2.063
#
#   ❌ Grouped CV mean below 0.15 (-0.469)
#   ⚠️  Grouped CV std above 0.25 (2.063) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.444 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.191 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   NDRE1                                         0.3922  ===================
#   EVI                                           0.3373  ================
#   NBR                                           0.0925  ====
#   NDRE2                                         0.0572  ==
#   CIrededge                                     0.0462  ==
#   NDRE3                                         0.0341  =
#   MNDWI                                         0.0276  =
#   NDVI                                          0.0129
#   CLOUD_COVERAGE                                0.0000
#
# [6/18]
# Grid search over MERF base RF params:
#   n_estimators=500, max_depth=None, min_samples_leaf=2 → Train R² (log)=0.4040
#   n_estimators=500, max_depth=10, min_samples_leaf=2 → Train R² (log)=0.4040
#   n_estimators=200, max_depth=5, min_samples_leaf=4 → Train R² (log)=0.4003
#   n_estimators=100, max_depth=5, min_samples_leaf=8 → Train R² (log)=0.4002
#   Best train R² (log): 0.4040
#
#  MERF. EXPERIMENT-6 Plot groups. Grid search: Yes, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# MERF model fitting starts
# MERF model fitting completed
# MERF cross validation starts
#
#  Cross-validation ---
# CV R² mean: 0.2153
# CV R² std : 0.1696
# CV scores : [0.126 0.156 0.183 0.066 0.546]
# Time taken for MERF cross validation: 61.4079s
# MERF Grouped cross validation starts
#   [Grouped CV 1/10] Fitting fold: ['Big Creek_5', 'Channel Caye_1', 'Channel Caye_4', 'New River_2', 'Turneffe Atoll_3'] ... R² = -0.0817
#   [Grouped CV 2/10] Fitting fold: ['Frenchman Caye_6', 'Gra Gra Lagoon_6', 'Hicks Caye_2', 'Hicks Caye_6', 'Turneffe Atoll_4'] ... R² = 0.0994
#   [Grouped CV 3/10] Fitting fold: ['Frenchman Caye_3', 'Gra Gra Lagoon_3', 'Hicks Caye_4', "Payne's Creek_3", 'Shipstern Lagoon_6'] ... R² = 0.2598
#   [Grouped CV 4/10] Fitting fold: ['Big Creek_3', 'Channel Caye_3', 'Channel Caye_5', 'New River_1', "Payne's Creek_2"] ... R² = -0.0766
#   [Grouped CV 5/10] Fitting fold: ['Frenchman Caye_1', 'Gra Gra Lagoon_5', 'Hicks Caye_3', 'New River_3', "Payne's Creek_6"] ... R² = 0.4940
#   [Grouped CV 6/10] Fitting fold: ['Big Creek_2', 'Drowned Caye_4', 'New River_6', "Payne's Creek_1", 'Shipstern Lagoon_2'] ... R² = 0.5848
#   [Grouped CV 7/10] Fitting fold: ['Drowned Caye_5', 'Drowned Caye_6', 'Frenchman Caye_2', 'Frenchman Caye_4'] ... R² = 0.5801
#   [Grouped CV 8/10] Fitting fold: ['Gra Gra Lagoon_4', 'Shipstern Lagoon_4', 'Shipstern Lagoon_5', 'Turneffe Atoll_6'] ... R² = 0.2501
#   [Grouped CV 9/10] Fitting fold: ['Channel Caye_2', 'Frenchman Caye_5', 'Hicks Caye_1', 'New River_5', "Payne's Creek_4"] ... R² = 0.2057
#   [Grouped CV 10/10] Fitting fold: ['Channel Caye_6', 'Drowned Caye_3', 'Gra Gra Lagoon_1', 'Turneffe Atoll_2'] ... R² = 0.2961
#
#  Grouped Cross-validation ---
# Grouped CV R² mean: 0.2612
# Grouped CV R² std : 0.2287
# Grouped CV scores : [-0.082  0.099  0.26  -0.077  0.494  0.585  0.58   0.25   0.206  0.296]
# Time taken for MERF Grouped cross validation: 61.4079s
#
#  MERF: EXPERIMENT-6 Plot groups. Grid search: Yes, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²              : 0.1341
# Test RMSE            : 4.29 kg
# Train R² (log scale) : 0.4040
# Train R² (orig scale): 0.1658
# Train RMSE           : 16.96 kg
#
#  Cross-validation ---
# CV R² mean           : 0.2153
# CV R² std            : 0.1696
# CV scores            : [0.126 0.156 0.183 0.066 0.546]
# Num rows             : 3100
# Num groups           : 47
# ============================================================
#  EVALUATION: EXPERIMENT-6 Plot groups. Grid search: Yes, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : 0.134
#   RMSE : 4.29 kg
#
#   ✅ Test R² is positive (0.134)
#
# Regular CrossValidation:
#   Mean   : 0.215
#   Std    : 0.170
#   Scores : [0.126 0.156 0.183 0.066 0.546]
#   ✅ CV mean is positive (0.215)
#
# Grouped CrossValidation:
#   Big Creek            :  -0.082  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.099  ✅
#   Frenchman Caye       :   0.260  ✅
#   Big Creek            :  -0.077  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.494  ✅
#   Big Creek            :   0.585  ✅
#   Drowned Caye         :   0.580  ✅
#   Gra Gra Lagoon       :   0.250  ✅
#   Channel Caye         :   0.206  ✅
#   Channel Caye         :   0.296  ✅
#
#   Mean : 0.261
#   Std  : 0.229
#
#   ✅ Grouped CV mean above 0.15 (0.261)
#   ✅ Grouped CV std below 0.25 (0.229)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.127 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: 0.032)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ⚠️  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height_x_NDRE1                                0.3779  ==================
#   height_x_EVI                                  0.2208  ===========
#   height_x_NIR                                  0.1702  ========
#   EVI                                           0.0666  ===
#   MNDWI                                         0.0458  ==
#   NBR                                           0.0286  =
#   NDRE1                                         0.0219  =
#   CIrededge                                     0.0200
#   NDRE3                                         0.0187
#   NDRE2                                         0.0177
#
# [7/18]
# Grid search over MERF base RF params:
#   n_estimators=500, max_depth=None, min_samples_leaf=2 → Train R² (log)=0.4040
#   n_estimators=500, max_depth=10, min_samples_leaf=2 → Train R² (log)=0.4040
#   n_estimators=200, max_depth=5, min_samples_leaf=4 → Train R² (log)=0.3974
#   n_estimators=100, max_depth=5, min_samples_leaf=8 → Train R² (log)=0.3983
#   Best train R² (log): 0.4040
#
#  MERF. EXPERIMENT-7 Plot groups. Grid search: Yes, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# MERF model fitting starts
# MERF model fitting completed
# MERF cross validation starts
#
#  Cross-validation ---
# CV R² mean: -0.0933
# CV R² std : 0.5764
# CV scores : [ 0.128 -1.223  0.157  0.067  0.405]
# Time taken for MERF cross validation: 61.7308s
# MERF Grouped cross validation starts
#   [Grouped CV 1/10] Fitting fold: ['Big Creek_5', 'Channel Caye_1', 'Channel Caye_4', 'New River_2', 'Turneffe Atoll_3'] ... R² = -0.1315
#   [Grouped CV 2/10] Fitting fold: ['Frenchman Caye_6', 'Gra Gra Lagoon_6', 'Hicks Caye_2', 'Hicks Caye_6', 'Turneffe Atoll_4'] ... R² = -6.3475
#   [Grouped CV 3/10] Fitting fold: ['Frenchman Caye_3', 'Gra Gra Lagoon_3', 'Hicks Caye_4', "Payne's Creek_3", 'Shipstern Lagoon_6'] ... R² = 0.2469
#   [Grouped CV 4/10] Fitting fold: ['Big Creek_3', 'Channel Caye_3', 'Channel Caye_5', 'New River_1', "Payne's Creek_2"] ... R² = -0.0606
#   [Grouped CV 5/10] Fitting fold: ['Frenchman Caye_1', 'Gra Gra Lagoon_5', 'Hicks Caye_3', 'New River_3', "Payne's Creek_6"] ... R² = 0.4755
#   [Grouped CV 6/10] Fitting fold: ['Big Creek_2', 'Drowned Caye_4', 'New River_6', "Payne's Creek_1", 'Shipstern Lagoon_2'] ... R² = 0.5487
#   [Grouped CV 7/10] Fitting fold: ['Drowned Caye_5', 'Drowned Caye_6', 'Frenchman Caye_2', 'Frenchman Caye_4'] ... R² = 0.2113
#   [Grouped CV 8/10] Fitting fold: ['Gra Gra Lagoon_4', 'Shipstern Lagoon_4', 'Shipstern Lagoon_5', 'Turneffe Atoll_6'] ... R² = 0.2029
#   [Grouped CV 9/10] Fitting fold: ['Channel Caye_2', 'Frenchman Caye_5', 'Hicks Caye_1', 'New River_5', "Payne's Creek_4"] ... R² = 0.2077
#   [Grouped CV 10/10] Fitting fold: ['Channel Caye_6', 'Drowned Caye_3', 'Gra Gra Lagoon_1', 'Turneffe Atoll_2'] ... R² = 0.2330
#
#  Grouped Cross-validation ---
# Grouped CV R² mean: -0.4414
# Grouped CV R² std : 1.9782
# Grouped CV scores : [-0.132 -6.347  0.247 -0.061  0.475  0.549  0.211  0.203  0.208  0.233]
# Time taken for MERF Grouped cross validation: 61.7308s
#
#  MERF: EXPERIMENT-7 Plot groups. Grid search: Yes, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# Test R²              : 0.1861
# Test RMSE            : 4.16 kg
# Train R² (log scale) : 0.4040
# Train R² (orig scale): 0.1658
# Train RMSE           : 16.96 kg
#
#  Cross-validation ---
# CV R² mean           : -0.0933
# CV R² std            : 0.5764
# CV scores            : [ 0.128 -1.223  0.157  0.067  0.405]
# Num rows             : 3100
# Num groups           : 47
# ============================================================
#  EVALUATION: EXPERIMENT-7 Plot groups. Grid search: Yes, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# ============================================================
#
# Test set:
#   R²   : 0.186
#   RMSE : 4.16 kg
#
#   ✅ Test R² is positive (0.186)
#
# Regular CrossValidation:
#   Mean   : -0.093
#   Std    : 0.576
#   Scores : [ 0.128 -1.223  0.157  0.067  0.405]
#   ❌ CV mean is negative (-0.093)
#
# Grouped CrossValidation:
#   Big Creek            :  -0.132  ⚠️  near-zero variance artifact
#   Frenchman Caye       :  -6.347  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.247  ✅
#   Big Creek            :  -0.061  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.475  ✅
#   Big Creek            :   0.549  ✅
#   Drowned Caye         :   0.211  ✅
#   Gra Gra Lagoon       :   0.203  ✅
#   Channel Caye         :   0.208  ✅
#   Channel Caye         :   0.233  ✅
#
#   Mean : -0.441
#   Std  : 1.978
#
#   ❌ Grouped CV mean below 0.15 (-0.441)
#   ⚠️  Grouped CV std above 0.25 (1.978) — high variance across folds
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.627 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.020)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   NDRE1                                         0.3592  =================
#   EVI                                           0.2725  =============
#   NBR                                           0.0820  ====
#   NDRE2                                         0.0518  ==
#   MNDWI                                         0.0296  =
#   NDVI                                          0.0276  =
#   NIR                                           0.0233  =
#   RE3                                           0.0222  =
#   CIrededge                                     0.0203  =
#   Blue                                          0.0201  =
#
# [8/18]
# Grid search over MERF base RF params:
#   n_estimators=500, max_depth=None, min_samples_leaf=2 → Train R² (log)=0.4040
#   n_estimators=500, max_depth=10, min_samples_leaf=2 → Train R² (log)=0.4040
#   n_estimators=200, max_depth=5, min_samples_leaf=4 → Train R² (log)=0.3999
#   n_estimators=100, max_depth=5, min_samples_leaf=8 → Train R² (log)=0.3998
#   Best train R² (log): 0.4040
#
#  MERF. EXPERIMENT-8 Plot groups. Grid search: Yes, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# MERF model fitting starts
# MERF model fitting completed
# MERF cross validation starts
#
#  Cross-validation ---
# CV R² mean: 0.2248
# CV R² std : 0.1687
# CV scores : [0.113 0.206 0.168 0.086 0.552]
# Time taken for MERF cross validation: 62.1108s
# MERF Grouped cross validation starts
#   [Grouped CV 1/10] Fitting fold: ['Big Creek_5', 'Channel Caye_1', 'Channel Caye_4', 'New River_2', 'Turneffe Atoll_3'] ... R² = -0.1001
#   [Grouped CV 2/10] Fitting fold: ['Frenchman Caye_6', 'Gra Gra Lagoon_6', 'Hicks Caye_2', 'Hicks Caye_6', 'Turneffe Atoll_4'] ... R² = 0.0232
#   [Grouped CV 3/10] Fitting fold: ['Frenchman Caye_3', 'Gra Gra Lagoon_3', 'Hicks Caye_4', "Payne's Creek_3", 'Shipstern Lagoon_6'] ... R² = 0.2648
#   [Grouped CV 4/10] Fitting fold: ['Big Creek_3', 'Channel Caye_3', 'Channel Caye_5', 'New River_1', "Payne's Creek_2"] ... R² = -0.0675
#   [Grouped CV 5/10] Fitting fold: ['Frenchman Caye_1', 'Gra Gra Lagoon_5', 'Hicks Caye_3', 'New River_3', "Payne's Creek_6"] ... R² = 0.4769
#   [Grouped CV 6/10] Fitting fold: ['Big Creek_2', 'Drowned Caye_4', 'New River_6', "Payne's Creek_1", 'Shipstern Lagoon_2'] ... R² = 0.2459
#   [Grouped CV 7/10] Fitting fold: ['Drowned Caye_5', 'Drowned Caye_6', 'Frenchman Caye_2', 'Frenchman Caye_4'] ... R² = 0.5269
#   [Grouped CV 8/10] Fitting fold: ['Gra Gra Lagoon_4', 'Shipstern Lagoon_4', 'Shipstern Lagoon_5', 'Turneffe Atoll_6'] ... R² = 0.2538
#   [Grouped CV 9/10] Fitting fold: ['Channel Caye_2', 'Frenchman Caye_5', 'Hicks Caye_1', 'New River_5', "Payne's Creek_4"] ... R² = 0.2075
#   [Grouped CV 10/10] Fitting fold: ['Channel Caye_6', 'Drowned Caye_3', 'Gra Gra Lagoon_1', 'Turneffe Atoll_2'] ... R² = 0.2969
#
#  Grouped Cross-validation ---
# Grouped CV R² mean: 0.2128
# Grouped CV R² std : 0.1983
# Grouped CV scores : [-0.1    0.023  0.265 -0.067  0.477  0.246  0.527  0.254  0.207  0.297]
# Time taken for MERF Grouped cross validation: 62.1108s
#
#  MERF: EXPERIMENT-8 Plot groups. Grid search: Yes, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²              : 0.2130
# Test RMSE            : 4.09 kg
# Train R² (log scale) : 0.4040
# Train R² (orig scale): 0.1658
# Train RMSE           : 16.96 kg
#
#  Cross-validation ---
# CV R² mean           : 0.2248
# CV R² std            : 0.1687
# CV scores            : [0.113 0.206 0.168 0.086 0.552]
# Num rows             : 3100
# Num groups           : 47
# ============================================================
#  EVALUATION: EXPERIMENT-8 Plot groups. Grid search: Yes, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : 0.213
#   RMSE : 4.09 kg
#
#   ✅ Test R² is positive (0.213)
#
# Regular CrossValidation:
#   Mean   : 0.225
#   Std    : 0.169
#   Scores : [0.113 0.206 0.168 0.086 0.552]
#   ✅ CV mean is positive (0.225)
#
# Grouped CrossValidation:
#   Big Creek            :  -0.100  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.023  ✅
#   Frenchman Caye       :   0.265  ✅
#   Big Creek            :  -0.067  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.477  ✅
#   Big Creek            :   0.246  ✅
#   Drowned Caye         :   0.527  ✅
#   Gra Gra Lagoon       :   0.254  ✅
#   Channel Caye         :   0.207  ✅
#   Channel Caye         :   0.297  ✅
#
#   Mean : 0.213
#   Std  : 0.198
#
#   ✅ Grouped CV mean above 0.15 (0.213)
#   ✅ Grouped CV std below 0.25 (0.198)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ✅ Grouped CV and test R² agree (gap: 0.000)
#   ✅ Train/test R² gap acceptable (gap: -0.047)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ✅ ACCEPTABLE
#
# Top 10 feature importances:
#   height_x_NDRE1                                0.6126  ==============================
#   height_x_NIR                                  0.0733  ===
#   height_x_EVI                                  0.0501  ==
#   MNDWI                                         0.0312  =
#   EVI                                           0.0283  =
#   SWIR1                                         0.0236  =
#   Green                                         0.0211  =
#   NIR                                           0.0206  =
#   NBR                                           0.0193
#   RE3                                           0.0177
#
# [9/18]
# Grid search over MERF base RF params:
#   n_estimators=500, max_depth=None, min_samples_leaf=2 → Train R² (log)=0.4040
#   n_estimators=500, max_depth=10, min_samples_leaf=2 → Train R² (log)=0.4040
#   n_estimators=200, max_depth=5, min_samples_leaf=4 → Train R² (log)=0.3998
#   n_estimators=100, max_depth=5, min_samples_leaf=8 → Train R² (log)=0.3997
#   Best train R² (log): 0.4040
#
#  MERF. EXPERIMENT-9 Plot groups. Grid search: Yes, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# MERF model fitting starts
# MERF model fitting completed
# MERF cross validation starts
#
#  Cross-validation ---
# CV R² mean: 0.2292
# CV R² std : 0.1796
# CV scores : [0.126 0.098 0.272 0.087 0.563]
# Time taken for MERF cross validation: 62.1636s
# MERF Grouped cross validation starts
#   [Grouped CV 1/10] Fitting fold: ['Big Creek_5', 'Channel Caye_1', 'Channel Caye_4', 'New River_2', 'Turneffe Atoll_3'] ... R² = 0.0565
#   [Grouped CV 2/10] Fitting fold: ['Frenchman Caye_6', 'Gra Gra Lagoon_6', 'Hicks Caye_2', 'Hicks Caye_6', 'Turneffe Atoll_4'] ... R² = 0.2210
#   [Grouped CV 3/10] Fitting fold: ['Frenchman Caye_3', 'Gra Gra Lagoon_3', 'Hicks Caye_4', "Payne's Creek_3", 'Shipstern Lagoon_6'] ... R² = 0.2674
#   [Grouped CV 4/10] Fitting fold: ['Big Creek_3', 'Channel Caye_3', 'Channel Caye_5', 'New River_1', "Payne's Creek_2"] ... R² = -0.0688
#   [Grouped CV 5/10] Fitting fold: ['Frenchman Caye_1', 'Gra Gra Lagoon_5', 'Hicks Caye_3', 'New River_3', "Payne's Creek_6"] ... R² = 0.4593
#   [Grouped CV 6/10] Fitting fold: ['Big Creek_2', 'Drowned Caye_4', 'New River_6', "Payne's Creek_1", 'Shipstern Lagoon_2'] ... R² = 0.1851
#   [Grouped CV 7/10] Fitting fold: ['Drowned Caye_5', 'Drowned Caye_6', 'Frenchman Caye_2', 'Frenchman Caye_4'] ... R² = 0.6408
#   [Grouped CV 8/10] Fitting fold: ['Gra Gra Lagoon_4', 'Shipstern Lagoon_4', 'Shipstern Lagoon_5', 'Turneffe Atoll_6'] ... R² = 0.2572
#   [Grouped CV 9/10] Fitting fold: ['Channel Caye_2', 'Frenchman Caye_5', 'Hicks Caye_1', 'New River_5', "Payne's Creek_4"] ... R² = 0.2117
#   [Grouped CV 10/10] Fitting fold: ['Channel Caye_6', 'Drowned Caye_3', 'Gra Gra Lagoon_1', 'Turneffe Atoll_2'] ... R² = 0.2981
#
#  Grouped Cross-validation ---
# Grouped CV R² mean: 0.2528
# Grouped CV R² std : 0.1857
# Grouped CV scores : [ 0.056  0.221  0.267 -0.069  0.459  0.185  0.641  0.257  0.212  0.298]
# Time taken for MERF Grouped cross validation: 62.1636s
#
#  MERF: EXPERIMENT-9 Plot groups. Grid search: Yes, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# Test R²              : -2.5124
# Test RMSE            : 8.65 kg
# Train R² (log scale) : 0.4040
# Train R² (orig scale): 0.1658
# Train RMSE           : 16.96 kg
#
#  Cross-validation ---
# CV R² mean           : 0.2292
# CV R² std            : 0.1796
# CV scores            : [0.126 0.098 0.272 0.087 0.563]
# Num rows             : 3100
# Num groups           : 47
# ============================================================
#  EVALUATION: EXPERIMENT-9 Plot groups. Grid search: Yes, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# ============================================================
#
# Test set:
#   R²   : -2.512
#   RMSE : 8.65 kg
#
#   ❌ Test R² is negative (-2.512)
#
# Regular CrossValidation:
#   Mean   : 0.229
#   Std    : 0.180
#   Scores : [0.126 0.098 0.272 0.087 0.563]
#   ✅ CV mean is positive (0.229)
#
# Grouped CrossValidation:
#   Big Creek            :   0.056  ✅
#   Frenchman Caye       :   0.221  ✅
#   Frenchman Caye       :   0.267  ✅
#   Big Creek            :  -0.069  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.459  ✅
#   Big Creek            :   0.185  ✅
#   Drowned Caye         :   0.641  ✅
#   Gra Gra Lagoon       :   0.257  ✅
#   Channel Caye         :   0.212  ✅
#   Channel Caye         :   0.298  ✅
#
#   Mean : 0.253
#   Std  : 0.186
#
#   ✅ Grouped CV mean above 0.15 (0.253)
#   ✅ Grouped CV std below 0.25 (0.186)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 2.765 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 2.678 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height                                        0.7068  ===================================
#   MNDWI                                         0.0403  ==
#   EVI                                           0.0290  =
#   Green                                         0.0268  =
#   SWIR1                                         0.0264  =
#   NBR                                           0.0210  =
#   RE3                                           0.0202  =
#   NIR                                           0.0198
#   SWIR2                                         0.0184
#   NDRE1                                         0.0168
#
# [10/18]
# Grid search over MERF base RF params:
#   n_estimators=500, max_depth=None, min_samples_leaf=2 → Train R² (log)=0.4040
#   n_estimators=500, max_depth=10, min_samples_leaf=2 → Train R² (log)=0.4040
#   n_estimators=200, max_depth=5, min_samples_leaf=4 → Train R² (log)=0.3998
#   n_estimators=100, max_depth=5, min_samples_leaf=8 → Train R² (log)=0.3997
#   Best train R² (log): 0.4040
#
#  MERF. EXPERIMENT-10 Plot groups. Grid search: Yes, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# MERF model fitting starts
# MERF model fitting completed
# MERF cross validation starts
#
#  Cross-validation ---
# CV R² mean: 0.2395
# CV R² std : 0.1729
# CV scores : [0.113 0.274 0.169 0.082 0.56 ]
# Time taken for MERF cross validation: 62.2752s
# MERF Grouped cross validation starts
#   [Grouped CV 1/10] Fitting fold: ['Big Creek_5', 'Channel Caye_1', 'Channel Caye_4', 'New River_2', 'Turneffe Atoll_3'] ... R² = -0.1097
#   [Grouped CV 2/10] Fitting fold: ['Frenchman Caye_6', 'Gra Gra Lagoon_6', 'Hicks Caye_2', 'Hicks Caye_6', 'Turneffe Atoll_4'] ... R² = -0.9643
#   [Grouped CV 3/10] Fitting fold: ['Frenchman Caye_3', 'Gra Gra Lagoon_3', 'Hicks Caye_4', "Payne's Creek_3", 'Shipstern Lagoon_6'] ... R² = 0.2639
#   [Grouped CV 4/10] Fitting fold: ['Big Creek_3', 'Channel Caye_3', 'Channel Caye_5', 'New River_1', "Payne's Creek_2"] ... R² = -0.0656
#   [Grouped CV 5/10] Fitting fold: ['Frenchman Caye_1', 'Gra Gra Lagoon_5', 'Hicks Caye_3', 'New River_3', "Payne's Creek_6"] ... R² = 0.4656
#   [Grouped CV 6/10] Fitting fold: ['Big Creek_2', 'Drowned Caye_4', 'New River_6', "Payne's Creek_1", 'Shipstern Lagoon_2'] ... R² = 0.1773
#   [Grouped CV 7/10] Fitting fold: ['Drowned Caye_5', 'Drowned Caye_6', 'Frenchman Caye_2', 'Frenchman Caye_4'] ... R² = 0.4355
#   [Grouped CV 8/10] Fitting fold: ['Gra Gra Lagoon_4', 'Shipstern Lagoon_4', 'Shipstern Lagoon_5', 'Turneffe Atoll_6'] ... R² = 0.2567
#   [Grouped CV 9/10] Fitting fold: ['Channel Caye_2', 'Frenchman Caye_5', 'Hicks Caye_1', 'New River_5', "Payne's Creek_4"] ... R² = 0.2093
#   [Grouped CV 10/10] Fitting fold: ['Channel Caye_6', 'Drowned Caye_3', 'Gra Gra Lagoon_1', 'Turneffe Atoll_2'] ... R² = 0.2914
#
#  Grouped Cross-validation ---
# Grouped CV R² mean: 0.0960
# Grouped CV R² std : 0.3945
# Grouped CV scores : [-0.11  -0.964  0.264 -0.066  0.466  0.177  0.436  0.257  0.209  0.291]
# Time taken for MERF Grouped cross validation: 62.2752s
#
#  MERF: EXPERIMENT-10 Plot groups. Grid search: Yes, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²              : -0.1258
# Test RMSE            : 4.90 kg
# Train R² (log scale) : 0.4040
# Train R² (orig scale): 0.1658
# Train RMSE           : 16.96 kg
#
#  Cross-validation ---
# CV R² mean           : 0.2395
# CV R² std            : 0.1729
# CV scores            : [0.113 0.274 0.169 0.082 0.56 ]
# Num rows             : 3100
# Num groups           : 47
# ============================================================
#  EVALUATION: EXPERIMENT-10 Plot groups. Grid search: Yes, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : -0.126
#   RMSE : 4.90 kg
#
#   ❌ Test R² is negative (-0.126)
#
# Regular CrossValidation:
#   Mean   : 0.239
#   Std    : 0.173
#   Scores : [0.113 0.274 0.169 0.082 0.56 ]
#   ✅ CV mean is positive (0.239)
#
# Grouped CrossValidation:
#   Big Creek            :  -0.110  ⚠️  near-zero variance artifact
# ...
#   Frenchman Caye       :   0.465  ✅
#   Big Creek            :   0.156  ✅
#   Drowned Caye         :   0.485  ✅
#   Gra Gra Lagoon       :   0.249  ✅
#   Channel Caye         :   0.235  ✅
#   Channel Caye         :   0.296  ✅
#
#   Mean : 0.243
#   Std  : 0.154
#
#   ✅ Grouped CV mean above 0.15 (0.243)
#   ✅ Grouped CV std below 0.25 (0.154)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 3.573 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 3.496 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height                                        0.7454  =====================================
#   EVI                                           0.0653  ===
#   SWIR1                                         0.0615  ===
#   NIR                                           0.0453  ==
#   NBR                                           0.0365  =
#   RE2                                           0.0240  =
#   RE1                                           0.0220  =
#
# [16/18]
# Grid search over MERF base RF params:
#   n_estimators=500, max_depth=None, min_samples_leaf=2 → Train R² (log)=0.4040
#   n_estimators=500, max_depth=10, min_samples_leaf=2 → Train R² (log)=0.4040
#   n_estimators=200, max_depth=5, min_samples_leaf=4 → Train R² (log)=0.4003
#   n_estimators=100, max_depth=5, min_samples_leaf=8 → Train R² (log)=0.4001
#   Best train R² (log): 0.4040
#
#  MERF. EXPERIMENT-16 Plot groups. Grid search: Yes, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# MERF model fitting starts
# MERF model fitting completed
# MERF cross validation starts
#
#  Cross-validation ---
# CV R² mean: 0.2609
# CV R² std : 0.1757
# CV scores : [0.144 0.37  0.158 0.079 0.553]
# Time taken for MERF cross validation: 61.5459s
# MERF Grouped cross validation starts
#   [Grouped CV 1/10] Fitting fold: ['Big Creek_5', 'Channel Caye_1', 'Channel Caye_4', 'New River_2', 'Turneffe Atoll_3'] ... R² = -0.0848
#   [Grouped CV 2/10] Fitting fold: ['Frenchman Caye_6', 'Gra Gra Lagoon_6', 'Hicks Caye_2', 'Hicks Caye_6', 'Turneffe Atoll_4'] ... R² = 0.1841
#   [Grouped CV 3/10] Fitting fold: ['Frenchman Caye_3', 'Gra Gra Lagoon_3', 'Hicks Caye_4', "Payne's Creek_3", 'Shipstern Lagoon_6'] ... R² = 0.2536
#   [Grouped CV 4/10] Fitting fold: ['Big Creek_3', 'Channel Caye_3', 'Channel Caye_5', 'New River_1', "Payne's Creek_2"] ... R² = -0.0520
#   [Grouped CV 5/10] Fitting fold: ['Frenchman Caye_1', 'Gra Gra Lagoon_5', 'Hicks Caye_3', 'New River_3', "Payne's Creek_6"] ... R² = 0.4626
#   [Grouped CV 6/10] Fitting fold: ['Big Creek_2', 'Drowned Caye_4', 'New River_6', "Payne's Creek_1", 'Shipstern Lagoon_2'] ... R² = 0.2365
#   [Grouped CV 7/10] Fitting fold: ['Drowned Caye_5', 'Drowned Caye_6', 'Frenchman Caye_2', 'Frenchman Caye_4'] ... R² = 0.4851
#   [Grouped CV 8/10] Fitting fold: ['Gra Gra Lagoon_4', 'Shipstern Lagoon_4', 'Shipstern Lagoon_5', 'Turneffe Atoll_6'] ... R² = 0.2568
#   [Grouped CV 9/10] Fitting fold: ['Channel Caye_2', 'Frenchman Caye_5', 'Hicks Caye_1', 'New River_5', "Payne's Creek_4"] ... R² = 0.2365
#   [Grouped CV 10/10] Fitting fold: ['Channel Caye_6', 'Drowned Caye_3', 'Gra Gra Lagoon_1', 'Turneffe Atoll_2'] ... R² = 0.2839
#
#  Grouped Cross-validation ---
# Grouped CV R² mean: 0.2262
# Grouped CV R² std : 0.1744
# Grouped CV scores : [-0.085  0.184  0.254 -0.052  0.463  0.236  0.485  0.257  0.237  0.284]
# Time taken for MERF Grouped cross validation: 61.5459s
#
#  MERF: EXPERIMENT-16 Plot groups. Grid search: Yes, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²              : 0.1554
# Test RMSE            : 4.24 kg
# Train R² (log scale) : 0.4040
# Train R² (orig scale): 0.1658
# Train RMSE           : 16.96 kg
#
#  Cross-validation ---
# CV R² mean           : 0.2609
# CV R² std            : 0.1757
# CV scores            : [0.144 0.37  0.158 0.079 0.553]
# Num rows             : 3100
# Num groups           : 47
# ============================================================
#  EVALUATION: EXPERIMENT-16 Plot groups. Grid search: Yes, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : 0.155
#   RMSE : 4.24 kg
#
#   ✅ Test R² is positive (0.155)
#
# Regular CrossValidation:
#   Mean   : 0.261
#   Std    : 0.176
#   Scores : [0.144 0.37  0.158 0.079 0.553]
#   ✅ CV mean is positive (0.261)
#
# Grouped CrossValidation:
#   Big Creek            :  -0.085  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.184  ✅
#   Frenchman Caye       :   0.254  ✅
#   Big Creek            :  -0.052  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.463  ✅
#   Big Creek            :   0.236  ✅
#   Drowned Caye         :   0.485  ✅
#   Gra Gra Lagoon       :   0.257  ✅
#   Channel Caye         :   0.237  ✅
#   Channel Caye         :   0.284  ✅
#
#   Mean : 0.226
#   Std  : 0.174
#
#   ✅ Grouped CV mean above 0.15 (0.226)
#   ✅ Grouped CV std below 0.25 (0.174)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.071 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: 0.010)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ⚠️  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height_x_NDRE1                                0.2944  ==============
#   height                                        0.1820  =========
#   height_x_EVI                                  0.1587  =======
#   height_x_NIR                                  0.1436  =======
#   EVI                                           0.0556  ==
#   NBR                                           0.0508  ==
#   SWIR1                                         0.0435  ==
#   NIR                                           0.0353  =
#   RE2                                           0.0182
#   RE1                                           0.0178
#
# [17/18]
# Grid search over MERF base RF params:
#   n_estimators=500, max_depth=None, min_samples_leaf=2 → Train R² (log)=0.4657
#   n_estimators=500, max_depth=10, min_samples_leaf=2 → Train R² (log)=0.4654
#   n_estimators=200, max_depth=5, min_samples_leaf=4 → Train R² (log)=0.4411
#   n_estimators=100, max_depth=5, min_samples_leaf=8 → Train R² (log)=0.4414
#   Best train R² (log): 0.4657
#
#  MERF. EXPERIMENT-17 Plot groups. Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2'].
# MERF model fitting starts
# MERF model fitting completed
# MERF cross validation starts
#
#  Cross-validation ---
# CV R² mean: 0.3132
# CV R² std : 0.1660
# CV scores : [0.131 0.453 0.303 0.135 0.544]
# Time taken for MERF cross validation: 63.0834s
# MERF Grouped cross validation starts
#   [Grouped CV 1/10] Fitting fold: ['Big Creek_5', 'Channel Caye_1', 'Channel Caye_4', 'New River_2', 'Turneffe Atoll_3'] ... R² = 0.1191
#   [Grouped CV 2/10] Fitting fold: ['Frenchman Caye_6', 'Gra Gra Lagoon_6', 'Hicks Caye_2', 'Hicks Caye_6', 'Turneffe Atoll_4'] ... R² = 0.3377
#   [Grouped CV 3/10] Fitting fold: ['Frenchman Caye_3', 'Gra Gra Lagoon_3', 'Hicks Caye_4', "Payne's Creek_3", 'Shipstern Lagoon_6'] ... R² = 0.3707
#   [Grouped CV 4/10] Fitting fold: ['Big Creek_3', 'Channel Caye_3', 'Channel Caye_5', 'New River_1', "Payne's Creek_2"] ... R² = -0.0391
#   [Grouped CV 5/10] Fitting fold: ['Frenchman Caye_1', 'Gra Gra Lagoon_5', 'Hicks Caye_3', 'New River_3', "Payne's Creek_6"] ... R² = 0.5042
#   [Grouped CV 6/10] Fitting fold: ['Big Creek_2', 'Drowned Caye_4', 'New River_6', "Payne's Creek_1", 'Shipstern Lagoon_2'] ... R² = 0.3288
#   [Grouped CV 7/10] Fitting fold: ['Drowned Caye_5', 'Drowned Caye_6', 'Frenchman Caye_2', 'Frenchman Caye_4'] ... R² = 0.5053
#   [Grouped CV 8/10] Fitting fold: ['Gra Gra Lagoon_4', 'Shipstern Lagoon_4', 'Shipstern Lagoon_5', 'Turneffe Atoll_6'] ... R² = 0.1977
#   [Grouped CV 9/10] Fitting fold: ['Channel Caye_2', 'Frenchman Caye_5', 'Hicks Caye_1', 'New River_5', "Payne's Creek_4"] ... R² = 0.3367
#   [Grouped CV 10/10] Fitting fold: ['Channel Caye_6', 'Drowned Caye_3', 'Gra Gra Lagoon_1', 'Turneffe Atoll_2'] ... R² = 0.2944
#
#  Grouped Cross-validation ---
# Grouped CV R² mean: 0.2955
# Grouped CV R² std : 0.1583
# Grouped CV scores : [ 0.119  0.338  0.371 -0.039  0.504  0.329  0.505  0.198  0.337  0.294]
# Time taken for MERF Grouped cross validation: 63.0834s
#
#  MERF: EXPERIMENT-17 Plot groups. Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2'].
# Test R²              : -3.0898
# Test RMSE            : 9.33 kg
# Train R² (log scale) : 0.4657
# Train R² (orig scale): 0.1868
# Train RMSE           : 16.75 kg
#
#  Cross-validation ---
# CV R² mean           : 0.3132
# CV R² std            : 0.1660
# CV scores            : [0.131 0.453 0.303 0.135 0.544]
# Num rows             : 3100
# Num groups           : 47
# ============================================================
#  EVALUATION: EXPERIMENT-17 Plot groups. Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2'].
# ============================================================
#
# Test set:
#   R²   : -3.090
#   RMSE : 9.33 kg
#
#   ❌ Test R² is negative (-3.090)
#
# Regular CrossValidation:
#   Mean   : 0.313
#   Std    : 0.166
#   Scores : [0.131 0.453 0.303 0.135 0.544]
#   ✅ CV mean is positive (0.313)
#
# Grouped CrossValidation:
#   Big Creek            :   0.119  ✅
#   Frenchman Caye       :   0.338  ✅
#   Frenchman Caye       :   0.371  ✅
#   Big Creek            :  -0.039  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.504  ✅
#   Big Creek            :   0.329  ✅
#   Drowned Caye         :   0.505  ✅
#   Gra Gra Lagoon       :   0.198  ✅
#   Channel Caye         :   0.337  ✅
#   Channel Caye         :   0.294  ✅
#
#   Mean : 0.296
#   Std  : 0.158
#
#   ✅ Grouped CV mean above 0.15 (0.296)
#   ✅ Grouped CV std below 0.25 (0.158)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 3.385 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 3.277 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height                                        0.6311  ===============================
#   SWIR1                                         0.0591  ==
#   EVI                                           0.0582  ==
#   species_Avicennia germinans                   0.0520  ==
#   NBR                                           0.0505  ==
#   NIR                                           0.0386  =
#   RE2                                           0.0362  =
#   RE1                                           0.0322  =
#   species_Rhizophora mangle                     0.0320  =
#   species_Laguncularia racemosa                 0.0101
#
# [18/18]
# Grid search over MERF base RF params:
#   n_estimators=500, max_depth=None, min_samples_leaf=2 → Train R² (log)=0.4658
#   n_estimators=500, max_depth=10, min_samples_leaf=2 → Train R² (log)=0.4654
#   n_estimators=200, max_depth=5, min_samples_leaf=4 → Train R² (log)=0.4406
#   n_estimators=100, max_depth=5, min_samples_leaf=8 → Train R² (log)=0.4427
#   Best train R² (log): 0.4658
#
#  MERF. EXPERIMENT-18 Plot groups. Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# MERF model fitting starts
# MERF model fitting completed
# MERF cross validation starts
#
#  Cross-validation ---
# CV R² mean: 0.2849
# CV R² std : 0.1751
# CV scores : [0.122 0.444 0.187 0.127 0.544]
# Time taken for MERF cross validation: 63.1737s
# MERF Grouped cross validation starts
#   [Grouped CV 1/10] Fitting fold: ['Big Creek_5', 'Channel Caye_1', 'Channel Caye_4', 'New River_2', 'Turneffe Atoll_3'] ... R² = -0.0799
#   [Grouped CV 2/10] Fitting fold: ['Frenchman Caye_6', 'Gra Gra Lagoon_6', 'Hicks Caye_2', 'Hicks Caye_6', 'Turneffe Atoll_4'] ... R² = 0.3107
#   [Grouped CV 3/10] Fitting fold: ['Frenchman Caye_3', 'Gra Gra Lagoon_3', 'Hicks Caye_4', "Payne's Creek_3", 'Shipstern Lagoon_6'] ... R² = 0.3681
#   [Grouped CV 4/10] Fitting fold: ['Big Creek_3', 'Channel Caye_3', 'Channel Caye_5', 'New River_1', "Payne's Creek_2"] ... R² = -0.0383
#   [Grouped CV 5/10] Fitting fold: ['Frenchman Caye_1', 'Gra Gra Lagoon_5', 'Hicks Caye_3', 'New River_3', "Payne's Creek_6"] ... R² = 0.4941
#   [Grouped CV 6/10] Fitting fold: ['Big Creek_2', 'Drowned Caye_4', 'New River_6', "Payne's Creek_1", 'Shipstern Lagoon_2'] ... R² = 0.3338
#   [Grouped CV 7/10] Fitting fold: ['Drowned Caye_5', 'Drowned Caye_6', 'Frenchman Caye_2', 'Frenchman Caye_4'] ... R² = 0.5050
#   [Grouped CV 8/10] Fitting fold: ['Gra Gra Lagoon_4', 'Shipstern Lagoon_4', 'Shipstern Lagoon_5', 'Turneffe Atoll_6'] ... R² = 0.2118
#   [Grouped CV 9/10] Fitting fold: ['Channel Caye_2', 'Frenchman Caye_5', 'Hicks Caye_1', 'New River_5', "Payne's Creek_4"] ... R² = 0.3524
#   [Grouped CV 10/10] Fitting fold: ['Channel Caye_6', 'Drowned Caye_3', 'Gra Gra Lagoon_1', 'Turneffe Atoll_2'] ... R² = 0.2908
#
#  Grouped Cross-validation ---
# Grouped CV R² mean: 0.2749
# Grouped CV R² std : 0.1867
# Grouped CV scores : [-0.08   0.311  0.368 -0.038  0.494  0.334  0.505  0.212  0.352  0.291]
# Time taken for MERF Grouped cross validation: 63.1737s
#
#  MERF: EXPERIMENT-18 Plot groups. Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²              : 0.2180
# Test RMSE            : 4.08 kg
# Train R² (log scale) : 0.4658
# Train R² (orig scale): 0.1868
# Train RMSE           : 16.75 kg
#
#  Cross-validation ---
# CV R² mean           : 0.2849
# CV R² std            : 0.1751
# CV scores            : [0.122 0.444 0.187 0.127 0.544]
# Num rows             : 3100
# Num groups           : 47
# ============================================================
#  EVALUATION: EXPERIMENT-18 Plot groups. Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : 0.218
#   RMSE : 4.08 kg
#
#   ✅ Test R² is positive (0.218)
#
# Regular CrossValidation:
#   Mean   : 0.285
#   Std    : 0.175
#   Scores : [0.122 0.444 0.187 0.127 0.544]
#   ✅ CV mean is positive (0.285)
#
# Grouped CrossValidation:
#   Big Creek            :  -0.080  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.311  ✅
#   Frenchman Caye       :   0.368  ✅
#   Big Creek            :  -0.038  ⚠️  near-zero variance artifact
#   Frenchman Caye       :   0.494  ✅
#   Big Creek            :   0.334  ✅
#   Drowned Caye         :   0.505  ✅
#   Gra Gra Lagoon       :   0.212  ✅
#   Channel Caye         :   0.352  ✅
#   Channel Caye         :   0.291  ✅
#
#   Mean : 0.275
#   Std  : 0.187
#
#   ✅ Grouped CV mean above 0.15 (0.275)
#   ✅ Grouped CV std below 0.25 (0.187)
#   ✅ All negative folds explained
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.057 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: -0.031)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ⚠️  MARGINAL — positive metrics but concerns
#
# Top 10 feature importances:
#   height_x_NDRE1                                0.3039  ===============
#   height_x_NIR                                  0.1608  ========
#   height_x_EVI                                  0.1125  =====
#   height                                        0.1115  =====
#   SWIR1                                         0.0479  ==
#   species_Avicennia germinans                   0.0469  ==
#   EVI                                           0.0465  ==
#   NIR                                           0.0347  =
#   RE2                                           0.0327  =
#   species_Rhizophora mangle                     0.0319  =
#
# Completed: 18/18 experiments

# %%
tabulate_results(merf_belige_grid_grps, acceptable_only=True)
# Out:
# Showing 8 acceptable experiments
# <style type="text/css">
# #T_6c7f6_row0_col7, #T_6c7f6_row4_col8, #T_6c7f6_row6_col9, #T_6c7f6_row7_col1, #T_6c7f6_row7_col2 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_6c7f6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c7f6_level0_col0" class="col_heading level0 col0" >Experiment</th>
#       <th id="T_6c7f6_level0_col1" class="col_heading level0 col1" >Test R²</th>
#       <th id="T_6c7f6_level0_col2" class="col_heading level0 col2" >Test RMSE</th>
#       <th id="T_6c7f6_level0_col3" class="col_heading level0 col3" >Train R²</th>
#       <th id="T_6c7f6_level0_col4" class="col_heading level0 col4" >Train RMSE</th>
#       <th id="T_6c7f6_level0_col5" class="col_heading level0 col5" >CV R² Mean</th>
#       <th id="T_6c7f6_level0_col6" class="col_heading level0 col6" >CV R² Std</th>
#       <th id="T_6c7f6_level0_col7" class="col_heading level0 col7" >Group CV R² Mean</th>
#       <th id="T_6c7f6_level0_col8" class="col_heading level0 col8" >Group CV R² Std</th>
#       <th id="T_6c7f6_level0_col9" class="col_heading level0 col9" >CV-Test Gap</th>
#       <th id="T_6c7f6_level0_col10" class="col_heading level0 col10" >-ve Folds</th>
#       <th id="T_6c7f6_level0_col11" class="col_heading level0 col11" >verdict</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c7f6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6c7f6_row0_col0" class="data row0 col0" >EXPERIMENT-18 Plot groups. Grid search: Yes, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].</td>
#       <td id="T_6c7f6_row0_col1" class="data row0 col1" >0.218</td>
#       <td id="T_6c7f6_row0_col2" class="data row0 col2" >4.08</td>
#       <td id="T_6c7f6_row0_col3" class="data row0 col3" >0.1868</td>
#       <td id="T_6c7f6_row0_col4" class="data row0 col4" >16.75</td>
#       <td id="T_6c7f6_row0_col5" class="data row0 col5" >0.2849</td>
#       <td id="T_6c7f6_row0_col6" class="data row0 col6" >0.1751</td>
#       <td id="T_6c7f6_row0_col7" class="data row0 col7" >0.2749</td>
#       <td id="T_6c7f6_row0_col8" class="data row0 col8" >0.1867</td>
#       <td id="T_6c7f6_row0_col9" class="data row0 col9" >0.0569</td>
#       <td id="T_6c7f6_row0_col10" class="data row0 col10" >2 (Big Creek, Big Creek)</td>
#       <td id="T_6c7f6_row0_col11" class="data row0 col11" >⚠️  MARGINAL — positive metrics but concerns</td>
#     </tr>
#     <tr>
#       <th id="T_6c7f6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6c7f6_row1_col0" class="data row1 col0" >EXPERIMENT-6 Plot groups. Grid search: Yes, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].</td>
#       <td id="T_6c7f6_row1_col1" class="data row1 col1" >0.1341</td>
#       <td id="T_6c7f6_row1_col2" class="data row1 col2" >4.29</td>
#       <td id="T_6c7f6_row1_col3" class="data row1 col3" >0.1658</td>
#       <td id="T_6c7f6_row1_col4" class="data row1 col4" >16.96</td>
#       <td id="T_6c7f6_row1_col5" class="data row1 col5" >0.2153</td>
#       <td id="T_6c7f6_row1_col6" class="data row1 col6" >0.1696</td>
#       <td id="T_6c7f6_row1_col7" class="data row1 col7" >0.2612</td>
#       <td id="T_6c7f6_row1_col8" class="data row1 col8" >0.2287</td>
#       <td id="T_6c7f6_row1_col9" class="data row1 col9" >0.127</td>
#       <td id="T_6c7f6_row1_col10" class="data row1 col10" >2 (Big Creek, Big Creek)</td>
#       <td id="T_6c7f6_row1_col11" class="data row1 col11" >⚠️  MARGINAL — positive metrics but concerns</td>
#     </tr>
#     <tr>
#       <th id="T_6c7f6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6c7f6_row2_col0" class="data row2 col0" >EXPERIMENT-12 Plot groups. Grid search: Yes, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].</td>
#       <td id="T_6c7f6_row2_col1" class="data row2 col1" >0.1604</td>
#       <td id="T_6c7f6_row2_col2" class="data row2 col2" >4.23</td>
#       <td id="T_6c7f6_row2_col3" class="data row2 col3" >0.1658</td>
#       <td id="T_6c7f6_row2_col4" class="data row2 col4" >16.96</td>
#       <td id="T_6c7f6_row2_col5" class="data row2 col5" >0.2655</td>
#       <td id="T_6c7f6_row2_col6" class="data row2 col6" >0.1772</td>
#       <td id="T_6c7f6_row2_col7" class="data row2 col7" >0.2584</td>
#       <td id="T_6c7f6_row2_col8" class="data row2 col8" >0.1935</td>
#       <td id="T_6c7f6_row2_col9" class="data row2 col9" >0.098</td>
#       <td id="T_6c7f6_row2_col10" class="data row2 col10" >2 (Big Creek, Big Creek)</td>
#       <td id="T_6c7f6_row2_col11" class="data row2 col11" >⚠️  MARGINAL — positive metrics but concerns</td>
#     </tr>
#     <tr>
#       <th id="T_6c7f6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6c7f6_row3_col0" class="data row3 col0" >EXPERIMENT-2 Plot groups. Grid search: Yes, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].</td>
#       <td id="T_6c7f6_row3_col1" class="data row3 col1" >0.211</td>
#       <td id="T_6c7f6_row3_col2" class="data row3 col2" >4.1</td>
#       <td id="T_6c7f6_row3_col3" class="data row3 col3" >0.1658</td>
#       <td id="T_6c7f6_row3_col4" class="data row3 col4" >16.96</td>
#       <td id="T_6c7f6_row3_col5" class="data row3 col5" >0.2428</td>
#       <td id="T_6c7f6_row3_col6" class="data row3 col6" >0.1679</td>
#       <td id="T_6c7f6_row3_col7" class="data row3 col7" >0.2532</td>
#       <td id="T_6c7f6_row3_col8" class="data row3 col8" >0.2083</td>
#       <td id="T_6c7f6_row3_col9" class="data row3 col9" >0.0422</td>
#       <td id="T_6c7f6_row3_col10" class="data row3 col10" >2 (Big Creek, Big Creek)</td>
#       <td id="T_6c7f6_row3_col11" class="data row3 col11" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_6c7f6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6c7f6_row4_col0" class="data row4 col0" >EXPERIMENT-16 Plot groups. Grid search: Yes, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].</td>
#       <td id="T_6c7f6_row4_col1" class="data row4 col1" >0.1554</td>
#       <td id="T_6c7f6_row4_col2" class="data row4 col2" >4.24</td>
#       <td id="T_6c7f6_row4_col3" class="data row4 col3" >0.1658</td>
#       <td id="T_6c7f6_row4_col4" class="data row4 col4" >16.96</td>
#       <td id="T_6c7f6_row4_col5" class="data row4 col5" >0.2609</td>
#       <td id="T_6c7f6_row4_col6" class="data row4 col6" >0.1757</td>
#       <td id="T_6c7f6_row4_col7" class="data row4 col7" >0.2262</td>
#       <td id="T_6c7f6_row4_col8" class="data row4 col8" >0.1744</td>
#       <td id="T_6c7f6_row4_col9" class="data row4 col9" >0.0708</td>
#       <td id="T_6c7f6_row4_col10" class="data row4 col10" >2 (Big Creek, Big Creek)</td>
#       <td id="T_6c7f6_row4_col11" class="data row4 col11" >⚠️  MARGINAL — positive metrics but concerns</td>
#     </tr>
#     <tr>
#       <th id="T_6c7f6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6c7f6_row5_col0" class="data row5 col0" >EXPERIMENT-4 Plot groups. Grid search: Yes, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].</td>
#       <td id="T_6c7f6_row5_col1" class="data row5 col1" >0.261</td>
#       <td id="T_6c7f6_row5_col2" class="data row5 col2" >3.97</td>
#       <td id="T_6c7f6_row5_col3" class="data row5 col3" >0.1658</td>
#       <td id="T_6c7f6_row5_col4" class="data row5 col4" >16.96</td>
#       <td id="T_6c7f6_row5_col5" class="data row5 col5" >0.246</td>
#       <td id="T_6c7f6_row5_col6" class="data row5 col6" >0.1769</td>
#       <td id="T_6c7f6_row5_col7" class="data row5 col7" >0.2261</td>
#       <td id="T_6c7f6_row5_col8" class="data row5 col8" >0.1818</td>
#       <td id="T_6c7f6_row5_col9" class="data row5 col9" >0.0349</td>
#       <td id="T_6c7f6_row5_col10" class="data row5 col10" >2 (Big Creek, Big Creek)</td>
#       <td id="T_6c7f6_row5_col11" class="data row5 col11" >✅ AC

# %% [markdown]
# Across 36 total experiments (18 untuned + 18 tuned), only 5 passed.
#
# **What worked?**
# Feature sets where interaction terms dominate height (Exp 2, 4, 8):
#  - Test R² 0.21–0.27
#  - Grouped CV 0.21–0.25.
#
# **What failed?**
# Any feature set where bare height dominates (importance > 0.60)
#  - Test R² collapses to −2 to −4
#  - Grouped CV looks clean at 0.28–0.33.

# %% [markdown]
# # BELIGE DATA. PLOT-AVERAGE

# %%
belige_plot_df = sentinel_df[sentinel_df['dataset'] == 'Belige'].copy()

# Select TANDEMX
belige_plot_df_avg = belige_plot_df.drop(columns=['height'])
belige_plot_df_avg = belige_plot_df_avg.rename({'tandemx_height_m': 'height'}, axis=1)
belige_plot_df_avg = belige_plot_df_avg.drop(columns=['simard_height_m'])
belige_plot_df_avg.columns
# Out:
# Index(['dataset', 'plot_id', 'start_date', 'end_date', 'latitude', 'longitude',
#        'diameter', 'species', 'plant_AGB_kg', 'capture_start', 'capture_end',
#        'sentinel_time', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR',
#        'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2',
#        'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'cloud_threshold_used',
#        'height'],
#       dtype='object')

# %%
PLOT_AREA_HA = 0.0154  # Kauffman and Donato 2012

# Sentinel-2 band and index columns
s2_band_cols  = ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2']
s2_index_cols = ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 
                 'CIrededge', 'CLOUD_COVERAGE']
coord_cols    = ['latitude', 'longitude']
height_cols   = ['height']   # already renamed from tandemx_height_m

eo_cols       = s2_band_cols + s2_index_cols + height_cols + coord_cols

agg_dict = {}
agg_dict['plant_AGB_kg'] = ['sum', 'count']
agg_dict['diameter']     = 'mean'
for col in eo_cols:
    if col in belige_plot_df_avg.columns:
        agg_dict[col] = 'mean'

plot_df = belige_plot_df_avg.groupby('plot_id').agg(agg_dict).reset_index()

# Flatten multi-level columns
plot_df.columns = ['plot_id'] + [
    f"{col}_{agg}" if isinstance(agg, str) and agg in ['sum', 'count', 'mean']
    else col
    for col, agg in plot_df.columns[1:]
]

# Compute AGB in Mg/ha
plot_df['AGB_Mg_ha'] = (plot_df['plant_AGB_kg_sum'] / 1000) / PLOT_AREA_HA

print(f"Plot-level rows  : {len(plot_df)}")
print(f"\nAGB_Mg_ha range  : {plot_df['AGB_Mg_ha'].min():.2f} to {plot_df['AGB_Mg_ha'].max():.2f}")
print(f"AGB_Mg_ha mean   : {plot_df['AGB_Mg_ha'].mean():.2f}")

plot_df.columns
# Out:
# Plot-level rows  : 59
#
# AGB_Mg_ha range  : 0.01 to 98.26
# AGB_Mg_ha mean   : 17.98
# Index(['plot_id', 'plant_AGB_kg_sum', 'plant_AGB_kg_count', 'diameter_mean',
#        'Blue_mean', 'Green_mean', 'Red_mean', 'RE1_mean', 'RE2_mean',
#        'RE3_mean', 'NIR_mean', 'SWIR1_mean', 'SWIR2_mean', 'NDVI_mean',
#        'MNDWI_mean', 'NBR_mean', 'EVI_mean', 'NDRE1_mean', 'NDRE2_mean',
#        'NDRE3_mean', 'CIrededge_mean', 'CLOUD_COVERAGE_mean', 'height_mean',
#        'latitude_mean', 'longitude_mean', 'AGB_Mg_ha'],
#       dtype='object')

# %%
non_feature_cols = [
    'total_AGB_kg',
    'AGB_Mg_ha',
    'latitude',
    'longitude',
    'diameter_mean',
    'latitude_mean',
    'longitude_mean'
]

targets = ['AGB_Mg_ha', 'plant_AGB_kg_sum']
target  = 'AGB_Mg_ha'

sentinel_cols  = ['Blue_mean', 'Green_mean', 'Red_mean',
                  'RE1_mean', 'RE2_mean', 'RE3_mean',
                  'NIR_mean', 'SWIR1_mean', 'SWIR2_mean',
                  'NDVI_mean', 'MNDWI_mean', 'NBR_mean', 'EVI_mean',
                  'NDRE1_mean', 'NDRE2_mean', 'NDRE3_mean',
                  'CIrededge_mean', 'CLOUD_COVERAGE_mean']

feature_cols_avg = [c for c in plot_df.columns if c not in targets and c not in non_feature_cols]

X_plot = plot_df[feature_cols_avg]
y_plot = plot_df[target]

# %%
X_plot.columns
# Out:
# Index(['plot_id', 'plant_AGB_kg_count', 'Blue_mean', 'Green_mean', 'Red_mean',
#        'RE1_mean', 'RE2_mean', 'RE3_mean', 'NIR_mean', 'SWIR1_mean',
#        'SWIR2_mean', 'NDVI_mean', 'MNDWI_mean', 'NBR_mean', 'EVI_mean',
#        'NDRE1_mean', 'NDRE2_mean', 'NDRE3_mean', 'CIrededge_mean',
#        'CLOUD_COVERAGE_mean', 'height_mean'],
#       dtype='object')

# %%
print(f"Non-Sentinel Features : {set(feature_cols_avg) - set(sentinel_cols)}")
# Out:
# Non-Sentinel Features : {'plot_id', 'height_mean', 'plant_AGB_kg_count'}

# %%
print(f"Sentinel Features : {set(feature_cols_avg) - set(non_feature_cols) - set(['plot_id'])}")
# Out:
# Sentinel Features : {'plant_AGB_kg_count', 'Green_mean', 'NDRE3_mean', 'NBR_mean', 'SWIR1_mean', 'RE3_mean', 'EVI_mean', 'CLOUD_COVERAGE_mean', 'CIrededge_mean', 'Red_mean', 'MNDWI_mean', 'NDRE1_mean', 'NIR_mean', 'NDVI_mean', 'RE1_mean', 'RE2_mean', 'Blue_mean', 'SWIR2_mean', 'height_mean', 'NDRE2_mean'}

# %%
numerical_cols = get_numerical_cols(X_plot)
target_corr = plot_correlation_matrix(X_plot[numerical_cols],
                                      y_plot,
                                      top_n=20)
print(target_corr)
# Out:
# height_mean            0.449033
# EVI_mean               0.293036
# CIrededge_mean         0.267157
# NDRE1_mean             0.250277
# NIR_mean               0.242700
# RE3_mean               0.225970
# NDVI_mean              0.214131
# Red_mean               0.199162
# NDRE2_mean             0.194402
# RE1_mean               0.192343
# RE2_mean               0.178787
# NBR_mean               0.147452
# Green_mean             0.136956
# MNDWI_mean             0.135677
# Blue_mean              0.131772
# SWIR2_mean             0.105008
# plant_AGB_kg_count     0.076747
# SWIR1_mean             0.037037
# NDRE3_mean             0.026120
# CLOUD_COVERAGE_mean         NaN
# Name: plant_AGB_kg, dtype: float64

# %%
X_plot = X_plot.drop(columns=['CLOUD_COVERAGE_mean'])

# %%
features_list_avg = [
    ['height_mean'],
    ['height_mean', 'EVI_mean', 'NIR_mean', 'NBR_mean', 'SWIR1_mean'],
    ['height_mean', 'EVI_mean', 'NIR_mean', 'NBR_mean', 'SWIR1_mean', 'RE1_mean', 'RE2_mean'],
    ['Blue_mean', 'Green_mean', 'Red_mean', 'RE1_mean', 'RE2_mean', 'RE3_mean', 
     'NIR_mean', 'SWIR1_mean', 'SWIR2_mean'],
    ['NDVI_mean', 'MNDWI_mean', 'NBR_mean', 'EVI_mean', 
     'NDRE1_mean', 'NDRE2_mean', 'NDRE3_mean', 'CIrededge_mean'],
    ['height_mean', 'Blue_mean', 'Green_mean', 'Red_mean', 'RE1_mean', 'RE2_mean', 'RE3_mean',
     'NIR_mean', 'SWIR1_mean', 'SWIR2_mean', 'NDVI_mean', 'MNDWI_mean', 'NBR_mean', 'EVI_mean',
     'NDRE1_mean', 'NDRE2_mean', 'NDRE3_mean', 'CIrededge_mean'],
]

# %%
test_cv = 5

if 'plot_id' in X_plot.columns:
    X_plot = X_plot.drop(columns=['plot_id'])

# Near-zero and high AGB for evaluation — based directly on y values
low_threshold  = y_plot.quantile(0.25)
high_threshold = y_plot.quantile(0.75)

near_zero_plots_avg = y_plot[y_plot <= low_threshold].index.tolist()
high_agb_plots_avg  = y_plot[y_plot >= high_threshold].index.tolist()

print(f"Near-zero plots : {len(near_zero_plots_avg)}")
print(f"High-AGB plots  : {len(high_agb_plots_avg)}")

grp_belige_avg = GROUP_INFO(None, None,
                            near_zero_plots_avg, high_agb_plots_avg,
                            groups=None,
                            cv=test_cv)
# Out:
# Near-zero plots : 15
# High-AGB plots  : 15

# %% [markdown]
# ### BELIGE. PLOT-AVEAGE. LINEAR REGRESSION

# %%
# %run Model_functions.ipynb
lin_belige_plot_avg = {}

run_experiment(X_plot, y_plot,
               is_groups=False, group_info=grp_belige_avg,
               features_list=features_list_avg,
               experiments=lin_belige_plot_avg,
               model_type="linear",
               label = "Plot averages,"
               is_grid=False,
               is_stratified=is_stratified_g,
               global_experiment_list=global_experiment_list)
# Out:
# [1/24]
#
#  EXPERIMENT-1 Plot average,, Model: regular, Features: ['height_mean'], ALGO: LINEAR REGRESSION:
# Test R²     : -0.0397
# Test RMSE   : 17.19 kg
# Train R² (log scale): 0.2404
# Train R² (orig scale): -0.8533
# Train RMSE  : 33.63 kg
# Num rows    : 47
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: 0.0503
# CV R² std : 0.2225
# CV scores : [ 0.048  0.158 -0.378  0.195  0.228]
# ============================================================
#  EVALUATION: EXPERIMENT-1 Plot average,, Model: regular, Features: ['height_mean']
# ============================================================
#
# Test set:
#   R²   : -0.040
#   RMSE : 17.19 kg
#
#  ❌ Test R² is negative (-0.040)
#
# Regular CrossValidation:
#   Mean   : 0.050
#   Std    : 0.223
#   Scores : [ 0.048  0.158 -0.378  0.195  0.228]
#  ✅ CV mean is positive (0.050)
#   ✅ Train/test R² gap acceptable (gap: -0.814)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {RED_CROSS} REJECTED
#
# [2/24]
#
#  EXPERIMENT-2 Plot average,, Model: ridge, Features: ['height_mean'], ALGO: RIDGE REGRESSION:
# Test R²     : -0.0938
# Test RMSE   : 17.63 kg
# Train R² (log scale): 0.2330
# Train R² (orig scale): -0.1969
# Train RMSE  : 27.03 kg
# Num rows    : 47
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: 0.0624
# CV R² std : 0.1538
# CV scores : [ 0.043  0.119 -0.226  0.181  0.195]
# ============================================================
#  EVALUATION: EXPERIMENT-2 Plot average,, Model: ridge, Features: ['height_mean']
# ============================================================
#
# Test set:
#   R²   : -0.094
#   RMSE : 17.63 kg
#
#  ❌ Test R² is negative (-0.094)
#
# Regular CrossValidation:
#   Mean   : 0.062
#   Std    : 0.154
#   Scores : [ 0.043  0.119 -0.226  0.181  0.195]
#  ✅ CV mean is positive (0.062)
#   ✅ Train/test R² gap acceptable (gap: -0.103)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {RED_CROSS} REJECTED
#
# [3/24]
#
#  EXPERIMENT-3 Plot average,, Model: lasso, Features: ['height_mean'], ALGO: LASSO REGRESSION:
# Test R²     : -0.0824
# Test RMSE   : 17.53 kg
# Train R² (log scale): 0.2358
# Train R² (orig scale): -0.2686
# Train RMSE  : 27.83 kg
# Num rows    : 47
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: 0.1425
# CV R² std : 0.0557
# CV scores : [0.045 0.133 0.141 0.188 0.205]
# ============================================================
#  EVALUATION: EXPERIMENT-3 Plot average,, Model: lasso, Features: ['height_mean']
# ============================================================
#
# Test set:
#   R²   : -0.082
#   RMSE : 17.53 kg
#
#  ❌ Test R² is negative (-0.082)
#
# Regular CrossValidation:
#   Mean   : 0.143
#   Std    : 0.056
#   Scores : [0.045 0.133 0.141 0.188 0.205]
#  ✅ CV mean is positive (0.143)
#   ✅ Train/test R² gap acceptable (gap: -0.186)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {RED_CROSS} REJECTED
#
# [4/24]
#
#  EXPERIMENT-4 Plot average,, Model: elasticnet, Features: ['height_mean'], ALGO: ELASTICNET REGRESSION:
# Test R²     : -0.0749
# Test RMSE   : 17.47 kg
# Train R² (log scale): 0.2373
# Train R² (orig scale): -0.3300
# Train RMSE  : 28.49 kg
# Num rows    : 47
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: 0.1347
# CV R² std : 0.0623
# CV scores : [0.046 0.141 0.084 0.189 0.213]
# ============================================================
#  EVALUATION: EXPERIMENT-4 Plot average,, Model: elasticnet, Features: ['height_mean']
# ============================================================
#
# Test set:
#   R²   : -0.075
#   RMSE : 17.47 kg
#
#  ❌ Test R² is negative (-0.075)
#
# Regular CrossValidation:
#   Mean   : 0.135
#   Std    : 0.062
#   Scores : [0.046 0.141 0.084 0.189 0.213]
#  ✅ CV mean is positive (0.135)
#   ✅ Train/test R² gap acceptable (gap: -0.255)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {RED_CROSS} REJECTED
#
# [5/24]
#
#  EXPERIMENT-5 Plot average,, Model: regular, Features: ['height_mean', 'EVI_mean', 'NIR_mean', 'NBR_mean', 'SWIR1_mean'], ALGO: LINEAR REGRESSION:
# Test R²     : 0.4207
# Test RMSE   : 12.83 kg
# Train R² (log scale): 0.3819
# Train R² (orig scale): -0.0446
# Train RMSE  : 25.25 kg
# Num rows    : 47
# Num Features: 5
#
#  Cross-validation ---
# CV R² mean: 0.2439
# CV R² std : 0.1503
# CV scores : [0.079 0.334 0.237 0.477 0.091]
# ============================================================
#  EVALUATION: EXPERIMENT-5 Plot average,, Model: regular, Features: ['height_mean', 'EVI_mean', 'NIR_mean', 'NBR_mean', 'SWIR1_mean']
# ============================================================
#
# Test set:
#   R²   : 0.421
#   RMSE : 12.83 kg
#
#  ✅ Test R² is positive (0.421)
#
# Regular CrossValidation:
#   Mean   : 0.244
#   Std    : 0.150
#   Scores : [0.079 0.334 0.237 0.477 0.091]
#  ✅ CV mean is positive (0.244)
#   ✅ Train/test R² gap acceptable (gap: -0.465)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [6/24]
#
#  EXPERIMENT-6 Plot average,, Model: ridge, Features: ['height_mean', 'EVI_mean', 'NIR_mean', 'NBR_mean', 'SWIR1_mean'], ALGO: RIDGE REGRESSION:
# Test R²     : 0.3564
# Test RMSE   : 13.52 kg
# Train R² (log scale): 0.3554
# Train R² (orig scale): -0.0296
# Train RMSE  : 25.07 kg
# Num rows    : 47
# Num Features: 5
#
#  Cross-validation ---
# CV R² mean: 0.3194
# CV R² std : 0.2546
# CV scores : [0.047 0.344 0.745 0.392 0.069]
# ============================================================
#  EVALUATION: EXPERIMENT-6 Plot average,, Model: ridge, Features: ['height_mean', 'EVI_mean', 'NIR_mean', 'NBR_mean', 'SWIR1_mean']
# ============================================================
#
# Test set:
#   R²   : 0.356
#   RMSE : 13.52 kg
#
#  ✅ Test R² is positive (0.356)
#
# Regular CrossValidation:
#   Mean   : 0.319
#   Std    : 0.255
#   Scores : [0.047 0.344 0.745 0.392 0.069]
#  ✅ CV mean is positive (0.319)
#   ✅ Train/test R² gap acceptable (gap: -0.386)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [7/24]
#
#  EXPERIMENT-7 Plot average,, Model: lasso, Features: ['height_mean', 'EVI_mean', 'NIR_mean', 'NBR_mean', 'SWIR1_mean'], ALGO: LASSO REGRESSION:
# Test R²     : 0.3373
# Test RMSE   : 13.72 kg
# Train R² (log scale): 0.3598
# Train R² (orig scale): -0.0253
# Train RMSE  : 25.02 kg
# Num rows    : 47
# Num Features: 5
#
#  Cross-validation ---
# CV R² mean: 0.3263
# CV R² std : 0.2180
# CV scores : [0.073 0.356 0.682 0.396 0.124]
# ============================================================
#  EVALUATION: EXPERIMENT-7 Plot average,, Model: lasso, Features: ['height_mean', 'EVI_mean', 'NIR_mean', 'NBR_mean', 'SWIR1_mean']
# ============================================================
#
# Test set:
#   R²   : 0.337
#   RMSE : 13.72 kg
#
#  ✅ Test R² is positive (0.337)
#
# Regular CrossValidation:
#   Mean   : 0.326
#   Std    : 0.218
#   Scores : [0.073 0.356 0.682 0.396 0.124]
#  ✅ CV mean is positive (0.326)
#   ✅ Train/test R² gap acceptable (gap: -0.363)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [8/24]
#
#  EXPERIMENT-8 Plot average,, Model: elasticnet, Features: ['height_mean', 'EVI_mean', 'NIR_mean', 'NBR_mean', 'SWIR1_mean'], ALGO: ELASTICNET REGRESSION:
# Test R²     : 0.3443
# Test RMSE   : 13.65 kg
# Train R² (log scale): 0.3610
# Train R² (orig scale): -0.0272
# Train RMSE  : 25.04 kg
# Num rows    : 47
# Num Features: 5
#
#  Cross-validation ---
# CV R² mean: 0.3222
# CV R² std : 0.2128
# CV scores : [0.072 0.361 0.659 0.403 0.116]
# ============================================================
#  EVALUATION: EXPERIMENT-8 Plot average,, Model: elasticnet, Features: ['height_mean', 'EVI_mean', 'NIR_mean', 'NBR_mean', 'SWIR1_mean']
# ============================================================
#
# Test set:
#   R²   : 0.344
#   RMSE : 13.65 kg
#
#  ✅ Test R² is positive (0.344)
#
# Regular CrossValidation:
#   Mean   : 0.322
#   Std    : 0.213
#   Scores : [0.072 0.361 0.659 0.403 0.116]
#  ✅ CV mean is positive (0.322)
#   ✅ Train/test R² gap acceptable (gap: -0.371)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [9/24]
#
#  EXPERIMENT-9 Plot average,, Model: regular, Features: ['height_mean', 'EVI_mean', 'NIR_mean', 'NBR_mean', 'SWIR1_mean', 'RE1_mean', 'RE2_mean'], ALGO: LINEAR REGRESSION:
# Test R²     : 0.4949
# Test RMSE   : 11.98 kg
# Train R² (log scale): 0.4187
# Train R² (orig scale): 0.0247
# Train RMSE  : 24.40 kg
# Num rows    : 47
# Num Features: 7
#
#  Cross-validation ---
# CV R² mean: 0.1837
# CV R² std : 0.1342
# CV scores : [0.127 0.028 0.408 0.256 0.099]
# ============================================================
#  EVALUATION: EXPERIMENT-9 Plot average,, Model: regular, Features: ['height_mean', 'EVI_mean', 'NIR_mean', 'NBR_mean', 'SWIR1_mean', 'RE1_mean', 'RE2_mean']
# ============================================================
#
# Test set:
#   R²   : 0.495
#   RMSE : 11.98 kg
#
#  ✅ Test R² is positive (0.495)
#
# Regular CrossValidation:
#   Mean   : 0.184
#   Std    : 0.134
#   Scores : [0.127 0.028 0.408 0.256 0.099]
#  ✅ CV mean is positive (0.184)
#   ✅ Train/test R² gap acceptable (gap: -0.470)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [10/24]
#
#  EXPERIMENT-10 Plot average,, Model: ridge, Features: ['height_mean', 'EVI_mean', 'NIR_mean', 'NBR_mean', 'SWIR1_mean', 'RE1_mean', 'RE2_mean'], ALGO: RIDGE REGRESSION:
# Test R²     : 0.3530
# Test RMSE   : 13.56 kg
# Train R² (log scale): 0.3550
# Train R² (orig scale): -0.0287
# Train RMSE  : 25.06 kg
# Num rows    : 47
# Num Features: 7
#
#  Cross-validation ---
# CV R² mean: 0.2592
# CV R² std : 0.2683
# CV scores : [-0.002  0.133  0.727  0.382  0.055]
# ============================================================
#  EVALUATION: EXPERIMENT-10 Plot average,, Model: ridge, Features: ['height_mean', 'EVI_mean', 'NIR_mean', 'NBR_mean', 'SWIR1_mean', 'RE1_mean', 'RE2_mean']
# ============================================================
#
# Test set:
#   R²   : 0.353
#   RMSE : 13.56 kg
#
#  ✅ Test R² is positive (0.353)
#
# Regular CrossValidation:
#   Mean   : 0.259
#   Std    : 0.268
#   Scores : [-0.002  0.133  0.727  0.382  0.055]
#  ✅ CV mean is positive (0.259)
#   ✅ Train/test R² gap acceptable (gap: -0.382)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [11/24]
#
#  EXPERIMENT-11 Plot average,, Model: lasso, Features: ['height_mean', 'EVI_mean', 'NIR_mean', 'NBR_mean', 'SWIR1_mean', 'RE1_mean', 'RE2_mean'], ALGO: LASSO REGRESSION:
# Test R²     : 0.3373
# Test RMSE   : 13.72 kg
# Train R² (log scale): 0.3598
# Train R² (orig scale): -0.0253
# Train RMSE  : 25.02 kg
# Num rows    : 47
# Num Features: 7
#
#  Cross-validation ---
# CV R² mean: 0.3219
# CV R² std : 0.2233
# CV scores : [0.051 0.356 0.682 0.396 0.124]
# ============================================================
#  EVALUATION: EXPERIMENT-11 Plot average,, Model: lasso, Features: ['height_mean', 'EVI_mean', 'NIR_mean', 'NBR_mean', 'SWIR1_mean', 'RE1_mean', 'RE2_mean']
# ============================================================
#
# Test set:
#   R²   : 0.337
#   RMSE : 13.72 kg
#
#  ✅ Test R² is positive (0.337)
#
# Regular CrossValidation:
#   Mean   : 0.322
#   Std    : 0.223
#   Scores : [0.051 0.356 0.682 0.396 0.124]
#  ✅ CV mean is positive (0.322)
#   ✅ Train/test R² gap acceptable (gap: -0.363)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [12/24]
#
#  EXPERIMENT-12 Plot average,, Model: elasticnet, Features: ['height_mean', 'EVI_mean', 'NIR_mean', 'NBR_mean', 'SWIR1_mean', 'RE1_mean', 'RE2_mean'], ALGO: ELASTICNET REGRESSION:
# Test R²     : 0.3443
# Test RMSE   : 13.65 kg
# Train R² (log scale): 0.3610
# Train R² (orig scale): -0.0272
# Train RMSE  : 25.04 kg
# Num rows    : 47
# Num Features: 7
#
#  Cross-validation ---
# CV R² mean: 0.3168
# CV R² std : 0.2193
# CV scores : [0.045 0.361 0.659 0.403 0.116]
# ============================================================
#  EVALUATION: EXPERIMENT-12 Plot average,, Model: elasticnet, Features: ['height_mean', 'EVI_mean', 'NIR_mean', 'NBR_mean', 'SWIR1_mean', 'RE1_mean', 'RE2_mean']
# ============================================================
#
# Test set:
#   R²   : 0.344
#   RMSE : 13.65 kg
#
#  ✅ Test R² is positive (0.344)
#
# Regular CrossValidation:
#   Mean   : 0.317
#   Std    : 0.219
#   Scores : [0.045 0.361 0.659 0.403 0.116]
#  ✅ CV mean is positive (0.317)
#   ✅ Train/test R² gap acceptable (gap: -0.371)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [13/24]
#
#  EXPERIMENT-13 Plot average,, Model: regular, Features: ['Blue_mean', 'Green_mean', 'Red_mean', 'RE1_mean', 'RE2_mean', 'RE3_mean', 'NIR_mean', 'SWIR1_mean', 'SWIR2_mean'], ALGO: LINEAR REGRESSION:
# Test R²     : 0.3947
# Test RMSE   : 13.11 kg
# Train R² (log scale): 0.5344
# Train R² (orig scale): 0.1980
# Train RMSE  : 22.13 kg
# Num rows    : 47
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: 0.0162
# CV R² std : 0.4306
# CV scores : [-0.212 -0.607 -0.105  0.489  0.515]
# ============================================================
#  EVALUATION: EXPERIMENT-13 Plot average,, Model: regular, Features: ['Blue_mean', 'Green_mean', 'Red_mean', 'RE1_mean', 'RE2_mean', 'RE3_mean', 'NIR_mean', 'SWIR1_mean', 'SWIR2_mean']
# ============================================================
#
# Test set:
#   R²   : 0.395
#   RMSE : 13.11 kg
#
#  ✅ Test R² is positive (0.395)
#
# Regular CrossValidation:
#   Mean   : 0.016
#   Std    : 0.431
#   Scores : [-0.212 -0.607 -0.105  0.489  0.515]
#  ✅ CV mean is positive (0.016)
#   ✅ Train/test R² gap acceptable (gap: -0.197)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [14/24]
#
#  EXPERIMENT-14 Plot average,, Model: ridge, Features: ['Blue_mean', 'Green_mean', 'Red_mean', 'RE1_mean', 'RE2_mean', 'RE3_mean', 'NIR_mean', 'SWIR1_mean', 'SWIR2_mean'], ALGO: RIDGE REGRESSION:
# Test R²     : 0.4197
# Test RMSE   : 12.84 kg
# Train R² (log scale): 0.4057
# Train R² (orig scale): -0.0380
# Train RMSE  : 25.17 kg
# Num rows    : 47
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: 0.0426
# CV R² std : 0.3348
# CV scores : [ 0.069 -0.577  0.099  0.429  0.193]
# ============================================================
#  EVALUATION: EXPERIMENT-14 Plot average,, Model: ridge, Features: ['Blue_mean', 'Green_mean', 'Red_mean', 'RE1_mean', 'RE2_mean', 'RE3_mean', 'NIR_mean', 'SWIR1_mean', 'SWIR2_mean']
# ============================================================
#
# Test set:
#   R²   : 0.420
#   RMSE : 12.84 kg
#
#  ✅ Test R² is positive (0.420)
#
# Regular CrossValidation:
#   Mean   : 0.043
#   Std    : 0.335
#   Scores : [ 0.069 -0.577  0.099  0.429  0.193]
#  ✅ CV mean is positive (0.043)
#   ✅ Train/test R² gap acceptable (gap: -0.458)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [15/24]
#
#  EXPERIMENT-15 Plot average,, Model: lasso, Features: ['Blue_mean', 'Green_mean', 'Red_mean', 'RE1_mean', 'RE2_mean', 'RE3_mean', 'NIR_mean', 'SWIR1_mean', 'SWIR2_mean'], ALGO: LASSO REGRESSION:
# Test R²     : 0.4837
# Test RMSE   : 12.11 kg
# Train R² (log scale): 0.4939
# Train R² (orig scale): 0.0950
# Train RMSE  : 23.50 kg
# Num rows    : 47
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: 0.0451
# CV R² std : 0.3376
# CV scores : [ 0.183 -0.601  0.185  0.381  0.078]
# ============================================================
#  EVALUATION: EXPERIMENT-15 Plot average,, Model: lasso, Features: ['Blue_mean', 'Green_mean', 'Red_mean', 'RE1_mean', 'RE2_mean', 'RE3_mean', 'NIR_mean', 'SWIR1_mean', 'SWIR2_mean']
# ============================================================
#
# Test set:
#   R²   : 0.484
#   RMSE : 12.11 kg
#
#  ✅ Test R² is positive (0.484)
#
# Regular CrossValidation:
#   Mean   : 0.045
#   Std    : 0.338
#   Scores : [ 0.183 -0.601  0.185  0.381  0.078]
#  ✅ CV mean is positive (0.045)
#   ✅ Train/test R² gap acceptable (gap: -0.389)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [16/24]
#
#  EXPERIMENT-16 Plot average,, Model: elasticnet, Features: ['Blue_mean', 'Green_mean', 'Red_mean', 'RE1_mean', 'RE2_mean', 'RE3_mean', 'NIR_mean', 'SWIR1_mean', 'SWIR2_mean'], ALGO: ELASTICNET REGRESSION:
# Test R²     : 0.4804
# Test RMSE   : 12.15 kg
# Train R² (log scale): 0.5053
# Train R² (orig scale): 0.1081
# Train RMSE  : 23.33 kg
# Num rows    : 47
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: 0.0997
# CV R² std : 0.3412
# CV scores : [ 0.089 -0.536  0.216  0.474  0.255]
# ============================================================
#  EVALUATION: EXPERIMENT-16 Plot average,, Model: elasticnet, Features: ['Blue_mean', 'Green_mean', 'Red_mean', 'RE1_mean', 'RE2_mean', 'RE3_mean', 'NIR_mean', 'SWIR1_mean', 'SWIR2_mean']
# ============================================================
#
# Test set:
#   R²   : 0.480
#   RMSE : 12.15 kg
#
#  ✅ Test R² is positive (0.480)
#
# Regular CrossValidation:
#   Mean   : 0.100
#   Std    : 0.341
#   Scores : [ 0.089 -0.536  0.216  0.474  0.255]
#  ✅ CV mean is positive (0.100)
#   ✅ Train/test R² gap acceptable (gap: -0.372)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [17/24]
#
#  EXPERIMENT-17 Plot average,, Model: regular, Features: ['NDVI_mean', 'MNDWI_mean', 'NBR_mean', 'EVI_mean', 'NDRE1_mean', 'NDRE2_mean', 'NDRE3_mean', 'CIrededge_mean'], ALGO: LINEAR REGRESSION:
# Test R²     : -316.6002
# Test RMSE   : 300.37 kg
# Train R² (log scale): 0.4642
# Train R² (orig scale): -0.2094
# Train RMSE  : 27.17 kg
# Num rows    : 47
# Num Features: 8
#
#  Cross-validation ---
# CV R² mean: -0.2013
# CV R² std : 0.4001
# CV scores : [ 0.043 -0.251 -0.95   0.187 -0.036]
# ============================================================
#  EVALUATION: EXPERIMENT-17 Plot average,, Model: regular, Features: ['NDVI_mean', 'MNDWI_mean', 'NBR_mean', 'EVI_mean', 'NDRE1_mean', 'NDRE2_mean', 'NDRE3_mean', 'CIrededge_mean']
# ============================================================
#
# Test set:
#   R²   : -316.600
#   RMSE : 300.37 kg
#
#  ❌ Test R² is negative (-316.600)
#
# Regular CrossValidation:
#   Mean   : -0.201
#   Std    : 0.400
#   Scores : [ 0.043 -0.251 -0.95   0.187 -0.036]
#  ❌ CV mean is negative (-0.201)
#   ⚠️  Train R² well above test R² (gap: 316.391 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: {RED_CROSS} REJECTED
#
# [18/24]
#
#  EXPERIMENT-18 Plot average,, Model: ridge, Features: ['NDVI_mean', 'MNDWI_mean', 'NBR_mean', 'EVI_mean', 'NDRE1_mean', 'NDRE2_mean', 'NDRE3_mean', 'CIrededge_mean'], ALGO: RIDGE REGRESSION:
# Test R²     : 0.0466
# Test RMSE   : 16.46 kg
# Train R² (log scale): 0.3381
# Train R² (orig scale): -0.0699
# Train RMSE  : 25.56 kg
# Num rows    : 47
# Num Features: 8
#
#  Cross-validation ---
# CV R² mean: 0.1352
# CV R² std : 0.1794
# CV scores : [-0.078  0.035  0.441  0.216  0.062]
# ============================================================
#  EVALUATION: EXPERIMENT-18 Plot average,, Model: ridge, Features: ['NDVI_mean', 'MNDWI_mean', 'NBR_mean', 'EVI_mean', 'NDRE1_mean', 'NDRE2_mean', 'NDRE3_mean', 'CIrededge_mean']
# ============================================================
#
# Test set:
#   R²   : 0.047
#   RMSE : 16.46 kg
#
#  ✅ Test R² is positive (0.047)
#
# Regular CrossValidation:
#   Mean   : 0.135
#   Std    : 0.179
#   Scores : [-0.078  0.035  0.441  0.216  0.062]
#  ✅ CV mean is positive (0.135)
#   ✅ Train/test R² gap acceptable (gap: -0.117)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [19/24]
#
#  EXPERIMENT-19 Plot average,, Model: lasso, Features: ['NDVI_mean', 'MNDWI_mean', 'NBR_mean', 'EVI_mean', 'NDRE1_mean', 'NDRE2_mean', 'NDRE3_mean', 'CIrededge_mean'], ALGO: LASSO REGRESSION:
# Test R²     : 0.3049
# Test RMSE   : 14.05 kg
# Train R² (log scale): 0.3125
# Train R² (orig scale): -0.0789
# Train RMSE  : 25.66 kg
# Num rows    : 47
# Num Features: 8
#
#  Cross-validation ---
# CV R² mean: 0.2334
# CV R² std : 0.1961
# CV scores : [-0.05   0.249  0.499  0.378  0.091]
# ============================================================
#  EVALUATION: EXPERIMENT-19 Plot average,, Model: lasso, Features: ['NDVI_mean', 'MNDWI_mean', 'NBR_mean', 'EVI_mean', 'NDRE1_mean', 'NDRE2_mean', 'NDRE3_mean', 'CIrededge_mean']
# ============================================================
#
# Test set:
#   R²   : 0.305
#   RMSE : 14.05 kg
#
#  ✅ Test R² is positive (0.305)
#
# Regular CrossValidation:
#   Mean   : 0.233
#   Std    : 0.196
#   Scores : [-0.05   0.249  0.499  0.378  0.091]
#  ✅ CV mean is positive (0.233)
#   ✅ Train/test R² gap acceptable (gap: -0.384)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [20/24]
#
#  EXPERIMENT-20 Plot average,, Model: elasticnet, Features: ['NDVI_mean', 'MNDWI_mean', 'NBR_mean', 'EVI_mean', 'NDRE1_mean', 'NDRE2_mean', 'NDRE3_mean', 'CIrededge_mean'], ALGO: ELASTICNET REGRESSION:
# Test R²     : 0.2986
# Test RMSE   : 14.12 kg
# Train R² (log scale): 0.3231
# Train R² (orig scale): -0.0735
# Train RMSE  : 25.60 kg
# Num rows    : 47
# Num Features: 8
#
#  Cross-validation ---
# CV R² mean: 0.1987
# CV R² std : 0.1705
# CV scores : [-0.063  0.2    0.373  0.388  0.096]
# ============================================================
#  EVALUATION: EXPERIMENT-20 Plot average,, Model: elasticnet, Features: ['NDVI_mean', 'MNDWI_mean', 'NBR_mean', 'EVI_mean', 'NDRE1_mean', 'NDRE2_mean', 'NDRE3_mean', 'CIrededge_mean']
# ============================================================
#
# Test set:
#   R²   : 0.299
#   RMSE : 14.12 kg
#
#  ✅ Test R² is positive (0.299)
#
# Regular CrossValidation:
#   Mean   : 0.199
#   Std    : 0.170
#   Scores : [-0.063  0.2    0.373  0.388  0.096]
#  ✅ CV mean is positive (0.199)
#   ✅ Train/test R² gap acceptable (gap: -0.372)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# [21/24]
#
#  EXPERIMENT-21 Plot average,, Model: regular, Features: ['height_mean', 'Blue_mean', 'Green_mean', 'Red_mean', 'RE1_mean', 'RE2_mean', 'RE3_mean', 'NIR_mean', 'SWIR1_mean', 'SWIR2_mean', 'NDVI_mean', 'MNDWI_mean', 'NBR_mean', 'EVI_mean', 'NDRE1_mean', 'NDRE2_mean', 'NDRE3_mean', 'CIrededge_mean'], ALGO: LINEAR REGRESSION:
# Test R²     : -1888670.4445
# Test RMSE   : 23162.66 kg
# Train R² (log scale): 0.8201
# Train R² (orig scale): 0.6073
# Train RMSE  : 15.48 kg
# Num rows    : 47
# Num Features: 18
#
#  Cross-validation ---
# CV R² mean: -0.9560
# CV R² std : 1.6015
# CV scores : [-1.168  0.433 -3.961  0.229 -0.314]
# ============================================================
#  EVALUATION: EXPERIMENT-21 Plot average,, Model: regular, Features: ['height_mean', 'Blue_mean', 'Green_mean', 'Red_mean', 'RE1_mean', 'RE2_mean', 'RE3_mean', 'NIR_mean', 'SWIR1_mean', 'SWIR2_mean', 'NDVI_mean', 'MNDWI_mean', 'NBR_mean', 'EVI_mean', 'NDRE1_mean', 'NDRE2_mean', 'NDRE3_mean', 'CIrededge_mean']
# ============================================================
#
# Test set:
#   R²   : -1888670.445
#   RMSE : 23162.66 kg
#
#  ❌ Test R² is negative (-1888670.445)
#
# Regular CrossValidation:
#   Mean   : -0.956
#   Std    : 1.601
#   Scores : [-1.168  0.433 -3.961  0.229 -0.314]
#  ❌ CV mean is negative (-0.956)
#   ⚠️  Train R² well above test R² (gap: 1888671.052 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: {RED_CROSS} REJECTED
#
# [22/24]
#
#  EXPERIMENT-22 Plot average,, Model: ridge, Features: ['height_mean', 'Blue_mean', 'Green_mean', 'Red_mean', 'RE1_mean', 'RE2_mean', 'RE3_mean', 'NIR_mean', 'SWIR1_mean', 'SWIR2_mean', 'NDVI_mean', 'MNDWI_mean', 'NBR_mean', 'EVI_mean', 'NDRE1_mean', 'NDRE2_mean', 'NDRE3_mean', 'CIrededge_mean'], ALGO: RIDGE REGRESSION:
# Test R²     : 0.4168
# Test RMSE   : 12.87 kg
# Train R² (log scale): 0.5147
# Train R² (orig scale): 0.0556
# Train RMSE  : 24.01 kg
# Num rows    : 47
# Num Features: 18
#
#  Cross-validation ---
# CV R² mean: -0.0099
# CV R² std : 0.6232
# CV scores : [ 0.147  0.092 -1.2    0.286  0.626]
# ============================================================
#  EVALUATION: EXPERIMENT-22 Plot average,, Model: ridge, Features: ['height_mean', 'Blue_mean', 'Green_mean', 'Red_mean', 'RE1_mean', 'RE2_mean', 'RE3_mean', 'NIR_mean', 'SWIR1_mean', 'SWIR2_mean', 'NDVI_mean', 'MNDWI_mean', 'NBR_mean', 'EVI_mean', 'NDRE1_mean', 'NDRE2_mean', 'NDRE3_mean', 'CIrededge_mean']
# ============================================================
#
# Test set:
#   R²   : 0.417
#   RMSE : 12.87 kg
#
#  ✅ Test R² is positive (0.417)
#
# Regular CrossValidation:
#   Mean   : -0.010
#   Std    : 0.623
#   Scores : [ 0.147  0.092 -1.2    0.286  0.626]
#  ❌ CV mean is negative (-0.010)
#   ✅ Train/test R² gap acceptable (gap: -0.361)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {RED_CROSS} REJECTED
#
# [23/24]
#
#  EXPERIMENT-23 Plot average,, Model: lasso, Features: ['height_mean', 'Blue_mean', 'Green_mean', 'Red_mean', 'RE1_mean', 'RE2_mean', 'RE3_mean', 'NIR_mean', 'SWIR1_mean', 'SWIR2_mean', 'NDVI_mean', 'MNDWI_mean', 'NBR_mean', 'EVI_mean', 'NDRE1_mean', 'NDRE2_mean', 'NDRE3_mean', 'CIrededge_mean'], ALGO: LASSO REGRESSION:
# Test R²     : 0.8321
# Test RMSE   : 6.91 kg
# Train R² (log scale): 0.7434
# Train R² (orig scale): 0.3536
# Train RMSE  : 19.86 kg
# Num rows    : 47
# Num Features: 18
#
#  Cross-validation ---
# CV R² mean: -0.0239
# CV R² std : 0.5396
# CV scores : [ 0.244  0.341 -1.09   0.294  0.091]
# ============================================================
#  EVALUATION: EXPERIMENT-23 Plot average,, Model: lasso, Features: ['height_mean', 'Blue_mean', 'Green_mean', 'Red_mean', 'RE1_mean', 'RE2_mean', 'RE3_mean', 'NIR_mean', 'SWIR1_mean', 'SWIR2_mean', 'NDVI_mean', 'MNDWI_mean', 'NBR_mean', 'EVI_mean', 'NDRE1_mean', 'NDRE2_mean', 'NDRE3_mean', 'CIrededge_mean']
# ============================================================
#
# Test set:
#   R²   : 0.832
#   RMSE : 6.91 kg
#
#  ✅ Test R² is positive (0.832)
#
# Regular CrossValidation:
#   Mean   : -0.024
#   Std    : 0.540
#   Scores : [ 0.244  0.341 -1.09   0.294  0.091]
#  ❌ CV mean is negative (-0.024)
#   ✅ Train/test R² gap acceptable (gap: -0.478)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {RED_CROSS} REJECTED
#
# [24/24]
#
#  EXPERIMENT-24 Plot average,, Model: elasticnet, Features: ['height_mean', 'Blue_mean', 'Green_mean', 'Red_mean', 'RE1_mean', 'RE2_mean', 'RE3_mean', 'NIR_mean', 'SWIR1_mean', 'SWIR2_mean', 'NDVI_mean', 'MNDWI_mean', 'NBR_mean', 'EVI_mean', 'NDRE1_mean', 'NDRE2_mean', 'NDRE3_mean', 'CIrededge_mean'], ALGO: ELASTICNET REGRESSION:
# Test R²     : 0.8011
# Test RMSE   : 7.52 kg
# Train R² (log scale): 0.7405
# Train R² (orig scale): 0.3675
# Train RMSE  : 19.65 kg
# Num rows    : 47
# Num Features: 18
#
#  Cross-validation ---
# CV R² mean: 0.0655
# CV R² std : 0.3956
# CV scores : [ 0.41   0.02  -0.683  0.318  0.263]
# ============================================================
#  EVALUATION: EXPERIMENT-24 Plot average,, Model: elasticnet, Features: ['height_mean', 'Blue_mean', 'Green_mean', 'Red_mean', 'RE1_mean', 'RE2_mean', 'RE3_mean', 'NIR_mean', 'SWIR1_mean', 'SWIR2_mean', 'NDVI_mean', 'MNDWI_mean', 'NBR_mean', 'EVI_mean', 'NDRE1_mean', 'NDRE2_mean', 'NDRE3_mean', 'CIrededge_mean']
# ============================================================
#
# Test set:
#   R²   : 0.801
#   RMSE : 7.52 kg
#
#  ✅ Test R² is positive (0.801)
#
# Regular CrossValidation:
#   Mean   : 0.066
#   Std    : 0.396
#   Scores : [ 0.41   0.02  -0.683  0.318  0.263]
#  ✅ CV mean is positive (0.066)
#   ✅ Train/test R² gap acceptable (gap: -0.434)
#
# ────────────────────────────────────────────────────────────
# VERDICT: {GREEN_TICK} ACCEPTABLE
#
# Completed: 24/24 experiments

# %% [markdown]
# Key findings
#
# Exp 23 (Lasso, all features) — Test R² 0.832 is suspicious. CV mean is −0.024 with a fold score of −1.09. This is a classic sign of lucky test split, not genuine generalisation. The model fits 18 features on 47 rows — severely underdetermined. Lasso is shrinking aggressively but the test set happened to align well. Discard.
#
# Exp 24 (ElasticNet, all features) — Test R² 0.801, CV mean 0.066. Same problem — CV is near zero while test is 0.80. The gap is too large to trust.
#
# Exp 21 (OLS, all features) — Test R² −1,888,670. Perfect illustration of what happens when you fit 18 features on 47 rows with no regularisation. Complete numerical collapse.
#
# The genuinely trustworthy results are Exp 5–12 — height + spectral subsets with moderate feature counts.
# ![image.png](attachment:6db2ce9f-109a-478f-b2e4-20fabd6abc90.png)
#
# Exp 9 has the best test R² among honest models. Exp 7 has the best CV mean with tight std. The plot-level signal is real and stronger than the tree-level results (0.49 vs 0.28), which makes sense — plot averaging suppresses within-plot noise.
#
# The consistent message: height_mean combined with a handful of spectral features is the right feature set. All-feature models are too many parameters for 59 plots.

# %%
# %run Model_functions.ipynb
tabulate_results(lin_belige_plot_avg, acceptable_only=True)
# Out:
# Showing 16 acceptable experiments
# <style type="text/css">
# #T_587c7_row0_col6, #T_587c7_row12_col2, #T_587c7_row12_col3 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_587c7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_587c7_level0_col0" class="col_heading level0 col0" >Experiment</th>
#       <th id="T_587c7_level0_col1" class="col_heading level0 col1" >Num_features</th>
#       <th id="T_587c7_level0_col2" class="col_heading level0 col2" >Test R²</th>
#       <th id="T_587c7_level0_col3" class="col_heading level0 col3" >Test RMSE</th>
#       <th id="T_587c7_level0_col4" class="col_heading level0 col4" >Train R²</th>
#       <th id="T_587c7_level0_col5" class="col_heading level0 col5" >Train RMSE</th>
#       <th id="T_587c7_level0_col6" class="col_heading level0 col6" >CV R² Mean</th>
#       <th id="T_587c7_level0_col7" class="col_heading level0 col7" >CV R² Std</th>
#       <th id="T_587c7_level0_col8" class="col_heading level0 col8" >verdict</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_587c7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_587c7_row0_col0" class="data row0 col0" >EXPERIMENT-7 Plot average,, Model: lasso, Features: ['height_mean', 'EVI_mean', 'NIR_mean', 'NBR_mean', 'SWIR1_mean']</td>
#       <td id="T_587c7_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_587c7_row0_col2" class="data row0 col2" >0.3373</td>
#       <td id="T_587c7_row0_col3" class="data row0 col3" >13.72</td>
#       <td id="T_587c7_row0_col4" class="data row0 col4" >-0.0253</td>
#       <td id="T_587c7_row0_col5" class="data row0 col5" >25.02</td>
#       <td id="T_587c7_row0_col6" class="data row0 col6" >0.3263</td>
#       <td id="T_587c7_row0_col7" class="data row0 col7" >0.218</td>
#       <td id="T_587c7_row0_col8" class="data row0 col8" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_587c7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_587c7_row1_col0" class="data row1 col0" >EXPERIMENT-8 Plot average,, Model: elasticnet, Features: ['height_mean', 'EVI_mean', 'NIR_mean', 'NBR_mean', 'SWIR1_mean']</td>
#       <td id="T_587c7_row1_col1" class="data row1 col1" >5</td>
#       <td id="T_587c7_row1_col2" class="data row1 col2" >0.3443</td>
#       <td id="T_587c7_row1_col3" class="data row1 col3" >13.65</td>
#       <td id="T_587c7_row1_col4" class="data row1 col4" >-0.0272</td>
#       <td id="T_587c7_row1_col5" class="data row1 col5" >25.04</td>
#       <td id="T_587c7_row1_col6" class="data row1 col6" >0.3222</td>
#       <td id="T_587c7_row1_col7" class="data row1 col7" >0.2128</td>
#       <td id="T_587c7_row1_col8" class="data row1 col8" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_587c7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_587c7_row2_col0" class="data row2 col0" >EXPERIMENT-11 Plot average,, Model: lasso, Features: ['height_mean', 'EVI_mean', 'NIR_mean', 'NBR_mean', 'SWIR1_mean', 'RE1_mean', 'RE2_mean']</td>
#       <td id="T_587c7_row2_col1" class="data row2 col1" >7</td>
#       <td id="T_587c7_row2_col2" class="data row2 col2" >0.3373</td>
#       <td id="T_587c7_row2_col3" class="data row2 col3" >13.72</td>
#       <td id="T_587c7_row2_col4" class="data row2 col4" >-0.0253</td>
#       <td id="T_587c7_row2_col5" class="data row2 col5" >25.02</td>
#       <td id="T_587c7_row2_col6" class="data row2 col6" >0.3219</td>
#       <td id="T_587c7_row2_col7" class="data row2 col7" >0.2233</td>
#       <td id="T_587c7_row2_col8" class="data row2 col8" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_587c7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_587c7_row3_col0" class="data row3 col0" >EXPERIMENT-6 Plot average,, Model: ridge, Features: ['height_mean', 'EVI_mean', 'NIR_mean', 'NBR_mean', 'SWIR1_mean']</td>
#       <td id="T_587c7_row3_col1" class="data row3 col1" >5</td>
#       <td id="T_587c7_row3_col2" class="data row3 col2" >0.3564</td>
#       <td id="T_587c7_row3_col3" class="data row3 col3" >13.52</td>
#       <td id="T_587c7_row3_col4" class="data row3 col4" >-0.0296</td>
#       <td id="T_587c7_row3_col5" class="data row3 col5" >25.07</td>
#       <td id="T_587c7_row3_col6" class="data row3 col6" >0.3194</td>
#       <td id="T_587c7_row3_col7" class="data row3 col7" >0.2546</td>
#       <td id="T_587c7_row3_col8" class="data row3 col8" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_587c7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_587c7_row4_col0" class="data row4 col0" >EXPERIMENT-12 Plot average,, Model: elasticnet, Features: ['height_mean', 'EVI_mean', 'NIR_mean', 'NBR_mean', 'SWIR1_mean', 'RE1_mean', 'RE2_mean']</td>
#       <td id="T_587c7_row4_col1" class="data row4 col1" >7</td>
#       <td id="T_587c7_row4_col2" class="data row4 col2" >0.3443</td>
#       <td id="T_587c7_row4_col3" class="data row4 col3" >13.65</td>
#       <td id="T_587c7_row4_col4" class="data row4 col4" >-0.0272</td>
#       <td id="T_587c7_row4_col5" class="data row4 col5" >25.04</td>
#       <td id="T_587c7_row4_col6" class="data row4 col6" >0.3168</td>
#       <td id="T_587c7_row4_col7" class="data row4 col7" >0.2193</td>
#       <td id="T_587c7_row4_col8" class="data row4 col8" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_587c7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_587c7_row5_col0" class="data row5 col0" >EXPERIMENT-10 Plot average,, Model: ridge, Features: ['height_mean', 'EVI_mean', 'NIR_mean', 'NBR_mean', 'SWIR1_mean', 'RE1_mean', 'RE2_mean']</td>
#       <td id="T_587c7_row5_col1" class="data row5 col1" >7</td>
#       <td id="T_587c7_row5_col2" class="data row5 col2" >0.353</td>
#       <td id="T_587c7_row5_col3" class="data row5 col3" >13.56</td>
#       <td id="T_587c7_row5_col4" class="data row5 col4" >-0.0287</td>
#       <td id="T_587c7_row5_col5" class="data row5 col5" >25.06</td>
#       <td id="T_587c7_row5_col6" class="data row5 col6" >0.2592</td>
#       <td id="T_587c7_row5_col7" class="data row5 col7" >0.2683</td>
#       <td id="T_587c7_row5_col8" class="data row5 col8" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_587c7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_587c7_row6_col0" class="data row6 col0" >EXPERIMENT-5 Plot average,, Model: regular, Features: ['height_mean', 'EVI_mean', 'NIR_mean', 'NBR_mean', 'SWIR1_mean']</td>
#       <td id="T_587c7_row6_col1" class="data row6 col1" >5</td>
#       <td id="T_587c7_row6_col2" class="data row6 col2" >0.4207</td>
#       <td id="T_587c7_row6_col3" class="data row6 col3" >12.83</td>
#       <td id="T_587c7_row6_col4" class="data row6 col4" >-0.0446</td>
#       <td id="T_587c7_row6_col5" class="data row6 col5" >25.25</td>
#       <td id="T_587c7_row6_col6" class="data row6 col6" >0.2439</td>
#       <td id="T_587c7_row6_col7" class="data row6 col7" >0.1503</td>
#       <td id="T_587c7_row6_col8" class="data row6 col8" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_587c7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_587c7_row7_col0" class="data row7 col0" >EXPERIMENT-19 Plot average,, Model: lasso, Features: ['NDVI_mean', 'MNDWI_mean', 'NBR_mean', 'EVI_mean', 'NDRE1_mean', 'NDRE2_mean', 'NDRE3_mean', 'CIrededge_mean']</td>
#       <td id="T_587c7_row7_col1" class="data row7 col1" >8</td>
#       <td id="T_587c7_row7_col2" class="data row7 col2" >0.3049</td>
#       <td id="T_587c7_row7_col3" class="data row7 col3" >14.05</td>
#       <td id="T_587c7_row7_col4" class="data row7 col4" >-0.0789</td>
#       <td id="T_587c7_row7_col5" class="data row7 col5" >25.66</td>
#       <td id="T_587c7_row7_col6" class="data row7 col6" >0.2334</td>
#       <td id="T_587c7_row7_col7" class="data row7 col7" >0.1961</td>
#       <td id="T_587c7_row7_col8" class="data row7 col8" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_587c7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_587c7_row8_col0" class="data row8 col0" >EXPERIMENT-20 Plot average,, Model: elasticnet, Features: ['NDVI_mean', 'MNDWI_mean', 'NBR_mean', 'EVI_mean', 'NDRE1_mean', 'N

# %% [markdown]
# ### BELIGE. PLOT-AVEAGE. LINEAR REGRESSION {Hyperparameter tuning: NO}

# %%
# %run Model_functions.ipynb

rf_belige_avg_no_grid = {}

run_experiment(X_plot, y_plot,
               is_groups=False, group_info=grp_belige_avg,
               features_list=features_list_avg,
               experiments=rf_belige_avg_no_grid,
               model_type="rf",
               label = "Plot averages,"
               is_grid=False,
               is_stratified=is_stratified_g,
               global_experiment_list=global_experiment_list)
# Out:
# [1/6]
#
#  RANDOM FOREST: EXPERIMENT-1 Plot average,, Features: ['height_mean'].
# Test R²     : 0.5793
# Test RMSE   : 10.93 kg
# Train R² (log scale): 0.7536
# Train R² (orig scale): 0.4702
# Train RMSE  : 17.98 kg
# Num rows    : 47
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: 0.3062
# CV R² std : 0.1270
# CV scores : [0.32  0.132 0.207 0.377 0.494]
# ============================================================
#  EVALUATION: EXPERIMENT-1 Plot average,, Features: ['height_mean'].
# ============================================================
#
# Test set:
#   R²   : 0.579
#   RMSE : 10.93 kg
#
# Regular CrossValidation:
#   Mean   : 0.306
#   Std    : 0.127
#   Scores : [0.32  0.132 0.207 0.377 0.494]
#
#   ✅ Test R² is positive (0.579)
#   ✅ CV mean is positive (0.306)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ✅ ACCEPTABLE
#
# [2/6]
#
#  RANDOM FOREST: EXPERIMENT-2 Plot average,, Features: ['height_mean', 'EVI_mean', 'NIR_mean', 'NBR_mean', 'SWIR1_mean'].
# Test R²     : 0.5447
# Test RMSE   : 11.37 kg
# Train R² (log scale): 0.8549
# Train R² (orig scale): 0.5647
# Train RMSE  : 16.30 kg
# Num rows    : 47
# Num Features: 5
#
#  Cross-validation ---
# CV R² mean: 0.5603
# CV R² std : 0.2424
# CV scores : [0.594 0.877 0.572 0.632 0.128]
# ============================================================
#  EVALUATION: EXPERIMENT-2 Plot average,, Features: ['height_mean', 'EVI_mean', 'NIR_mean', 'NBR_mean', 'SWIR1_mean'].
# ============================================================
#
# Test set:
#   R²   : 0.545
#   RMSE : 11.37 kg
#
# Regular CrossValidation:
#   Mean   : 0.560
#   Std    : 0.242
#   Scores : [0.594 0.877 0.572 0.632 0.128]
#
#   ✅ Test R² is positive (0.545)
#   ✅ CV mean is positive (0.560)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ✅ ACCEPTABLE
#
# [3/6]
#
#  RANDOM FOREST: EXPERIMENT-3 Plot average,, Features: ['height_mean', 'EVI_mean', 'NIR_mean', 'NBR_mean', 'SWIR1_mean', 'RE1_mean', 'RE2_mean'].
# Test R²     : 0.5766
# Test RMSE   : 10.97 kg
# Train R² (log scale): 0.8717
# Train R² (orig scale): 0.5583
# Train RMSE  : 16.42 kg
# Num rows    : 47
# Num Features: 7
#
#  Cross-validation ---
# CV R² mean: 0.5820
# CV R² std : 0.2486
# CV scores : [0.576 0.878 0.641 0.687 0.127]
# ============================================================
#  EVALUATION: EXPERIMENT-3 Plot average,, Features: ['height_mean', 'EVI_mean', 'NIR_mean', 'NBR_mean', 'SWIR1_mean', 'RE1_mean', 'RE2_mean'].
# ============================================================
#
# Test set:
#   R²   : 0.577
#   RMSE : 10.97 kg
#
# Regular CrossValidation:
#   Mean   : 0.582
#   Std    : 0.249
#   Scores : [0.576 0.878 0.641 0.687 0.127]
#
#   ✅ Test R² is positive (0.577)
#   ✅ CV mean is positive (0.582)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ✅ ACCEPTABLE
#
# [4/6]
#
#  RANDOM FOREST: EXPERIMENT-4 Plot average,, Features: ['Blue_mean', 'Green_mean', 'Red_mean', 'RE1_mean', 'RE2_mean', 'RE3_mean', 'NIR_mean', 'SWIR1_mean', 'SWIR2_mean'].
# Test R²     : 0.5838
# Test RMSE   : 10.87 kg
# Train R² (log scale): 0.8901
# Train R² (orig scale): 0.5842
# Train RMSE  : 15.93 kg
# Num rows    : 47
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: 0.5221
# CV R² std : 0.2079
# CV scores : [0.657 0.65  0.372 0.742 0.189]
# ============================================================
#  EVALUATION: EXPERIMENT-4 Plot average,, Features: ['Blue_mean', 'Green_mean', 'Red_mean', 'RE1_mean', 'RE2_mean', 'RE3_mean', 'NIR_mean', 'SWIR1_mean', 'SWIR2_mean'].
# ============================================================
#
# Test set:
#   R²   : 0.584
#   RMSE : 10.87 kg
#
# Regular CrossValidation:
#   Mean   : 0.522
#   Std    : 0.208
#   Scores : [0.657 0.65  0.372 0.742 0.189]
#
#   ✅ Test R² is positive (0.584)
#   ✅ CV mean is positive (0.522)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ✅ ACCEPTABLE
#
# [5/6]
#
#  RANDOM FOREST: EXPERIMENT-5 Plot average,, Features: ['NDVI_mean', 'MNDWI_mean', 'NBR_mean', 'EVI_mean', 'NDRE1_mean', 'NDRE2_mean', 'NDRE3_mean', 'CIrededge_mean'].
# Test R²     : 0.5682
# Test RMSE   : 11.08 kg
# Train R² (log scale): 0.9013
# Train R² (orig scale): 0.5540
# Train RMSE  : 16.50 kg
# Num rows    : 47
# Num Features: 8
#
#  Cross-validation ---
# CV R² mean: 0.5826
# CV R² std : 0.2383
# CV scores : [0.706 0.879 0.452 0.685 0.191]
# ============================================================
#  EVALUATION: EXPERIMENT-5 Plot average,, Features: ['NDVI_mean', 'MNDWI_mean', 'NBR_mean', 'EVI_mean', 'NDRE1_mean', 'NDRE2_mean', 'NDRE3_mean', 'CIrededge_mean'].
# ============================================================
#
# Test set:
#   R²   : 0.568
#   RMSE : 11.08 kg
#
# Regular CrossValidation:
#   Mean   : 0.583
#   Std    : 0.238
#   Scores : [0.706 0.879 0.452 0.685 0.191]
#
#   ✅ Test R² is positive (0.568)
#   ✅ CV mean is positive (0.583)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ✅ ACCEPTABLE
#
# [6/6]
#
#  RANDOM FOREST: EXPERIMENT-6 Plot average,, Features: ['height_mean', 'Blue_mean', 'Green_mean', 'Red_mean', 'RE1_mean', 'RE2_mean', 'RE3_mean', 'NIR_mean', 'SWIR1_mean', 'SWIR2_mean', 'NDVI_mean', 'MNDWI_mean', 'NBR_mean', 'EVI_mean', 'NDRE1_mean', 'NDRE2_mean', 'NDRE3_mean', 'CIrededge_mean'].
# Test R²     : 0.7101
# Test RMSE   : 9.07 kg
# Train R² (log scale): 0.9130
# Train R² (orig scale): 0.6076
# Train RMSE  : 15.48 kg
# Num rows    : 47
# Num Features: 18
#
#  Cross-validation ---
# CV R² mean: 0.6411
# CV R² std : 0.2301
# CV scores : [0.732 0.871 0.623 0.771 0.209]
# ============================================================
#  EVALUATION: EXPERIMENT-6 Plot average,, Features: ['height_mean', 'Blue_mean', 'Green_mean', 'Red_mean', 'RE1_mean', 'RE2_mean', 'RE3_mean', 'NIR_mean', 'SWIR1_mean', 'SWIR2_mean', 'NDVI_mean', 'MNDWI_mean', 'NBR_mean', 'EVI_mean', 'NDRE1_mean', 'NDRE2_mean', 'NDRE3_mean', 'CIrededge_mean'].
# ============================================================
#
# Test set:
#   R²   : 0.710
#   RMSE : 9.07 kg
#
# Regular CrossValidation:
#   Mean   : 0.641
#   Std    : 0.230
#   Scores : [0.732 0.871 0.623 0.771 0.209]
#
#   ✅ Test R² is positive (0.710)
#   ✅ CV mean is positive (0.641)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ✅ ACCEPTABLE
#
# Completed: 6/6 experiments

# %%
# %run Model_functions.ipynb
tabulate_results(rf_belige_avg_no_grid, acceptable_only=True)
# Out:
# Showing 6 acceptable experiments
# <style type="text/css">
# #T_b3740_row0_col2, #T_b3740_row0_col3, #T_b3740_row0_col6 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b3740">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b3740_level0_col0" class="col_heading level0 col0" >Experiment</th>
#       <th id="T_b3740_level0_col1" class="col_heading level0 col1" >Num_features</th>
#       <th id="T_b3740_level0_col2" class="col_heading level0 col2" >Test R²</th>
#       <th id="T_b3740_level0_col3" class="col_heading level0 col3" >Test RMSE</th>
#       <th id="T_b3740_level0_col4" class="col_heading level0 col4" >Train R²</th>
#       <th id="T_b3740_level0_col5" class="col_heading level0 col5" >Train RMSE</th>
#       <th id="T_b3740_level0_col6" class="col_heading level0 col6" >CV R² Mean</th>
#       <th id="T_b3740_level0_col7" class="col_heading level0 col7" >CV R² Std</th>
#       <th id="T_b3740_level0_col8" class="col_heading level0 col8" >verdict</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b3740_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b3740_row0_col0" class="data row0 col0" >EXPERIMENT-6 Plot average,, Features: ['height_mean', 'Blue_mean', 'Green_mean', 'Red_mean', 'RE1_mean', 'RE2_mean', 'RE3_mean', 'NIR_mean', 'SWIR1_mean', 'SWIR2_mean', 'NDVI_mean', 'MNDWI_mean', 'NBR_mean', 'EVI_mean', 'NDRE1_mean', 'NDRE2_mean', 'NDRE3_mean', 'CIrededge_mean'].</td>
#       <td id="T_b3740_row0_col1" class="data row0 col1" >18</td>
#       <td id="T_b3740_row0_col2" class="data row0 col2" >0.7101</td>
#       <td id="T_b3740_row0_col3" class="data row0 col3" >9.07</td>
#       <td id="T_b3740_row0_col4" class="data row0 col4" >0.6076</td>
#       <td id="T_b3740_row0_col5" class="data row0 col5" >15.48</td>
#       <td id="T_b3740_row0_col6" class="data row0 col6" >0.6411</td>
#       <td id="T_b3740_row0_col7" class="data row0 col7" >0.2301</td>
#       <td id="T_b3740_row0_col8" class="data row0 col8" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_b3740_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b3740_row1_col0" class="data row1 col0" >EXPERIMENT-5 Plot average,, Features: ['NDVI_mean', 'MNDWI_mean', 'NBR_mean', 'EVI_mean', 'NDRE1_mean', 'NDRE2_mean', 'NDRE3_mean', 'CIrededge_mean'].</td>
#       <td id="T_b3740_row1_col1" class="data row1 col1" >8</td>
#       <td id="T_b3740_row1_col2" class="data row1 col2" >0.5682</td>
#       <td id="T_b3740_row1_col3" class="data row1 col3" >11.08</td>
#       <td id="T_b3740_row1_col4" class="data row1 col4" >0.554</td>
#       <td id="T_b3740_row1_col5" class="data row1 col5" >16.5</td>
#       <td id="T_b3740_row1_col6" class="data row1 col6" >0.5826</td>
#       <td id="T_b3740_row1_col7" class="data row1 col7" >0.2383</td>
#       <td id="T_b3740_row1_col8" class="data row1 col8" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_b3740_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b3740_row2_col0" class="data row2 col0" >EXPERIMENT-3 Plot average,, Features: ['height_mean', 'EVI_mean', 'NIR_mean', 'NBR_mean', 'SWIR1_mean', 'RE1_mean', 'RE2_mean'].</td>
#       <td id="T_b3740_row2_col1" class="data row2 col1" >7</td>
#       <td id="T_b3740_row2_col2" class="data row2 col2" >0.5766</td>
#       <td id="T_b3740_row2_col3" class="data row2 col3" >10.97</td>
#       <td id="T_b3740_row2_col4" class="data row2 col4" >0.5583</td>
#       <td id="T_b3740_row2_col5" class="data row2 col5" >16.42</td>
#       <td id="T_b3740_row2_col6" class="data row2 col6" >0.582</td>
#       <td id="T_b3740_row2_col7" class="data row2 col7" >0.2486</td>
#       <td id="T_b3740_row2_col8" class="data row2 col8" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_b3740_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b3740_row3_col0" class="data row3 col0" >EXPERIMENT-2 Plot average,, Features: ['height_mean', 'EVI_mean', 'NIR_mean', 'NBR_mean', 'SWIR1_mean'].</td>
#       <td id="T_b3740_row3_col1" class="data row3 col1" >5</td>
#       <td id="T_b3740_row3_col2" class="data row3 col2" >0.5447</td>
#       <td id="T_b3740_row3_col3" class="data row3 col3" >11.37</td>
#       <td id="T_b3740_row3_col4" class="data row3 col4" >0.5647</td>
#       <td id="T_b3740_row3_col5" class="data row3 col5" >16.3</td>
#       <td id="T_b3740_row3_col6" class="data row3 col6" >0.5603</td>
#       <td id="T_b3740_row3_col7" class="data row3 col7" >0.2424</td>
#       <td id="T_b3740_row3_col8" class="data row3 col8" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_b3740_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b3740_row4_col0" class="data row4 col0" >EXPERIMENT-4 Plot average,, Features: ['Blue_mean', 'Green_mean', 'Red_mean', 'RE1_mean', 'RE2_mean', 'RE3_mean', 'NIR_mean', 'SWIR1_mean', 'SWIR2_mean'].</td>
#       <td id="T_b3740_row4_col1" class="data row4 col1" >9</td>
#       <td id="T_b3740_row4_col2" class="data row4 col2" >0.5838</td>
#       <td id="T_b3740_row4_col3" class="data row4 col3" >10.87</td>
#       <td id="T_b3740_row4_col4" class="data row4 col4" >0.5842</td>
#       <td id="T_b3740_row4_col5" class="data row4 col5" >15.93</td>
#       <td id="T_b3740_row4_col6" class="data row4 col6" >0.5221</td>
#       <td id="T_b3740_row4_col7" class="data row4 col7" >0.2079</td>
#       <td id="T_b3740_row4_col8" class="data row4 col8" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_b3740_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b3740_row5_col0" class="data row5 col0" >EXPERIMENT-1 Plot average,, Features: ['height_mean'].</td>
#       <td id="T_b3740_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_b3740_row5_col2" class="data row5 col2" >0.5793</td>
#       <td id="T_b3740_row5_col3" class="data row5 col3" >10.93</td>
#       <td id="T_b3740_row5_col4" class="data row5 col4" >0.4702</td>
#       <td id="T_b3740_row5_col5" class="data row5 col5" >17.98</td>
#       <td id="T_b3740_row5_col6" class="data row5 col6" >0.3062</td>
#       <td id="T_b3740_row5_col7" class="data row5 col7" >0.127</td>
#       <td id="T_b3740_row5_col8" class="data row5 col8" >✅ ACCEPTABLE</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **COMMENTS**
# Every experiment passes, and the numbers are substantially better than the tree-level RF (best was 0.300 grouped CV). Plot-level aggregation has genuinely improved the signal.
#
# Exp 6 is the standout — test R² 0.710 and CV mean 0.641, both honest. Unlike the LR all-features experiments which collapsed (R² −1.8M), RF handles 18 features on 47 rows gracefully through its built-in feature subsampling. The CV std of 0.23 is acceptable given only 59 plots.
#
# Exp 1 is remarkable on its own — height alone gives CV mean 0.306 and test R² 0.579 with the tightest CV std (0.127). A single feature explaining 58% of variance on a held-out test set is a strong result.
#
# The low CV std in Exp 1 vs the wider std in Exps 2–6 suggests adding spectral features improves mean performance but introduces fold-to-fold variance — some folds benefit more than others from the spectral signal.

# %%
### BELIGE. PLOT-AVEAGE. LINEAR REGRESSION {Hyperparameter tuning: Yes}

# %%
# %run Model_functions.ipynb

rf_belige_avg_grid = {}

run_experiment(X_plot, y_plot,
               is_groups=False, group_info=grp_belige_avg,
               features_list=features_list_avg,
               experiments=rf_belige_avg_grid,
               model_type="rf",
               label = "Plot averages,"
               is_grid=False,
               is_stratified=is_stratified_g,
               global_experiment_list=global_experiment_list)
# Out:
# [1/6]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'n_estimators': 500, 'min_samples_leaf': 4, 'max_samples': 0.6, 'max_features': 0.5, 'max_depth': None}
#
#  RANDOM FOREST: EXPERIMENT-1 Plot average,, Features: ['height_mean'].
# Test R²     : 0.5763
# Test RMSE   : 10.97 kg
# Train R² (log scale): 0.5840
# Train R² (orig scale): 0.2276
# Train RMSE  : 21.71 kg
# Num rows    : 47
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: 0.4232
# CV R² std : 0.0840
# CV scores : [0.435 0.56  0.31  0.367 0.443]
# ============================================================
#  EVALUATION: EXPERIMENT-1 Plot average,, Features: ['height_mean'].
# ============================================================
#
# Test set:
#   R²   : 0.576
#   RMSE : 10.97 kg
#
# Regular CrossValidation:
#   Mean   : 0.423
#   Std    : 0.084
#   Scores : [0.435 0.56  0.31  0.367 0.443]
#
#   ✅ Test R² is positive (0.576)
#   ✅ CV mean is positive (0.423)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ✅ ACCEPTABLE
#
# [2/6]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'n_estimators': 500, 'min_samples_leaf': 2, 'max_samples': 1.0, 'max_features': 'sqrt', 'max_depth': 10}
#
#  RANDOM FOREST: EXPERIMENT-2 Plot average,, Features: ['height_mean', 'EVI_mean', 'NIR_mean', 'NBR_mean', 'SWIR1_mean'].
# Test R²     : 0.5447
# Test RMSE   : 11.37 kg
# Train R² (log scale): 0.8549
# Train R² (orig scale): 0.5647
# Train RMSE  : 16.30 kg
# Num rows    : 47
# Num Features: 5
#
#  Cross-validation ---
# CV R² mean: 0.5603
# CV R² std : 0.2424
# CV scores : [0.594 0.877 0.572 0.632 0.128]
# ============================================================
#  EVALUATION: EXPERIMENT-2 Plot average,, Features: ['height_mean', 'EVI_mean', 'NIR_mean', 'NBR_mean', 'SWIR1_mean'].
# ============================================================
#
# Test set:
#   R²   : 0.545
#   RMSE : 11.37 kg
#
# Regular CrossValidation:
#   Mean   : 0.560
#   Std    : 0.242
#   Scores : [0.594 0.877 0.572 0.632 0.128]
#
#   ✅ Test R² is positive (0.545)
#   ✅ CV mean is positive (0.560)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ✅ ACCEPTABLE
#
# [3/6]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'n_estimators': 200, 'min_samples_leaf': 2, 'max_samples': 1.0, 'max_features': 'sqrt', 'max_depth': None}
#
#  RANDOM FOREST: EXPERIMENT-3 Plot average,, Features: ['height_mean', 'EVI_mean', 'NIR_mean', 'NBR_mean', 'SWIR1_mean', 'RE1_mean', 'RE2_mean'].
# Test R²     : 0.5825
# Test RMSE   : 10.89 kg
# Train R² (log scale): 0.8759
# Train R² (orig scale): 0.5619
# Train RMSE  : 16.35 kg
# Num rows    : 47
# Num Features: 7
#
#  Cross-validation ---
# CV R² mean: 0.5914
# CV R² std : 0.2457
# CV scores : [0.593 0.883 0.635 0.705 0.142]
# ============================================================
#  EVALUATION: EXPERIMENT-3 Plot average,, Features: ['height_mean', 'EVI_mean', 'NIR_mean', 'NBR_mean', 'SWIR1_mean', 'RE1_mean', 'RE2_mean'].
# ============================================================
#
# Test set:
#   R²   : 0.583
#   RMSE : 10.89 kg
#
# Regular CrossValidation:
#   Mean   : 0.591
#   Std    : 0.246
#   Scores : [0.593 0.883 0.635 0.705 0.142]
#
#   ✅ Test R² is positive (0.583)
#   ✅ CV mean is positive (0.591)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ✅ ACCEPTABLE
#
# [4/6]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'n_estimators': 100, 'min_samples_leaf': 2, 'max_samples': 1.0, 'max_features': 0.3, 'max_depth': 10}
#
#  RANDOM FOREST: EXPERIMENT-4 Plot average,, Features: ['Blue_mean', 'Green_mean', 'Red_mean', 'RE1_mean', 'RE2_mean', 'RE3_mean', 'NIR_mean', 'SWIR1_mean', 'SWIR2_mean'].
# Test R²     : 0.5504
# Test RMSE   : 11.30 kg
# Train R² (log scale): 0.8842
# Train R² (orig scale): 0.5829
# Train RMSE  : 15.96 kg
# Num rows    : 47
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: 0.5471
# CV R² std : 0.1770
# CV scores : [0.627 0.709 0.363 0.728 0.308]
# ============================================================
#  EVALUATION: EXPERIMENT-4 Plot average,, Features: ['Blue_mean', 'Green_mean', 'Red_mean', 'RE1_mean', 'RE2_mean', 'RE3_mean', 'NIR_mean', 'SWIR1_mean', 'SWIR2_mean'].
# ============================================================
#
# Test set:
#   R²   : 0.550
#   RMSE : 11.30 kg
#
# Regular CrossValidation:
#   Mean   : 0.547
#   Std    : 0.177
#   Scores : [0.627 0.709 0.363 0.728 0.308]
#
#   ✅ Test R² is positive (0.550)
#   ✅ CV mean is positive (0.547)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ✅ ACCEPTABLE
#
# [5/6]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'n_estimators': 200, 'min_samples_leaf': 2, 'max_samples': 1.0, 'max_features': 'sqrt', 'max_depth': None}
#
#  RANDOM FOREST: EXPERIMENT-5 Plot average,, Features: ['NDVI_mean', 'MNDWI_mean', 'NBR_mean', 'EVI_mean', 'NDRE1_mean', 'NDRE2_mean', 'NDRE3_mean', 'CIrededge_mean'].
# Test R²     : 0.5479
# Test RMSE   : 11.33 kg
# Train R² (log scale): 0.9043
# Train R² (orig scale): 0.5669
# Train RMSE  : 16.26 kg
# Num rows    : 47
# Num Features: 8
#
#  Cross-validation ---
# CV R² mean: 0.5928
# CV R² std : 0.2318
# CV scores : [0.712 0.888 0.464 0.685 0.215]
# ============================================================
#  EVALUATION: EXPERIMENT-5 Plot average,, Features: ['NDVI_mean', 'MNDWI_mean', 'NBR_mean', 'EVI_mean', 'NDRE1_mean', 'NDRE2_mean', 'NDRE3_mean', 'CIrededge_mean'].
# ============================================================
#
# Test set:
#   R²   : 0.548
#   RMSE : 11.33 kg
#
# Regular CrossValidation:
#   Mean   : 0.593
#   Std    : 0.232
#   Scores : [0.712 0.888 0.464 0.685 0.215]
#
#   ✅ Test R² is positive (0.548)
#   ✅ CV mean is positive (0.593)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ✅ ACCEPTABLE
#
# [6/6]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'n_estimators': 200, 'min_samples_leaf': 2, 'max_samples': 1.0, 'max_features': 'sqrt', 'max_depth': 15}
#
#  RANDOM FOREST: EXPERIMENT-6 Plot average,, Features: ['height_mean', 'Blue_mean', 'Green_mean', 'Red_mean', 'RE1_mean', 'RE2_mean', 'RE3_mean', 'NIR_mean', 'SWIR1_mean', 'SWIR2_mean', 'NDVI_mean', 'MNDWI_mean', 'NBR_mean', 'EVI_mean', 'NDRE1_mean', 'NDRE2_mean', 'NDRE3_mean', 'CIrededge_mean'].
# Test R²     : 0.7011
# Test RMSE   : 9.22 kg
# Train R² (log scale): 0.9186
# Train R² (orig scale): 0.6239
# Train RMSE  : 15.15 kg
# Num rows    : 47
# Num Features: 18
#
#  Cross-validation ---
# CV R² mean: 0.6665
# CV R² std : 0.2156
# CV scores : [0.75  0.892 0.659 0.771 0.261]
# ============================================================
#  EVALUATION: EXPERIMENT-6 Plot average,, Features: ['height_mean', 'Blue_mean', 'Green_mean', 'Red_mean', 'RE1_mean', 'RE2_mean', 'RE3_mean', 'NIR_mean', 'SWIR1_mean', 'SWIR2_mean', 'NDVI_mean', 'MNDWI_mean', 'NBR_mean', 'EVI_mean', 'NDRE1_mean', 'NDRE2_mean', 'NDRE3_mean', 'CIrededge_mean'].
# ============================================================
#
# Test set:
#   R²   : 0.701
#   RMSE : 9.22 kg
#
# Regular CrossValidation:
#   Mean   : 0.666
#   Std    : 0.216
#   Scores : [0.75  0.892 0.659 0.771 0.261]
#
#   ✅ Test R² is positive (0.701)
#   ✅ CV mean is positive (0.666)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ✅ ACCEPTABLE
#
# Completed: 6/6 experiments

# %%
# %run Model_functions.ipynb
tabulate_results(rf_belige_avg_grid, acceptable_only=True)
# Out:
# Showing 6 acceptable experiments
# <style type="text/css">
# #T_a6740_row0_col2, #T_a6740_row0_col3, #T_a6740_row0_col6 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a6740">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a6740_level0_col0" class="col_heading level0 col0" >Experiment</th>
#       <th id="T_a6740_level0_col1" class="col_heading level0 col1" >Num_features</th>
#       <th id="T_a6740_level0_col2" class="col_heading level0 col2" >Test R²</th>
#       <th id="T_a6740_level0_col3" class="col_heading level0 col3" >Test RMSE</th>
#       <th id="T_a6740_level0_col4" class="col_heading level0 col4" >Train R²</th>
#       <th id="T_a6740_level0_col5" class="col_heading level0 col5" >Train RMSE</th>
#       <th id="T_a6740_level0_col6" class="col_heading level0 col6" >CV R² Mean</th>
#       <th id="T_a6740_level0_col7" class="col_heading level0 col7" >CV R² Std</th>
#       <th id="T_a6740_level0_col8" class="col_heading level0 col8" >verdict</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a6740_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a6740_row0_col0" class="data row0 col0" >EXPERIMENT-6 Plot average,, Features: ['height_mean', 'Blue_mean', 'Green_mean', 'Red_mean', 'RE1_mean', 'RE2_mean', 'RE3_mean', 'NIR_mean', 'SWIR1_mean', 'SWIR2_mean', 'NDVI_mean', 'MNDWI_mean', 'NBR_mean', 'EVI_mean', 'NDRE1_mean', 'NDRE2_mean', 'NDRE3_mean', 'CIrededge_mean'].</td>
#       <td id="T_a6740_row0_col1" class="data row0 col1" >18</td>
#       <td id="T_a6740_row0_col2" class="data row0 col2" >0.7011</td>
#       <td id="T_a6740_row0_col3" class="data row0 col3" >9.22</td>
#       <td id="T_a6740_row0_col4" class="data row0 col4" >0.6239</td>
#       <td id="T_a6740_row0_col5" class="data row0 col5" >15.15</td>
#       <td id="T_a6740_row0_col6" class="data row0 col6" >0.6665</td>
#       <td id="T_a6740_row0_col7" class="data row0 col7" >0.2156</td>
#       <td id="T_a6740_row0_col8" class="data row0 col8" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_a6740_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a6740_row1_col0" class="data row1 col0" >EXPERIMENT-5 Plot average,, Features: ['NDVI_mean', 'MNDWI_mean', 'NBR_mean', 'EVI_mean', 'NDRE1_mean', 'NDRE2_mean', 'NDRE3_mean', 'CIrededge_mean'].</td>
#       <td id="T_a6740_row1_col1" class="data row1 col1" >8</td>
#       <td id="T_a6740_row1_col2" class="data row1 col2" >0.5479</td>
#       <td id="T_a6740_row1_col3" class="data row1 col3" >11.33</td>
#       <td id="T_a6740_row1_col4" class="data row1 col4" >0.5669</td>
#       <td id="T_a6740_row1_col5" class="data row1 col5" >16.26</td>
#       <td id="T_a6740_row1_col6" class="data row1 col6" >0.5928</td>
#       <td id="T_a6740_row1_col7" class="data row1 col7" >0.2318</td>
#       <td id="T_a6740_row1_col8" class="data row1 col8" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_a6740_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a6740_row2_col0" class="data row2 col0" >EXPERIMENT-3 Plot average,, Features: ['height_mean', 'EVI_mean', 'NIR_mean', 'NBR_mean', 'SWIR1_mean', 'RE1_mean', 'RE2_mean'].</td>
#       <td id="T_a6740_row2_col1" class="data row2 col1" >7</td>
#       <td id="T_a6740_row2_col2" class="data row2 col2" >0.5825</td>
#       <td id="T_a6740_row2_col3" class="data row2 col3" >10.89</td>
#       <td id="T_a6740_row2_col4" class="data row2 col4" >0.5619</td>
#       <td id="T_a6740_row2_col5" class="data row2 col5" >16.35</td>
#       <td id="T_a6740_row2_col6" class="data row2 col6" >0.5914</td>
#       <td id="T_a6740_row2_col7" class="data row2 col7" >0.2457</td>
#       <td id="T_a6740_row2_col8" class="data row2 col8" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_a6740_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a6740_row3_col0" class="data row3 col0" >EXPERIMENT-2 Plot average,, Features: ['height_mean', 'EVI_mean', 'NIR_mean', 'NBR_mean', 'SWIR1_mean'].</td>
#       <td id="T_a6740_row3_col1" class="data row3 col1" >5</td>
#       <td id="T_a6740_row3_col2" class="data row3 col2" >0.5447</td>
#       <td id="T_a6740_row3_col3" class="data row3 col3" >11.37</td>
#       <td id="T_a6740_row3_col4" class="data row3 col4" >0.5647</td>
#       <td id="T_a6740_row3_col5" class="data row3 col5" >16.3</td>
#       <td id="T_a6740_row3_col6" class="data row3 col6" >0.5603</td>
#       <td id="T_a6740_row3_col7" class="data row3 col7" >0.2424</td>
#       <td id="T_a6740_row3_col8" class="data row3 col8" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_a6740_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a6740_row4_col0" class="data row4 col0" >EXPERIMENT-4 Plot average,, Features: ['Blue_mean', 'Green_mean', 'Red_mean', 'RE1_mean', 'RE2_mean', 'RE3_mean', 'NIR_mean', 'SWIR1_mean', 'SWIR2_mean'].</td>
#       <td id="T_a6740_row4_col1" class="data row4 col1" >9</td>
#       <td id="T_a6740_row4_col2" class="data row4 col2" >0.5504</td>
#       <td id="T_a6740_row4_col3" class="data row4 col3" >11.3</td>
#       <td id="T_a6740_row4_col4" class="data row4 col4" >0.5829</td>
#       <td id="T_a6740_row4_col5" class="data row4 col5" >15.96</td>
#       <td id="T_a6740_row4_col6" class="data row4 col6" >0.5471</td>
#       <td id="T_a6740_row4_col7" class="data row4 col7" >0.177</td>
#       <td id="T_a6740_row4_col8" class="data row4 col8" >✅ ACCEPTABLE</td>
#     </tr>
#     <tr>
#       <th id="T_a6740_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a6740_row5_col0" class="data row5 col0" >EXPERIMENT-1 Plot average,, Features: ['height_mean'].</td>
#       <td id="T_a6740_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_a6740_row5_col2" class="data row5 col2" >0.5763</td>
#       <td id="T_a6740_row5_col3" class="data row5 col3" >10.97</td>
#       <td id="T_a6740_row5_col4" class="data row5 col4" >0.2276</td>
#       <td id="T_a6740_row5_col5" class="data row5 col5" >21.71</td>
#       <td id="T_a6740_row5_col6" class="data row5 col6" >0.4232</td>
#       <td id="T_a6740_row5_col7" class="data row5 col7" >0.084</td>
#       <td id="T_a6740_row5_col8" class="data row5 col8" >✅ ACCEPTABLE</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **COMMENTS**
#
# Tuning had modest impact — test R² barely moved, CV mean improved slightly.
# The model was already well-behaved untuned.
# Exp 6 remains the best model with test R² 0.701 and CV mean 0.666.
#
# Two observations worth noting:
#  - The last CV fold consistently scores 0.128–0.261 across all experiments. One fold is systematically harder than the others — likely the plots in that fold have unusual spectral characteristics or AGB values. Worth investigating which plots fall in that fold.
#  - Exp 1 (height only) CV improved significantly from 0.306 to 0.423 after tuning with minimal test R² change — the tuned model generalises more consistently from height alone, which is a meaningful ecological result.

# %% [markdown]
# # BELIGE DATA. WITHOUT LOW VARIANCE ROWS

# %%
# %run Model_functions.ipynb

belige_var_df = sentinel_df[sentinel_df['dataset'] == 'Belige'].copy()
assert len(belige_var_df['simard_height_m'].head())
assert len(belige_var_df['tandemx_height_m'].head())

# %%
belige_var_df = remove_low_variance_plots(belige_var_df, threshold=0.01).copy()
# Out:
# Removing 14 plots: ['Big Creek_1', 'Big Creek_4', 'Frenchman Caye_1', 'Frenchman Caye_2', 'Frenchman Caye_3', 'Frenchman Caye_4', 'Frenchman Caye_5', 'Frenchman Caye_6', 'Shipstern Lagoon_1', 'Shipstern Lagoon_2', 'Shipstern Lagoon_3', 'Shipstern Lagoon_4', 'Shipstern Lagoon_5', 'Shipstern Lagoon_6']
# Rows: 3880 → 2823
# Plots: 59 → 45

# %%
X_belige_sub = belige_var_df[feature_cols].copy()

# Select TANDEMX
X_belige_sub = X_belige_sub.rename({'tandemx_height_m': 'height'}, axis=1)
X_belige_sub = X_belige_sub.drop(columns=['simard_height_m'])

y_belige_sub  = belige_var_df[target]

X_belige_sub.columns
# Out:
# Index(['plot_id', 'species', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3',
#        'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1',
#        'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height'],
#       dtype='object')

# %% [markdown]
# ## Interaction terms

# %%
# height × EVI — the most promising. Height captures structural biomass, EVI captures canopy greenness.
# Their product approximates a "green volume" index and may capture the AGB signal better than either alone.
X_belige_sub['height_x_EVI'] = X_belige_sub['height'] * X_belige_sub['EVI']

#height × NIR — NIR reflectance is strongly tied to canopy density.
# Combined with height it approximates canopy biomass density.
X_belige_sub['height_x_NIR'] = X_belige_sub['height'] * X_belige_sub['NIR']

#height × NDRE1 — red-edge is sensitive to chlorophyll content.
# For mangroves, chlorophyll × height is a reasonable proxy for woody biomass.
X_belige_sub['height_x_NDRE1'] = X_belige_sub['height'] * X_belige_sub['NDRE1']

# %%
X_belige_sub.columns
# Out:
# Index(['plot_id', 'species', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3',
#        'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1',
#        'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height',
#        'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'],
#       dtype='object')

# %% [markdown]
# ## Form groups

# %%
# %run Model_functions.ipynb

plot_groups_belige_sub = X_belige_sub['plot_id'].copy()
X_belige_sub           = X_belige_sub.drop(columns=['plot_id'])

near_zero_sites_sub, high_agb_sites_sub,\
    near_zero_plots_sub, high_agb_plots_sub = get_low_and_high_agb_plots(y_belige_sub,
                                                                         plot_groups_belige_sub)

site_groups_belige_sub = plot_groups_belige_sub.map(lambda x: x.rsplit('_', maxsplit=1)[0])

grp_belige_sub = GROUP_INFO(near_zero_sites_sub, high_agb_sites_sub,
                            near_zero_plots_sub, high_agb_plots_sub,
                            groups=plot_groups_belige_sub,
                            cv=test_cv)
# Out:
# High-AGB threshold  : 111.23 kg
# Near-zero threshold : 0.060779
#
# Near-zero variance plots:
#
# High-AGB plots:
#   Channel Caye_1            : max AGB = 310.9 kg
#   Channel Caye_2            : max AGB = 206.4 kg
#   Channel Caye_3            : max AGB = 427.2 kg
#   Channel Caye_4            : max AGB = 237.6 kg
#   Channel Caye_5            : max AGB = 170.4 kg
#   Channel Caye_6            : max AGB = 128.6 kg
#   New River_2               : max AGB = 144.2 kg
#   New River_3               : max AGB = 260.8 kg
#
# within-site high-AGB plots
# Big Creek            : within-site high-AGB plots = ['Big Creek_3']
#
# Near-zero sites: []
# High-AGB sites : ['Big Creek', 'Channel Caye', 'New River']

# %% [markdown]
# ### BELIGE WITHOUT LOW VARIANCE ROWS. PLOT GROUPS. LINEAR REGRESSION

# %%
# %run Model_functions.ipynb
lin_belige_subset_groups = {}

run_experiment(X_belige_sub, y_belige_sub,
               is_groups=True, group_info=grp_belige_sub,
               features_list=gen_features_list,
               experiments=lin_belige_subset_groups,
               model_type="linear",
               is_grid=False,
               is_stratified=is_stratified_g,
               global_experiment_list=global_experiment_list)
# Out:
# [1/72]
#
#  EXPERIMENT-1 Plot groups. Without LOW VARIANCE ROWS, Model: regular, Features: ['height'], ALGO: LINEAR REGRESSION:
# Test R²     : -0.0693
# Test RMSE   : 23.53 kg
# Train R² (log scale): 0.1911
# Train R² (orig scale): 0.0499
# Train RMSE  : 18.15 kg
# Num rows    : 2334
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: 0.0908
# CV R² std : 0.0834
# CV scores : [0.003 0.115 0.104 0.228 0.005]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1313
# Grouped CV R² std : 0.1464
# Grouped CV scores : [ 0.15   0.12   0.422  0.016 -0.118  0.275  0.014  0.139  0.049  0.245]
# ============================================================
#  EVALUATION: EXPERIMENT-1 Plot groups. Without LOW VARIANCE ROWS, Model: regular, Features: ['height']
# ============================================================
#
# Test set:
#   R²   : -0.069
#   RMSE : 23.53 kg
#
# Regular CrossValidation:
#   Mean   : 0.091
#   Std    : 0.083
#   Scores : [0.003 0.115 0.104 0.228 0.005]
#
#   ❌ Test R² is negative (-0.069)
#   ✅ CV mean is positive (0.091)
#
# Grouped CrossValidation:
#   Channel Caye_2       :   0.150  ✅
#   Hicks Caye_3         :   0.120  ✅
#   Big Creek_6          :   0.422  ✅
#   Big Creek_3          :   0.016  ✅
#   Hicks Caye_1         :  -0.118  ❌ negative — cause unknown
#   Big Creek_5          :   0.275  ✅
#   Gra Gra Lagoon_3     :   0.014  ✅
#   Drowned Caye_1       :   0.139  ✅
#   Big Creek_2          :   0.049  ✅
#   Drowned Caye_5       :   0.245  ✅
#
#   Mean : 0.131
#   Std  : 0.146
#
#   ❌ Grouped CV mean below 0.15 (0.131)
#   ✅ Grouped CV std below 0.25 (0.146)
#   ❌ Unexplained negative folds: ['Hicks Caye_1']
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.201 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.119 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# [2/72]
#
#  EXPERIMENT-2 Plot groups. Without LOW VARIANCE ROWS, Model: ridge, Features: ['height'], ALGO: RIDGE REGRESSION:
# Test R²     : -0.0697
# Test RMSE   : 23.53 kg
# Train R² (log scale): 0.1908
# Train R² (orig scale): 0.0570
# Train RMSE  : 18.08 kg
# Num rows    : 2334
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: 0.0919
# CV R² std : 0.0831
# CV scores : [0.003 0.115 0.104 0.23  0.009]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1333
# Grouped CV R² std : 0.1441
# Grouped CV scores : [ 0.146  0.15   0.422  0.018 -0.108  0.267  0.007  0.141  0.048  0.241]
# ============================================================
#  EVALUATION: EXPERIMENT-2 Plot groups. Without LOW VARIANCE ROWS, Model: ridge, Features: ['height']
# ============================================================
#
# Test set:
#   R²   : -0.070
#   RMSE : 23.53 kg
#
# Regular CrossValidation:
#   Mean   : 0.092
#   Std    : 0.083
#   Scores : [0.003 0.115 0.104 0.23  0.009]
#
#   ❌ Test R² is negative (-0.070)
#   ✅ CV mean is positive (0.092)
#
# Grouped CrossValidation:
#   Channel Caye_2       :   0.146  ✅
#   Hicks Caye_3         :   0.150  ✅
#   Big Creek_6          :   0.422  ✅
#   Big Creek_3          :   0.018  ✅
#   Hicks Caye_1         :  -0.108  ❌ negative — cause unknown
#   Big Creek_5          :   0.267  ✅
#   Gra Gra Lagoon_3     :   0.007  ✅
#   Drowned Caye_1       :   0.141  ✅
#   Big Creek_2          :   0.048  ✅
#   Drowned Caye_5       :   0.241  ✅
#
#   Mean : 0.133
#   Std  : 0.144
#
#   ❌ Grouped CV mean below 0.15 (0.133)
#   ✅ Grouped CV std below 0.25 (0.144)
#   ❌ Unexplained negative folds: ['Hicks Caye_1']
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.203 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.127 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# [3/72]
#
#  EXPERIMENT-3 Plot groups. Without LOW VARIANCE ROWS, Model: lasso, Features: ['height'], ALGO: LASSO REGRESSION:
# Test R²     : -0.0695
# Test RMSE   : 23.53 kg
# Train R² (log scale): 0.1910
# Train R² (orig scale): 0.0542
# Train RMSE  : 18.11 kg
# Num rows    : 2334
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: 0.0928
# CV R² std : 0.0815
# CV scores : [0.003 0.115 0.103 0.229 0.015]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1322
# Grouped CV R² std : 0.1452
# Grouped CV scores : [ 0.148  0.132  0.421  0.017 -0.114  0.272  0.011  0.142  0.049  0.243]
# ============================================================
#  EVALUATION: EXPERIMENT-3 Plot groups. Without LOW VARIANCE ROWS, Model: lasso, Features: ['height']
# ============================================================
#
# Test set:
#   R²   : -0.070
#   RMSE : 23.53 kg
#
# Regular CrossValidation:
#   Mean   : 0.093
#   Std    : 0.082
#   Scores : [0.003 0.115 0.103 0.229 0.015]
#
#   ❌ Test R² is negative (-0.070)
#   ✅ CV mean is positive (0.093)
#
# Grouped CrossValidation:
#   Channel Caye_2       :   0.148  ✅
#   Hicks Caye_3         :   0.132  ✅
#   Big Creek_6          :   0.421  ✅
#   Big Creek_3          :   0.017  ✅
#   Hicks Caye_1         :  -0.114  ❌ negative — cause unknown
#   Big Creek_5          :   0.272  ✅
#   Gra Gra Lagoon_3     :   0.011  ✅
#   Drowned Caye_1       :   0.142  ✅
#   Big Creek_2          :   0.049  ✅
#   Drowned Caye_5       :   0.243  ✅
#
#   Mean : 0.132
#   Std  : 0.145
#
#   ❌ Grouped CV mean below 0.15 (0.132)
#   ✅ Grouped CV std below 0.25 (0.145)
#   ❌ Unexplained negative folds: ['Hicks Caye_1']
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.202 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.124 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# [4/72]
#
#  EXPERIMENT-4 Plot groups. Without LOW VARIANCE ROWS, Model: elasticnet, Features: ['height'], ALGO: ELASTICNET REGRESSION:
# Test R²     : -0.0702
# Test RMSE   : 23.54 kg
# Train R² (log scale): 0.1888
# Train R² (orig scale): 0.0569
# Train RMSE  : 18.08 kg
# Num rows    : 2334
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: 0.0923
# CV R² std : 0.0820
# CV scores : [0.003 0.115 0.103 0.228 0.012]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1284
# Grouped CV R² std : 0.1427
# Grouped CV scores : [ 0.14   0.128  0.421  0.021 -0.114  0.255  0.011  0.143  0.046  0.234]
# ============================================================
#  EVALUATION: EXPERIMENT-4 Plot groups. Without LOW VARIANCE ROWS, Model: elasticnet, Features: ['height']
# ============================================================
#
# Test set:
#   R²   : -0.070
#   RMSE : 23.54 kg
#
# Regular CrossValidation:
#   Mean   : 0.092
#   Std    : 0.082
#   Scores : [0.003 0.115 0.103 0.228 0.012]
#
#   ❌ Test R² is negative (-0.070)
#   ✅ CV mean is positive (0.092)
#
# Grouped CrossValidation:
#   Channel Caye_2       :   0.140  ✅
#   Hicks Caye_3         :   0.128  ✅
#   Big Creek_6          :   0.421  ✅
#   Big Creek_3          :   0.021  ✅
#   Hicks Caye_1         :  -0.114  ❌ negative — cause unknown
#   Big Creek_5          :   0.255  ✅
#   Gra Gra Lagoon_3     :   0.011  ✅
#   Drowned Caye_1       :   0.143  ✅
#   Big Creek_2          :   0.046  ✅
#   Drowned Caye_5       :   0.234  ✅
#
#   Mean : 0.128
#   Std  : 0.143
#
#   ❌ Grouped CV mean below 0.15 (0.128)
#   ✅ Grouped CV std below 0.25 (0.143)
#   ❌ Unexplained negative folds: ['Hicks Caye_1']
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.199 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.127 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# [5/72]
#
#  EXPERIMENT-5 Plot groups. Without LOW VARIANCE ROWS, Model: regular, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'], ALGO: LINEAR REGRESSION:
# Test R²     : -0.0658
# Test RMSE   : 23.49 kg
# Train R² (log scale): 0.2051
# Train R² (orig scale): 0.0648
# Train RMSE  : 18.01 kg
# Num rows    : 2334
# Num Features: 4
#
#  Cross-validation ---
# CV R² mean: 0.0839
# CV R² std : 0.0854
# CV scores : [-0.     0.079  0.097  0.237  0.007]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1135
# Grouped CV R² std : 0.1662
# Grouped CV scores : [ 0.141  0.129  0.414  0.037 -0.052  0.298 -0.191  0.086  0.03   0.243]
# ============================================================
#  EVALUATION: EXPERIMENT-5 Plot groups. Without LOW VARIANCE ROWS, Model: regular, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']
# ============================================================
#
# Test set:
#   R²   : -0.066
#   RMSE : 23.49 kg
#
# Regular CrossValidation:
#   Mean   : 0.084
#   Std    : 0.085
#   Scores : [-0.     0.079  0.097  0.237  0.007]
#
#   ❌ Test R² is negative (-0.066)
#   ✅ CV mean is positive (0.084)
#
# Grouped CrossValidation:
#   Channel Caye_2       :   0.141  ✅
#   Hicks Caye_3         :   0.129  ✅
#   Big Creek_6          :   0.414  ✅
#   Big Creek_3          :   0.037  ✅
#   Hicks Caye_1         :  -0.052  ❌ negative — cause unknown
#   Big Creek_5          :   0.298  ✅
#   Gra Gra Lagoon_3     :  -0.191  ❌ negative — cause unknown
#   Drowned Caye_1       :   0.086  ✅
#   Big Creek_2          :   0.030  ✅
#   Drowned Caye_5       :   0.243  ✅
#
#   Mean : 0.113
#   Std  : 0.166
#
#   ❌ Grouped CV mean below 0.15 (0.113)
#   ✅ Grouped CV std below 0.25 (0.166)
#   ❌ Unexplained negative folds: ['Hicks Caye_1', 'Gra Gra Lagoon_3']
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.179 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.131 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# [6/72]
#
#  EXPERIMENT-6 Plot groups. Without LOW VARIANCE ROWS, Model: ridge, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'], ALGO: RIDGE REGRESSION:
# Test R²     : -0.0681
# Test RMSE   : 23.51 kg
# Train R² (log scale): 0.1975
# Train R² (orig scale): 0.0604
# Train RMSE  : 18.05 kg
# Num rows    : 2334
# Num Features: 4
#
#  Cross-validation ---
# CV R² mean: 0.1007
# CV R² std : 0.0835
# CV scores : [0.022 0.113 0.108 0.246 0.016]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1247
# Grouped CV R² std : 0.1563
# Grouped CV scores : [ 0.151  0.121  0.431  0.023 -0.091  0.287 -0.088  0.114  0.051  0.248]
# ============================================================
#  EVALUATION: EXPERIMENT-6 Plot groups. Without LOW VARIANCE ROWS, Model: ridge, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']
# ============================================================
#
# Test set:
#   R²   : -0.068
#   RMSE : 23.51 kg
#
# Regular CrossValidation:
#   Mean   : 0.101
#   Std    : 0.083
#   Scores : [0.022 0.113 0.108 0.246 0.016]
#
#   ❌ Test R² is negative (-0.068)
#   ✅ CV mean is positive (0.101)
#
# Grouped CrossValidation:
#   Channel Caye_2       :   0.151  ✅
#   Hicks Caye_3         :   0.121  ✅
#   Big Creek_6          :   0.431  ✅
#   Big Creek_3          :   0.023  ✅
#   Hicks Caye_1         :  -0.091  ❌ negative — cause unknown
#   Big Creek_5          :   0.287  ✅
#   Gra Gra Lagoon_3     :  -0.088  ❌ negative — cause unknown
#   Drowned Caye_1       :   0.114  ✅
#   Big Creek_2          :   0.051  ✅
#   Drowned Caye_5       :   0.248  ✅
#
#   Mean : 0.125
#   Std  : 0.156
#
#   ❌ Grouped CV mean below 0.15 (0.125)
#   ✅ Grouped CV std below 0.25 (0.156)
#   ❌ Unexplained negative folds: ['Hicks Caye_1', 'Gra Gra Lagoon_3']
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.193 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.128 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# [7/72]
#
#  EXPERIMENT-7 Plot groups. Without LOW VARIANCE ROWS, Model: lasso, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'], ALGO: LASSO REGRESSION:
# Test R²     : -0.0684
# Test RMSE   : 23.52 kg
# Train R² (log scale): 0.2016
# Train R² (orig scale): 0.0610
# Train RMSE  : 18.04 kg
# Num rows    : 2334
# Num Features: 4
#
#  Cross-validation ---
# CV R² mean: 0.0962
# CV R² std : 0.0812
# CV scores : [0.022 0.105 0.099 0.24  0.015]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1270
# Grouped CV R² std : 0.1513
# Grouped CV scores : [ 0.143  0.127  0.428  0.026 -0.095  0.284 -0.056  0.113  0.051  0.248]
# ============================================================
#  EVALUATION: EXPERIMENT-7 Plot groups. Without LOW VARIANCE ROWS, Model: lasso, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']
# ============================================================
#
# Test set:
#   R²   : -0.068
#   RMSE : 23.52 kg
#
# Regular CrossValidation:
#   Mean   : 0.096
#   Std    : 0.081
#   Scores : [0.022 0.105 0.099 0.24  0.015]
#
#   ❌ Test R² is negative (-0.068)
#   ✅ CV mean is positive (0.096)
#
# Grouped CrossValidation:
#   Channel Caye_2       :   0.143  ✅
#   Hicks Caye_3         :   0.127  ✅
#   Big Creek_6          :   0.428  ✅
#   Big Creek_3          :   0.026  ✅
#   Hicks Caye_1         :  -0.095  ❌ negative — cause unknown
#   Big Creek_5          :   0.284  ✅
#   Gra Gra Lagoon_3     :  -0.056  ❌ negative — cause unknown
#   Drowned Caye_1       :   0.113  ✅
#   Big Creek_2          :   0.051  ✅
#   Drowned Caye_5       :   0.248  ✅
#
#   Mean : 0.127
#   Std  : 0.151
#
#   ❌ Grouped CV mean below 0.15 (0.127)
#   ✅ Grouped CV std below 0.25 (0.151)
#   ❌ Unexplained negative folds: ['Hicks Caye_1', 'Gra Gra Lagoon_3']
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.195 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.129 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# [8/72]
#
#  EXPERIMENT-8 Plot groups. Without LOW VARIANCE ROWS, Model: elasticnet, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'], ALGO: ELASTICNET REGRESSION:
# Test R²     : -0.0686
# Test RMSE   : 23.52 kg
# Train R² (log scale): 0.1966
# Train R² (orig scale): 0.0564
# Train RMSE  : 18.09 kg
# Num rows    : 2334
# Num Features: 4
#
#  Cross-validation ---
# CV R² mean: 0.1000
# CV R² std : 0.0832
# CV scores : [0.022 0.107 0.106 0.247 0.017]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1271
# Grouped CV R² std : 0.1519
# Grouped CV scores : [ 0.146  0.126  0.431  0.026 -0.095  0.279 -0.06   0.122  0.049  0.247]
# ============================================================
#  EVALUATION: EXPERIMENT-8 Plot groups. Without LOW VARIANCE ROWS, Model: elasticnet, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']
# ============================================================
#
# Test set:
#   R²   : -0.069
#   RMSE : 23.52 kg
#
# Regular CrossValidation:
#   Mean   : 0.100
#   Std    : 0.083
#   Scores : [0.022 0.107 0.106 0.247 0.017]
#
#   ❌ Test R² is negative (-0.069)
#   ✅ CV mean is positive (0.100)
#
# Grouped CrossValidation:
#   Channel Caye_2       :   0.146  ✅
#   Hicks Caye_3         :   0.126  ✅
#   Big Creek_6          :   0.431  ✅
#   Big Creek_3          :   0.026  ✅
#   Hicks Caye_1         :  -0.095  ❌ negative — cause unknown
#   Big Creek_5          :   0.279  ✅
#   Gra Gra Lagoon_3     :  -0.060  ❌ negative — cause unknown
#   Drowned Caye_1       :   0.122  ✅
#   Big Creek_2          :   0.049  ✅
#   Drowned Caye_5       :   0.247  ✅
#
#   Mean : 0.127
#   Std  : 0.152
#
#   ❌ Grouped CV mean below 0.15 (0.127)
#   ✅ Grouped CV std below 0.25 (0.152)
#   ❌ Unexplained negative folds: ['Hicks Caye_1', 'Gra Gra Lagoon_3']
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.196 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.125 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# [9/72]
#
#  EXPERIMENT-9 Plot groups. Without LOW VARIANCE ROWS, Model: regular, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2'], ALGO: LINEAR REGRESSION:
# Test R²     : -0.0617
# Test RMSE   : 23.44 kg
# Train R² (log scale): 0.2200
# Train R² (orig scale): 0.0489
# Train RMSE  : 18.16 kg
# Num rows    : 2334
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: -0.3209
# CV R² std : 0.4407
# CV scores : [-1.159  0.043  0.018 -0.33  -0.175]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1088
# Grouped CV R² std : 0.1861
# Grouped CV scores : [ 0.206  0.229  0.393 -0.063 -0.058  0.338 -0.237  0.076  0.027  0.178]
# ============================================================
#  EVALUATION: EXPERIMENT-9 Plot groups. Without LOW VARIANCE ROWS, Model: regular, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2']
# ============================================================
#
# Test set:
#   R²   : -0.062
#   RMSE : 23.44 kg
#
# Regular CrossValidation:
#   Mean   : -0.321
#   Std    : 0.441
#   Scores : [-1.159  0.043  0.018 -0.33  -0.175]
#
#   ❌ Test R² is negative (-0.062)
#   ❌ CV mean is negative (-0.321)
#
# Grouped CrossValidation:
#   Channel Caye_2       :   0.206  ✅
#   Hicks Caye_3         :   0.229  ✅
#   Big Creek_6          :   0.393  ✅
#   Big Creek_3          :  -0.063  ❌ negative — cause unknown
#   Hicks Caye_1         :  -0.058  ❌ negative — cause unknown
#   Big Creek_5          :   0.338  ✅
#   Gra Gra Lagoon_3     :  -0.237  ❌ negative — cause unknown
#   Drowned Caye_1       :   0.076  ✅
#   Big Creek_2          :   0.027  ✅
#   Drowned Caye_5       :   0.178  ✅
#
#   Mean : 0.109
#   Std  : 0.186
#
#   ❌ Grouped CV mean below 0.15 (0.109)
#   ✅ Grouped CV std below 0.25 (0.186)
#   ❌ Unexplained negative folds: ['Big Creek_3', 'Hicks Caye_1', 'Gra Gra Lagoon_3']
#   ❌ High-AGB sites failed: ['Big Creek_3']
#   ⚠️  Grouped CV and test R² diverge (gap: 0.171 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.111 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# [10/72]
#
#  EXPERIMENT-10 Plot groups. Without LOW VARIANCE ROWS, Model: ridge, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2'], ALGO: RIDGE REGRESSION:
# Test R²     : -0.0614
# Test RMSE   : 23.44 kg
# Train R² (log scale): 0.2121
# Train R² (orig scale): 0.0205
# Train RMSE  : 18.43 kg
# Num rows    : 2334
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: 0.0117
# CV R² std : 0.0939
# CV scores : [ 0.071  0.053  0.1   -0.001 -0.164]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1282
# Grouped CV R² std : 0.1840
# Grouped CV scores : [ 0.173  0.189  0.486 -0.01  -0.059  0.328 -0.167  0.074  0.034  0.234]
# ============================================================
#  EVALUATION: EXPERIMENT-10 Plot groups. Without LOW VARIANCE ROWS, Model: ridge, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2']
# ============================================================
#
# Test set:
#   R²   : -0.061
#   RMSE : 23.44 kg
#
# Regular CrossValidation:
#   Mean   : 0.012
#   Std    : 0.094
#   Scores : [ 0.071  0.053  0.1   -0.001 -0.164]
#
#   ❌ Test R² is negative (-0.061)
#   ✅ CV mean is positive (0.012)
#
# Grouped CrossValidation:
#   Channel Caye_2       :   0.173  ✅
#   Hicks Caye_3         :   0.189  ✅
#   Big Creek_6          :   0.486  ✅
#   Big Creek_3          :  -0.010  ❌ negative — cause unknown
#   Hicks Caye_1         :  -0.059  ❌ negative — cause unknown
#   Big Creek_5          :   0.328  ✅
#   Gra Gra Lagoon_3     :  -0.167  ❌ negative — cause unknown
#   Drowned Caye_1       :   0.074  ✅
#   Big Creek_2          :   0.034  ✅
#   Drowned Caye_5       :   0.234  ✅
#
#   Mean : 0.128
#   Std  : 0.184
#
#   ❌ Grouped CV mean below 0.15 (0.128)
#   ✅ Grouped CV std below 0.25 (0.184)
#   ❌ Unexplained negative folds: ['Big Creek_3', 'Hicks Caye_1', 'Gra Gra Lagoon_3']
#   ❌ High-AGB sites failed: ['Big Creek_3']
#   ⚠️  Grouped CV and test R² diverge (gap: 0.190 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: 0.082)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# [11/72]
#
#  EXPERIMENT-11 Plot groups. Without LOW VARIANCE ROWS, Model: lasso, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2'], ALGO: LASSO REGRESSION:
# Test R²     : -0.0672
# Test RMSE   : 23.50 kg
# Train R² (log scale): 0.1743
# Train R² (orig scale): -0.0143
# Train RMSE  : 18.75 kg
# Num rows    : 2334
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: 0.0106
# CV R² std : 0.1163
# CV scores : [ 0.135  0.056  0.077 -0.013 -0.202]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.0909
# Grouped CV R² std : 0.1822
# Grouped CV scores : [ 0.172  0.118  0.443 -0.047 -0.038  0.277 -0.26   0.109  0.015  0.121]
# ============================================================
#  EVALUATION: EXPERIMENT-11 Plot groups. Without LOW VARIANCE ROWS, Model: lasso, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2']
# ============================================================
#
# Test set:
#   R²   : -0.067
#   RMSE : 23.50 kg
#
# Regular CrossValidation:
#   Mean   : 0.011
#   Std    : 0.116
#   Scores : [ 0.135  0.056  0.077 -0.013 -0.202]
#
#   ❌ Test R² is negative (-0.067)
#   ✅ CV mean is positive (0.011)
#
# Grouped CrossValidation:
#   Channel Caye_2       :   0.172  ✅
#   Hicks Caye_3         :   0.118  ✅
#   Big Creek_6          :   0.443  ✅
#   Big Creek_3          :  -0.047  ❌ negative — cause unknown
#   Hicks Caye_1         :  -0.038  ❌ negative — cause unknown
#   Big Creek_5          :   0.277  ✅
#   Gra Gra Lagoon_3     :  -0.260  ❌ negative — cause unknown
#   Drowned Caye_1       :   0.109  ✅
#   Big Creek_2          :   0.015  ✅
#   Drowned Caye_5       :   0.121  ✅
#
#   Mean : 0.091
#   Std  : 0.182
#
#   ❌ Grouped CV mean below 0.15 (0.091)
#   ✅ Grouped CV std below 0.25 (0.182)
#   ❌ Unexplained negative folds: ['Big Creek_3', 'Hicks Caye_1', 'Gra Gra Lagoon_3']
#   ❌ High-AGB sites failed: ['Big Creek_3']
#   ⚠️  Grouped CV and test R² diverge (gap: 0.158 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: 0.053)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# [12/72]
#
#  EXPERIMENT-12 Plot groups. Without LOW VARIANCE ROWS, Model: elasticnet, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2'], ALGO: ELASTICNET REGRESSION:
# Test R²     : -0.0617
# Test RMSE   : 23.44 kg
# Train R² (log scale): 0.2171
# Train R² (orig scale): 0.0336
# Train RMSE  : 18.31 kg
# Num rows    : 2334
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: 0.0148
# CV R² std : 0.1205
# CV scores : [ 0.123  0.075  0.079  0.013 -0.216]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1037
# Grouped CV R² std : 0.1922
# Grouped CV scores : [ 0.189  0.135  0.486 -0.028 -0.042  0.298 -0.255  0.107  0.012  0.137]
# ============================================================
#  EVALUATION: EXPERIMENT-12 Plot groups. Without LOW VARIANCE ROWS, Model: elasticnet, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2']
# ============================================================
#
# Test set:
#   R²   : -0.062
#   RMSE : 23.44 kg
#
# Regular CrossValidation:
#   Mean   : 0.015
#   Std    : 0.120
#   Scores : [ 0.123  0.075  0.079  0.013 -0.216]
#
#   ❌ Test R² is negative (-0.062)
#   ✅ CV mean is positive (0.015)
#
# Grouped CrossValidation:
#   Channel Caye_2       :   0.189  ✅
#   Hicks Caye_3         :   0.135  ✅
#   Big Creek_6          :   0.486  ✅
#   Big Creek_3          :  -0.028  ❌ negative — cause unknown
#   Hicks Caye_1         :  -0.042  ❌ negative — cause unknown
#   Big Creek_5          :   0.298  ✅
#   Gra Gra Lagoon_3     :  -0.255  ❌ negative — cause unknown
#   Drowned Caye_1       :   0.107  ✅
#   Big Creek_2          :   0.012  ✅
#   Drowned Caye_5       :   0.137  ✅
#
#   Mean : 0.104
#   Std  : 0.192
#
#   ❌ Grouped CV mean below 0.15 (0.104)
#   ✅ Grouped CV std below 0.25 (0.192)
#   ❌ Unexplained negative folds: ['Big Creek_3', 'Hicks Caye_1', 'Gra Gra Lagoon_3']
#   ❌ High-AGB sites failed: ['Big Creek_3']
#   ⚠️  Grouped CV and test R² diverge (gap: 0.165 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: 0.095)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# [13/72]
#
#  EXPERIMENT-13 Plot groups. Without LOW VARIANCE ROWS, Model: regular, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'], ALGO: LINEAR REGRESSION:
# Test R²     : -0.0633
# Test RMSE   : 23.46 kg
# Train R² (log scale): 0.2291
# Train R² (orig scale): 0.0817
# Train RMSE  : 17.84 kg
# Num rows    : 2334
# Num Features: 12
#
#  Cross-validation ---
# CV R² mean: -0.0847
# CV R² std : 0.1342
# CV scores : [-0.197  0.078  0.039 -0.071 -0.273]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.0260
# Grouped CV R² std : 0.2319
# Grouped CV scores : [ 0.109 -0.088  0.24  -0.067 -0.083  0.348 -0.5    0.117 -0.072  0.256]
# ============================================================
#  EVALUATION: EXPERIMENT-13 Plot groups. Without LOW VARIANCE ROWS, Model: regular, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']
# ============================================================
#
# Test set:
#   R²   : -0.063
#   RMSE : 23.46 kg
#
# Regular CrossValidation:
#   Mean   : -0.085
#   Std    : 0.134
#   Scores : [-0.197  0.078  0.039 -0.071 -0.273]
#
#   ❌ Test R² is negative (-0.063)
#   ❌ CV mean is negative (-0.085)
#
# Grouped CrossValidation:
#   Channel Caye_2       :   0.109  ✅
#   Hicks Caye_3         :  -0.088  ❌ negative — cause unknown
#   Big Creek_6          :   0.240  ✅
#   Big Creek_3          :  -0.067  ❌ negative — cause unknown
#   Hicks Caye_1         :  -0.083  ❌ negative — cause unknown
#   Big Creek_5          :   0.348  ✅
#   Gra Gra Lagoon_3     :  -0.500  ❌ negative — cause unknown
#   Drowned Caye_1       :   0.117  ✅
#   Big Creek_2          :  -0.072  ❌ negative — cause unknown
#   Drowned Caye_5       :   0.256  ✅
#
#   Mean : 0.026
#   Std  : 0.232
#
#   ❌ Grouped CV mean below 0.15 (0.026)
#   ✅ Grouped CV std below 0.25 (0.232)
#   ❌ Unexplained negative folds: ['Hicks Caye_3', 'Big Creek_3', 'Hicks Caye_1', 'Gra Gra Lagoon_3', 'Big Creek_2']
#   ❌ High-AGB sites failed: ['Big Creek_3', 'Big Creek_2']
#   ⚠️  Grouped CV and test R² diverge (gap: 0.089 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.145 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# [14/72]
#
#  EXPERIMENT-14 Plot groups. Without LOW VARIANCE ROWS, Model: ridge, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'], ALGO: RIDGE REGRESSION:
# Test R²     : -0.0642
# Test RMSE   : 23.47 kg
# Train R² (log scale): 0.2199
# Train R² (orig scale): 0.0578
# Train RMSE  : 18.07 kg
# Num rows    : 2334
# Num Features: 12
#
#  Cross-validation ---
# CV R² mean: 0.0687
# CV R² std : 0.0949
# CV scores : [ 0.127  0.087  0.107  0.14  -0.118]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1410
# Grouped CV R² std : 0.1733
# Grouped CV scores : [ 0.157  0.257  0.474  0.007 -0.059  0.334 -0.113  0.097  0.046  0.211]
# ============================================================
#  EVALUATION: EXPERIMENT-14 Plot groups. Without LOW VARIANCE ROWS, Model: ridge, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']
# ============================================================
#
# Test set:
#   R²   : -0.064
#   RMSE : 23.47 kg
#
# Regular CrossValidation:
#   Mean   : 0.069
#   Std    : 0.095
#   Scores : [ 0.127  0.087  0.107  0.14  -0.118]
#
#   ❌ Test R² is negative (-0.064)
#   ✅ CV mean is positive (0.069)
#
# Grouped CrossValidation:
#   Channel Caye_2       :   0.157  ✅
#   Hicks Caye_3         :   0.257  ✅
#   Big Creek_6          :   0.474  ✅
#   Big Creek_3          :   0.007  ✅
#   Hicks Caye_1         :  -0.059  ❌ negative — cause unknown
#   Big Creek_5          :   0.334  ✅
#   Gra Gra Lagoon_3     :  -0.113  ❌ negative — cause unknown
#   Drowned Caye_1       :   0.097  ✅
#   Big Creek_2          :   0.046  ✅
#   Drowned Caye_5       :   0.211  ✅
#
#   Mean : 0.141
#   Std  : 0.173
#
#   ❌ Grouped CV mean below 0.15 (0.141)
#   ✅ Grouped CV std below 0.25 (0.173)
#   ❌ Unexplained negative folds: ['Hicks Caye_1', 'Gra Gra Lagoon_3']
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.205 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.122 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# [15/72]
#
#  EXPERIMENT-15 Plot groups. Without LOW VARIANCE ROWS, Model: lasso, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'], ALGO: LASSO REGRESSION:
# Test R²     : -0.0660
# Test RMSE   : 23.49 kg
# Train R² (log scale): 0.2191
# Train R² (orig scale): 0.0625
# Train RMSE  : 18.03 kg
# Num rows    : 2334
# Num Features: 12
#
#  Cross-validation ---
# CV R² mean: 0.0542
# CV R² std : 0.0924
# CV scores : [-0.013  0.097  0.101  0.173 -0.087]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1327
# Grouped CV R² std : 0.1567
# Grouped CV scores : [ 0.15   0.243  0.426  0.014 -0.055  0.274 -0.12   0.138  0.045  0.213]
# ============================================================
#  EVALUATION: EXPERIMENT-15 Plot groups. Without LOW VARIANCE ROWS, Model: lasso, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']
# ============================================================
#
# Test set:
#   R²   : -0.066
#   RMSE : 23.49 kg
#
# Regular CrossValidation:
#   Mean   : 0.054
#   Std    : 0.092
#   Scores : [-0.013  0.097  0.101  0.173 -0.087]
#
#   ❌ Test R² is negative (-0.066)
#   ✅ CV mean is positive (0.054)
#
# Grouped CrossValidation:
#   Channel Caye_2       :   0.150  ✅
#   Hicks Caye_3         :   0.243  ✅
#   Big Creek_6          :   0.426  ✅
#   Big Creek_3          :   0.014  ✅
#   Hicks Caye_1         :  -0.055  ❌ negative — cause unknown
#   Big Creek_5          :   0.274  ✅
#   Gra Gra Lagoon_3     :  -0.120  ❌ negative — cause unknown
#   Drowned Caye_1       :   0.138  ✅
#   Big Creek_2          :   0.045  ✅
#   Drowned Caye_5       :   0.213  ✅
#
#   Mean : 0.133
#   Std  : 0.157
#
#   ❌ Grouped CV mean below 0.15 (0.133)
#   ✅ Grouped CV std below 0.25 (0.157)
#   ❌ Unexplained negative folds: ['Hicks Caye_1', 'Gra Gra Lagoon_3']
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.199 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.129 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# [16/72]
#
#  EXPERIMENT-16 Plot groups. Without LOW VARIANCE ROWS, Model: elasticnet, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'], ALGO: ELASTICNET REGRESSION:
# Test R²     : -0.0648
# Test RMSE   : 23.48 kg
# Train R² (log scale): 0.2176
# Train R² (orig scale): 0.0513
# Train RMSE  : 18.14 kg
# Num rows    : 2334
# Num Features: 12
#
#  Cross-validation ---
# CV R² mean: 0.0634
# CV R² std : 0.1011
# CV scores : [-0.001  0.112  0.105  0.196 -0.095]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1442
# Grouped CV R² std : 0.1720
# Grouped CV scores : [ 0.149  0.256  0.488  0.023 -0.048  0.323 -0.116  0.111  0.049  0.207]
# ============================================================
#  EVALUATION: EXPERIMENT-16 Plot groups. Without LOW VARIANCE ROWS, Model: elasticnet, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']
# ============================================================
#
# Test set:
#   R²   : -0.065
#   RMSE : 23.48 kg
#
# Regular CrossValidation:
#   Mean   : 0.063
#   Std    : 0.101
#   Scores : [-0.001  0.112  0.105  0.196 -0.095]
#
#   ❌ Test R² is negative (-0.065)
#   ✅ CV mean is positive (0.063)
#
# Grouped CrossValidation:
#   Channel Caye_2       :   0.149  ✅
#   Hicks Caye_3         :   0.256  ✅
#   Big Creek_6          :   0.488  ✅
#   Big Creek_3          :   0.023  ✅
#   Hicks Caye_1         :  -0.048  ❌ negative — cause unknown
#   Big Creek_5          :   0.323  ✅
#   Gra Gra Lagoon_3     :  -0.116  ❌ negative — cause unknown
#   Drowned Caye_1       :   0.111  ✅
#   Big Creek_2          :   0.049  ✅
#   Drowned Caye_5       :   0.207  ✅
#
#   Mean : 0.144
#   Std  : 0.172
#
#   ❌ Grouped CV mean below 0.15 (0.144)
#   ✅ Grouped CV std below 0.25 (0.172)
#   ❌ Unexplained negative folds: ['Hicks Caye_1', 'Gra Gra Lagoon_3']
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.209 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.116 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# [17/72]
#
#  EXPERIMENT-17 Plot groups. Without LOW VARIANCE ROWS, Model: regular, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'], ALGO: LINEAR REGRESSION:
# Test R²     : -0.0588
# Test RMSE   : 23.41 kg
# Train R² (log scale): 0.2128
# Train R² (orig scale): 0.0575
# Train RMSE  : 18.08 kg
# Num rows    : 2334
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: -0.1075
# CV R² std : 0.1179
# CV scores : [-0.188  0.005  0.064 -0.197 -0.222]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.0874
# Grouped CV R² std : 0.2151
# Grouped CV scores : [ 0.216  0.246  0.445 -0.08  -0.229  0.316 -0.166 -0.075 -0.002  0.204]
# ============================================================
#  EVALUATION: EXPERIMENT-17 Plot groups. Without LOW VARIANCE ROWS, Model: regular, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']
# ============================================================
#
# Test set:
#   R²   : -0.059
#   RMSE : 23.41 kg
#
# Regular CrossValidation:
#   Mean   : -0.107
#   Std    : 0.118
#   Scores : [-0.188  0.005  0.064 -0.197 -0.222]
#
#   ❌ Test R² is negative (-0.059)
#   ❌ CV mean is negative (-0.107)
#
# Grouped CrossValidation:
#   Channel Caye_2       :   0.216  ✅
#   Hicks Caye_3         :   0.246  ✅
#   Big Creek_6          :   0.445  ✅
#   Big Creek_3          :  -0.080  ❌ negative — cause unknown
#   Hicks Caye_1         :  -0.229  ❌ negative — cause unknown
#   Big Creek_5          :   0.316  ✅
#   Gra Gra Lagoon_3     :  -0.166  ❌ negative — cause unknown
#   Drowned Caye_1       :  -0.075  ❌ negative — cause unknown
#   Big Creek_2          :  -0.002  ❌ negative — cause unknown
#   Drowned Caye_5       :   0.204  ✅
#
#   Mean : 0.087
#   Std  : 0.215
#
#   ❌ Grouped CV mean below 0.15 (0.087)
#   ✅ Grouped CV std below 0.25 (0.215)
#   ❌ Unexplained negative folds: ['Big Creek_3', 'Hicks Caye_1', 'Gra Gra Lagoon_3', 'Drowned Caye_1', 'Big Creek_2']
#   ❌ High-AGB sites failed: ['Big Creek_3', 'Big Creek_2']
#   ⚠️  Grouped CV and test R² diverge (gap: 0.146 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.116 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# [18/72]
#
#  EXPERIMENT-18 Plot groups. Without LOW VARIANCE ROWS, Model: ridge, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'], ALGO: RIDGE REGRESSION:
# Test R²     : -0.0666
# Test RMSE   : 23.50 kg
# Train R² (log scale): 0.2096
# Train R² (orig scale): 0.0328
# Train RMSE  : 18.31 kg
# Num rows    : 2334
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: 0.0287
# CV R² std : 0.0890
# CV scores : [ 0.082  0.088  0.069  0.053 -0.148]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1181
# Grouped CV R² std : 0.1986
# Grouped CV scores : [ 0.194  0.226  0.496 -0.031 -0.12   0.323 -0.13  -0.03   0.004  0.248]
# ============================================================
#  EVALUATION: EXPERIMENT-18 Plot groups. Without LOW VARIANCE ROWS, Model: ridge, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']
# ============================================================
#
# Test set:
#   R²   : -0.067
#   RMSE : 23.50 kg
#
# Regular CrossValidation:
#   Mean   : 0.029
#   Std    : 0.089
#   Scores : [ 0.082  0.088  0.069  0.053 -0.148]
#
#   ❌ Test R² is negative (-0.067)
#   ✅ CV mean is positive (0.029)
#
# Grouped CrossValidation:
#   Channel Caye_2       :   0.194  ✅
#   Hicks Caye_3         :   0.226  ✅
#   Big Creek_6          :   0.496  ✅
#   Big Creek_3          :  -0.031  ❌ negative — cause unknown
#   Hicks Caye_1         :  -0.120  ❌ negative — cause unknown
#   Big Creek_5          :   0.323  ✅
#   Gra Gra Lagoon_3     :  -0.130  ❌ negative — cause unknown
#   Drowned Caye_1       :  -0.030  ❌ negative — cause unknown
#   Big Creek_2          :   0.004  ✅
#   Drowned Caye_5       :   0.248  ✅
#
#   Mean : 0.118
#   Std  : 0.199
#
#   ❌ Grouped CV mean below 0.15 (0.118)
#   ✅ Grouped CV std below 0.25 (0.199)
#   ❌ Unexplained negative folds: ['Big Creek_3', 'Hicks Caye_1', 'Gra Gra Lagoon_3', 'Drowned Caye_1']
#   ❌ High-AGB sites failed: ['Big Creek_3']
#   ⚠️  Grouped CV and test R² diverge (gap: 0.185 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: 0.099)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# [19/72]
#
#  EXPERIMENT-19 Plot groups. Without LOW VARIANCE ROWS, Model: lasso, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'], ALGO: LASSO REGRESSION:
# Test R²     : -0.0734
# Test RMSE   : 23.57 kg
# Train R² (log scale): 0.1877
# Train R² (orig scale): -0.0035
# Train RMSE  : 18.65 kg
# Num rows    : 2334
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: 0.0291
# CV R² std : 0.0954
# CV scores : [ 0.11   0.101  0.061  0.026 -0.152]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1081
# Grouped CV R² std : 0.1814
# Grouped CV scores : [ 0.142  0.16   0.459  0.011 -0.042  0.298 -0.216  0.05  -0.004  0.223]
# ============================================================
#  EVALUATION: EXPERIMENT-19 Plot groups. Without LOW VARIANCE ROWS, Model: lasso, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']
# ============================================================
#
# Test set:
#   R²   : -0.073
#   RMSE : 23.57 kg
#
# Regular CrossValidation:
#   Mean   : 0.029
#   Std    : 0.095
#   Scores : [ 0.11   0.101  0.061  0.026 -0.152]
#
#   ❌ Test R² is negative (-0.073)
#   ✅ CV mean is positive (0.029)
#
# Grouped CrossValidation:
#   Channel Caye_2       :   0.142  ✅
#   Hicks Caye_3         :   0.160  ✅
#   Big Creek_6          :   0.459  ✅
#   Big Creek_3          :   0.011  ✅
#   Hicks Caye_1         :  -0.042  ❌ negative — cause unknown
#   Big Creek_5          :   0.298  ✅
#   Gra Gra Lagoon_3     :  -0.216  ❌ negative — cause unknown
#   Drowned Caye_1       :   0.050  ✅
#   Big Creek_2          :  -0.004  ❌ negative — cause unknown
#   Drowned Caye_5       :   0.223  ✅
#
#   Mean : 0.108
#   Std  : 0.181
#
#   ❌ Grouped CV mean below 0.15 (0.108)
#   ✅ Grouped CV std below 0.25 (0.181)
#   ❌ Unexplained negative folds: ['Hicks Caye_1', 'Gra Gra Lagoon_3', 'Big Creek_2']
#   ❌ High-AGB sites failed: ['Big Creek_2']
#   ⚠️  Grouped CV and test R² diverge (gap: 0.181 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: 0.070)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# [20/72]
#
#  EXPERIMENT-20 Plot groups. Without LOW VARIANCE ROWS, Model: elasticnet, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'], ALGO: ELASTICNET REGRESSION:
# Test R²     : -0.0727
# Test RMSE   : 23.57 kg
# Train R² (log scale): 0.1905
# Train R² (orig scale): -0.0003
# Train RMSE  : 18.62 kg
# Num rows    : 2334
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: 0.0394
# CV R² std : 0.0991
# CV scores : [ 0.114  0.102  0.061  0.075 -0.155]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1110
# Grouped CV R² std : 0.1826
# Grouped CV scores : [ 0.152  0.168  0.468 -0.003 -0.048  0.302 -0.198  0.042 -0.001  0.227]
# ============================================================
#  EVALUATION: EXPERIMENT-20 Plot groups. Without LOW VARIANCE ROWS, Model: elasticnet, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE']
# ============================================================
#
# Test set:
#   R²   : -0.073
#   RMSE : 23.57 kg
#
# Regular CrossValidation:
#   Mean   : 0.039
#   Std    : 0.099
#   Scores : [ 0.114  0.102  0.061  0.075 -0.155]
#
#   ❌ Test R² is negative (-0.073)
#   ✅ CV mean is positive (0.039)
#
# Grouped CrossValidation:
#   Channel Caye_2       :   0.152  ✅
#   Hicks Caye_3         :   0.168  ✅
#   Big Creek_6          :   0.468  ✅
#   Big Creek_3          :  -0.003  ❌ negative — cause unknown
#   Hicks Caye_1         :  -0.048  ❌ negative — cause unknown
#   Big Creek_5          :   0.302  ✅
#   Gra Gra Lagoon_3     :  -0.198  ❌ negative — cause unknown
#   Drowned Caye_1       :   0.042  ✅
#   Big Creek_2          :  -0.001  ❌ negative — cause unknown
#   Drowned Caye_5       :   0.227  ✅
#
#   Mean : 0.111
#   Std  : 0.183
#
#   ❌ Grouped CV mean below 0.15 (0.111)
#   ✅ Grouped CV std below 0.25 (0.183)
#   ❌ Unexplained negative folds: ['Big Creek_3', 'Hicks Caye_1', 'Gra Gra Lagoon_3', 'Big Creek_2']
#   ❌ High-AGB sites failed: ['Big Creek_3', 'Big Creek_2']
#   ⚠️  Grouped CV and test R² diverge (gap: 0.184 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: 0.072)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# [21/72]
#
#  EXPERIMENT-21 Plot groups. Without LOW VARIANCE ROWS, Model: regular, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'], ALGO: LINEAR REGRESSION:
# Test R²     : -0.0711
# Test RMSE   : 23.55 kg
# Train R² (log scale): 0.2205
# Train R² (orig scale): 0.0721
# Train RMSE  : 17.94 kg
# Num rows    : 2334
# Num Features: 12
#
#  Cross-validation ---
# CV R² mean: -0.0671
# CV R² std : 0.2438
# CV scores : [ 0.116  0.041  0.046  0.012 -0.55 ]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.0198
# Grouped CV R² std : 0.2138
# Grouped CV scores : [-0.001 -0.175  0.42  -0.043 -0.314  0.326 -0.164 -0.008  0.014  0.144]
# ============================================================
#  EVALUATION: EXPERIMENT-21 Plot groups. Without LOW VARIANCE ROWS, Model: regular, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']
# ============================================================
#
# Test set:
#   R²   : -0.071
#   RMSE : 23.55 kg
#
# Regular CrossValidation:
#   Mean   : -0.067
#   Std    : 0.244
#   Scores : [ 0.116  0.041  0.046  0.012 -0.55 ]
#
#   ❌ Test R² is negative (-0.071)
#   ❌ CV mean is negative (-0.067)
#
# Grouped CrossValidation:
#   Channel Caye_2       :  -0.001  ❌ negative — cause unknown
#   Hicks Caye_3         :  -0.175  ❌ negative — cause unknown
#   Big Creek_6          :   0.420  ✅
#   Big Creek_3          :  -0.043  ❌ negative — cause unknown
#   Hicks Caye_1         :  -0.314  ❌ negative — cause unknown
#   Big Creek_5          :   0.326  ✅
#   Gra Gra Lagoon_3     :  -0.164  ❌ negative — cause unknown
#   Drowned Caye_1       :  -0.008  ❌ negative — cause unknown
#   Big Creek_2          :   0.014  ✅
#   Drowned Caye_5       :   0.144  ✅
#
#   Mean : 0.020
#   Std  : 0.214
#
#   ❌ Grouped CV mean below 0.15 (0.020)
#   ✅ Grouped CV std below 0.25 (0.214)
#   ❌ Unexplained negative folds: ['Channel Caye_2', 'Hicks Caye_3', 'Big Creek_3', 'Hicks Caye_1', 'Gra Gra Lagoon_3', 'Drowned Caye_1']
#   ❌ High-AGB sites failed: ['Channel Caye_2', 'Big Creek_3']
#   ⚠️  Grouped CV and test R² diverge (gap: 0.091 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.143 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# [22/72]
#
#  EXPERIMENT-22 Plot groups. Without LOW VARIANCE ROWS, Model: ridge, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'], ALGO: RIDGE REGRESSION:
# Test R²     : -0.0676
# Test RMSE   : 23.51 kg
# Train R² (log scale): 0.2195
# Train R² (orig scale): 0.0621
# Train RMSE  : 18.03 kg
# Num rows    : 2334
# Num Features: 12
#
#  Cross-validation ---
# CV R² mean: 0.0709
# CV R² std : 0.0848
# CV scores : [ 0.104  0.086  0.092  0.162 -0.09 ]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1335
# Grouped CV R² std : 0.1800
# Grouped CV scores : [ 0.161  0.251  0.486 -0.006 -0.079  0.328 -0.101  0.037  0.034  0.225]
# ============================================================
#  EVALUATION: EXPERIMENT-22 Plot groups. Without LOW VARIANCE ROWS, Model: ridge, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']
# ============================================================
#
# Test set:
#   R²   : -0.068
#   RMSE : 23.51 kg
#
# Regular CrossValidation:
#   Mean   : 0.071
#   Std    : 0.085
#   Scores : [ 0.104  0.086  0.092  0.162 -0.09 ]
#
#   ❌ Test R² is negative (-0.068)
#   ✅ CV mean is positive (0.071)
#
# Grouped CrossValidation:
#   Channel Caye_2       :   0.161  ✅
#   Hicks Caye_3         :   0.251  ✅
#   Big Creek_6          :   0.486  ✅
#   Big Creek_3          :  -0.006  ❌ negative — cause unknown
#   Hicks Caye_1         :  -0.079  ❌ negative — cause unknown
#   Big Creek_5          :   0.328  ✅
#   Gra Gra Lagoon_3     :  -0.101  ❌ negative — cause unknown
#   Drowned Caye_1       :   0.037  ✅
#   Big Creek_2          :   0.034  ✅
#   Drowned Caye_5       :   0.225  ✅
#
#   Mean : 0.133
#   Std  : 0.180
#
#   ❌ Grouped CV mean below 0.15 (0.133)
#   ✅ Grouped CV std below 0.25 (0.180)
#   ❌ Unexplained negative folds: ['Big Creek_3', 'Hicks Caye_1', 'Gra Gra Lagoon_3']
#   ❌ High-AGB sites failed: ['Big Creek_3']
#   ⚠️  Grouped CV and test R² diverge (gap: 0.201 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.130 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# [23/72]
#
#  EXPERIMENT-23 Plot groups. Without LOW VARIANCE ROWS, Model: lasso, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'], ALGO: LASSO REGRESSION:
# Test R²     : -0.0684
# Test RMSE   : 23.52 kg
# Train R² (log scale): 0.2181
# Train R² (orig scale): 0.0587
# Train RMSE  : 18.07 kg
# Num rows    : 2334
# Num Features: 12
#
#  Cross-validation ---
# CV R² mean: 0.0662
# CV R² std : 0.0704
# CV scores : [-0.013  0.088  0.087  0.176 -0.008]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1298
# Grouped CV R² std : 0.1643
# Grouped CV scores : [ 0.134  0.244  0.448 -0.011 -0.043  0.284 -0.116  0.094  0.03   0.235]
# ============================================================
#  EVALUATION: EXPERIMENT-23 Plot groups. Without LOW VARIANCE ROWS, Model: lasso, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']
# ============================================================
#
# Test set:
#   R²   : -0.068
#   RMSE : 23.52 kg
#
# Regular CrossValidation:
#   Mean   : 0.066
#   Std    : 0.070
#   Scores : [-0.013  0.088  0.087  0.176 -0.008]
#
#   ❌ Test R² is negative (-0.068)
#   ✅ CV mean is positive (0.066)
#
# Grouped CrossValidation:
#   Channel Caye_2       :   0.134  ✅
#   Hicks Caye_3         :   0.244  ✅
#   Big Creek_6          :   0.448  ✅
#   Big Creek_3          :  -0.011  ❌ negative — cause unknown
#   Hicks Caye_1         :  -0.043  ❌ negative — cause unknown
#   Big Creek_5          :   0.284  ✅
#   Gra Gra Lagoon_3     :  -0.116  ❌ negative — cause unknown
#   Drowned Caye_1       :   0.094  ✅
#   Big Creek_2          :   0.030  ✅
#   Drowned Caye_5       :   0.235  ✅
#
#   Mean : 0.130
#   Std  : 0.164
#
#   ❌ Grouped CV mean below 0.15 (0.130)
#   ✅ Grouped CV std below 0.25 (0.164)
#   ❌ Unexplained negative folds: ['Big Creek_3', 'Hicks Caye_1', 'Gra Gra Lagoon_3']
#   ❌ High-AGB sites failed: ['Big Creek_3']
#   ⚠️  Grouped CV and test R² diverge (gap: 0.198 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.127 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# [24/72]
#
# ...
#  EVALUATION: EXPERIMENT-65 Plot groups. Without LOW VARIANCE ROWS, Model: regular, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2']
# ============================================================
#
# Test set:
#   R²   : -0.045
#   RMSE : 23.26 kg
#
# Regular CrossValidation:
#   Mean   : -0.049
#   Std    : 0.163
#   Scores : [ 0.069  0.09   0.089 -0.213 -0.279]
#
#   ❌ Test R² is negative (-0.045)
#   ❌ CV mean is negative (-0.049)
#
# Grouped CrossValidation:
#   Channel Caye_2       :   0.118  ✅
#   Hicks Caye_3         :   0.182  ✅
#   Big Creek_6          :   0.479  ✅
#   Big Creek_3          :  -0.074  ❌ negative — cause unknown
#   Hicks Caye_1         :  -0.108  ❌ negative — cause unknown
#   Big Creek_5          :   0.333  ✅
#   Gra Gra Lagoon_3     :   0.090  ✅
#   Drowned Caye_1       :   0.185  ✅
#   Big Creek_2          :   0.058  ✅
#   Drowned Caye_5       :   0.297  ✅
#
#   Mean : 0.156
#   Std  : 0.172
#
#   ✅ Grouped CV mean above 0.15 (0.156)
#   ✅ Grouped CV std below 0.25 (0.172)
#   ❌ Unexplained negative folds: ['Big Creek_3', 'Hicks Caye_1']
#   ❌ High-AGB sites failed: ['Big Creek_3']
#   ⚠️  Grouped CV and test R² diverge (gap: 0.201 > 0.05) — possible leakage or instability
#   ✅ Train/test R² gap acceptable (gap: 0.096)
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# [66/72]
#
#  EXPERIMENT-66 Plot groups. Without LOW VARIANCE ROWS, Model: ridge, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2'], ALGO: RIDGE REGRESSION:
# Test R²     : -0.0558
# Test RMSE   : 23.38 kg
# Train R² (log scale): 0.2392
# Train R² (orig scale): 0.0534
# Train RMSE  : 18.12 kg
# Num rows    : 2334
# Num Features: 10
#
#  Cross-validation ---
# CV R² mean: 0.0178
# CV R² std : 0.0897
# CV scores : [ 0.033  0.104  0.122 -0.104 -0.066]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1662
# Grouped CV R² std : 0.1616
# Grouped CV scores : [ 0.126  0.21   0.512  0.059 -0.07   0.314  0.015  0.15   0.06   0.285]
# ============================================================
#  EVALUATION: EXPERIMENT-66 Plot groups. Without LOW VARIANCE ROWS, Model: ridge, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2']
# ============================================================
#
# Test set:
#   R²   : -0.056
#   RMSE : 23.38 kg
#
# Regular CrossValidation:
#   Mean   : 0.018
#   Std    : 0.090
#   Scores : [ 0.033  0.104  0.122 -0.104 -0.066]
#
#   ❌ Test R² is negative (-0.056)
#   ✅ CV mean is positive (0.018)
#
# Grouped CrossValidation:
#   Channel Caye_2       :   0.126  ✅
#   Hicks Caye_3         :   0.210  ✅
#   Big Creek_6          :   0.512  ✅
#   Big Creek_3          :   0.059  ✅
#   Hicks Caye_1         :  -0.070  ❌ negative — cause unknown
#   Big Creek_5          :   0.314  ✅
#   Gra Gra Lagoon_3     :   0.015  ✅
#   Drowned Caye_1       :   0.150  ✅
#   Big Creek_2          :   0.060  ✅
#   Drowned Caye_5       :   0.285  ✅
#
#   Mean : 0.166
#   Std  : 0.162
#
#   ✅ Grouped CV mean above 0.15 (0.166)
#   ✅ Grouped CV std below 0.25 (0.162)
#   ❌ Unexplained negative folds: ['Hicks Caye_1']
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.222 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.109 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# [67/72]
#
#  EXPERIMENT-67 Plot groups. Without LOW VARIANCE ROWS, Model: lasso, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2'], ALGO: LASSO REGRESSION:
# Test R²     : -0.0564
# Test RMSE   : 23.39 kg
# Train R² (log scale): 0.2379
# Train R² (orig scale): 0.0575
# Train RMSE  : 18.08 kg
# Num rows    : 2334
# Num Features: 10
#
#  Cross-validation ---
# CV R² mean: -0.0056
# CV R² std : 0.1134
# CV scores : [-0.01   0.1    0.099 -0.211 -0.005]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1500
# Grouped CV R² std : 0.1401
# Grouped CV scores : [ 0.135  0.223  0.438  0.062 -0.068  0.279  0.002  0.144  0.058  0.227]
# ============================================================
#  EVALUATION: EXPERIMENT-67 Plot groups. Without LOW VARIANCE ROWS, Model: lasso, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2']
# ============================================================
#
# Test set:
#   R²   : -0.056
#   RMSE : 23.39 kg
#
# Regular CrossValidation:
#   Mean   : -0.006
#   Std    : 0.113
#   Scores : [-0.01   0.1    0.099 -0.211 -0.005]
#
#   ❌ Test R² is negative (-0.056)
#   ❌ CV mean is negative (-0.006)
#
# Grouped CrossValidation:
#   Channel Caye_2       :   0.135  ✅
#   Hicks Caye_3         :   0.223  ✅
#   Big Creek_6          :   0.438  ✅
#   Big Creek_3          :   0.062  ✅
#   Hicks Caye_1         :  -0.068  ❌ negative — cause unknown
#   Big Creek_5          :   0.279  ✅
#   Gra Gra Lagoon_3     :   0.002  ✅
#   Drowned Caye_1       :   0.144  ✅
#   Big Creek_2          :   0.058  ✅
#   Drowned Caye_5       :   0.227  ✅
#
#   Mean : 0.150
#   Std  : 0.140
#
#   ✅ Grouped CV mean above 0.15 (0.150)
#   ✅ Grouped CV std below 0.25 (0.140)
#   ❌ Unexplained negative folds: ['Hicks Caye_1']
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.206 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.114 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# [68/72]
#
#  EXPERIMENT-68 Plot groups. Without LOW VARIANCE ROWS, Model: elasticnet, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2'], ALGO: ELASTICNET REGRESSION:
# Test R²     : -0.0584
# Test RMSE   : 23.41 kg
# Train R² (log scale): 0.2335
# Train R² (orig scale): 0.0458
# Train RMSE  : 18.19 kg
# Num rows    : 2334
# Num Features: 10
#
#  Cross-validation ---
# CV R² mean: 0.0530
# CV R² std : 0.0661
# CV scores : [ 0.007  0.124  0.143 -0.011  0.002]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1669
# Grouped CV R² std : 0.1577
# Grouped CV scores : [ 0.135  0.223  0.503  0.068 -0.036  0.314 -0.022  0.154  0.058  0.273]
# ============================================================
#  EVALUATION: EXPERIMENT-68 Plot groups. Without LOW VARIANCE ROWS, Model: elasticnet, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2']
# ============================================================
#
# Test set:
#   R²   : -0.058
#   RMSE : 23.41 kg
#
# Regular CrossValidation:
#   Mean   : 0.053
#   Std    : 0.066
#   Scores : [ 0.007  0.124  0.143 -0.011  0.002]
#
#   ❌ Test R² is negative (-0.058)
#   ✅ CV mean is positive (0.053)
#
# Grouped CrossValidation:
#   Channel Caye_2       :   0.135  ✅
#   Hicks Caye_3         :   0.223  ✅
#   Big Creek_6          :   0.503  ✅
#   Big Creek_3          :   0.068  ✅
#   Hicks Caye_1         :  -0.036  ❌ negative — cause unknown
#   Big Creek_5          :   0.314  ✅
#   Gra Gra Lagoon_3     :  -0.022  ❌ negative — cause unknown
#   Drowned Caye_1       :   0.154  ✅
#   Big Creek_2          :   0.058  ✅
#   Drowned Caye_5       :   0.273  ✅
#
#   Mean : 0.167
#   Std  : 0.158
#
#   ✅ Grouped CV mean above 0.15 (0.167)
#   ✅ Grouped CV std below 0.25 (0.158)
#   ❌ Unexplained negative folds: ['Hicks Caye_1', 'Gra Gra Lagoon_3']
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.225 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.104 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# [69/72]
#
#  EXPERIMENT-69 Plot groups. Without LOW VARIANCE ROWS, Model: regular, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'], ALGO: LINEAR REGRESSION:
# Test R²     : -0.0518
# Test RMSE   : 23.33 kg
# Train R² (log scale): 0.2640
# Train R² (orig scale): 0.0806
# Train RMSE  : 17.85 kg
# Num rows    : 2334
# Num Features: 13
#
#  Cross-validation ---
# CV R² mean: -0.3288
# CV R² std : 0.6272
# CV scores : [-1.532  0.152  0.187 -0.219 -0.232]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1213
# Grouped CV R² std : 0.1921
# Grouped CV scores : [ 0.155 -0.053  0.449 -0.016 -0.084  0.333 -0.049  0.25  -0.085  0.313]
# ============================================================
#  EVALUATION: EXPERIMENT-69 Plot groups. Without LOW VARIANCE ROWS, Model: regular, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']
# ============================================================
#
# Test set:
#   R²   : -0.052
#   RMSE : 23.33 kg
#
# Regular CrossValidation:
#   Mean   : -0.329
#   Std    : 0.627
#   Scores : [-1.532  0.152  0.187 -0.219 -0.232]
#
#   ❌ Test R² is negative (-0.052)
#   ❌ CV mean is negative (-0.329)
#
# Grouped CrossValidation:
#   Channel Caye_2       :   0.155  ✅
#   Hicks Caye_3         :  -0.053  ❌ negative — cause unknown
#   Big Creek_6          :   0.449  ✅
#   Big Creek_3          :  -0.016  ❌ negative — cause unknown
#   Hicks Caye_1         :  -0.084  ❌ negative — cause unknown
#   Big Creek_5          :   0.333  ✅
#   Gra Gra Lagoon_3     :  -0.049  ❌ negative — cause unknown
#   Drowned Caye_1       :   0.250  ✅
#   Big Creek_2          :  -0.085  ❌ negative — cause unknown
#   Drowned Caye_5       :   0.313  ✅
#
#   Mean : 0.121
#   Std  : 0.192
#
#   ❌ Grouped CV mean below 0.15 (0.121)
#   ✅ Grouped CV std below 0.25 (0.192)
#   ❌ Unexplained negative folds: ['Hicks Caye_3', 'Big Creek_3', 'Hicks Caye_1', 'Gra Gra Lagoon_3', 'Big Creek_2']
#   ❌ High-AGB sites failed: ['Big Creek_3', 'Big Creek_2']
#   ⚠️  Grouped CV and test R² diverge (gap: 0.173 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.132 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# [70/72]
#
#  EXPERIMENT-70 Plot groups. Without LOW VARIANCE ROWS, Model: ridge, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'], ALGO: RIDGE REGRESSION:
# Test R²     : -0.0533
# Test RMSE   : 23.35 kg
# Train R² (log scale): 0.2405
# Train R² (orig scale): 0.0582
# Train RMSE  : 18.07 kg
# Num rows    : 2334
# Num Features: 13
#
#  Cross-validation ---
# CV R² mean: 0.0297
# CV R² std : 0.0942
# CV scores : [ 0.084  0.1    0.131 -0.1   -0.067]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1664
# Grouped CV R² std : 0.1606
# Grouped CV scores : [ 0.131  0.197  0.507  0.061 -0.076  0.316  0.02   0.154  0.064  0.291]
# ============================================================
#  EVALUATION: EXPERIMENT-70 Plot groups. Without LOW VARIANCE ROWS, Model: ridge, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']
# ============================================================
#
# Test set:
#   R²   : -0.053
#   RMSE : 23.35 kg
#
# Regular CrossValidation:
#   Mean   : 0.030
#   Std    : 0.094
#   Scores : [ 0.084  0.1    0.131 -0.1   -0.067]
#
#   ❌ Test R² is negative (-0.053)
#   ✅ CV mean is positive (0.030)
#
# Grouped CrossValidation:
#   Channel Caye_2       :   0.131  ✅
#   Hicks Caye_3         :   0.197  ✅
#   Big Creek_6          :   0.507  ✅
#   Big Creek_3          :   0.061  ✅
#   Hicks Caye_1         :  -0.076  ❌ negative — cause unknown
#   Big Creek_5          :   0.316  ✅
#   Gra Gra Lagoon_3     :   0.020  ✅
#   Drowned Caye_1       :   0.154  ✅
#   Big Creek_2          :   0.064  ✅
#   Drowned Caye_5       :   0.291  ✅
#
#   Mean : 0.166
#   Std  : 0.161
#
#   ✅ Grouped CV mean above 0.15 (0.166)
#   ✅ Grouped CV std below 0.25 (0.161)
#   ❌ Unexplained negative folds: ['Hicks Caye_1']
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.220 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.111 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# [71/72]
#
#  EXPERIMENT-71 Plot groups. Without LOW VARIANCE ROWS, Model: lasso, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'], ALGO: LASSO REGRESSION:
# Test R²     : -0.0543
# Test RMSE   : 23.36 kg
# Train R² (log scale): 0.2394
# Train R² (orig scale): 0.0601
# Train RMSE  : 18.05 kg
# Num rows    : 2334
# Num Features: 13
#
#  Cross-validation ---
# CV R² mean: 0.0730
# CV R² std : 0.0623
# CV scores : [ 0.01   0.103  0.103  0.157 -0.008]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1491
# Grouped CV R² std : 0.1392
# Grouped CV scores : [ 0.14   0.212  0.432  0.061 -0.07   0.278 -0.002  0.151  0.06   0.23 ]
# ============================================================
#  EVALUATION: EXPERIMENT-71 Plot groups. Without LOW VARIANCE ROWS, Model: lasso, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']
# ============================================================
#
# Test set:
#   R²   : -0.054
#   RMSE : 23.36 kg
#
# Regular CrossValidation:
#   Mean   : 0.073
#   Std    : 0.062
#   Scores : [ 0.01   0.103  0.103  0.157 -0.008]
#
#   ❌ Test R² is negative (-0.054)
#   ✅ CV mean is positive (0.073)
#
# Grouped CrossValidation:
#   Channel Caye_2       :   0.140  ✅
#   Hicks Caye_3         :   0.212  ✅
#   Big Creek_6          :   0.432  ✅
#   Big Creek_3          :   0.061  ✅
#   Hicks Caye_1         :  -0.070  ❌ negative — cause unknown
#   Big Creek_5          :   0.278  ✅
#   Gra Gra Lagoon_3     :  -0.002  ❌ negative — cause unknown
#   Drowned Caye_1       :   0.151  ✅
#   Big Creek_2          :   0.060  ✅
#   Drowned Caye_5       :   0.230  ✅
#
#   Mean : 0.149
#   Std  : 0.139
#
#   ❌ Grouped CV mean below 0.15 (0.149)
#   ✅ Grouped CV std below 0.25 (0.139)
#   ❌ Unexplained negative folds: ['Hicks Caye_1', 'Gra Gra Lagoon_3']
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.203 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.114 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# [72/72]
#
#  EXPERIMENT-72 Plot groups. Without LOW VARIANCE ROWS, Model: elasticnet, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'], ALGO: ELASTICNET REGRESSION:
# Test R²     : -0.0556
# Test RMSE   : 23.38 kg
# Train R² (log scale): 0.2357
# Train R² (orig scale): 0.0531
# Train RMSE  : 18.12 kg
# Num rows    : 2334
# Num Features: 13
#
#  Cross-validation ---
# CV R² mean: 0.0944
# CV R² std : 0.0680
# CV scores : [0.023 0.126 0.152 0.168 0.003]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: 0.1684
# Grouped CV R² std : 0.1564
# Grouped CV scores : [ 0.14   0.203  0.501  0.071 -0.049  0.317 -0.003  0.159  0.064  0.281]
# ============================================================
#  EVALUATION: EXPERIMENT-72 Plot groups. Without LOW VARIANCE ROWS, Model: elasticnet, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1']
# ============================================================
#
# Test set:
#   R²   : -0.056
#   RMSE : 23.38 kg
#
# Regular CrossValidation:
#   Mean   : 0.094
#   Std    : 0.068
#   Scores : [0.023 0.126 0.152 0.168 0.003]
#
#   ❌ Test R² is negative (-0.056)
#   ✅ CV mean is positive (0.094)
#
# Grouped CrossValidation:
#   Channel Caye_2       :   0.140  ✅
#   Hicks Caye_3         :   0.203  ✅
#   Big Creek_6          :   0.501  ✅
#   Big Creek_3          :   0.071  ✅
#   Hicks Caye_1         :  -0.049  ❌ negative — cause unknown
#   Big Creek_5          :   0.317  ✅
#   Gra Gra Lagoon_3     :  -0.003  ❌ negative — cause unknown
#   Drowned Caye_1       :   0.159  ✅
#   Big Creek_2          :   0.064  ✅
#   Drowned Caye_5       :   0.281  ✅
#
#   Mean : 0.168
#   Std  : 0.156
#
#   ✅ Grouped CV mean above 0.15 (0.168)
#   ✅ Grouped CV std below 0.25 (0.156)
#   ❌ Unexplained negative folds: ['Hicks Caye_1', 'Gra Gra Lagoon_3']
#   ✅ High-AGB sites generalize correctly
#   ⚠️  Grouped CV and test R² diverge (gap: 0.224 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.109 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Completed: 72/72 experiments

# %%
# %run Model_functions.ipynb
tabulate_results(lin_belige_subset_groups, acceptable_only=True)
# Out:
# Showing 0 acceptable experiments
# No acceptable experiments found.

# %% [markdown]
# ### BELIGE WITHOUT LOW VARIANCE ROWS. PLOT GROUPS. RANDOM FOREST. NO Grid

# %%
# %run Model_functions.ipynb

rf_belige_subset_no_grid_groups = {}

run_experiment(X_belige_sub, y_belige_sub,
               is_groups=True, group_info=grp_belige_sub,
               features_list=gen_features_list,
               experiments=rf_belige_subset_no_grid_groups,
               model_type="rf",
               is_grid=False,
               is_stratified=is_stratified_g,
               global_experiment_list=global_experiment_list)
# Out:
# [1/18]
#
#  RANDOM FOREST: EXPERIMENT-1 Plot groups. Without LOW VARIANCE ROWS. No Grid, Features: ['height'].
# Test R²     : -0.0580
# Test RMSE   : 23.40 kg
# Train R² (log scale): 0.2795
# Train R² (orig scale): 0.1721
# Train RMSE  : 16.94 kg
# Num rows    : 2334
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: -0.2130
# CV R² std : 0.2522
# CV scores : [-0.3    0.114 -0.138 -0.099 -0.643]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.5160
# Grouped CV R² std : 1.3000
# Grouped CV scores : [-1.590e-01 -5.700e-02 -4.300e-02 -5.000e-03 -0.000e+00 -7.400e-02
#  -6.770e-01 -1.300e-02 -3.500e-02 -3.200e-02 -6.190e-01 -1.410e-01
#  -9.600e-02 -1.000e-03 -7.830e-01 -2.000e-02 -1.900e-02 -1.000e-03
#  -0.000e+00 -4.200e-02 -5.570e-01 -2.560e-01 -8.800e-02 -1.730e-01
#  -9.810e-01 -8.300e-02 -1.900e-02 -7.460e-01 -1.080e-01 -2.000e-03
#  -2.250e-01 -7.757e+00 -1.796e+00 -1.267e+00 -1.327e+00 -3.740e-01]
# ============================================================
#  EVALUATION: EXPERIMENT-1 Plot groups. Without LOW VARIANCE ROWS. No Grid, Features: ['height'].
# ============================================================
#
# Test set:
#   R²   : -0.058
#   RMSE : 23.40 kg
#
# Regular CrossValidation:
#   Mean   : -0.213
#   Std    : 0.252
#   Scores : [-0.3    0.114 -0.138 -0.099 -0.643]
#
#   ❌ Test R² is negative (-0.058)
#   ❌ CV mean is negative (-0.213)
#
# Grouped CrossValidation:
#   Channel Caye_2       :  -0.159  ❌ negative — cause unknown
#   Hicks Caye_3         :  -0.057  ❌ negative — cause unknown
#   Big Creek_6          :  -0.043  ❌ negative — cause unknown
#   Big Creek_3          :  -0.005  ❌ negative — cause unknown
#   Hicks Caye_1         :  -0.000  ❌ negative — cause unknown
#   Big Creek_5          :  -0.074  ❌ negative — cause unknown
#   Gra Gra Lagoon_3     :  -0.677  ❌ negative — cause unknown
#   Drowned Caye_1       :  -0.013  ❌ negative — cause unknown
#   Big Creek_2          :  -0.035  ❌ negative — cause unknown
#   Drowned Caye_5       :  -0.032  ❌ negative — cause unknown
#
#   Mean : -0.516
#   Std  : 1.300
#
#   ❌ Grouped CV mean below 0.15 (-0.516)
#   ⚠️  Grouped CV std above 0.25 (1.300) — high variance across folds
#   ❌ Unexplained negative folds: ['Channel Caye_2', 'Hicks Caye_3', 'Big Creek_6', 'Big Creek_3', 'Hicks Caye_1', 'Big Creek_5', 'Gra Gra Lagoon_3', 'Drowned Caye_1', 'Big Creek_2', 'Drowned Caye_5']
#   ❌ High-AGB sites failed: ['Channel Caye_2', 'Big Creek_6', 'Big Creek_3', 'Big Creek_5', 'Big Creek_2']
#   ⚠️  Grouped CV and test R² diverge (gap: 0.458 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.230 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height                                        1.0000  ==================================================
#
# [2/18]
#
#  RANDOM FOREST: EXPERIMENT-2 Plot groups. Without LOW VARIANCE ROWS. No Grid, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : -0.0765
# Test RMSE   : 23.61 kg
# Train R² (log scale): 0.2795
# Train R² (orig scale): 0.1721
# Train RMSE  : 16.94 kg
# Num rows    : 2334
# Num Features: 4
#
#  Cross-validation ---
# CV R² mean: -0.1983
# CV R² std : 0.2265
# CV scores : [-0.206  0.088 -0.163 -0.107 -0.604]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.6551
# Grouped CV R² std : 1.6144
# Grouped CV scores : [-1.590e-01 -2.400e-02 -6.409e+00 -1.200e-02 -0.000e+00 -2.000e-03
#  -6.340e-01 -3.900e-02 -1.000e-02 -4.600e-02 -6.190e-01 -1.270e-01
#  -9.600e-02 -1.000e-03 -4.940e-01 -6.000e-02 -4.000e-03 -1.000e-03
#  -0.000e+00 -1.360e-01 -3.400e-01 -1.170e-01 -7.500e-02 -2.330e-01
#  -1.600e-02 -8.300e-02 -8.000e-03 -7.460e-01 -3.930e-01 -5.000e-03
#  -8.500e-02 -7.757e+00 -1.415e+00 -1.267e+00 -1.232e+00 -9.380e-01]
# ============================================================
#  EVALUATION: EXPERIMENT-2 Plot groups. Without LOW VARIANCE ROWS. No Grid, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : -0.076
#   RMSE : 23.61 kg
#
# Regular CrossValidation:
#   Mean   : -0.198
#   Std    : 0.227
#   Scores : [-0.206  0.088 -0.163 -0.107 -0.604]
#
#   ❌ Test R² is negative (-0.076)
#   ❌ CV mean is negative (-0.198)
#
# Grouped CrossValidation:
#   Channel Caye_2       :  -0.159  ❌ negative — cause unknown
#   Hicks Caye_3         :  -0.024  ❌ negative — cause unknown
#   Big Creek_6          :  -6.409  ❌ negative — cause unknown
#   Big Creek_3          :  -0.012  ❌ negative — cause unknown
#   Hicks Caye_1         :  -0.000  ❌ negative — cause unknown
#   Big Creek_5          :  -0.002  ❌ negative — cause unknown
#   Gra Gra Lagoon_3     :  -0.634  ❌ negative — cause unknown
#   Drowned Caye_1       :  -0.039  ❌ negative — cause unknown
#   Big Creek_2          :  -0.010  ❌ negative — cause unknown
#   Drowned Caye_5       :  -0.046  ❌ negative — cause unknown
#
#   Mean : -0.655
#   Std  : 1.614
#
#   ❌ Grouped CV mean below 0.15 (-0.655)
#   ⚠️  Grouped CV std above 0.25 (1.614) — high variance across folds
#   ❌ Unexplained negative folds: ['Channel Caye_2', 'Hicks Caye_3', 'Big Creek_6', 'Big Creek_3', 'Hicks Caye_1', 'Big Creek_5', 'Gra Gra Lagoon_3', 'Drowned Caye_1', 'Big Creek_2', 'Drowned Caye_5']
#   ❌ High-AGB sites failed: ['Channel Caye_2', 'Big Creek_6', 'Big Creek_3', 'Big Creek_5', 'Big Creek_2']
#   ⚠️  Grouped CV and test R² diverge (gap: 0.579 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.249 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height_x_EVI                                  0.2738  =============
#   height                                        0.2548  ============
#   height_x_NIR                                  0.2382  ===========
#   height_x_NDRE1                                0.2332  ===========
#
# [3/18]
#
#  RANDOM FOREST: EXPERIMENT-3 Plot groups. Without LOW VARIANCE ROWS. No Grid, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2'].
# Test R²     : -0.0562
# Test RMSE   : 23.38 kg
# Train R² (log scale): 0.2795
# Train R² (orig scale): 0.1721
# Train RMSE  : 16.94 kg
# Num rows    : 2334
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: -0.2447
# CV R² std : 0.3326
# CV scores : [-0.023  0.106 -0.123 -0.341 -0.842]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.9781
# Grouped CV R² std : 3.4877
# Grouped CV scores : [-1.4700e-01 -6.7000e-02 -2.0800e-01 -4.2000e-02 -0.0000e+00 -0.0000e+00
#  -5.8370e+00 -7.3000e-02 -2.8000e-02 -1.0420e+00 -2.7100e-01 -4.5000e-02
#  -3.7000e-02 -0.0000e+00 -8.7000e-02 -1.0000e-03 -1.6000e-02 -2.8000e-01
#  -0.0000e+00 -1.3000e-02 -4.9000e-02 -1.4000e-02 -3.0000e-02 -9.6000e-02
#  -2.8000e-02 -3.9000e-02 -8.1000e-02 -6.8400e-01 -2.0000e-03 -0.0000e+00
#  -1.0600e-01 -2.0622e+01 -1.1420e+00 -2.4400e-01 -8.7500e-01 -3.0050e+00]
# ============================================================
#  EVALUATION: EXPERIMENT-3 Plot groups. Without LOW VARIANCE ROWS. No Grid, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2'].
# ============================================================
#
# Test set:
#   R²   : -0.056
#   RMSE : 23.38 kg
#
# Regular CrossValidation:
#   Mean   : -0.245
#   Std    : 0.333
#   Scores : [-0.023  0.106 -0.123 -0.341 -0.842]
#
#   ❌ Test R² is negative (-0.056)
#   ❌ CV mean is negative (-0.245)
#
# Grouped CrossValidation:
#   Channel Caye_2       :  -0.147  ❌ negative — cause unknown
#   Hicks Caye_3         :  -0.067  ❌ negative — cause unknown
#   Big Creek_6          :  -0.208  ❌ negative — cause unknown
#   Big Creek_3          :  -0.042  ❌ negative — cause unknown
#   Hicks Caye_1         :  -0.000  ❌ negative — cause unknown
#   Big Creek_5          :  -0.000  ❌ negative — cause unknown
#   Gra Gra Lagoon_3     :  -5.837  ❌ negative — cause unknown
#   Drowned Caye_1       :  -0.073  ❌ negative — cause unknown
#   Big Creek_2          :  -0.028  ❌ negative — cause unknown
#   Drowned Caye_5       :  -1.042  ❌ negative — cause unknown
#
#   Mean : -0.978
#   Std  : 3.488
#
#   ❌ Grouped CV mean below 0.15 (-0.978)
#   ⚠️  Grouped CV std above 0.25 (3.488) — high variance across folds
#   ❌ Unexplained negative folds: ['Channel Caye_2', 'Hicks Caye_3', 'Big Creek_6', 'Big Creek_3', 'Hicks Caye_1', 'Big Creek_5', 'Gra Gra Lagoon_3', 'Drowned Caye_1', 'Big Creek_2', 'Drowned Caye_5']
#   ❌ High-AGB sites failed: ['Channel Caye_2', 'Big Creek_6', 'Big Creek_3', 'Big Creek_5', 'Big Creek_2']
#   ⚠️  Grouped CV and test R² diverge (gap: 0.922 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.228 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   Green                                         0.1718  ========
#   RE1                                           0.1633  ========
#   RE2                                           0.1433  =======
#   NIR                                           0.1329  ======
#   Red                                           0.1107  =====
#   RE3                                           0.1070  =====
#   SWIR2                                         0.0772  ===
#   SWIR1                                         0.0495  ==
#   Blue                                          0.0442  ==
#
# [4/18]
#
#  RANDOM FOREST: EXPERIMENT-4 Plot groups. Without LOW VARIANCE ROWS. No Grid, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : -0.0703
# Test RMSE   : 23.54 kg
# Train R² (log scale): 0.2795
# Train R² (orig scale): 0.1721
# Train RMSE  : 16.94 kg
# Num rows    : 2334
# Num Features: 12
#
#  Cross-validation ---
# CV R² mean: -0.1628
# CV R² std : 0.2127
# CV scores : [-0.048  0.08  -0.114 -0.179 -0.552]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.5349
# Grouped CV R² std : 1.9510
# Grouped CV scores : [-1.5400e-01 -4.8000e-02 -1.1310e+00 -4.9000e-02 -0.0000e+00 -0.0000e+00
#  -1.7950e+00 -6.4000e-02 -3.1000e-02 -4.2200e-01 -3.7900e-01 -7.0000e-02
#  -5.5000e-02 -0.0000e+00 -2.1300e-01 -0.0000e+00 -5.0000e-03 -1.8100e-01
#  -1.0000e-03 -6.2000e-02 -9.2000e-02 -1.3000e-02 -4.1000e-02 -1.0100e-01
#  -4.5000e-02 -7.1000e-02 -6.4000e-02 -6.8500e-01 -1.5400e-01 -0.0000e+00
#  -3.0000e-03 -1.1843e+01 -1.2520e+00 -1.0500e-01 -1.5000e-02 -1.0800e-01]
# ============================================================
#  EVALUATION: EXPERIMENT-4 Plot groups. Without LOW VARIANCE ROWS. No Grid, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : -0.070
#   RMSE : 23.54 kg
#
# Regular CrossValidation:
#   Mean   : -0.163
#   Std    : 0.213
#   Scores : [-0.048  0.08  -0.114 -0.179 -0.552]
#
#   ❌ Test R² is negative (-0.070)
#   ❌ CV mean is negative (-0.163)
#
# Grouped CrossValidation:
#   Channel Caye_2       :  -0.154  ❌ negative — cause unknown
#   Hicks Caye_3         :  -0.048  ❌ negative — cause unknown
#   Big Creek_6          :  -1.131  ❌ negative — cause unknown
#   Big Creek_3          :  -0.049  ❌ negative — cause unknown
#   Hicks Caye_1         :  -0.000  ❌ negative — cause unknown
#   Big Creek_5          :  -0.000  ❌ negative — cause unknown
#   Gra Gra Lagoon_3     :  -1.795  ❌ negative — cause unknown
#   Drowned Caye_1       :  -0.064  ❌ negative — cause unknown
#   Big Creek_2          :  -0.031  ❌ negative — cause unknown
#   Drowned Caye_5       :  -0.422  ❌ negative — cause unknown
#
#   Mean : -0.535
#   Std  : 1.951
#
#   ❌ Grouped CV mean below 0.15 (-0.535)
#   ⚠️  Grouped CV std above 0.25 (1.951) — high variance across folds
#   ❌ Unexplained negative folds: ['Channel Caye_2', 'Hicks Caye_3', 'Big Creek_6', 'Big Creek_3', 'Hicks Caye_1', 'Big Creek_5', 'Gra Gra Lagoon_3', 'Drowned Caye_1', 'Big Creek_2', 'Drowned Caye_5']
#   ❌ High-AGB sites failed: ['Channel Caye_2', 'Big Creek_6', 'Big Creek_3', 'Big Creek_5', 'Big Creek_2']
#   ⚠️  Grouped CV and test R² diverge (gap: 0.465 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.242 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height_x_EVI                                  0.1927  =========
#   height_x_NIR                                  0.1918  =========
#   height_x_NDRE1                                0.1878  =========
#   RE3                                           0.0662  ===
#   NIR                                           0.0607  ===
#   RE2                                           0.0601  ===
#   Red                                           0.0553  ==
#   Green                                         0.0541  ==
#   RE1                                           0.0474  ==
#   SWIR1                                         0.0289  =
#
# [5/18]
#
#  RANDOM FOREST: EXPERIMENT-5 Plot groups. Without LOW VARIANCE ROWS. No Grid, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# Test R²     : -0.0723
# Test RMSE   : 23.56 kg
# Train R² (log scale): 0.2795
# Train R² (orig scale): 0.1721
# Train RMSE  : 16.94 kg
# Num rows    : 2334
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: -0.1607
# CV R² std : 0.1979
# CV scores : [-0.023  0.096 -0.161 -0.229 -0.486]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.6794
# Grouped CV R² std : 1.9299
# Grouped CV scores : [-1.2800e-01 -9.5000e-02 -1.6510e+00 -4.4600e-01 -2.0000e-03 -0.0000e+00
#  -4.1530e+00 -3.5000e-02 -4.2000e-02 -1.0000e-02 -1.9300e-01 -4.8000e-02
#  -9.6000e-02 -4.0000e-03 -4.2000e-02 -2.4000e-02 -4.0000e-02 -0.0000e+00
#  -0.0000e+00 -8.1000e-02 -1.1000e-02 -5.3000e-02 -1.5000e-02 -6.4000e-02
#  -5.7000e-02 -3.7000e-02 -0.0000e+00 -6.1500e-01 -3.5000e-02 -8.0000e-03
#  -1.3950e+00 -1.0963e+01 -1.3890e+00 -1.8200e-01 -2.4360e+00 -1.0600e-01]
# ============================================================
#  EVALUATION: EXPERIMENT-5 Plot groups. Without LOW VARIANCE ROWS. No Grid, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# ============================================================
#
# Test set:
#   R²   : -0.072
#   RMSE : 23.56 kg
#
# Regular CrossValidation:
#   Mean   : -0.161
#   Std    : 0.198
#   Scores : [-0.023  0.096 -0.161 -0.229 -0.486]
#
#   ❌ Test R² is negative (-0.072)
#   ❌ CV mean is negative (-0.161)
#
# Grouped CrossValidation:
#   Channel Caye_2       :  -0.128  ❌ negative — cause unknown
#   Hicks Caye_3         :  -0.095  ❌ negative — cause unknown
#   Big Creek_6          :  -1.651  ❌ negative — cause unknown
#   Big Creek_3          :  -0.446  ❌ negative — cause unknown
#   Hicks Caye_1         :  -0.002  ❌ negative — cause unknown
#   Big Creek_5          :  -0.000  ❌ negative — cause unknown
#   Gra Gra Lagoon_3     :  -4.153  ❌ negative — cause unknown
#   Drowned Caye_1       :  -0.035  ❌ negative — cause unknown
#   Big Creek_2          :  -0.042  ❌ negative — cause unknown
#   Drowned Caye_5       :  -0.010  ❌ negative — cause unknown
#
#   Mean : -0.679
#   Std  : 1.930
#
#   ❌ Grouped CV mean below 0.15 (-0.679)
#   ⚠️  Grouped CV std above 0.25 (1.930) — high variance across folds
#   ❌ Unexplained negative folds: ['Channel Caye_2', 'Hicks Caye_3', 'Big Creek_6', 'Big Creek_3', 'Hicks Caye_1', 'Big Creek_5', 'Gra Gra Lagoon_3', 'Drowned Caye_1', 'Big Creek_2', 'Drowned Caye_5']
#   ❌ High-AGB sites failed: ['Channel Caye_2', 'Big Creek_6', 'Big Creek_3', 'Big Creek_5', 'Big Creek_2']
#   ⚠️  Grouped CV and test R² diverge (gap: 0.607 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.244 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   NDRE1                                         0.2526  ============
#   CIrededge                                     0.2167  ==========
#   NBR                                           0.1744  ========
#   EVI                                           0.1080  =====
#   NDVI                                          0.0972  ====
#   NDRE2                                         0.0789  ===
#   NDRE3                                         0.0489  ==
#   MNDWI                                         0.0231  =
#   CLOUD_COVERAGE                                0.0000
#
# [6/18]
#
#  RANDOM FOREST: EXPERIMENT-6 Plot groups. Without LOW VARIANCE ROWS. No Grid, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : -0.0728
# Test RMSE   : 23.57 kg
# Train R² (log scale): 0.2795
# Train R² (orig scale): 0.1721
# Train RMSE  : 16.94 kg
# Num rows    : 2334
# Num Features: 12
#
#  Cross-validation ---
# CV R² mean: -0.1432
# CV R² std : 0.1829
# CV scores : [-0.033  0.091 -0.168 -0.148 -0.459]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.5368
# Grouped CV R² std : 1.6741
# Grouped CV scores : [-1.470e-01 -5.300e-02 -2.106e+00 -1.500e-01 -0.000e+00 -0.000e+00
#  -2.434e+00 -3.300e-02 -4.000e-02 -4.400e-02 -2.700e-01 -5.000e-02
#  -9.600e-02 -3.000e-03 -1.840e-01 -2.800e-02 -1.800e-02 -4.000e-03
#  -0.000e+00 -1.000e-01 -1.200e-02 -0.000e+00 -2.200e-02 -6.300e-02
#  -7.200e-02 -1.800e-02 -4.300e-02 -5.950e-01 -1.950e-01 -5.000e-03
#  -3.370e-01 -9.892e+00 -1.342e+00 -2.790e-01 -6.880e-01 -1.000e-03]
# ============================================================
#  EVALUATION: EXPERIMENT-6 Plot groups. Without LOW VARIANCE ROWS. No Grid, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : -0.073
#   RMSE : 23.57 kg
#
# Regular CrossValidation:
#   Mean   : -0.143
#   Std    : 0.183
#   Scores : [-0.033  0.091 -0.168 -0.148 -0.459]
#
#   ❌ Test R² is negative (-0.073)
#   ❌ CV mean is negative (-0.143)
#
# Grouped CrossValidation:
#   Channel Caye_2       :  -0.147  ❌ negative — cause unknown
#   Hicks Caye_3         :  -0.053  ❌ negative — cause unknown
#   Big Creek_6          :  -2.106  ❌ negative — cause unknown
#   Big Creek_3          :  -0.150  ❌ negative — cause unknown
#   Hicks Caye_1         :  -0.000  ❌ negative — cause unknown
#   Big Creek_5          :  -0.000  ❌ negative — cause unknown
#   Gra Gra Lagoon_3     :  -2.434  ❌ negative — cause unknown
#   Drowned Caye_1       :  -0.033  ❌ negative — cause unknown
#   Big Creek_2          :  -0.040  ❌ negative — cause unknown
#   Drowned Caye_5       :  -0.044  ❌ negative — cause unknown
#
#   Mean : -0.537
#   Std  : 1.674
#
#   ❌ Grouped CV mean below 0.15 (-0.537)
#   ⚠️  Grouped CV std above 0.25 (1.674) — high variance across folds
#   ❌ Unexplained negative folds: ['Channel Caye_2', 'Hicks Caye_3', 'Big Creek_6', 'Big Creek_3', 'Hicks Caye_1', 'Big Creek_5', 'Gra Gra Lagoon_3', 'Drowned Caye_1', 'Big Creek_2', 'Drowned Caye_5']
#   ❌ High-AGB sites failed: ['Channel Caye_2', 'Big Creek_6', 'Big Creek_3', 'Big Creek_5', 'Big Creek_2']
#   ⚠️  Grouped CV and test R² diverge (gap: 0.464 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.245 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height_x_NIR                                  0.1645  ========
#   height_x_NDRE1                                0.1618  ========
#   height_x_EVI                                  0.1616  ========
#   CIrededge                                     0.1160  =====
#   NDRE1                                         0.1061  =====
#   NBR                                           0.0811  ====
#   EVI                                           0.0590  ==
#   NDVI                                          0.0572  ==
#   NDRE2                                         0.0435  ==
#   NDRE3                                         0.0320  =
#
# [7/18]
#
#  RANDOM FOREST: EXPERIMENT-7 Plot groups. Without LOW VARIANCE ROWS. No Grid, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# Test R²     : -0.0687
# Test RMSE   : 23.52 kg
# Train R² (log scale): 0.2795
# Train R² (orig scale): 0.1721
# Train RMSE  : 16.94 kg
# Num rows    : 2334
# Num Features: 18
#
#  Cross-validation ---
# CV R² mean: -0.1758
# CV R² std : 0.2288
# CV scores : [-0.021  0.1   -0.12  -0.279 -0.56 ]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.7166
# Grouped CV R² std : 2.4545
# Grouped CV scores : [-1.4300e-01 -9.5000e-02 -6.2100e-01 -2.1300e-01 -0.0000e+00 -0.0000e+00
#  -4.3940e+00 -5.6000e-02 -2.8000e-02 -1.5000e-01 -2.4700e-01 -5.5000e-02
#  -6.5000e-02 -1.0000e-03 -4.2000e-02 -3.0000e-03 -0.0000e+00 -7.7000e-02
#  -0.0000e+00 -4.5000e-02 -2.5000e-02 -0.0000e+00 -2.4000e-02 -6.9000e-02
#  -4.6000e-02 -0.0000e+00 -1.0000e-03 -6.3800e-01 -4.0000e-03 -1.0000e-03
#  -1.1660e+00 -1.4491e+01 -1.3350e+00 -1.1800e-01 -1.3600e+00 -2.8500e-01]
# ============================================================
#  EVALUATION: EXPERIMENT-7 Plot groups. Without LOW VARIANCE ROWS. No Grid, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# ============================================================
#
# Test set:
#   R²   : -0.069
#   RMSE : 23.52 kg
#
# Regular CrossValidation:
#   Mean   : -0.176
#   Std    : 0.229
#   Scores : [-0.021  0.1   -0.12  -0.279 -0.56 ]
#
#   ❌ Test R² is negative (-0.069)
#   ❌ CV mean is negative (-0.176)
#
# Grouped CrossValidation:
#   Channel Caye_2       :  -0.143  ❌ negative — cause unknown
#   Hicks Caye_3         :  -0.095  ❌ negative — cause unknown
#   Big Creek_6          :  -0.621  ❌ negative — cause unknown
#   Big Creek_3          :  -0.213  ❌ negative — cause unknown
#   Hicks Caye_1         :  -0.000  ❌ negative — cause unknown
#   Big Creek_5          :  -0.000  ❌ negative — cause unknown
#   Gra Gra Lagoon_3     :  -4.394  ❌ negative — cause unknown
#   Drowned Caye_1       :  -0.056  ❌ negative — cause unknown
#   Big Creek_2          :  -0.028  ❌ negative — cause unknown
#   Drowned Caye_5       :  -0.150  ❌ negative — cause unknown
#
#   Mean : -0.717
#   Std  : 2.454
#
#   ❌ Grouped CV mean below 0.15 (-0.717)
#   ⚠️  Grouped CV std above 0.25 (2.454) — high variance across folds
#   ❌ Unexplained negative folds: ['Channel Caye_2', 'Hicks Caye_3', 'Big Creek_6', 'Big Creek_3', 'Hicks Caye_1', 'Big Creek_5', 'Gra Gra Lagoon_3', 'Drowned Caye_1', 'Big Creek_2', 'Drowned Caye_5']
#   ❌ High-AGB sites failed: ['Channel Caye_2', 'Big Creek_6', 'Big Creek_3', 'Big Creek_5', 'Big Creek_2']
#   ⚠️  Grouped CV and test R² diverge (gap: 0.648 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.241 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   NDRE1                                         0.1680  ========
#   CIrededge                                     0.1666  ========
#   NBR                                           0.1365  ======
#   EVI                                           0.0701  ===
#   NDVI                                          0.0649  ===
#   NDRE2                                         0.0576  ==
#   Red                                           0.0547  ==
#   Green                                         0.0445  ==
#   NIR                                           0.0386  =
#   RE2                                           0.0323  =
#
# [8/18]
#
#  RANDOM FOREST: EXPERIMENT-8 Plot groups. Without LOW VARIANCE ROWS. No Grid, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : -0.0712
# Test RMSE   : 23.55 kg
# Train R² (log scale): 0.2795
# Train R² (orig scale): 0.1721
# Train RMSE  : 16.94 kg
# Num rows    : 2334
# Num Features: 21
#
#  Cross-validation ---
# CV R² mean: -0.1490
# CV R² std : 0.1930
# CV scores : [-0.042  0.086 -0.111 -0.189 -0.49 ]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.5369
# Grouped CV R² std : 1.8892
# Grouped CV scores : [-1.4700e-01 -5.5000e-02 -1.2360e+00 -1.2100e-01 -0.0000e+00 -1.0000e-03
#  -2.2160e+00 -5.3000e-02 -3.3000e-02 -1.7700e-01 -2.7900e-01 -5.2000e-02
#  -7.4000e-02 -2.0000e-03 -1.7700e-01 -3.0000e-03 -0.0000e+00 -6.4000e-02
#  -0.0000e+00 -7.4000e-02 -2.1000e-02 -5.0000e-03 -3.2000e-02 -6.6000e-02
#  -6.6000e-02 -1.0000e-03 -2.9000e-02 -6.4600e-01 -1.0600e-01 -0.0000e+00
#  -2.2500e-01 -1.1385e+01 -1.3740e+00 -5.8000e-02 -4.7700e-01 -7.5000e-02]
# ============================================================
#  EVALUATION: EXPERIMENT-8 Plot groups. Without LOW VARIANCE ROWS. No Grid, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : -0.071
#   RMSE : 23.55 kg
#
# Regular CrossValidation:
#   Mean   : -0.149
#   Std    : 0.193
#   Scores : [-0.042  0.086 -0.111 -0.189 -0.49 ]
#
#   ❌ Test R² is negative (-0.071)
#   ❌ CV mean is negative (-0.149)
#
# Grouped CrossValidation:
#   Channel Caye_2       :  -0.147  ❌ negative — cause unknown
#   Hicks Caye_3         :  -0.055  ❌ negative — cause unknown
#   Big Creek_6          :  -1.236  ❌ negative — cause unknown
#   Big Creek_3          :  -0.121  ❌ negative — cause unknown
#   Hicks Caye_1         :  -0.000  ❌ negative — cause unknown
#   Big Creek_5          :  -0.001  ❌ negative — cause unknown
#   Gra Gra Lagoon_3     :  -2.216  ❌ negative — cause unknown
#   Drowned Caye_1       :  -0.053  ❌ negative — cause unknown
#   Big Creek_2          :  -0.033  ❌ negative — cause unknown
#   Drowned Caye_5       :  -0.177  ❌ negative — cause unknown
#
#   Mean : -0.537
#   Std  : 1.889
#
#   ❌ Grouped CV mean below 0.15 (-0.537)
#   ⚠️  Grouped CV std above 0.25 (1.889) — high variance across folds
#   ❌ Unexplained negative folds: ['Channel Caye_2', 'Hicks Caye_3', 'Big Creek_6', 'Big Creek_3', 'Hicks Caye_1', 'Big Creek_5', 'Gra Gra Lagoon_3', 'Drowned Caye_1', 'Big Creek_2', 'Drowned Caye_5']
#   ❌ High-AGB sites failed: ['Channel Caye_2', 'Big Creek_6', 'Big Creek_3', 'Big Creek_5', 'Big Creek_2']
#   ⚠️  Grouped CV and test R² diverge (gap: 0.466 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.243 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height_x_EVI                                  0.1320  ======
#   height_x_NDRE1                                0.1272  ======
#   height_x_NIR                                  0.1190  =====
#   NDRE1                                         0.0943  ====
#   CIrededge                                     0.0823  ====
#   EVI                                           0.0640  ===
#   NBR                                           0.0587  ==
#   NDRE2                                         0.0430  ==
#   Red                                           0.0342  =
#   NDVI                                          0.0338  =
#
# [9/18]
#
#  RANDOM FOREST: EXPERIMENT-9 Plot groups. Without LOW VARIANCE ROWS. No Grid, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# Test R²     : -0.0683
# Test RMSE   : 23.52 kg
# Train R² (log scale): 0.2795
# Train R² (orig scale): 0.1721
# Train RMSE  : 16.94 kg
# Num rows    : 2334
# Num Features: 19
#
#  Cross-validation ---
# CV R² mean: -0.1619
# CV R² std : 0.2155
# CV scores : [-0.056  0.107 -0.099 -0.225 -0.537]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.6615
# Grouped CV R² std : 2.3092
# Grouped CV scores : [-1.4500e-01 -8.0000e-02 -6.1400e-01 -2.1600e-01 -0.0000e+00 -0.0000e+00
#  -3.4670e+00 -5.6000e-02 -3.2000e-02 -1.5800e-01 -2.7100e-01 -4.7000e-02
#  -7.0000e-02 -2.0000e-03 -1.3300e-01 -1.0000e-03 -1.0000e-03 -7.8000e-02
#  -0.0000e+00 -6.7000e-02 -1.6000e-02 -0.0000e+00 -2.7000e-02 -6.7000e-02
#  -3.8000e-02 -4.0000e-03 -1.1000e-02 -6.2700e-01 -8.0000e-03 -0.0000e+00
#  -7.1900e-01 -1.3798e+01 -1.3390e+00 -6.6000e-02 -1.4010e+00 -2.5500e-01]
# ============================================================
#  EVALUATION: EXPERIMENT-9 Plot groups. Without LOW VARIANCE ROWS. No Grid, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# ============================================================
#
# Test set:
#   R²   : -0.068
#   RMSE : 23.52 kg
#
# Regular CrossValidation:
#   Mean   : -0.162
#   Std    : 0.216
#   Scores : [-0.056  0.107 -0.099 -0.225 -0.537]
#
#   ❌ Test R² is negative (-0.068)
#   ❌ CV mean is negative (-0.162)
#
# Grouped CrossValidation:
#   Channel Caye_2       :  -0.145  ❌ negative — cause unknown
#   Hicks Caye_3         :  -0.080  ❌ negative — cause unknown
#   Big Creek_6          :  -0.614  ❌ negative — cause unknown
#   Big Creek_3          :  -0.216  ❌ negative — cause unknown
#   Hicks Caye_1         :  -0.000  ❌ negative — cause unknown
#   Big Creek_5          :  -0.000  ❌ negative — cause unknown
#   Gra Gra Lagoon_3     :  -3.467  ❌ negative — cause unknown
#   Drowned Caye_1       :  -0.056  ❌ negative — cause unknown
#   Big Creek_2          :  -0.032  ❌ negative — cause unknown
#   Drowned Caye_5       :  -0.158  ❌ negative — cause unknown
#
#   Mean : -0.661
#   Std  : 2.309
#
#   ❌ Grouped CV mean below 0.15 (-0.661)
#   ⚠️  Grouped CV std above 0.25 (2.309) — high variance across folds
#   ❌ Unexplained negative folds: ['Channel Caye_2', 'Hicks Caye_3', 'Big Creek_6', 'Big Creek_3', 'Hicks Caye_1', 'Big Creek_5', 'Gra Gra Lagoon_3', 'Drowned Caye_1', 'Big Creek_2', 'Drowned Caye_5']
#   ❌ High-AGB sites failed: ['Channel Caye_2', 'Big Creek_6', 'Big Creek_3', 'Big Creek_5', 'Big Creek_2']
#   ⚠️  Grouped CV and test R² diverge (gap: 0.593 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.240 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height                                        0.1807  =========
#   NDRE1                                         0.1375  ======
#   CIrededge                                     0.1177  =====
#   NBR                                           0.0994  ====
#   EVI                                           0.0595  ==
#   NDVI                                          0.0546  ==
#   NDRE2                                         0.0539  ==
#   Red                                           0.0459  ==
#   RE3                                           0.0375  =
#   NIR                                           0.0330  =
#
# [10/18]
#
#  RANDOM FOREST: EXPERIMENT-10 Plot groups. Without LOW VARIANCE ROWS. No Grid, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : -0.0714
# Test RMSE   : 23.55 kg
# Train R² (log scale): 0.2795
# Train R² (orig scale): 0.1721
# Train RMSE  : 16.94 kg
# Num rows    : 2334
# Num Features: 22
#
#  Cross-validation ---
# CV R² mean: -0.1473
# CV R² std : 0.1956
# CV scores : [-0.049  0.098 -0.122 -0.169 -0.495]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.5392
# Grouped CV R² std : 1.9155
# Grouped CV scores : [-1.5300e-01 -5.3000e-02 -1.1040e+00 -1.1400e-01 -0.0000e+00 -0.0000e+00
#  -2.1720e+00 -5.3000e-02 -3.0000e-02 -1.6500e-01 -3.0600e-01 -5.6000e-02
#  -6.9000e-02 -2.0000e-03 -2.1800e-01 -3.0000e-03 -0.0000e+00 -5.5000e-02
#  -0.0000e+00 -7.8000e-02 -2.3000e-02 -3.0000e-03 -3.1000e-02 -6.9000e-02
#  -5.9000e-02 -0.0000e+00 -2.3000e-02 -6.3600e-01 -1.2800e-01 -0.0000e+00
#  -1.7800e-01 -1.1571e+01 -1.3260e+00 -1.0600e-01 -5.0600e-01 -1.2200e-01]
# ============================================================
#  EVALUATION: EXPERIMENT-10 Plot groups. Without LOW VARIANCE ROWS. No Grid, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : -0.071
#   RMSE : 23.55 kg
#
# Regular CrossValidation:
#   Mean   : -0.147
#   Std    : 0.196
#   Scores : [-0.049  0.098 -0.122 -0.169 -0.495]
#
#   ❌ Test R² is negative (-0.071)
#   ❌ CV mean is negative (-0.147)
#
# Grouped CrossValidation:
#   Channel Caye_2       :  -0.153  ❌ negative — cause unknown
#   Hicks Caye_3         :  -0.053  ❌ negative — cause unknown
#   Big Creek_6          :  -1.104  ❌ negative — cause unknown
#   Big Creek_3          :  -0.114  ❌ negative — cause unknown
#   Hicks Caye_1         :  -0.000  ❌ negative — cause unknown
#   Big Creek_5          :  -0.000  ❌ negative — cause unknown
#   Gra Gra Lagoon_3     :  -2.172  ❌ negative — cause unknown
#   Drowned Caye_1       :  -0.053  ❌ negative — cause unknown
#   Big Creek_2          :  -0.030  ❌ negative — cause unknown
#   Drowned Caye_5       :  -0.165  ❌ negative — cause unknown
#
#   Mean : -0.539
#   Std  : 1.915
#
#   ❌ Grouped CV mean below 0.15 (-0.539)
#   ⚠️  Grouped CV std above 0.25 (1.915) — high variance across folds
#   ❌ Unexplained negative folds: ['Channel Caye_2', 'Hicks Caye_3', 'Big Creek_6', 'Big Creek_3', 'Hicks Caye_1', 'Big Creek_5', 'Gra Gra Lagoon_3', 'Drowned Caye_1', 'Big Creek_2', 'Drowned Caye_5']
#   ❌ High-AGB sites failed: ['Channel Caye_2', 'Big Creek_6', 'Big Creek_3', 'Big Creek_5', 'Big Creek_2']
#   ⚠️  Grouped CV and test R² diverge (gap: 0.468 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.243 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height_x_NIR                                  0.1184  =====
#   height_x_NDRE1                                0.1170  =====
#   height_x_EVI                                  0.1117  =====
#   height                                        0.1001  =====
#   CIrededge                                     0.0843  ====
#   NDRE1                                         0.0814  ====
#   NBR                                           0.0538  ==
#   EVI                                           0.0412  ==
#   NDRE2                                         0.0387  =
#   NDVI                                          0.0377  =
#
# [11/18]
#
#  RANDOM FOREST: EXPERIMENT-11 Plot groups. Without LOW VARIANCE ROWS. No Grid, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1'].
# Test R²     : -0.0676
# Test RMSE   : 23.51 kg
# Train R² (log scale): 0.2795
# Train R² (orig scale): 0.1721
# Train RMSE  : 16.94 kg
# Num rows    : 2334
# Num Features: 5
#
#  Cross-validation ---
# CV R² mean: -0.1732
# CV R² std : 0.2430
# CV scores : [-0.045  0.115 -0.174 -0.146 -0.615]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.1305
# Grouped CV R² std : 4.1265
# Grouped CV scores : [-1.5500e-01 -4.7000e-02 -4.4000e-01 -8.0000e-02 -0.0000e+00 -6.0000e-03
#  -4.5880e+00 -6.5000e-02 -4.9000e-02 -4.0000e-03 -3.0100e-01 -8.4000e-02
#  -8.9000e-02 -3.0000e-03 -1.3400e-01 -0.0000e+00 -7.0000e-03 -9.0000e-02
#  -1.0000e-03 -7.9000e-02 -1.2000e-02 -3.0000e-03 -2.4000e-02 -1.1600e-01
#  -3.8000e-02 -2.9000e-02 -5.2000e-02 -6.5000e-01 -4.2000e-02 -0.0000e+00
#  -2.8470e+00 -2.4689e+01 -1.0000e+00 -3.2700e-01 -4.2720e+00 -3.7400e-01]
# ============================================================
#  EVALUATION: EXPERIMENT-11 Plot groups. Without LOW VARIANCE ROWS. No Grid, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1'].
# ============================================================
#
# Test set:
#   R²   : -0.068
#   RMSE : 23.51 kg
#
# Regular CrossValidation:
#   Mean   : -0.173
#   Std    : 0.243
#   Scores : [-0.045  0.115 -0.174 -0.146 -0.615]
#
#   ❌ Test R² is negative (-0.068)
#   ❌ CV mean is negative (-0.173)
#
# Grouped CrossValidation:
#   Channel Caye_2       :  -0.155  ❌ negative — cause unknown
#   Hicks Caye_3         :  -0.047  ❌ negative — cause unknown
#   Big Creek_6          :  -0.440  ❌ negative — cause unknown
#   Big Creek_3          :  -0.080  ❌ negative — cause unknown
#   Hicks Caye_1         :  -0.000  ❌ negative — cause unknown
#   Big Creek_5          :  -0.006  ❌ negative — cause unknown
#   Gra Gra Lagoon_3     :  -4.588  ❌ negative — cause unknown
#   Drowned Caye_1       :  -0.065  ❌ negative — cause unknown
#   Big Creek_2          :  -0.049  ❌ negative — cause unknown
#   Drowned Caye_5       :  -0.004  ❌ negative — cause unknown
#
#   Mean : -1.130
#   Std  : 4.127
#
#   ❌ Grouped CV mean below 0.15 (-1.130)
#   ⚠️  Grouped CV std above 0.25 (4.127) — high variance across folds
#   ❌ Unexplained negative folds: ['Channel Caye_2', 'Hicks Caye_3', 'Big Creek_6', 'Big Creek_3', 'Hicks Caye_1', 'Big Creek_5', 'Gra Gra Lagoon_3', 'Drowned Caye_1', 'Big Creek_2', 'Drowned Caye_5']
#   ❌ High-AGB sites failed: ['Channel Caye_2', 'Big Creek_6', 'Big Creek_3', 'Big Creek_5', 'Big Creek_2']
#   ⚠️  Grouped CV and test R² diverge (gap: 1.063 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.240 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height                                        0.3803  ===================
#   NBR                                           0.2782  =============
#   EVI                                           0.1660  ========
#   NIR                                           0.0965  ====
#   SWIR1                                         0.0791  ===
#
# [12/18]
#
#  RANDOM FOREST: EXPERIMENT-12 Plot groups. Without LOW VARIANCE ROWS. No Grid, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : -0.0732
# Test RMSE   : 23.57 kg
# Train R² (log scale): 0.2795
# Train R² (orig scale): 0.1721
# Train RMSE  : 16.94 kg
# Num rows    : 2334
# Num Features: 8
#
#  Cross-validation ---
# CV R² mean: -0.1356
# CV R² std : 0.1815
# CV scores : [-0.075  0.103 -0.168 -0.084 -0.453]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.6074
# Grouped CV R² std : 2.2823
# Grouped CV scores : [-1.5900e-01 -4.2000e-02 -2.4950e+00 -5.4000e-02 -0.0000e+00 -1.0000e-03
#  -1.3110e+00 -4.8000e-02 -3.4000e-02 -1.6000e-02 -4.0600e-01 -1.0000e-01
#  -9.3000e-02 -4.0000e-03 -2.2900e-01 -3.8000e-02 -4.0000e-03 -3.2000e-02
#  -0.0000e+00 -9.4000e-02 -5.5000e-02 -5.0000e-03 -3.0000e-02 -1.2200e-01
#  -3.6000e-02 -0.0000e+00 -5.2000e-02 -6.9600e-01 -2.8000e-01 -0.0000e+00
#  -2.4900e-01 -1.3798e+01 -1.2410e+00 -1.2400e-01 -7.0000e-03 -1.0000e-02]
# ============================================================
#  EVALUATION: EXPERIMENT-12 Plot groups. Without LOW VARIANCE ROWS. No Grid, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : -0.073
#   RMSE : 23.57 kg
#
# Regular CrossValidation:
#   Mean   : -0.136
#   Std    : 0.182
#   Scores : [-0.075  0.103 -0.168 -0.084 -0.453]
#
#   ❌ Test R² is negative (-0.073)
#   ❌ CV mean is negative (-0.136)
#
# Grouped CrossValidation:
#   Channel Caye_2       :  -0.159  ❌ negative — cause unknown
#   Hicks Caye_3         :  -0.042  ❌ negative — cause unknown
#   Big Creek_6          :  -2.495  ❌ negative — cause unknown
#   Big Creek_3          :  -0.054  ❌ negative — cause unknown
#   Hicks Caye_1         :  -0.000  ❌ negative — cause unknown
#   Big Creek_5          :  -0.001  ❌ negative — cause unknown
#   Gra Gra Lagoon_3     :  -1.311  ❌ negative — cause unknown
#   Drowned Caye_1       :  -0.048  ❌ negative — cause unknown
#   Big Creek_2          :  -0.034  ❌ negative — cause unknown
#   Drowned Caye_5       :  -0.016  ❌ negative — cause unknown
#
#   Mean : -0.607
#   Std  : 2.282
#
#   ❌ Grouped CV mean below 0.15 (-0.607)
#   ⚠️  Grouped CV std above 0.25 (2.282) — high variance across folds
#   ❌ Unexplained negative folds: ['Channel Caye_2', 'Hicks Caye_3', 'Big Creek_6', 'Big Creek_3', 'Hicks Caye_1', 'Big Creek_5', 'Gra Gra Lagoon_3', 'Drowned Caye_1', 'Big Creek_2', 'Drowned Caye_5']
#   ❌ High-AGB sites failed: ['Channel Caye_2', 'Big Creek_6', 'Big Creek_3', 'Big Creek_5', 'Big Creek_2']
#   ⚠️  Grouped CV and test R² diverge (gap: 0.534 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.245 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height_x_EVI                                  0.2009  ==========
#   height_x_NDRE1                                0.1789  ========
#   height                                        0.1651  ========
#   height_x_NIR                                  0.1621  ========
#   NBR                                           0.1120  =====
#   EVI                                           0.0871  ====
#   NIR                                           0.0526  ==
#   SWIR1                                         0.0413  ==
#
# [13/18]
#
#  RANDOM FOREST: EXPERIMENT-13 Plot groups. Without LOW VARIANCE ROWS. No Grid, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1'].
# Test R²     : -0.0410
# Test RMSE   : 23.21 kg
# Train R² (log scale): 0.3547
# Train R² (orig scale): 0.1879
# Train RMSE  : 16.78 kg
# Num rows    : 2334
# Num Features: 8
#
#  Cross-validation ---
# CV R² mean: -0.3659
# CV R² std : 0.5092
# CV scores : [-1.305  0.078  0.055 -0.192 -0.465]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.2219
# Grouped CV R² std : 5.1020
# Grouped CV scores : [-2.000e-01 -5.800e-02 -2.670e-01 -9.000e-02  1.570e-01 -4.000e-02
#  -3.621e+00  1.830e-01  7.100e-02 -8.000e-03 -2.950e-01  2.970e-01
#  -7.300e-02  3.000e-03 -2.100e-02 -3.200e-02  6.500e-02  7.000e-03
#   1.000e-03 -1.300e-02 -4.000e-03 -4.400e-02  2.500e-01  2.090e-01
#  -8.000e-03 -7.400e-02 -1.800e-02 -3.330e-01  4.900e-02 -2.020e-01
#  -4.044e+00 -3.081e+01 -7.280e-01 -7.440e-01 -3.207e+00 -3.460e-01]
# ============================================================
#  EVALUATION: EXPERIMENT-13 Plot groups. Without LOW VARIANCE ROWS. No Grid, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1'].
# ============================================================
#
# Test set:
#   R²   : -0.041
#   RMSE : 23.21 kg
#
# Regular CrossValidation:
#   Mean   : -0.366
#   Std    : 0.509
#   Scores : [-1.305  0.078  0.055 -0.192 -0.465]
#
#   ❌ Test R² is negative (-0.041)
#   ❌ CV mean is negative (-0.366)
#
# Grouped CrossValidation:
#   Channel Caye_2       :  -0.200  ❌ negative — cause unknown
#   Hicks Caye_3         :  -0.058  ❌ negative — cause unknown
#   Big Creek_6          :  -0.267  ❌ negative — cause unknown
#   Big Creek_3          :  -0.090  ❌ negative — cause unknown
#   Hicks Caye_1         :   0.157  ✅
#   Big Creek_5          :  -0.040  ❌ negative — cause unknown
#   Gra Gra Lagoon_3     :  -3.621  ❌ negative — cause unknown
#   Drowned Caye_1       :   0.183  ✅
#   Big Creek_2          :   0.071  ✅
#   Drowned Caye_5       :  -0.008  ❌ negative — cause unknown
#
#   Mean : -1.222
#   Std  : 5.102
#
#   ❌ Grouped CV mean below 0.15 (-1.222)
#   ⚠️  Grouped CV std above 0.25 (5.102) — high variance across folds
#   ❌ Unexplained negative folds: ['Channel Caye_2', 'Hicks Caye_3', 'Big Creek_6', 'Big Creek_3', 'Big Creek_5', 'Gra Gra Lagoon_3', 'Drowned Caye_5']
#   ❌ High-AGB sites failed: ['Channel Caye_2', 'Big Creek_6', 'Big Creek_3', 'Big Creek_5']
#   ⚠️  Grouped CV and test R² diverge (gap: 1.181 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.229 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height                                        0.2512  ============
#   NBR                                           0.2125  ==========
#   EVI                                           0.1646  ========
#   NIR                                           0.1434  =======
#   SWIR1                                         0.1010  =====
#   species_Avicennia germinans                   0.0575  ==
#   species_Rhizophora mangle                     0.0509  ==
#   species_Laguncularia racemosa                 0.0190
#
# [14/18]
#
#  RANDOM FOREST: EXPERIMENT-14 Plot groups. Without LOW VARIANCE ROWS. No Grid, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : -0.0537
# Test RMSE   : 23.36 kg
# Train R² (log scale): 0.3547
# Train R² (orig scale): 0.1891
# Train RMSE  : 16.77 kg
# Num rows    : 2334
# Num Features: 11
#
#  Cross-validation ---
# CV R² mean: -0.3585
# CV R² std : 0.5114
# CV scores : [-1.334  0.058 -0.03  -0.088 -0.399]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.5111
# Grouped CV R² std : 2.2161
# Grouped CV scores : [-2.0400e-01 -1.2200e-01 -1.7630e+00 -1.0800e-01  1.4100e-01 -1.2000e-02
#  -7.5300e-01  1.9200e-01  8.6000e-02  2.0000e-03 -3.5600e-01  3.1100e-01
#  -8.4000e-02  1.0000e-03 -1.5700e-01 -5.0000e-02  3.0000e-02  1.0000e-03
#   3.0000e-03 -1.5000e-02 -1.4000e-02 -9.7000e-02  2.6400e-01  2.0100e-01
#  -6.1000e-02 -6.6000e-02  2.6000e-02 -3.0100e-01 -1.2700e-01 -2.1400e-01
#  -1.6300e-01 -1.3424e+01 -1.2630e+00 -1.0300e-01 -1.8300e-01 -1.8000e-02]
# ============================================================
#  EVALUATION: EXPERIMENT-14 Plot groups. Without LOW VARIANCE ROWS. No Grid, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : -0.054
#   RMSE : 23.36 kg
#
# Regular CrossValidation:
#   Mean   : -0.358
#   Std    : 0.511
#   Scores : [-1.334  0.058 -0.03  -0.088 -0.399]
#
#   ❌ Test R² is negative (-0.054)
#   ❌ CV mean is negative (-0.358)
#
# Grouped CrossValidation:
#   Channel Caye_2       :  -0.204  ❌ negative — cause unknown
#   Hicks Caye_3         :  -0.122  ❌ negative — cause unknown
#   Big Creek_6          :  -1.763  ❌ negative — cause unknown
#   Big Creek_3          :  -0.108  ❌ negative — cause unknown
#   Hicks Caye_1         :   0.141  ✅
#   Big Creek_5          :  -0.012  ❌ negative — cause unknown
#   Gra Gra Lagoon_3     :  -0.753  ❌ negative — cause unknown
#   Drowned Caye_1       :   0.192  ✅
#   Big Creek_2          :   0.086  ✅
#   Drowned Caye_5       :   0.002  ✅
#
#   Mean : -0.511
#   Std  : 2.216
#
#   ❌ Grouped CV mean below 0.15 (-0.511)
#   ⚠️  Grouped CV std above 0.25 (2.216) — high variance across folds
#   ❌ Unexplained negative folds: ['Channel Caye_2', 'Hicks Caye_3', 'Big Creek_6', 'Big Creek_3', 'Big Creek_5', 'Gra Gra Lagoon_3']
#   ❌ High-AGB sites failed: ['Channel Caye_2', 'Big Creek_6', 'Big Creek_3', 'Big Creek_5']
#   ⚠️  Grouped CV and test R² diverge (gap: 0.457 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.243 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height_x_NDRE1                                0.1711  ========
#   height_x_EVI                                  0.1500  =======
#   height_x_NIR                                  0.1398  ======
#   height                                        0.1298  ======
#   EVI                                           0.0870  ====
#   NBR                                           0.0846  ====
#   species_Avicennia germinans                   0.0604  ===
#   NIR                                           0.0579  ==
#   species_Rhizophora mangle                     0.0548  ==
#   SWIR1                                         0.0444  ==
#
# [15/18]
#
#  RANDOM FOREST: EXPERIMENT-15 Plot groups. Without LOW VARIANCE ROWS. No Grid, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2'].
# Test R²     : -0.0664
# Test RMSE   : 23.50 kg
# Train R² (log scale): 0.2795
# Train R² (orig scale): 0.1721
# Train RMSE  : 16.94 kg
# Num rows    : 2334
# Num Features: 7
#
#  Cross-validation ---
# CV R² mean: -0.1573
# CV R² std : 0.2365
# CV scores : [-0.037  0.108 -0.068 -0.201 -0.588]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.9196
# Grouped CV R² std : 3.3847
# Grouped CV scores : [-1.5800e-01 -4.8000e-02 -2.9700e-01 -1.3200e-01 -0.0000e+00 -7.0000e-03
#  -3.6240e+00 -5.9000e-02 -5.2000e-02 -2.3100e-01 -2.5700e-01 -9.7000e-02
#  -8.8000e-02 -3.0000e-03 -1.7300e-01 -7.0000e-03 -4.0000e-03 -1.3200e-01
#  -0.0000e+00 -6.9000e-02 -2.7000e-02 -2.0000e-02 -1.7000e-02 -1.1100e-01
#  -4.0000e-03 -2.0000e-03 -8.2000e-02 -6.6100e-01 -3.1000e-02 -4.0000e-03
#  -2.2290e+00 -2.0435e+01 -1.2020e+00 -1.2000e-01 -2.1460e+00 -5.7800e-01]
# ============================================================
#  EVALUATION: EXPERIMENT-15 Plot groups. Without LOW VARIANCE ROWS. No Grid, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2'].
# ============================================================
#
# Test set:
#   R²   : -0.066
#   RMSE : 23.50 kg
#
# Regular CrossValidation:
#   Mean   : -0.157
#   Std    : 0.237
#   Scores : [-0.037  0.108 -0.068 -0.201 -0.588]
#
#   ❌ Test R² is negative (-0.066)
#   ❌ CV mean is negative (-0.157)
#
# Grouped CrossValidation:
#   Channel Caye_2       :  -0.158  ❌ negative — cause unknown
#   Hicks Caye_3         :  -0.048  ❌ negative — cause unknown
#   Big Creek_6          :  -0.297  ❌ negative — cause unknown
#   Big Creek_3          :  -0.132  ❌ negative — cause unknown
#   Hicks Caye_1         :  -0.000  ❌ negative — cause unknown
#   Big Creek_5          :  -0.007  ❌ negative — cause unknown
#   Gra Gra Lagoon_3     :  -3.624  ❌ negative — cause unknown
#   Drowned Caye_1       :  -0.059  ❌ negative — cause unknown
#   Big Creek_2          :  -0.052  ❌ negative — cause unknown
#   Drowned Caye_5       :  -0.231  ❌ negative — cause unknown
#
#   Mean : -0.920
#   Std  : 3.385
#
#   ❌ Grouped CV mean below 0.15 (-0.920)
#   ⚠️  Grouped CV std above 0.25 (3.385) — high variance across folds
#   ❌ Unexplained negative folds: ['Channel Caye_2', 'Hicks Caye_3', 'Big Creek_6', 'Big Creek_3', 'Hicks Caye_1', 'Big Creek_5', 'Gra Gra Lagoon_3', 'Drowned Caye_1', 'Big Creek_2', 'Drowned Caye_5']
#   ❌ High-AGB sites failed: ['Channel Caye_2', 'Big Creek_6', 'Big Creek_3', 'Big Creek_5', 'Big Creek_2']
#   ⚠️  Grouped CV and test R² diverge (gap: 0.853 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.238 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height                                        0.3082  ===============
#   NBR                                           0.2036  ==========
#   EVI                                           0.1445  =======
#   RE1                                           0.1106  =====
#   RE2                                           0.0902  ====
#   NIR                                           0.0804  ====
#   SWIR1                                         0.0626  ===
#
# [16/18]
#
#  RANDOM FOREST: EXPERIMENT-16 Plot groups. Without LOW VARIANCE ROWS. No Grid, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : -0.0711
# Test RMSE   : 23.55 kg
# Train R² (log scale): 0.2795
# Train R² (orig scale): 0.1721
# Train RMSE  : 16.94 kg
# Num rows    : 2334
# Num Features: 10
#
#  Cross-validation ---
# CV R² mean: -0.1153
# CV R² std : 0.1680
# CV scores : [-0.084  0.102 -0.079 -0.098 -0.418]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.5304
# Grouped CV R² std : 1.8902
# Grouped CV scores : [-1.5900e-01 -4.5000e-02 -2.0040e+00 -9.3000e-02 -0.0000e+00 -3.0000e-03
#  -1.1630e+00 -5.5000e-02 -4.3000e-02 -5.5000e-02 -3.7300e-01 -1.0600e-01
#  -9.5000e-02 -3.0000e-03 -3.2100e-01 -1.0000e-03 -8.0000e-03 -1.3800e-01
#  -0.0000e+00 -1.0000e-01 -5.4000e-02 -3.1000e-02 -3.5000e-02 -1.2600e-01
#  -3.1000e-02 -0.0000e+00 -8.0000e-02 -6.8100e-01 -2.7400e-01 -1.0000e-03
#  -2.0200e-01 -1.1444e+01 -1.2070e+00 -7.0000e-02 -2.7000e-02 -6.9000e-02]
# ============================================================
#  EVALUATION: EXPERIMENT-16 Plot groups. Without LOW VARIANCE ROWS. No Grid, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : -0.071
#   RMSE : 23.55 kg
#
# Regular CrossValidation:
#   Mean   : -0.115
#   Std    : 0.168
#   Scores : [-0.084  0.102 -0.079 -0.098 -0.418]
#
#   ❌ Test R² is negative (-0.071)
#   ❌ CV mean is negative (-0.115)
#
# Grouped CrossValidation:
#   Channel Caye_2       :  -0.159  ❌ negative — cause unknown
#   Hicks Caye_3         :  -0.045  ❌ negative — cause unknown
#   Big Creek_6          :  -2.004  ❌ negative — cause unknown
#   Big Creek_3          :  -0.093  ❌ negative — cause unknown
#   Hicks Caye_1         :  -0.000  ❌ negative — cause unknown
#   Big Creek_5          :  -0.003  ❌ negative — cause unknown
#   Gra Gra Lagoon_3     :  -1.163  ❌ negative — cause unknown
#   Drowned Caye_1       :  -0.055  ❌ negative — cause unknown
#   Big Creek_2          :  -0.043  ❌ negative — cause unknown
#   Drowned Caye_5       :  -0.055  ❌ negative — cause unknown
#
#   Mean : -0.530
#   Std  : 1.890
#
#   ❌ Grouped CV mean below 0.15 (-0.530)
#   ⚠️  Grouped CV std above 0.25 (1.890) — high variance across folds
#   ❌ Unexplained negative folds: ['Channel Caye_2', 'Hicks Caye_3', 'Big Creek_6', 'Big Creek_3', 'Hicks Caye_1', 'Big Creek_5', 'Gra Gra Lagoon_3', 'Drowned Caye_1', 'Big Creek_2', 'Drowned Caye_5']
#   ❌ High-AGB sites failed: ['Channel Caye_2', 'Big Creek_6', 'Big Creek_3', 'Big Creek_5', 'Big Creek_2']
#   ⚠️  Grouped CV and test R² diverge (gap: 0.459 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.243 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height                                        0.1860  =========
#   height_x_NDRE1                                0.1812  =========
#   height_x_NIR                                  0.1806  =========
#   height_x_EVI                                  0.1571  =======
#   NBR                                           0.0869  ====
#   EVI                                           0.0693  ===
#   NIR                                           0.0435  ==
#   RE1                                           0.0395  =
#   SWIR1                                         0.0313  =
#   RE2                                           0.0245  =
#
# [17/18]
#
#  RANDOM FOREST: EXPERIMENT-17 Plot groups. Without LOW VARIANCE ROWS. No Grid, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2'].
# Test R²     : -0.0349
# Test RMSE   : 23.15 kg
# Train R² (log scale): 0.3547
# Train R² (orig scale): 0.1889
# Train RMSE  : 16.77 kg
# Num rows    : 2334
# Num Features: 10
#
#  Cross-validation ---
# CV R² mean: -0.3848
# CV R² std : 0.5084
# CV scores : [-1.32   0.038  0.057 -0.207 -0.493]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.8850
# Grouped CV R² std : 3.5783
# Grouped CV scores : [-1.9100e-01 -9.6000e-02 -1.6700e-01 -2.9800e-01  1.5600e-01 -4.6000e-02
#  -2.4650e+00  1.8400e-01  4.6000e-02 -7.5000e-02 -2.4000e-01  3.0100e-01
#  -7.5000e-02  4.0000e-03 -2.6100e-01 -1.6000e-02  7.8000e-02 -4.6000e-02
#  -4.0000e-03  1.9000e-02 -2.0000e-03 -7.5000e-02  2.6000e-01  2.3500e-01
#  -4.0000e-03 -6.3000e-02 -6.4000e-02 -3.3300e-01  3.9000e-02 -1.4300e-01
#  -2.4520e+00 -2.1636e+01 -1.1850e+00 -1.0900e-01 -2.5340e+00 -6.0100e-01]
# ============================================================
#  EVALUATION: EXPERIMENT-17 Plot groups. Without LOW VARIANCE ROWS. No Grid, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2'].
# ============================================================
#
# Test set:
#   R²   : -0.035
#   RMSE : 23.15 kg
#
# Regular CrossValidation:
#   Mean   : -0.385
#   Std    : 0.508
#   Scores : [-1.32   0.038  0.057 -0.207 -0.493]
#
#   ❌ Test R² is negative (-0.035)
#   ❌ CV mean is negative (-0.385)
#
# Grouped CrossValidation:
#   Channel Caye_2       :  -0.191  ❌ negative — cause unknown
#   Hicks Caye_3         :  -0.096  ❌ negative — cause unknown
#   Big Creek_6          :  -0.167  ❌ negative — cause unknown
#   Big Creek_3          :  -0.298  ❌ negative — cause unknown
#   Hicks Caye_1         :   0.156  ✅
#   Big Creek_5          :  -0.046  ❌ negative — cause unknown
#   Gra Gra Lagoon_3     :  -2.465  ❌ negative — cause unknown
#   Drowned Caye_1       :   0.184  ✅
#   Big Creek_2          :   0.046  ✅
#   Drowned Caye_5       :  -0.075  ❌ negative — cause unknown
#
#   Mean : -0.885
#   Std  : 3.578
#
#   ❌ Grouped CV mean below 0.15 (-0.885)
#   ⚠️  Grouped CV std above 0.25 (3.578) — high variance across folds
#   ❌ Unexplained negative folds: ['Channel Caye_2', 'Hicks Caye_3', 'Big Creek_6', 'Big Creek_3', 'Big Creek_5', 'Gra Gra Lagoon_3', 'Drowned Caye_5']
#   ❌ High-AGB sites failed: ['Channel Caye_2', 'Big Creek_6', 'Big Creek_3', 'Big Creek_5']
#   ⚠️  Grouped CV and test R² diverge (gap: 0.850 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.224 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height                                        0.2397  ===========
#   NBR                                           0.1625  ========
#   EVI                                           0.1244  ======
#   RE1                                           0.1052  =====
#   NIR                                           0.0844  ====
#   RE2                                           0.0815  ====
#   SWIR1                                         0.0662  ===
#   species_Rhizophora mangle                     0.0585  ==
#   species_Avicennia germinans                   0.0584  ==
#   species_Laguncularia racemosa                 0.0191
#
# [18/18]
#
#  RANDOM FOREST: EXPERIMENT-18 Plot groups. Without LOW VARIANCE ROWS. No Grid, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : -0.0474
# Test RMSE   : 23.29 kg
# Train R² (log scale): 0.3547
# Train R² (orig scale): 0.1890
# Train RMSE  : 16.77 kg
# Num rows    : 2334
# Num Features: 13
#
#  Cross-validation ---
# CV R² mean: -0.3583
# CV R² std : 0.5034
# CV scores : [-1.318  0.047 -0.007 -0.12  -0.394]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.5088
# Grouped CV R² std : 2.2440
# Grouped CV scores : [-2.0200e-01 -1.1400e-01 -1.0480e+00 -2.1800e-01  1.2900e-01 -1.6000e-02
#  -9.7400e-01  1.8900e-01  6.2000e-02 -1.5000e-02 -3.1300e-01  3.0500e-01
#  -8.1000e-02  3.0000e-03 -2.2800e-01 -1.9000e-02  3.0000e-02 -3.5000e-02
#   1.0000e-03  1.0000e-03 -8.0000e-03 -7.4000e-02  2.5300e-01  1.9500e-01
#  -4.3000e-02 -5.6000e-02 -1.7000e-02 -3.2700e-01 -9.0000e-02 -1.6400e-01
#  -9.4000e-02 -1.3643e+01 -1.2910e+00 -1.2400e-01 -2.4300e-01 -4.8000e-02]
# ============================================================
#  EVALUATION: EXPERIMENT-18 Plot groups. Without LOW VARIANCE ROWS. No Grid, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : -0.047
#   RMSE : 23.29 kg
#
# Regular CrossValidation:
#   Mean   : -0.358
#   Std    : 0.503
#   Scores : [-1.318  0.047 -0.007 -0.12  -0.394]
#
#   ❌ Test R² is negative (-0.047)
#   ❌ CV mean is negative (-0.358)
#
# Grouped CrossValidation:
#   Channel Caye_2       :  -0.202  ❌ negative — cause unknown
#   Hicks Caye_3         :  -0.114  ❌ negative — cause unknown
#   Big Creek_6          :  -1.048  ❌ negative — cause unknown
#   Big Creek_3          :  -0.218  ❌ negative — cause unknown
#   Hicks Caye_1         :   0.129  ✅
#   Big Creek_5          :  -0.016  ❌ negative — cause unknown
#   Gra Gra Lagoon_3     :  -0.974  ❌ negative — cause unknown
#   Drowned Caye_1       :   0.189  ✅
#   Big Creek_2          :   0.062  ✅
#   Drowned Caye_5       :  -0.015  ❌ negative — cause unknown
#
#   Mean : -0.509
#   Std  : 2.244
#
#   ❌ Grouped CV mean below 0.15 (-0.509)
#   ⚠️  Grouped CV std above 0.25 (2.244) — high variance across folds
#   ❌ Unexplained negative folds: ['Channel Caye_2', 'Hicks Caye_3', 'Big Creek_6', 'Big Creek_3', 'Big Creek_5', 'Gra Gra Lagoon_3', 'Drowned Caye_5']
#   ❌ High-AGB sites failed: ['Channel Caye_2', 'Big Creek_6', 'Big Creek_3', 'Big Creek_5']
#   ⚠️  Grouped CV and test R² diverge (gap: 0.461 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.236 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height                                        0.1423  =======
#   height_x_EVI                                  0.1404  =======
#   height_x_NIR                                  0.1291  ======
#   height_x_NDRE1                                0.1223  ======
#   NBR                                           0.0820  ====
#   EVI                                           0.0706  ===
#   species_Avicennia germinans                   0.0619  ===
#   species_Rhizophora mangle                     0.0565  ==
#   NIR                                           0.0490  ==
#   RE1                                           0.0463  ==
#
# Completed: 18/18 experiments

# %%
# %run Model_functions.ipynb
tabulate_results(rf_belige_subset_no_grid_groups, acceptable_only=True)
# Out:
# Showing 0 acceptable experiments
# No acceptable experiments found.

# %% [markdown]
# ### BELIGE WITHOUT LOW VARIANCE ROWS. PLOT GROUPS. RANDOM FOREST. With Grid

# %%
# %run Model_functions.ipynb

rf_belige_subset_grid_groups = {}

run_experiment(X_belige_sub, y_belige_sub,
               is_groups=True, group_info=grp_belige_sub,
               features_list=gen_features_list,
               experiments=rf_belige_subset_grid_groups,
               model_type="rf",
               is_grid=True,
               is_stratified=is_stratified_g,
               global_experiment_list=global_experiment_list)
# Out:
# [1/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'n_estimators': 100, 'min_samples_leaf': 8, 'max_samples': 0.6, 'max_features': 0.3, 'max_depth': 5}
#
#  RANDOM FOREST: EXPERIMENT-1 Plot groups. Without LOW VARIANCE ROWS. With Grid, Features: ['height'].
# Test R²     : -0.0587
# Test RMSE   : 23.41 kg
# Train R² (log scale): 0.2678
# Train R² (orig scale): 0.1040
# Train RMSE  : 17.63 kg
# Num rows    : 2334
# Num Features: 1
#
#  Cross-validation ---
# CV R² mean: -0.0596
# CV R² std : 0.1762
# CV scores : [-0.233  0.128  0.045  0.07  -0.309]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.7431
# Grouped CV R² std : 2.0354
# Grouped CV scores : [-1.620e-01 -5.600e-02 -3.310e-01 -1.800e-02 -3.000e-03 -3.500e-02
#  -1.508e+00 -1.900e-02 -1.400e-02 -2.900e-02 -6.130e-01 -6.300e-02
#  -9.400e-02 -0.000e+00 -7.410e-01 -5.000e-03 -1.500e-02 -3.000e-03
#  -2.000e-03 -7.200e-02 -5.170e-01 -2.470e-01 -5.000e-02 -1.280e-01
#  -9.840e-01 -9.400e-02 -2.000e-03 -7.260e-01 -2.690e-01 -2.000e-03
#  -2.040e-01 -9.453e+00 -1.122e+00 -1.800e-01 -8.534e+00 -4.560e-01]
# ============================================================
#  EVALUATION: EXPERIMENT-1 Plot groups. Without LOW VARIANCE ROWS. With Grid, Features: ['height'].
# ============================================================
#
# Test set:
#   R²   : -0.059
#   RMSE : 23.41 kg
#
# Regular CrossValidation:
#   Mean   : -0.060
#   Std    : 0.176
#   Scores : [-0.233  0.128  0.045  0.07  -0.309]
#
#   ❌ Test R² is negative (-0.059)
#   ❌ CV mean is negative (-0.060)
#
# Grouped CrossValidation:
#   Channel Caye_2       :  -0.162  ❌ negative — cause unknown
#   Hicks Caye_3         :  -0.056  ❌ negative — cause unknown
#   Big Creek_6          :  -0.331  ❌ negative — cause unknown
#   Big Creek_3          :  -0.018  ❌ negative — cause unknown
#   Hicks Caye_1         :  -0.003  ❌ negative — cause unknown
#   Big Creek_5          :  -0.035  ❌ negative — cause unknown
#   Gra Gra Lagoon_3     :  -1.508  ❌ negative — cause unknown
#   Drowned Caye_1       :  -0.019  ❌ negative — cause unknown
#   Big Creek_2          :  -0.014  ❌ negative — cause unknown
#   Drowned Caye_5       :  -0.029  ❌ negative — cause unknown
#
#   Mean : -0.743
#   Std  : 2.035
#
#   ❌ Grouped CV mean below 0.15 (-0.743)
#   ⚠️  Grouped CV std above 0.25 (2.035) — high variance across folds
#   ❌ Unexplained negative folds: ['Channel Caye_2', 'Hicks Caye_3', 'Big Creek_6', 'Big Creek_3', 'Hicks Caye_1', 'Big Creek_5', 'Gra Gra Lagoon_3', 'Drowned Caye_1', 'Big Creek_2', 'Drowned Caye_5']
#   ❌ High-AGB sites failed: ['Channel Caye_2', 'Big Creek_6', 'Big Creek_3', 'Big Creek_5', 'Big Creek_2']
#   ⚠️  Grouped CV and test R² diverge (gap: 0.684 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.163 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height                                        1.0000  ==================================================
#
# [2/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'n_estimators': 200, 'min_samples_leaf': 8, 'max_samples': 0.6, 'max_features': 'sqrt', 'max_depth': 5}
#
#  RANDOM FOREST: EXPERIMENT-2 Plot groups. Without LOW VARIANCE ROWS. With Grid, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : -0.0761
# Test RMSE   : 23.60 kg
# Train R² (log scale): 0.2708
# Train R² (orig scale): 0.1075
# Train RMSE  : 17.59 kg
# Num rows    : 2334
# Num Features: 4
#
#  Cross-validation ---
# CV R² mean: -0.0562
# CV R² std : 0.1290
# CV scores : [-0.185  0.081 -0.054  0.093 -0.217]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.6297
# Grouped CV R² std : 1.7815
# Grouped CV scores : [-1.450e-01 -3.500e-02 -5.616e+00 -4.400e-02 -1.000e-03 -2.000e-03
#  -6.360e-01 -3.100e-02 -1.800e-02 -6.400e-02 -6.110e-01 -8.300e-02
#  -9.500e-02 -1.000e-03 -4.590e-01 -7.200e-02 -1.000e-03 -2.000e-03
#  -0.000e+00 -1.150e-01 -2.710e-01 -6.900e-02 -4.300e-02 -1.560e-01
#  -3.000e-03 -8.900e-02 -1.800e-02 -7.500e-01 -4.380e-01 -1.000e-03
#  -6.900e-02 -9.537e+00 -1.045e+00 -3.220e-01 -1.704e+00 -1.250e-01]
# ============================================================
#  EVALUATION: EXPERIMENT-2 Plot groups. Without LOW VARIANCE ROWS. With Grid, Features: ['height', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : -0.076
#   RMSE : 23.60 kg
#
# Regular CrossValidation:
#   Mean   : -0.056
#   Std    : 0.129
#   Scores : [-0.185  0.081 -0.054  0.093 -0.217]
#
#   ❌ Test R² is negative (-0.076)
#   ❌ CV mean is negative (-0.056)
#
# Grouped CrossValidation:
#   Channel Caye_2       :  -0.145  ❌ negative — cause unknown
#   Hicks Caye_3         :  -0.035  ❌ negative — cause unknown
#   Big Creek_6          :  -5.616  ❌ negative — cause unknown
#   Big Creek_3          :  -0.044  ❌ negative — cause unknown
#   Hicks Caye_1         :  -0.001  ❌ negative — cause unknown
#   Big Creek_5          :  -0.002  ❌ negative — cause unknown
#   Gra Gra Lagoon_3     :  -0.636  ❌ negative — cause unknown
#   Drowned Caye_1       :  -0.031  ❌ negative — cause unknown
#   Big Creek_2          :  -0.018  ❌ negative — cause unknown
#   Drowned Caye_5       :  -0.064  ❌ negative — cause unknown
#
#   Mean : -0.630
#   Std  : 1.782
#
#   ❌ Grouped CV mean below 0.15 (-0.630)
#   ⚠️  Grouped CV std above 0.25 (1.782) — high variance across folds
#   ❌ Unexplained negative folds: ['Channel Caye_2', 'Hicks Caye_3', 'Big Creek_6', 'Big Creek_3', 'Hicks Caye_1', 'Big Creek_5', 'Gra Gra Lagoon_3', 'Drowned Caye_1', 'Big Creek_2', 'Drowned Caye_5']
#   ❌ High-AGB sites failed: ['Channel Caye_2', 'Big Creek_6', 'Big Creek_3', 'Big Creek_5', 'Big Creek_2']
#   ⚠️  Grouped CV and test R² diverge (gap: 0.554 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.184 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height                                        0.2965  ==============
#   height_x_NDRE1                                0.2776  =============
#   height_x_EVI                                  0.2503  ============
#   height_x_NIR                                  0.1756  ========
#
# [3/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'n_estimators': 200, 'min_samples_leaf': 8, 'max_samples': 0.8, 'max_features': 'sqrt', 'max_depth': 5}
#
#  RANDOM FOREST: EXPERIMENT-3 Plot groups. Without LOW VARIANCE ROWS. With Grid, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2'].
# Test R²     : -0.0577
# Test RMSE   : 23.40 kg
# Train R² (log scale): 0.2675
# Train R² (orig scale): 0.1172
# Train RMSE  : 17.50 kg
# Num rows    : 2334
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: -0.1896
# CV R² std : 0.2494
# CV scores : [-0.043  0.117 -0.102 -0.315 -0.605]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.0355
# Grouped CV R² std : 3.4622
# Grouped CV scores : [-7.600e-02 -5.600e-02 -2.910e-01 -9.800e-02 -0.000e+00 -0.000e+00
#  -6.245e+00 -4.400e-02 -3.400e-02 -1.335e+00 -2.650e-01 -8.800e-02
#  -3.900e-02 -1.000e-03 -8.700e-02 -4.000e-03 -8.000e-03 -2.800e-01
#  -0.000e+00 -4.800e-02 -6.800e-02 -1.500e-02 -7.000e-03 -1.100e-01
#  -2.500e-02 -2.300e-02 -7.900e-02 -6.670e-01 -5.000e-03 -1.000e-03
#  -1.070e-01 -2.024e+01 -1.066e+00 -2.930e-01 -1.742e+00 -3.830e+00]
# ============================================================
#  EVALUATION: EXPERIMENT-3 Plot groups. Without LOW VARIANCE ROWS. With Grid, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2'].
# ============================================================
#
# Test set:
#   R²   : -0.058
#   RMSE : 23.40 kg
#
# Regular CrossValidation:
#   Mean   : -0.190
#   Std    : 0.249
#   Scores : [-0.043  0.117 -0.102 -0.315 -0.605]
#
#   ❌ Test R² is negative (-0.058)
#   ❌ CV mean is negative (-0.190)
#
# Grouped CrossValidation:
#   Channel Caye_2       :  -0.076  ❌ negative — cause unknown
#   Hicks Caye_3         :  -0.056  ❌ negative — cause unknown
#   Big Creek_6          :  -0.291  ❌ negative — cause unknown
#   Big Creek_3          :  -0.098  ❌ negative — cause unknown
#   Hicks Caye_1         :  -0.000  ❌ negative — cause unknown
#   Big Creek_5          :  -0.000  ❌ negative — cause unknown
#   Gra Gra Lagoon_3     :  -6.245  ❌ negative — cause unknown
#   Drowned Caye_1       :  -0.044  ❌ negative — cause unknown
#   Big Creek_2          :  -0.034  ❌ negative — cause unknown
#   Drowned Caye_5       :  -1.335  ❌ negative — cause unknown
#
#   Mean : -1.035
#   Std  : 3.462
#
#   ❌ Grouped CV mean below 0.15 (-1.035)
#   ⚠️  Grouped CV std above 0.25 (3.462) — high variance across folds
#   ❌ Unexplained negative folds: ['Channel Caye_2', 'Hicks Caye_3', 'Big Creek_6', 'Big Creek_3', 'Hicks Caye_1', 'Big Creek_5', 'Gra Gra Lagoon_3', 'Drowned Caye_1', 'Big Creek_2', 'Drowned Caye_5']
#   ❌ High-AGB sites failed: ['Channel Caye_2', 'Big Creek_6', 'Big Creek_3', 'Big Creek_5', 'Big Creek_2']
#   ⚠️  Grouped CV and test R² diverge (gap: 0.978 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.175 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   Green                                         0.1623  ========
#   RE1                                           0.1590  =======
#   NIR                                           0.1413  =======
#   RE2                                           0.1318  ======
#   Red                                           0.1149  =====
#   RE3                                           0.1096  =====
#   SWIR2                                         0.0893  ====
#   SWIR1                                         0.0561  ==
#   Blue                                          0.0360  =
#
# [4/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'n_estimators': 100, 'min_samples_leaf': 8, 'max_samples': 0.6, 'max_features': 0.3, 'max_depth': 5}
#
#  RANDOM FOREST: EXPERIMENT-4 Plot groups. Without LOW VARIANCE ROWS. With Grid, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : -0.0700
# Test RMSE   : 23.54 kg
# Train R² (log scale): 0.2728
# Train R² (orig scale): 0.1322
# Train RMSE  : 17.35 kg
# Num rows    : 2334
# Num Features: 12
#
#  Cross-validation ---
# CV R² mean: -0.0807
# CV R² std : 0.1260
# CV scores : [-0.04   0.112 -0.09  -0.106 -0.28 ]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.4947
# Grouped CV R² std : 1.6417
# Grouped CV scores : [-1.310e-01 -3.800e-02 -1.232e+00 -6.700e-02 -1.000e-03 -0.000e+00
#  -2.297e+00 -5.100e-02 -3.100e-02 -3.150e-01 -3.610e-01 -6.100e-02
#  -5.800e-02 -2.000e-03 -2.090e-01 -0.000e+00 -3.000e-03 -2.450e-01
#  -1.000e-03 -7.600e-02 -6.100e-02 -1.600e-02 -1.400e-02 -7.300e-02
#  -6.300e-02 -5.200e-02 -4.400e-02 -6.750e-01 -1.390e-01 -0.000e+00
#  -2.000e-03 -9.839e+00 -1.120e+00 -2.440e-01 -7.100e-02 -2.130e-01]
# ============================================================
#  EVALUATION: EXPERIMENT-4 Plot groups. Without LOW VARIANCE ROWS. With Grid, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : -0.070
#   RMSE : 23.54 kg
#
# Regular CrossValidation:
#   Mean   : -0.081
#   Std    : 0.126
#   Scores : [-0.04   0.112 -0.09  -0.106 -0.28 ]
#
#   ❌ Test R² is negative (-0.070)
#   ❌ CV mean is negative (-0.081)
#
# Grouped CrossValidation:
#   Channel Caye_2       :  -0.131  ❌ negative — cause unknown
#   Hicks Caye_3         :  -0.038  ❌ negative — cause unknown
#   Big Creek_6          :  -1.232  ❌ negative — cause unknown
#   Big Creek_3          :  -0.067  ❌ negative — cause unknown
#   Hicks Caye_1         :  -0.001  ❌ negative — cause unknown
#   Big Creek_5          :  -0.000  ❌ negative — cause unknown
#   Gra Gra Lagoon_3     :  -2.297  ❌ negative — cause unknown
#   Drowned Caye_1       :  -0.051  ❌ negative — cause unknown
#   Big Creek_2          :  -0.031  ❌ negative — cause unknown
#   Drowned Caye_5       :  -0.315  ❌ negative — cause unknown
#
#   Mean : -0.495
#   Std  : 1.642
#
#   ❌ Grouped CV mean below 0.15 (-0.495)
#   ⚠️  Grouped CV std above 0.25 (1.642) — high variance across folds
#   ❌ Unexplained negative folds: ['Channel Caye_2', 'Hicks Caye_3', 'Big Creek_6', 'Big Creek_3', 'Hicks Caye_1', 'Big Creek_5', 'Gra Gra Lagoon_3', 'Drowned Caye_1', 'Big Creek_2', 'Drowned Caye_5']
#   ❌ High-AGB sites failed: ['Channel Caye_2', 'Big Creek_6', 'Big Creek_3', 'Big Creek_5', 'Big Creek_2']
#   ⚠️  Grouped CV and test R² diverge (gap: 0.425 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.202 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height_x_EVI                                  0.2169  ==========
#   height_x_NDRE1                                0.1910  =========
#   height_x_NIR                                  0.1768  ========
#   Green                                         0.0699  ===
#   NIR                                           0.0650  ===
#   RE3                                           0.0637  ===
#   Red                                           0.0451  ==
#   RE2                                           0.0408  ==
#   RE1                                           0.0405  ==
#   SWIR2                                         0.0392  =
#
# [5/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'n_estimators': 100, 'min_samples_leaf': 8, 'max_samples': 0.8, 'max_features': 0.3, 'max_depth': 5}
#
#  RANDOM FOREST: EXPERIMENT-5 Plot groups. Without LOW VARIANCE ROWS. With Grid, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# Test R²     : -0.0700
# Test RMSE   : 23.54 kg
# Train R² (log scale): 0.2717
# Train R² (orig scale): 0.1435
# Train RMSE  : 17.23 kg
# Num rows    : 2334
# Num Features: 9
#
#  Cross-validation ---
# CV R² mean: -0.0933
# CV R² std : 0.1739
# CV scores : [-0.042  0.119 -0.009 -0.132 -0.402]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.9880
# Grouped CV R² std : 3.0507
# Grouped CV scores : [-1.0500e-01 -7.9000e-02 -1.4360e+00 -3.7400e-01 -2.0000e-03 -0.0000e+00
#  -5.0630e+00 -7.0000e-03 -3.9000e-02 -2.2000e-02 -1.5900e-01 -9.0000e-02
#  -6.2000e-02 -2.0000e-03 -1.0200e-01 -3.2000e-02 -5.0000e-03 -5.0000e-03
#  -0.0000e+00 -6.0000e-02 -1.7000e-02 -1.6000e-02 -6.0000e-03 -1.3200e-01
#  -4.8000e-02 -5.0000e-03 -2.0000e-03 -5.9700e-01 -4.3000e-02 -1.0000e-03
#  -1.5310e+00 -1.7103e+01 -1.0030e+00 -4.9800e-01 -6.7650e+00 -1.5600e-01]
# ============================================================
#  EVALUATION: EXPERIMENT-5 Plot groups. Without LOW VARIANCE ROWS. With Grid, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# ============================================================
#
# Test set:
#   R²   : -0.070
#   RMSE : 23.54 kg
#
# Regular CrossValidation:
#   Mean   : -0.093
#   Std    : 0.174
#   Scores : [-0.042  0.119 -0.009 -0.132 -0.402]
#
#   ❌ Test R² is negative (-0.070)
#   ❌ CV mean is negative (-0.093)
#
# Grouped CrossValidation:
#   Channel Caye_2       :  -0.105  ❌ negative — cause unknown
#   Hicks Caye_3         :  -0.079  ❌ negative — cause unknown
#   Big Creek_6          :  -1.436  ❌ negative — cause unknown
#   Big Creek_3          :  -0.374  ❌ negative — cause unknown
#   Hicks Caye_1         :  -0.002  ❌ negative — cause unknown
#   Big Creek_5          :  -0.000  ❌ negative — cause unknown
#   Gra Gra Lagoon_3     :  -5.063  ❌ negative — cause unknown
#   Drowned Caye_1       :  -0.007  ❌ negative — cause unknown
#   Big Creek_2          :  -0.039  ❌ negative — cause unknown
#   Drowned Caye_5       :  -0.022  ❌ negative — cause unknown
#
#   Mean : -0.988
#   Std  : 3.051
#
#   ❌ Grouped CV mean below 0.15 (-0.988)
#   ⚠️  Grouped CV std above 0.25 (3.051) — high variance across folds
#   ❌ Unexplained negative folds: ['Channel Caye_2', 'Hicks Caye_3', 'Big Creek_6', 'Big Creek_3', 'Hicks Caye_1', 'Big Creek_5', 'Gra Gra Lagoon_3', 'Drowned Caye_1', 'Big Creek_2', 'Drowned Caye_5']
#   ❌ High-AGB sites failed: ['Channel Caye_2', 'Big Creek_6', 'Big Creek_3', 'Big Creek_5', 'Big Creek_2']
#   ⚠️  Grouped CV and test R² diverge (gap: 0.918 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.214 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   NBR                                           0.2033  ==========
#   CIrededge                                     0.1961  =========
#   NDRE1                                         0.1854  =========
#   NDVI                                          0.1230  ======
#   NDRE2                                         0.1129  =====
#   EVI                                           0.1101  =====
#   NDRE3                                         0.0424  ==
#   MNDWI                                         0.0268  =
#   CLOUD_COVERAGE                                0.0000
#
# [6/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'n_estimators': 100, 'min_samples_leaf': 8, 'max_samples': 0.6, 'max_features': 0.3, 'max_depth': 5}
#
#  RANDOM FOREST: EXPERIMENT-6 Plot groups. Without LOW VARIANCE ROWS. With Grid, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : -0.0722
# Test RMSE   : 23.56 kg
# Train R² (log scale): 0.2743
# Train R² (orig scale): 0.1319
# Train RMSE  : 17.35 kg
# Num rows    : 2334
# Num Features: 12
#
#  Cross-validation ---
# CV R² mean: -0.0597
# CV R² std : 0.1268
# CV scores : [-0.027  0.115 -0.086 -0.023 -0.276]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.5590
# Grouped CV R² std : 1.5730
# Grouped CV scores : [-1.360e-01 -4.800e-02 -2.866e+00 -2.070e-01 -1.000e-03 -0.000e+00
#  -2.335e+00 -1.400e-02 -3.900e-02 -3.200e-02 -2.590e-01 -4.700e-02
#  -7.900e-02 -3.000e-03 -2.330e-01 -4.000e-02 -8.000e-03 -3.000e-03
#  -0.000e+00 -9.400e-02 -1.700e-02 -1.000e-03 -1.300e-02 -9.900e-02
#  -7.100e-02 -2.000e-03 -4.500e-02 -5.980e-01 -2.440e-01 -1.000e-03
#  -7.000e-02 -8.992e+00 -1.073e+00 -5.090e-01 -1.936e+00 -1.000e-02]
# ============================================================
#  EVALUATION: EXPERIMENT-6 Plot groups. Without LOW VARIANCE ROWS. With Grid, Features: ['NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : -0.072
#   RMSE : 23.56 kg
#
# Regular CrossValidation:
#   Mean   : -0.060
#   Std    : 0.127
#   Scores : [-0.027  0.115 -0.086 -0.023 -0.276]
#
#   ❌ Test R² is negative (-0.072)
#   ❌ CV mean is negative (-0.060)
#
# Grouped CrossValidation:
#   Channel Caye_2       :  -0.136  ❌ negative — cause unknown
#   Hicks Caye_3         :  -0.048  ❌ negative — cause unknown
#   Big Creek_6          :  -2.866  ❌ negative — cause unknown
#   Big Creek_3          :  -0.207  ❌ negative — cause unknown
#   Hicks Caye_1         :  -0.001  ❌ negative — cause unknown
#   Big Creek_5          :  -0.000  ❌ negative — cause unknown
#   Gra Gra Lagoon_3     :  -2.335  ❌ negative — cause unknown
#   Drowned Caye_1       :  -0.014  ❌ negative — cause unknown
#   Big Creek_2          :  -0.039  ❌ negative — cause unknown
#   Drowned Caye_5       :  -0.032  ❌ negative — cause unknown
#
#   Mean : -0.559
#   Std  : 1.573
#
#   ❌ Grouped CV mean below 0.15 (-0.559)
#   ⚠️  Grouped CV std above 0.25 (1.573) — high variance across folds
#   ❌ Unexplained negative folds: ['Channel Caye_2', 'Hicks Caye_3', 'Big Creek_6', 'Big Creek_3', 'Hicks Caye_1', 'Big Creek_5', 'Gra Gra Lagoon_3', 'Drowned Caye_1', 'Big Creek_2', 'Drowned Caye_5']
#   ❌ High-AGB sites failed: ['Channel Caye_2', 'Big Creek_6', 'Big Creek_3', 'Big Creek_5', 'Big Creek_2']
#   ⚠️  Grouped CV and test R² diverge (gap: 0.487 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.204 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height_x_EVI                                  0.2295  ===========
#   height_x_NDRE1                                0.1831  =========
#   height_x_NIR                                  0.1478  =======
#   CIrededge                                     0.0995  ====
#   NDRE1                                         0.0820  ====
#   NBR                                           0.0714  ===
#   EVI                                           0.0481  ==
#   NDVI                                          0.0448  ==
#   NDRE2                                         0.0440  ==
#   NDRE3                                         0.0312  =
#
# [7/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'n_estimators': 100, 'min_samples_leaf': 8, 'max_samples': 0.6, 'max_features': 0.5, 'max_depth': 5}
#
#  RANDOM FOREST: EXPERIMENT-7 Plot groups. Without LOW VARIANCE ROWS. With Grid, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# Test R²     : -0.0663
# Test RMSE   : 23.50 kg
# Train R² (log scale): 0.2755
# Train R² (orig scale): 0.1520
# Train RMSE  : 17.15 kg
# Num rows    : 2334
# Num Features: 18
#
#  Cross-validation ---
# CV R² mean: -0.1303
# CV R² std : 0.1591
# CV scores : [-0.055  0.11  -0.106 -0.253 -0.348]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.6828
# Grouped CV R² std : 1.9008
# Grouped CV scores : [-1.2600e-01 -9.4000e-02 -1.1140e+00 -4.4800e-01 -1.0000e-03 -0.0000e+00
#  -3.8300e+00 -5.4000e-02 -3.2000e-02 -7.2000e-02 -2.0300e-01 -6.3000e-02
#  -5.5000e-02 -3.0000e-03 -8.4000e-02 -0.0000e+00 -6.0000e-03 -1.8400e-01
#  -0.0000e+00 -5.7000e-02 -7.0000e-03 -1.2000e-02 -7.0000e-03 -8.7000e-02
#  -4.9000e-02 -1.8000e-02 -1.0000e-03 -6.0600e-01 -1.0000e-03 -2.0000e-03
#  -8.8200e-01 -1.0521e+01 -1.1350e+00 -5.0900e-01 -4.1480e+00 -1.7100e-01]
# ============================================================
#  EVALUATION: EXPERIMENT-7 Plot groups. Without LOW VARIANCE ROWS. With Grid, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# ============================================================
#
# Test set:
#   R²   : -0.066
#   RMSE : 23.50 kg
#
# Regular CrossValidation:
#   Mean   : -0.130
#   Std    : 0.159
#   Scores : [-0.055  0.11  -0.106 -0.253 -0.348]
#
#   ❌ Test R² is negative (-0.066)
#   ❌ CV mean is negative (-0.130)
#
# Grouped CrossValidation:
#   Channel Caye_2       :  -0.126  ❌ negative — cause unknown
#   Hicks Caye_3         :  -0.094  ❌ negative — cause unknown
#   Big Creek_6          :  -1.114  ❌ negative — cause unknown
#   Big Creek_3          :  -0.448  ❌ negative — cause unknown
#   Hicks Caye_1         :  -0.001  ❌ negative — cause unknown
#   Big Creek_5          :  -0.000  ❌ negative — cause unknown
#   Gra Gra Lagoon_3     :  -3.830  ❌ negative — cause unknown
#   Drowned Caye_1       :  -0.054  ❌ negative — cause unknown
#   Big Creek_2          :  -0.032  ❌ negative — cause unknown
#   Drowned Caye_5       :  -0.072  ❌ negative — cause unknown
#
#   Mean : -0.683
#   Std  : 1.901
#
#   ❌ Grouped CV mean below 0.15 (-0.683)
#   ⚠️  Grouped CV std above 0.25 (1.901) — high variance across folds
#   ❌ Unexplained negative folds: ['Channel Caye_2', 'Hicks Caye_3', 'Big Creek_6', 'Big Creek_3', 'Hicks Caye_1', 'Big Creek_5', 'Gra Gra Lagoon_3', 'Drowned Caye_1', 'Big Creek_2', 'Drowned Caye_5']
#   ❌ High-AGB sites failed: ['Channel Caye_2', 'Big Creek_6', 'Big Creek_3', 'Big Creek_5', 'Big Creek_2']
#   ⚠️  Grouped CV and test R² diverge (gap: 0.617 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.218 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   NDRE1                                         0.2582  ============
#   CIrededge                                     0.2562  ============
#   NBR                                           0.1061  =====
#   EVI                                           0.0658  ===
#   NDVI                                          0.0462  ==
#   Red                                           0.0441  ==
#   NDRE2                                         0.0425  ==
#   SWIR1                                         0.0384  =
#   SWIR2                                         0.0260  =
#   NIR                                           0.0241  =
#
# [8/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'n_estimators': 100, 'min_samples_leaf': 8, 'max_samples': 0.6, 'max_features': 0.5, 'max_depth': 5}
#
#  RANDOM FOREST: EXPERIMENT-8 Plot groups. Without LOW VARIANCE ROWS. With Grid, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : -0.0737
# Test RMSE   : 23.58 kg
# Train R² (log scale): 0.2772
# Train R² (orig scale): 0.1545
# Train RMSE  : 17.12 kg
# Num rows    : 2334
# Num Features: 21
#
#  Cross-validation ---
# CV R² mean: -0.0915
# CV R² std : 0.1374
# CV scores : [-0.014  0.11  -0.12  -0.128 -0.305]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.4514
# Grouped CV R² std : 1.2393
# Grouped CV scores : [-1.370e-01 -4.600e-02 -1.595e+00 -1.120e-01 -0.000e+00 -0.000e+00
#  -2.261e+00 -6.100e-02 -3.600e-02 -1.620e-01 -1.750e-01 -5.600e-02
#  -6.000e-02 -3.000e-03 -2.710e-01 -0.000e+00 -7.000e-03 -1.520e-01
#  -0.000e+00 -9.600e-02 -6.000e-03 -6.800e-02 -1.800e-02 -9.200e-02
#  -9.100e-02 -2.600e-02 -6.200e-02 -5.580e-01 -2.330e-01 -0.000e+00
#  -1.800e-02 -7.230e+00 -1.084e+00 -3.340e-01 -8.170e-01 -3.860e-01]
# ============================================================
#  EVALUATION: EXPERIMENT-8 Plot groups. Without LOW VARIANCE ROWS. With Grid, Features: ['Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : -0.074
#   RMSE : 23.58 kg
#
# Regular CrossValidation:
#   Mean   : -0.091
#   Std    : 0.137
#   Scores : [-0.014  0.11  -0.12  -0.128 -0.305]
#
#   ❌ Test R² is negative (-0.074)
#   ❌ CV mean is negative (-0.091)
#
# Grouped CrossValidation:
#   Channel Caye_2       :  -0.137  ❌ negative — cause unknown
#   Hicks Caye_3         :  -0.046  ❌ negative — cause unknown
#   Big Creek_6          :  -1.595  ❌ negative — cause unknown
#   Big Creek_3          :  -0.112  ❌ negative — cause unknown
#   Hicks Caye_1         :  -0.000  ❌ negative — cause unknown
#   Big Creek_5          :  -0.000  ❌ negative — cause unknown
#   Gra Gra Lagoon_3     :  -2.261  ❌ negative — cause unknown
#   Drowned Caye_1       :  -0.061  ❌ negative — cause unknown
#   Big Creek_2          :  -0.036  ❌ negative — cause unknown
#   Drowned Caye_5       :  -0.162  ❌ negative — cause unknown
#
#   Mean : -0.451
#   Std  : 1.239
#
#   ❌ Grouped CV mean below 0.15 (-0.451)
#   ⚠️  Grouped CV std above 0.25 (1.239) — high variance across folds
#   ❌ Unexplained negative folds: ['Channel Caye_2', 'Hicks Caye_3', 'Big Creek_6', 'Big Creek_3', 'Hicks Caye_1', 'Big Creek_5', 'Gra Gra Lagoon_3', 'Drowned Caye_1', 'Big Creek_2', 'Drowned Caye_5']
#   ❌ High-AGB sites failed: ['Channel Caye_2', 'Big Creek_6', 'Big Creek_3', 'Big Creek_5', 'Big Creek_2']
#   ⚠️  Grouped CV and test R² diverge (gap: 0.378 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.228 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height_x_NDRE1                                0.2569  ============
#   height_x_EVI                                  0.2528  ============
#   height_x_NIR                                  0.1416  =======
#   CIrededge                                     0.0624  ===
#   EVI                                           0.0447  ==
#   NDRE2                                         0.0307  =
#   NBR                                           0.0228  =
#   NDVI                                          0.0227  =
#   NDRE1                                         0.0222  =
#   Green                                         0.0202  =
#
# [9/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'n_estimators': 100, 'min_samples_leaf': 8, 'max_samples': 0.6, 'max_features': 0.5, 'max_depth': 5}
#
#  RANDOM FOREST: EXPERIMENT-9 Plot groups. Without LOW VARIANCE ROWS. With Grid, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# Test R²     : -0.0691
# Test RMSE   : 23.53 kg
# Train R² (log scale): 0.2760
# Train R² (orig scale): 0.1533
# Train RMSE  : 17.13 kg
# Num rows    : 2334
# Num Features: 19
#
#  Cross-validation ---
# CV R² mean: -0.0980
# CV R² std : 0.1390
# CV scores : [-0.052  0.121 -0.096 -0.158 -0.305]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.5817
# Grouped CV R² std : 1.5988
# Grouped CV scores : [-1.330e-01 -1.060e-01 -9.410e-01 -4.090e-01 -0.000e+00 -0.000e+00
#  -3.736e+00 -4.500e-02 -3.500e-02 -1.050e-01 -1.970e-01 -4.700e-02
#  -5.200e-02 -3.000e-03 -2.960e-01 -0.000e+00 -1.500e-02 -1.490e-01
#  -0.000e+00 -6.800e-02 -1.500e-02 -3.000e-03 -1.400e-02 -8.200e-02
#  -4.700e-02 -8.000e-03 -7.000e-03 -6.210e-01 -1.000e-02 -0.000e+00
#  -1.120e-01 -8.880e+00 -1.084e+00 -4.550e-01 -2.861e+00 -4.060e-01]
# ============================================================
#  EVALUATION: EXPERIMENT-9 Plot groups. Without LOW VARIANCE ROWS. With Grid, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE'].
# ============================================================
#
# Test set:
#   R²   : -0.069
#   RMSE : 23.53 kg
#
# Regular CrossValidation:
#   Mean   : -0.098
#   Std    : 0.139
#   Scores : [-0.052  0.121 -0.096 -0.158 -0.305]
#
#   ❌ Test R² is negative (-0.069)
#   ❌ CV mean is negative (-0.098)
#
# Grouped CrossValidation:
#   Channel Caye_2       :  -0.133  ❌ negative — cause unknown
#   Hicks Caye_3         :  -0.106  ❌ negative — cause unknown
#   Big Creek_6          :  -0.941  ❌ negative — cause unknown
#   Big Creek_3          :  -0.409  ❌ negative — cause unknown
#   Hicks Caye_1         :  -0.000  ❌ negative — cause unknown
#   Big Creek_5          :  -0.000  ❌ negative — cause unknown
#   Gra Gra Lagoon_3     :  -3.736  ❌ negative — cause unknown
#   Drowned Caye_1       :  -0.045  ❌ negative — cause unknown
#   Big Creek_2          :  -0.035  ❌ negative — cause unknown
#   Drowned Caye_5       :  -0.105  ❌ negative — cause unknown
#
#   Mean : -0.582
#   Std  : 1.599
#
#   ❌ Grouped CV mean below 0.15 (-0.582)
#   ⚠️  Grouped CV std above 0.25 (1.599) — high variance across folds
#   ❌ Unexplained negative folds: ['Channel Caye_2', 'Hicks Caye_3', 'Big Creek_6', 'Big Creek_3', 'Hicks Caye_1', 'Big Creek_5', 'Gra Gra Lagoon_3', 'Drowned Caye_1', 'Big Creek_2', 'Drowned Caye_5']
#   ❌ High-AGB sites failed: ['Channel Caye_2', 'Big Creek_6', 'Big Creek_3', 'Big Creek_5', 'Big Creek_2']
#   ⚠️  Grouped CV and test R² diverge (gap: 0.513 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.222 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height                                        0.3271  ================
#   NDRE1                                         0.1411  =======
#   CIrededge                                     0.1277  ======
#   NBR                                           0.0846  ====
#   Red                                           0.0489  ==
#   EVI                                           0.0470  ==
#   SWIR1                                         0.0291  =
#   NDRE2                                         0.0276  =
#   NIR                                           0.0253  =
#   NDVI                                          0.0220  =
#
# [10/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'n_estimators': 200, 'min_samples_leaf': 8, 'max_samples': 0.6, 'max_features': 'sqrt', 'max_depth': 5}
#
#  RANDOM FOREST: EXPERIMENT-10 Plot groups. Without LOW VARIANCE ROWS. With Grid, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : -0.0704
# Test RMSE   : 23.54 kg
# Train R² (log scale): 0.2746
# Train R² (orig scale): 0.1362
# Train RMSE  : 17.31 kg
# Num rows    : 2334
# Num Features: 22
#
#  Cross-validation ---
# CV R² mean: -0.0838
# CV R² std : 0.1260
# CV scores : [-0.06   0.12  -0.103 -0.1   -0.275]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.5266
# Grouped CV R² std : 1.8184
# Grouped CV scores : [-1.2600e-01 -6.1000e-02 -1.2590e+00 -1.4800e-01 -1.0000e-03 -0.0000e+00
#  -2.7710e+00 -4.0000e-02 -2.8000e-02 -1.4600e-01 -2.5000e-01 -6.6000e-02
#  -6.0000e-02 -1.0000e-03 -2.5400e-01 -1.0000e-02 -2.0000e-03 -6.1000e-02
#  -0.0000e+00 -7.8000e-02 -2.2000e-02 -5.0000e-03 -1.4000e-02 -6.9000e-02
#  -5.6000e-02 -1.0000e-03 -3.3000e-02 -6.3800e-01 -1.3700e-01 -0.0000e+00
#  -3.8000e-02 -1.0856e+01 -1.0180e+00 -3.7400e-01 -2.7400e-01 -6.2000e-02]
# ============================================================
#  EVALUATION: EXPERIMENT-10 Plot groups. Without LOW VARIANCE ROWS. With Grid, Features: ['height', 'Blue', 'Green', 'Red', 'RE1', 'RE2', 'RE3', 'NIR', 'SWIR1', 'SWIR2', 'NDVI', 'MNDWI', 'NBR', 'EVI', 'NDRE1', 'NDRE2', 'NDRE3', 'CIrededge', 'CLOUD_COVERAGE', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : -0.070
#   RMSE : 23.54 kg
#
# Regular CrossValidation:
#   Mean   : -0.084
#   Std    : 0.126
#   Scores : [-0.06   0.12  -0.103 -0.1   -0.275]
#
#   ❌ Test R² is negative (-0.070)
#   ❌ CV mean is negative (-0.084)
#
# Grouped CrossValidation:
#   Channel Caye_2       :  -0.126  ❌ negative — cause unknown
#   Hicks Caye_3         :  -0.061  ❌ negative — cause unknown
#   Big Creek_6          :  -1.259  ❌ negative — cause unknown
#   Big Creek_3          :  -0.148  ❌ negative — cause unknown
#   Hicks Caye_1         :  -0.001  ❌ negative — cause unknown
#   Big Creek_5          :  -0.000  ❌ negative — cause unknown
#   Gra Gra Lagoon_3     :  -2.771  ❌ negative — cause unknown
#   Drowned Caye_1       :  -0.040  ❌ negative — cause unknown
#   Big Creek_2          :  -0.028  ❌ negative — cause unknown
#   Drowned Caye_5       :  -0.146  ❌ negative — cause unknown
#
#   Mean : -0.527
#   Std  : 1.818
#
#   ❌ Grouped CV mean below 0.15 (-0.527)
#   ⚠️  Grouped CV std above 0.25 (1.818) — high variance across folds
#   ❌ Unexplained negative folds: ['Channel Caye_2', 'Hicks Caye_3', 'Big Creek_6', 'Big Creek_3', 'Hicks Caye_1', 'Big Creek_5', 'Gra Gra Lagoon_3', 'Drowned Caye_1', 'Big Creek_2', 'Drowned Caye_5']
#   ❌ High-AGB sites failed: ['Channel Caye_2', 'Big Creek_6', 'Big Creek_3', 'Big Creek_5', 'Big Creek_2']
#   ⚠️  Grouped CV and test R² diverge (gap: 0.456 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.207 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height_x_NDRE1                                0.1412  =======
#   height_x_NIR                                  0.1144  =====
#   height                                        0.1062  =====
#   height_x_EVI                                  0.1048  =====
#   NDRE1                                         0.0800  ====
#   NBR                                           0.0552  ==
#   CIrededge                                     0.0526  ==
#   NDRE2                                         0.0420  ==
#   NDVI                                          0.0393  =
#   EVI                                           0.0388  =
#
# [11/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'n_estimators': 100, 'min_samples_leaf': 8, 'max_samples': 0.6, 'max_features': 0.3, 'max_depth': 5}
#
#  RANDOM FOREST: EXPERIMENT-11 Plot groups. Without LOW VARIANCE ROWS. With Grid, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1'].
# Test R²     : -0.0691
# Test RMSE   : 23.53 kg
# Train R² (log scale): 0.2678
# Train R² (orig scale): 0.0947
# Train RMSE  : 17.72 kg
# Num rows    : 2334
# Num Features: 5
#
#  Cross-validation ---
# CV R² mean: -0.0936
# CV R² std : 0.1991
# CV scores : [-0.057  0.137 -0.055 -0.029 -0.465]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.1895
# Grouped CV R² std : 4.5578
# Grouped CV scores : [-9.9000e-02 -3.4000e-02 -6.8300e-01 -5.7000e-02 -0.0000e+00 -2.0000e-03
#  -7.1930e+00 -3.4000e-02 -4.0000e-02 -3.0000e-03 -3.3600e-01 -1.0800e-01
#  -6.2000e-02 -2.0000e-03 -9.0000e-03 -5.0000e-03 -0.0000e+00 -2.8000e-02
#  -1.0000e-03 -7.6000e-02 -4.1000e-02 -3.0000e-03 -0.0000e+00 -9.8000e-02
#  -3.0000e-02 -1.0000e-03 -2.7000e-02 -6.3900e-01 -6.5000e-02 -4.0000e-03
#  -3.7930e+00 -2.7012e+01 -4.4200e-01 -9.0500e-01 -2.0000e-02 -9.6800e-01]
# ============================================================
#  EVALUATION: EXPERIMENT-11 Plot groups. Without LOW VARIANCE ROWS. With Grid, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1'].
# ============================================================
#
# Test set:
#   R²   : -0.069
#   RMSE : 23.53 kg
#
# Regular CrossValidation:
#   Mean   : -0.094
#   Std    : 0.199
#   Scores : [-0.057  0.137 -0.055 -0.029 -0.465]
#
#   ❌ Test R² is negative (-0.069)
#   ❌ CV mean is negative (-0.094)
#
# Grouped CrossValidation:
#   Channel Caye_2       :  -0.099  ❌ negative — cause unknown
#   Hicks Caye_3         :  -0.034  ❌ negative — cause unknown
#   Big Creek_6          :  -0.683  ❌ negative — cause unknown
#   Big Creek_3          :  -0.057  ❌ negative — cause unknown
#   Hicks Caye_1         :  -0.000  ❌ negative — cause unknown
#   Big Creek_5          :  -0.002  ❌ negative — cause unknown
#   Gra Gra Lagoon_3     :  -7.193  ❌ negative — cause unknown
#   Drowned Caye_1       :  -0.034  ❌ negative — cause unknown
#   Big Creek_2          :  -0.040  ❌ negative — cause unknown
#   Drowned Caye_5       :  -0.003  ❌ negative — cause unknown
#
#   Mean : -1.189
#   Std  : 4.558
#
#   ❌ Grouped CV mean below 0.15 (-1.189)
#   ⚠️  Grouped CV std above 0.25 (4.558) — high variance across folds
#   ❌ Unexplained negative folds: ['Channel Caye_2', 'Hicks Caye_3', 'Big Creek_6', 'Big Creek_3', 'Hicks Caye_1', 'Big Creek_5', 'Gra Gra Lagoon_3', 'Drowned Caye_1', 'Big Creek_2', 'Drowned Caye_5']
#   ❌ High-AGB sites failed: ['Channel Caye_2', 'Big Creek_6', 'Big Creek_3', 'Big Creek_5', 'Big Creek_2']
#   ⚠️  Grouped CV and test R² diverge (gap: 1.120 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.164 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height                                        0.2807  ==============
#   NBR                                           0.2629  =============
#   EVI                                           0.1801  =========
#   NIR                                           0.1477  =======
#   SWIR1                                         0.1285  ======
#
# [12/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'n_estimators': 200, 'min_samples_leaf': 8, 'max_samples': 0.6, 'max_features': 'sqrt', 'max_depth': 5}
#
#  RANDOM FOREST: EXPERIMENT-12 Plot groups. Without LOW VARIANCE ROWS. With Grid, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : -0.0728
# Test RMSE   : 23.57 kg
# Train R² (log scale): 0.2740
# Train R² (orig scale): 0.1396
# Train RMSE  : 17.27 kg
# Num rows    : 2334
# Num Features: 8
#
#  Cross-validation ---
# CV R² mean: -0.0520
# CV R² std : 0.1279
# CV scores : [-0.08   0.125 -0.13   0.056 -0.231]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.5629
# Grouped CV R² std : 1.9356
# Grouped CV scores : [-1.4200e-01 -4.3000e-02 -2.4430e+00 -8.0000e-02 -0.0000e+00 -0.0000e+00
#  -2.0270e+00 -3.9000e-02 -3.8000e-02 -1.9000e-02 -3.9900e-01 -8.7000e-02
#  -8.3000e-02 -3.0000e-03 -2.5500e-01 -1.8000e-02 -5.0000e-03 -3.9000e-02
#  -1.0000e-03 -9.1000e-02 -5.5000e-02 -6.0000e-03 -2.1000e-02 -1.1800e-01
#  -5.0000e-02 -0.0000e+00 -4.7000e-02 -6.8400e-01 -2.6200e-01 -0.0000e+00
#  -7.4000e-02 -1.1584e+01 -1.0010e+00 -3.9700e-01 -5.7000e-02 -9.7000e-02]
# ============================================================
#  EVALUATION: EXPERIMENT-12 Plot groups. Without LOW VARIANCE ROWS. With Grid, Features: ['height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : -0.073
#   RMSE : 23.57 kg
#
# Regular CrossValidation:
#   Mean   : -0.052
#   Std    : 0.128
#   Scores : [-0.08   0.125 -0.13   0.056 -0.231]
#
#   ❌ Test R² is negative (-0.073)
#   ❌ CV mean is negative (-0.052)
#
# Grouped CrossValidation:
#   Channel Caye_2       :  -0.142  ❌ negative — cause unknown
#   Hicks Caye_3         :  -0.043  ❌ negative — cause unknown
#   Big Creek_6          :  -2.443  ❌ negative — cause unknown
#   Big Creek_3          :  -0.080  ❌ negative — cause unknown
#   Hicks Caye_1         :  -0.000  ❌ negative — cause unknown
#   Big Creek_5          :  -0.000  ❌ negative — cause unknown
#   Gra Gra Lagoon_3     :  -2.027  ❌ negative — cause unknown
#   Drowned Caye_1       :  -0.039  ❌ negative — cause unknown
#   Big Creek_2          :  -0.038  ❌ negative — cause unknown
#   Drowned Caye_5       :  -0.019  ❌ negative — cause unknown
#
#   Mean : -0.563
#   Std  : 1.936
#
#   ❌ Grouped CV mean below 0.15 (-0.563)
#   ⚠️  Grouped CV std above 0.25 (1.936) — high variance across folds
#   ❌ Unexplained negative folds: ['Channel Caye_2', 'Hicks Caye_3', 'Big Creek_6', 'Big Creek_3', 'Hicks Caye_1', 'Big Creek_5', 'Gra Gra Lagoon_3', 'Drowned Caye_1', 'Big Creek_2', 'Drowned Caye_5']
#   ❌ High-AGB sites failed: ['Channel Caye_2', 'Big Creek_6', 'Big Creek_3', 'Big Creek_5', 'Big Creek_2']
#   ⚠️  Grouped CV and test R² diverge (gap: 0.490 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.212 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height_x_NDRE1                                0.2131  ==========
#   height_x_EVI                                  0.2003  ==========
#   height                                        0.1842  =========
#   height_x_NIR                                  0.1389  ======
#   NBR                                           0.0999  ====
#   EVI                                           0.0860  ====
#   SWIR1                                         0.0406  ==
#   NIR                                           0.0372  =
#
# [13/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'n_estimators': 200, 'min_samples_leaf': 8, 'max_samples': 0.6, 'max_features': 'sqrt', 'max_depth': 5}
#
#  RANDOM FOREST: EXPERIMENT-13 Plot groups. Without LOW VARIANCE ROWS. With Grid, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1'].
# Test R²     : -0.0533
# Test RMSE   : 23.35 kg
# Train R² (log scale): 0.3151
# Train R² (orig scale): 0.1043
# Train RMSE  : 17.62 kg
# Num rows    : 2334
# Num Features: 8
#
#  Cross-validation ---
# CV R² mean: -0.0189
# CV R² std : 0.1550
# CV scores : [-0.037  0.126  0.148 -0.048 -0.284]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -1.1449
# Grouped CV R² std : 4.6204
# Grouped CV scores : [-9.9000e-02 -1.0600e-01 -7.6600e-01 -6.0000e-02  1.4000e-02 -1.3000e-02
#  -7.0290e+00  1.9100e-01  5.5000e-02 -7.0000e-03 -1.8300e-01  2.7500e-01
#  -4.6000e-02  7.0000e-03 -9.5000e-02 -5.0000e-02  8.8000e-02 -1.1000e-02
#   0.0000e+00 -1.2000e-02 -4.0000e-03 -3.0000e-02  2.0700e-01  2.3000e-01
#  -2.0000e-02  1.1000e-02  4.5000e-02 -4.6900e-01  2.9000e-02 -1.3500e-01
#  -3.7130e+00 -2.7383e+01 -4.9000e-01 -8.6900e-01 -2.5000e-02 -7.5400e-01]
# ============================================================
#  EVALUATION: EXPERIMENT-13 Plot groups. Without LOW VARIANCE ROWS. With Grid, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1'].
# ============================================================
#
# Test set:
#   R²   : -0.053
#   RMSE : 23.35 kg
#
# Regular CrossValidation:
#   Mean   : -0.019
#   Std    : 0.155
#   Scores : [-0.037  0.126  0.148 -0.048 -0.284]
#
#   ❌ Test R² is negative (-0.053)
#   ❌ CV mean is negative (-0.019)
#
# Grouped CrossValidation:
#   Channel Caye_2       :  -0.099  ❌ negative — cause unknown
#   Hicks Caye_3         :  -0.106  ❌ negative — cause unknown
#   Big Creek_6          :  -0.766  ❌ negative — cause unknown
#   Big Creek_3          :  -0.060  ❌ negative — cause unknown
#   Hicks Caye_1         :   0.014  ✅
#   Big Creek_5          :  -0.013  ❌ negative — cause unknown
#   Gra Gra Lagoon_3     :  -7.029  ❌ negative — cause unknown
#   Drowned Caye_1       :   0.191  ✅
#   Big Creek_2          :   0.055  ✅
#   Drowned Caye_5       :  -0.007  ❌ negative — cause unknown
#
#   Mean : -1.145
#   Std  : 4.620
#
#   ❌ Grouped CV mean below 0.15 (-1.145)
#   ⚠️  Grouped CV std above 0.25 (4.620) — high variance across folds
#   ❌ Unexplained negative folds: ['Channel Caye_2', 'Hicks Caye_3', 'Big Creek_6', 'Big Creek_3', 'Big Creek_5', 'Gra Gra Lagoon_3', 'Drowned Caye_5']
#   ❌ High-AGB sites failed: ['Channel Caye_2', 'Big Creek_6', 'Big Creek_3', 'Big Creek_5']
#   ⚠️  Grouped CV and test R² diverge (gap: 1.092 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.158 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height                                        0.2823  ==============
#   NBR                                           0.2026  ==========
#   EVI                                           0.1848  =========
#   NIR                                           0.1351  ======
#   SWIR1                                         0.0958  ====
#   species_Avicennia germinans                   0.0494  ==
#   species_Rhizophora mangle                     0.0456  ==
#   species_Laguncularia racemosa                 0.0045
#
# [14/18]
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params: {'n_estimators': 100, 'min_samples_leaf': 8, 'max_samples': 0.6, 'max_features': 0.3, 'max_depth': 5}
#
#  RANDOM FOREST: EXPERIMENT-14 Plot groups. Without LOW VARIANCE ROWS. With Grid, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# Test R²     : -0.0618
# Test RMSE   : 23.44 kg
# Train R² (log scale): 0.3206
# Train R² (orig scale): 0.1452
# Train RMSE  : 17.22 kg
# Num rows    : 2334
# Num Features: 11
#
#  Cross-validation ---
# CV R² mean: 0.0115
# CV R² std : 0.0945
# CV scores : [-0.07   0.107  0.092  0.058 -0.131]
#
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.4857
# Grouped CV R² std : 1.9857
# Grouped CV scores : [-1.4100e-01 -1.3000e-01 -1.6260e+00 -1.0700e-01  1.3000e-02 -2.0000e-02
#  -1.6410e+00  1.9500e-01  8.3000e-02  5.0000e-03 -2.8700e-01  2.8000e-01
#  -5.5000e-02  6.0000e-03 -1.8200e-01 -2.0000e-02  6.5000e-02 -6.1000e-02
#   5.0000e-03 -4.0000e-02 -9.0000e-03 -4.6000e-02  2.3700e-01  2.2000e-01
#  -6.5000e-02  3.0000e-02  6.0000e-03 -5.0200e-01 -2.2400e-01 -1.2100e-01
#   5.8000e-02 -1.1967e+01 -1.0420e+00 -2.3800e-01 -1.1900e-01 -4.7000e-02]
# ============================================================
#  EVALUATION: EXPERIMENT-14 Plot groups. Without LOW VARIANCE ROWS. With Grid, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ...
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /opt/anaconda3/envs/bkos/lib/python3.14/site-packages/sklearn/utils/parallel.py:144: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# Grouped Cross-validation ---
# Grouped CV R² mean: -0.4946
# Grouped CV R² std : 1.9328
# Grouped CV scores : [-1.4600e-01 -1.4800e-01 -1.9350e+00 -1.6500e-01  2.1000e-02 -1.4000e-02
#  -1.4990e+00  1.9100e-01  8.6000e-02 -9.2000e-02 -2.9800e-01  2.6900e-01
#  -5.1000e-02  6.0000e-03 -3.6400e-01 -1.7000e-02  6.3000e-02 -1.4300e-01
#   3.0000e-03 -3.1000e-02 -2.7000e-02 -4.3000e-02  2.1100e-01  2.2700e-01
#  -4.6000e-02  1.9000e-02  3.0000e-03 -5.3900e-01 -1.8000e-01 -9.8000e-02
#   1.1000e-01 -1.1625e+01 -1.0780e+00 -2.8700e-01 -5.0000e-02 -1.4300e-01]
# ============================================================
#  EVALUATION: EXPERIMENT-18 Plot groups. Without LOW VARIANCE ROWS. With Grid, Features: ['species', 'height', 'EVI', 'NIR', 'NBR', 'SWIR1', 'RE1', 'RE2', 'height_x_EVI', 'height_x_NIR', 'height_x_NDRE1'].
# ============================================================
#
# Test set:
#   R²   : -0.059
#   RMSE : 23.42 kg
#
# Regular CrossValidation:
#   Mean   : -0.006
#   Std    : 0.097
#   Scores : [-0.065  0.1    0.077  0.02  -0.162]
#
#   ❌ Test R² is negative (-0.059)
#   ❌ CV mean is negative (-0.006)
#
# Grouped CrossValidation:
#   Channel Caye_2       :  -0.146  ❌ negative — cause unknown
#   Hicks Caye_3         :  -0.148  ❌ negative — cause unknown
#   Big Creek_6          :  -1.935  ❌ negative — cause unknown
#   Big Creek_3          :  -0.165  ❌ negative — cause unknown
#   Hicks Caye_1         :   0.021  ✅
#   Big Creek_5          :  -0.014  ❌ negative — cause unknown
#   Gra Gra Lagoon_3     :  -1.499  ❌ negative — cause unknown
#   Drowned Caye_1       :   0.191  ✅
#   Big Creek_2          :   0.086  ✅
#   Drowned Caye_5       :  -0.092  ❌ negative — cause unknown
#
#   Mean : -0.495
#   Std  : 1.933
#
#   ❌ Grouped CV mean below 0.15 (-0.495)
#   ⚠️  Grouped CV std above 0.25 (1.933) — high variance across folds
#   ❌ Unexplained negative folds: ['Channel Caye_2', 'Hicks Caye_3', 'Big Creek_6', 'Big Creek_3', 'Big Creek_5', 'Gra Gra Lagoon_3', 'Drowned Caye_5']
#   ❌ High-AGB sites failed: ['Channel Caye_2', 'Big Creek_6', 'Big Creek_3', 'Big Creek_5']
#   ⚠️  Grouped CV and test R² diverge (gap: 0.435 > 0.05) — possible leakage or instability
#   ⚠️  Train R² well above test R² (gap: 0.201 > 0.1) — overfitting signal
#
# ────────────────────────────────────────────────────────────
# VERDICT: ❌ REJECTED
#
# Top 10 feature importances:
#   height_x_EVI                                  0.1614  ========
#   height                                        0.1514  =======
#   height_x_NDRE1                                0.1462  =======
#   height_x_NIR                                  0.1308  ======
#   NBR                                           0.0809  ====
#   EVI                                           0.0727  ===
#   RE2                                           0.0534  ==
#   RE1                                           0.0464  ==
#   species_Avicennia germinans                   0.0427  ==
#   NIR                                           0.0421  ==
#
# Completed: 18/18 experiments

# %%
tabulate_results(rf_belige_subset_grid_groups, acceptable_only=True)
# Out:
# Showing 0 acceptable experiments
# No acceptable experiments found.

# %% [markdown]
# **COMMENTS**
# Removing low-variance rows does not destroy test performance on the same plots. But it degrades grouped CV generalisation because the training distribution no longer spans the full ecological range, making the model less reliable when evaluated against unseen high-AGB plots in cross-validation.
#
# **What IS genuinely hurt is the grouped CV**
# Every experiment now has unexplained negative folds at high-AGB sites — Channel Caye_4, Channel Caye_5, Big Creek_2, Big Creek_3.
# This is the real effect of removing low-variance rows: the CV assignment shifts to harder, higher-variance folds, and the model trained without near-zero AGB examples cannot generalise across them consistently.
