# %% [markdown]
# A script to extract EMIT reflectance to points

# %%
# Import Packages
import sys
import os
import numpy as np
import pandas as pd
import holoviews as hv
import pandas as pd

# Import Packages
import earthaccess

import xarray as xr
import hvplot.pandas
import hvplot.xarray

#sys.path.append('../')
sys.path.append('EMIT-Data-Resources/python/modules/')

from emit_tools import emit_xarray
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='23fa12de-f92c-4b4a-bce2-ee753c53a169'>
#   <div id="bbe1a87f-b994-45b1-8108-8078ef9814a8" data-root-id="23fa12de-f92c-4b4a-bce2-ee753c53a169" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# Getting the working directory to inform the user

# %%
os.getcwd()
# Out:
# 'C:\\Users\\campb\\Documents'

# %%
earthaccess.login(persist=True)

# %%
url = 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/EMITL2ARFL.001/EMIT_L2A_RFL_001_20260125T172705_2602511_009/EMIT_L2A_RFL_001_20260125T172705_2602511_009.nc'
##Panama cifuentes https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/EMITL2ARFL.001/EMIT_L2A_RFL_001_20250523T182128_2514312_003/EMIT_L2A_RFL_001_20250523T182128_2514312_003.nc

# %%
# Get requests https Session using Earthdata Login Info
fs = earthaccess.get_requests_https_session()
# Retrieve granule asset ID from URL (to maintain existing naming convention)
granule_asset_id = url.split('/')[-1]
# Define Local Filepath
fp = f'C:/Users/campb/Documents/{granule_asset_id}'
# Download the Granule Asset if it doesn't exist
if not os.path.isfile(fp):
    with fs.get(url,stream=True) as src:
        with open(fp,'wb') as dst:
            for chunk in src.iter_content(chunk_size=64*1024*1024):
                dst.write(chunk)

# %%
ds = emit_xarray(fp, ortho=True)
ds
# Out:
# <xarray.Dataset> Size: 4GB
# Dimensions:           (latitude: 1884, longitude: 1990, wavelengths: 285)
# Coordinates:
#   * latitude          (latitude) float64 15kB 17.84 17.84 17.84 ... 16.82 16.82
#   * longitude         (longitude) float64 16kB -88.49 -88.48 ... -87.41 -87.41
#     elev              (latitude, longitude) float32 15MB nan nan nan ... nan nan
#   * wavelengths       (wavelengths) float32 1kB 380.9 388.3 ... 2.493e+03
#     fwhm              (wavelengths) float32 1kB ...
#     good_wavelengths  (wavelengths) float32 1kB ...
#     spatial_ref       int32 4B 0
# Data variables:
#     reflectance       (latitude, longitude, wavelengths) float32 4GB nan ... nan
# Attributes: (12/39)
#     ncei_template_version:             NCEI_NetCDF_Swath_Template_v2.0
#     summary:                           The Earth Surface Mineral Dust Source ...
#     keywords:                          Imaging Spectroscopy, minerals, EMIT, ...
#     Conventions:                       CF-1.63
# ...

# %%
ds.latitude.max()
# Out:
# <xarray.DataArray 'latitude' ()> Size: 8B
# array(17.83614388)
# Coordinates:
#     spatial_ref  int32 4B 0
# Attributes:
#     long_name:  Latitude (WGS-84)
#     units:      degrees north

# %%
ds.latitude.min()
# Out:
# <xarray.DataArray 'latitude' ()> Size: 8B
# array(16.81512005)
# Coordinates:
#     spatial_ref  int32 4B 0
# Attributes:
#     long_name:  Latitude (WGS-84)
#     units:      degrees north

# %%
ds.longitude.max()
# Out:
# <xarray.DataArray 'longitude' ()> Size: 8B
# array(-87.40680289)
# Coordinates:
#     spatial_ref  int32 4B 0
# Attributes:
#     long_name:  Longitude (WGS-84)
#     units:      degrees east

# %%
ds.longitude.min()
# Out:
# <xarray.DataArray 'longitude' ()> Size: 8B
# array(-88.48530337)
# Coordinates:
#     spatial_ref  int32 4B 0
# Attributes:
#     long_name:  Longitude (WGS-84)
#     units:      degrees east

# %%
points = pd.read_csv('C:/Users/campb/Downloads/Morrissette_et_al_2023_plots.csv')
points
# Out:
#       Id                study_id         site_id             plot_id  year  \
# 0      1  Morrissette_et_al_2023      Hicks Caye      Hicks Caye_1_1  2021
# 1      2  Morrissette_et_al_2023      Hicks Caye      Hicks Caye_1_2  2021
# 2      3  Morrissette_et_al_2023      Hicks Caye      Hicks Caye_1_3  2021
# 3      4  Morrissette_et_al_2023      Hicks Caye      Hicks Caye_1_4  2021
# 4      5  Morrissette_et_al_2023      Hicks Caye      Hicks Caye_1_5  2021
# ..   ...                     ...             ...                 ...   ...
# 108  109  Morrissette_et_al_2023  Turneffe Atoll  Turneffe Atoll_2_4  2022
# 109  110  Morrissette_et_al_2023  Turneffe Atoll  Turneffe Atoll_2_5  2022
# 110  111  Morrissette_et_al_2023  Turneffe Atoll  Turneffe Atoll_2_6  2022
# 111  112  Morrissette_et_al_2023    Channel Caye    Channel Caye_S_1  2021
# 112  113  Morrissette_et_al_2023    Channel Caye    Channel Caye_S_2  2021
#
#      month  day   latitude  longitude position_method  ...  \
# ...

# %%
#ds.sel(wavelengths=850,method='nearest').hvplot.image(cmap='greys', frame_height=600, frame_width=600, geo=True, crs='EPSG:4326').opts(title=f"Example Points")*\
#points.hvplot.points(x='longitude',y='latitude', by='Id', color=hv.Cycle('Dark2'), geo=True, crs='EPSG:4326')

# %%
points = points.set_index(['Id'])

# %%
xp = points.to_xarray()
xp
# Out:
# <xarray.Dataset> Size: 26kB
# Dimensions:                     (Id: 113)
# Coordinates:
#   * Id                          (Id) int64 904B 1 2 3 4 5 ... 110 111 112 113
# Data variables: (12/30)
#     study_id                    (Id) object 904B 'Morrissette_et_al_2023' ......
#     site_id                     (Id) object 904B 'Hicks Caye' ... 'Channel Caye'
#     plot_id                     (Id) object 904B 'Hicks Caye_1_1' ... 'Channe...
#     year                        (Id) int64 904B 2021 2021 2021 ... 2021 2021
#     month                       (Id) int64 904B 9 9 9 9 9 9 9 ... 3 3 3 3 3 9 9
#     day                         (Id) int64 904B 2 2 2 2 2 2 ... 11 11 11 10 10
#     ...                          ...
#     vegetation_class            (Id) object 904B 'forested' ... 'seagrass'
#     plot_shape                  (Id) object 904B 'circular' ... 'circular'
#     coordinates_obscured_flag   (Id) object 904B 'not obscured' ... 'not obsc...
# ...

# %%
extracted = ds.sel(latitude=xp.latitude,longitude=xp.longitude, method='nearest').to_dataframe()
extracted
# Out:
#                  reflectance   fwhm  good_wavelengths   latitude  longitude  \
# Id  wavelengths
# 1   380.857880      0.020274  8.415               1.0  17.691368 -88.116043
#     388.261475      0.020874  8.415               1.0  17.691368 -88.116043
#     395.668091      0.021483  8.415               1.0  17.691368 -88.116043
#     403.077698      0.022109  8.415               1.0  17.691368 -88.116043
#     410.490265      0.023012  8.417               1.0  17.691368 -88.116043
# ...                      ...    ...               ...        ...        ...
# 113 2463.233887          NaN  8.803               1.0  16.815120 -88.164302
#     2470.620117          NaN  8.804               1.0  16.815120 -88.164302
#     2478.005371          NaN  8.806               1.0  16.815120 -88.164302
#     2485.390869          NaN  8.807               1.0  16.815120 -88.164302
#     2492.776123          NaN  8.809               1.0  16.815120 -88.164302
#
#                      elev  spatial_ref
# ...

# %%
filtered_df = extracted[extracted['good_wavelengths'] == 1]
#change file name to reflect a particular scene and CCN dataset
filtered_df.to_csv('C:/Users/campb/Documents/morrisette_out_20260125T172705.csv')

# %%
df = pd.read_csv('C:/Users/campb/Documents/morrisette_out_20260125T172705.csv')

# %%
# Data values are slightly different than -0.01 because of floating point precision, which requires a tolerance to be set
#1068 caye
#5875 lagoon
#3804 riverine
#df2 = df[df['Id']==1068]
df2 = df.loc[df['Id'].isin([1,7,100])]

#df2 = df({'Id': [200,300,400,500]})
df2['reflectance'] = df2['reflectance'].where(abs(df2['reflectance'] - (-0.01)) > 1e-8, np.nan)

df2
# Out:
#         Id  wavelengths  reflectance   fwhm  good_wavelengths   latitude  \
# 0        1    380.85788     0.020274  8.415               1.0  17.691368
# 1        1    388.26147     0.020874  8.415               1.0  17.691368
# 2        1    395.66810     0.021483  8.415               1.0  17.691368
# 3        1    403.07770     0.022109  8.415               1.0  17.691368
# 4        1    410.49026     0.023012  8.417               1.0  17.691368
# ...    ...          ...          ...    ...               ...        ...
# 25495  100   2463.23400     0.014251  8.803               1.0  17.287947
# 25496  100   2470.62000     0.015019  8.804               1.0  17.287947
# 25497  100   2478.00540     0.014578  8.806               1.0  17.287947
# 25498  100   2485.39090     0.014131  8.807               1.0  17.287947
# 25499  100   2492.77610     0.013690  8.809               1.0  17.287947
#
#        longitude      elev  spatial_ref
# 0     -88.116043 -6.412017            0
# ...

# %%
df2.hvplot(x='wavelengths',y='reflectance', by=['Id'], color=hv.Cycle('Dark2'), frame_height=400, frame_width=600).opts(title='Example Points - Reflectance', xlabel='Wavelengths (nm)',ylabel='Reflectance')
# Out:
# :NdOverlay   [Id]
#    :Curve   [wavelengths]   (reflectance)
